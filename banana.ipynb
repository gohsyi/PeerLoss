# %% [markdown]
# # Banana Dataset

# %% [markdown]
# | | |
# |:-:|:-:|
# |    Total    |  5300 |
# |   Positive  | 44.8% |
# |  Attributes |   2  |

# %%
import pandas as pd

pd.read_csv('uci/banana.csv').describe()
# Out:
#                   x             y       target
# count  5.300000e+03  5.300000e+03  5300.000000
# mean  -3.889075e-10 -3.304355e-10     0.448302
# std    1.000000e+00  1.000000e+00     0.497367
# min   -3.089839e+00 -2.385937e+00     0.000000
# 25%   -7.533486e-01 -9.139026e-01     0.000000
# 50%   -1.523143e-02 -3.721518e-02     0.000000
# 75%    7.818310e-01  8.221039e-01     1.000000
# max    2.813360e+00  3.194302e+00     1.000000

# %%
from runner import run

arg_dict = {
    'dataset': 'banana', 
    'lr': 0.001, 
    'hidsize': 8, 
    'episodes': 100, 
    'batchsize': 256, 
    'test_size': 0.25,
    'dropout': 0.5,
    'normalize': False,
    'equalize_prior': False
}

# %%
from utils.dataloader import UCIDataLoader

dataset = UCIDataLoader('banana')
X_train, X_test, y_train, y_test = dataset.train_test_split()

# %%
y_train
# Out:
# array([1., 1., 1., ..., 1., 1., 0.])

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.scatter(X_train[y_train==0, 0], X_train[y_train==0, 1], s=3, alpha=0.5)
plt.scatter(X_train[y_train==1, 0], X_train[y_train==1, 1], s=3, alpha=0.5)

# %%
plt.scatter(X_test[y_test==0, 0], X_test[y_test==0, 1], s=3, alpha=0.5)
plt.scatter(X_test[y_test==1, 0], X_test[y_test==1, 1], s=3, alpha=0.5)

# %% [markdown]
# $e_0 = 0, e_1 = 0$

# %%
arg_dict.update({'e0': 0, 'e1': 0})
run(arg_dict.copy())
# Out:
# {'dataset': 'banana', 'lr': 0.001, 'hidsize': 8, 'episodes': 100, 'batchsize': 256, 'test_size': 0.25, 'dropout': 0.5, 'normalize': False, 'equalize_prior': False, 'e0': 0, 'e1': 0}
# --------------------------------------
# | knn                     | 0.891    |
# | logistic regression     | 0.555    |
# | nn                      | 0.743    |
# | nn with peer prediction | 0.606    |
# | random forest           | 0.893    |
# | svm                     | 0.902    |
# --------------------------------------

# %% [markdown]
# $e_0 = 0.1, e_1 = 0.3$

# %%
arg_dict.update({'e0': 0.2, 'e1': 0.2})
run(arg_dict.copy())
# Out:
# {'dataset': 'banana', 'lr': 0.001, 'hidsize': 8, 'episodes': 100, 'batchsize': 256, 'test_size': 0.25, 'dropout': 0.5, 'normalize': False, 'equalize_prior': False, 'e0': 0.2, 'e1': 0.2}
# --------------------------------------
# | knn                     | 0.834    |
# | logistic regression     | 0.545    |
# | nn                      | 0.695    |
# | nn with peer prediction | 0.599    |
# | random forest           | 0.828    |
# | svm                     | 0.895    |
# --------------------------------------

# %%
arg_dict.update({'e0': 0.1, 'e1': 0.3})
run(arg_dict.copy())
# Out:
# {'dataset': 'banana', 'lr': 0.001, 'hidsize': 8, 'episodes': 100, 'batchsize': 256, 'test_size': 0.25, 'dropout': 0.5, 'normalize': False, 'equalize_prior': False, 'e0': 0.1, 'e1': 0.3}
# --------------------------------------
# | knn                     | 0.825    |
# | logistic regression     | 0.553    |
# | nn                      | 0.558    |
# | nn with peer prediction | 0.604    |
# | random forest           | 0.815    |
# | svm                     | 0.888    |
# --------------------------------------

# %% [markdown]
# $e_0 = 0.2, e_1 = 0.4$

# %%
arg_dict.update({'e0': 0.2, 'e1': 0.4})
run(arg_dict.copy())
# Out:
# {'dataset': 'banana', 'lr': 0.001, 'hidsize': 8, 'episodes': 100, 'batchsize': 256, 'test_size': 0.25, 'dropout': 0.5, 'normalize': False, 'equalize_prior': False, 'e0': 0.2, 'e1': 0.4}
# --------------------------------------
# | knn                     | 0.749    |
# | logistic regression     | 0.553    |
# | nn                      | 0.553    |
# | nn with peer prediction | 0.594    |
# | random forest           | 0.741    |
# | svm                     | 0.825    |
# --------------------------------------

# %%
arg_dict.update({'e0': 0.4, 'e1': 0.4})
run(arg_dict.copy())
# Out:
# {'dataset': 'banana', 'lr': 0.001, 'hidsize': 8, 'episodes': 100, 'batchsize': 256, 'test_size': 0.25, 'dropout': 0.5, 'normalize': False, 'equalize_prior': False, 'e0': 0.4, 'e1': 0.4}
# --------------------------------------
# | knn                     | 0.635    |
# | logistic regression     | 0.528    |
# | nn                      | 0.596    |
# | nn with peer prediction | 0.557    |
# | random forest           | 0.632    |
# | svm                     | 0.874    |
# --------------------------------------

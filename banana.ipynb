# %% [markdown]
# # Banana Dataset

# %% [markdown]
# | | |
# |:-:|:-:|
# |    Total    |  5300 |
# |   Positive  | 44.8% |
# |  Attributes |   2  |

# %%
import pandas as pd

pd.read_csv('uci/banana.csv').describe()
# Out:
#                   x             y       target
# count  5.300000e+03  5.300000e+03  5300.000000
# mean  -3.889075e-10 -3.304355e-10     0.448302
# std    1.000000e+00  1.000000e+00     0.497367
# min   -3.089839e+00 -2.385937e+00     0.000000
# 25%   -7.533486e-01 -9.139026e-01     0.000000
# 50%   -1.523143e-02 -3.721518e-02     0.000000
# 75%    7.818310e-01  8.221039e-01     1.000000
# max    2.813360e+00  3.194302e+00     1.000000

# %%
from runner import run

arg_dict = {
    'dataset': 'banana', 
    'lr': 0.001, 
    'hidsize': 8, 
    'episodes': 100, 
    'batchsize': 256, 
    'test_size': 0.25,
    'dropout': 0.5,
    'normalize': False,
}

# %%
from utils.dataloader import UCIDataLoader

dataset = UCIDataLoader('banana')
X_train, X_test, y_train, y_test = dataset.train_test_split()

# %%
y_train
# Out:
# array([1., 1., 1., ..., 1., 1., 0.])

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.scatter(X_train[y_train==0, 0], X_train[y_train==0, 1], s=3, alpha=0.5)
plt.scatter(X_train[y_train==1, 0], X_train[y_train==1, 1], s=3, alpha=0.5)

# %%
plt.scatter(X_test[y_test==0, 0], X_test[y_test==0, 1], s=3, alpha=0.5)
plt.scatter(X_test[y_test==1, 0], X_test[y_test==1, 1], s=3, alpha=0.5)

# %% [markdown]
# $e_0 = 0, e_1 = 0$

# %%
arg_dict.update({'e0': 0, 'e1': 0})
run(arg_dict.copy())
# Out:
# {'dataset': 'banana', 'lr': 0.001, 'hidsize': 8, 'episodes': 100, 'batchsize': 256, 'test_size': 0.25, 'dropout': 0.5, 'normalize': False, 'e0': 0, 'e1': 0}
# --------------------------------------
# | knn                     | 0.887    |
# | logistic regression     | 0.555    |
# | nn                      | 0.733    |
# | nn with peer prediction | 0.587    |
# | random forest           | 0.891    |
# | svm                     | 0.9      |
# --------------------------------------

# %% [markdown]
# $e_0 = 0.1, e_1 = 0.3$

# %%
arg_dict.update({'e0': 0.1, 'e1': 0.3})
run(arg_dict.copy())
# Out:
# {'dataset': 'banana', 'lr': 0.001, 'hidsize': 8, 'episodes': 100, 'batchsize': 256, 'test_size': 0.25, 'dropout': 0.5, 'normalize': False, 'e0': 0.1, 'e1': 0.3}
# --------------------------------------
# | knn                     | 0.811    |
# | logistic regression     | 0.5      |
# | nn                      | 0.512    |
# | nn with peer prediction | 0.584    |
# | random forest           | 0.803    |
# | svm                     | 0.883    |
# --------------------------------------

# %% [markdown]
# $e_0 = 0.2, e_1 = 0.4$

# %%
arg_dict.update({'e0': 0.2, 'e1': 0.4})
run(arg_dict.copy())
# Out:
# {'dataset': 'banana', 'lr': 0.001, 'hidsize': 8, 'episodes': 100, 'batchsize': 256, 'test_size': 0.25, 'dropout': 0.5, 'normalize': False, 'e0': 0.2, 'e1': 0.4}
# --------------------------------------
# | knn                     | 0.73     |
# | logistic regression     | 0.5      |
# | nn                      | 0.502    |
# | nn with peer prediction | 0.578    |
# | random forest           | 0.723    |
# | svm                     | 0.835    |
# --------------------------------------

# %%
arg_dict.update({'e0': 0.4, 'e1': 0.4})
run(arg_dict.copy())
# Out:
# {'dataset': 'banana', 'lr': 0.001, 'hidsize': 8, 'episodes': 100, 'batchsize': 256, 'test_size': 0.25, 'dropout': 0.5, 'normalize': False, 'e0': 0.4, 'e1': 0.4}
# --------------------------------------
# | knn                     | 0.635    |
# | logistic regression     | 0.513    |
# | nn                      | 0.623    |
# | nn with peer prediction | 0.553    |
# | random forest           | 0.63     |
# | svm                     | 0.866    |
# --------------------------------------

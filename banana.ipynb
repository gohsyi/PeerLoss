# %% [markdown]
# # Banana Dataset

# %%
from runner import run

arg_dict = {
    'dataset': 'banana', 
    'lr': 0.001, 
    'hidsize': 8, 
    'episodes': 100, 
    'batchsize': 10, 
    'test_size': 0.50,
    'dropout': 0.
}

# %% [markdown]
# $e_0 = 0, e_1 = 0$

# %%
arg_dict.update({'e0': 0, 'e1': 0})
run(arg_dict.copy())
# Out:
# {'dataset': 'banana', 'lr': 0.001, 'hidsize': 8, 'episodes': 100, 'batchsize': 10, 'test_size': 0.5, 'dropout': 0.0, 'e0': 0, 'e1': 0}
# --------------------------------------
# | knn                     | 0.887    |
# | logistic regression     | 0.538    |
# | nn                      | 0.886    |
# | nn with peer prediction | 0.62     |
# | random forest           | 0.884    |
# | svm                     | 0.911    |
# --------------------------------------

# %%
arg_dict.update({'e0': 0, 'e1': 0})
run(arg_dict.copy())
# Out:
# {'dataset': 'banana', 'lr': 0.001, 'hidsize': 8, 'episodes': 100, 'batchsize': 10, 'test_size': 0.8, 'dropout': 0.0, 'e0': 0, 'e1': 0}
# --------------------------------------
# | knn                     | 0.902    |
# | logistic regression     | 0.572    |
# | nn with bce             | 0.835    |
# | nn with peer prediction | 0.644    |
# | random forest           | 0.897    |
# | svm                     | 0.906    |
# --------------------------------------

# %% [markdown]
# $e_0 = 0.1, e_1 = 0.3$

# %%
arg_dict.update({'e0': 0.1, 'e1': 0.3})
run(arg_dict.copy())
# Out:
# {'dataset': 'banana', 'lr': 0.001, 'hidsize': 8, 'episodes': 100, 'batchsize': 10, 'test_size': 0.8, 'dropout': 0.0, 'e0': 0.1, 'e1': 0.3}
# --------------------------------------
# | knn                     | 0.794    |
# | logistic regression     | 0.514    |
# | nn with bce             | 0.745    |
# | nn with peer prediction | 0.61     |
# | random forest           | 0.801    |
# | svm                     | 0.888    |
# --------------------------------------

# %% [markdown]
# $e_0 = 0.2, e_1 = 0.4$

# %%
arg_dict.update({'e0': 0.2, 'e1': 0.4})
run(arg_dict.copy())
# Out:
# {'dataset': 'banana', 'lr': 0.001, 'hidsize': 8, 'episodes': 100, 'batchsize': 10, 'test_size': 0.8, 'dropout': 0.0, 'e0': 0.2, 'e1': 0.4}
# --------------------------------------
# | knn                     | 0.74     |
# | logistic regression     | 0.498    |
# | nn with bce             | 0.669    |
# | nn with peer prediction | 0.608    |
# | random forest           | 0.721    |
# | svm                     | 0.781    |
# --------------------------------------

# %% [markdown]
# # Breast (30,212,357)

# %% [markdown]
# ## Describe
#
# | Total | Positive | Attributes | Normalized |
# |:-----:|:--------:|:----------:|:----------:|
# |  569  |   0.37   |     30     |     Not    |

# %%
default_args = {
    'dataset': 'breast2',
    'test_size': 0.15,
    'val_size': 0.1,
    'dropout': 0, 
    'normalize': True,
    'loss': 'bce',
    'activation': 'relu',
    'verbose': True,
}

# %% [markdown]
# ## With Prior Equalization

# %% [markdown]
# ### $e_0 = 0.1, e_1 = 0.3$

# %%
from runner import run
args = default_args.copy()
args.update({
    'dataset': 'breast2', 
    'e0': 0.1, 'e1': 0.3, 
    'equalize_prior': True, 
    'episodes': 1000, 
#     'batchsize': 64, 
#     'hidsize': [64, 64], 
#     'lr': 0.001, 
    'alpha': 1.,
})
run(args)
# Out:
# Logging to logs/nn/19-08-28-15-52-36
# {'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'dataset': 'breast2', 'e0': 0.1, 'e1': 0.3, 'equalize_prior': True, 'episodes': 1000, 'alpha': 1.0}
# acc:0.912	batchsize: 1	lr:0.0007	hidsize:[8, 8]
# acc:0.916	batchsize: 1	lr:0.0007	hidsize:[16, 16]
# acc:0.922	batchsize: 1	lr:0.0007	hidsize:[32, 32]
# acc:0.916	batchsize: 1	lr:0.0007	hidsize:[64, 64]
# acc:0.916	batchsize: 1	lr: 0.001	hidsize:[8, 8]
# acc:0.926	batchsize: 1	lr: 0.001	hidsize:[16, 16]
# acc:0.924	batchsize: 1	lr: 0.001	hidsize:[32, 32]
# acc:0.918	batchsize: 1	lr: 0.001	hidsize:[64, 64]
# acc:0.918	batchsize: 1	lr: 0.005	hidsize:[8, 8]
# acc:0.928	batchsize: 1	lr: 0.005	hidsize:[16, 16]
# acc:0.924	batchsize: 1	lr: 0.005	hidsize:[32, 32]
# acc:0.924	batchsize: 1	lr: 0.005	hidsize:[64, 64]
# acc:0.871	batchsize: 1	lr:  0.01	hidsize:[8, 8]
# acc:0.926	batchsize: 1	lr:  0.01	hidsize:[16, 16]
# acc:0.926	batchsize: 1	lr:  0.01	hidsize:[32, 32]
# acc:0.926	batchsize: 1	lr:  0.01	hidsize:[64, 64]
# acc:0.686	batchsize: 1	lr:  0.05	hidsize:[8, 8]
# acc:0.85	batchsize: 1	lr:  0.05	hidsize:[16, 16]
# acc:0.924	batchsize: 1	lr:  0.05	hidsize:[32, 32]
# acc:0.92	batchsize: 1	lr:  0.05	hidsize:[64, 64]
# acc:0.918	batchsize: 4	lr:0.0007	hidsize:[8, 8]
# acc:0.922	batchsize: 4	lr:0.0007	hidsize:[16, 16]
# acc:0.918	batchsize: 4	lr:0.0007	hidsize:[32, 32]
# acc:0.912	batchsize: 4	lr:0.0007	hidsize:[64, 64]
# acc:0.916	batchsize: 4	lr: 0.001	hidsize:[8, 8]
# acc:0.92	batchsize: 4	lr: 0.001	hidsize:[16, 16]
# acc:0.918	batchsize: 4	lr: 0.001	hidsize:[32, 32]
# acc:0.91	batchsize: 4	lr: 0.001	hidsize:[64, 64]
# acc:0.914	batchsize: 4	lr: 0.005	hidsize:[8, 8]
# acc:0.918	batchsize: 4	lr: 0.005	hidsize:[16, 16]
# acc:0.912	batchsize: 4	lr: 0.005	hidsize:[32, 32]
# acc:0.908	batchsize: 4	lr: 0.005	hidsize:[64, 64]
# acc:0.85	batchsize: 4	lr:  0.01	hidsize:[8, 8]
# acc:0.91	batchsize: 4	lr:  0.01	hidsize:[16, 16]
# acc:0.912	batchsize: 4	lr:  0.01	hidsize:[32, 32]
# acc:0.91	batchsize: 4	lr:  0.01	hidsize:[64, 64]
# acc:0.852	batchsize: 4	lr:  0.05	hidsize:[8, 8]
# acc:0.908	batchsize: 4	lr:  0.05	hidsize:[16, 16]
# acc:0.912	batchsize: 4	lr:  0.05	hidsize:[32, 32]
# acc:0.916	batchsize: 4	lr:  0.05	hidsize:[64, 64]
# acc:0.92	batchsize:16	lr:0.0007	hidsize:[8, 8]
# acc:0.924	batchsize:16	lr:0.0007	hidsize:[16, 16]
# acc:0.918	batchsize:16	lr:0.0007	hidsize:[32, 32]
# acc:0.91	batchsize:16	lr:0.0007	hidsize:[64, 64]
# acc:0.922	batchsize:16	lr: 0.001	hidsize:[8, 8]
# acc:0.922	batchsize:16	lr: 0.001	hidsize:[16, 16]
# acc:0.914	batchsize:16	lr: 0.001	hidsize:[32, 32]
# acc:0.91	batchsize:16	lr: 0.001	hidsize:[64, 64]
# acc:0.91	batchsize:16	lr: 0.005	hidsize:[8, 8]
# acc:0.912	batchsize:16	lr: 0.005	hidsize:[16, 16]
# acc:0.91	batchsize:16	lr: 0.005	hidsize:[32, 32]
# acc:0.908	batchsize:16	lr: 0.005	hidsize:[64, 64]
# acc:0.906	batchsize:16	lr:  0.01	hidsize:[8, 8]
# acc:0.91	batchsize:16	lr:  0.01	hidsize:[16, 16]
# acc:0.908	batchsize:16	lr:  0.01	hidsize:[32, 32]
# acc:0.906	batchsize:16	lr:  0.01	hidsize:[64, 64]
# acc:0.906	batchsize:16	lr:  0.05	hidsize:[8, 8]
# acc:0.91	batchsize:16	lr:  0.05	hidsize:[16, 16]
# acc:0.906	batchsize:16	lr:  0.05	hidsize:[32, 32]
# acc:0.912	batchsize:16	lr:  0.05	hidsize:[64, 64]
# acc:0.92	batchsize:32	lr:0.0007	hidsize:[8, 8]
# acc:0.924	batchsize:32	lr:0.0007	hidsize:[16, 16]
# acc:0.912	batchsize:32	lr:0.0007	hidsize:[32, 32]
# acc:0.906	batchsize:32	lr:0.0007	hidsize:[64, 64]
# acc:0.918	batchsize:32	lr: 0.001	hidsize:[8, 8]
# acc:0.92	batchsize:32	lr: 0.001	hidsize:[16, 16]
# acc:0.908	batchsize:32	lr: 0.001	hidsize:[32, 32]
# acc:0.908	batchsize:32	lr: 0.001	hidsize:[64, 64]
# acc:0.908	batchsize:32	lr: 0.005	hidsize:[8, 8]
# acc:0.916	batchsize:32	lr: 0.005	hidsize:[16, 16]
# acc:0.908	batchsize:32	lr: 0.005	hidsize:[32, 32]
# acc:0.902	batchsize:32	lr: 0.005	hidsize:[64, 64]
# acc:0.91	batchsize:32	lr:  0.01	hidsize:[8, 8]
# acc:0.912	batchsize:32	lr:  0.01	hidsize:[16, 16]
# acc:0.906	batchsize:32	lr:  0.01	hidsize:[32, 32]
# acc:0.902	batchsize:32	lr:  0.01	hidsize:[64, 64]
# acc:0.906	batchsize:32	lr:  0.05	hidsize:[8, 8]
# acc:0.914	batchsize:32	lr:  0.05	hidsize:[16, 16]
# acc:0.906	batchsize:32	lr:  0.05	hidsize:[32, 32]
# acc:0.904	batchsize:32	lr:  0.05	hidsize:[64, 64]
# acc:0.918	batchsize:64	lr:0.0007	hidsize:[8, 8]
# acc:0.916	batchsize:64	lr:0.0007	hidsize:[16, 16]
# acc:0.914	batchsize:64	lr:0.0007	hidsize:[32, 32]
# acc:0.902	batchsize:64	lr:0.0007	hidsize:[64, 64]
# acc:0.91	batchsize:64	lr: 0.001	hidsize:[8, 8]
# acc:0.912	batchsize:64	lr: 0.001	hidsize:[16, 16]
# acc:0.912	batchsize:64	lr: 0.001	hidsize:[32, 32]
# acc:0.904	batchsize:64	lr: 0.001	hidsize:[64, 64]
# acc:0.908	batchsize:64	lr: 0.005	hidsize:[8, 8]
# acc:0.906	batchsize:64	lr: 0.005	hidsize:[16, 16]
# acc:0.91	batchsize:64	lr: 0.005	hidsize:[32, 32]
# acc:0.902	batchsize:64	lr: 0.005	hidsize:[64, 64]
# acc:0.904	batchsize:64	lr:  0.01	hidsize:[8, 8]
# acc:0.906	batchsize:64	lr:  0.01	hidsize:[16, 16]
# acc:0.908	batchsize:64	lr:  0.01	hidsize:[32, 32]
# acc:0.902	batchsize:64	lr:  0.01	hidsize:[64, 64]
# acc:0.902	batchsize:64	lr:  0.05	hidsize:[8, 8]
# acc:0.92	batchsize:64	lr:  0.05	hidsize:[16, 16]
# acc:0.902	batchsize:64	lr:  0.05	hidsize:[32, 32]
# acc: 0.9	batchsize:64	lr:  0.05	hidsize:[64, 64]
# --------------------------------------
# | [PEER] best batchsize   | 1        |
# | [PEER] best hidsize     | [16, 16] |
# | [PEER] best learning... | 0.005    |
# --------------------------------------
# --------------------------------------
# | [NN] with bce loss      | 0.873    |
# | [NN] with peer loss     | 0.928    |
# | [NN] with surrogate ... | 0.922    |
# --------------------------------------
# Logging to logs/svm/19-08-28-15-58-02
# {'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'dataset': 'breast2', 'e0': 0.1, 'e1': 0.3, 'equalize_prior': True, 'episodes': 1000, 'alpha': 1.0}
# --------------------------------
# | [C-SVM] C1 = 0.1  | 0.605    |
# | [C-SVM] C1 = 0.2  | 0.605    |
# | [C-SVM] C1 = 0.25 | 0.602    |
# | [C-SVM] C1 = 0.33 | 0.61     |
# | [C-SVM] C1 = 0.5  | 0.706    |
# | [C-SVM] C1 = 1.0  | 0.797    |
# | [C-SVM] C1 = 10.0 | 0.584    |
# | [C-SVM] C1 = 2.0  | 0.797    |
# | [C-SVM] C1 = 3.0  | 0.788    |
# | [C-SVM] C1 = 4.0  | 0.782    |
# | [C-SVM] C1 = 5.0  | 0.765    |
# --------------------------------
# ------------------------------------
# | [C-SVM] accuracy max  | 0.953    |
# | [C-SVM] accuracy mean | 0.924    |
# | [C-SVM] accuracy min  | 0.875    |
# | [C-SVM] accuracy std  | 0.0286   |
# | [C-SVM] best C1       | 1        |
# ------------------------------------
# Logging to logs/pam/19-08-28-15-58-03
# {'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'dataset': 'breast2', 'e0': 0.1, 'e1': 0.3, 'equalize_prior': True, 'episodes': 1000, 'alpha': 1.0}
# -----------------------------------
# | [PAM] margin = 0     | 0.692    |
# | [PAM] margin = 0.125 | 0.762    |
# | [PAM] margin = 0.25  | 0.753    |
# | [PAM] margin = 0.5   | 0.767    |
# | [PAM] margin = 1     | 0.773    |
# -----------------------------------
# ----------------------------------
# | [PAM] accuracy max  | 0.969    |
# | [PAM] accuracy mean | 0.898    |
# | [PAM] accuracy min  | 0.859    |
# | [PAM] accuracy std  | 0.0303   |
# | [PAM] best margin   | 1        |
# ----------------------------------

# %% [markdown]
# ### $e_0 = 0.2, e_1 = 0.2$

# %%
from runner import run
args = default_args.copy()
args.update({
    'dataset': 'breast2', 
    'e0': 0.2, 'e1': 0.2, 
    'equalize_prior': True, 
    'episodes': 1000, 
#     'batchsize': 64, 
#     'hidsize': [64, 64], 
#     'lr': 0.001, 
    'alpha': 1.,
})
run(args)
# Out:
# Logging to logs/nn/19-08-28-15-58-07
# {'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'dataset': 'breast2', 'e0': 0.2, 'e1': 0.2, 'equalize_prior': True, 'episodes': 1000, 'alpha': 1.0}
# acc:0.91	batchsize: 1	lr:0.0007	hidsize:[8, 8]
# acc:0.92	batchsize: 1	lr:0.0007	hidsize:[16, 16]
# acc:0.926	batchsize: 1	lr:0.0007	hidsize:[32, 32]
# acc:0.92	batchsize: 1	lr:0.0007	hidsize:[64, 64]
# acc:0.916	batchsize: 1	lr: 0.001	hidsize:[8, 8]
# acc:0.922	batchsize: 1	lr: 0.001	hidsize:[16, 16]
# acc:0.924	batchsize: 1	lr: 0.001	hidsize:[32, 32]
# acc:0.922	batchsize: 1	lr: 0.001	hidsize:[64, 64]
# acc:0.924	batchsize: 1	lr: 0.005	hidsize:[8, 8]
# acc:0.924	batchsize: 1	lr: 0.005	hidsize:[16, 16]
# acc:0.928	batchsize: 1	lr: 0.005	hidsize:[32, 32]
# acc:0.922	batchsize: 1	lr: 0.005	hidsize:[64, 64]
# acc:0.92	batchsize: 1	lr:  0.01	hidsize:[8, 8]
# acc:0.924	batchsize: 1	lr:  0.01	hidsize:[16, 16]
# acc:0.924	batchsize: 1	lr:  0.01	hidsize:[32, 32]
# acc:0.922	batchsize: 1	lr:  0.01	hidsize:[64, 64]
# acc:0.861	batchsize: 1	lr:  0.05	hidsize:[8, 8]
# acc:0.812	batchsize: 1	lr:  0.05	hidsize:[16, 16]
# acc:0.811	batchsize: 1	lr:  0.05	hidsize:[32, 32]
# acc:0.916	batchsize: 1	lr:  0.05	hidsize:[64, 64]
# acc:0.906	batchsize: 4	lr:0.0007	hidsize:[8, 8]
# acc:0.92	batchsize: 4	lr:0.0007	hidsize:[16, 16]
# acc:0.918	batchsize: 4	lr:0.0007	hidsize:[32, 32]
# acc:0.912	batchsize: 4	lr:0.0007	hidsize:[64, 64]
# acc:0.906	batchsize: 4	lr: 0.001	hidsize:[8, 8]
# acc:0.918	batchsize: 4	lr: 0.001	hidsize:[16, 16]
# acc:0.914	batchsize: 4	lr: 0.001	hidsize:[32, 32]
# acc:0.908	batchsize: 4	lr: 0.001	hidsize:[64, 64]
# acc:0.914	batchsize: 4	lr: 0.005	hidsize:[8, 8]
# acc:0.914	batchsize: 4	lr: 0.005	hidsize:[16, 16]
# acc:0.91	batchsize: 4	lr: 0.005	hidsize:[32, 32]
# acc:0.908	batchsize: 4	lr: 0.005	hidsize:[64, 64]
# acc:0.908	batchsize: 4	lr:  0.01	hidsize:[8, 8]
# acc:0.912	batchsize: 4	lr:  0.01	hidsize:[16, 16]
# acc:0.91	batchsize: 4	lr:  0.01	hidsize:[32, 32]
# acc:0.908	batchsize: 4	lr:  0.01	hidsize:[64, 64]
# acc:0.898	batchsize: 4	lr:  0.05	hidsize:[8, 8]
# acc:0.908	batchsize: 4	lr:  0.05	hidsize:[16, 16]
# acc:0.912	batchsize: 4	lr:  0.05	hidsize:[32, 32]
# acc:0.908	batchsize: 4	lr:  0.05	hidsize:[64, 64]
# acc:0.916	batchsize:16	lr:0.0007	hidsize:[8, 8]
# acc:0.918	batchsize:16	lr:0.0007	hidsize:[16, 16]
# acc:0.916	batchsize:16	lr:0.0007	hidsize:[32, 32]
# acc:0.908	batchsize:16	lr:0.0007	hidsize:[64, 64]
# acc:0.916	batchsize:16	lr: 0.001	hidsize:[8, 8]
# acc:0.918	batchsize:16	lr: 0.001	hidsize:[16, 16]
# acc:0.914	batchsize:16	lr: 0.001	hidsize:[32, 32]
# acc:0.908	batchsize:16	lr: 0.001	hidsize:[64, 64]
# acc:0.918	batchsize:16	lr: 0.005	hidsize:[8, 8]
# acc:0.918	batchsize:16	lr: 0.005	hidsize:[16, 16]
# acc:0.908	batchsize:16	lr: 0.005	hidsize:[32, 32]
# acc:0.908	batchsize:16	lr: 0.005	hidsize:[64, 64]
# acc:0.912	batchsize:16	lr:  0.01	hidsize:[8, 8]
# acc:0.916	batchsize:16	lr:  0.01	hidsize:[16, 16]
# acc:0.908	batchsize:16	lr:  0.01	hidsize:[32, 32]
# acc:0.904	batchsize:16	lr:  0.01	hidsize:[64, 64]
# acc:0.912	batchsize:16	lr:  0.05	hidsize:[8, 8]
# acc:0.91	batchsize:16	lr:  0.05	hidsize:[16, 16]
# acc:0.908	batchsize:16	lr:  0.05	hidsize:[32, 32]
# acc:0.91	batchsize:16	lr:  0.05	hidsize:[64, 64]
# acc:0.912	batchsize:32	lr:0.0007	hidsize:[8, 8]
# acc:0.916	batchsize:32	lr:0.0007	hidsize:[16, 16]
# acc:0.912	batchsize:32	lr:0.0007	hidsize:[32, 32]
# acc:0.908	batchsize:32	lr:0.0007	hidsize:[64, 64]
# acc:0.912	batchsize:32	lr: 0.001	hidsize:[8, 8]
# acc:0.918	batchsize:32	lr: 0.001	hidsize:[16, 16]
# acc:0.91	batchsize:32	lr: 0.001	hidsize:[32, 32]
# acc:0.908	batchsize:32	lr: 0.001	hidsize:[64, 64]
# acc:0.91	batchsize:32	lr: 0.005	hidsize:[8, 8]
# acc:0.912	batchsize:32	lr: 0.005	hidsize:[16, 16]
# acc:0.908	batchsize:32	lr: 0.005	hidsize:[32, 32]
# acc:0.902	batchsize:32	lr: 0.005	hidsize:[64, 64]
# acc:0.91	batchsize:32	lr:  0.01	hidsize:[8, 8]
# acc:0.912	batchsize:32	lr:  0.01	hidsize:[16, 16]
# acc:0.908	batchsize:32	lr:  0.01	hidsize:[32, 32]
# acc:0.902	batchsize:32	lr:  0.01	hidsize:[64, 64]
# acc:0.912	batchsize:32	lr:  0.05	hidsize:[8, 8]
# acc:0.91	batchsize:32	lr:  0.05	hidsize:[16, 16]
# acc:0.904	batchsize:32	lr:  0.05	hidsize:[32, 32]
# acc:0.902	batchsize:32	lr:  0.05	hidsize:[64, 64]
# acc:0.91	batchsize:64	lr:0.0007	hidsize:[8, 8]
# acc:0.91	batchsize:64	lr:0.0007	hidsize:[16, 16]
# acc:0.906	batchsize:64	lr:0.0007	hidsize:[32, 32]
# acc:0.904	batchsize:64	lr:0.0007	hidsize:[64, 64]
# acc:0.91	batchsize:64	lr: 0.001	hidsize:[8, 8]
# acc:0.91	batchsize:64	lr: 0.001	hidsize:[16, 16]
# acc:0.908	batchsize:64	lr: 0.001	hidsize:[32, 32]
# acc:0.904	batchsize:64	lr: 0.001	hidsize:[64, 64]
# acc:0.906	batchsize:64	lr: 0.005	hidsize:[8, 8]
# acc:0.908	batchsize:64	lr: 0.005	hidsize:[16, 16]
# acc:0.906	batchsize:64	lr: 0.005	hidsize:[32, 32]
# acc:0.902	batchsize:64	lr: 0.005	hidsize:[64, 64]
# acc:0.908	batchsize:64	lr:  0.01	hidsize:[8, 8]
# acc:0.904	batchsize:64	lr:  0.01	hidsize:[16, 16]
# acc:0.902	batchsize:64	lr:  0.01	hidsize:[32, 32]
# acc:0.902	batchsize:64	lr:  0.01	hidsize:[64, 64]
# acc:0.904	batchsize:64	lr:  0.05	hidsize:[8, 8]
# acc:0.906	batchsize:64	lr:  0.05	hidsize:[16, 16]
# acc:0.902	batchsize:64	lr:  0.05	hidsize:[32, 32]
# acc:0.902	batchsize:64	lr:  0.05	hidsize:[64, 64]
# --------------------------------------
# | [PEER] best batchsize   | 1        |
# | [PEER] best hidsize     | [32, 32] |
# | [PEER] best learning... | 0.005    |
# --------------------------------------
# --------------------------------------
# | [NN] with bce loss      | 0.887    |
# | [NN] with peer loss     | 0.928    |
# | [NN] with surrogate ... | 0.904    |
# --------------------------------------
# Logging to logs/svm/19-08-28-16-03-23
# {'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'dataset': 'breast2', 'e0': 0.2, 'e1': 0.2, 'equalize_prior': True, 'episodes': 1000, 'alpha': 1.0}
# --------------------------------
# | [C-SVM] C1 = 0.1  | 0.5      |
# | [C-SVM] C1 = 0.2  | 0.523    |
# | [C-SVM] C1 = 0.25 | 0.552    |
# | [C-SVM] C1 = 0.33 | 0.686    |
# | [C-SVM] C1 = 0.5  | 0.747    |
# | [C-SVM] C1 = 1.0  | 0.779    |
# | [C-SVM] C1 = 10.0 | 0.529    |
# | [C-SVM] C1 = 2.0  | 0.753    |
# | [C-SVM] C1 = 3.0  | 0.709    |
# | [C-SVM] C1 = 4.0  | 0.616    |
# | [C-SVM] C1 = 5.0  | 0.576    |
# --------------------------------
# ------------------------------------
# | [C-SVM] accuracy max  | 0.984    |
# | [C-SVM] accuracy mean | 0.961    |
# | [C-SVM] accuracy min  | 0.922    |
# | [C-SVM] accuracy std  | 0.0191   |
# | [C-SVM] best C1       | 1        |
# ------------------------------------
# Logging to logs/pam/19-08-28-16-03-24
# {'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'dataset': 'breast2', 'e0': 0.2, 'e1': 0.2, 'equalize_prior': True, 'episodes': 1000, 'alpha': 1.0}
# -----------------------------------
# | [PAM] margin = 0     | 0.642    |
# | [PAM] margin = 0.125 | 0.759    |
# | [PAM] margin = 0.25  | 0.767    |
# | [PAM] margin = 0.5   | 0.773    |
# | [PAM] margin = 1     | 0.776    |
# -----------------------------------
# ----------------------------------
# | [PAM] accuracy max  | 0.969    |
# | [PAM] accuracy mean | 0.934    |
# | [PAM] accuracy min  | 0.875    |
# | [PAM] accuracy std  | 0.0268   |
# | [PAM] best margin   | 1        |
# ----------------------------------

# %% [markdown]
# ### $e_0 = 0.1, e_1 = 0.4$

# %%
from runner import run
args = default_args.copy()
args.update({
    'dataset': 'breast2', 
    'e0': 0.1, 'e1': 0.4, 
    'equalize_prior': True, 
    'episodes': 1000, 
#     'batchsize': 64, 
#     'hidsize': [64, 64], 
#     'lr': 0.001, 
    'alpha': 1.,
})
run(args)
# Out:
# Logging to logs/nn/19-08-29-09-36-49
# {'dataset': 'breast2', 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'e0': 0.1, 'e1': 0.4, 'equalize_prior': True, 'episodes': 1000, 'alpha': 1.0}
# acc: 0.9	batchsize: 1	lr:0.0007	hidsize:[8, 8]
# acc:0.916	batchsize: 1	lr:0.0007	hidsize:[16, 16]
# acc:0.932	batchsize: 1	lr:0.0007	hidsize:[32, 32]
# acc:0.92	batchsize: 1	lr:0.0007	hidsize:[64, 64]
# acc:0.906	batchsize: 1	lr: 0.001	hidsize:[8, 8]
# acc:0.924	batchsize: 1	lr: 0.001	hidsize:[16, 16]
# acc:0.922	batchsize: 1	lr: 0.001	hidsize:[32, 32]
# acc:0.918	batchsize: 1	lr: 0.001	hidsize:[64, 64]
# acc:0.916	batchsize: 1	lr: 0.005	hidsize:[8, 8]
# acc:0.926	batchsize: 1	lr: 0.005	hidsize:[16, 16]
# acc:0.924	batchsize: 1	lr: 0.005	hidsize:[32, 32]
# acc:0.918	batchsize: 1	lr: 0.005	hidsize:[64, 64]
# acc:0.863	batchsize: 1	lr:  0.01	hidsize:[8, 8]
# acc:0.926	batchsize: 1	lr:  0.01	hidsize:[16, 16]
# acc:0.916	batchsize: 1	lr:  0.01	hidsize:[32, 32]
# acc:0.926	batchsize: 1	lr:  0.01	hidsize:[64, 64]
# acc:0.734	batchsize: 1	lr:  0.05	hidsize:[8, 8]
# acc:0.922	batchsize: 1	lr:  0.05	hidsize:[16, 16]
# acc:0.918	batchsize: 1	lr:  0.05	hidsize:[32, 32]
# acc:0.918	batchsize: 1	lr:  0.05	hidsize:[64, 64]
# acc:0.914	batchsize: 4	lr:0.0007	hidsize:[8, 8]
# acc:0.93	batchsize: 4	lr:0.0007	hidsize:[16, 16]
# acc:0.93	batchsize: 4	lr:0.0007	hidsize:[32, 32]
# acc:0.92	batchsize: 4	lr:0.0007	hidsize:[64, 64]
# acc:0.92	batchsize: 4	lr: 0.001	hidsize:[8, 8]
# acc:0.93	batchsize: 4	lr: 0.001	hidsize:[16, 16]
# acc:0.928	batchsize: 4	lr: 0.001	hidsize:[32, 32]
# acc:0.92	batchsize: 4	lr: 0.001	hidsize:[64, 64]
# acc:0.922	batchsize: 4	lr: 0.005	hidsize:[8, 8]
# acc:0.918	batchsize: 4	lr: 0.005	hidsize:[16, 16]
# acc:0.922	batchsize: 4	lr: 0.005	hidsize:[32, 32]
# acc:0.922	batchsize: 4	lr: 0.005	hidsize:[64, 64]
# acc:0.918	batchsize: 4	lr:  0.01	hidsize:[8, 8]
# acc:0.867	batchsize: 4	lr:  0.01	hidsize:[16, 16]
# acc:0.922	batchsize: 4	lr:  0.01	hidsize:[32, 32]
# acc:0.918	batchsize: 4	lr:  0.01	hidsize:[64, 64]
# acc:0.916	batchsize: 4	lr:  0.05	hidsize:[8, 8]
# acc:0.865	batchsize: 4	lr:  0.05	hidsize:[16, 16]
# acc:0.922	batchsize: 4	lr:  0.05	hidsize:[32, 32]
# acc:0.92	batchsize: 4	lr:  0.05	hidsize:[64, 64]
# acc:0.924	batchsize:16	lr:0.0007	hidsize:[8, 8]
# acc:0.922	batchsize:16	lr:0.0007	hidsize:[16, 16]
# acc:0.92	batchsize:16	lr:0.0007	hidsize:[32, 32]
# acc:0.916	batchsize:16	lr:0.0007	hidsize:[64, 64]
# acc:0.922	batchsize:16	lr: 0.001	hidsize:[8, 8]
# acc:0.922	batchsize:16	lr: 0.001	hidsize:[16, 16]
# acc:0.916	batchsize:16	lr: 0.001	hidsize:[32, 32]
# acc:0.916	batchsize:16	lr: 0.001	hidsize:[64, 64]
# acc:0.916	batchsize:16	lr: 0.005	hidsize:[8, 8]
# acc:0.92	batchsize:16	lr: 0.005	hidsize:[16, 16]
# acc:0.914	batchsize:16	lr: 0.005	hidsize:[32, 32]
# acc:0.916	batchsize:16	lr: 0.005	hidsize:[64, 64]
# acc:0.914	batchsize:16	lr:  0.01	hidsize:[8, 8]
# acc:0.916	batchsize:16	lr:  0.01	hidsize:[16, 16]
# acc:0.912	batchsize:16	lr:  0.01	hidsize:[32, 32]
# acc:0.914	batchsize:16	lr:  0.01	hidsize:[64, 64]
# acc:0.916	batchsize:16	lr:  0.05	hidsize:[8, 8]
# acc:0.918	batchsize:16	lr:  0.05	hidsize:[16, 16]
# acc:0.912	batchsize:16	lr:  0.05	hidsize:[32, 32]
# acc:0.906	batchsize:16	lr:  0.05	hidsize:[64, 64]
# acc:0.92	batchsize:32	lr:0.0007	hidsize:[8, 8]
# acc:0.92	batchsize:32	lr:0.0007	hidsize:[16, 16]
# acc:0.916	batchsize:32	lr:0.0007	hidsize:[32, 32]
# acc:0.914	batchsize:32	lr:0.0007	hidsize:[64, 64]
# acc:0.92	batchsize:32	lr: 0.001	hidsize:[8, 8]
# acc:0.916	batchsize:32	lr: 0.001	hidsize:[16, 16]
# acc:0.916	batchsize:32	lr: 0.001	hidsize:[32, 32]
# acc:0.914	batchsize:32	lr: 0.001	hidsize:[64, 64]
# acc:0.914	batchsize:32	lr: 0.005	hidsize:[8, 8]
# acc:0.914	batchsize:32	lr: 0.005	hidsize:[16, 16]
# acc:0.908	batchsize:32	lr: 0.005	hidsize:[32, 32]
# acc:0.91	batchsize:32	lr: 0.005	hidsize:[64, 64]
# acc:0.916	batchsize:32	lr:  0.01	hidsize:[8, 8]
# acc:0.914	batchsize:32	lr:  0.01	hidsize:[16, 16]
# acc:0.91	batchsize:32	lr:  0.01	hidsize:[32, 32]
# acc:0.912	batchsize:32	lr:  0.01	hidsize:[64, 64]
# acc:0.914	batchsize:32	lr:  0.05	hidsize:[8, 8]
# acc:0.916	batchsize:32	lr:  0.05	hidsize:[16, 16]
# acc:0.908	batchsize:32	lr:  0.05	hidsize:[32, 32]
# acc:0.912	batchsize:32	lr:  0.05	hidsize:[64, 64]
# acc:0.922	batchsize:64	lr:0.0007	hidsize:[8, 8]
# acc:0.922	batchsize:64	lr:0.0007	hidsize:[16, 16]
# acc:0.914	batchsize:64	lr:0.0007	hidsize:[32, 32]
# acc:0.91	batchsize:64	lr:0.0007	hidsize:[64, 64]
# acc:0.92	batchsize:64	lr: 0.001	hidsize:[8, 8]
# acc:0.92	batchsize:64	lr: 0.001	hidsize:[16, 16]
# acc:0.914	batchsize:64	lr: 0.001	hidsize:[32, 32]
# acc:0.91	batchsize:64	lr: 0.001	hidsize:[64, 64]
# acc:0.912	batchsize:64	lr: 0.005	hidsize:[8, 8]
# acc:0.918	batchsize:64	lr: 0.005	hidsize:[16, 16]
# acc:0.91	batchsize:64	lr: 0.005	hidsize:[32, 32]
# acc:0.906	batchsize:64	lr: 0.005	hidsize:[64, 64]
# acc:0.91	batchsize:64	lr:  0.01	hidsize:[8, 8]
# acc:0.916	batchsize:64	lr:  0.01	hidsize:[16, 16]
# acc:0.91	batchsize:64	lr:  0.01	hidsize:[32, 32]
# acc:0.902	batchsize:64	lr:  0.01	hidsize:[64, 64]
# acc:0.908	batchsize:64	lr:  0.05	hidsize:[8, 8]
# acc:0.914	batchsize:64	lr:  0.05	hidsize:[16, 16]
# acc:0.904	batchsize:64	lr:  0.05	hidsize:[32, 32]
# acc:0.904	batchsize:64	lr:  0.05	hidsize:[64, 64]
# --------------------------------------
# | [PEER] best batchsize   | 1        |
# | [PEER] best hidsize     | [32, 32] |
# | [PEER] best learning... | 0.0007   |
# --------------------------------------
# --------------------------------------
# | [NN] with bce loss      | 0.83     |
# | [NN] with peer loss     | 0.932    |
# | [NN] with surrogate ... | 0.938    |
# --------------------------------------
# Logging to logs/svm/19-08-29-09-41-57
# {'dataset': 'breast2', 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'e0': 0.1, 'e1': 0.4, 'equalize_prior': True, 'episodes': 1000, 'alpha': 1.0}
# --------------------------------
# | [C-SVM] C1 = 0.1  | 0.654    |
# | [C-SVM] C1 = 0.2  | 0.654    |
# | [C-SVM] C1 = 0.25 | 0.654    |
# | [C-SVM] C1 = 0.33 | 0.651    |
# | [C-SVM] C1 = 0.5  | 0.657    |
# | [C-SVM] C1 = 1.0  | 0.77     |
# | [C-SVM] C1 = 10.0 | 0.549    |
# | [C-SVM] C1 = 2.0  | 0.759    |
# | [C-SVM] C1 = 3.0  | 0.75     |
# | [C-SVM] C1 = 4.0  | 0.733    |
# | [C-SVM] C1 = 5.0  | 0.706    |
# --------------------------------
# ------------------------------------
# | [C-SVM] accuracy max  | 0.875    |
# | [C-SVM] accuracy mean | 0.85     |
# | [C-SVM] accuracy min  | 0.797    |
# | [C-SVM] accuracy std  | 0.022    |
# | [C-SVM] best C1       | 1        |
# ------------------------------------
# Logging to logs/pam/19-08-29-09-41-57
# {'dataset': 'breast2', 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'e0': 0.1, 'e1': 0.4, 'equalize_prior': True, 'episodes': 1000, 'alpha': 1.0}
# -----------------------------------
# | [PAM] margin = 0     | 0.68     |
# | [PAM] margin = 0.125 | 0.703    |
# | [PAM] margin = 0.25  | 0.715    |
# | [PAM] margin = 0.5   | 0.715    |
# | [PAM] margin = 1     | 0.73     |
# -----------------------------------
# ----------------------------------
# | [PAM] accuracy max  | 0.906    |
# | [PAM] accuracy mean | 0.812    |
# | [PAM] accuracy min  | 0.75     |
# | [PAM] accuracy std  | 0.0428   |
# | [PAM] best margin   | 1        |
# ----------------------------------

# %% [markdown]
# ### $e_0 = 0.2, e_1 = 0.4$

# %%
from runner import run
args = default_args.copy()
args.update({
    'dataset': 'breast2', 
    'e0': 0.2, 'e1': 0.4, 
    'equalize_prior': True, 
    'episodes': 1000, 
#     'batchsize': 64, 
#     'hidsize': [64, 64], 
#     'lr': 0.001, 
    'alpha': 1.,
})
run(args)
# Out:
# Logging to logs/nn/19-08-28-17-18-40
# {'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'dataset': 'breast2', 'e0': 0.2, 'e1': 0.4, 'equalize_prior': True, 'episodes': 1000, 'alpha': 1.0}
# acc:0.846	batchsize: 1	lr:0.0007	hidsize:[8, 8]
# acc:0.891	batchsize: 1	lr:0.0007	hidsize:[16, 16]
# acc:0.922	batchsize: 1	lr:0.0007	hidsize:[32, 32]
# acc:0.918	batchsize: 1	lr:0.0007	hidsize:[64, 64]
# acc: 0.9	batchsize: 1	lr: 0.001	hidsize:[8, 8]
# acc:0.904	batchsize: 1	lr: 0.001	hidsize:[16, 16]
# acc:0.928	batchsize: 1	lr: 0.001	hidsize:[32, 32]
# acc:0.914	batchsize: 1	lr: 0.001	hidsize:[64, 64]
# acc:0.92	batchsize: 1	lr: 0.005	hidsize:[8, 8]
# acc:0.922	batchsize: 1	lr: 0.005	hidsize:[16, 16]
# acc:0.918	batchsize: 1	lr: 0.005	hidsize:[32, 32]
# acc:0.914	batchsize: 1	lr: 0.005	hidsize:[64, 64]
# acc:0.93	batchsize: 1	lr:  0.01	hidsize:[8, 8]
# acc:0.928	batchsize: 1	lr:  0.01	hidsize:[16, 16]
# acc:0.916	batchsize: 1	lr:  0.01	hidsize:[32, 32]
# acc:0.928	batchsize: 1	lr:  0.01	hidsize:[64, 64]
# acc:0.818	batchsize: 1	lr:  0.05	hidsize:[8, 8]
# acc:0.742	batchsize: 1	lr:  0.05	hidsize:[16, 16]
# acc:0.912	batchsize: 1	lr:  0.05	hidsize:[32, 32]
# acc:0.902	batchsize: 1	lr:  0.05	hidsize:[64, 64]
# acc:0.908	batchsize: 4	lr:0.0007	hidsize:[8, 8]
# acc:0.924	batchsize: 4	lr:0.0007	hidsize:[16, 16]
# acc:0.926	batchsize: 4	lr:0.0007	hidsize:[32, 32]
# acc:0.92	batchsize: 4	lr:0.0007	hidsize:[64, 64]
# acc:0.912	batchsize: 4	lr: 0.001	hidsize:[8, 8]
# acc:0.922	batchsize: 4	lr: 0.001	hidsize:[16, 16]
# acc:0.93	batchsize: 4	lr: 0.001	hidsize:[32, 32]
# acc:0.92	batchsize: 4	lr: 0.001	hidsize:[64, 64]
# acc:0.92	batchsize: 4	lr: 0.005	hidsize:[8, 8]
# acc:0.924	batchsize: 4	lr: 0.005	hidsize:[16, 16]
# acc:0.918	batchsize: 4	lr: 0.005	hidsize:[32, 32]
# acc:0.922	batchsize: 4	lr: 0.005	hidsize:[64, 64]
# acc:0.914	batchsize: 4	lr:  0.01	hidsize:[8, 8]
# acc:0.926	batchsize: 4	lr:  0.01	hidsize:[16, 16]
# acc:0.922	batchsize: 4	lr:  0.01	hidsize:[32, 32]
# acc:0.92	batchsize: 4	lr:  0.01	hidsize:[64, 64]
# acc:0.85	batchsize: 4	lr:  0.05	hidsize:[8, 8]
# acc:0.869	batchsize: 4	lr:  0.05	hidsize:[16, 16]
# acc:0.92	batchsize: 4	lr:  0.05	hidsize:[32, 32]
# acc:0.865	batchsize: 4	lr:  0.05	hidsize:[64, 64]
# acc:0.912	batchsize:16	lr:0.0007	hidsize:[8, 8]
# acc:0.922	batchsize:16	lr:0.0007	hidsize:[16, 16]
# acc:0.924	batchsize:16	lr:0.0007	hidsize:[32, 32]
# acc:0.916	batchsize:16	lr:0.0007	hidsize:[64, 64]
# acc:0.92	batchsize:16	lr: 0.001	hidsize:[8, 8]
# acc:0.926	batchsize:16	lr: 0.001	hidsize:[16, 16]
# acc:0.922	batchsize:16	lr: 0.001	hidsize:[32, 32]
# acc:0.918	batchsize:16	lr: 0.001	hidsize:[64, 64]
# acc:0.922	batchsize:16	lr: 0.005	hidsize:[8, 8]
# acc:0.918	batchsize:16	lr: 0.005	hidsize:[16, 16]
# acc:0.918	batchsize:16	lr: 0.005	hidsize:[32, 32]
# acc:0.916	batchsize:16	lr: 0.005	hidsize:[64, 64]
# acc:0.914	batchsize:16	lr:  0.01	hidsize:[8, 8]
# acc:0.918	batchsize:16	lr:  0.01	hidsize:[16, 16]
# acc:0.914	batchsize:16	lr:  0.01	hidsize:[32, 32]
# acc:0.916	batchsize:16	lr:  0.01	hidsize:[64, 64]
# acc:0.914	batchsize:16	lr:  0.05	hidsize:[8, 8]
# acc:0.92	batchsize:16	lr:  0.05	hidsize:[16, 16]
# acc:0.914	batchsize:16	lr:  0.05	hidsize:[32, 32]
# acc:0.914	batchsize:16	lr:  0.05	hidsize:[64, 64]
# acc:0.914	batchsize:32	lr:0.0007	hidsize:[8, 8]
# acc:0.918	batchsize:32	lr:0.0007	hidsize:[16, 16]
# acc:0.922	batchsize:32	lr:0.0007	hidsize:[32, 32]
# acc:0.912	batchsize:32	lr:0.0007	hidsize:[64, 64]
# acc:0.914	batchsize:32	lr: 0.001	hidsize:[8, 8]
# acc:0.918	batchsize:32	lr: 0.001	hidsize:[16, 16]
# acc:0.92	batchsize:32	lr: 0.001	hidsize:[32, 32]
# acc:0.912	batchsize:32	lr: 0.001	hidsize:[64, 64]
# acc:0.912	batchsize:32	lr: 0.005	hidsize:[8, 8]
# acc:0.914	batchsize:32	lr: 0.005	hidsize:[16, 16]
# acc:0.912	batchsize:32	lr: 0.005	hidsize:[32, 32]
# acc:0.91	batchsize:32	lr: 0.005	hidsize:[64, 64]
# acc:0.916	batchsize:32	lr:  0.01	hidsize:[8, 8]
# acc:0.914	batchsize:32	lr:  0.01	hidsize:[16, 16]
# acc:0.91	batchsize:32	lr:  0.01	hidsize:[32, 32]
# acc:0.91	batchsize:32	lr:  0.01	hidsize:[64, 64]
# acc:0.91	batchsize:32	lr:  0.05	hidsize:[8, 8]
# acc:0.91	batchsize:32	lr:  0.05	hidsize:[16, 16]
# acc:0.91	batchsize:32	lr:  0.05	hidsize:[32, 32]
# acc:0.906	batchsize:32	lr:  0.05	hidsize:[64, 64]
# acc:0.914	batchsize:64	lr:0.0007	hidsize:[8, 8]
# acc:0.918	batchsize:64	lr:0.0007	hidsize:[16, 16]
# acc:0.916	batchsize:64	lr:0.0007	hidsize:[32, 32]
# acc:0.91	batchsize:64	lr:0.0007	hidsize:[64, 64]
# acc:0.914	batchsize:64	lr: 0.001	hidsize:[8, 8]
# acc:0.918	batchsize:64	lr: 0.001	hidsize:[16, 16]
# acc:0.916	batchsize:64	lr: 0.001	hidsize:[32, 32]
# acc:0.912	batchsize:64	lr: 0.001	hidsize:[64, 64]
# acc:0.916	batchsize:64	lr: 0.005	hidsize:[8, 8]
# acc:0.916	batchsize:64	lr: 0.005	hidsize:[16, 16]
# acc:0.916	batchsize:64	lr: 0.005	hidsize:[32, 32]
# acc:0.91	batchsize:64	lr: 0.005	hidsize:[64, 64]
# acc:0.916	batchsize:64	lr:  0.01	hidsize:[8, 8]
# acc:0.916	batchsize:64	lr:  0.01	hidsize:[16, 16]
# acc:0.912	batchsize:64	lr:  0.01	hidsize:[32, 32]
# acc:0.91	batchsize:64	lr:  0.01	hidsize:[64, 64]
# acc:0.912	batchsize:64	lr:  0.05	hidsize:[8, 8]
# acc:0.91	batchsize:64	lr:  0.05	hidsize:[16, 16]
# acc:0.904	batchsize:64	lr:  0.05	hidsize:[32, 32]
# acc:0.898	batchsize:64	lr:  0.05	hidsize:[64, 64]
# --------------------------------------
# | [PEER] best batchsize   | 1        |
# | [PEER] best hidsize     | [8, 8]   |
# | [PEER] best learning... | 0.01     |
# --------------------------------------
# --------------------------------------
# | [NN] with bce loss      | 0.844    |
# | [NN] with peer loss     | 0.93     |
# | [NN] with surrogate ... | 0.885    |
# --------------------------------------
# Logging to logs/svm/19-08-28-17-24-06
# {'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'dataset': 'breast2', 'e0': 0.2, 'e1': 0.4, 'equalize_prior': True, 'episodes': 1000, 'alpha': 1.0}
# --------------------------------
# | [C-SVM] C1 = 0.1  | 0.599    |
# | [C-SVM] C1 = 0.2  | 0.599    |
# | [C-SVM] C1 = 0.25 | 0.599    |
# | [C-SVM] C1 = 0.33 | 0.596    |
# | [C-SVM] C1 = 0.5  | 0.605    |
# | [C-SVM] C1 = 1.0  | 0.706    |
# | [C-SVM] C1 = 10.0 | 0.43     |
# | [C-SVM] C1 = 2.0  | 0.689    |
# | [C-SVM] C1 = 3.0  | 0.648    |
# | [C-SVM] C1 = 4.0  | 0.538    |
# | [C-SVM] C1 = 5.0  | 0.497    |
# --------------------------------
# ------------------------------------
# | [C-SVM] accuracy max  | 0.891    |
# | [C-SVM] accuracy mean | 0.865    |
# | [C-SVM] accuracy min  | 0.844    |
# | [C-SVM] accuracy std  | 0.0155   |
# | [C-SVM] best C1       | 1        |
# ------------------------------------
# Logging to logs/pam/19-08-28-17-24-06
# {'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'dataset': 'breast2', 'e0': 0.2, 'e1': 0.4, 'equalize_prior': True, 'episodes': 1000, 'alpha': 1.0}
# -----------------------------------
# | [PAM] margin = 0     | 0.616    |
# | [PAM] margin = 0.125 | 0.651    |
# | [PAM] margin = 0.25  | 0.654    |
# | [PAM] margin = 0.5   | 0.651    |
# | [PAM] margin = 1     | 0.672    |
# -----------------------------------
# ----------------------------------
# | [PAM] accuracy max  | 0.906    |
# | [PAM] accuracy mean | 0.811    |
# | [PAM] accuracy min  | 0.734    |
# | [PAM] accuracy std  | 0.0509   |
# | [PAM] best margin   | 1        |
# ----------------------------------

# %% [markdown]
# ### $e_0=0.4, e_1=0.4$

# %%
from runner import run
args = default_args.copy()
args.update({
    'dataset': 'breast2', 
    'e0': 0.4, 'e1': 0.4, 
    'equalize_prior': True, 
    'episodes': 1000, 
#     'batchsize': 64, 
#     'hidsize': [64, 64], 
#     'lr': 0.001, 
    'alpha': 1.,
})
run(args)
# Out:
# Logging to logs/nn/19-08-29-09-42-01
# {'dataset': 'breast2', 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'e0': 0.4, 'e1': 0.4, 'equalize_prior': True, 'episodes': 1000, 'alpha': 1.0}
# acc:0.656	batchsize: 1	lr:0.0007	hidsize:[8, 8]
# acc:0.797	batchsize: 1	lr:0.0007	hidsize:[16, 16]
# acc:0.822	batchsize: 1	lr:0.0007	hidsize:[32, 32]
# acc:0.875	batchsize: 1	lr:0.0007	hidsize:[64, 64]
# acc:0.672	batchsize: 1	lr: 0.001	hidsize:[8, 8]
# acc:0.816	batchsize: 1	lr: 0.001	hidsize:[16, 16]
# acc:0.852	batchsize: 1	lr: 0.001	hidsize:[32, 32]
# acc:0.869	batchsize: 1	lr: 0.001	hidsize:[64, 64]
# acc:0.689	batchsize: 1	lr: 0.005	hidsize:[8, 8]
# acc:0.871	batchsize: 1	lr: 0.005	hidsize:[16, 16]
# acc:0.889	batchsize: 1	lr: 0.005	hidsize:[32, 32]
# acc:0.869	batchsize: 1	lr: 0.005	hidsize:[64, 64]
# acc:0.779	batchsize: 1	lr:  0.01	hidsize:[8, 8]
# acc:0.836	batchsize: 1	lr:  0.01	hidsize:[16, 16]
# acc:0.875	batchsize: 1	lr:  0.01	hidsize:[32, 32]
# acc:0.764	batchsize: 1	lr:  0.01	hidsize:[64, 64]
# acc:0.617	batchsize: 1	lr:  0.05	hidsize:[8, 8]
# acc:0.689	batchsize: 1	lr:  0.05	hidsize:[16, 16]
# acc:0.65	batchsize: 1	lr:  0.05	hidsize:[32, 32]
# acc:0.67	batchsize: 1	lr:  0.05	hidsize:[64, 64]
# acc:0.824	batchsize: 4	lr:0.0007	hidsize:[8, 8]
# acc:0.865	batchsize: 4	lr:0.0007	hidsize:[16, 16]
# acc:0.928	batchsize: 4	lr:0.0007	hidsize:[32, 32]
# acc:0.91	batchsize: 4	lr:0.0007	hidsize:[64, 64]
# acc:0.863	batchsize: 4	lr: 0.001	hidsize:[8, 8]
# acc:0.914	batchsize: 4	lr: 0.001	hidsize:[16, 16]
# acc:0.918	batchsize: 4	lr: 0.001	hidsize:[32, 32]
# acc:0.91	batchsize: 4	lr: 0.001	hidsize:[64, 64]
# acc:0.846	batchsize: 4	lr: 0.005	hidsize:[8, 8]
# acc:0.898	batchsize: 4	lr: 0.005	hidsize:[16, 16]
# acc:0.904	batchsize: 4	lr: 0.005	hidsize:[32, 32]
# acc:0.906	batchsize: 4	lr: 0.005	hidsize:[64, 64]
# acc:0.916	batchsize: 4	lr:  0.01	hidsize:[8, 8]
# acc:0.898	batchsize: 4	lr:  0.01	hidsize:[16, 16]
# acc:0.908	batchsize: 4	lr:  0.01	hidsize:[32, 32]
# acc:0.895	batchsize: 4	lr:  0.01	hidsize:[64, 64]
# acc:0.547	batchsize: 4	lr:  0.05	hidsize:[8, 8]
# acc:0.682	batchsize: 4	lr:  0.05	hidsize:[16, 16]
# acc:0.811	batchsize: 4	lr:  0.05	hidsize:[32, 32]
# acc:0.904	batchsize: 4	lr:  0.05	hidsize:[64, 64]
# acc:0.902	batchsize:16	lr:0.0007	hidsize:[8, 8]
# acc:0.895	batchsize:16	lr:0.0007	hidsize:[16, 16]
# acc:0.906	batchsize:16	lr:0.0007	hidsize:[32, 32]
# acc:0.902	batchsize:16	lr:0.0007	hidsize:[64, 64]
# acc:0.902	batchsize:16	lr: 0.001	hidsize:[8, 8]
# acc:0.902	batchsize:16	lr: 0.001	hidsize:[16, 16]
# acc:0.914	batchsize:16	lr: 0.001	hidsize:[32, 32]
# acc:0.908	batchsize:16	lr: 0.001	hidsize:[64, 64]
# acc:0.904	batchsize:16	lr: 0.005	hidsize:[8, 8]
# acc:0.918	batchsize:16	lr: 0.005	hidsize:[16, 16]
# acc:0.91	batchsize:16	lr: 0.005	hidsize:[32, 32]
# acc:0.904	batchsize:16	lr: 0.005	hidsize:[64, 64]
# acc:0.908	batchsize:16	lr:  0.01	hidsize:[8, 8]
# acc:0.92	batchsize:16	lr:  0.01	hidsize:[16, 16]
# acc:0.912	batchsize:16	lr:  0.01	hidsize:[32, 32]
# acc:0.906	batchsize:16	lr:  0.01	hidsize:[64, 64]
# acc:0.895	batchsize:16	lr:  0.05	hidsize:[8, 8]
# acc:0.895	batchsize:16	lr:  0.05	hidsize:[16, 16]
# acc:0.895	batchsize:16	lr:  0.05	hidsize:[32, 32]
# acc:0.902	batchsize:16	lr:  0.05	hidsize:[64, 64]
# acc:0.889	batchsize:32	lr:0.0007	hidsize:[8, 8]
# acc: 0.9	batchsize:32	lr:0.0007	hidsize:[16, 16]
# acc:0.902	batchsize:32	lr:0.0007	hidsize:[32, 32]
# acc:0.895	batchsize:32	lr:0.0007	hidsize:[64, 64]
# acc:0.893	batchsize:32	lr: 0.001	hidsize:[8, 8]
# acc:0.898	batchsize:32	lr: 0.001	hidsize:[16, 16]
# acc:0.902	batchsize:32	lr: 0.001	hidsize:[32, 32]
# acc:0.896	batchsize:32	lr: 0.001	hidsize:[64, 64]
# acc:0.902	batchsize:32	lr: 0.005	hidsize:[8, 8]
# acc:0.902	batchsize:32	lr: 0.005	hidsize:[16, 16]
# acc:0.906	batchsize:32	lr: 0.005	hidsize:[32, 32]
# acc:0.902	batchsize:32	lr: 0.005	hidsize:[64, 64]
# acc:0.895	batchsize:32	lr:  0.01	hidsize:[8, 8]
# acc:0.902	batchsize:32	lr:  0.01	hidsize:[16, 16]
# acc:0.906	batchsize:32	lr:  0.01	hidsize:[32, 32]
# acc:0.902	batchsize:32	lr:  0.01	hidsize:[64, 64]
# acc:0.893	batchsize:32	lr:  0.05	hidsize:[8, 8]
# acc:0.902	batchsize:32	lr:  0.05	hidsize:[16, 16]
# acc:0.895	batchsize:32	lr:  0.05	hidsize:[32, 32]
# acc:0.918	batchsize:32	lr:  0.05	hidsize:[64, 64]
# acc:0.889	batchsize:64	lr:0.0007	hidsize:[8, 8]
# acc:0.902	batchsize:64	lr:0.0007	hidsize:[16, 16]
# acc:0.906	batchsize:64	lr:0.0007	hidsize:[32, 32]
# acc:0.904	batchsize:64	lr:0.0007	hidsize:[64, 64]
# acc:0.893	batchsize:64	lr: 0.001	hidsize:[8, 8]
# acc: 0.9	batchsize:64	lr: 0.001	hidsize:[16, 16]
# acc:0.91	batchsize:64	lr: 0.001	hidsize:[32, 32]
# acc:0.902	batchsize:64	lr: 0.001	hidsize:[64, 64]
# acc: 0.9	batchsize:64	lr: 0.005	hidsize:[8, 8]
# acc:0.908	batchsize:64	lr: 0.005	hidsize:[16, 16]
# acc:0.908	batchsize:64	lr: 0.005	hidsize:[32, 32]
# acc:0.902	batchsize:64	lr: 0.005	hidsize:[64, 64]
# acc:0.906	batchsize:64	lr:  0.01	hidsize:[8, 8]
# acc:0.898	batchsize:64	lr:  0.01	hidsize:[16, 16]
# acc:0.908	batchsize:64	lr:  0.01	hidsize:[32, 32]
# acc:0.902	batchsize:64	lr:  0.01	hidsize:[64, 64]
# acc:0.803	batchsize:64	lr:  0.05	hidsize:[8, 8]
# acc:0.863	batchsize:64	lr:  0.05	hidsize:[16, 16]
# acc:0.898	batchsize:64	lr:  0.05	hidsize:[32, 32]
# acc:0.885	batchsize:64	lr:  0.05	hidsize:[64, 64]
# --------------------------------------
# | [PEER] best batchsize   | 4        |
# | [PEER] best hidsize     | [32, 32] |
# | [PEER] best learning... | 0.0007   |
# --------------------------------------
# --------------------------------------
# | [NN] with bce loss      | 0.824    |
# | [NN] with peer loss     | 0.928    |
# | [NN] with surrogate ... | 0.867    |
# --------------------------------------
# Logging to logs/svm/19-08-29-09-47-26
# {'dataset': 'breast2', 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'e0': 0.4, 'e1': 0.4, 'equalize_prior': True, 'episodes': 1000, 'alpha': 1.0}
# --------------------------------
# | [C-SVM] C1 = 0.1  | 0.497    |
# | [C-SVM] C1 = 0.2  | 0.497    |
# | [C-SVM] C1 = 0.25 | 0.497    |
# | [C-SVM] C1 = 0.33 | 0.494    |
# | [C-SVM] C1 = 0.5  | 0.506    |
# | [C-SVM] C1 = 1.0  | 0.605    |
# | [C-SVM] C1 = 10.0 | 0.503    |
# | [C-SVM] C1 = 2.0  | 0.503    |
# | [C-SVM] C1 = 3.0  | 0.5      |
# | [C-SVM] C1 = 4.0  | 0.503    |
# | [C-SVM] C1 = 5.0  | 0.503    |
# --------------------------------
# ------------------------------------
# | [C-SVM] accuracy max  | 0.891    |
# | [C-SVM] accuracy mean | 0.855    |
# | [C-SVM] accuracy min  | 0.75     |
# | [C-SVM] accuracy std  | 0.0528   |
# | [C-SVM] best C1       | 1        |
# ------------------------------------
# Logging to logs/pam/19-08-29-09-47-26
# {'dataset': 'breast2', 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'e0': 0.4, 'e1': 0.4, 'equalize_prior': True, 'episodes': 1000, 'alpha': 1.0}
# -----------------------------------
# | [PAM] margin = 0     | 0.515    |
# | [PAM] margin = 0.125 | 0.558    |
# | [PAM] margin = 0.25  | 0.567    |
# | [PAM] margin = 0.5   | 0.59     |
# | [PAM] margin = 1     | 0.596    |
# -----------------------------------
# ----------------------------------
# | [PAM] accuracy max  | 0.891    |
# | [PAM] accuracy mean | 0.812    |
# | [PAM] accuracy min  | 0.75     |
# | [PAM] accuracy std  | 0.0462   |
# | [PAM] best margin   | 1        |
# ----------------------------------

# %% [markdown]
# ## Without Prior Equalization

# %% [markdown]
# ### $e_0 = 0.1, e_1 = 0.3$

# %%
from run_nn import find_best_alpha

args = default_args.copy()
args.update({
    'dataset': 'breast2', 
    'e0': 0.1, 'e1': 0.3, 
    'equalize_prior': False, 
    'episodes': 3000, 
    'batchsize': 1, 
    'hidsize': [32, 32], 
    'lr': 0.0007, 
#     'alpha': 0.5,
})
find_best_alpha(args)
# Out:
# ---------------------------------
# | [PEER] alpha = 0.1 | 0.936    |
# | [PEER] alpha = 0.2 | 0.948    |
# | [PEER] alpha = 0.3 | 0.948    |
# | [PEER] alpha = 0.4 | 0.958    |
# | [PEER] alpha = 0.5 | 0.956    |
# | [PEER] alpha = 0.6 | 0.952    |
# | [PEER] alpha = 0.7 | 0.951    |
# | [PEER] alpha = 0.8 | 0.943    |
# | [PEER] alpha = 0.9 | 0.943    |
# | [PEER] alpha = 1.0 | 0.943    |
# ---------------------------------
# {'alpha': 0.4}

# %%
from runner import run

args = default_args.copy()
args.update({
    'dataset': 'breast2', 
    'e0': 0.1, 'e1': 0.3, 
    'equalize_prior': False, 
    'episodes': 3000, 
#     'batchsize': 1, 
#     'hidsize': [32, 32], 
#     'lr': 0.01, 
#     'alpha': 0.6,
})
run(args)
# Out:
# Logging to logs/nn/19-08-28-16-09-04
# {'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'dataset': 'breast2', 'e0': 0.1, 'e1': 0.3, 'equalize_prior': False, 'episodes': 3000}
# acc:0.897	batchsize: 1	lr:0.0007	hidsize:[8, 8]
# acc:0.936	batchsize: 1	lr:0.0007	hidsize:[16, 16]
# acc:0.943	batchsize: 1	lr:0.0007	hidsize:[32, 32]
# acc:0.94	batchsize: 1	lr:0.0007	hidsize:[64, 64]
# acc:0.897	batchsize: 1	lr: 0.001	hidsize:[8, 8]
# acc:0.935	batchsize: 1	lr: 0.001	hidsize:[16, 16]
# acc:0.943	batchsize: 1	lr: 0.001	hidsize:[32, 32]
# acc:0.939	batchsize: 1	lr: 0.001	hidsize:[64, 64]
# acc:0.938	batchsize: 1	lr: 0.005	hidsize:[8, 8]
# acc:0.936	batchsize: 1	lr: 0.005	hidsize:[16, 16]
# acc:0.942	batchsize: 1	lr: 0.005	hidsize:[32, 32]
# acc:0.94	batchsize: 1	lr: 0.005	hidsize:[64, 64]
# acc:0.938	batchsize: 1	lr:  0.01	hidsize:[8, 8]
# acc:0.939	batchsize: 1	lr:  0.01	hidsize:[16, 16]
# acc:0.94	batchsize: 1	lr:  0.01	hidsize:[32, 32]
# acc:0.942	batchsize: 1	lr:  0.01	hidsize:[64, 64]
# acc:0.824	batchsize: 1	lr:  0.05	hidsize:[8, 8]
# acc:0.882	batchsize: 1	lr:  0.05	hidsize:[16, 16]
# acc:0.938	batchsize: 1	lr:  0.05	hidsize:[32, 32]
# acc:0.924	batchsize: 1	lr:  0.05	hidsize:[64, 64]
# acc:0.943	batchsize: 4	lr:0.0007	hidsize:[8, 8]
# acc:0.935	batchsize: 4	lr:0.0007	hidsize:[16, 16]
# acc:0.939	batchsize: 4	lr:0.0007	hidsize:[32, 32]
# acc:0.938	batchsize: 4	lr:0.0007	hidsize:[64, 64]
# acc:0.943	batchsize: 4	lr: 0.001	hidsize:[8, 8]
# acc:0.935	batchsize: 4	lr: 0.001	hidsize:[16, 16]
# acc:0.938	batchsize: 4	lr: 0.001	hidsize:[32, 32]
# acc:0.938	batchsize: 4	lr: 0.001	hidsize:[64, 64]
# acc:0.939	batchsize: 4	lr: 0.005	hidsize:[8, 8]
# acc:0.936	batchsize: 4	lr: 0.005	hidsize:[16, 16]
# acc:0.935	batchsize: 4	lr: 0.005	hidsize:[32, 32]
# acc:0.935	batchsize: 4	lr: 0.005	hidsize:[64, 64]
# acc:0.94	batchsize: 4	lr:  0.01	hidsize:[8, 8]
# acc:0.933	batchsize: 4	lr:  0.01	hidsize:[16, 16]
# acc:0.933	batchsize: 4	lr:  0.01	hidsize:[32, 32]
# acc:0.93	batchsize: 4	lr:  0.01	hidsize:[64, 64]
# acc:0.863	batchsize: 4	lr:  0.05	hidsize:[8, 8]
# acc:0.927	batchsize: 4	lr:  0.05	hidsize:[16, 16]
# acc:0.926	batchsize: 4	lr:  0.05	hidsize:[32, 32]
# acc:0.924	batchsize: 4	lr:  0.05	hidsize:[64, 64]
# acc:0.94	batchsize:16	lr:0.0007	hidsize:[8, 8]
# acc:0.936	batchsize:16	lr:0.0007	hidsize:[16, 16]
# acc:0.936	batchsize:16	lr:0.0007	hidsize:[32, 32]
# acc:0.935	batchsize:16	lr:0.0007	hidsize:[64, 64]
# acc:0.94	batchsize:16	lr: 0.001	hidsize:[8, 8]
# acc:0.935	batchsize:16	lr: 0.001	hidsize:[16, 16]
# acc:0.935	batchsize:16	lr: 0.001	hidsize:[32, 32]
# acc:0.936	batchsize:16	lr: 0.001	hidsize:[64, 64]
# acc:0.936	batchsize:16	lr: 0.005	hidsize:[8, 8]
# acc:0.933	batchsize:16	lr: 0.005	hidsize:[16, 16]
# acc:0.93	batchsize:16	lr: 0.005	hidsize:[32, 32]
# acc:0.935	batchsize:16	lr: 0.005	hidsize:[64, 64]
# acc:0.938	batchsize:16	lr:  0.01	hidsize:[8, 8]
# acc:0.936	batchsize:16	lr:  0.01	hidsize:[16, 16]
# acc:0.933	batchsize:16	lr:  0.01	hidsize:[32, 32]
# acc:0.933	batchsize:16	lr:  0.01	hidsize:[64, 64]
# acc:0.935	batchsize:16	lr:  0.05	hidsize:[8, 8]
# acc:0.929	batchsize:16	lr:  0.05	hidsize:[16, 16]
# acc:0.93	batchsize:16	lr:  0.05	hidsize:[32, 32]
# acc:0.936	batchsize:16	lr:  0.05	hidsize:[64, 64]
# acc:0.938	batchsize:32	lr:0.0007	hidsize:[8, 8]
# acc:0.933	batchsize:32	lr:0.0007	hidsize:[16, 16]
# acc:0.93	batchsize:32	lr:0.0007	hidsize:[32, 32]
# acc:0.932	batchsize:32	lr:0.0007	hidsize:[64, 64]
# acc:0.935	batchsize:32	lr: 0.001	hidsize:[8, 8]
# acc:0.932	batchsize:32	lr: 0.001	hidsize:[16, 16]
# acc:0.927	batchsize:32	lr: 0.001	hidsize:[32, 32]
# acc:0.929	batchsize:32	lr: 0.001	hidsize:[64, 64]
# acc:0.929	batchsize:32	lr: 0.005	hidsize:[8, 8]
# acc:0.926	batchsize:32	lr: 0.005	hidsize:[16, 16]
# acc:0.927	batchsize:32	lr: 0.005	hidsize:[32, 32]
# acc:0.929	batchsize:32	lr: 0.005	hidsize:[64, 64]
# acc:0.935	batchsize:32	lr:  0.01	hidsize:[8, 8]
# acc:0.927	batchsize:32	lr:  0.01	hidsize:[16, 16]
# acc:0.927	batchsize:32	lr:  0.01	hidsize:[32, 32]
# acc:0.927	batchsize:32	lr:  0.01	hidsize:[64, 64]
# acc:0.935	batchsize:32	lr:  0.05	hidsize:[8, 8]
# acc:0.929	batchsize:32	lr:  0.05	hidsize:[16, 16]
# acc:0.926	batchsize:32	lr:  0.05	hidsize:[32, 32]
# acc:0.93	batchsize:32	lr:  0.05	hidsize:[64, 64]
# acc:0.926	batchsize:64	lr:0.0007	hidsize:[8, 8]
# acc:0.929	batchsize:64	lr:0.0007	hidsize:[16, 16]
# acc:0.924	batchsize:64	lr:0.0007	hidsize:[32, 32]
# acc:0.927	batchsize:64	lr:0.0007	hidsize:[64, 64]
# acc:0.926	batchsize:64	lr: 0.001	hidsize:[8, 8]
# acc:0.929	batchsize:64	lr: 0.001	hidsize:[16, 16]
# acc:0.924	batchsize:64	lr: 0.001	hidsize:[32, 32]
# acc:0.927	batchsize:64	lr: 0.001	hidsize:[64, 64]
# acc:0.926	batchsize:64	lr: 0.005	hidsize:[8, 8]
# acc:0.922	batchsize:64	lr: 0.005	hidsize:[16, 16]
# acc:0.923	batchsize:64	lr: 0.005	hidsize:[32, 32]
# acc:0.924	batchsize:64	lr: 0.005	hidsize:[64, 64]
# acc:0.93	batchsize:64	lr:  0.01	hidsize:[8, 8]
# acc:0.923	batchsize:64	lr:  0.01	hidsize:[16, 16]
# acc:0.923	batchsize:64	lr:  0.01	hidsize:[32, 32]
# acc:0.926	batchsize:64	lr:  0.01	hidsize:[64, 64]
# acc:0.932	batchsize:64	lr:  0.05	hidsize:[8, 8]
# acc:0.923	batchsize:64	lr:  0.05	hidsize:[16, 16]
# acc:0.923	batchsize:64	lr:  0.05	hidsize:[32, 32]
# acc:0.929	batchsize:64	lr:  0.05	hidsize:[64, 64]
# --------------------------------------
# | [PEER] best batchsize   | 1        |
# | [PEER] best hidsize     | [32, 32] |
# | [PEER] best learning... | 0.0007   |
# --------------------------------------
# ---------------------------------
# | [PEER] alpha = 0.1 | 0.827    |
# | [PEER] alpha = 0.2 | 0.825    |
# | [PEER] alpha = 0.3 | 0.818    |
# | [PEER] alpha = 0.4 | 0.818    |
# | [PEER] alpha = 0.5 | 0.827    |
# | [PEER] alpha = 0.6 | 0.822    |
# | [PEER] alpha = 0.7 | 0.816    |
# | [PEER] alpha = 0.8 | 0.816    |
# | [PEER] alpha = 0.9 | 0.816    |
# | [PEER] alpha = 1.0 | 0.803    |
# ---------------------------------
# --------------------------------------
# | [NN] with bce loss      | 0.92     |
# | [NN] with peer loss     | 0.936    |
# | [NN] with surrogate ... | 0.949    |
# | [PEER] best alpha       | 0.1      |
# --------------------------------------
# Logging to logs/svm/19-08-28-16-26-22
# {'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'dataset': 'breast2', 'e0': 0.1, 'e1': 0.3, 'equalize_prior': False, 'episodes': 3000}
# --------------------------------
# | [C-SVM] C1 = 0.1  | 0.68     |
# | [C-SVM] C1 = 0.2  | 0.68     |
# | [C-SVM] C1 = 0.25 | 0.68     |
# | [C-SVM] C1 = 0.33 | 0.68     |
# | [C-SVM] C1 = 0.5  | 0.746    |
# | [C-SVM] C1 = 1.0  | 0.818    |
# | [C-SVM] C1 = 10.0 | 0.566    |
# | [C-SVM] C1 = 2.0  | 0.82     |
# | [C-SVM] C1 = 3.0  | 0.809    |
# | [C-SVM] C1 = 4.0  | 0.798    |
# | [C-SVM] C1 = 5.0  | 0.768    |
# --------------------------------
# ------------------------------------
# | [C-SVM] accuracy max  | 0.977    |
# | [C-SVM] accuracy mean | 0.943    |
# | [C-SVM] accuracy min  | 0.86     |
# | [C-SVM] accuracy std  | 0.0341   |
# | [C-SVM] best C1       | 2        |
# ------------------------------------
# Logging to logs/pam/19-08-28-16-26-23
# {'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'dataset': 'breast2', 'e0': 0.1, 'e1': 0.3, 'equalize_prior': False, 'episodes': 3000}
# -----------------------------------
# | [PAM] margin = 0     | 0.741    |
# | [PAM] margin = 0.125 | 0.825    |
# | [PAM] margin = 0.25  | 0.814    |
# | [PAM] margin = 0.5   | 0.827    |
# | [PAM] margin = 1     | 0.82     |
# -----------------------------------
# ----------------------------------
# | [PAM] accuracy max  | 0.953    |
# | [PAM] accuracy mean | 0.904    |
# | [PAM] accuracy min  | 0.86     |
# | [PAM] accuracy std  | 0.0367   |
# | [PAM] best margin   | 0.5      |
# ----------------------------------

# %% [markdown]
# ### $e_0 = 0.2, e_1 = 0.2$

# %%
from run_nn import find_best_alpha

args = default_args.copy()
args.update({
    'dataset': 'breast2', 
    'e0': 0.2, 'e1': 0.2, 
    'equalize_prior': False, 
    'episodes': 3000, 
    'batchsize': 4, 
    'hidsize': [8, 8], 
    'lr': 0.0007, 
#     'alpha': 0.5,
})
find_best_alpha(args)
# Out:
# ---------------------------------
# | [PEER] alpha = 0.1 | 0.952    |
# | [PEER] alpha = 0.2 | 0.949    |
# | [PEER] alpha = 0.3 | 0.952    |
# | [PEER] alpha = 0.4 | 0.951    |
# | [PEER] alpha = 0.5 | 0.942    |
# | [PEER] alpha = 0.6 | 0.94     |
# | [PEER] alpha = 0.7 | 0.946    |
# | [PEER] alpha = 0.8 | 0.949    |
# | [PEER] alpha = 0.9 | 0.948    |
# | [PEER] alpha = 1.0 | 0.945    |
# ---------------------------------
# {'alpha': 0.1}

# %%
from runner import run

args = default_args.copy()
args.update({
    'dataset': 'breast2', 
    'e0': 0.2, 'e1': 0.2, 
    'equalize_prior': False, 
    'episodes': 3000, 
#     'batchsize': 16, 
#     'hidsize': [8, 8], 
#     'lr': 0.01, 
#     'alpha': 0.8,
})
run(args)
# Out:
# Logging to logs/nn/19-08-28-16-26-29
# {'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'dataset': 'breast2', 'e0': 0.2, 'e1': 0.2, 'equalize_prior': False, 'episodes': 3000}
# acc:0.933	batchsize: 1	lr:0.0007	hidsize:[8, 8]
# acc:0.935	batchsize: 1	lr:0.0007	hidsize:[16, 16]
# acc:0.942	batchsize: 1	lr:0.0007	hidsize:[32, 32]
# acc:0.938	batchsize: 1	lr:0.0007	hidsize:[64, 64]
# acc:0.933	batchsize: 1	lr: 0.001	hidsize:[8, 8]
# acc:0.935	batchsize: 1	lr: 0.001	hidsize:[16, 16]
# acc:0.942	batchsize: 1	lr: 0.001	hidsize:[32, 32]
# acc:0.936	batchsize: 1	lr: 0.001	hidsize:[64, 64]
# acc:0.94	batchsize: 1	lr: 0.005	hidsize:[8, 8]
# acc:0.935	batchsize: 1	lr: 0.005	hidsize:[16, 16]
# acc:0.939	batchsize: 1	lr: 0.005	hidsize:[32, 32]
# acc:0.933	batchsize: 1	lr: 0.005	hidsize:[64, 64]
# acc:0.939	batchsize: 1	lr:  0.01	hidsize:[8, 8]
# acc:0.93	batchsize: 1	lr:  0.01	hidsize:[16, 16]
# acc:0.938	batchsize: 1	lr:  0.01	hidsize:[32, 32]
# acc:0.935	batchsize: 1	lr:  0.01	hidsize:[64, 64]
# acc:0.804	batchsize: 1	lr:  0.05	hidsize:[8, 8]
# acc:0.842	batchsize: 1	lr:  0.05	hidsize:[16, 16]
# acc:0.917	batchsize: 1	lr:  0.05	hidsize:[32, 32]
# acc:0.927	batchsize: 1	lr:  0.05	hidsize:[64, 64]
# acc:0.945	batchsize: 4	lr:0.0007	hidsize:[8, 8]
# acc:0.935	batchsize: 4	lr:0.0007	hidsize:[16, 16]
# acc:0.936	batchsize: 4	lr:0.0007	hidsize:[32, 32]
# acc:0.936	batchsize: 4	lr:0.0007	hidsize:[64, 64]
# acc:0.94	batchsize: 4	lr: 0.001	hidsize:[8, 8]
# acc:0.935	batchsize: 4	lr: 0.001	hidsize:[16, 16]
# acc:0.935	batchsize: 4	lr: 0.001	hidsize:[32, 32]
# acc:0.936	batchsize: 4	lr: 0.001	hidsize:[64, 64]
# acc:0.936	batchsize: 4	lr: 0.005	hidsize:[8, 8]
# acc:0.933	batchsize: 4	lr: 0.005	hidsize:[16, 16]
# acc:0.932	batchsize: 4	lr: 0.005	hidsize:[32, 32]
# acc:0.929	batchsize: 4	lr: 0.005	hidsize:[64, 64]
# acc:0.936	batchsize: 4	lr:  0.01	hidsize:[8, 8]
# acc:0.929	batchsize: 4	lr:  0.01	hidsize:[16, 16]
# acc:0.924	batchsize: 4	lr:  0.01	hidsize:[32, 32]
# acc:0.927	batchsize: 4	lr:  0.01	hidsize:[64, 64]
# acc:0.863	batchsize: 4	lr:  0.05	hidsize:[8, 8]
# acc:0.923	batchsize: 4	lr:  0.05	hidsize:[16, 16]
# acc:0.923	batchsize: 4	lr:  0.05	hidsize:[32, 32]
# acc:0.923	batchsize: 4	lr:  0.05	hidsize:[64, 64]
# acc:0.942	batchsize:16	lr:0.0007	hidsize:[8, 8]
# acc:0.932	batchsize:16	lr:0.0007	hidsize:[16, 16]
# acc:0.94	batchsize:16	lr:0.0007	hidsize:[32, 32]
# acc:0.939	batchsize:16	lr:0.0007	hidsize:[64, 64]
# acc:0.939	batchsize:16	lr: 0.001	hidsize:[8, 8]
# acc:0.935	batchsize:16	lr: 0.001	hidsize:[16, 16]
# acc:0.939	batchsize:16	lr: 0.001	hidsize:[32, 32]
# acc:0.938	batchsize:16	lr: 0.001	hidsize:[64, 64]
# acc:0.94	batchsize:16	lr: 0.005	hidsize:[8, 8]
# acc:0.932	batchsize:16	lr: 0.005	hidsize:[16, 16]
# acc:0.936	batchsize:16	lr: 0.005	hidsize:[32, 32]
# acc:0.936	batchsize:16	lr: 0.005	hidsize:[64, 64]
# acc:0.942	batchsize:16	lr:  0.01	hidsize:[8, 8]
# acc:0.932	batchsize:16	lr:  0.01	hidsize:[16, 16]
# acc:0.938	batchsize:16	lr:  0.01	hidsize:[32, 32]
# acc:0.936	batchsize:16	lr:  0.01	hidsize:[64, 64]
# acc:0.938	batchsize:16	lr:  0.05	hidsize:[8, 8]
# acc:0.891	batchsize:16	lr:  0.05	hidsize:[16, 16]
# acc:0.932	batchsize:16	lr:  0.05	hidsize:[32, 32]
# acc:0.936	batchsize:16	lr:  0.05	hidsize:[64, 64]
# acc:0.938	batchsize:32	lr:0.0007	hidsize:[8, 8]
# acc:0.93	batchsize:32	lr:0.0007	hidsize:[16, 16]
# acc:0.936	batchsize:32	lr:0.0007	hidsize:[32, 32]
# acc:0.935	batchsize:32	lr:0.0007	hidsize:[64, 64]
# acc:0.936	batchsize:32	lr: 0.001	hidsize:[8, 8]
# acc:0.929	batchsize:32	lr: 0.001	hidsize:[16, 16]
# acc:0.933	batchsize:32	lr: 0.001	hidsize:[32, 32]
# acc:0.935	batchsize:32	lr: 0.001	hidsize:[64, 64]
# acc:0.936	batchsize:32	lr: 0.005	hidsize:[8, 8]
# acc:0.929	batchsize:32	lr: 0.005	hidsize:[16, 16]
# acc:0.932	batchsize:32	lr: 0.005	hidsize:[32, 32]
# acc:0.932	batchsize:32	lr: 0.005	hidsize:[64, 64]
# acc:0.936	batchsize:32	lr:  0.01	hidsize:[8, 8]
# acc:0.926	batchsize:32	lr:  0.01	hidsize:[16, 16]
# acc:0.935	batchsize:32	lr:  0.01	hidsize:[32, 32]
# acc:0.932	batchsize:32	lr:  0.01	hidsize:[64, 64]
# acc:0.929	batchsize:32	lr:  0.05	hidsize:[8, 8]
# acc:0.927	batchsize:32	lr:  0.05	hidsize:[16, 16]
# acc:0.933	batchsize:32	lr:  0.05	hidsize:[32, 32]
# acc:0.933	batchsize:32	lr:  0.05	hidsize:[64, 64]
# acc:0.933	batchsize:64	lr:0.0007	hidsize:[8, 8]
# acc:0.927	batchsize:64	lr:0.0007	hidsize:[16, 16]
# acc:0.935	batchsize:64	lr:0.0007	hidsize:[32, 32]
# acc:0.933	batchsize:64	lr:0.0007	hidsize:[64, 64]
# acc:0.932	batchsize:64	lr: 0.001	hidsize:[8, 8]
# acc:0.929	batchsize:64	lr: 0.001	hidsize:[16, 16]
# acc:0.933	batchsize:64	lr: 0.001	hidsize:[32, 32]
# acc:0.929	batchsize:64	lr: 0.001	hidsize:[64, 64]
# acc:0.935	batchsize:64	lr: 0.005	hidsize:[8, 8]
# acc:0.929	batchsize:64	lr: 0.005	hidsize:[16, 16]
# acc:0.929	batchsize:64	lr: 0.005	hidsize:[32, 32]
# acc:0.924	batchsize:64	lr: 0.005	hidsize:[64, 64]
# acc:0.935	batchsize:64	lr:  0.01	hidsize:[8, 8]
# acc:0.93	batchsize:64	lr:  0.01	hidsize:[16, 16]
# acc:0.926	batchsize:64	lr:  0.01	hidsize:[32, 32]
# acc:0.926	batchsize:64	lr:  0.01	hidsize:[64, 64]
# acc:0.935	batchsize:64	lr:  0.05	hidsize:[8, 8]
# acc:0.93	batchsize:64	lr:  0.05	hidsize:[16, 16]
# acc:0.924	batchsize:64	lr:  0.05	hidsize:[32, 32]
# acc:0.933	batchsize:64	lr:  0.05	hidsize:[64, 64]
# --------------------------------------
# | [PEER] best batchsize   | 4        |
# | [PEER] best hidsize     | [8, 8]   |
# | [PEER] best learning... | 0.0007   |
# --------------------------------------
# ---------------------------------
# | [PEER] alpha = 0.1 | 0.787    |
# | [PEER] alpha = 0.2 | 0.781    |
# | [PEER] alpha = 0.3 | 0.783    |
# | [PEER] alpha = 0.4 | 0.781    |
# | [PEER] alpha = 0.5 | 0.779    |
# | [PEER] alpha = 0.6 | 0.776    |
# | [PEER] alpha = 0.7 | 0.783    |
# | [PEER] alpha = 0.8 | 0.779    |
# | [PEER] alpha = 0.9 | 0.776    |
# | [PEER] alpha = 1.0 | 0.779    |
# ---------------------------------
# --------------------------------------
# | [NN] with bce loss      | 0.955    |
# | [NN] with peer loss     | 0.952    |
# | [NN] with surrogate ... | 0.952    |
# | [PEER] best alpha       | 0.1      |
# --------------------------------------
# Logging to logs/svm/19-08-28-16-42-53
# {'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'dataset': 'breast2', 'e0': 0.2, 'e1': 0.2, 'equalize_prior': False, 'episodes': 3000}
# --------------------------------
# | [C-SVM] C1 = 0.1  | 0.583    |
# | [C-SVM] C1 = 0.2  | 0.588    |
# | [C-SVM] C1 = 0.25 | 0.614    |
# | [C-SVM] C1 = 0.33 | 0.706    |
# | [C-SVM] C1 = 0.5  | 0.772    |
# | [C-SVM] C1 = 1.0  | 0.783    |
# | [C-SVM] C1 = 10.0 | 0.478    |
# | [C-SVM] C1 = 2.0  | 0.757    |
# | [C-SVM] C1 = 3.0  | 0.675    |
# | [C-SVM] C1 = 4.0  | 0.577    |
# | [C-SVM] C1 = 5.0  | 0.526    |
# --------------------------------
# ------------------------------------
# | [C-SVM] accuracy max  | 0.988    |
# | [C-SVM] accuracy mean | 0.946    |
# | [C-SVM] accuracy min  | 0.919    |
# | [C-SVM] accuracy std  | 0.0209   |
# | [C-SVM] best C1       | 1        |
# ------------------------------------
# Logging to logs/pam/19-08-28-16-42-53
# {'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'dataset': 'breast2', 'e0': 0.2, 'e1': 0.2, 'equalize_prior': False, 'episodes': 3000}
# -----------------------------------
# | [PAM] margin = 0     | 0.638    |
# | [PAM] margin = 0.125 | 0.776    |
# | [PAM] margin = 0.25  | 0.781    |
# | [PAM] margin = 0.5   | 0.783    |
# | [PAM] margin = 1     | 0.787    |
# -----------------------------------
# ----------------------------------
# | [PAM] accuracy max  | 0.977    |
# | [PAM] accuracy mean | 0.945    |
# | [PAM] accuracy min  | 0.907    |
# | [PAM] accuracy std  | 0.0208   |
# | [PAM] best margin   | 1        |
# ----------------------------------

# %% [markdown]
# ### $e_0 = 0.1, e_1 = 0.4$

# %%
from run_nn import find_best_alpha

args = default_args.copy()
args.update({
    'dataset': 'breast2', 
    'e0': 0.2, 'e1': 0.4, 
    'equalize_prior': False, 
    'episodes': 3000, 
    'batchsize': 4, 
    'hidsize': [8, 8], 
    'lr': 0.0007, 
#     'alpha': 0.5,
})
find_best_alpha(args)
# Out:
# ---------------------------------
# | [PEER] alpha = 0.1 | 0.885    |
# | [PEER] alpha = 0.2 | 0.885    |
# | [PEER] alpha = 0.3 | 0.907    |
# | [PEER] alpha = 0.4 | 0.922    |
# | [PEER] alpha = 0.5 | 0.927    |
# | [PEER] alpha = 0.6 | 0.94     |
# | [PEER] alpha = 0.7 | 0.948    |
# | [PEER] alpha = 0.8 | 0.94     |
# | [PEER] alpha = 0.9 | 0.94     |
# | [PEER] alpha = 1.0 | 0.94     |
# ---------------------------------
# {'alpha': 0.7}

# %%
from runner import run

args = default_args.copy()
args.update({
    'dataset': 'breast2', 
    'e0': 0.1, 'e1': 0.4, 
    'equalize_prior': False, 
    'episodes': 3000, 
#     'batchsize': 1, 
#     'hidsize': [32, 32], 
#     'lr': 0.01, 
#     'alpha': 0.6,
})
run(args)
# Out:
# Logging to logs/nn/19-08-29-09-56-30
# {'dataset': 'breast2', 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'e0': 0.1, 'e1': 0.4, 'equalize_prior': False, 'episodes': 3000}
# acc:0.932	batchsize: 1	lr:0.0007	hidsize:[8, 8]
# acc:0.932	batchsize: 1	lr:0.0007	hidsize:[16, 16]
# acc:0.94	batchsize: 1	lr:0.0007	hidsize:[32, 32]
# acc:0.939	batchsize: 1	lr:0.0007	hidsize:[64, 64]
# acc:0.929	batchsize: 1	lr: 0.001	hidsize:[8, 8]
# acc:0.933	batchsize: 1	lr: 0.001	hidsize:[16, 16]
# acc:0.942	batchsize: 1	lr: 0.001	hidsize:[32, 32]
# acc:0.938	batchsize: 1	lr: 0.001	hidsize:[64, 64]
# acc:0.919	batchsize: 1	lr: 0.005	hidsize:[8, 8]
# acc:0.933	batchsize: 1	lr: 0.005	hidsize:[16, 16]
# acc:0.935	batchsize: 1	lr: 0.005	hidsize:[32, 32]
# acc:0.936	batchsize: 1	lr: 0.005	hidsize:[64, 64]
# acc:0.878	batchsize: 1	lr:  0.01	hidsize:[8, 8]
# acc:0.935	batchsize: 1	lr:  0.01	hidsize:[16, 16]
# acc:0.938	batchsize: 1	lr:  0.01	hidsize:[32, 32]
# acc:0.933	batchsize: 1	lr:  0.01	hidsize:[64, 64]
# acc:0.631	batchsize: 1	lr:  0.05	hidsize:[8, 8]
# acc:0.875	batchsize: 1	lr:  0.05	hidsize:[16, 16]
# acc:0.865	batchsize: 1	lr:  0.05	hidsize:[32, 32]
# acc:0.932	batchsize: 1	lr:  0.05	hidsize:[64, 64]
# acc:0.943	batchsize: 4	lr:0.0007	hidsize:[8, 8]
# acc:0.936	batchsize: 4	lr:0.0007	hidsize:[16, 16]
# acc:0.938	batchsize: 4	lr:0.0007	hidsize:[32, 32]
# acc:0.936	batchsize: 4	lr:0.0007	hidsize:[64, 64]
# acc:0.943	batchsize: 4	lr: 0.001	hidsize:[8, 8]
# acc:0.936	batchsize: 4	lr: 0.001	hidsize:[16, 16]
# acc:0.938	batchsize: 4	lr: 0.001	hidsize:[32, 32]
# acc:0.933	batchsize: 4	lr: 0.001	hidsize:[64, 64]
# acc:0.938	batchsize: 4	lr: 0.005	hidsize:[8, 8]
# acc:0.935	batchsize: 4	lr: 0.005	hidsize:[16, 16]
# acc:0.935	batchsize: 4	lr: 0.005	hidsize:[32, 32]
# acc:0.933	batchsize: 4	lr: 0.005	hidsize:[64, 64]
# acc:0.936	batchsize: 4	lr:  0.01	hidsize:[8, 8]
# acc:0.935	batchsize: 4	lr:  0.01	hidsize:[16, 16]
# acc:0.93	batchsize: 4	lr:  0.01	hidsize:[32, 32]
# acc:0.93	batchsize: 4	lr:  0.01	hidsize:[64, 64]
# acc:0.862	batchsize: 4	lr:  0.05	hidsize:[8, 8]
# acc:0.929	batchsize: 4	lr:  0.05	hidsize:[16, 16]
# acc:0.926	batchsize: 4	lr:  0.05	hidsize:[32, 32]
# acc:0.871	batchsize: 4	lr:  0.05	hidsize:[64, 64]
# acc:0.939	batchsize:16	lr:0.0007	hidsize:[8, 8]
# acc:0.939	batchsize:16	lr:0.0007	hidsize:[16, 16]
# acc:0.938	batchsize:16	lr:0.0007	hidsize:[32, 32]
# acc:0.936	batchsize:16	lr:0.0007	hidsize:[64, 64]
# acc:0.939	batchsize:16	lr: 0.001	hidsize:[8, 8]
# acc:0.936	batchsize:16	lr: 0.001	hidsize:[16, 16]
# acc:0.938	batchsize:16	lr: 0.001	hidsize:[32, 32]
# acc:0.936	batchsize:16	lr: 0.001	hidsize:[64, 64]
# acc:0.936	batchsize:16	lr: 0.005	hidsize:[8, 8]
# acc:0.936	batchsize:16	lr: 0.005	hidsize:[16, 16]
# acc:0.933	batchsize:16	lr: 0.005	hidsize:[32, 32]
# acc:0.933	batchsize:16	lr: 0.005	hidsize:[64, 64]
# acc:0.933	batchsize:16	lr:  0.01	hidsize:[8, 8]
# acc:0.932	batchsize:16	lr:  0.01	hidsize:[16, 16]
# acc:0.929	batchsize:16	lr:  0.01	hidsize:[32, 32]
# acc:0.933	batchsize:16	lr:  0.01	hidsize:[64, 64]
# acc:0.839	batchsize:16	lr:  0.05	hidsize:[8, 8]
# acc:0.875	batchsize:16	lr:  0.05	hidsize:[16, 16]
# acc:0.93	batchsize:16	lr:  0.05	hidsize:[32, 32]
# acc:0.932	batchsize:16	lr:  0.05	hidsize:[64, 64]
# acc:0.936	batchsize:32	lr:0.0007	hidsize:[8, 8]
# acc:0.935	batchsize:32	lr:0.0007	hidsize:[16, 16]
# acc:0.938	batchsize:32	lr:0.0007	hidsize:[32, 32]
# acc:0.933	batchsize:32	lr:0.0007	hidsize:[64, 64]
# acc:0.936	batchsize:32	lr: 0.001	hidsize:[8, 8]
# acc:0.939	batchsize:32	lr: 0.001	hidsize:[16, 16]
# acc:0.935	batchsize:32	lr: 0.001	hidsize:[32, 32]
# acc:0.933	batchsize:32	lr: 0.001	hidsize:[64, 64]
# acc:0.932	batchsize:32	lr: 0.005	hidsize:[8, 8]
# acc:0.936	batchsize:32	lr: 0.005	hidsize:[16, 16]
# acc:0.927	batchsize:32	lr: 0.005	hidsize:[32, 32]
# acc:0.93	batchsize:32	lr: 0.005	hidsize:[64, 64]
# acc:0.932	batchsize:32	lr:  0.01	hidsize:[8, 8]
# acc:0.938	batchsize:32	lr:  0.01	hidsize:[16, 16]
# acc:0.929	batchsize:32	lr:  0.01	hidsize:[32, 32]
# acc:0.932	batchsize:32	lr:  0.01	hidsize:[64, 64]
# acc:0.93	batchsize:32	lr:  0.05	hidsize:[8, 8]
# acc:0.935	batchsize:32	lr:  0.05	hidsize:[16, 16]
# acc:0.923	batchsize:32	lr:  0.05	hidsize:[32, 32]
# acc:0.926	batchsize:32	lr:  0.05	hidsize:[64, 64]
# acc:0.933	batchsize:64	lr:0.0007	hidsize:[8, 8]
# acc:0.933	batchsize:64	lr:0.0007	hidsize:[16, 16]
# acc:0.927	batchsize:64	lr:0.0007	hidsize:[32, 32]
# acc:0.927	batchsize:64	lr:0.0007	hidsize:[64, 64]
# acc:0.93	batchsize:64	lr: 0.001	hidsize:[8, 8]
# acc:0.932	batchsize:64	lr: 0.001	hidsize:[16, 16]
# acc:0.924	batchsize:64	lr: 0.001	hidsize:[32, 32]
# acc:0.927	batchsize:64	lr: 0.001	hidsize:[64, 64]
# acc:0.926	batchsize:64	lr: 0.005	hidsize:[8, 8]
# acc:0.926	batchsize:64	lr: 0.005	hidsize:[16, 16]
# acc:0.924	batchsize:64	lr: 0.005	hidsize:[32, 32]
# acc:0.923	batchsize:64	lr: 0.005	hidsize:[64, 64]
# acc:0.929	batchsize:64	lr:  0.01	hidsize:[8, 8]
# acc:0.927	batchsize:64	lr:  0.01	hidsize:[16, 16]
# acc:0.922	batchsize:64	lr:  0.01	hidsize:[32, 32]
# acc:0.929	batchsize:64	lr:  0.01	hidsize:[64, 64]
# acc:0.929	batchsize:64	lr:  0.05	hidsize:[8, 8]
# acc:0.926	batchsize:64	lr:  0.05	hidsize:[16, 16]
# acc:0.923	batchsize:64	lr:  0.05	hidsize:[32, 32]
# acc:0.927	batchsize:64	lr:  0.05	hidsize:[64, 64]
# --------------------------------------
# | [PEER] best batchsize   | 4        |
# | [PEER] best hidsize     | [8, 8]   |
# | [PEER] best learning... | 0.0007   |
# --------------------------------------
# ---------------------------------
# | [PEER] alpha = 0.1 | 0.783    |
# | [PEER] alpha = 0.2 | 0.781    |
# | [PEER] alpha = 0.3 | 0.785    |
# | [PEER] alpha = 0.4 | 0.787    |
# | [PEER] alpha = 0.5 | 0.785    |
# | [PEER] alpha = 0.6 | 0.787    |
# | [PEER] alpha = 0.7 | 0.792    |
# | [PEER] alpha = 0.8 | 0.781    |
# | [PEER] alpha = 0.9 | 0.776    |
# | [PEER] alpha = 1.0 | 0.772    |
# ---------------------------------
# --------------------------------------
# | [NN] with bce loss      | 0.898    |
# | [NN] with peer loss     | 0.951    |
# | [NN] with surrogate ... | 0.929    |
# | [PEER] best alpha       | 0.7      |
# --------------------------------------
# Logging to logs/svm/19-08-29-10-13-31
# {'dataset': 'breast2', 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'e0': 0.1, 'e1': 0.4, 'equalize_prior': False, 'episodes': 3000}
# --------------------------------
# | [C-SVM] C1 = 0.1  | 0.719    |
# | [C-SVM] C1 = 0.2  | 0.719    |
# | [C-SVM] C1 = 0.25 | 0.719    |
# | [C-SVM] C1 = 0.33 | 0.719    |
# | [C-SVM] C1 = 0.5  | 0.719    |
# | [C-SVM] C1 = 1.0  | 0.781    |
# | [C-SVM] C1 = 10.0 | 0.533    |
# | [C-SVM] C1 = 2.0  | 0.783    |
# | [C-SVM] C1 = 3.0  | 0.77     |
# | [C-SVM] C1 = 4.0  | 0.757    |
# | [C-SVM] C1 = 5.0  | 0.732    |
# --------------------------------
# ------------------------------------
# | [C-SVM] accuracy max  | 0.953    |
# | [C-SVM] accuracy mean | 0.929    |
# | [C-SVM] accuracy min  | 0.86     |
# | [C-SVM] accuracy std  | 0.0299   |
# | [C-SVM] best C1       | 2        |
# ------------------------------------
# Logging to logs/pam/19-08-29-10-13-31
# {'dataset': 'breast2', 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'e0': 0.1, 'e1': 0.4, 'equalize_prior': False, 'episodes': 3000}
# -----------------------------------
# | [PAM] margin = 0     | 0.686    |
# | [PAM] margin = 0.125 | 0.768    |
# | [PAM] margin = 0.25  | 0.75     |
# | [PAM] margin = 0.5   | 0.75     |
# | [PAM] margin = 1     | 0.759    |
# -----------------------------------
# ----------------------------------
# | [PAM] accuracy max  | 0.93     |
# | [PAM] accuracy mean | 0.805    |
# | [PAM] accuracy min  | 0.674    |
# | [PAM] accuracy std  | 0.0889   |
# | [PAM] best margin   | 0.125    |
# ----------------------------------

# %% [markdown]
# ### $e_0 = 0.2, e_1 = 0.4$

# %%
from run_nn import find_best_alpha

args = default_args.copy()
args.update({
    'dataset': 'breast2', 
    'e0': 0.2, 'e1': 0.4, 
    'equalize_prior': False, 
    'episodes': 3000, 
    'batchsize': 32, 
    'hidsize': [16, 16], 
    'lr': 0.05, 
#     'alpha': 0.5,
})
find_best_alpha(args)
# Out:
# ---------------------------------
# | [PEER] alpha = 0.1 | 0.641    |
# | [PEER] alpha = 0.2 | 0.685    |
# | [PEER] alpha = 0.3 | 0.715    |
# | [PEER] alpha = 0.4 | 0.714    |
# | [PEER] alpha = 0.5 | 0.802    |
# | [PEER] alpha = 0.6 | 0.875    |
# | [PEER] alpha = 0.7 | 0.916    |
# | [PEER] alpha = 0.8 | 0.933    |
# | [PEER] alpha = 0.9 | 0.94     |
# | [PEER] alpha = 1.0 | 0.943    |
# ---------------------------------
# {'alpha': 1.0}

# %%
from runner import run

args = default_args.copy()
args.update({
    'dataset': 'breast2', 
    'e0': 0.2, 'e1': 0.4, 
    'equalize_prior': False, 
    'episodes': 3000, 
#     'batchsize': 1, 
#     'hidsize': [32, 32], 
#     'lr': 0.01, 
#     'alpha': 0.6,
})
run(args)
# Out:
# Logging to logs/nn/19-08-28-16-44-40
# {'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'dataset': 'breast2', 'e0': 0.2, 'e1': 0.4, 'equalize_prior': False, 'episodes': 3000}
# acc: 0.9	batchsize: 1	lr:0.0007	hidsize:[8, 8]
# acc:0.929	batchsize: 1	lr:0.0007	hidsize:[16, 16]
# acc:0.933	batchsize: 1	lr:0.0007	hidsize:[32, 32]
# acc:0.936	batchsize: 1	lr:0.0007	hidsize:[64, 64]
# acc: 0.9	batchsize: 1	lr: 0.001	hidsize:[8, 8]
# acc:0.93	batchsize: 1	lr: 0.001	hidsize:[16, 16]
# acc:0.938	batchsize: 1	lr: 0.001	hidsize:[32, 32]
# acc:0.938	batchsize: 1	lr: 0.001	hidsize:[64, 64]
# acc:0.839	batchsize: 1	lr: 0.005	hidsize:[8, 8]
# acc:0.929	batchsize: 1	lr: 0.005	hidsize:[16, 16]
# acc:0.936	batchsize: 1	lr: 0.005	hidsize:[32, 32]
# acc:0.926	batchsize: 1	lr: 0.005	hidsize:[64, 64]
# acc:0.837	batchsize: 1	lr:  0.01	hidsize:[8, 8]
# acc:0.922	batchsize: 1	lr:  0.01	hidsize:[16, 16]
# acc:0.92	batchsize: 1	lr:  0.01	hidsize:[32, 32]
# acc:0.92	batchsize: 1	lr:  0.01	hidsize:[64, 64]
# acc:0.622	batchsize: 1	lr:  0.05	hidsize:[8, 8]
# acc:0.826	batchsize: 1	lr:  0.05	hidsize:[16, 16]
# acc:0.879	batchsize: 1	lr:  0.05	hidsize:[32, 32]
# acc:0.849	batchsize: 1	lr:  0.05	hidsize:[64, 64]
# acc:0.94	batchsize: 4	lr:0.0007	hidsize:[8, 8]
# acc:0.935	batchsize: 4	lr:0.0007	hidsize:[16, 16]
# acc:0.933	batchsize: 4	lr:0.0007	hidsize:[32, 32]
# acc:0.935	batchsize: 4	lr:0.0007	hidsize:[64, 64]
# acc:0.942	batchsize: 4	lr: 0.001	hidsize:[8, 8]
# acc:0.938	batchsize: 4	lr: 0.001	hidsize:[16, 16]
# acc:0.933	batchsize: 4	lr: 0.001	hidsize:[32, 32]
# acc:0.936	batchsize: 4	lr: 0.001	hidsize:[64, 64]
# acc:0.932	batchsize: 4	lr: 0.005	hidsize:[8, 8]
# acc:0.933	batchsize: 4	lr: 0.005	hidsize:[16, 16]
# acc:0.933	batchsize: 4	lr: 0.005	hidsize:[32, 32]
# acc:0.93	batchsize: 4	lr: 0.005	hidsize:[64, 64]
# acc:0.936	batchsize: 4	lr:  0.01	hidsize:[8, 8]
# acc:0.933	batchsize: 4	lr:  0.01	hidsize:[16, 16]
# acc:0.929	batchsize: 4	lr:  0.01	hidsize:[32, 32]
# acc:0.929	batchsize: 4	lr:  0.01	hidsize:[64, 64]
# acc:0.753	batchsize: 4	lr:  0.05	hidsize:[8, 8]
# acc:0.894	batchsize: 4	lr:  0.05	hidsize:[16, 16]
# acc:0.858	batchsize: 4	lr:  0.05	hidsize:[32, 32]
# acc:0.924	batchsize: 4	lr:  0.05	hidsize:[64, 64]
# acc:0.936	batchsize:16	lr:0.0007	hidsize:[8, 8]
# acc:0.935	batchsize:16	lr:0.0007	hidsize:[16, 16]
# acc:0.938	batchsize:16	lr:0.0007	hidsize:[32, 32]
# acc:0.939	batchsize:16	lr:0.0007	hidsize:[64, 64]
# acc:0.939	batchsize:16	lr: 0.001	hidsize:[8, 8]
# acc:0.935	batchsize:16	lr: 0.001	hidsize:[16, 16]
# acc:0.938	batchsize:16	lr: 0.001	hidsize:[32, 32]
# acc:0.939	batchsize:16	lr: 0.001	hidsize:[64, 64]
# acc:0.94	batchsize:16	lr: 0.005	hidsize:[8, 8]
# acc:0.935	batchsize:16	lr: 0.005	hidsize:[16, 16]
# acc:0.938	batchsize:16	lr: 0.005	hidsize:[32, 32]
# acc:0.938	batchsize:16	lr: 0.005	hidsize:[64, 64]
# acc:0.939	batchsize:16	lr:  0.01	hidsize:[8, 8]
# acc:0.936	batchsize:16	lr:  0.01	hidsize:[16, 16]
# acc:0.938	batchsize:16	lr:  0.01	hidsize:[32, 32]
# acc:0.938	batchsize:16	lr:  0.01	hidsize:[64, 64]
# acc:0.938	batchsize:16	lr:  0.05	hidsize:[8, 8]
# acc:0.932	batchsize:16	lr:  0.05	hidsize:[16, 16]
# acc:0.894	batchsize:16	lr:  0.05	hidsize:[32, 32]
# acc:0.935	batchsize:16	lr:  0.05	hidsize:[64, 64]
# acc:0.938	batchsize:32	lr:0.0007	hidsize:[8, 8]
# acc:0.935	batchsize:32	lr:0.0007	hidsize:[16, 16]
# acc:0.938	batchsize:32	lr:0.0007	hidsize:[32, 32]
# acc:0.94	batchsize:32	lr:0.0007	hidsize:[64, 64]
# acc:0.942	batchsize:32	lr: 0.001	hidsize:[8, 8]
# acc:0.935	batchsize:32	lr: 0.001	hidsize:[16, 16]
# acc:0.939	batchsize:32	lr: 0.001	hidsize:[32, 32]
# acc:0.942	batchsize:32	lr: 0.001	hidsize:[64, 64]
# acc:0.939	batchsize:32	lr: 0.005	hidsize:[8, 8]
# acc:0.935	batchsize:32	lr: 0.005	hidsize:[16, 16]
# acc:0.939	batchsize:32	lr: 0.005	hidsize:[32, 32]
# acc:0.936	batchsize:32	lr: 0.005	hidsize:[64, 64]
# acc:0.942	batchsize:32	lr:  0.01	hidsize:[8, 8]
# acc:0.935	batchsize:32	lr:  0.01	hidsize:[16, 16]
# acc:0.938	batchsize:32	lr:  0.01	hidsize:[32, 32]
# acc:0.942	batchsize:32	lr:  0.01	hidsize:[64, 64]
# acc:0.935	batchsize:32	lr:  0.05	hidsize:[8, 8]
# acc:0.943	batchsize:32	lr:  0.05	hidsize:[16, 16]
# acc:0.942	batchsize:32	lr:  0.05	hidsize:[32, 32]
# acc:0.942	batchsize:32	lr:  0.05	hidsize:[64, 64]
# acc:0.943	batchsize:64	lr:0.0007	hidsize:[8, 8]
# acc:0.938	batchsize:64	lr:0.0007	hidsize:[16, 16]
# acc:0.938	batchsize:64	lr:0.0007	hidsize:[32, 32]
# acc:0.939	batchsize:64	lr:0.0007	hidsize:[64, 64]
# acc:0.942	batchsize:64	lr: 0.001	hidsize:[8, 8]
# acc:0.936	batchsize:64	lr: 0.001	hidsize:[16, 16]
# acc:0.936	batchsize:64	lr: 0.001	hidsize:[32, 32]
# acc:0.938	batchsize:64	lr: 0.001	hidsize:[64, 64]
# acc:0.939	batchsize:64	lr: 0.005	hidsize:[8, 8]
# acc:0.938	batchsize:64	lr: 0.005	hidsize:[16, 16]
# acc:0.939	batchsize:64	lr: 0.005	hidsize:[32, 32]
# acc:0.939	batchsize:64	lr: 0.005	hidsize:[64, 64]
# acc:0.939	batchsize:64	lr:  0.01	hidsize:[8, 8]
# acc:0.938	batchsize:64	lr:  0.01	hidsize:[16, 16]
# acc:0.939	batchsize:64	lr:  0.01	hidsize:[32, 32]
# acc:0.936	batchsize:64	lr:  0.01	hidsize:[64, 64]
# acc:0.938	batchsize:64	lr:  0.05	hidsize:[8, 8]
# acc:0.935	batchsize:64	lr:  0.05	hidsize:[16, 16]
# acc:0.933	batchsize:64	lr:  0.05	hidsize:[32, 32]
# acc:0.936	batchsize:64	lr:  0.05	hidsize:[64, 64]
# --------------------------------------
# | [PEER] best batchsize   | 32       |
# | [PEER] best hidsize     | [16, 16] |
# | [PEER] best learning... | 0.05     |
# --------------------------------------
# ---------------------------------
# | [PEER] alpha = 0.1 | 0.634    |
# | [PEER] alpha = 0.2 | 0.649    |
# | [PEER] alpha = 0.3 | 0.638    |
# | [PEER] alpha = 0.4 | 0.632    |
# | [PEER] alpha = 0.5 | 0.643    |
# | [PEER] alpha = 0.6 | 0.686    |
# | [PEER] alpha = 0.7 | 0.706    |
# | [PEER] alpha = 0.8 | 0.713    |
# | [PEER] alpha = 0.9 | 0.697    |
# | [PEER] alpha = 1.0 | 0.693    |
# ---------------------------------
# --------------------------------------
# | [NN] with bce loss      | 0.831    |
# | [NN] with peer loss     | 0.933    |
# | [NN] with surrogate ... | 0.898    |
# | [PEER] best alpha       | 0.8      |
# --------------------------------------
# Logging to logs/svm/19-08-28-17-01-02
# {'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'dataset': 'breast2', 'e0': 0.2, 'e1': 0.4, 'equalize_prior': False, 'episodes': 3000}
# --------------------------------
# | [C-SVM] C1 = 0.1  | 0.656    |
# | [C-SVM] C1 = 0.2  | 0.656    |
# | [C-SVM] C1 = 0.25 | 0.656    |
# | [C-SVM] C1 = 0.33 | 0.656    |
# | [C-SVM] C1 = 0.5  | 0.656    |
# | [C-SVM] C1 = 1.0  | 0.717    |
# | [C-SVM] C1 = 10.0 | 0.412    |
# | [C-SVM] C1 = 2.0  | 0.702    |
# | [C-SVM] C1 = 3.0  | 0.629    |
# | [C-SVM] C1 = 4.0  | 0.524    |
# | [C-SVM] C1 = 5.0  | 0.461    |
# --------------------------------
# ------------------------------------
# | [C-SVM] accuracy max  | 0.942    |
# | [C-SVM] accuracy mean | 0.862    |
# | [C-SVM] accuracy min  | 0.802    |
# | [C-SVM] accuracy std  | 0.0477   |
# | [C-SVM] best C1       | 1        |
# ------------------------------------
# Logging to logs/pam/19-08-28-17-01-02
# {'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'dataset': 'breast2', 'e0': 0.2, 'e1': 0.4, 'equalize_prior': False, 'episodes': 3000}
# -----------------------------------
# | [PAM] margin = 0     | 0.592    |
# | [PAM] margin = 0.125 | 0.697    |
# | [PAM] margin = 0.25  | 0.686    |
# | [PAM] margin = 0.5   | 0.682    |
# | [PAM] margin = 1     | 0.691    |
# -----------------------------------
# ----------------------------------
# | [PAM] accuracy max  | 0.93     |
# | [PAM] accuracy mean | 0.843    |
# | [PAM] accuracy min  | 0.767    |
# | [PAM] accuracy std  | 0.0618   |
# | [PAM] best margin   | 0.125    |
# ----------------------------------

# %% [markdown]
# ### $e_0=0.4, e_1=0.4$

# %%
from run_nn import find_best_alpha

args = default_args.copy()
args.update({
    'dataset': 'breast2', 
    'e0': 0.4, 'e1': 0.4, 
    'equalize_prior': False, 
    'episodes': 3000, 
    'batchsize': 32, 
    'hidsize': [8, 8], 
    'lr': 0.001, 
#     'alpha': 0.5,
})
find_best_alpha(args)
# Out:
# ---------------------------------
# | [PEER] alpha = 0.1 | 0.677    |
# | [PEER] alpha = 0.2 | 0.703    |
# | [PEER] alpha = 0.3 | 0.701    |
# | [PEER] alpha = 0.4 | 0.705    |
# | [PEER] alpha = 0.5 | 0.712    |
# | [PEER] alpha = 0.6 | 0.738    |
# | [PEER] alpha = 0.7 | 0.782    |
# | [PEER] alpha = 0.8 | 0.83     |
# | [PEER] alpha = 0.9 | 0.908    |
# | [PEER] alpha = 1.0 | 0.936    |
# ---------------------------------
# {'alpha': 1.0}

# %%
from runner import run

args = default_args.copy()
args.update({
    'dataset': 'breast2', 
    'e0': 0.4, 'e1': 0.4, 
    'equalize_prior': False, 
    'episodes': 3000, 
#     'batchsize': 64, 
#     'hidsize': [8, 8], 
#     'lr': 0.0007, 
#     'alpha': 0.8,
})
run(args)
# Out:
# Logging to logs/nn/19-08-28-17-01-08
# {'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'dataset': 'breast2', 'e0': 0.4, 'e1': 0.4, 'equalize_prior': False, 'episodes': 3000}
# acc:0.913	batchsize: 1	lr:0.0007	hidsize:[8, 8]
# acc:0.866	batchsize: 1	lr:0.0007	hidsize:[16, 16]
# acc:0.898	batchsize: 1	lr:0.0007	hidsize:[32, 32]
# acc: 0.9	batchsize: 1	lr:0.0007	hidsize:[64, 64]
# acc:0.916	batchsize: 1	lr: 0.001	hidsize:[8, 8]
# acc:0.881	batchsize: 1	lr: 0.001	hidsize:[16, 16]
# acc:0.904	batchsize: 1	lr: 0.001	hidsize:[32, 32]
# acc:0.901	batchsize: 1	lr: 0.001	hidsize:[64, 64]
# acc:0.913	batchsize: 1	lr: 0.005	hidsize:[8, 8]
# acc:0.907	batchsize: 1	lr: 0.005	hidsize:[16, 16]
# acc:0.917	batchsize: 1	lr: 0.005	hidsize:[32, 32]
# acc:0.852	batchsize: 1	lr: 0.005	hidsize:[64, 64]
# acc:0.911	batchsize: 1	lr:  0.01	hidsize:[8, 8]
# acc:0.846	batchsize: 1	lr:  0.01	hidsize:[16, 16]
# acc:0.901	batchsize: 1	lr:  0.01	hidsize:[32, 32]
# acc:0.843	batchsize: 1	lr:  0.01	hidsize:[64, 64]
# acc:0.692	batchsize: 1	lr:  0.05	hidsize:[8, 8]
# acc:0.765	batchsize: 1	lr:  0.05	hidsize:[16, 16]
# acc:0.712	batchsize: 1	lr:  0.05	hidsize:[32, 32]
# acc:0.887	batchsize: 1	lr:  0.05	hidsize:[64, 64]
# acc:0.917	batchsize: 4	lr:0.0007	hidsize:[8, 8]
# acc:0.898	batchsize: 4	lr:0.0007	hidsize:[16, 16]
# acc:0.922	batchsize: 4	lr:0.0007	hidsize:[32, 32]
# acc:0.917	batchsize: 4	lr:0.0007	hidsize:[64, 64]
# acc:0.926	batchsize: 4	lr: 0.001	hidsize:[8, 8]
# acc:0.894	batchsize: 4	lr: 0.001	hidsize:[16, 16]
# acc:0.917	batchsize: 4	lr: 0.001	hidsize:[32, 32]
# acc:0.916	batchsize: 4	lr: 0.001	hidsize:[64, 64]
# acc:0.922	batchsize: 4	lr: 0.005	hidsize:[8, 8]
# acc:0.917	batchsize: 4	lr: 0.005	hidsize:[16, 16]
# acc:0.913	batchsize: 4	lr: 0.005	hidsize:[32, 32]
# acc:0.882	batchsize: 4	lr: 0.005	hidsize:[64, 64]
# acc:0.911	batchsize: 4	lr:  0.01	hidsize:[8, 8]
# acc:0.913	batchsize: 4	lr:  0.01	hidsize:[16, 16]
# acc:0.881	batchsize: 4	lr:  0.01	hidsize:[32, 32]
# acc:0.906	batchsize: 4	lr:  0.01	hidsize:[64, 64]
# acc:0.773	batchsize: 4	lr:  0.05	hidsize:[8, 8]
# acc:0.826	batchsize: 4	lr:  0.05	hidsize:[16, 16]
# acc:0.887	batchsize: 4	lr:  0.05	hidsize:[32, 32]
# acc:0.894	batchsize: 4	lr:  0.05	hidsize:[64, 64]
# acc:0.927	batchsize:16	lr:0.0007	hidsize:[8, 8]
# acc:0.911	batchsize:16	lr:0.0007	hidsize:[16, 16]
# acc:0.923	batchsize:16	lr:0.0007	hidsize:[32, 32]
# acc:0.926	batchsize:16	lr:0.0007	hidsize:[64, 64]
# acc:0.935	batchsize:16	lr: 0.001	hidsize:[8, 8]
# acc:0.922	batchsize:16	lr: 0.001	hidsize:[16, 16]
# acc:0.922	batchsize:16	lr: 0.001	hidsize:[32, 32]
# acc:0.926	batchsize:16	lr: 0.001	hidsize:[64, 64]
# acc:0.923	batchsize:16	lr: 0.005	hidsize:[8, 8]
# acc:0.913	batchsize:16	lr: 0.005	hidsize:[16, 16]
# acc:0.919	batchsize:16	lr: 0.005	hidsize:[32, 32]
# acc:0.923	batchsize:16	lr: 0.005	hidsize:[64, 64]
# acc:0.924	batchsize:16	lr:  0.01	hidsize:[8, 8]
# acc:0.917	batchsize:16	lr:  0.01	hidsize:[16, 16]
# acc:0.922	batchsize:16	lr:  0.01	hidsize:[32, 32]
# acc:0.924	batchsize:16	lr:  0.01	hidsize:[64, 64]
# acc:0.795	batchsize:16	lr:  0.05	hidsize:[8, 8]
# acc:0.783	batchsize:16	lr:  0.05	hidsize:[16, 16]
# acc:0.903	batchsize:16	lr:  0.05	hidsize:[32, 32]
# acc:0.913	batchsize:16	lr:  0.05	hidsize:[64, 64]
# acc:0.929	batchsize:32	lr:0.0007	hidsize:[8, 8]
# acc:0.914	batchsize:32	lr:0.0007	hidsize:[16, 16]
# acc:0.93	batchsize:32	lr:0.0007	hidsize:[32, 32]
# acc:0.935	batchsize:32	lr:0.0007	hidsize:[64, 64]
# acc:0.936	batchsize:32	lr: 0.001	hidsize:[8, 8]
# acc:0.913	batchsize:32	lr: 0.001	hidsize:[16, 16]
# acc:0.932	batchsize:32	lr: 0.001	hidsize:[32, 32]
# acc:0.933	batchsize:32	lr: 0.001	hidsize:[64, 64]
# acc:0.923	batchsize:32	lr: 0.005	hidsize:[8, 8]
# acc:0.926	batchsize:32	lr: 0.005	hidsize:[16, 16]
# acc:0.932	batchsize:32	lr: 0.005	hidsize:[32, 32]
# acc:0.932	batchsize:32	lr: 0.005	hidsize:[64, 64]
# acc:0.929	batchsize:32	lr:  0.01	hidsize:[8, 8]
# acc:0.872	batchsize:32	lr:  0.01	hidsize:[16, 16]
# acc:0.932	batchsize:32	lr:  0.01	hidsize:[32, 32]
# acc:0.93	batchsize:32	lr:  0.01	hidsize:[64, 64]
# acc:0.884	batchsize:32	lr:  0.05	hidsize:[8, 8]
# acc:0.914	batchsize:32	lr:  0.05	hidsize:[16, 16]
# acc:0.933	batchsize:32	lr:  0.05	hidsize:[32, 32]
# acc:0.926	batchsize:32	lr:  0.05	hidsize:[64, 64]
# acc:0.927	batchsize:64	lr:0.0007	hidsize:[8, 8]
# acc:0.908	batchsize:64	lr:0.0007	hidsize:[16, 16]
# acc:0.924	batchsize:64	lr:0.0007	hidsize:[32, 32]
# acc:0.919	batchsize:64	lr:0.0007	hidsize:[64, 64]
# acc:0.926	batchsize:64	lr: 0.001	hidsize:[8, 8]
# acc:0.914	batchsize:64	lr: 0.001	hidsize:[16, 16]
# acc:0.927	batchsize:64	lr: 0.001	hidsize:[32, 32]
# acc:0.926	batchsize:64	lr: 0.001	hidsize:[64, 64]
# acc:0.922	batchsize:64	lr: 0.005	hidsize:[8, 8]
# acc:0.917	batchsize:64	lr: 0.005	hidsize:[16, 16]
# acc:0.924	batchsize:64	lr: 0.005	hidsize:[32, 32]
# acc:0.929	batchsize:64	lr: 0.005	hidsize:[64, 64]
# acc:0.924	batchsize:64	lr:  0.01	hidsize:[8, 8]
# acc:0.916	batchsize:64	lr:  0.01	hidsize:[16, 16]
# acc:0.932	batchsize:64	lr:  0.01	hidsize:[32, 32]
# acc:0.93	batchsize:64	lr:  0.01	hidsize:[64, 64]
# acc:0.876	batchsize:64	lr:  0.05	hidsize:[8, 8]
# acc:0.914	batchsize:64	lr:  0.05	hidsize:[16, 16]
# acc:0.93	batchsize:64	lr:  0.05	hidsize:[32, 32]
# acc:0.932	batchsize:64	lr:  0.05	hidsize:[64, 64]
# --------------------------------------
# | [PEER] best batchsize   | 32       |
# | [PEER] best hidsize     | [8, 8]   |
# | [PEER] best learning... | 0.001    |
# --------------------------------------
# ---------------------------------
# | [PEER] alpha = 0.1 | 0.588    |
# | [PEER] alpha = 0.2 | 0.566    |
# | [PEER] alpha = 0.3 | 0.57     |
# | [PEER] alpha = 0.4 | 0.57     |
# | [PEER] alpha = 0.5 | 0.57     |
# | [PEER] alpha = 0.6 | 0.557    |
# | [PEER] alpha = 0.7 | 0.57     |
# | [PEER] alpha = 0.8 | 0.581    |
# | [PEER] alpha = 0.9 | 0.607    |
# | [PEER] alpha = 1.0 | 0.596    |
# ---------------------------------
# --------------------------------------
# | [NN] with bce loss      | 0.673    |
# | [NN] with peer loss     | 0.908    |
# | [NN] with surrogate ... | 0.839    |
# | [PEER] best alpha       | 0.9      |
# --------------------------------------
# Logging to logs/svm/19-08-28-17-18-33
# {'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'dataset': 'breast2', 'e0': 0.4, 'e1': 0.4, 'equalize_prior': False, 'episodes': 3000}
# --------------------------------
# | [C-SVM] C1 = 0.1  | 0.531    |
# | [C-SVM] C1 = 0.2  | 0.531    |
# | [C-SVM] C1 = 0.25 | 0.531    |
# | [C-SVM] C1 = 0.33 | 0.531    |
# | [C-SVM] C1 = 0.5  | 0.529    |
# | [C-SVM] C1 = 1.0  | 0.596    |
# | [C-SVM] C1 = 10.0 | 0.471    |
# | [C-SVM] C1 = 2.0  | 0.487    |
# | [C-SVM] C1 = 3.0  | 0.476    |
# | [C-SVM] C1 = 4.0  | 0.471    |
# | [C-SVM] C1 = 5.0  | 0.471    |
# --------------------------------
# ------------------------------------
# | [C-SVM] accuracy max  | 0.919    |
# | [C-SVM] accuracy mean | 0.866    |
# | [C-SVM] accuracy min  | 0.791    |
# | [C-SVM] accuracy std  | 0.039    |
# | [C-SVM] best C1       | 1        |
# ------------------------------------
# Logging to logs/pam/19-08-28-17-18-34
# {'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'dataset': 'breast2', 'e0': 0.4, 'e1': 0.4, 'equalize_prior': False, 'episodes': 3000}
# -----------------------------------
# | [PAM] margin = 0     | 0.515    |
# | [PAM] margin = 0.125 | 0.586    |
# | [PAM] margin = 0.25  | 0.577    |
# | [PAM] margin = 0.5   | 0.566    |
# | [PAM] margin = 1     | 0.583    |
# -----------------------------------
# ----------------------------------
# | [PAM] accuracy max  | 0.93     |
# | [PAM] accuracy mean | 0.789    |
# | [PAM] accuracy min  | 0.535    |
# | [PAM] accuracy std  | 0.116    |
# | [PAM] best margin   | 0.125    |
# ----------------------------------

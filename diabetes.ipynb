# %% [markdown]
# # Pima Indians Diabetes Database
#
# https://www.kaggle.com/uciml/pima-indians-diabetes-database

# %% [markdown]
# ## Describe
#
# | Total | Positive | Attributes | Normalized |
# |:-----:|:--------:|:----------:|:----------:|
# |  768  |  34.9%   |     8      |     Not    |

# %%
from utils.dataloader import DataLoader

df = DataLoader('diabetes').df
df.target.describe()
# Out:
# count    768.000000
# mean       0.348958
# std        0.476951
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        1.000000
# max        1.000000
# Name: target, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
# Pregnancies                 768 non-null int64
# Glucose                     768 non-null int64
# BloodPressure               768 non-null int64
# SkinThickness               768 non-null int64
# Insulin                     768 non-null int64
# BMI                         768 non-null float64
# DiabetesPedigreeFunction    768 non-null float64
# Age                         768 non-null int64
# target                      768 non-null int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age      target
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# min      0.000000                  0.078000   21.000000    0.000000
# 25%     27.300000                  0.243750   24.000000    0.000000
# 50%     32.000000                  0.372500   29.000000    0.000000
# 75%     36.600000                  0.626250   41.000000    1.000000
# max     67.100000                  2.420000   81.000000    1.000000

# %% [markdown]
# ## With prior equalization

# %%
from runner import run

arg_dict = {
    'dataset': 'diabetes', 
    'lr': 0.001, 
    'hidsize': 8, 
    'episodes': 150, 
    'batchsize': 10, 
    'test_size': 0.80,
    'dropout': 0.,
    'normalize': True,
    'equalize_prior': True,
}

# %% [markdown]
# $e_0 = 0, e_1 = 0$

# %%
arg_dict.update({'e0': 0, 'e1': 0})
run(arg_dict.copy())
# Out:
# {'dataset': 'diabetes', 'lr': 0.001, 'hidsize': 8, 'episodes': 150, 'batchsize': 10, 'test_size': 0.8, 'dropout': 0.0, 'normalize': True, 'equalize_prior': True, 'e0': 0, 'e1': 0}
# --------------------------------------
# | knn                     | 0.708    |
# | logistic regression     | 0.744    |
# | nn                      | 0.728    |
# | nn with peer prediction | 0.719    |
# | random forest           | 0.746    |
# | svm                     | 0.742    |
# --------------------------------------

# %% [markdown]
# $e_0 = 0.2, e_1 = 0.2$

# %%
arg_dict.update({'e0': 0.2, 'e1': 0.2})
run(arg_dict.copy())
# Out:
# {'dataset': 'heart', 'lr': 0.001, 'hidsize': 8, 'episodes': 150, 'batchsize': 10, 'test_size': 0.8, 'dropout': 0.0, 'normalize': True, 'equalize_prior': False, 'e0': 0.2, 'e1': 0.2}
# --------------------------------------
# | knn                     | 0.742    |
# | logistic regression     | 0.772    |
# | nn                      | 0.758    |
# | nn with peer prediction | 0.79     |
# | random forest           | 0.775    |
# | svm                     | 0.779    |
# --------------------------------------

# %% [markdown]
# $e_0 = 0.1, e_1 = 0.3$

# %%
arg_dict.update({'e0': 0.1, 'e1': 0.3})
run(arg_dict.copy())
# Out:
# {'dataset': 'diabetes', 'lr': 0.001, 'hidsize': 8, 'episodes': 150, 'batchsize': 10, 'test_size': 0.8, 'dropout': 0.0, 'normalize': True, 'equalize_prior': True, 'e0': 0.1, 'e1': 0.3}
# --------------------------------------
# | knn                     | 0.639    |
# | logistic regression     | 0.698    |
# | nn                      | 0.668    |
# | nn with peer prediction | 0.694    |
# | random forest           | 0.669    |
# | svm                     | 0.669    |
# --------------------------------------

# %% [markdown]
# $e_0 = 0.2, e_1 = 0.4$

# %%
arg_dict.update({'e0': 0.2, 'e1': 0.4})
run(arg_dict.copy())
# Out:
# {'dataset': 'diabetes', 'lr': 0.001, 'hidsize': 8, 'episodes': 150, 'batchsize': 10, 'test_size': 0.8, 'dropout': 0.0, 'normalize': True, 'equalize_prior': True, 'e0': 0.2, 'e1': 0.4}
# --------------------------------------
# | knn                     | 0.599    |
# | logistic regression     | 0.661    |
# | nn                      | 0.618    |
# | nn with peer prediction | 0.667    |
# | random forest           | 0.635    |
# | svm                     | 0.627    |
# --------------------------------------

# %% [markdown]
# $e_0=0.4, e_1=0.4$

# %%
arg_dict.update({'e0': 0.4, 'e1': 0.4})
run(arg_dict.copy())
# Out:
# {'dataset': 'diabetes', 'lr': 0.001, 'hidsize': 8, 'episodes': 150, 'batchsize': 10, 'test_size': 0.8, 'dropout': 0.0, 'normalize': True, 'equalize_prior': True, 'e0': 0.4, 'e1': 0.4}
# --------------------------------------
# | knn                     | 0.551    |
# | logistic regression     | 0.674    |
# | nn                      | 0.606    |
# | nn with peer prediction | 0.614    |
# | random forest           | 0.597    |
# | svm                     | 0.631    |
# --------------------------------------

# %% [markdown]
# ## No prior equalization

# %%
from runner import run

arg_dict = {
    'dataset': 'heart', 
    'lr': 0.001, 
    'hidsize': 8, 
    'episodes': 150, 
    'batchsize': 10, 
    'test_size': 0.80,
    'dropout': 0.,
    'normalize': True,
    'equalize_prior': False,
}

# %% [markdown]
# $e_0 = 0, e_1 = 0$

# %%
arg_dict.update({'e0': 0, 'e1': 0})
run(arg_dict.copy())
# Out:
# {'dataset': 'heart', 'lr': 0.001, 'hidsize': 8, 'episodes': 150, 'batchsize': 10, 'test_size': 0.8, 'dropout': 0.0, 'normalize': True, 'equalize_prior': False, 'e0': 0, 'e1': 0}
# --------------------------------------
# | knn                     | 0.818    |
# | logistic regression     | 0.82     |
# | nn                      | 0.803    |
# | nn with peer prediction | 0.81     |
# | random forest           | 0.816    |
# | svm                     | 0.808    |
# --------------------------------------

# %% [markdown]
# $e_0 = 0.2, e_1 = 0.2$

# %%
arg_dict.update({'e0': 0.2, 'e1': 0.2})
run(arg_dict.copy())
# Out:
# {'dataset': 'heart', 'lr': 0.001, 'hidsize': 8, 'episodes': 150, 'batchsize': 10, 'test_size': 0.8, 'dropout': 0.0, 'normalize': True, 'equalize_prior': False, 'e0': 0.2, 'e1': 0.2}
# --------------------------------------
# | knn                     | 0.742    |
# | logistic regression     | 0.772    |
# | nn                      | 0.758    |
# | nn with peer prediction | 0.79     |
# | random forest           | 0.775    |
# | svm                     | 0.779    |
# --------------------------------------

# %% [markdown]
# $e_0 = 0.1, e_1 = 0.3$

# %%
arg_dict.update({'e0': 0.1, 'e1': 0.3})
run(arg_dict.copy())
# Out:
# {'dataset': 'heart', 'lr': 0.001, 'hidsize': 8, 'episodes': 150, 'batchsize': 10, 'test_size': 0.8, 'dropout': 0.0, 'normalize': True, 'equalize_prior': False, 'e0': 0.1, 'e1': 0.3}
# --------------------------------------
# | knn                     | 0.727    |
# | logistic regression     | 0.75     |
# | nn                      | 0.733    |
# | nn with peer prediction | 0.781    |
# | random forest           | 0.727    |
# | svm                     | 0.75     |
# --------------------------------------

# %% [markdown]
# $e_0 = 0.2, e_1 = 0.4$

# %%
arg_dict.update({'e0': 0.2, 'e1': 0.4})
run(arg_dict.copy())
# Out:
# {'dataset': 'heart', 'lr': 0.001, 'hidsize': 8, 'episodes': 150, 'batchsize': 10, 'test_size': 0.8, 'dropout': 0.0, 'normalize': True, 'equalize_prior': False, 'e0': 0.2, 'e1': 0.4}
# --------------------------------------
# | knn                     | 0.648    |
# | logistic regression     | 0.684    |
# | nn                      | 0.683    |
# | nn with peer prediction | 0.749    |
# | random forest           | 0.666    |
# | svm                     | 0.675    |
# --------------------------------------

# %% [markdown]
# $e_0=0.4, e_1=0.4$

# %%
arg_dict.update({'e0': 0.4, 'e1': 0.4})
run(arg_dict.copy())
# Out:
# {'dataset': 'heart', 'lr': 0.001, 'hidsize': 8, 'episodes': 150, 'batchsize': 10, 'test_size': 0.8, 'dropout': 0.0, 'normalize': True, 'equalize_prior': False, 'e0': 0.4, 'e1': 0.4}
# --------------------------------------
# | knn                     | 0.583    |
# | logistic regression     | 0.657    |
# | nn                      | 0.652    |
# | nn with peer prediction | 0.668    |
# | random forest           | 0.626    |
# | svm                     | 0.666    |
# --------------------------------------

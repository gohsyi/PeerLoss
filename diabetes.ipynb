# %% [markdown]
# # Diabetes (8,268,500)

# %% [markdown]
# ## Describe
#
# | Total | Positive | Attributes | Normalized |
# |:-----:|:--------:|:----------:|:----------:|
# |  768  |  34.9%   |     8      |     Not    |

# %%
default_args = {
    'dataset': 'diabetes',
    'test_size': 0.15,
    'val_size': 0.1,
    'dropout': 0, 
    'normalize': True,
    'loss': 'bce',
    'activation': 'relu',
    'verbose': True,
}

# %% [markdown]
# ## With Prior Equalization

# %% [markdown]
# ### $e_0 = 0.1, e_1 = 0.3$

# %%
from run_nn import find_best_alpha
args = default_args.copy()
args.update({
    'e0': 0.1, 'e1': 0.3, 
    'equalize_prior': True, 
    'episodes': 1000, 
    'batchsize': 64, 
    'hidsize': [64, 64], 
    'lr': 0.001, 
})
find_best_alpha(args)
# Out:
# ---------------------------------
# | [PEER] alpha = 0.1 | 0.665    |
# | [PEER] alpha = 0.2 | 0.676    |
# | [PEER] alpha = 0.3 | 0.685    |
# | [PEER] alpha = 0.4 | 0.698    |
# | [PEER] alpha = 0.5 | 0.713    |
# | [PEER] alpha = 0.6 | 0.73     |
# | [PEER] alpha = 0.7 | 0.744    |
# | [PEER] alpha = 0.8 | 0.741    |
# | [PEER] alpha = 0.9 | 0.752    |
# | [PEER] alpha = 1.0 | 0.745    |
# ---------------------------------
# {'alpha': 0.9}

# %%
from runner import run
args = default_args.copy()
args.update({
    'e0': 0.1, 'e1': 0.3, 
    'equalize_prior': True, 
    'episodes': 1000, 
    'batchsize': 64, 
    'hidsize': [64, 64], 
    'lr': 0.001, 
})
run(args)
# Out:
# Logging to logs/nn/19-08-28-20-10-43
# {'dataset': 'diabetes', 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'e0': 0.1, 'e1': 0.3, 'equalize_prior': True, 'episodes': 1000, 'batchsize': 64, 'hidsize': [64, 64], 'lr': 0.001}
# ---------------------------------
# | [PEER] alpha = 0.1 | 0.634    |
# | [PEER] alpha = 0.2 | 0.648    |
# | [PEER] alpha = 0.3 | 0.646    |
# | [PEER] alpha = 0.4 | 0.674    |
# | [PEER] alpha = 0.5 | 0.667    |
# | [PEER] alpha = 0.6 | 0.685    |
# | [PEER] alpha = 0.7 | 0.683    |
# | [PEER] alpha = 0.8 | 0.667    |
# | [PEER] alpha = 0.9 | 0.667    |
# | [PEER] alpha = 1.0 | 0.646    |
# ---------------------------------
# --------------------------------------
# | [NN] with bce loss      | 0.667    |
# | [NN] with peer loss     | 0.73     |
# | [NN] with surrogate ... | 0.707    |
# | [PEER] best alpha       | 0.6      |
# --------------------------------------
# Logging to logs/svm/19-08-28-20-11-57
# {'dataset': 'diabetes', 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'e0': 0.1, 'e1': 0.3, 'equalize_prior': True, 'episodes': 1000, 'batchsize': 64, 'hidsize': [64, 64], 'lr': 0.001}
# --------------------------------
# | [C-SVM] C1 = 0.1  | 0.602    |
# | [C-SVM] C1 = 0.2  | 0.602    |
# | [C-SVM] C1 = 0.25 | 0.602    |
# | [C-SVM] C1 = 0.33 | 0.602    |
# | [C-SVM] C1 = 0.5  | 0.606    |
# | [C-SVM] C1 = 1.0  | 0.681    |
# | [C-SVM] C1 = 10.0 | 0.431    |
# | [C-SVM] C1 = 2.0  | 0.644    |
# | [C-SVM] C1 = 3.0  | 0.569    |
# | [C-SVM] C1 = 4.0  | 0.537    |
# | [C-SVM] C1 = 5.0  | 0.488    |
# --------------------------------
# ------------------------------------
# | [C-SVM] accuracy max  | 0.765    |
# | [C-SVM] accuracy mean | 0.67     |
# | [C-SVM] accuracy min  | 0.58     |
# | [C-SVM] accuracy std  | 0.0591   |
# | [C-SVM] best C1       | 1        |
# ------------------------------------
# Logging to logs/pam/19-08-28-20-11-58
# {'dataset': 'diabetes', 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'e0': 0.1, 'e1': 0.3, 'equalize_prior': True, 'episodes': 1000, 'batchsize': 64, 'hidsize': [64, 64], 'lr': 0.001}
# -----------------------------------
# | [PAM] margin = 0     | 0.597    |
# | [PAM] margin = 0.125 | 0.685    |
# | [PAM] margin = 0.25  | 0.681    |
# | [PAM] margin = 0.5   | 0.681    |
# | [PAM] margin = 1     | 0.681    |
# -----------------------------------
# ----------------------------------
# | [PAM] accuracy max  | 0.753    |
# | [PAM] accuracy mean | 0.698    |
# | [PAM] accuracy min  | 0.568    |
# | [PAM] accuracy std  | 0.0569   |
# | [PAM] best margin   | 0.125    |
# ----------------------------------

# %% [markdown]
# ### $e_0 = 0.2, e_1 = 0.2$

# %%
from run_nn import find_best_alpha
args = default_args.copy()
args.update({
    'e0': 0.2, 'e1': 0.2, 
    'equalize_prior': True, 
    'episodes': 1000, 
    'batchsize': 64, 
    'hidsize': [64, 64], 
    'lr': 0.001, 
})
find_best_alpha(args)
# Out:
# ---------------------------------
# | [PEER] alpha = 0.1 | 0.664    |
# | [PEER] alpha = 0.2 | 0.685    |
# | [PEER] alpha = 0.3 | 0.696    |
# | [PEER] alpha = 0.4 | 0.724    |
# | [PEER] alpha = 0.5 | 0.753    |
# | [PEER] alpha = 0.6 | 0.745    |
# | [PEER] alpha = 0.7 | 0.745    |
# | [PEER] alpha = 0.8 | 0.748    |
# | [PEER] alpha = 0.9 | 0.759    |
# | [PEER] alpha = 1.0 | 0.755    |
# ---------------------------------
# {'alpha': 0.9}

# %%
from runner import run
args = default_args.copy()
args.update({
    'e0': 0.2, 'e1': 0.2, 
    'equalize_prior': True, 
    'episodes': 1000, 
    'batchsize': 64, 
    'hidsize': [64, 64], 
    'lr': 0.001, 
})
run(args)
# Out:
# Logging to logs/nn/19-08-28-20-17-01
# {'dataset': 'diabetes', 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'e0': 0.2, 'e1': 0.2, 'equalize_prior': True, 'episodes': 1000, 'batchsize': 64, 'hidsize': [64, 64], 'lr': 0.001}
# ---------------------------------
# | [PEER] alpha = 0.1 | 0.606    |
# | [PEER] alpha = 0.2 | 0.597    |
# | [PEER] alpha = 0.3 | 0.639    |
# | [PEER] alpha = 0.4 | 0.637    |
# | [PEER] alpha = 0.5 | 0.634    |
# | [PEER] alpha = 0.6 | 0.65     |
# | [PEER] alpha = 0.7 | 0.676    |
# | [PEER] alpha = 0.8 | 0.671    |
# | [PEER] alpha = 0.9 | 0.662    |
# | [PEER] alpha = 1.0 | 0.653    |
# ---------------------------------
# --------------------------------------
# | [NN] with bce loss      | 0.671    |
# | [NN] with peer loss     | 0.745    |
# | [NN] with surrogate ... | 0.708    |
# | [PEER] best alpha       | 0.7      |
# --------------------------------------
# Logging to logs/svm/19-08-28-20-18-10
# {'dataset': 'diabetes', 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'e0': 0.2, 'e1': 0.2, 'equalize_prior': True, 'episodes': 1000, 'batchsize': 64, 'hidsize': [64, 64], 'lr': 0.001}
# --------------------------------
# | [C-SVM] C1 = 0.1  | 0.505    |
# | [C-SVM] C1 = 0.2  | 0.505    |
# | [C-SVM] C1 = 0.25 | 0.505    |
# | [C-SVM] C1 = 0.33 | 0.512    |
# | [C-SVM] C1 = 0.5  | 0.569    |
# | [C-SVM] C1 = 1.0  | 0.632    |
# | [C-SVM] C1 = 10.0 | 0.502    |
# | [C-SVM] C1 = 2.0  | 0.593    |
# | [C-SVM] C1 = 3.0  | 0.542    |
# | [C-SVM] C1 = 4.0  | 0.514    |
# | [C-SVM] C1 = 5.0  | 0.509    |
# --------------------------------
# ------------------------------------
# | [C-SVM] accuracy max  | 0.852    |
# | [C-SVM] accuracy mean | 0.745    |
# | [C-SVM] accuracy min  | 0.691    |
# | [C-SVM] accuracy std  | 0.0486   |
# | [C-SVM] best C1       | 1        |
# ------------------------------------
# Logging to logs/pam/19-08-28-20-18-10
# {'dataset': 'diabetes', 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'e0': 0.2, 'e1': 0.2, 'equalize_prior': True, 'episodes': 1000, 'batchsize': 64, 'hidsize': [64, 64], 'lr': 0.001}
# -----------------------------------
# | [PAM] margin = 0     | 0.549    |
# | [PAM] margin = 0.125 | 0.664    |
# | [PAM] margin = 0.25  | 0.678    |
# | [PAM] margin = 0.5   | 0.669    |
# | [PAM] margin = 1     | 0.662    |
# -----------------------------------
# ----------------------------------
# | [PAM] accuracy max  | 0.79     |
# | [PAM] accuracy mean | 0.747    |
# | [PAM] accuracy min  | 0.667    |
# | [PAM] accuracy std  | 0.0432   |
# | [PAM] best margin   | 0.25     |
# ----------------------------------

# %% [markdown]
# ### $e_0 = 0.1, e_1 = 0.4$

# %%
from run_nn import find_best_alpha
args = default_args.copy()
args.update({
    'e0': 0.1, 'e1': 0.4, 
    'equalize_prior': True, 
    'episodes': 1000, 
    'batchsize': 64, 
    'hidsize': [64, 64], 
    'lr': 0.001, 
})
find_best_alpha(args)
# Out:
# ---------------------------------
# | [PEER] alpha = 0.1 | 0.625    |
# | [PEER] alpha = 0.2 | 0.631    |
# | [PEER] alpha = 0.3 | 0.651    |
# | [PEER] alpha = 0.4 | 0.66     |
# | [PEER] alpha = 0.5 | 0.673    |
# | [PEER] alpha = 0.6 | 0.684    |
# | [PEER] alpha = 0.7 | 0.727    |
# | [PEER] alpha = 0.8 | 0.731    |
# | [PEER] alpha = 0.9 | 0.733    |
# | [PEER] alpha = 1.0 | 0.745    |
# ---------------------------------
# {'alpha': 1.0}

# %%
from runner import run
args = default_args.copy()
args.update({
    'e0': 0.1, 'e1': 0.4, 
    'equalize_prior': True, 
    'episodes': 1000, 
    'batchsize': 64, 
    'hidsize': [64, 64], 
    'lr': 0.001, 
})
run(args)
# Out:
# Logging to logs/nn/19-08-28-20-19-17
# {'dataset': 'diabetes', 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'e0': 0.1, 'e1': 0.4, 'equalize_prior': True, 'episodes': 1000, 'batchsize': 64, 'hidsize': [64, 64], 'lr': 0.001}
# ---------------------------------
# | [PEER] alpha = 0.1 | 0.655    |
# | [PEER] alpha = 0.2 | 0.653    |
# | [PEER] alpha = 0.3 | 0.664    |
# | [PEER] alpha = 0.4 | 0.66     |
# | [PEER] alpha = 0.5 | 0.662    |
# | [PEER] alpha = 0.6 | 0.685    |
# | [PEER] alpha = 0.7 | 0.688    |
# | [PEER] alpha = 0.8 | 0.667    |
# | [PEER] alpha = 0.9 | 0.653    |
# | [PEER] alpha = 1.0 | 0.623    |
# ---------------------------------
# --------------------------------------
# | [NN] with bce loss      | 0.627    |
# | [NN] with peer loss     | 0.727    |
# | [NN] with surrogate ... | 0.682    |
# | [PEER] best alpha       | 0.7      |
# --------------------------------------
# Logging to logs/svm/19-08-28-20-20-26
# {'dataset': 'diabetes', 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'e0': 0.1, 'e1': 0.4, 'equalize_prior': True, 'episodes': 1000, 'batchsize': 64, 'hidsize': [64, 64], 'lr': 0.001}
# --------------------------------
# | [C-SVM] C1 = 0.1  | 0.653    |
# | [C-SVM] C1 = 0.2  | 0.653    |
# | [C-SVM] C1 = 0.25 | 0.653    |
# | [C-SVM] C1 = 0.33 | 0.653    |
# | [C-SVM] C1 = 0.5  | 0.653    |
# | [C-SVM] C1 = 1.0  | 0.685    |
# | [C-SVM] C1 = 10.0 | 0.4      |
# | [C-SVM] C1 = 2.0  | 0.644    |
# | [C-SVM] C1 = 3.0  | 0.569    |
# | [C-SVM] C1 = 4.0  | 0.512    |
# | [C-SVM] C1 = 5.0  | 0.481    |
# --------------------------------
# ------------------------------------
# | [C-SVM] accuracy max  | 0.654    |
# | [C-SVM] accuracy mean | 0.568    |
# | [C-SVM] accuracy min  | 0.432    |
# | [C-SVM] accuracy std  | 0.0783   |
# | [C-SVM] best C1       | 1        |
# ------------------------------------
# Logging to logs/pam/19-08-28-20-20-26
# {'dataset': 'diabetes', 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'e0': 0.1, 'e1': 0.4, 'equalize_prior': True, 'episodes': 1000, 'batchsize': 64, 'hidsize': [64, 64], 'lr': 0.001}
# -----------------------------------
# | [PAM] margin = 0     | 0.6      |
# | [PAM] margin = 0.125 | 0.681    |
# | [PAM] margin = 0.25  | 0.676    |
# | [PAM] margin = 0.5   | 0.678    |
# | [PAM] margin = 1     | 0.676    |
# -----------------------------------
# ----------------------------------
# | [PAM] accuracy max  | 0.654    |
# | [PAM] accuracy mean | 0.529    |
# | [PAM] accuracy min  | 0.395    |
# | [PAM] accuracy std  | 0.0904   |
# | [PAM] best margin   | 0.125    |
# ----------------------------------

# %% [markdown]
# ### $e_0 = 0.2, e_1 = 0.4$

# %%
from run_nn import find_best_alpha
args = default_args.copy()
args.update({
    'e0': 0.2, 'e1': 0.4, 
    'equalize_prior': True, 
    'episodes': 1000, 
    'batchsize': 64, 
    'hidsize': [64, 64], 
    'lr': 0.001, 
})
find_best_alpha(args)
# Out:
# ---------------------------------
# | [PEER] alpha = 0.1 | 0.631    |
# | [PEER] alpha = 0.2 | 0.628    |
# | [PEER] alpha = 0.3 | 0.623    |
# | [PEER] alpha = 0.4 | 0.644    |
# | [PEER] alpha = 0.5 | 0.653    |
# | [PEER] alpha = 0.6 | 0.671    |
# | [PEER] alpha = 0.7 | 0.691    |
# | [PEER] alpha = 0.8 | 0.713    |
# | [PEER] alpha = 0.9 | 0.722    |
# | [PEER] alpha = 1.0 | 0.755    |
# ---------------------------------
# {'alpha': 1.0}

# %%
from runner import run
args = default_args.copy()
args.update({
    'e0': 0.2, 'e1': 0.4, 
    'equalize_prior': True, 
    'episodes': 1000, 
    'batchsize': 64, 
    'hidsize': [64, 64], 
    'lr': 0.001, 
})
run(args)
# Out:
# Logging to logs/nn/19-08-28-20-21-29
# {'dataset': 'diabetes', 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'e0': 0.2, 'e1': 0.4, 'equalize_prior': True, 'episodes': 1000, 'batchsize': 64, 'hidsize': [64, 64], 'lr': 0.001}
# ---------------------------------
# | [PEER] alpha = 0.1 | 0.574    |
# | [PEER] alpha = 0.2 | 0.574    |
# | [PEER] alpha = 0.3 | 0.574    |
# | [PEER] alpha = 0.4 | 0.583    |
# | [PEER] alpha = 0.5 | 0.623    |
# | [PEER] alpha = 0.6 | 0.63     |
# | [PEER] alpha = 0.7 | 0.613    |
# | [PEER] alpha = 0.8 | 0.618    |
# | [PEER] alpha = 0.9 | 0.618    |
# | [PEER] alpha = 1.0 | 0.595    |
# ---------------------------------
# --------------------------------------
# | [NN] with bce loss      | 0.596    |
# | [NN] with peer loss     | 0.671    |
# | [NN] with surrogate ... | 0.681    |
# | [PEER] best alpha       | 0.6      |
# --------------------------------------
# Logging to logs/svm/19-08-28-20-22-32
# {'dataset': 'diabetes', 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'e0': 0.2, 'e1': 0.4, 'equalize_prior': True, 'episodes': 1000, 'batchsize': 64, 'hidsize': [64, 64], 'lr': 0.001}
# --------------------------------
# | [C-SVM] C1 = 0.1  | 0.604    |
# | [C-SVM] C1 = 0.2  | 0.604    |
# | [C-SVM] C1 = 0.25 | 0.604    |
# | [C-SVM] C1 = 0.33 | 0.604    |
# | [C-SVM] C1 = 0.5  | 0.606    |
# | [C-SVM] C1 = 1.0  | 0.618    |
# | [C-SVM] C1 = 10.0 | 0.412    |
# | [C-SVM] C1 = 2.0  | 0.581    |
# | [C-SVM] C1 = 3.0  | 0.475    |
# | [C-SVM] C1 = 4.0  | 0.444    |
# | [C-SVM] C1 = 5.0  | 0.426    |
# --------------------------------
# ------------------------------------
# | [C-SVM] accuracy max  | 0.691    |
# | [C-SVM] accuracy mean | 0.59     |
# | [C-SVM] accuracy min  | 0.457    |
# | [C-SVM] accuracy std  | 0.0681   |
# | [C-SVM] best C1       | 1        |
# ------------------------------------
# Logging to logs/pam/19-08-28-20-22-33
# {'dataset': 'diabetes', 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'e0': 0.2, 'e1': 0.4, 'equalize_prior': True, 'episodes': 1000, 'batchsize': 64, 'hidsize': [64, 64], 'lr': 0.001}
# -----------------------------------
# | [PAM] margin = 0     | 0.553    |
# | [PAM] margin = 0.125 | 0.632    |
# | [PAM] margin = 0.25  | 0.625    |
# | [PAM] margin = 0.5   | 0.625    |
# | [PAM] margin = 1     | 0.627    |
# -----------------------------------
# ----------------------------------
# | [PAM] accuracy max  | 0.716    |
# | [PAM] accuracy mean | 0.554    |
# | [PAM] accuracy min  | 0.395    |
# | [PAM] accuracy std  | 0.114    |
# | [PAM] best margin   | 0.125    |
# ----------------------------------

# %% [markdown]
# ### $e_0 = 0.4, e_1 = 0.4$

# %%
from run_nn import find_best_alpha
args = default_args.copy()
args.update({
    'e0': 0.4, 'e1': 0.4, 
    'equalize_prior': True, 
    'episodes': 1000, 
    'batchsize': 64, 
    'hidsize': [64, 64], 
    'lr': 0.001, 
})
find_best_alpha(args)
# Out:
# ---------------------------------
# | [PEER] alpha = 0.1 | 0.539    |
# | [PEER] alpha = 0.2 | 0.549    |
# | [PEER] alpha = 0.3 | 0.556    |
# | [PEER] alpha = 0.4 | 0.54     |
# | [PEER] alpha = 0.5 | 0.566    |
# | [PEER] alpha = 0.6 | 0.588    |
# | [PEER] alpha = 0.7 | 0.63     |
# | [PEER] alpha = 0.8 | 0.66     |
# | [PEER] alpha = 0.9 | 0.673    |
# | [PEER] alpha = 1.0 | 0.719    |
# ---------------------------------
# {'alpha': 1.0}

# %%
from runner import run
args = default_args.copy()
args.update({
    'e0': 0.4, 'e1': 0.4, 
    'equalize_prior': True, 
    'episodes': 1000, 
    'batchsize': 64, 
    'hidsize': [64, 64], 
    'lr': 0.001, 
})
run(args)
# Out:
# Logging to logs/nn/19-08-28-20-23-30
# {'dataset': 'diabetes', 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'e0': 0.4, 'e1': 0.4, 'equalize_prior': True, 'episodes': 1000, 'batchsize': 64, 'hidsize': [64, 64], 'lr': 0.001}
# ---------------------------------
# | [PEER] alpha = 0.1 | 0.532    |
# | [PEER] alpha = 0.2 | 0.542    |
# | [PEER] alpha = 0.3 | 0.544    |
# | [PEER] alpha = 0.4 | 0.544    |
# | [PEER] alpha = 0.5 | 0.535    |
# | [PEER] alpha = 0.6 | 0.546    |
# | [PEER] alpha = 0.7 | 0.565    |
# | [PEER] alpha = 0.8 | 0.535    |
# | [PEER] alpha = 0.9 | 0.558    |
# | [PEER] alpha = 1.0 | 0.562    |
# ---------------------------------
# --------------------------------------
# | [NN] with bce loss      | 0.551    |
# | [NN] with peer loss     | 0.63     |
# | [NN] with surrogate ... | 0.645    |
# | [PEER] best alpha       | 0.7      |
# --------------------------------------
# Logging to logs/svm/19-08-28-20-24-37
# {'dataset': 'diabetes', 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'e0': 0.4, 'e1': 0.4, 'equalize_prior': True, 'episodes': 1000, 'batchsize': 64, 'hidsize': [64, 64], 'lr': 0.001}
# --------------------------------
# | [C-SVM] C1 = 0.1  | 0.505    |
# | [C-SVM] C1 = 0.2  | 0.505    |
# | [C-SVM] C1 = 0.25 | 0.505    |
# | [C-SVM] C1 = 0.33 | 0.507    |
# | [C-SVM] C1 = 0.5  | 0.514    |
# | [C-SVM] C1 = 1.0  | 0.56     |
# | [C-SVM] C1 = 10.0 | 0.491    |
# | [C-SVM] C1 = 2.0  | 0.495    |
# | [C-SVM] C1 = 3.0  | 0.495    |
# | [C-SVM] C1 = 4.0  | 0.493    |
# | [C-SVM] C1 = 5.0  | 0.491    |
# --------------------------------
# ------------------------------------
# | [C-SVM] accuracy max  | 0.765    |
# | [C-SVM] accuracy mean | 0.654    |
# | [C-SVM] accuracy min  | 0.58     |
# | [C-SVM] accuracy std  | 0.0566   |
# | [C-SVM] best C1       | 1        |
# ------------------------------------
# Logging to logs/pam/19-08-28-20-24-37
# {'dataset': 'diabetes', 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'e0': 0.4, 'e1': 0.4, 'equalize_prior': True, 'episodes': 1000, 'batchsize': 64, 'hidsize': [64, 64], 'lr': 0.001}
# -----------------------------------
# | [PAM] margin = 0     | 0.5      |
# | [PAM] margin = 0.125 | 0.576    |
# | [PAM] margin = 0.25  | 0.572    |
# | [PAM] margin = 0.5   | 0.565    |
# | [PAM] margin = 1     | 0.56     |
# -----------------------------------
# ----------------------------------
# | [PAM] accuracy max  | 0.802    |
# | [PAM] accuracy mean | 0.691    |
# | [PAM] accuracy min  | 0.63     |
# | [PAM] accuracy std  | 0.0486   |
# | [PAM] best margin   | 0.125    |
# ----------------------------------

# %% [markdown]
# ## Without Prior Equalization

# %% [markdown]
# ### $e_0 = 0.1, e_1 = 0.3$

# %%
from run_nn import find_best_alpha
args = default_args.copy()
args.update({
    'e0': 0.1, 'e1': 0.3, 
    'equalize_prior': False, 
    'episodes': 1000, 
    'batchsize': 64, 
    'hidsize': [64, 64], 
    'lr': 0.001, 
})
find_best_alpha(args)
# Out:
# ---------------------------------
# | [PEER] alpha = 0.1 | 0.739    |
# | [PEER] alpha = 0.2 | 0.74     |
# | [PEER] alpha = 0.3 | 0.742    |
# | [PEER] alpha = 0.4 | 0.758    |
# | [PEER] alpha = 0.5 | 0.761    |
# | [PEER] alpha = 0.6 | 0.784    |
# | [PEER] alpha = 0.7 | 0.778    |
# | [PEER] alpha = 0.8 | 0.767    |
# | [PEER] alpha = 0.9 | 0.75     |
# | [PEER] alpha = 1.0 | 0.728    |
# ---------------------------------
# {'alpha': 0.6}

# %%
from runner import run
args = default_args.copy()
args.update({
    'e0': 0.1, 'e1': 0.3, 
    'equalize_prior': False, 
    'episodes': 1000, 
    'batchsize': 64, 
    'hidsize': [64, 64], 
    'lr': 0.001, 
})
run(args)
# Out:
# Logging to logs/nn/19-08-28-20-25-37
# {'dataset': 'diabetes', 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'e0': 0.1, 'e1': 0.3, 'equalize_prior': False, 'episodes': 1000, 'batchsize': 64, 'hidsize': [64, 64], 'lr': 0.001}
# ---------------------------------
# | [PEER] alpha = 0.1 | 0.667    |
# | [PEER] alpha = 0.2 | 0.674    |
# | [PEER] alpha = 0.3 | 0.662    |
# | [PEER] alpha = 0.4 | 0.649    |
# | [PEER] alpha = 0.5 | 0.664    |
# | [PEER] alpha = 0.6 | 0.68     |
# | [PEER] alpha = 0.7 | 0.703    |
# | [PEER] alpha = 0.8 | 0.688    |
# | [PEER] alpha = 0.9 | 0.657    |
# | [PEER] alpha = 1.0 | 0.609    |
# ---------------------------------
# --------------------------------------
# | [NN] with bce loss      | 0.727    |
# | [NN] with peer loss     | 0.778    |
# | [NN] with surrogate ... | 0.75     |
# | [PEER] best alpha       | 0.7      |
# --------------------------------------
# Logging to logs/svm/19-08-28-20-26-44
# {'dataset': 'diabetes', 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'e0': 0.1, 'e1': 0.3, 'equalize_prior': False, 'episodes': 1000, 'batchsize': 64, 'hidsize': [64, 64], 'lr': 0.001}
# --------------------------------
# | [C-SVM] C1 = 0.1  | 0.693    |
# | [C-SVM] C1 = 0.2  | 0.693    |
# | [C-SVM] C1 = 0.25 | 0.693    |
# | [C-SVM] C1 = 0.33 | 0.693    |
# | [C-SVM] C1 = 0.5  | 0.695    |
# | [C-SVM] C1 = 1.0  | 0.705    |
# | [C-SVM] C1 = 10.0 | 0.372    |
# | [C-SVM] C1 = 2.0  | 0.67     |
# | [C-SVM] C1 = 3.0  | 0.578    |
# | [C-SVM] C1 = 4.0  | 0.521    |
# | [C-SVM] C1 = 5.0  | 0.482    |
# --------------------------------
# ------------------------------------
# | [C-SVM] accuracy max  | 0.767    |
# | [C-SVM] accuracy mean | 0.726    |
# | [C-SVM] accuracy min  | 0.69     |
# | [C-SVM] accuracy std  | 0.0243   |
# | [C-SVM] best C1       | 1        |
# ------------------------------------
# Logging to logs/pam/19-08-28-20-26-45
# {'dataset': 'diabetes', 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'e0': 0.1, 'e1': 0.3, 'equalize_prior': False, 'episodes': 1000, 'batchsize': 64, 'hidsize': [64, 64], 'lr': 0.001}
# -----------------------------------
# | [PAM] margin = 0     | 0.614    |
# | [PAM] margin = 0.125 | 0.713    |
# | [PAM] margin = 0.25  | 0.705    |
# | [PAM] margin = 0.5   | 0.703    |
# | [PAM] margin = 1     | 0.706    |
# -----------------------------------
# ----------------------------------
# | [PAM] accuracy max  | 0.776    |
# | [PAM] accuracy mean | 0.697    |
# | [PAM] accuracy min  | 0.621    |
# | [PAM] accuracy std  | 0.0582   |
# | [PAM] best margin   | 0.125    |
# ----------------------------------

# %% [markdown]
# ### $e_0 = 0.2, e_1 = 0.2$

# %%
from run_nn import find_best_alpha
args = default_args.copy()
args.update({
    'e0': 0.2, 'e1': 0.2, 
    'equalize_prior': False, 
    'episodes': 1000, 
    'batchsize': 64, 
    'hidsize': [64, 64], 
    'lr': 0.001, 
})
find_best_alpha(args)
# Out:
# ---------------------------------
# | [PEER] alpha = 0.1 | 0.723    |
# | [PEER] alpha = 0.2 | 0.737    |
# | [PEER] alpha = 0.3 | 0.734    |
# | [PEER] alpha = 0.4 | 0.742    |
# | [PEER] alpha = 0.5 | 0.731    |
# | [PEER] alpha = 0.6 | 0.75     |
# | [PEER] alpha = 0.7 | 0.759    |
# | [PEER] alpha = 0.8 | 0.752    |
# | [PEER] alpha = 0.9 | 0.737    |
# | [PEER] alpha = 1.0 | 0.723    |
# ---------------------------------
# {'alpha': 0.7}

# %%
from runner import run
args = default_args.copy()
args.update({
    'e0': 0.2, 'e1': 0.2, 
    'equalize_prior': False, 
    'episodes': 1000, 
    'batchsize': 64, 
    'hidsize': [64, 64], 
    'lr': 0.001, 
})
run(args)
# Out:
# Logging to logs/nn/19-08-28-20-27-49
# {'dataset': 'diabetes', 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'e0': 0.2, 'e1': 0.2, 'equalize_prior': False, 'episodes': 1000, 'batchsize': 64, 'hidsize': [64, 64], 'lr': 0.001}
# ---------------------------------
# | [PEER] alpha = 0.1 | 0.625    |
# | [PEER] alpha = 0.2 | 0.615    |
# | [PEER] alpha = 0.3 | 0.607    |
# | [PEER] alpha = 0.4 | 0.617    |
# | [PEER] alpha = 0.5 | 0.635    |
# | [PEER] alpha = 0.6 | 0.657    |
# | [PEER] alpha = 0.7 | 0.659    |
# | [PEER] alpha = 0.8 | 0.636    |
# | [PEER] alpha = 0.9 | 0.617    |
# | [PEER] alpha = 1.0 | 0.607    |
# ---------------------------------
# --------------------------------------
# | [NN] with bce loss      | 0.706    |
# | [NN] with peer loss     | 0.759    |
# | [NN] with surrogate ... | 0.736    |
# | [PEER] best alpha       | 0.7      |
# --------------------------------------
# Logging to logs/svm/19-08-28-20-28-48
# {'dataset': 'diabetes', 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'e0': 0.2, 'e1': 0.2, 'equalize_prior': False, 'episodes': 1000, 'batchsize': 64, 'hidsize': [64, 64], 'lr': 0.001}
# --------------------------------
# | [C-SVM] C1 = 0.1  | 0.594    |
# | [C-SVM] C1 = 0.2  | 0.594    |
# | [C-SVM] C1 = 0.25 | 0.594    |
# | [C-SVM] C1 = 0.33 | 0.594    |
# | [C-SVM] C1 = 0.5  | 0.599    |
# | [C-SVM] C1 = 1.0  | 0.627    |
# | [C-SVM] C1 = 10.0 | 0.411    |
# | [C-SVM] C1 = 2.0  | 0.614    |
# | [C-SVM] C1 = 3.0  | 0.508    |
# | [C-SVM] C1 = 4.0  | 0.438    |
# | [C-SVM] C1 = 5.0  | 0.412    |
# --------------------------------
# ------------------------------------
# | [C-SVM] accuracy max  | 0.793    |
# | [C-SVM] accuracy mean | 0.759    |
# | [C-SVM] accuracy min  | 0.724    |
# | [C-SVM] accuracy std  | 0.0248   |
# | [C-SVM] best C1       | 1        |
# ------------------------------------
# Logging to logs/pam/19-08-28-20-28-49
# {'dataset': 'diabetes', 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'e0': 0.2, 'e1': 0.2, 'equalize_prior': False, 'episodes': 1000, 'batchsize': 64, 'hidsize': [64, 64], 'lr': 0.001}
# -----------------------------------
# | [PAM] margin = 0     | 0.589    |
# | [PAM] margin = 0.125 | 0.646    |
# | [PAM] margin = 0.25  | 0.654    |
# | [PAM] margin = 0.5   | 0.661    |
# | [PAM] margin = 1     | 0.659    |
# -----------------------------------
# ----------------------------------
# | [PAM] accuracy max  | 0.819    |
# | [PAM] accuracy mean | 0.782    |
# | [PAM] accuracy min  | 0.733    |
# | [PAM] accuracy std  | 0.031    |
# | [PAM] best margin   | 0.5      |
# ----------------------------------

# %% [markdown]
# ### $e_0 = 0.1, e_1 = 0.4$

# %%
from run_nn import find_best_alpha
args = default_args.copy()
args.update({
    'e0': 0.1, 'e1': 0.4, 
    'equalize_prior': False, 
    'episodes': 1000, 
    'batchsize': 64, 
    'hidsize': [64, 64], 
    'lr': 0.001, 
})
find_best_alpha(args)
# Out:
# ---------------------------------
# | [PEER] alpha = 0.1 | 0.722    |
# | [PEER] alpha = 0.2 | 0.717    |
# | [PEER] alpha = 0.3 | 0.725    |
# | [PEER] alpha = 0.4 | 0.732    |
# | [PEER] alpha = 0.5 | 0.749    |
# | [PEER] alpha = 0.6 | 0.759    |
# | [PEER] alpha = 0.7 | 0.777    |
# | [PEER] alpha = 0.8 | 0.77     |
# | [PEER] alpha = 0.9 | 0.755    |
# | [PEER] alpha = 1.0 | 0.722    |
# ---------------------------------
# {'alpha': 0.7}

# %% [markdown]
# Search alpha from at least 0.4, then the best will become 0.7

# %%
from runner import run
args = default_args.copy()
args.update({
    'e0': 0.1, 'e1': 0.4, 
    'equalize_prior': False, 
    'episodes': 1000, 
    'batchsize': 64, 
    'hidsize': [64, 64], 
    'lr': 0.001, 
})
run(args)
# Out:
# Logging to logs/nn/19-08-28-20-29-49
# {'dataset': 'diabetes', 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'e0': 0.1, 'e1': 0.4, 'equalize_prior': False, 'episodes': 1000, 'batchsize': 64, 'hidsize': [64, 64], 'lr': 0.001}
# ---------------------------------
# | [PEER] alpha = 0.1 | 0.698    |
# | [PEER] alpha = 0.2 | 0.69     |
# | [PEER] alpha = 0.3 | 0.7      |
# | [PEER] alpha = 0.4 | 0.685    |
# | [PEER] alpha = 0.5 | 0.67     |
# | [PEER] alpha = 0.6 | 0.685    |
# | [PEER] alpha = 0.7 | 0.693    |
# | [PEER] alpha = 0.8 | 0.692    |
# | [PEER] alpha = 0.9 | 0.679    |
# | [PEER] alpha = 1.0 | 0.597    |
# ---------------------------------
# --------------------------------------
# | [NN] with bce loss      | 0.71     |
# | [NN] with peer loss     | 0.725    |
# | [NN] with surrogate ... | 0.724    |
# | [PEER] best alpha       | 0.3      |
# --------------------------------------
# Logging to logs/svm/19-08-28-20-30-52
# {'dataset': 'diabetes', 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'e0': 0.1, 'e1': 0.4, 'equalize_prior': False, 'episodes': 1000, 'batchsize': 64, 'hidsize': [64, 64], 'lr': 0.001}
# --------------------------------
# | [C-SVM] C1 = 0.1  | 0.729    |
# | [C-SVM] C1 = 0.2  | 0.729    |
# | [C-SVM] C1 = 0.25 | 0.729    |
# | [C-SVM] C1 = 0.33 | 0.729    |
# | [C-SVM] C1 = 0.5  | 0.729    |
# | [C-SVM] C1 = 1.0  | 0.731    |
# | [C-SVM] C1 = 10.0 | 0.359    |
# | [C-SVM] C1 = 2.0  | 0.693    |
# | [C-SVM] C1 = 3.0  | 0.612    |
# | [C-SVM] C1 = 4.0  | 0.539    |
# | [C-SVM] C1 = 5.0  | 0.485    |
# --------------------------------
# ------------------------------------
# | [C-SVM] accuracy max  | 0.741    |
# | [C-SVM] accuracy mean | 0.688    |
# | [C-SVM] accuracy min  | 0.638    |
# | [C-SVM] accuracy std  | 0.0347   |
# | [C-SVM] best C1       | 1        |
# ------------------------------------
# Logging to logs/pam/19-08-28-20-30-52
# {'dataset': 'diabetes', 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'e0': 0.1, 'e1': 0.4, 'equalize_prior': False, 'episodes': 1000, 'batchsize': 64, 'hidsize': [64, 64], 'lr': 0.001}
# -----------------------------------
# | [PAM] margin = 0     | 0.635    |
# | [PAM] margin = 0.125 | 0.729    |
# | [PAM] margin = 0.25  | 0.729    |
# | [PAM] margin = 0.5   | 0.729    |
# | [PAM] margin = 1     | 0.729    |
# -----------------------------------
# ----------------------------------
# | [PAM] accuracy max  | 0.707    |
# | [PAM] accuracy mean | 0.651    |
# | [PAM] accuracy min  | 0.595    |
# | [PAM] accuracy std  | 0.0355   |
# | [PAM] best margin   | 0.125    |
# ----------------------------------

# %% [markdown]
# ### $e_0 = 0.2, e_1 = 0.4$

# %%
from run_nn import find_best_alpha
args = default_args.copy()
args.update({
    'e0': 0.2, 'e1': 0.4, 
    'equalize_prior': False, 
    'episodes': 1000, 
    'batchsize': 64, 
    'hidsize': [64, 64], 
    'lr': 0.001, 
})
find_best_alpha(args)
# Out:
# ---------------------------------
# | [PEER] alpha = 0.1 | 0.681    |
# | [PEER] alpha = 0.2 | 0.679    |
# | [PEER] alpha = 0.3 | 0.673    |
# | [PEER] alpha = 0.4 | 0.671    |
# | [PEER] alpha = 0.5 | 0.694    |
# | [PEER] alpha = 0.6 | 0.713    |
# | [PEER] alpha = 0.7 | 0.728    |
# | [PEER] alpha = 0.8 | 0.739    |
# | [PEER] alpha = 0.9 | 0.739    |
# | [PEER] alpha = 1.0 | 0.699    |
# ---------------------------------
# {'alpha': 0.8}

# %% [markdown]
# Search from at least 0.2, them the best will become 0.8

# %%
from runner import run
args = default_args.copy()
args.update({
    'e0': 0.2, 'e1': 0.4, 
    'equalize_prior': False, 
    'episodes': 1000, 
    'batchsize': 64, 
    'hidsize': [64, 64], 
    'lr': 0.001, 
})
run(args)
# Out:
# Logging to logs/nn/19-08-28-20-31-58
# {'dataset': 'diabetes', 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'e0': 0.2, 'e1': 0.4, 'equalize_prior': False, 'episodes': 1000, 'batchsize': 64, 'hidsize': [64, 64], 'lr': 0.001}
# ---------------------------------
# | [PEER] alpha = 0.1 | 0.636    |
# | [PEER] alpha = 0.2 | 0.625    |
# | [PEER] alpha = 0.3 | 0.625    |
# | [PEER] alpha = 0.4 | 0.623    |
# | [PEER] alpha = 0.5 | 0.63     |
# | [PEER] alpha = 0.6 | 0.63     |
# | [PEER] alpha = 0.7 | 0.631    |
# | [PEER] alpha = 0.8 | 0.635    |
# | [PEER] alpha = 0.9 | 0.627    |
# | [PEER] alpha = 1.0 | 0.57     |
# ---------------------------------
# --------------------------------------
# | [NN] with bce loss      | 0.672    |
# | [NN] with peer loss     | 0.681    |
# | [NN] with surrogate ... | 0.705    |
# | [PEER] best alpha       | 0.1      |
# --------------------------------------
# Logging to logs/svm/19-08-28-20-33-14
# {'dataset': 'diabetes', 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'e0': 0.2, 'e1': 0.4, 'equalize_prior': False, 'episodes': 1000, 'batchsize': 64, 'hidsize': [64, 64], 'lr': 0.001}
# --------------------------------
# | [C-SVM] C1 = 0.1  | 0.662    |
# | [C-SVM] C1 = 0.2  | 0.662    |
# | [C-SVM] C1 = 0.25 | 0.662    |
# | [C-SVM] C1 = 0.33 | 0.662    |
# | [C-SVM] C1 = 0.5  | 0.662    |
# | [C-SVM] C1 = 1.0  | 0.664    |
# | [C-SVM] C1 = 10.0 | 0.357    |
# | [C-SVM] C1 = 2.0  | 0.602    |
# | [C-SVM] C1 = 3.0  | 0.492    |
# | [C-SVM] C1 = 4.0  | 0.42     |
# | [C-SVM] C1 = 5.0  | 0.373    |
# --------------------------------
# ------------------------------------
# | [C-SVM] accuracy max  | 0.767    |
# | [C-SVM] accuracy mean | 0.7      |
# | [C-SVM] accuracy min  | 0.647    |
# | [C-SVM] accuracy std  | 0.0424   |
# | [C-SVM] best C1       | 1        |
# ------------------------------------
# Logging to logs/pam/19-08-28-20-33-14
# {'dataset': 'diabetes', 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'e0': 0.2, 'e1': 0.4, 'equalize_prior': False, 'episodes': 1000, 'batchsize': 64, 'hidsize': [64, 64], 'lr': 0.001}
# -----------------------------------
# | [PAM] margin = 0     | 0.597    |
# | [PAM] margin = 0.125 | 0.662    |
# | [PAM] margin = 0.25  | 0.662    |
# | [PAM] margin = 0.5   | 0.662    |
# | [PAM] margin = 1     | 0.662    |
# -----------------------------------
# ----------------------------------
# | [PAM] accuracy max  | 0.707    |
# | [PAM] accuracy mean | 0.651    |
# | [PAM] accuracy min  | 0.595    |
# | [PAM] accuracy std  | 0.0355   |
# | [PAM] best margin   | 0.125    |
# ----------------------------------

# %% [markdown]
# ### $e_0 = 0.4, e_1 = 0.4$

# %%
from run_nn import find_best_alpha
args = default_args.copy()
args.update({
    'e0': 0.4, 'e1': 0.4, 
    'equalize_prior': False, 
    'episodes': 1000, 
    'batchsize': 64, 
    'hidsize': [64, 64], 
    'lr': 0.001, 
})
find_best_alpha(args)
# Out:
# ---------------------------------
# | [PEER] alpha = 0.1 | 0.581    |
# | [PEER] alpha = 0.2 | 0.58     |
# | [PEER] alpha = 0.3 | 0.593    |
# | [PEER] alpha = 0.4 | 0.598    |
# | [PEER] alpha = 0.5 | 0.612    |
# | [PEER] alpha = 0.6 | 0.61     |
# | [PEER] alpha = 0.7 | 0.601    |
# | [PEER] alpha = 0.8 | 0.623    |
# | [PEER] alpha = 0.9 | 0.651    |
# | [PEER] alpha = 1.0 | 0.62     |
# ---------------------------------
# {'alpha': 0.9}

# %%
from runner import run
args = default_args.copy()
args.update({
    'e0': 0.4, 'e1': 0.4, 
    'equalize_prior': False, 
    'episodes': 1000, 
    'batchsize': 64, 
    'hidsize': [64, 64], 
    'lr': 0.001, 
})
run(args)
# Out:
# Logging to logs/nn/19-08-28-20-34-17
# {'dataset': 'diabetes', 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'e0': 0.4, 'e1': 0.4, 'equalize_prior': False, 'episodes': 1000, 'batchsize': 64, 'hidsize': [64, 64], 'lr': 0.001}
# ---------------------------------
# | [PEER] alpha = 0.1 | 0.532    |
# | [PEER] alpha = 0.2 | 0.536    |
# | [PEER] alpha = 0.3 | 0.528    |
# | [PEER] alpha = 0.4 | 0.534    |
# | [PEER] alpha = 0.5 | 0.531    |
# | [PEER] alpha = 0.6 | 0.534    |
# | [PEER] alpha = 0.7 | 0.542    |
# | [PEER] alpha = 0.8 | 0.542    |
# | [PEER] alpha = 0.9 | 0.56     |
# | [PEER] alpha = 1.0 | 0.528    |
# ---------------------------------
# --------------------------------------
# | [NN] with bce loss      | 0.583    |
# | [NN] with peer loss     | 0.651    |
# | [NN] with surrogate ... | 0.685    |
# | [PEER] best alpha       | 0.9      |
# --------------------------------------
# Logging to logs/svm/19-08-28-20-35-21
# {'dataset': 'diabetes', 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'e0': 0.4, 'e1': 0.4, 'equalize_prior': False, 'episodes': 1000, 'batchsize': 64, 'hidsize': [64, 64], 'lr': 0.001}
# --------------------------------
# | [C-SVM] C1 = 0.1  | 0.532    |
# | [C-SVM] C1 = 0.2  | 0.532    |
# | [C-SVM] C1 = 0.25 | 0.532    |
# | [C-SVM] C1 = 0.33 | 0.532    |
# | [C-SVM] C1 = 0.5  | 0.534    |
# | [C-SVM] C1 = 1.0  | 0.55     |
# | [C-SVM] C1 = 10.0 | 0.466    |
# | [C-SVM] C1 = 2.0  | 0.477    |
# | [C-SVM] C1 = 3.0  | 0.468    |
# | [C-SVM] C1 = 4.0  | 0.466    |
# | [C-SVM] C1 = 5.0  | 0.466    |
# --------------------------------
# ------------------------------------
# | [C-SVM] accuracy max  | 0.784    |
# | [C-SVM] accuracy mean | 0.702    |
# | [C-SVM] accuracy min  | 0.621    |
# | [C-SVM] accuracy std  | 0.0517   |
# | [C-SVM] best C1       | 1        |
# ------------------------------------
# Logging to logs/pam/19-08-28-20-35-21
# {'dataset': 'diabetes', 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'e0': 0.4, 'e1': 0.4, 'equalize_prior': False, 'episodes': 1000, 'batchsize': 64, 'hidsize': [64, 64], 'lr': 0.001}
# -----------------------------------
# | [PAM] margin = 0     | 0.516    |
# | [PAM] margin = 0.125 | 0.541    |
# | [PAM] margin = 0.25  | 0.549    |
# | [PAM] margin = 0.5   | 0.537    |
# | [PAM] margin = 1     | 0.537    |
# -----------------------------------
# ----------------------------------
# | [PAM] accuracy max  | 0.802    |
# | [PAM] accuracy mean | 0.721    |
# | [PAM] accuracy min  | 0.655    |
# | [PAM] accuracy std  | 0.0495   |
# | [PAM] best margin   | 0.25     |
# ----------------------------------

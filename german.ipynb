# %% [markdown]
# # German (23,300,700)

# %% [markdown]
# ## Describe
#
# | Total | Positive | Attributes | Normalized |
# |:-----:|:--------:|:----------:|:----------:|
# | 1000  |    70%   |     23     |     Not    |

# %%
default_args = {
    'dataset': 'german',
    'test_size': 0.15,
    'val_size': 0.1,
    'dropout': 0, 
    'normalize': True,
    'loss': 'bce',
    'activation': 'relu',
    'verbose': True,
}

# %% [markdown]
# ## With Prior Equalization

# %% [markdown]
# ### $e_0 = 0.1, e_1 = 0.3$

# %% [markdown]
# Best can get:

# %%
from runner import run
args = default_args.copy()
args.update({
    'dataset': 'german', 
    'e0': 0.1, 'e1': 0.3, 
    'equalize_prior': True, 
    'episodes': 1500, 
    'batchsize': 32, 
    'hidsize': [16, 16], 
    'lr': 0.0007, 
    'alpha': 1.
})
run(args)
# Out:
# Logging to logs/nn/19-08-28-13-29-14
# {'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'dataset': 'german', 'e0': 0.1, 'e1': 0.3, 'equalize_prior': True, 'episodes': 1500, 'batchsize': 32, 'hidsize': [16, 16], 'lr': 0.0007, 'alpha': 1.0}
# --------------------------------------
# | [NN] with bce loss      | 0.581    |
# | [NN] with peer loss     | 0.701    |
# | [NN] with surrogate ... | 0.624    |
# --------------------------------------
# Logging to logs/svm/19-08-28-13-29-24
# {'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'dataset': 'german', 'e0': 0.1, 'e1': 0.3, 'equalize_prior': True, 'episodes': 1500, 'batchsize': 32, 'hidsize': [16, 16], 'lr': 0.0007, 'alpha': 1.0}
# --------------------------------
# | [C-SVM] C1 = 0.1  | 0.602    |
# | [C-SVM] C1 = 0.2  | 0.602    |
# | [C-SVM] C1 = 0.25 | 0.602    |
# | [C-SVM] C1 = 0.33 | 0.602    |
# | [C-SVM] C1 = 0.5  | 0.605    |
# | [C-SVM] C1 = 1.0  | 0.641    |
# | [C-SVM] C1 = 10.0 | 0.59     |
# | [C-SVM] C1 = 2.0  | 0.605    |
# | [C-SVM] C1 = 3.0  | 0.59     |
# | [C-SVM] C1 = 4.0  | 0.594    |
# | [C-SVM] C1 = 5.0  | 0.59     |
# --------------------------------
# ------------------------------------
# | [C-SVM] accuracy max  | 0.678    |
# | [C-SVM] accuracy mean | 0.611    |
# | [C-SVM] accuracy min  | 0.544    |
# | [C-SVM] accuracy std  | 0.0487   |
# | [C-SVM] best C1       | 1        |
# ------------------------------------
# Logging to logs/pam/19-08-28-13-29-25
# {'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'dataset': 'german', 'e0': 0.1, 'e1': 0.3, 'equalize_prior': True, 'episodes': 1500, 'batchsize': 32, 'hidsize': [16, 16], 'lr': 0.0007, 'alpha': 1.0}
# -----------------------------------
# | [PAM] margin = 0     | 0.553    |
# | [PAM] margin = 0.125 | 0.607    |
# | [PAM] margin = 0.25  | 0.605    |
# | [PAM] margin = 0.5   | 0.619    |
# | [PAM] margin = 1     | 0.615    |
# -----------------------------------
# ----------------------------------
# | [PAM] accuracy max  | 0.689    |
# | [PAM] accuracy mean | 0.626    |
# | [PAM] accuracy min  | 0.578    |
# | [PAM] accuracy std  | 0.0347   |
# | [PAM] best margin   | 0.5      |
# ----------------------------------

# %% [markdown]
# ### $e_0 = 0.2, e_1 = 0.2$

# %% [markdown]
# Best can get

# %%
from runner import run
args = default_args.copy()
args.update({
    'dataset': 'german', 
    'e0': 0.2, 'e1': 0.2, 
    'equalize_prior': True, 
    'episodes': 2000, 
    'batchsize': 32, 
    'hidsize': [64, 64], 
    'lr': 0.0007, 
    'alpha': 1.
})
run(args)
# Out:
# Logging to logs/nn/19-08-28-13-07-42
# {'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'dataset': 'german', 'e0': 0.2, 'e1': 0.2, 'equalize_prior': True, 'episodes': 2000, 'batchsize': 32, 'hidsize': [64, 64], 'lr': 0.0007, 'alpha': 1.0}
# --------------------------------------
# | [NN] with bce loss      | 0.611    |
# | [NN] with peer loss     | 0.689    |
# | [NN] with surrogate ... | 0.65     |
# --------------------------------------
# Logging to logs/svm/19-08-28-13-08-10
# {'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'dataset': 'german', 'e0': 0.2, 'e1': 0.2, 'equalize_prior': True, 'episodes': 2000, 'batchsize': 32, 'hidsize': [64, 64], 'lr': 0.0007, 'alpha': 1.0}
# --------------------------------
# | [C-SVM] C1 = 0.1  | 0.502    |
# | [C-SVM] C1 = 0.2  | 0.502    |
# | [C-SVM] C1 = 0.25 | 0.502    |
# | [C-SVM] C1 = 0.33 | 0.502    |
# | [C-SVM] C1 = 0.5  | 0.553    |
# | [C-SVM] C1 = 1.0  | 0.594    |
# | [C-SVM] C1 = 10.0 | 0.553    |
# | [C-SVM] C1 = 2.0  | 0.588    |
# | [C-SVM] C1 = 3.0  | 0.566    |
# | [C-SVM] C1 = 4.0  | 0.559    |
# | [C-SVM] C1 = 5.0  | 0.553    |
# --------------------------------
# ------------------------------------
# | [C-SVM] accuracy max  | 0.711    |
# | [C-SVM] accuracy mean | 0.664    |
# | [C-SVM] accuracy min  | 0.6      |
# | [C-SVM] accuracy std  | 0.0363   |
# | [C-SVM] best C1       | 1        |
# ------------------------------------
# Logging to logs/pam/19-08-28-13-08-10
# {'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'dataset': 'german', 'e0': 0.2, 'e1': 0.2, 'equalize_prior': True, 'episodes': 2000, 'batchsize': 32, 'hidsize': [64, 64], 'lr': 0.0007, 'alpha': 1.0}
# -----------------------------------
# | [PAM] margin = 0     | 0.529    |
# | [PAM] margin = 0.125 | 0.584    |
# | [PAM] margin = 0.25  | 0.578    |
# | [PAM] margin = 0.5   | 0.59     |
# | [PAM] margin = 1     | 0.58     |
# -----------------------------------
# ----------------------------------
# | [PAM] accuracy max  | 0.7      |
# | [PAM] accuracy mean | 0.649    |
# | [PAM] accuracy min  | 0.589    |
# | [PAM] accuracy std  | 0.0314   |
# | [PAM] best margin   | 0.5      |
# ----------------------------------

# %% [markdown]
# ### $e_0 = 0.2, e_1 = 0.4$

# %%
from runner import run
args = default_args.copy()
args.update({
    'dataset': 'german', 
    'e0': 0.2, 'e1': 0.4, 
    'equalize_prior': True, 
    'episodes': 1000, 
#     'batchsize': 16, 
#     'hidsize': [32, 32], 
#     'lr': 0.005, 
    'alpha': 1.
})
run(args)
# Out:
# Logging to logs/nn/19-08-28-13-08-17
# {'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'dataset': 'german', 'e0': 0.2, 'e1': 0.4, 'equalize_prior': True, 'episodes': 1000, 'alpha': 1.0}
# acc:0.556	batchsize: 1	lr:0.0007	hidsize:[8, 8]
# acc:0.56	batchsize: 1	lr:0.0007	hidsize:[16, 16]
# acc:0.571	batchsize: 1	lr:0.0007	hidsize:[32, 32]
# acc:0.564	batchsize: 1	lr:0.0007	hidsize:[64, 64]
# acc:0.571	batchsize: 1	lr: 0.001	hidsize:[8, 8]
# acc:0.574	batchsize: 1	lr: 0.001	hidsize:[16, 16]
# acc:0.571	batchsize: 1	lr: 0.001	hidsize:[32, 32]
# acc:0.567	batchsize: 1	lr: 0.001	hidsize:[64, 64]
# acc:0.543	batchsize: 1	lr: 0.005	hidsize:[8, 8]
# acc:0.568	batchsize: 1	lr: 0.005	hidsize:[16, 16]
# acc:0.561	batchsize: 1	lr: 0.005	hidsize:[32, 32]
# acc:0.569	batchsize: 1	lr: 0.005	hidsize:[64, 64]
# acc:0.533	batchsize: 1	lr:  0.01	hidsize:[8, 8]
# acc:0.558	batchsize: 1	lr:  0.01	hidsize:[16, 16]
# acc:0.544	batchsize: 1	lr:  0.01	hidsize:[32, 32]
# acc:0.564	batchsize: 1	lr:  0.01	hidsize:[64, 64]
# acc:0.532	batchsize: 1	lr:  0.05	hidsize:[8, 8]
# acc:0.564	batchsize: 1	lr:  0.05	hidsize:[16, 16]
# acc:0.544	batchsize: 1	lr:  0.05	hidsize:[32, 32]
# acc:0.539	batchsize: 1	lr:  0.05	hidsize:[64, 64]
# acc:0.567	batchsize: 4	lr:0.0007	hidsize:[8, 8]
# acc:0.618	batchsize: 4	lr:0.0007	hidsize:[16, 16]
# acc:0.597	batchsize: 4	lr:0.0007	hidsize:[32, 32]
# acc:0.624	batchsize: 4	lr:0.0007	hidsize:[64, 64]
# acc:0.582	batchsize: 4	lr: 0.001	hidsize:[8, 8]
# acc:0.617	batchsize: 4	lr: 0.001	hidsize:[16, 16]
# acc:0.601	batchsize: 4	lr: 0.001	hidsize:[32, 32]
# acc:0.625	batchsize: 4	lr: 0.001	hidsize:[64, 64]
# acc:0.607	batchsize: 4	lr: 0.005	hidsize:[8, 8]
# acc:0.615	batchsize: 4	lr: 0.005	hidsize:[16, 16]
# acc:0.631	batchsize: 4	lr: 0.005	hidsize:[32, 32]
# acc:0.64	batchsize: 4	lr: 0.005	hidsize:[64, 64]
# acc:0.632	batchsize: 4	lr:  0.01	hidsize:[8, 8]
# acc:0.64	batchsize: 4	lr:  0.01	hidsize:[16, 16]
# acc:0.633	batchsize: 4	lr:  0.01	hidsize:[32, 32]
# acc:0.638	batchsize: 4	lr:  0.01	hidsize:[64, 64]
# acc: 0.6	batchsize: 4	lr:  0.05	hidsize:[8, 8]
# acc:0.657	batchsize: 4	lr:  0.05	hidsize:[16, 16]
# acc:0.603	batchsize: 4	lr:  0.05	hidsize:[32, 32]
# acc:0.651	batchsize: 4	lr:  0.05	hidsize:[64, 64]
# acc:0.604	batchsize:16	lr:0.0007	hidsize:[8, 8]
# acc:0.661	batchsize:16	lr:0.0007	hidsize:[16, 16]
# acc:0.643	batchsize:16	lr:0.0007	hidsize:[32, 32]
# acc:0.65	batchsize:16	lr:0.0007	hidsize:[64, 64]
# acc:0.612	batchsize:16	lr: 0.001	hidsize:[8, 8]
# acc:0.649	batchsize:16	lr: 0.001	hidsize:[16, 16]
# acc:0.647	batchsize:16	lr: 0.001	hidsize:[32, 32]
# acc:0.649	batchsize:16	lr: 0.001	hidsize:[64, 64]
# acc:0.644	batchsize:16	lr: 0.005	hidsize:[8, 8]
# acc:0.628	batchsize:16	lr: 0.005	hidsize:[16, 16]
# acc:0.657	batchsize:16	lr: 0.005	hidsize:[32, 32]
# acc:0.646	batchsize:16	lr: 0.005	hidsize:[64, 64]
# acc:0.635	batchsize:16	lr:  0.01	hidsize:[8, 8]
# acc:0.646	batchsize:16	lr:  0.01	hidsize:[16, 16]
# acc:0.654	batchsize:16	lr:  0.01	hidsize:[32, 32]
# acc:0.633	batchsize:16	lr:  0.01	hidsize:[64, 64]
# acc:0.588	batchsize:16	lr:  0.05	hidsize:[8, 8]
# acc:0.632	batchsize:16	lr:  0.05	hidsize:[16, 16]
# acc:0.638	batchsize:16	lr:  0.05	hidsize:[32, 32]
# acc:0.619	batchsize:16	lr:  0.05	hidsize:[64, 64]
# acc:0.596	batchsize:32	lr:0.0007	hidsize:[8, 8]
# acc:0.644	batchsize:32	lr:0.0007	hidsize:[16, 16]
# acc:0.649	batchsize:32	lr:0.0007	hidsize:[32, 32]
# acc:0.654	batchsize:32	lr:0.0007	hidsize:[64, 64]
# acc:0.619	batchsize:32	lr: 0.001	hidsize:[8, 8]
# acc:0.646	batchsize:32	lr: 0.001	hidsize:[16, 16]
# acc:0.649	batchsize:32	lr: 0.001	hidsize:[32, 32]
# acc:0.657	batchsize:32	lr: 0.001	hidsize:[64, 64]
# acc:0.635	batchsize:32	lr: 0.005	hidsize:[8, 8]
# acc:0.658	batchsize:32	lr: 0.005	hidsize:[16, 16]
# acc:0.66	batchsize:32	lr: 0.005	hidsize:[32, 32]
# acc:0.651	batchsize:32	lr: 0.005	hidsize:[64, 64]
# acc:0.642	batchsize:32	lr:  0.01	hidsize:[8, 8]
# acc:0.66	batchsize:32	lr:  0.01	hidsize:[16, 16]
# acc:0.65	batchsize:32	lr:  0.01	hidsize:[32, 32]
# acc:0.644	batchsize:32	lr:  0.01	hidsize:[64, 64]
# acc:0.606	batchsize:32	lr:  0.05	hidsize:[8, 8]
# acc:0.642	batchsize:32	lr:  0.05	hidsize:[16, 16]
# acc:0.649	batchsize:32	lr:  0.05	hidsize:[32, 32]
# acc:0.637	batchsize:32	lr:  0.05	hidsize:[64, 64]
# acc:0.608	batchsize:64	lr:0.0007	hidsize:[8, 8]
# acc:0.643	batchsize:64	lr:0.0007	hidsize:[16, 16]
# acc:0.657	batchsize:64	lr:0.0007	hidsize:[32, 32]
# acc:0.647	batchsize:64	lr:0.0007	hidsize:[64, 64]
# acc:0.625	batchsize:64	lr: 0.001	hidsize:[8, 8]
# acc:0.654	batchsize:64	lr: 0.001	hidsize:[16, 16]
# acc:0.657	batchsize:64	lr: 0.001	hidsize:[32, 32]
# acc:0.647	batchsize:64	lr: 0.001	hidsize:[64, 64]
# acc:0.647	batchsize:64	lr: 0.005	hidsize:[8, 8]
# acc:0.65	batchsize:64	lr: 0.005	hidsize:[16, 16]
# acc:0.65	batchsize:64	lr: 0.005	hidsize:[32, 32]
# acc:0.633	batchsize:64	lr: 0.005	hidsize:[64, 64]
# acc:0.631	batchsize:64	lr:  0.01	hidsize:[8, 8]
# acc:0.644	batchsize:64	lr:  0.01	hidsize:[16, 16]
# acc:0.664	batchsize:64	lr:  0.01	hidsize:[32, 32]
# acc:0.636	batchsize:64	lr:  0.01	hidsize:[64, 64]
# acc:0.594	batchsize:64	lr:  0.05	hidsize:[8, 8]
# acc:0.632	batchsize:64	lr:  0.05	hidsize:[16, 16]
# acc:0.647	batchsize:64	lr:  0.05	hidsize:[32, 32]
# acc:0.639	batchsize:64	lr:  0.05	hidsize:[64, 64]
# --------------------------------------
# | [PEER] best batchsize   | 64       |
# | [PEER] best hidsize     | [32, 32] |
# | [PEER] best learning... | 0.01     |
# --------------------------------------
# --------------------------------------
# | [NN] with bce loss      | 0.572    |
# | [NN] with peer loss     | 0.664    |
# | [NN] with surrogate ... | 0.59     |
# --------------------------------------
# Logging to logs/svm/19-08-28-13-14-12
# {'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'dataset': 'german', 'e0': 0.2, 'e1': 0.4, 'equalize_prior': True, 'episodes': 1000, 'alpha': 1.0}
# --------------------------------
# | [C-SVM] C1 = 0.1  | 0.602    |
# | [C-SVM] C1 = 0.2  | 0.602    |
# | [C-SVM] C1 = 0.25 | 0.602    |
# | [C-SVM] C1 = 0.33 | 0.602    |
# | [C-SVM] C1 = 0.5  | 0.602    |
# | [C-SVM] C1 = 1.0  | 0.598    |
# | [C-SVM] C1 = 10.0 | 0.523    |
# | [C-SVM] C1 = 2.0  | 0.559    |
# | [C-SVM] C1 = 3.0  | 0.531    |
# | [C-SVM] C1 = 4.0  | 0.527    |
# | [C-SVM] C1 = 5.0  | 0.525    |
# --------------------------------
# ------------------------------------
# | [C-SVM] accuracy max  | 0.511    |
# | [C-SVM] accuracy mean | 0.469    |
# | [C-SVM] accuracy min  | 0.411    |
# | [C-SVM] accuracy std  | 0.0355   |
# | [C-SVM] best C1       | 0.1      |
# ------------------------------------
# Logging to logs/pam/19-08-28-13-14-13
# {'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'dataset': 'german', 'e0': 0.2, 'e1': 0.4, 'equalize_prior': True, 'episodes': 1000, 'alpha': 1.0}
# -----------------------------------
# | [PAM] margin = 0     | 0.539    |
# | [PAM] margin = 0.125 | 0.568    |
# | [PAM] margin = 0.25  | 0.6      |
# | [PAM] margin = 0.5   | 0.588    |
# | [PAM] margin = 1     | 0.592    |
# -----------------------------------
# ----------------------------------
# | [PAM] accuracy max  | 0.678    |
# | [PAM] accuracy mean | 0.583    |
# | [PAM] accuracy min  | 0.5      |
# | [PAM] accuracy std  | 0.0527   |
# | [PAM] best margin   | 0.25     |
# ----------------------------------

# %% [markdown]
# ### $e_0 = 0.1, e_1 = 0.4$

# %%
from runner import run
args = default_args.copy()
args.update({
    'dataset': 'german', 
    'e0': 0.1, 'e1': 0.4, 
    'equalize_prior': True, 
    'episodes': 1000, 
#     'batchsize': 16, 
#     'hidsize': [32, 32], 
#     'lr': 0.005, 
    'alpha': 1.
})
run(args)
# Out:
# Logging to logs/nn/19-08-28-13-14-19
# {'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'dataset': 'german', 'e0': 0.1, 'e1': 0.4, 'equalize_prior': True, 'episodes': 1000, 'alpha': 1.0}
# acc:0.576	batchsize: 1	lr:0.0007	hidsize:[8, 8]
# acc:0.592	batchsize: 1	lr:0.0007	hidsize:[16, 16]
# acc:0.583	batchsize: 1	lr:0.0007	hidsize:[32, 32]
# acc:0.583	batchsize: 1	lr:0.0007	hidsize:[64, 64]
# acc:0.578	batchsize: 1	lr: 0.001	hidsize:[8, 8]
# acc:0.603	batchsize: 1	lr: 0.001	hidsize:[16, 16]
# acc:0.587	batchsize: 1	lr: 0.001	hidsize:[32, 32]
# acc:0.608	batchsize: 1	lr: 0.001	hidsize:[64, 64]
# acc:0.551	batchsize: 1	lr: 0.005	hidsize:[8, 8]
# acc:0.585	batchsize: 1	lr: 0.005	hidsize:[16, 16]
# acc:0.579	batchsize: 1	lr: 0.005	hidsize:[32, 32]
# acc:0.586	batchsize: 1	lr: 0.005	hidsize:[64, 64]
# acc:0.561	batchsize: 1	lr:  0.01	hidsize:[8, 8]
# acc:0.583	batchsize: 1	lr:  0.01	hidsize:[16, 16]
# acc:0.59	batchsize: 1	lr:  0.01	hidsize:[32, 32]
# acc:0.572	batchsize: 1	lr:  0.01	hidsize:[64, 64]
# acc:0.569	batchsize: 1	lr:  0.05	hidsize:[8, 8]
# acc:0.569	batchsize: 1	lr:  0.05	hidsize:[16, 16]
# acc:0.537	batchsize: 1	lr:  0.05	hidsize:[32, 32]
# acc:0.561	batchsize: 1	lr:  0.05	hidsize:[64, 64]
# acc:0.589	batchsize: 4	lr:0.0007	hidsize:[8, 8]
# acc:0.643	batchsize: 4	lr:0.0007	hidsize:[16, 16]
# acc:0.649	batchsize: 4	lr:0.0007	hidsize:[32, 32]
# acc:0.65	batchsize: 4	lr:0.0007	hidsize:[64, 64]
# acc:0.593	batchsize: 4	lr: 0.001	hidsize:[8, 8]
# acc:0.643	batchsize: 4	lr: 0.001	hidsize:[16, 16]
# acc:0.643	batchsize: 4	lr: 0.001	hidsize:[32, 32]
# acc:0.65	batchsize: 4	lr: 0.001	hidsize:[64, 64]
# acc:0.625	batchsize: 4	lr: 0.005	hidsize:[8, 8]
# acc:0.653	batchsize: 4	lr: 0.005	hidsize:[16, 16]
# acc:0.657	batchsize: 4	lr: 0.005	hidsize:[32, 32]
# acc:0.664	batchsize: 4	lr: 0.005	hidsize:[64, 64]
# acc:0.632	batchsize: 4	lr:  0.01	hidsize:[8, 8]
# acc:0.658	batchsize: 4	lr:  0.01	hidsize:[16, 16]
# acc:0.651	batchsize: 4	lr:  0.01	hidsize:[32, 32]
# acc:0.649	batchsize: 4	lr:  0.01	hidsize:[64, 64]
# acc:0.56	batchsize: 4	lr:  0.05	hidsize:[8, 8]
# acc:0.635	batchsize: 4	lr:  0.05	hidsize:[16, 16]
# acc:0.638	batchsize: 4	lr:  0.05	hidsize:[32, 32]
# acc:0.64	batchsize: 4	lr:  0.05	hidsize:[64, 64]
# acc:0.612	batchsize:16	lr:0.0007	hidsize:[8, 8]
# acc:0.689	batchsize:16	lr:0.0007	hidsize:[16, 16]
# acc:0.674	batchsize:16	lr:0.0007	hidsize:[32, 32]
# acc:0.676	batchsize:16	lr:0.0007	hidsize:[64, 64]
# acc:0.643	batchsize:16	lr: 0.001	hidsize:[8, 8]
# acc:0.667	batchsize:16	lr: 0.001	hidsize:[16, 16]
# acc:0.674	batchsize:16	lr: 0.001	hidsize:[32, 32]
# acc:0.681	batchsize:16	lr: 0.001	hidsize:[64, 64]
# acc:0.66	batchsize:16	lr: 0.005	hidsize:[8, 8]
# acc:0.668	batchsize:16	lr: 0.005	hidsize:[16, 16]
# acc:0.675	batchsize:16	lr: 0.005	hidsize:[32, 32]
# acc:0.681	batchsize:16	lr: 0.005	hidsize:[64, 64]
# acc:0.657	batchsize:16	lr:  0.01	hidsize:[8, 8]
# acc:0.66	batchsize:16	lr:  0.01	hidsize:[16, 16]
# acc:0.683	batchsize:16	lr:  0.01	hidsize:[32, 32]
# acc:0.662	batchsize:16	lr:  0.01	hidsize:[64, 64]
# acc:0.647	batchsize:16	lr:  0.05	hidsize:[8, 8]
# acc:0.651	batchsize:16	lr:  0.05	hidsize:[16, 16]
# acc:0.672	batchsize:16	lr:  0.05	hidsize:[32, 32]
# acc:0.646	batchsize:16	lr:  0.05	hidsize:[64, 64]
# acc:0.624	batchsize:32	lr:0.0007	hidsize:[8, 8]
# acc:0.672	batchsize:32	lr:0.0007	hidsize:[16, 16]
# acc:0.683	batchsize:32	lr:0.0007	hidsize:[32, 32]
# acc:0.678	batchsize:32	lr:0.0007	hidsize:[64, 64]
# acc:0.635	batchsize:32	lr: 0.001	hidsize:[8, 8]
# acc:0.674	batchsize:32	lr: 0.001	hidsize:[16, 16]
# acc:0.696	batchsize:32	lr: 0.001	hidsize:[32, 32]
# acc:0.679	batchsize:32	lr: 0.001	hidsize:[64, 64]
# acc:0.664	batchsize:32	lr: 0.005	hidsize:[8, 8]
# acc:0.674	batchsize:32	lr: 0.005	hidsize:[16, 16]
# acc:0.689	batchsize:32	lr: 0.005	hidsize:[32, 32]
# acc:0.669	batchsize:32	lr: 0.005	hidsize:[64, 64]
# acc:0.676	batchsize:32	lr:  0.01	hidsize:[8, 8]
# acc:0.678	batchsize:32	lr:  0.01	hidsize:[16, 16]
# acc:0.689	batchsize:32	lr:  0.01	hidsize:[32, 32]
# acc:0.678	batchsize:32	lr:  0.01	hidsize:[64, 64]
# acc:0.642	batchsize:32	lr:  0.05	hidsize:[8, 8]
# acc:0.66	batchsize:32	lr:  0.05	hidsize:[16, 16]
# acc:0.676	batchsize:32	lr:  0.05	hidsize:[32, 32]
# acc:0.665	batchsize:32	lr:  0.05	hidsize:[64, 64]
# acc:0.631	batchsize:64	lr:0.0007	hidsize:[8, 8]
# acc:0.672	batchsize:64	lr:0.0007	hidsize:[16, 16]
# acc:0.682	batchsize:64	lr:0.0007	hidsize:[32, 32]
# acc:0.679	batchsize:64	lr:0.0007	hidsize:[64, 64]
# acc:0.636	batchsize:64	lr: 0.001	hidsize:[8, 8]
# acc:0.671	batchsize:64	lr: 0.001	hidsize:[16, 16]
# acc:0.681	batchsize:64	lr: 0.001	hidsize:[32, 32]
# acc:0.679	batchsize:64	lr: 0.001	hidsize:[64, 64]
# acc:0.661	batchsize:64	lr: 0.005	hidsize:[8, 8]
# acc:0.657	batchsize:64	lr: 0.005	hidsize:[16, 16]
# acc:0.689	batchsize:64	lr: 0.005	hidsize:[32, 32]
# acc:0.664	batchsize:64	lr: 0.005	hidsize:[64, 64]
# acc:0.653	batchsize:64	lr:  0.01	hidsize:[8, 8]
# acc:0.654	batchsize:64	lr:  0.01	hidsize:[16, 16]
# acc:0.678	batchsize:64	lr:  0.01	hidsize:[32, 32]
# acc:0.664	batchsize:64	lr:  0.01	hidsize:[64, 64]
# acc:0.625	batchsize:64	lr:  0.05	hidsize:[8, 8]
# acc:0.653	batchsize:64	lr:  0.05	hidsize:[16, 16]
# acc:0.653	batchsize:64	lr:  0.05	hidsize:[32, 32]
# acc:0.643	batchsize:64	lr:  0.05	hidsize:[64, 64]
# --------------------------------------
# | [PEER] best batchsize   | 32       |
# | [PEER] best hidsize     | [32, 32] |
# | [PEER] best learning... | 0.001    |
# --------------------------------------
# --------------------------------------
# | [NN] with bce loss      | 0.562    |
# | [NN] with peer loss     | 0.696    |
# | [NN] with surrogate ... | 0.642    |
# --------------------------------------
# Logging to logs/svm/19-08-28-13-20-19
# {'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'dataset': 'german', 'e0': 0.1, 'e1': 0.4, 'equalize_prior': True, 'episodes': 1000, 'alpha': 1.0}
# --------------------------------
# | [C-SVM] C1 = 0.1  | 0.652    |
# | [C-SVM] C1 = 0.2  | 0.652    |
# | [C-SVM] C1 = 0.25 | 0.652    |
# | [C-SVM] C1 = 0.33 | 0.652    |
# | [C-SVM] C1 = 0.5  | 0.652    |
# | [C-SVM] C1 = 1.0  | 0.662    |
# | [C-SVM] C1 = 10.0 | 0.57     |
# | [C-SVM] C1 = 2.0  | 0.602    |
# | [C-SVM] C1 = 3.0  | 0.588    |
# | [C-SVM] C1 = 4.0  | 0.57     |
# | [C-SVM] C1 = 5.0  | 0.57     |
# --------------------------------
# ------------------------------------
# | [C-SVM] accuracy max  | 0.589    |
# | [C-SVM] accuracy mean | 0.55     |
# | [C-SVM] accuracy min  | 0.478    |
# | [C-SVM] accuracy std  | 0.0342   |
# | [C-SVM] best C1       | 1        |
# ------------------------------------
# Logging to logs/pam/19-08-28-13-20-19
# {'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'dataset': 'german', 'e0': 0.1, 'e1': 0.4, 'equalize_prior': True, 'episodes': 1000, 'alpha': 1.0}
# -----------------------------------
# | [PAM] margin = 0     | 0.588    |
# | [PAM] margin = 0.125 | 0.615    |
# | [PAM] margin = 0.25  | 0.635    |
# | [PAM] margin = 0.5   | 0.631    |
# | [PAM] margin = 1     | 0.643    |
# -----------------------------------
# ----------------------------------
# | [PAM] accuracy max  | 0.644    |
# | [PAM] accuracy mean | 0.586    |
# | [PAM] accuracy min  | 0.511    |
# | [PAM] accuracy std  | 0.0419   |
# | [PAM] best margin   | 1        |
# ----------------------------------

# %% [markdown]
# ### $e_0=0.4, e_1=0.4$

# %%
from runner import run
args = default_args.copy()
args.update({
    'dataset': 'german', 
    'e0': 0.4, 'e1': 0.4, 
    'equalize_prior': True, 
    'episodes': 1500, 
#     'batchsize': 16, 
#     'hidsize': [32, 32], 
#     'lr': 0.005, 
    'alpha': 1.
})
run(args)
# Out:
# Logging to logs/nn/19-08-28-13-20-26
# {'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'dataset': 'german', 'e0': 0.4, 'e1': 0.4, 'equalize_prior': True, 'episodes': 1500, 'alpha': 1.0}
# acc:0.533	batchsize: 1	lr:0.0007	hidsize:[8, 8]
# acc:0.532	batchsize: 1	lr:0.0007	hidsize:[16, 16]
# acc:0.518	batchsize: 1	lr:0.0007	hidsize:[32, 32]
# acc:0.528	batchsize: 1	lr:0.0007	hidsize:[64, 64]
# acc:0.515	batchsize: 1	lr: 0.001	hidsize:[8, 8]
# acc:0.528	batchsize: 1	lr: 0.001	hidsize:[16, 16]
# acc:0.514	batchsize: 1	lr: 0.001	hidsize:[32, 32]
# acc:0.531	batchsize: 1	lr: 0.001	hidsize:[64, 64]
# acc:0.501	batchsize: 1	lr: 0.005	hidsize:[8, 8]
# acc:0.503	batchsize: 1	lr: 0.005	hidsize:[16, 16]
# acc:0.524	batchsize: 1	lr: 0.005	hidsize:[32, 32]
# acc:0.524	batchsize: 1	lr: 0.005	hidsize:[64, 64]
# acc:0.55	batchsize: 1	lr:  0.01	hidsize:[8, 8]
# acc:0.517	batchsize: 1	lr:  0.01	hidsize:[16, 16]
# acc:0.533	batchsize: 1	lr:  0.01	hidsize:[32, 32]
# acc:0.507	batchsize: 1	lr:  0.01	hidsize:[64, 64]
# acc:0.507	batchsize: 1	lr:  0.05	hidsize:[8, 8]
# acc:0.506	batchsize: 1	lr:  0.05	hidsize:[16, 16]
# acc:0.529	batchsize: 1	lr:  0.05	hidsize:[32, 32]
# acc:0.529	batchsize: 1	lr:  0.05	hidsize:[64, 64]
# acc:0.54	batchsize: 4	lr:0.0007	hidsize:[8, 8]
# acc:0.579	batchsize: 4	lr:0.0007	hidsize:[16, 16]
# acc:0.583	batchsize: 4	lr:0.0007	hidsize:[32, 32]
# acc:0.583	batchsize: 4	lr:0.0007	hidsize:[64, 64]
# acc:0.537	batchsize: 4	lr: 0.001	hidsize:[8, 8]
# acc:0.583	batchsize: 4	lr: 0.001	hidsize:[16, 16]
# acc:0.59	batchsize: 4	lr: 0.001	hidsize:[32, 32]
# acc:0.593	batchsize: 4	lr: 0.001	hidsize:[64, 64]
# acc:0.564	batchsize: 4	lr: 0.005	hidsize:[8, 8]
# acc:0.578	batchsize: 4	lr: 0.005	hidsize:[16, 16]
# acc:0.604	batchsize: 4	lr: 0.005	hidsize:[32, 32]
# acc:0.585	batchsize: 4	lr: 0.005	hidsize:[64, 64]
# acc:0.586	batchsize: 4	lr:  0.01	hidsize:[8, 8]
# acc:0.594	batchsize: 4	lr:  0.01	hidsize:[16, 16]
# acc:0.597	batchsize: 4	lr:  0.01	hidsize:[32, 32]
# acc:0.594	batchsize: 4	lr:  0.01	hidsize:[64, 64]
# acc:0.531	batchsize: 4	lr:  0.05	hidsize:[8, 8]
# acc:0.596	batchsize: 4	lr:  0.05	hidsize:[16, 16]
# acc:0.579	batchsize: 4	lr:  0.05	hidsize:[32, 32]
# acc:0.599	batchsize: 4	lr:  0.05	hidsize:[64, 64]
# acc:0.546	batchsize:16	lr:0.0007	hidsize:[8, 8]
# acc:0.606	batchsize:16	lr:0.0007	hidsize:[16, 16]
# acc:0.582	batchsize:16	lr:0.0007	hidsize:[32, 32]
# acc:0.585	batchsize:16	lr:0.0007	hidsize:[64, 64]
# acc:0.544	batchsize:16	lr: 0.001	hidsize:[8, 8]
# acc: 0.6	batchsize:16	lr: 0.001	hidsize:[16, 16]
# acc:0.575	batchsize:16	lr: 0.001	hidsize:[32, 32]
# acc:0.582	batchsize:16	lr: 0.001	hidsize:[64, 64]
# acc:0.562	batchsize:16	lr: 0.005	hidsize:[8, 8]
# acc:0.581	batchsize:16	lr: 0.005	hidsize:[16, 16]
# acc:0.557	batchsize:16	lr: 0.005	hidsize:[32, 32]
# acc:0.578	batchsize:16	lr: 0.005	hidsize:[64, 64]
# acc:0.562	batchsize:16	lr:  0.01	hidsize:[8, 8]
# acc:0.562	batchsize:16	lr:  0.01	hidsize:[16, 16]
# acc:0.562	batchsize:16	lr:  0.01	hidsize:[32, 32]
# acc:0.572	batchsize:16	lr:  0.01	hidsize:[64, 64]
# acc:0.579	batchsize:16	lr:  0.05	hidsize:[8, 8]
# acc:0.567	batchsize:16	lr:  0.05	hidsize:[16, 16]
# acc:0.558	batchsize:16	lr:  0.05	hidsize:[32, 32]
# acc:0.569	batchsize:16	lr:  0.05	hidsize:[64, 64]
# acc:0.543	batchsize:32	lr:0.0007	hidsize:[8, 8]
# acc:0.576	batchsize:32	lr:0.0007	hidsize:[16, 16]
# acc:0.576	batchsize:32	lr:0.0007	hidsize:[32, 32]
# acc:0.585	batchsize:32	lr:0.0007	hidsize:[64, 64]
# acc:0.546	batchsize:32	lr: 0.001	hidsize:[8, 8]
# acc:0.565	batchsize:32	lr: 0.001	hidsize:[16, 16]
# acc:0.581	batchsize:32	lr: 0.001	hidsize:[32, 32]
# acc:0.582	batchsize:32	lr: 0.001	hidsize:[64, 64]
# acc:0.569	batchsize:32	lr: 0.005	hidsize:[8, 8]
# acc:0.59	batchsize:32	lr: 0.005	hidsize:[16, 16]
# acc:0.572	batchsize:32	lr: 0.005	hidsize:[32, 32]
# acc:0.581	batchsize:32	lr: 0.005	hidsize:[64, 64]
# acc:0.582	batchsize:32	lr:  0.01	hidsize:[8, 8]
# acc:0.593	batchsize:32	lr:  0.01	hidsize:[16, 16]
# acc:0.572	batchsize:32	lr:  0.01	hidsize:[32, 32]
# acc:0.583	batchsize:32	lr:  0.01	hidsize:[64, 64]
# acc:0.582	batchsize:32	lr:  0.05	hidsize:[8, 8]
# acc:0.585	batchsize:32	lr:  0.05	hidsize:[16, 16]
# acc:0.583	batchsize:32	lr:  0.05	hidsize:[32, 32]
# acc:0.594	batchsize:32	lr:  0.05	hidsize:[64, 64]
# acc:0.547	batchsize:64	lr:0.0007	hidsize:[8, 8]
# acc:0.575	batchsize:64	lr:0.0007	hidsize:[16, 16]
# acc:0.575	batchsize:64	lr:0.0007	hidsize:[32, 32]
# acc:0.583	batchsize:64	lr:0.0007	hidsize:[64, 64]
# acc:0.547	batchsize:64	lr: 0.001	hidsize:[8, 8]
# acc:0.579	batchsize:64	lr: 0.001	hidsize:[16, 16]
# acc:0.575	batchsize:64	lr: 0.001	hidsize:[32, 32]
# acc:0.572	batchsize:64	lr: 0.001	hidsize:[64, 64]
# acc:0.585	batchsize:64	lr: 0.005	hidsize:[8, 8]
# acc:0.576	batchsize:64	lr: 0.005	hidsize:[16, 16]
# acc:0.575	batchsize:64	lr: 0.005	hidsize:[32, 32]
# acc:0.581	batchsize:64	lr: 0.005	hidsize:[64, 64]
# acc:0.574	batchsize:64	lr:  0.01	hidsize:[8, 8]
# acc:0.583	batchsize:64	lr:  0.01	hidsize:[16, 16]
# acc:0.585	batchsize:64	lr:  0.01	hidsize:[32, 32]
# acc:0.574	batchsize:64	lr:  0.01	hidsize:[64, 64]
# acc:0.575	batchsize:64	lr:  0.05	hidsize:[8, 8]
# acc:0.594	batchsize:64	lr:  0.05	hidsize:[16, 16]
# acc:0.571	batchsize:64	lr:  0.05	hidsize:[32, 32]
# acc:0.551	batchsize:64	lr:  0.05	hidsize:[64, 64]
# --------------------------------------
# | [PEER] best batchsize   | 16       |
# | [PEER] best hidsize     | [16, 16] |
# | [PEER] best learning... | 0.0007   |
# --------------------------------------
# --------------------------------------
# | [NN] with bce loss      | 0.556    |
# | [NN] with peer loss     | 0.606    |
# | [NN] with surrogate ... | 0.55     |
# --------------------------------------
# Logging to logs/svm/19-08-28-13-29-06
# {'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'dataset': 'german', 'e0': 0.4, 'e1': 0.4, 'equalize_prior': True, 'episodes': 1500, 'alpha': 1.0}
# --------------------------------
# | [C-SVM] C1 = 0.1  | 0.504    |
# | [C-SVM] C1 = 0.2  | 0.504    |
# | [C-SVM] C1 = 0.25 | 0.504    |
# | [C-SVM] C1 = 0.33 | 0.504    |
# | [C-SVM] C1 = 0.5  | 0.504    |
# | [C-SVM] C1 = 1.0  | 0.559    |
# | [C-SVM] C1 = 10.0 | 0.502    |
# | [C-SVM] C1 = 2.0  | 0.518    |
# | [C-SVM] C1 = 3.0  | 0.506    |
# | [C-SVM] C1 = 4.0  | 0.506    |
# | [C-SVM] C1 = 5.0  | 0.502    |
# --------------------------------
# ------------------------------------
# | [C-SVM] accuracy max  | 0.656    |
# | [C-SVM] accuracy mean | 0.572    |
# | [C-SVM] accuracy min  | 0.511    |
# | [C-SVM] accuracy std  | 0.0481   |
# | [C-SVM] best C1       | 1        |
# ------------------------------------
# Logging to logs/pam/19-08-28-13-29-07
# {'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'dataset': 'german', 'e0': 0.4, 'e1': 0.4, 'equalize_prior': True, 'episodes': 1500, 'alpha': 1.0}
# -----------------------------------
# | [PAM] margin = 0     | 0.494    |
# | [PAM] margin = 0.125 | 0.514    |
# | [PAM] margin = 0.25  | 0.525    |
# | [PAM] margin = 0.5   | 0.504    |
# | [PAM] margin = 1     | 0.516    |
# -----------------------------------
# ----------------------------------
# | [PAM] accuracy max  | 0.656    |
# | [PAM] accuracy mean | 0.55     |
# | [PAM] accuracy min  | 0.489    |
# | [PAM] accuracy std  | 0.0601   |
# | [PAM] best margin   | 0.25     |
# ----------------------------------

# %% [markdown]
# ## Without Prior Equalization

# %% [markdown]
# ### $e_0 = 0.1, e_1 = 0.3$

# %%
from run_nn import find_best_alpha

args = default_args.copy()
args.update({
    'dataset': 'german', 
    'e0': 0.1, 'e1': 0.3, 
    'equalize_prior': False, 
    'episodes': 1500, 
    'batchsize': 32, 
    'hidsize': [32, 32], 
    'lr': 0.0007, 
#     'alpha': 1.0,
})
find_best_alpha(args)
# Out:
# ---------------------------------
# | [PEER] alpha = 0.4 | 0.638    |
# | [PEER] alpha = 0.5 | 0.657    |
# | [PEER] alpha = 0.6 | 0.646    |
# | [PEER] alpha = 0.7 | 0.658    |
# | [PEER] alpha = 0.8 | 0.671    |
# | [PEER] alpha = 0.9 | 0.67     |
# | [PEER] alpha = 1.0 | 0.68     |
# | [PEER] alpha = 2.0 | 0.563    |
# | [PEER] alpha = 3.0 | 0.563    |
# | [PEER] alpha = 4.0 | 0.563    |
# | [PEER] alpha = 5.0 | 0.563    |
# ---------------------------------
# {'alpha': 1.0}

# %%
from run_nn import find_best_alpha

args = default_args.copy()
args.update({
    'dataset': 'german', 
    'e0': 0.1, 'e1': 0.3, 
    'equalize_prior': False, 
    'episodes': 1500, 
    'batchsize': 32, 
    'hidsize': [32, 32], 
    'lr': 0.0007, 
#     'alpha': 1.0,
})
find_best_alpha(args)
# Out:
# ---------------------------------
# | [PEER] alpha = 0.1 | 0.602    |
# | [PEER] alpha = 0.2 | 0.607    |
# | [PEER] alpha = 0.3 | 0.612    |
# | [PEER] alpha = 0.4 | 0.638    |
# | [PEER] alpha = 0.5 | 0.657    |
# | [PEER] alpha = 0.6 | 0.646    |
# | [PEER] alpha = 0.7 | 0.658    |
# | [PEER] alpha = 0.8 | 0.671    |
# | [PEER] alpha = 0.9 | 0.67     |
# | [PEER] alpha = 1.0 | 0.68     |
# ---------------------------------
# {'alpha': 1.0}

# %%
from runner import run

args = default_args.copy()
args.update({
    'dataset': 'german', 
    'e0': 0.1, 'e1': 0.3, 
    'equalize_prior': False, 
    'episodes': 3000, 
#     'batchsize': 32, 
#     'hidsize': [32, 32], 
#     'lr': 0.001, 
#     'alpha': 1.0,
})
run(args)
# Out:
# Logging to logs/nn/19-08-28-13-29-31
# {'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'dataset': 'german', 'e0': 0.1, 'e1': 0.3, 'equalize_prior': False, 'episodes': 3000}
# acc:0.623	batchsize: 1	lr:0.0007	hidsize:[8, 8]
# acc:0.623	batchsize: 1	lr:0.0007	hidsize:[16, 16]
# acc:0.652	batchsize: 1	lr:0.0007	hidsize:[32, 32]
# acc:0.631	batchsize: 1	lr:0.0007	hidsize:[64, 64]
# acc:0.628	batchsize: 1	lr: 0.001	hidsize:[8, 8]
# acc:0.622	batchsize: 1	lr: 0.001	hidsize:[16, 16]
# acc:0.647	batchsize: 1	lr: 0.001	hidsize:[32, 32]
# acc:0.62	batchsize: 1	lr: 0.001	hidsize:[64, 64]
# acc: 0.6	batchsize: 1	lr: 0.005	hidsize:[8, 8]
# acc:0.596	batchsize: 1	lr: 0.005	hidsize:[16, 16]
# acc:0.635	batchsize: 1	lr: 0.005	hidsize:[32, 32]
# acc:0.615	batchsize: 1	lr: 0.005	hidsize:[64, 64]
# acc:0.628	batchsize: 1	lr:  0.01	hidsize:[8, 8]
# acc:0.605	batchsize: 1	lr:  0.01	hidsize:[16, 16]
# acc:0.605	batchsize: 1	lr:  0.01	hidsize:[32, 32]
# acc:0.598	batchsize: 1	lr:  0.01	hidsize:[64, 64]
# acc:0.587	batchsize: 1	lr:  0.05	hidsize:[8, 8]
# acc:0.642	batchsize: 1	lr:  0.05	hidsize:[16, 16]
# acc:0.651	batchsize: 1	lr:  0.05	hidsize:[32, 32]
# acc:0.604	batchsize: 1	lr:  0.05	hidsize:[64, 64]
# acc:0.615	batchsize: 4	lr:0.0007	hidsize:[8, 8]
# acc:0.648	batchsize: 4	lr:0.0007	hidsize:[16, 16]
# acc:0.662	batchsize: 4	lr:0.0007	hidsize:[32, 32]
# acc:0.644	batchsize: 4	lr:0.0007	hidsize:[64, 64]
# acc:0.618	batchsize: 4	lr: 0.001	hidsize:[8, 8]
# acc:0.658	batchsize: 4	lr: 0.001	hidsize:[16, 16]
# acc:0.66	batchsize: 4	lr: 0.001	hidsize:[32, 32]
# acc:0.645	batchsize: 4	lr: 0.001	hidsize:[64, 64]
# acc:0.631	batchsize: 4	lr: 0.005	hidsize:[8, 8]
# acc:0.636	batchsize: 4	lr: 0.005	hidsize:[16, 16]
# acc:0.641	batchsize: 4	lr: 0.005	hidsize:[32, 32]
# acc:0.634	batchsize: 4	lr: 0.005	hidsize:[64, 64]
# acc:0.642	batchsize: 4	lr:  0.01	hidsize:[8, 8]
# acc:0.632	batchsize: 4	lr:  0.01	hidsize:[16, 16]
# acc:0.633	batchsize: 4	lr:  0.01	hidsize:[32, 32]
# acc:0.632	batchsize: 4	lr:  0.01	hidsize:[64, 64]
# acc:0.508	batchsize: 4	lr:  0.05	hidsize:[8, 8]
# acc:0.622	batchsize: 4	lr:  0.05	hidsize:[16, 16]
# acc:0.647	batchsize: 4	lr:  0.05	hidsize:[32, 32]
# acc:0.638	batchsize: 4	lr:  0.05	hidsize:[64, 64]
# acc:0.636	batchsize:16	lr:0.0007	hidsize:[8, 8]
# acc:0.668	batchsize:16	lr:0.0007	hidsize:[16, 16]
# acc:0.667	batchsize:16	lr:0.0007	hidsize:[32, 32]
# acc:0.655	batchsize:16	lr:0.0007	hidsize:[64, 64]
# acc:0.634	batchsize:16	lr: 0.001	hidsize:[8, 8]
# acc:0.668	batchsize:16	lr: 0.001	hidsize:[16, 16]
# acc:0.665	batchsize:16	lr: 0.001	hidsize:[32, 32]
# acc:0.664	batchsize:16	lr: 0.001	hidsize:[64, 64]
# acc:0.663	batchsize:16	lr: 0.005	hidsize:[8, 8]
# acc:0.664	batchsize:16	lr: 0.005	hidsize:[16, 16]
# acc:0.67	batchsize:16	lr: 0.005	hidsize:[32, 32]
# acc:0.664	batchsize:16	lr: 0.005	hidsize:[64, 64]
# acc:0.649	batchsize:16	lr:  0.01	hidsize:[8, 8]
# acc:0.667	batchsize:16	lr:  0.01	hidsize:[16, 16]
# acc:0.663	batchsize:16	lr:  0.01	hidsize:[32, 32]
# acc:0.667	batchsize:16	lr:  0.01	hidsize:[64, 64]
# acc:0.645	batchsize:16	lr:  0.05	hidsize:[8, 8]
# acc:0.667	batchsize:16	lr:  0.05	hidsize:[16, 16]
# acc:0.667	batchsize:16	lr:  0.05	hidsize:[32, 32]
# acc:0.669	batchsize:16	lr:  0.05	hidsize:[64, 64]
# acc:0.628	batchsize:32	lr:0.0007	hidsize:[8, 8]
# acc:0.667	batchsize:32	lr:0.0007	hidsize:[16, 16]
# acc:0.68	batchsize:32	lr:0.0007	hidsize:[32, 32]
# acc:0.664	batchsize:32	lr:0.0007	hidsize:[64, 64]
# acc:0.635	batchsize:32	lr: 0.001	hidsize:[8, 8]
# acc:0.673	batchsize:32	lr: 0.001	hidsize:[16, 16]
# acc:0.678	batchsize:32	lr: 0.001	hidsize:[32, 32]
# acc:0.663	batchsize:32	lr: 0.001	hidsize:[64, 64]
# acc:0.672	batchsize:32	lr: 0.005	hidsize:[8, 8]
# acc:0.657	batchsize:32	lr: 0.005	hidsize:[16, 16]
# acc:0.669	batchsize:32	lr: 0.005	hidsize:[32, 32]
# acc:0.659	batchsize:32	lr: 0.005	hidsize:[64, 64]
# acc:0.66	batchsize:32	lr:  0.01	hidsize:[8, 8]
# acc:0.668	batchsize:32	lr:  0.01	hidsize:[16, 16]
# acc:0.672	batchsize:32	lr:  0.01	hidsize:[32, 32]
# acc:0.653	batchsize:32	lr:  0.01	hidsize:[64, 64]
# acc:0.649	batchsize:32	lr:  0.05	hidsize:[8, 8]
# acc:0.653	batchsize:32	lr:  0.05	hidsize:[16, 16]
# acc:0.65	batchsize:32	lr:  0.05	hidsize:[32, 32]
# acc:0.641	batchsize:32	lr:  0.05	hidsize:[64, 64]
# acc:0.651	batchsize:64	lr:0.0007	hidsize:[8, 8]
# acc:0.662	batchsize:64	lr:0.0007	hidsize:[16, 16]
# acc:0.665	batchsize:64	lr:0.0007	hidsize:[32, 32]
# acc:0.659	batchsize:64	lr:0.0007	hidsize:[64, 64]
# acc:0.652	batchsize:64	lr: 0.001	hidsize:[8, 8]
# acc:0.668	batchsize:64	lr: 0.001	hidsize:[16, 16]
# acc:0.67	batchsize:64	lr: 0.001	hidsize:[32, 32]
# acc:0.657	batchsize:64	lr: 0.001	hidsize:[64, 64]
# acc:0.671	batchsize:64	lr: 0.005	hidsize:[8, 8]
# acc:0.667	batchsize:64	lr: 0.005	hidsize:[16, 16]
# acc:0.653	batchsize:64	lr: 0.005	hidsize:[32, 32]
# acc:0.642	batchsize:64	lr: 0.005	hidsize:[64, 64]
# acc:0.651	batchsize:64	lr:  0.01	hidsize:[8, 8]
# acc:0.662	batchsize:64	lr:  0.01	hidsize:[16, 16]
# acc:0.65	batchsize:64	lr:  0.01	hidsize:[32, 32]
# acc:0.64	batchsize:64	lr:  0.01	hidsize:[64, 64]
# acc:0.594	batchsize:64	lr:  0.05	hidsize:[8, 8]
# acc:0.65	batchsize:64	lr:  0.05	hidsize:[16, 16]
# acc:0.639	batchsize:64	lr:  0.05	hidsize:[32, 32]
# acc:0.641	batchsize:64	lr:  0.05	hidsize:[64, 64]
# --------------------------------------
# | [PEER] best batchsize   | 32       |
# | [PEER] best hidsize     | [32, 32] |
# | [PEER] best learning... | 0.0007   |
# --------------------------------------
# ---------------------------------
# | [PEER] alpha = 0.1 | 0.583    |
# | [PEER] alpha = 0.2 | 0.573    |
# | [PEER] alpha = 0.3 | 0.595    |
# | [PEER] alpha = 0.4 | 0.594    |
# | [PEER] alpha = 0.5 | 0.614    |
# | [PEER] alpha = 0.6 | 0.609    |
# | [PEER] alpha = 0.7 | 0.593    |
# | [PEER] alpha = 0.8 | 0.592    |
# | [PEER] alpha = 0.9 | 0.592    |
# | [PEER] alpha = 1.0 | 0.595    |
# ---------------------------------
# --------------------------------------
# | [NN] with bce loss      | 0.6      |
# | [NN] with peer loss     | 0.652    |
# | [NN] with surrogate ... | 0.693    |
# | [PEER] best alpha       | 0.5      |
# --------------------------------------
# Logging to logs/svm/19-08-28-13-58-45
# {'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'dataset': 'german', 'e0': 0.1, 'e1': 0.3, 'equalize_prior': False, 'episodes': 3000}
# --------------------------------
# | [C-SVM] C1 = 0.1  | 0.474    |
# | [C-SVM] C1 = 0.2  | 0.474    |
# | [C-SVM] C1 = 0.25 | 0.474    |
# | [C-SVM] C1 = 0.33 | 0.474    |
# | [C-SVM] C1 = 0.5  | 0.504    |
# | [C-SVM] C1 = 1.0  | 0.601    |
# | [C-SVM] C1 = 10.0 | 0.561    |
# | [C-SVM] C1 = 2.0  | 0.566    |
# | [C-SVM] C1 = 3.0  | 0.564    |
# | [C-SVM] C1 = 4.0  | 0.561    |
# | [C-SVM] C1 = 5.0  | 0.559    |
# --------------------------------
# ------------------------------------
# | [C-SVM] accuracy max  | 0.733    |
# | [C-SVM] accuracy mean | 0.671    |
# | [C-SVM] accuracy min  | 0.613    |
# | [C-SVM] accuracy std  | 0.0368   |
# | [C-SVM] best C1       | 1        |
# ------------------------------------
# Logging to logs/pam/19-08-28-13-58-46
# {'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'dataset': 'german', 'e0': 0.1, 'e1': 0.3, 'equalize_prior': False, 'episodes': 3000}
# -----------------------------------
# | [PAM] margin = 0     | 0.556    |
# | [PAM] margin = 0.125 | 0.603    |
# | [PAM] margin = 0.25  | 0.605    |
# | [PAM] margin = 0.5   | 0.598    |
# | [PAM] margin = 1     | 0.595    |
# -----------------------------------
# ----------------------------------
# | [PAM] accuracy max  | 0.72     |
# | [PAM] accuracy mean | 0.655    |
# | [PAM] accuracy min  | 0.6      |
# | [PAM] accuracy std  | 0.0395   |
# | [PAM] best margin   | 0.25     |
# ----------------------------------

# %% [markdown]
# ### $e_0 = 0.2, e_1 = 0.2$

# %%
from run_nn import find_best_alpha

args = default_args.copy()
args.update({
    'dataset': 'german', 
    'e0': 0.1, 'e1': 0.3, 
    'equalize_prior': False, 
    'episodes': 1500, 
    'batchsize': 4, 
    'hidsize': [32, 32], 
    'lr': 0.001, 
#     'alpha': 1.0,
})
find_best_alpha(args)
# Out:
# ---------------------------------
# | [PEER] alpha = 0.4 | 0.637    |
# | [PEER] alpha = 0.5 | 0.637    |
# | [PEER] alpha = 0.6 | 0.638    |
# | [PEER] alpha = 0.7 | 0.647    |
# | [PEER] alpha = 0.8 | 0.65     |
# | [PEER] alpha = 0.9 | 0.663    |
# | [PEER] alpha = 1.0 | 0.656    |
# | [PEER] alpha = 2.0 | 0.513    |
# | [PEER] alpha = 3.0 | 0.515    |
# | [PEER] alpha = 4.0 | 0.515    |
# | [PEER] alpha = 5.0 | 0.515    |
# ---------------------------------
# {'alpha': 0.9}

# %%
from run_nn import find_best_alpha

args = default_args.copy()
args.update({
    'dataset': 'german', 
    'e0': 0.1, 'e1': 0.3, 
    'equalize_prior': False, 
    'episodes': 1500, 
    'batchsize': 4, 
    'hidsize': [32, 32], 
    'lr': 0.001, 
#     'alpha': 1.0,
})
find_best_alpha(args)
# Out:
# ---------------------------------
# | [PEER] alpha = 0.1 | 0.617    |
# | [PEER] alpha = 0.2 | 0.616    |
# | [PEER] alpha = 0.3 | 0.627    |
# | [PEER] alpha = 0.4 | 0.637    |
# | [PEER] alpha = 0.5 | 0.637    |
# | [PEER] alpha = 0.6 | 0.638    |
# | [PEER] alpha = 0.7 | 0.647    |
# | [PEER] alpha = 0.8 | 0.65     |
# | [PEER] alpha = 0.9 | 0.663    |
# | [PEER] alpha = 1.0 | 0.656    |
# ---------------------------------
# {'alpha': 0.9}

# %%
from runner import run

args = default_args.copy()
args.update({
    'dataset': 'german', 
    'e0': 0.2, 'e1': 0.2, 
    'equalize_prior': False, 
    'episodes': 1500, 
#     'batchsize': 4, 
#     'hidsize': [32, 32], 
#     'lr': 0.001, 
#     'alpha': 1.0,
})
run(args)
# Out:
# Logging to logs/nn/19-08-28-14-01-12
# {'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'dataset': 'german', 'e0': 0.2, 'e1': 0.2, 'equalize_prior': False, 'episodes': 1500}
# acc:0.619	batchsize: 1	lr:0.0007	hidsize:[8, 8]
# acc:0.619	batchsize: 1	lr:0.0007	hidsize:[16, 16]
# acc:0.649	batchsize: 1	lr:0.0007	hidsize:[32, 32]
# acc:0.64	batchsize: 1	lr:0.0007	hidsize:[64, 64]
# acc:0.612	batchsize: 1	lr: 0.001	hidsize:[8, 8]
# acc:0.642	batchsize: 1	lr: 0.001	hidsize:[16, 16]
# acc:0.647	batchsize: 1	lr: 0.001	hidsize:[32, 32]
# acc:0.634	batchsize: 1	lr: 0.001	hidsize:[64, 64]
# acc:0.649	batchsize: 1	lr: 0.005	hidsize:[8, 8]
# acc:0.626	batchsize: 1	lr: 0.005	hidsize:[16, 16]
# acc:0.623	batchsize: 1	lr: 0.005	hidsize:[32, 32]
# acc:0.618	batchsize: 1	lr: 0.005	hidsize:[64, 64]
# acc:0.607	batchsize: 1	lr:  0.01	hidsize:[8, 8]
# acc:0.627	batchsize: 1	lr:  0.01	hidsize:[16, 16]
# acc:0.638	batchsize: 1	lr:  0.01	hidsize:[32, 32]
# acc:0.646	batchsize: 1	lr:  0.01	hidsize:[64, 64]
# acc:0.583	batchsize: 1	lr:  0.05	hidsize:[8, 8]
# acc:0.639	batchsize: 1	lr:  0.05	hidsize:[16, 16]
# acc:0.645	batchsize: 1	lr:  0.05	hidsize:[32, 32]
# acc:0.635	batchsize: 1	lr:  0.05	hidsize:[64, 64]
# acc:0.634	batchsize: 4	lr:0.0007	hidsize:[8, 8]
# acc:0.661	batchsize: 4	lr:0.0007	hidsize:[16, 16]
# acc:0.686	batchsize: 4	lr:0.0007	hidsize:[32, 32]
# acc:0.676	batchsize: 4	lr:0.0007	hidsize:[64, 64]
# acc:0.648	batchsize: 4	lr: 0.001	hidsize:[8, 8]
# acc:0.674	batchsize: 4	lr: 0.001	hidsize:[16, 16]
# acc:0.697	batchsize: 4	lr: 0.001	hidsize:[32, 32]
# acc:0.678	batchsize: 4	lr: 0.001	hidsize:[64, 64]
# acc:0.651	batchsize: 4	lr: 0.005	hidsize:[8, 8]
# acc:0.671	batchsize: 4	lr: 0.005	hidsize:[16, 16]
# acc:0.664	batchsize: 4	lr: 0.005	hidsize:[32, 32]
# acc:0.66	batchsize: 4	lr: 0.005	hidsize:[64, 64]
# acc:0.627	batchsize: 4	lr:  0.01	hidsize:[8, 8]
# acc:0.667	batchsize: 4	lr:  0.01	hidsize:[16, 16]
# acc:0.667	batchsize: 4	lr:  0.01	hidsize:[32, 32]
# acc:0.667	batchsize: 4	lr:  0.01	hidsize:[64, 64]
# acc:0.598	batchsize: 4	lr:  0.05	hidsize:[8, 8]
# acc:0.669	batchsize: 4	lr:  0.05	hidsize:[16, 16]
# acc:0.676	batchsize: 4	lr:  0.05	hidsize:[32, 32]
# acc:0.663	batchsize: 4	lr:  0.05	hidsize:[64, 64]
# acc:0.631	batchsize:16	lr:0.0007	hidsize:[8, 8]
# acc:0.676	batchsize:16	lr:0.0007	hidsize:[16, 16]
# acc:0.685	batchsize:16	lr:0.0007	hidsize:[32, 32]
# acc:0.671	batchsize:16	lr:0.0007	hidsize:[64, 64]
# acc:0.639	batchsize:16	lr: 0.001	hidsize:[8, 8]
# acc:0.672	batchsize:16	lr: 0.001	hidsize:[16, 16]
# acc:0.683	batchsize:16	lr: 0.001	hidsize:[32, 32]
# acc:0.666	batchsize:16	lr: 0.001	hidsize:[64, 64]
# acc:0.642	batchsize:16	lr: 0.005	hidsize:[8, 8]
# acc:0.678	batchsize:16	lr: 0.005	hidsize:[16, 16]
# acc:0.679	batchsize:16	lr: 0.005	hidsize:[32, 32]
# acc:0.671	batchsize:16	lr: 0.005	hidsize:[64, 64]
# acc:0.643	batchsize:16	lr:  0.01	hidsize:[8, 8]
# acc:0.662	batchsize:16	lr:  0.01	hidsize:[16, 16]
# acc:0.669	batchsize:16	lr:  0.01	hidsize:[32, 32]
# acc:0.675	batchsize:16	lr:  0.01	hidsize:[64, 64]
# acc:0.655	batchsize:16	lr:  0.05	hidsize:[8, 8]
# acc:0.665	batchsize:16	lr:  0.05	hidsize:[16, 16]
# acc:0.663	batchsize:16	lr:  0.05	hidsize:[32, 32]
# acc:0.659	batchsize:16	lr:  0.05	hidsize:[64, 64]
# acc:0.631	batchsize:32	lr:0.0007	hidsize:[8, 8]
# acc:0.671	batchsize:32	lr:0.0007	hidsize:[16, 16]
# acc:0.69	batchsize:32	lr:0.0007	hidsize:[32, 32]
# acc:0.677	batchsize:32	lr:0.0007	hidsize:[64, 64]
# acc:0.646	batchsize:32	lr: 0.001	hidsize:[8, 8]
# acc:0.673	batchsize:32	lr: 0.001	hidsize:[16, 16]
# acc:0.685	batchsize:32	lr: 0.001	hidsize:[32, 32]
# acc:0.674	batchsize:32	lr: 0.001	hidsize:[64, 64]
# acc:0.65	batchsize:32	lr: 0.005	hidsize:[8, 8]
# acc:0.673	batchsize:32	lr: 0.005	hidsize:[16, 16]
# acc:0.674	batchsize:32	lr: 0.005	hidsize:[32, 32]
# acc:0.671	batchsize:32	lr: 0.005	hidsize:[64, 64]
# acc:0.642	batchsize:32	lr:  0.01	hidsize:[8, 8]
# acc:0.663	batchsize:32	lr:  0.01	hidsize:[16, 16]
# acc:0.659	batchsize:32	lr:  0.01	hidsize:[32, 32]
# acc:0.663	batchsize:32	lr:  0.01	hidsize:[64, 64]
# acc:0.643	batchsize:32	lr:  0.05	hidsize:[8, 8]
# acc:0.662	batchsize:32	lr:  0.05	hidsize:[16, 16]
# acc:0.658	batchsize:32	lr:  0.05	hidsize:[32, 32]
# acc:0.649	batchsize:32	lr:  0.05	hidsize:[64, 64]
# acc:0.649	batchsize:64	lr:0.0007	hidsize:[8, 8]
# acc:0.665	batchsize:64	lr:0.0007	hidsize:[16, 16]
# acc:0.674	batchsize:64	lr:0.0007	hidsize:[32, 32]
# acc:0.667	batchsize:64	lr:0.0007	hidsize:[64, 64]
# acc:0.646	batchsize:64	lr: 0.001	hidsize:[8, 8]
# acc:0.667	batchsize:64	lr: 0.001	hidsize:[16, 16]
# acc:0.675	batchsize:64	lr: 0.001	hidsize:[32, 32]
# acc:0.669	batchsize:64	lr: 0.001	hidsize:[64, 64]
# acc:0.652	batchsize:64	lr: 0.005	hidsize:[8, 8]
# acc:0.67	batchsize:64	lr: 0.005	hidsize:[16, 16]
# acc:0.669	batchsize:64	lr: 0.005	hidsize:[32, 32]
# acc:0.666	batchsize:64	lr: 0.005	hidsize:[64, 64]
# acc:0.653	batchsize:64	lr:  0.01	hidsize:[8, 8]
# acc:0.663	batchsize:64	lr:  0.01	hidsize:[16, 16]
# acc:0.663	batchsize:64	lr:  0.01	hidsize:[32, 32]
# acc:0.661	batchsize:64	lr:  0.01	hidsize:[64, 64]
# acc:0.652	batchsize:64	lr:  0.05	hidsize:[8, 8]
# acc:0.665	batchsize:64	lr:  0.05	hidsize:[16, 16]
# acc:0.643	batchsize:64	lr:  0.05	hidsize:[32, 32]
# acc:0.649	batchsize:64	lr:  0.05	hidsize:[64, 64]
# --------------------------------------
# | [PEER] best batchsize   | 4        |
# | [PEER] best hidsize     | [32, 32] |
# | [PEER] best learning... | 0.001    |
# --------------------------------------
# ---------------------------------
# | [PEER] alpha = 0.1 | 0.594    |
# | [PEER] alpha = 0.2 | 0.603    |
# | [PEER] alpha = 0.3 | 0.587    |
# | [PEER] alpha = 0.4 | 0.6      |
# | [PEER] alpha = 0.5 | 0.605    |
# | [PEER] alpha = 0.6 | 0.62     |
# | [PEER] alpha = 0.7 | 0.615    |
# | [PEER] alpha = 0.8 | 0.619    |
# | [PEER] alpha = 0.9 | 0.631    |
# | [PEER] alpha = 1.0 | 0.621    |
# ---------------------------------
# --------------------------------------
# | [NN] with bce loss      | 0.666    |
# | [NN] with peer loss     | 0.702    |
# | [NN] with surrogate ... | 0.679    |
# | [PEER] best alpha       | 0.9      |
# --------------------------------------
# Logging to logs/svm/19-08-28-14-14-34
# {'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'dataset': 'german', 'e0': 0.2, 'e1': 0.2, 'equalize_prior': False, 'episodes': 1500}
# --------------------------------
# | [C-SVM] C1 = 0.1  | 0.375    |
# | [C-SVM] C1 = 0.2  | 0.375    |
# | [C-SVM] C1 = 0.25 | 0.38     |
# | [C-SVM] C1 = 0.33 | 0.439    |
# | [C-SVM] C1 = 0.5  | 0.566    |
# | [C-SVM] C1 = 1.0  | 0.646    |
# | [C-SVM] C1 = 10.0 | 0.636    |
# | [C-SVM] C1 = 2.0  | 0.636    |
# | [C-SVM] C1 = 3.0  | 0.635    |
# | [C-SVM] C1 = 4.0  | 0.636    |
# | [C-SVM] C1 = 5.0  | 0.636    |
# --------------------------------
# ------------------------------------
# | [C-SVM] accuracy max  | 0.833    |
# | [C-SVM] accuracy mean | 0.738    |
# | [C-SVM] accuracy min  | 0.687    |
# | [C-SVM] accuracy std  | 0.0457   |
# | [C-SVM] best C1       | 1        |
# ------------------------------------
# Logging to logs/pam/19-08-28-14-14-35
# {'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'dataset': 'german', 'e0': 0.2, 'e1': 0.2, 'equalize_prior': False, 'episodes': 1500}
# -----------------------------------
# | [PAM] margin = 0     | 0.579    |
# | [PAM] margin = 0.125 | 0.627    |
# | [PAM] margin = 0.25  | 0.634    |
# | [PAM] margin = 0.5   | 0.63     |
# | [PAM] margin = 1     | 0.635    |
# -----------------------------------
# ----------------------------------
# | [PAM] accuracy max  | 0.773    |
# | [PAM] accuracy mean | 0.722    |
# | [PAM] accuracy min  | 0.66     |
# | [PAM] accuracy std  | 0.0401   |
# | [PAM] best margin   | 1        |
# ----------------------------------

# %% [markdown]
# ### $e_0 = 0.1, e_1 = 0.4$

# %%
from run_nn import find_best_alpha

args = default_args.copy()
args.update({
    'dataset': 'german', 
    'e0': 0.1, 'e1': 0.3, 
    'equalize_prior': False, 
    'episodes': 3000, 
    'batchsize': 32, 
    'hidsize': [16, 16], 
    'lr': 0.0007, 
#     'alpha': 1.0,
})
find_best_alpha(args)
# Out:
# ---------------------------------
# | [PEER] alpha = 0.4 | 0.624    |
# | [PEER] alpha = 0.5 | 0.637    |
# | [PEER] alpha = 0.6 | 0.652    |
# | [PEER] alpha = 0.7 | 0.652    |
# | [PEER] alpha = 0.8 | 0.665    |
# | [PEER] alpha = 0.9 | 0.662    |
# | [PEER] alpha = 1.0 | 0.667    |
# | [PEER] alpha = 2.0 | 0.52     |
# | [PEER] alpha = 3.0 | 0.345    |
# | [PEER] alpha = 4.0 | 0.345    |
# | [PEER] alpha = 5.0 | 0.345    |
# ---------------------------------
# {'alpha': 1.0}

# %%
from run_nn import find_best_alpha

args = default_args.copy()
args.update({
    'dataset': 'german', 
    'e0': 0.1, 'e1': 0.3, 
    'equalize_prior': False, 
    'episodes': 3000, 
    'batchsize': 32, 
    'hidsize': [16, 16], 
    'lr': 0.0007, 
#     'alpha': 1.0,
})
find_best_alpha(args)
# Out:
# ---------------------------------
# | [PEER] alpha = 0.1 | 0.591    |
# | [PEER] alpha = 0.2 | 0.599    |
# | [PEER] alpha = 0.3 | 0.611    |
# | [PEER] alpha = 0.4 | 0.624    |
# | [PEER] alpha = 0.5 | 0.637    |
# | [PEER] alpha = 0.6 | 0.652    |
# | [PEER] alpha = 0.7 | 0.652    |
# | [PEER] alpha = 0.8 | 0.665    |
# | [PEER] alpha = 0.9 | 0.662    |
# | [PEER] alpha = 1.0 | 0.667    |
# ---------------------------------
# {'alpha': 1.0}

# %%
from runner import run

args = default_args.copy()
args.update({
    'dataset': 'german', 
    'e0': 0.1, 'e1': 0.4, 
    'equalize_prior': False, 
    'episodes': 3000, 
#     'batchsize': 4, 
#     'hidsize': [32, 32], 
#     'lr': 0.001, 
#     'alpha': 1.0,
})
run(args)
# Out:
# Logging to logs/nn/19-08-28-14-14-46
# {'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'dataset': 'german', 'e0': 0.1, 'e1': 0.4, 'equalize_prior': False, 'episodes': 3000}
# acc:0.63	batchsize: 1	lr:0.0007	hidsize:[8, 8]
# acc:0.617	batchsize: 1	lr:0.0007	hidsize:[16, 16]
# acc:0.645	batchsize: 1	lr:0.0007	hidsize:[32, 32]
# acc:0.645	batchsize: 1	lr:0.0007	hidsize:[64, 64]
# acc:0.632	batchsize: 1	lr: 0.001	hidsize:[8, 8]
# acc:0.642	batchsize: 1	lr: 0.001	hidsize:[16, 16]
# acc:0.655	batchsize: 1	lr: 0.001	hidsize:[32, 32]
# acc:0.63	batchsize: 1	lr: 0.001	hidsize:[64, 64]
# acc:0.626	batchsize: 1	lr: 0.005	hidsize:[8, 8]
# acc:0.603	batchsize: 1	lr: 0.005	hidsize:[16, 16]
# acc:0.619	batchsize: 1	lr: 0.005	hidsize:[32, 32]
# acc:0.626	batchsize: 1	lr: 0.005	hidsize:[64, 64]
# acc:0.549	batchsize: 1	lr:  0.01	hidsize:[8, 8]
# acc:0.588	batchsize: 1	lr:  0.01	hidsize:[16, 16]
# acc:0.624	batchsize: 1	lr:  0.01	hidsize:[32, 32]
# acc:0.633	batchsize: 1	lr:  0.01	hidsize:[64, 64]
# acc:0.556	batchsize: 1	lr:  0.05	hidsize:[8, 8]
# acc:0.627	batchsize: 1	lr:  0.05	hidsize:[16, 16]
# acc:0.622	batchsize: 1	lr:  0.05	hidsize:[32, 32]
# acc:0.588	batchsize: 1	lr:  0.05	hidsize:[64, 64]
# acc:0.638	batchsize: 4	lr:0.0007	hidsize:[8, 8]
# acc:0.654	batchsize: 4	lr:0.0007	hidsize:[16, 16]
# acc:0.667	batchsize: 4	lr:0.0007	hidsize:[32, 32]
# acc:0.647	batchsize: 4	lr:0.0007	hidsize:[64, 64]
# acc:0.636	batchsize: 4	lr: 0.001	hidsize:[8, 8]
# acc:0.659	batchsize: 4	lr: 0.001	hidsize:[16, 16]
# acc:0.656	batchsize: 4	lr: 0.001	hidsize:[32, 32]
# acc:0.641	batchsize: 4	lr: 0.001	hidsize:[64, 64]
# acc:0.618	batchsize: 4	lr: 0.005	hidsize:[8, 8]
# acc:0.653	batchsize: 4	lr: 0.005	hidsize:[16, 16]
# acc:0.647	batchsize: 4	lr: 0.005	hidsize:[32, 32]
# acc:0.624	batchsize: 4	lr: 0.005	hidsize:[64, 64]
# acc:0.642	batchsize: 4	lr:  0.01	hidsize:[8, 8]
# acc:0.644	batchsize: 4	lr:  0.01	hidsize:[16, 16]
# acc:0.642	batchsize: 4	lr:  0.01	hidsize:[32, 32]
# acc:0.625	batchsize: 4	lr:  0.01	hidsize:[64, 64]
# acc:0.576	batchsize: 4	lr:  0.05	hidsize:[8, 8]
# acc:0.622	batchsize: 4	lr:  0.05	hidsize:[16, 16]
# acc:0.642	batchsize: 4	lr:  0.05	hidsize:[32, 32]
# acc:0.654	batchsize: 4	lr:  0.05	hidsize:[64, 64]
# acc:0.632	batchsize:16	lr:0.0007	hidsize:[8, 8]
# acc:0.67	batchsize:16	lr:0.0007	hidsize:[16, 16]
# acc:0.659	batchsize:16	lr:0.0007	hidsize:[32, 32]
# acc:0.652	batchsize:16	lr:0.0007	hidsize:[64, 64]
# acc:0.63	batchsize:16	lr: 0.001	hidsize:[8, 8]
# acc:0.669	batchsize:16	lr: 0.001	hidsize:[16, 16]
# acc:0.66	batchsize:16	lr: 0.001	hidsize:[32, 32]
# acc:0.653	batchsize:16	lr: 0.001	hidsize:[64, 64]
# acc:0.647	batchsize:16	lr: 0.005	hidsize:[8, 8]
# acc:0.665	batchsize:16	lr: 0.005	hidsize:[16, 16]
# acc:0.668	batchsize:16	lr: 0.005	hidsize:[32, 32]
# acc:0.653	batchsize:16	lr: 0.005	hidsize:[64, 64]
# acc:0.613	batchsize:16	lr:  0.01	hidsize:[8, 8]
# acc:0.651	batchsize:16	lr:  0.01	hidsize:[16, 16]
# acc:0.662	batchsize:16	lr:  0.01	hidsize:[32, 32]
# acc:0.658	batchsize:16	lr:  0.01	hidsize:[64, 64]
# acc:0.589	batchsize:16	lr:  0.05	hidsize:[8, 8]
# acc:0.645	batchsize:16	lr:  0.05	hidsize:[16, 16]
# acc:0.655	batchsize:16	lr:  0.05	hidsize:[32, 32]
# acc:0.652	batchsize:16	lr:  0.05	hidsize:[64, 64]
# acc:0.637	batchsize:32	lr:0.0007	hidsize:[8, 8]
# acc:0.683	batchsize:32	lr:0.0007	hidsize:[16, 16]
# acc:0.662	batchsize:32	lr:0.0007	hidsize:[32, 32]
# acc:0.654	batchsize:32	lr:0.0007	hidsize:[64, 64]
# acc:0.642	batchsize:32	lr: 0.001	hidsize:[8, 8]
# acc:0.681	batchsize:32	lr: 0.001	hidsize:[16, 16]
# acc:0.667	batchsize:32	lr: 0.001	hidsize:[32, 32]
# acc:0.657	batchsize:32	lr: 0.001	hidsize:[64, 64]
# acc:0.633	batchsize:32	lr: 0.005	hidsize:[8, 8]
# acc:0.653	batchsize:32	lr: 0.005	hidsize:[16, 16]
# acc:0.665	batchsize:32	lr: 0.005	hidsize:[32, 32]
# acc:0.656	batchsize:32	lr: 0.005	hidsize:[64, 64]
# acc:0.641	batchsize:32	lr:  0.01	hidsize:[8, 8]
# acc:0.652	batchsize:32	lr:  0.01	hidsize:[16, 16]
# acc:0.662	batchsize:32	lr:  0.01	hidsize:[32, 32]
# acc:0.648	batchsize:32	lr:  0.01	hidsize:[64, 64]
# acc:0.633	batchsize:32	lr:  0.05	hidsize:[8, 8]
# acc:0.649	batchsize:32	lr:  0.05	hidsize:[16, 16]
# acc:0.666	batchsize:32	lr:  0.05	hidsize:[32, 32]
# acc:0.653	batchsize:32	lr:  0.05	hidsize:[64, 64]
# acc:0.643	batchsize:64	lr:0.0007	hidsize:[8, 8]
# acc:0.672	batchsize:64	lr:0.0007	hidsize:[16, 16]
# acc:0.662	batchsize:64	lr:0.0007	hidsize:[32, 32]
# acc:0.649	batchsize:64	lr:0.0007	hidsize:[64, 64]
# acc:0.654	batchsize:64	lr: 0.001	hidsize:[8, 8]
# acc:0.673	batchsize:64	lr: 0.001	hidsize:[16, 16]
# acc:0.657	batchsize:64	lr: 0.001	hidsize:[32, 32]
# acc:0.652	batchsize:64	lr: 0.001	hidsize:[64, 64]
# acc:0.64	batchsize:64	lr: 0.005	hidsize:[8, 8]
# acc:0.65	batchsize:64	lr: 0.005	hidsize:[16, 16]
# acc:0.649	batchsize:64	lr: 0.005	hidsize:[32, 32]
# acc:0.651	batchsize:64	lr: 0.005	hidsize:[64, 64]
# acc:0.634	batchsize:64	lr:  0.01	hidsize:[8, 8]
# acc:0.652	batchsize:64	lr:  0.01	hidsize:[16, 16]
# acc:0.641	batchsize:64	lr:  0.01	hidsize:[32, 32]
# acc:0.645	batchsize:64	lr:  0.01	hidsize:[64, 64]
# acc:0.627	batchsize:64	lr:  0.05	hidsize:[8, 8]
# acc:0.616	batchsize:64	lr:  0.05	hidsize:[16, 16]
# acc:0.641	batchsize:64	lr:  0.05	hidsize:[32, 32]
# acc:0.629	batchsize:64	lr:  0.05	hidsize:[64, 64]
# --------------------------------------
# | [PEER] best batchsize   | 32       |
# | [PEER] best hidsize     | [16, 16] |
# | [PEER] best learning... | 0.0007   |
# --------------------------------------
# ---------------------------------
# | [PEER] alpha = 0.1 | 0.556    |
# | [PEER] alpha = 0.2 | 0.559    |
# | [PEER] alpha = 0.3 | 0.564    |
# | [PEER] alpha = 0.4 | 0.545    |
# | [PEER] alpha = 0.5 | 0.575    |
# | [PEER] alpha = 0.6 | 0.559    |
# | [PEER] alpha = 0.7 | 0.553    |
# | [PEER] alpha = 0.8 | 0.552    |
# | [PEER] alpha = 0.9 | 0.559    |
# | [PEER] alpha = 1.0 | 0.562    |
# ---------------------------------
# --------------------------------------
# | [NN] with bce loss      | 0.54     |
# | [NN] with peer loss     | 0.584    |
# | [NN] with surrogate ... | 0.693    |
# | [PEER] best alpha       | 0.5      |
# --------------------------------------
# Logging to logs/svm/19-08-28-14-43-08
# {'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'dataset': 'german', 'e0': 0.1, 'e1': 0.4, 'equalize_prior': False, 'episodes': 3000}
# --------------------------------
# | [C-SVM] C1 = 0.1  | 0.547    |
# | [C-SVM] C1 = 0.2  | 0.547    |
# | [C-SVM] C1 = 0.25 | 0.547    |
# | [C-SVM] C1 = 0.33 | 0.547    |
# | [C-SVM] C1 = 0.5  | 0.545    |
# | [C-SVM] C1 = 1.0  | 0.579    |
# | [C-SVM] C1 = 10.0 | 0.52     |
# | [C-SVM] C1 = 2.0  | 0.537    |
# | [C-SVM] C1 = 3.0  | 0.531    |
# | [C-SVM] C1 = 4.0  | 0.522    |
# | [C-SVM] C1 = 5.0  | 0.52     |
# --------------------------------
# ------------------------------------
# | [C-SVM] accuracy max  | 0.607    |
# | [C-SVM] accuracy mean | 0.553    |
# | [C-SVM] accuracy min  | 0.5      |
# | [C-SVM] accuracy std  | 0.0311   |
# | [C-SVM] best C1       | 1        |
# ------------------------------------
# Logging to logs/pam/19-08-28-14-43-10
# {'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'dataset': 'german', 'e0': 0.1, 'e1': 0.4, 'equalize_prior': False, 'episodes': 3000}
# -----------------------------------
# | [PAM] margin = 0     | 0.524    |
# | [PAM] margin = 0.125 | 0.559    |
# | [PAM] margin = 0.25  | 0.572    |
# | [PAM] margin = 0.5   | 0.562    |
# | [PAM] margin = 1     | 0.564    |
# -----------------------------------
# ----------------------------------
# | [PAM] accuracy max  | 0.653    |
# | [PAM] accuracy mean | 0.583    |
# | [PAM] accuracy min  | 0.527    |
# | [PAM] accuracy std  | 0.039    |
# | [PAM] best margin   | 0.25     |
# ----------------------------------

# %% [markdown]
# ### $e_0 = 0.2, e_1 = 0.4$

# %%
from run_nn import find_best_alpha

args = default_args.copy()
args.update({
    'dataset': 'german', 
    'e0': 0.2, 'e1': 0.4, 
    'equalize_prior': False, 
    'episodes': 3000, 
    'batchsize': 32, 
    'hidsize': [16, 16], 
    'lr': 0.0007, 
#     'alpha': 1.0,
})

find_best_alpha(args)
# Out:
# ---------------------------------
# | [PEER] alpha = 0.4 | 0.559    |
# | [PEER] alpha = 0.5 | 0.575    |
# | [PEER] alpha = 0.6 | 0.61     |
# | [PEER] alpha = 0.7 | 0.619    |
# | [PEER] alpha = 0.8 | 0.632    |
# | [PEER] alpha = 0.9 | 0.651    |
# | [PEER] alpha = 1.0 | 0.676    |
# | [PEER] alpha = 2.0 | 0.627    |
# | [PEER] alpha = 3.0 | 0.632    |
# | [PEER] alpha = 4.0 | 0.653    |
# | [PEER] alpha = 5.0 | 0.703    |
# ---------------------------------
# {'alpha': 5.0}

# %%
from run_nn import run

args = default_args.copy()
args.update({
    'dataset': 'german', 
    'e0': 0.2, 'e1': 0.4, 
    'equalize_prior': False, 
    'episodes': 3000, 
    'batchsize': 32, 
    'hidsize': [16, 16], 
    'lr': 0.0007, 
#     'alpha': 1.0,
})

run(args)
# Out:
# Logging to logs/nn/19-08-30-10-37-12
# {'dataset': 'german', 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'e0': 0.2, 'e1': 0.4, 'equalize_prior': False, 'episodes': 3000, 'batchsize': 32, 'hidsize': [16, 16], 'lr': 0.0007}
# ---------------------------------
# | [PEER] alpha = 0.4 | 0.526    |
# | [PEER] alpha = 0.5 | 0.536    |
# | [PEER] alpha = 0.6 | 0.532    |
# | [PEER] alpha = 0.7 | 0.522    |
# | [PEER] alpha = 0.8 | 0.522    |
# | [PEER] alpha = 0.9 | 0.526    |
# | [PEER] alpha = 1.0 | 0.533    |
# | [PEER] alpha = 2.0 | 0.498    |
# | [PEER] alpha = 3.0 | 0.498    |
# | [PEER] alpha = 4.0 | 0.485    |
# | [PEER] alpha = 5.0 | 0.481    |
# ---------------------------------
# --------------------------------------
# | [NN] with bce loss      | 0.535    |
# | [NN] with peer loss     | 0.575    |
# | [NN] with surrogate ... | 0.681    |
# | [PEER] best alpha       | 0.5      |
# --------------------------------------

# %%
from run_nn import find_best_alpha

args = default_args.copy()
args.update({
    'dataset': 'german', 
    'e0': 0.2, 'e1': 0.4, 
    'equalize_prior': False, 
    'episodes': 3000, 
    'batchsize': 32, 
    'hidsize': [16, 16], 
    'lr': 0.0007, 
#     'alpha': 1.0,
})

find_best_alpha(args)
# Out:
# ---------------------------------
# | [PEER] alpha = 0.1 | 0.533    |
# | [PEER] alpha = 0.2 | 0.541    |
# | [PEER] alpha = 0.3 | 0.552    |
# | [PEER] alpha = 0.4 | 0.559    |
# | [PEER] alpha = 0.5 | 0.575    |
# | [PEER] alpha = 0.6 | 0.61     |
# | [PEER] alpha = 0.7 | 0.619    |
# | [PEER] alpha = 0.8 | 0.632    |
# | [PEER] alpha = 0.9 | 0.651    |
# | [PEER] alpha = 1.0 | 0.676    |
# ---------------------------------
# {'alpha': 1.0}

# %%
from runner import run

args = default_args.copy()
args.update({
    'dataset': 'german', 
    'e0': 0.2, 'e1': 0.4, 
    'equalize_prior': False, 
    'episodes': 3000, 
#     'batchsize': 32, 
#     'hidsize': [32, 32], 
#     'lr': 0.001, 
#     'alpha': 1.0,
})

run(args)
# Out:
# Logging to logs/nn/19-08-28-15-04-19
# {'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'dataset': 'german', 'e0': 0.2, 'e1': 0.4, 'equalize_prior': False, 'episodes': 3000}
# acc:0.633	batchsize: 1	lr:0.0007	hidsize:[8, 8]
# acc:0.628	batchsize: 1	lr:0.0007	hidsize:[16, 16]
# acc:0.634	batchsize: 1	lr:0.0007	hidsize:[32, 32]
# acc:0.623	batchsize: 1	lr:0.0007	hidsize:[64, 64]
# acc:0.617	batchsize: 1	lr: 0.001	hidsize:[8, 8]
# acc:0.62	batchsize: 1	lr: 0.001	hidsize:[16, 16]
# acc:0.65	batchsize: 1	lr: 0.001	hidsize:[32, 32]
# acc:0.619	batchsize: 1	lr: 0.001	hidsize:[64, 64]
# acc:0.583	batchsize: 1	lr: 0.005	hidsize:[8, 8]
# acc:0.615	batchsize: 1	lr: 0.005	hidsize:[16, 16]
# acc:0.626	batchsize: 1	lr: 0.005	hidsize:[32, 32]
# acc:0.607	batchsize: 1	lr: 0.005	hidsize:[64, 64]
# acc:0.627	batchsize: 1	lr:  0.01	hidsize:[8, 8]
# acc:0.568	batchsize: 1	lr:  0.01	hidsize:[16, 16]
# acc:0.636	batchsize: 1	lr:  0.01	hidsize:[32, 32]
# acc:0.617	batchsize: 1	lr:  0.01	hidsize:[64, 64]
# acc:0.565	batchsize: 1	lr:  0.05	hidsize:[8, 8]
# acc:0.566	batchsize: 1	lr:  0.05	hidsize:[16, 16]
# acc:0.563	batchsize: 1	lr:  0.05	hidsize:[32, 32]
# acc:0.607	batchsize: 1	lr:  0.05	hidsize:[64, 64]
# acc:0.627	batchsize: 4	lr:0.0007	hidsize:[8, 8]
# acc:0.639	batchsize: 4	lr:0.0007	hidsize:[16, 16]
# acc:0.657	batchsize: 4	lr:0.0007	hidsize:[32, 32]
# acc:0.635	batchsize: 4	lr:0.0007	hidsize:[64, 64]
# acc:0.627	batchsize: 4	lr: 0.001	hidsize:[8, 8]
# acc:0.644	batchsize: 4	lr: 0.001	hidsize:[16, 16]
# acc:0.641	batchsize: 4	lr: 0.001	hidsize:[32, 32]
# acc:0.629	batchsize: 4	lr: 0.001	hidsize:[64, 64]
# acc:0.595	batchsize: 4	lr: 0.005	hidsize:[8, 8]
# acc:0.649	batchsize: 4	lr: 0.005	hidsize:[16, 16]
# acc:0.635	batchsize: 4	lr: 0.005	hidsize:[32, 32]
# acc:0.621	batchsize: 4	lr: 0.005	hidsize:[64, 64]
# acc:0.614	batchsize: 4	lr:  0.01	hidsize:[8, 8]
# acc:0.631	batchsize: 4	lr:  0.01	hidsize:[16, 16]
# acc:0.639	batchsize: 4	lr:  0.01	hidsize:[32, 32]
# acc:0.623	batchsize: 4	lr:  0.01	hidsize:[64, 64]
# acc:0.489	batchsize: 4	lr:  0.05	hidsize:[8, 8]
# acc:0.627	batchsize: 4	lr:  0.05	hidsize:[16, 16]
# acc:0.598	batchsize: 4	lr:  0.05	hidsize:[32, 32]
# acc:0.64	batchsize: 4	lr:  0.05	hidsize:[64, 64]
# acc:0.622	batchsize:16	lr:0.0007	hidsize:[8, 8]
# acc:0.669	batchsize:16	lr:0.0007	hidsize:[16, 16]
# acc:0.655	batchsize:16	lr:0.0007	hidsize:[32, 32]
# acc:0.646	batchsize:16	lr:0.0007	hidsize:[64, 64]
# acc:0.635	batchsize:16	lr: 0.001	hidsize:[8, 8]
# acc:0.667	batchsize:16	lr: 0.001	hidsize:[16, 16]
# acc:0.657	batchsize:16	lr: 0.001	hidsize:[32, 32]
# acc:0.65	batchsize:16	lr: 0.001	hidsize:[64, 64]
# acc:0.617	batchsize:16	lr: 0.005	hidsize:[8, 8]
# acc:0.649	batchsize:16	lr: 0.005	hidsize:[16, 16]
# acc:0.653	batchsize:16	lr: 0.005	hidsize:[32, 32]
# acc:0.66	batchsize:16	lr: 0.005	hidsize:[64, 64]
# acc:0.629	batchsize:16	lr:  0.01	hidsize:[8, 8]
# acc:0.609	batchsize:16	lr:  0.01	hidsize:[16, 16]
# acc:0.662	batchsize:16	lr:  0.01	hidsize:[32, 32]
# acc:0.653	batchsize:16	lr:  0.01	hidsize:[64, 64]
# acc:0.548	batchsize:16	lr:  0.05	hidsize:[8, 8]
# acc:0.635	batchsize:16	lr:  0.05	hidsize:[16, 16]
# acc:0.648	batchsize:16	lr:  0.05	hidsize:[32, 32]
# acc:0.647	batchsize:16	lr:  0.05	hidsize:[64, 64]
# acc:0.627	batchsize:32	lr:0.0007	hidsize:[8, 8]
# acc:0.676	batchsize:32	lr:0.0007	hidsize:[16, 16]
# acc:0.663	batchsize:32	lr:0.0007	hidsize:[32, 32]
# acc:0.662	batchsize:32	lr:0.0007	hidsize:[64, 64]
# acc:0.628	batchsize:32	lr: 0.001	hidsize:[8, 8]
# acc:0.67	batchsize:32	lr: 0.001	hidsize:[16, 16]
# acc:0.664	batchsize:32	lr: 0.001	hidsize:[32, 32]
# acc:0.653	batchsize:32	lr: 0.001	hidsize:[64, 64]
# acc:0.623	batchsize:32	lr: 0.005	hidsize:[8, 8]
# acc:0.647	batchsize:32	lr: 0.005	hidsize:[16, 16]
# acc:0.66	batchsize:32	lr: 0.005	hidsize:[32, 32]
# acc:0.653	batchsize:32	lr: 0.005	hidsize:[64, 64]
# acc:0.634	batchsize:32	lr:  0.01	hidsize:[8, 8]
# acc:0.641	batchsize:32	lr:  0.01	hidsize:[16, 16]
# acc:0.645	batchsize:32	lr:  0.01	hidsize:[32, 32]
# acc:0.643	batchsize:32	lr:  0.01	hidsize:[64, 64]
# acc:0.607	batchsize:32	lr:  0.05	hidsize:[8, 8]
# acc:0.64	batchsize:32	lr:  0.05	hidsize:[16, 16]
# acc:0.637	batchsize:32	lr:  0.05	hidsize:[32, 32]
# acc:0.646	batchsize:32	lr:  0.05	hidsize:[64, 64]
# acc:0.643	batchsize:64	lr:0.0007	hidsize:[8, 8]
# acc:0.658	batchsize:64	lr:0.0007	hidsize:[16, 16]
# acc:0.652	batchsize:64	lr:0.0007	hidsize:[32, 32]
# acc:0.643	batchsize:64	lr:0.0007	hidsize:[64, 64]
# acc:0.636	batchsize:64	lr: 0.001	hidsize:[8, 8]
# acc:0.65	batchsize:64	lr: 0.001	hidsize:[16, 16]
# acc:0.652	batchsize:64	lr: 0.001	hidsize:[32, 32]
# acc:0.643	batchsize:64	lr: 0.001	hidsize:[64, 64]
# acc:0.624	batchsize:64	lr: 0.005	hidsize:[8, 8]
# acc:0.647	batchsize:64	lr: 0.005	hidsize:[16, 16]
# acc:0.644	batchsize:64	lr: 0.005	hidsize:[32, 32]
# acc:0.649	batchsize:64	lr: 0.005	hidsize:[64, 64]
# acc:0.617	batchsize:64	lr:  0.01	hidsize:[8, 8]
# acc:0.643	batchsize:64	lr:  0.01	hidsize:[16, 16]
# acc:0.636	batchsize:64	lr:  0.01	hidsize:[32, 32]
# acc:0.646	batchsize:64	lr:  0.01	hidsize:[64, 64]
# acc:0.625	batchsize:64	lr:  0.05	hidsize:[8, 8]
# acc:0.629	batchsize:64	lr:  0.05	hidsize:[16, 16]
# acc:0.631	batchsize:64	lr:  0.05	hidsize:[32, 32]
# acc:0.636	batchsize:64	lr:  0.05	hidsize:[64, 64]
# --------------------------------------
# | [PEER] best batchsize   | 32       |
# | [PEER] best hidsize     | [16, 16] |
# | [PEER] best learning... | 0.0007   |
# --------------------------------------
# ---------------------------------
# | [PEER] alpha = 0.1 | 0.532    |
# | [PEER] alpha = 0.2 | 0.498    |
# | [PEER] alpha = 0.3 | 0.498    |
# | [PEER] alpha = 0.4 | 0.526    |
# | [PEER] alpha = 0.5 | 0.536    |
# | [PEER] alpha = 0.6 | 0.532    |
# | [PEER] alpha = 0.7 | 0.522    |
# | [PEER] alpha = 0.8 | 0.522    |
# | [PEER] alpha = 0.9 | 0.526    |
# | [PEER] alpha = 1.0 | 0.533    |
# ---------------------------------
# --------------------------------------
# | [NN] with bce loss      | 0.535    |
# | [NN] with peer loss     | 0.575    |
# | [NN] with surrogate ... | 0.681    |
# | [PEER] best alpha       | 0.5      |
# --------------------------------------
# Logging to logs/svm/19-08-28-15-30-15
# {'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'dataset': 'german', 'e0': 0.2, 'e1': 0.4, 'equalize_prior': False, 'episodes': 3000}
# --------------------------------
# | [C-SVM] C1 = 0.1  | 0.519    |
# | [C-SVM] C1 = 0.2  | 0.519    |
# | [C-SVM] C1 = 0.25 | 0.519    |
# | [C-SVM] C1 = 0.33 | 0.519    |
# | [C-SVM] C1 = 0.5  | 0.516    |
# | [C-SVM] C1 = 1.0  | 0.547    |
# | [C-SVM] C1 = 10.0 | 0.507    |
# | [C-SVM] C1 = 2.0  | 0.509    |
# | [C-SVM] C1 = 3.0  | 0.507    |
# | [C-SVM] C1 = 4.0  | 0.506    |
# | [C-SVM] C1 = 5.0  | 0.507    |
# --------------------------------
# ------------------------------------
# | [C-SVM] accuracy max  | 0.647    |
# | [C-SVM] accuracy mean | 0.581    |
# | [C-SVM] accuracy min  | 0.533    |
# | [C-SVM] accuracy std  | 0.036    |
# | [C-SVM] best C1       | 1        |
# ------------------------------------
# Logging to logs/pam/19-08-28-15-30-16
# {'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'dataset': 'german', 'e0': 0.2, 'e1': 0.4, 'equalize_prior': False, 'episodes': 3000}
# -----------------------------------
# | [PAM] margin = 0     | 0.531    |
# | [PAM] margin = 0.125 | 0.535    |
# | [PAM] margin = 0.25  | 0.528    |
# | [PAM] margin = 0.5   | 0.54     |
# | [PAM] margin = 1     | 0.538    |
# -----------------------------------
# ----------------------------------
# | [PAM] accuracy max  | 0.68     |
# | [PAM] accuracy mean | 0.602    |
# | [PAM] accuracy min  | 0.527    |
# | [PAM] accuracy std  | 0.0516   |
# | [PAM] best margin   | 0.5      |
# ----------------------------------

# %% [markdown]
# ### $e_0=0.4, e_1=0.4$

# %%
from run_nn import find_best_alpha

args = default_args.copy()
args.update({
    'dataset': 'german', 
    'e0': 0.4, 'e1': 0.4, 
    'equalize_prior': False, 
    'episodes': 2000, 
    'batchsize': 16, 
    'hidsize': [32, 32], 
    'lr': 0.01, 
#     'alpha': 1.0,
})

find_best_alpha(args)
# Out:
# ---------------------------------
# | [PEER] alpha = 0.4 | 0.573    |
# | [PEER] alpha = 0.5 | 0.59     |
# | [PEER] alpha = 0.6 | 0.578    |
# | [PEER] alpha = 0.7 | 0.604    |
# | [PEER] alpha = 0.8 | 0.606    |
# | [PEER] alpha = 0.9 | 0.619    |
# | [PEER] alpha = 1.0 | 0.654    |
# | [PEER] alpha = 2.0 | 0.567    |
# | [PEER] alpha = 3.0 | 0.542    |
# | [PEER] alpha = 4.0 | 0.522    |
# | [PEER] alpha = 5.0 | 0.512    |
# ---------------------------------
# {'alpha': 1.0}

# %%
from run_nn import find_best_alpha

args = default_args.copy()
args.update({
    'dataset': 'german', 
    'e0': 0.4, 'e1': 0.4, 
    'equalize_prior': False, 
    'episodes': 2000, 
    'batchsize': 16, 
    'hidsize': [32, 32], 
    'lr': 0.01, 
#     'alpha': 1.0,
})

find_best_alpha(args)
# Out:
# ---------------------------------
# | [PEER] alpha = 0.1 | 0.555    |
# | [PEER] alpha = 0.2 | 0.555    |
# | [PEER] alpha = 0.3 | 0.542    |
# | [PEER] alpha = 0.4 | 0.573    |
# | [PEER] alpha = 0.5 | 0.59     |
# | [PEER] alpha = 0.6 | 0.578    |
# | [PEER] alpha = 0.7 | 0.604    |
# | [PEER] alpha = 0.8 | 0.606    |
# | [PEER] alpha = 0.9 | 0.619    |
# | [PEER] alpha = 1.0 | 0.654    |
# ---------------------------------
# {'alpha': 1.0}

# %%
from runner import run

args = default_args.copy()
args.update({
    'dataset': 'german', 
    'e0': 0.4, 'e1': 0.4, 
    'equalize_prior': False, 
    'episodes': 2000, 
#     'batchsize': 16, 
#     'hidsize': [32, 32], 
#     'lr': 0.001, 
#     'alpha': 1.0,
})
run(args)
# Out:
# Logging to logs/nn/19-08-28-14-46-47
# {'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'dataset': 'german', 'e0': 0.4, 'e1': 0.4, 'equalize_prior': False, 'episodes': 2000}
# acc:0.589	batchsize: 1	lr:0.0007	hidsize:[8, 8]
# acc:0.543	batchsize: 1	lr:0.0007	hidsize:[16, 16]
# acc:0.598	batchsize: 1	lr:0.0007	hidsize:[32, 32]
# acc:0.593	batchsize: 1	lr:0.0007	hidsize:[64, 64]
# acc:0.592	batchsize: 1	lr: 0.001	hidsize:[8, 8]
# acc:0.537	batchsize: 1	lr: 0.001	hidsize:[16, 16]
# acc:0.603	batchsize: 1	lr: 0.001	hidsize:[32, 32]
# acc:0.601	batchsize: 1	lr: 0.001	hidsize:[64, 64]
# acc:0.569	batchsize: 1	lr: 0.005	hidsize:[8, 8]
# acc:0.581	batchsize: 1	lr: 0.005	hidsize:[16, 16]
# acc:0.603	batchsize: 1	lr: 0.005	hidsize:[32, 32]
# acc:0.562	batchsize: 1	lr: 0.005	hidsize:[64, 64]
# acc:0.603	batchsize: 1	lr:  0.01	hidsize:[8, 8]
# acc:0.561	batchsize: 1	lr:  0.01	hidsize:[16, 16]
# acc:0.571	batchsize: 1	lr:  0.01	hidsize:[32, 32]
# acc:0.603	batchsize: 1	lr:  0.01	hidsize:[64, 64]
# acc:0.592	batchsize: 1	lr:  0.05	hidsize:[8, 8]
# acc:0.622	batchsize: 1	lr:  0.05	hidsize:[16, 16]
# acc:0.566	batchsize: 1	lr:  0.05	hidsize:[32, 32]
# acc:0.569	batchsize: 1	lr:  0.05	hidsize:[64, 64]
# acc:0.577	batchsize: 4	lr:0.0007	hidsize:[8, 8]
# acc:0.584	batchsize: 4	lr:0.0007	hidsize:[16, 16]
# acc:0.608	batchsize: 4	lr:0.0007	hidsize:[32, 32]
# acc:0.606	batchsize: 4	lr:0.0007	hidsize:[64, 64]
# acc:0.565	batchsize: 4	lr: 0.001	hidsize:[8, 8]
# acc:0.587	batchsize: 4	lr: 0.001	hidsize:[16, 16]
# acc:0.604	batchsize: 4	lr: 0.001	hidsize:[32, 32]
# acc:0.594	batchsize: 4	lr: 0.001	hidsize:[64, 64]
# acc:0.577	batchsize: 4	lr: 0.005	hidsize:[8, 8]
# acc:0.593	batchsize: 4	lr: 0.005	hidsize:[16, 16]
# acc:0.607	batchsize: 4	lr: 0.005	hidsize:[32, 32]
# acc:0.603	batchsize: 4	lr: 0.005	hidsize:[64, 64]
# acc:0.586	batchsize: 4	lr:  0.01	hidsize:[8, 8]
# acc:0.622	batchsize: 4	lr:  0.01	hidsize:[16, 16]
# acc:0.605	batchsize: 4	lr:  0.01	hidsize:[32, 32]
# acc:0.59	batchsize: 4	lr:  0.01	hidsize:[64, 64]
# acc:0.574	batchsize: 4	lr:  0.05	hidsize:[8, 8]
# acc:0.614	batchsize: 4	lr:  0.05	hidsize:[16, 16]
# acc:0.575	batchsize: 4	lr:  0.05	hidsize:[32, 32]
# acc:0.601	batchsize: 4	lr:  0.05	hidsize:[64, 64]
# acc:0.593	batchsize:16	lr:0.0007	hidsize:[8, 8]
# acc:0.611	batchsize:16	lr:0.0007	hidsize:[16, 16]
# acc:0.616	batchsize:16	lr:0.0007	hidsize:[32, 32]
# acc:0.617	batchsize:16	lr:0.0007	hidsize:[64, 64]
# acc:0.605	batchsize:16	lr: 0.001	hidsize:[8, 8]
# acc:0.615	batchsize:16	lr: 0.001	hidsize:[16, 16]
# acc:0.614	batchsize:16	lr: 0.001	hidsize:[32, 32]
# acc:0.618	batchsize:16	lr: 0.001	hidsize:[64, 64]
# acc:0.628	batchsize:16	lr: 0.005	hidsize:[8, 8]
# acc:0.61	batchsize:16	lr: 0.005	hidsize:[16, 16]
# acc:0.628	batchsize:16	lr: 0.005	hidsize:[32, 32]
# acc:0.626	batchsize:16	lr: 0.005	hidsize:[64, 64]
# acc:0.608	batchsize:16	lr:  0.01	hidsize:[8, 8]
# acc:0.618	batchsize:16	lr:  0.01	hidsize:[16, 16]
# acc:0.654	batchsize:16	lr:  0.01	hidsize:[32, 32]
# acc:0.624	batchsize:16	lr:  0.01	hidsize:[64, 64]
# acc:0.644	batchsize:16	lr:  0.05	hidsize:[8, 8]
# acc:0.633	batchsize:16	lr:  0.05	hidsize:[16, 16]
# acc:0.614	batchsize:16	lr:  0.05	hidsize:[32, 32]
# acc:0.617	batchsize:16	lr:  0.05	hidsize:[64, 64]
# acc:0.578	batchsize:32	lr:0.0007	hidsize:[8, 8]
# acc:0.617	batchsize:32	lr:0.0007	hidsize:[16, 16]
# acc:0.632	batchsize:32	lr:0.0007	hidsize:[32, 32]
# acc:0.613	batchsize:32	lr:0.0007	hidsize:[64, 64]
# acc:0.577	batchsize:32	lr: 0.001	hidsize:[8, 8]
# acc:0.619	batchsize:32	lr: 0.001	hidsize:[16, 16]
# acc:0.643	batchsize:32	lr: 0.001	hidsize:[32, 32]
# acc:0.614	batchsize:32	lr: 0.001	hidsize:[64, 64]
# acc:0.611	batchsize:32	lr: 0.005	hidsize:[8, 8]
# acc:0.611	batchsize:32	lr: 0.005	hidsize:[16, 16]
# acc:0.624	batchsize:32	lr: 0.005	hidsize:[32, 32]
# acc:0.608	batchsize:32	lr: 0.005	hidsize:[64, 64]
# acc:0.623	batchsize:32	lr:  0.01	hidsize:[8, 8]
# acc:0.618	batchsize:32	lr:  0.01	hidsize:[16, 16]
# acc:0.618	batchsize:32	lr:  0.01	hidsize:[32, 32]
# acc:0.606	batchsize:32	lr:  0.01	hidsize:[64, 64]
# acc:0.62	batchsize:32	lr:  0.05	hidsize:[8, 8]
# acc:0.602	batchsize:32	lr:  0.05	hidsize:[16, 16]
# acc:0.593	batchsize:32	lr:  0.05	hidsize:[32, 32]
# acc: 0.6	batchsize:32	lr:  0.05	hidsize:[64, 64]
# acc:0.582	batchsize:64	lr:0.0007	hidsize:[8, 8]
# acc:0.608	batchsize:64	lr:0.0007	hidsize:[16, 16]
# acc:0.621	batchsize:64	lr:0.0007	hidsize:[32, 32]
# acc:0.612	batchsize:64	lr:0.0007	hidsize:[64, 64]
# acc:0.584	batchsize:64	lr: 0.001	hidsize:[8, 8]
# acc:0.606	batchsize:64	lr: 0.001	hidsize:[16, 16]
# acc:0.624	batchsize:64	lr: 0.001	hidsize:[32, 32]
# acc:0.608	batchsize:64	lr: 0.001	hidsize:[64, 64]
# acc:0.612	batchsize:64	lr: 0.005	hidsize:[8, 8]
# acc:0.603	batchsize:64	lr: 0.005	hidsize:[16, 16]
# acc:0.613	batchsize:64	lr: 0.005	hidsize:[32, 32]
# acc:0.613	batchsize:64	lr: 0.005	hidsize:[64, 64]
# acc:0.601	batchsize:64	lr:  0.01	hidsize:[8, 8]
# acc:0.594	batchsize:64	lr:  0.01	hidsize:[16, 16]
# acc:0.612	batchsize:64	lr:  0.01	hidsize:[32, 32]
# acc:0.624	batchsize:64	lr:  0.01	hidsize:[64, 64]
# acc:0.598	batchsize:64	lr:  0.05	hidsize:[8, 8]
# acc:0.602	batchsize:64	lr:  0.05	hidsize:[16, 16]
# acc:0.592	batchsize:64	lr:  0.05	hidsize:[32, 32]
# acc:0.622	batchsize:64	lr:  0.05	hidsize:[64, 64]
# --------------------------------------
# | [PEER] best batchsize   | 16       |
# | [PEER] best hidsize     | [32, 32] |
# | [PEER] best learning... | 0.01     |
# --------------------------------------
# ---------------------------------
# | [PEER] alpha = 0.1 | 0.532    |
# | [PEER] alpha = 0.2 | 0.475    |
# | [PEER] alpha = 0.3 | 0.485    |
# | [PEER] alpha = 0.4 | 0.509    |
# | [PEER] alpha = 0.5 | 0.501    |
# | [PEER] alpha = 0.6 | 0.488    |
# | [PEER] alpha = 0.7 | 0.517    |
# | [PEER] alpha = 0.8 | 0.516    |
# | [PEER] alpha = 0.9 | 0.489    |
# | [PEER] alpha = 1.0 | 0.488    |
# ---------------------------------
# --------------------------------------
# | [NN] with bce loss      | 0.553    |
# | [NN] with peer loss     | 0.555    |
# | [NN] with surrogate ... | 0.632    |
# | [PEER] best alpha       | 0.1      |
# --------------------------------------
# Logging to logs/svm/19-08-28-15-04-06
# {'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'dataset': 'german', 'e0': 0.4, 'e1': 0.4, 'equalize_prior': False, 'episodes': 2000}
# --------------------------------
# | [C-SVM] C1 = 0.1  | 0.46     |
# | [C-SVM] C1 = 0.2  | 0.46     |
# | [C-SVM] C1 = 0.25 | 0.46     |
# | [C-SVM] C1 = 0.33 | 0.46     |
# | [C-SVM] C1 = 0.5  | 0.46     |
# | [C-SVM] C1 = 1.0  | 0.519    |
# | [C-SVM] C1 = 10.0 | 0.537    |
# | [C-SVM] C1 = 2.0  | 0.538    |
# | [C-SVM] C1 = 3.0  | 0.538    |
# | [C-SVM] C1 = 4.0  | 0.537    |
# | [C-SVM] C1 = 5.0  | 0.537    |
# --------------------------------
# ------------------------------------
# | [C-SVM] accuracy max  | 0.767    |
# | [C-SVM] accuracy mean | 0.696    |
# | [C-SVM] accuracy min  | 0.64     |
# | [C-SVM] accuracy std  | 0.044    |
# | [C-SVM] best C1       | 2        |
# ------------------------------------
# Logging to logs/pam/19-08-28-15-04-07
# {'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'dataset': 'german', 'e0': 0.4, 'e1': 0.4, 'equalize_prior': False, 'episodes': 2000}
# -----------------------------------
# | [PAM] margin = 0     | 0.502    |
# | [PAM] margin = 0.125 | 0.502    |
# | [PAM] margin = 0.25  | 0.521    |
# | [PAM] margin = 0.5   | 0.515    |
# | [PAM] margin = 1     | 0.522    |
# -----------------------------------
# ----------------------------------
# | [PAM] accuracy max  | 0.7      |
# | [PAM] accuracy mean | 0.64     |
# | [PAM] accuracy min  | 0.593    |
# | [PAM] accuracy std  | 0.0359   |
# | [PAM] best margin   | 1        |
# ----------------------------------

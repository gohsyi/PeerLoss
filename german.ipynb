# %% [markdown]
# # German Dataset

# %% [markdown]
# ## Describe
#
# | Total | Positive | Attributes | Normalized |
# |:-----:|:--------:|:----------:|:----------:|
# | 1000  |    70%   |     23     |     Not    |

# %%
from utils.dataloader import DataLoader

df = DataLoader('german').df
df.target.describe()
# Out:
# count    1000.000000
# mean        0.700000
# std         0.458487
# min         0.000000
# 25%         0.000000
# 50%         1.000000
# 75%         1.000000
# max         1.000000
# Name: target, dtype: float64

# %%
df.describe()
# Out:
#                  0            1           2            3            4  \
# count  1000.000000  1000.000000  1000.00000  1000.000000  1000.000000
# mean      2.577000    20.903000     2.54500    32.711000     2.105000
# std       1.257638    12.058814     1.08312    28.252605     1.580023
# min       1.000000     4.000000     0.00000     2.000000     1.000000
# 25%       1.000000    12.000000     2.00000    14.000000     1.000000
# 50%       2.000000    18.000000     2.00000    23.000000     1.000000
# 75%       4.000000    24.000000     4.00000    40.000000     3.000000
# max       4.000000    72.000000     4.00000   184.000000     5.000000
#
#                  5           6            7            8            9  ...  \
# count  1000.000000  1000.00000  1000.000000  1000.000000  1000.000000  ...
# mean      3.384000     2.68200     2.845000     2.358000    35.546000  ...
# std       1.208306     0.70808     1.103718     1.050209    11.375469  ...
# min       1.000000     1.00000     1.000000     1.000000    19.000000  ...
# 25%       3.000000     2.00000     2.000000     1.000000    27.000000  ...
# 50%       3.000000     3.00000     3.000000     2.000000    33.000000  ...
# 75%       5.000000     3.00000     4.000000     3.000000    42.000000  ...
# max       5.000000     4.00000     4.000000     4.000000    75.000000  ...
#
#                 15           16           17           18           19  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.000000
# mean      0.234000     0.103000     0.907000     0.041000     0.179000
# std       0.423584     0.304111     0.290578     0.198389     0.383544
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.000000     0.000000     1.000000     0.000000     0.000000
# 50%       0.000000     0.000000     1.000000     0.000000     0.000000
# 75%       0.000000     0.000000     1.000000     0.000000     0.000000
# max       1.000000     1.000000     1.000000     1.000000     1.000000
#
#                 20           21         22           23       target
# count  1000.000000  1000.000000  1000.0000  1000.000000  1000.000000
# mean      0.713000     0.022000     0.2000     0.630000     0.700000
# std       0.452588     0.146757     0.4002     0.483046     0.458487
# min       0.000000     0.000000     0.0000     0.000000     0.000000
# 25%       0.000000     0.000000     0.0000     0.000000     0.000000
# 50%       1.000000     0.000000     0.0000     1.000000     1.000000
# 75%       1.000000     0.000000     0.0000     1.000000     1.000000
# max       1.000000     1.000000     1.0000     1.000000     1.000000
#
# [8 rows x 25 columns]

# %% [markdown]
# ## With prior equalization

# %%
from runner import run

arg_dict = {
    'dataset': 'german', 
    'lr': 0.001, 
    'hidsize': 8, 
    'episodes': 150, 
    'batchsize': 10, 
    'test_size': 0.25,
    'dropout': 0,
    'normalize': True,
    'equalize_prior': True
}

# %% [markdown]
# $e_0 = 0, e_1 = 0$

# %%
arg_dict.update({'e0': 0, 'e1': 0})
run(arg_dict.copy())
# Out:
# {'dataset': 'german', 'lr': 0.001, 'hidsize': 8, 'episodes': 150, 'batchsize': 10, 'test_size': 0.25, 'dropout': 0, 'normalize': True, 'equalize_prior': True, 'e0': 0, 'e1': 0}
# --------------------------------------
# | knn                     | 0.649    |
# | logistic regression     | 0.71     |
# | nn                      | 0.713    |
# | nn with peer prediction | 0.717    |
# | random forest           | 0.711    |
# | svm                     | 0.705    |
# --------------------------------------

# %% [markdown]
# $e_0 = 0.2, e_1 = 0.2$

# %%
arg_dict.update({'e0': 0.2, 'e1': 0.2})
run(arg_dict.copy())
# Out:
# {'dataset': 'german', 'lr': 0.001, 'hidsize': 8, 'episodes': 150, 'batchsize': 10, 'test_size': 0.25, 'dropout': 0, 'normalize': True, 'equalize_prior': True, 'e0': 0.2, 'e1': 0.2}
# --------------------------------------
# | knn                     | 0.601    |
# | logistic regression     | 0.683    |
# | nn                      | 0.675    |
# | nn with peer prediction | 0.691    |
# | random forest           | 0.664    |
# | svm                     | 0.666    |
# --------------------------------------

# %% [markdown]
# $e_0 = 0.1, e_1 = 0.3$

# %%
arg_dict.update({'e0': 0.1, 'e1': 0.3})
run(arg_dict.copy())
# Out:
# {'dataset': 'german', 'lr': 0.001, 'hidsize': 8, 'episodes': 150, 'batchsize': 10, 'test_size': 0.25, 'dropout': 0, 'normalize': True, 'equalize_prior': True, 'e0': 0.1, 'e1': 0.3}
# --------------------------------------
# | knn                     | 0.601    |
# | logistic regression     | 0.656    |
# | nn                      | 0.657    |
# | nn with peer prediction | 0.692    |
# | random forest           | 0.624    |
# | svm                     | 0.632    |
# --------------------------------------

# %% [markdown]
# $e_0 = 0.2, e_1 = 0.4$

# %%
arg_dict.update({'e0': 0.2, 'e1': 0.4})
run(arg_dict.copy())
# Out:
# {'dataset': 'german', 'lr': 0.001, 'hidsize': 8, 'episodes': 150, 'batchsize': 10, 'test_size': 0.25, 'dropout': 0, 'normalize': True, 'equalize_prior': True, 'e0': 0.2, 'e1': 0.4}
# --------------------------------------
# | knn                     | 0.568    |
# | logistic regression     | 0.616    |
# | nn                      | 0.615    |
# | nn with peer prediction | 0.667    |
# | random forest           | 0.595    |
# | svm                     | 0.585    |
# --------------------------------------

# %% [markdown]
# $e_0 = 0.4, e_1 = 0.4$

# %%
arg_dict.update({'e0': 0.4, 'e1': 0.4})
run(arg_dict.copy())
# Out:
# {'dataset': 'german', 'lr': 0.001, 'hidsize': 8, 'episodes': 150, 'batchsize': 10, 'test_size': 0.25, 'dropout': 0, 'normalize': True, 'equalize_prior': True, 'e0': 0.4, 'e1': 0.4}
# --------------------------------------
# | knn                     | 0.537    |
# | logistic regression     | 0.59     |
# | nn                      | 0.585    |
# | nn with peer prediction | 0.604    |
# | random forest           | 0.554    |
# | svm                     | 0.575    |
# --------------------------------------

# %% [markdown]
# ## No prior equalization

# %%
from runner import run

arg_dict = {
    'dataset': 'german', 
    'lr': 0.001, 
    'hidsize': 8, 
    'episodes': 150, 
    'batchsize': 10, 
    'test_size': 0.25,
    'dropout': 0,
    'normalize': True,
    'equalize_prior': False
}

# %% [markdown]
# $e_0 = 0, e_1 = 0$

# %%
arg_dict.update({'e0': 0, 'e1': 0})
run(arg_dict.copy())
# Out:
# {'dataset': 'german', 'lr': 0.001, 'hidsize': 8, 'episodes': 150, 'batchsize': 10, 'test_size': 0.25, 'dropout': 0, 'normalize': True, 'equalize_prior': False, 'e0': 0, 'e1': 0}
# --------------------------------------
# | knn                     | 0.708    |
# | logistic regression     | 0.766    |
# | nn                      | 0.757    |
# | nn with peer prediction | 0.704    |
# | random forest           | 0.757    |
# | svm                     | 0.755    |
# --------------------------------------

# %% [markdown]
# $e_0 = 0.2, e_1 = 0.2$

# %%
arg_dict.update({'e0': 0.2, 'e1': 0.2})
run(arg_dict.copy())
# Out:
# {'dataset': 'german', 'lr': 0.001, 'hidsize': 8, 'episodes': 150, 'batchsize': 10, 'test_size': 0.25, 'dropout': 0, 'normalize': True, 'equalize_prior': False, 'e0': 0.2, 'e1': 0.2}
# --------------------------------------
# | knn                     | 0.658    |
# | logistic regression     | 0.737    |
# | nn                      | 0.731    |
# | nn with peer prediction | 0.68     |
# | random forest           | 0.717    |
# | svm                     | 0.726    |
# --------------------------------------

# %% [markdown]
# $e_0 = 0.1, e_1 = 0.3$

# %%
arg_dict.update({'e0': 0.1, 'e1': 0.3})
run(arg_dict.copy())
# Out:
# {'dataset': 'german', 'lr': 0.001, 'hidsize': 8, 'episodes': 150, 'batchsize': 10, 'test_size': 0.25, 'dropout': 0, 'normalize': True, 'equalize_prior': False, 'e0': 0.1, 'e1': 0.3}
# --------------------------------------
# | knn                     | 0.595    |
# | logistic regression     | 0.686    |
# | nn                      | 0.695    |
# | nn with peer prediction | 0.668    |
# | random forest           | 0.659    |
# | svm                     | 0.683    |
# --------------------------------------

# %% [markdown]
# $e_0 = 0.2, e_1 = 0.4$

# %%
arg_dict.update({'e0': 0.2, 'e1': 0.4})
run(arg_dict.copy())
# Out:
# {'dataset': 'german', 'lr': 0.001, 'hidsize': 8, 'episodes': 150, 'batchsize': 10, 'test_size': 0.25, 'dropout': 0, 'normalize': True, 'equalize_prior': False, 'e0': 0.2, 'e1': 0.4}
# --------------------------------------
# | knn                     | 0.544    |
# | logistic regression     | 0.609    |
# | nn                      | 0.617    |
# | nn with peer prediction | 0.651    |
# | random forest           | 0.575    |
# | svm                     | 0.592    |
# --------------------------------------

# %% [markdown]
# $e_0 = 0.4, e_1 = 0.4$

# %%
arg_dict.update({'e0': 0.4, 'e1': 0.4})
run(arg_dict.copy())
# Out:
# {'dataset': 'german', 'lr': 0.001, 'hidsize': 8, 'episodes': 150, 'batchsize': 10, 'test_size': 0.25, 'dropout': 0, 'normalize': True, 'equalize_prior': False, 'e0': 0.4, 'e1': 0.4}
# --------------------------------------
# | knn                     | 0.561    |
# | logistic regression     | 0.643    |
# | nn                      | 0.673    |
# | nn with peer prediction | 0.598    |
# | random forest           | 0.598    |
# | svm                     | 0.636    |
# --------------------------------------

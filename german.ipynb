# %% [markdown]
# # German Credit Dataset

# %%
from runner import run

arg_dict = {
    'dataset': 'german', 
    'lr': 0.001, 
    'hidsize': 8, 
    'episodes': 100, 
    'batchsize': 10, 
}

# %% [markdown]
# ### $e_0=0, e_1=0$

# %%
arg_dict.update({'e0': 0, 'e1': 0})
run(arg_dict.copy())
# Out:
# {'dataset': 'german', 'lr': 0.001, 'hidsize': 8, 'episodes': 100, 'batchsize': 10, 'e0': 0, 'e1': 0}
# --------------------------------------
# | knn                     | 0.647    |
# | logistic regression     | 0.713    |
# | nn with bce             | 0.703    |
# | nn with peer prediction | 0.708    |
# | random forest           | 0.68     |
# | svm                     | 0.693    |
# --------------------------------------

# %% [markdown]
# ### $e_0=0.1$, $e_1=0.3$

# %%
arg_dict.update({'e0': 0.1, 'e1': 0.3})
run(arg_dict.copy())
# Out:
# {'dataset': 'german', 'lr': 0.001, 'hidsize': 8, 'episodes': 100, 'batchsize': 10, 'e0': 0.1, 'e1': 0.3}
# --------------------------------------
# | knn                     | 0.593    |
# | logistic regression     | 0.64     |
# | nn with bce             | 0.651    |
# | nn with peer prediction | 0.658    |
# | random forest           | 0.66     |
# | svm                     | 0.62     |
# --------------------------------------

# %% [markdown]
# ### $e_0=0.2$, $e_1=0.4$

# %%
arg_dict.update({'e0': 0.2, 'e1': 0.4})
run(arg_dict.copy())
# Out:
# {'dataset': 'german', 'lr': 0.001, 'hidsize': 8, 'episodes': 100, 'batchsize': 10, 'e0': 0.2, 'e1': 0.4}
# --------------------------------------
# | knn                     | 0.553    |
# | logistic regression     | 0.5      |
# | nn with bce             | 0.614    |
# | nn with peer prediction | 0.616    |
# | random forest           | 0.567    |
# | svm                     | 0.533    |
# --------------------------------------

# %% [markdown]
# ### $e_0 = 0.4$, $e_1 = 0.4$

# %%
arg_dict.update({'e0': 0.4, 'e1': 0.4})
run(arg_dict.copy())
# Out:
# {'dataset': 'german', 'lr': 0.001, 'hidsize': 8, 'episodes': 100, 'batchsize': 10, 'e0': 0.4, 'e1': 0.4}
# --------------------------------------
# | knn                     | 0.547    |
# | logistic regression     | 0.54     |
# | nn with bce             | 0.594    |
# | nn with peer prediction | 0.59     |
# | random forest           | 0.593    |
# | svm                     | 0.56     |
# --------------------------------------

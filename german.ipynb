# %% [markdown]
# # German Credit Dataset

# %%
from runner import run

arg_dict = {
    'dataset': 'german', 
    'lr': 0.001, 
    'hidsize': 8, 
    'episodes': 100, 
    'batchsize': 10, 
    'test_size': 0.25,
    'dropout': 0
}

# %% [markdown]
# $e_0 = 0, e_1 = 0$

# %%
arg_dict.update({'e0': 0, 'e1': 0})
run(arg_dict.copy())
# Out:
# {'dataset': 'german', 'lr': 0.001, 'hidsize': 8, 'episodes': 100, 'batchsize': 10, 'test_size': 0.25, 'dropout': 0, 'e0': 0, 'e1': 0}
# --------------------------------------
# | knn                     | 0.725    |
# | logistic regression     | 0.797    |
# | nn                      | 0.807    |
# | nn with peer prediction | 0.801    |
# | random forest           | 0.783    |
# | svm                     | 0.768    |
# --------------------------------------

# %% [markdown]
# $e_0 = 0.2, e_1 = 0.2$

# %%
arg_dict.update({'e0': 0.2, 'e1': 0.2})
run(arg_dict.copy())
# Out:
# {'dataset': 'german', 'lr': 0.001, 'hidsize': 8, 'episodes': 100, 'batchsize': 10, 'test_size': 0.25, 'dropout': 0, 'e0': 0.2, 'e1': 0.2}
# --------------------------------------
# | knn                     | 0.768    |
# | logistic regression     | 0.87     |
# | nn                      | 0.784    |
# | nn with peer prediction | 0.797    |
# | random forest           | 0.812    |
# | svm                     | 0.826    |
# --------------------------------------

# %% [markdown]
# $e_0 = 0.1, e_1 = 0.3$

# %%
arg_dict.update({'e0': 0.1, 'e1': 0.3})
run(arg_dict.copy())
# Out:
# {'dataset': 'german', 'lr': 0.001, 'hidsize': 8, 'episodes': 100, 'batchsize': 10, 'test_size': 0.25, 'dropout': 0, 'e0': 0.1, 'e1': 0.3}
# --------------------------------------
# | knn                     | 0.681    |
# | logistic regression     | 0.739    |
# | nn                      | 0.765    |
# | nn with peer prediction | 0.797    |
# | random forest           | 0.855    |
# | svm                     | 0.783    |
# --------------------------------------

# %% [markdown]
# $e_0 = 0.2, e_1 = 0.4$

# %%
arg_dict.update({'e0': 0.2, 'e1': 0.4})
run(arg_dict.copy())
# Out:
# {'dataset': 'german', 'lr': 0.001, 'hidsize': 8, 'episodes': 100, 'batchsize': 10, 'test_size': 0.25, 'dropout': 0, 'e0': 0.2, 'e1': 0.4}
# --------------------------------------
# | knn                     | 0.594    |
# | logistic regression     | 0.696    |
# | nn                      | 0.707    |
# | nn with peer prediction | 0.784    |
# | random forest           | 0.681    |
# | svm                     | 0.638    |
# --------------------------------------

# %% [markdown]
# $e_0 = 0.4, e_1 = 0.4$

# %%
arg_dict.update({'e0': 0.4, 'e1': 0.4})
run(arg_dict.copy())
# Out:
# {'dataset': 'german', 'lr': 0.001, 'hidsize': 8, 'episodes': 100, 'batchsize': 10, 'test_size': 0.25, 'dropout': 0, 'e0': 0.4, 'e1': 0.4}
# --------------------------------------
# | knn                     | 0.652    |
# | logistic regression     | 0.638    |
# | nn                      | 0.688    |
# | nn with peer prediction | 0.719    |
# | random forest           | 0.623    |
# | svm                     | 0.623    |
# --------------------------------------

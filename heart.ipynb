# %% [markdown]
# # Heart (13,165,138)

# %% [markdown]
# ## Describe
#
# | Total | Positive | Attributes | Normalized |
# |:-----:|:--------:|:----------:|:----------:|
# |  303  |   54.5%  |     13     |     Not    |

# %%
default_args = {
    'dataset': 'heart',
    'test_size': 0.15,
    'val_size': 0.1,
    'dropout': 0, 
    'normalize': True,
    'loss': 'bce',
    'activation': 'relu',
    'verbose': True,
}

# %% [markdown]
# ## With Prior Equalization

# %% [markdown]
# ### $e_0 = 0.1, e_1 = 0.3$

# %%
from runner import run
args = default_args.copy()
args.update({
    'e0': 0.1, 'e1': 0.3, 
    'equalize_prior': True, 
    'episodes': 1000, 
    'batchsize': 64, 
    'hidsize': [8, 8], 
    'lr': 0.0007, 
    'alpha': 1.
})
run(args)
# Out:
# Logging to logs/nn/19-08-30-15-38-23
# {'dataset': 'heart', 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'e0': 0.1, 'e1': 0.3, 'equalize_prior': True, 'episodes': 1000, 'batchsize': 64, 'hidsize': [8, 8], 'lr': 0.0007, 'alpha': 1.0}
# --------------------------------------
# | [NN] with bce loss      | 0.756    |
# | [NN] with peer loss     | 0.833    |
# | [NN] with surrogate ... | 0.78     |
# --------------------------------------
# Logging to logs/svm/19-08-30-15-38-29
# {'dataset': 'heart', 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'e0': 0.1, 'e1': 0.3, 'equalize_prior': True, 'episodes': 1000, 'batchsize': 64, 'hidsize': [8, 8], 'lr': 0.0007, 'alpha': 1.0}
# --------------------------------
# | [C-SVM] C1 = 0.1  | 0.562    |
# | [C-SVM] C1 = 0.2  | 0.562    |
# | [C-SVM] C1 = 0.25 | 0.562    |
# | [C-SVM] C1 = 0.33 | 0.562    |
# | [C-SVM] C1 = 0.5  | 0.598    |
# | [C-SVM] C1 = 1.0  | 0.665    |
# | [C-SVM] C1 = 10.0 | 0.603    |
# | [C-SVM] C1 = 2.0  | 0.661    |
# | [C-SVM] C1 = 3.0  | 0.634    |
# | [C-SVM] C1 = 4.0  | 0.621    |
# | [C-SVM] C1 = 5.0  | 0.621    |
# --------------------------------
# ------------------------------------
# | [C-SVM] accuracy max  | 0.81     |
# | [C-SVM] accuracy mean | 0.753    |
# | [C-SVM] accuracy min  | 0.619    |
# | [C-SVM] accuracy std  | 0.0629   |
# | [C-SVM] best C1       | 1        |
# ------------------------------------
# Logging to logs/pam/19-08-30-15-38-30
# {'dataset': 'heart', 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'e0': 0.1, 'e1': 0.3, 'equalize_prior': True, 'episodes': 1000, 'batchsize': 64, 'hidsize': [8, 8], 'lr': 0.0007, 'alpha': 1.0}
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-8-d710cd3f4f1e> in <module>
#      10     'alpha': 1.
#      11 })
# ---> 12 run(args)
#
# ~/Desktop/learning-with-noisy-labels/runner.py in run(args)
#      42     run_nn(args)
#      43     run_svm(args)
# ---> 44     run_pam(args)
#      45
#      46     """
#
# ~/Desktop/learning-with-noisy-labels/run_pam.py in run(args)
#      39     logger.info(args)
#      40
# ---> 41     pool = mp.Pool(mp.cpu_count())
#      42     pam_arg = args.copy()
#      43
#
# ~/anaconda3/envs/py36/lib/python3.6/multiprocessing/context.py in Pool(self, processes, initializer, initargs, maxtasksperchild)
#     117         from .pool import Pool
#     118         return Pool(processes, initializer, initargs, maxtasksperchild,
# --> 119                     context=self.get_context())
#     120
#     121     def RawValue(self, typecode_or_type, *args):
#
# ~/anaconda3/envs/py36/lib/python3.6/multiprocessing/pool.py in __init__(self, processes, initializer, initargs, maxtasksperchild, context)
#     172         self._processes = processes
#     173         self._pool = []
# --> 174         self._repopulate_pool()
#     175
#     176         self._worker_handler = threading.Thread(
#
# ~/anaconda3/envs/py36/lib/python3.6/multiprocessing/pool.py in _repopulate_pool(self)
#     237             w.name = w.name.replace('Process', 'PoolWorker')
#     238             w.daemon = True
# --> 239             w.start()
#     240             util.debug('added worker')
#     241
#
# ~/anaconda3/envs/py36/lib/python3.6/multiprocessing/process.py in start(self)
#     103                'daemonic processes are not allowed to have children'
#     104         _cleanup()
# --> 105         self._popen = self._Popen(self)
#     106         self._sentinel = self._popen.sentinel
#     107         # Avoid a refcycle if the target function holds an indirect
#
# ~/anaconda3/envs/py36/lib/python3.6/multiprocessing/context.py in _Popen(process_obj)
#     275         def _Popen(process_obj):
#     276             from .popen_fork import Popen
# --> 277             return Popen(process_obj)
#     278
#     279     class SpawnProcess(process.BaseProcess):
#
# ~/anaconda3/envs/py36/lib/python3.6/multiprocessing/popen_fork.py in __init__(self, process_obj)
#      17         util._flush_std_streams()
#      18         self.returncode = None
# ---> 19         self._launch(process_obj)
#      20
#      21     def duplicate_for_child(self, fd):
#
# ~/anaconda3/envs/py36/lib/python3.6/multiprocessing/popen_fork.py in _launch(self, process_obj)
#      63     def _launch(self, process_obj):
#      64         code = 1
# ---> 65         parent_r, child_w = os.pipe()
#      66         self.pid = os.fork()
#      67         if self.pid == 0:
#
# OSError: [Errno 24] Too many open files

# %%
from runner import run
run({
    'dataset': 'heart', 
    'e0': 0.1, 'e1': 0.3,
    'episodes': 1000,
#     'batchsize': 4,
#     'hidsize': [32, 32],
#     'lr': 0.005,
    'test_size': 0.15,
    'val_size': 0.1,
    'dropout': 0, 
    'normalize': True,
    'equalize_prior': True,
    'alpha': 1.,
    'loss': 'bce',
    'activation': 'relu',
    'verbose': True,
})
# Out:
# Logging to logs/nn/19-08-28-10-59-23
# {'dataset': 'heart', 'e0': 0.1, 'e1': 0.3, 'episodes': 1000, 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'equalize_prior': True, 'alpha': 1.0, 'loss': 'bce', 'activation': 'relu', 'verbose': True}
# acc:0.732	batchsize: 1	lr:0.0007	hidsize:[8, 8]
# acc:0.792	batchsize: 1	lr:0.0007	hidsize:[16, 16]
# acc:0.821	batchsize: 1	lr:0.0007	hidsize:[32, 32]
# acc:0.812	batchsize: 1	lr:0.0007	hidsize:[64, 64]
# acc:0.801	batchsize: 1	lr: 0.001	hidsize:[8, 8]
# acc:0.801	batchsize: 1	lr: 0.001	hidsize:[16, 16]
# acc:0.83	batchsize: 1	lr: 0.001	hidsize:[32, 32]
# acc:0.824	batchsize: 1	lr: 0.001	hidsize:[64, 64]
# acc:0.827	batchsize: 1	lr: 0.005	hidsize:[8, 8]
# acc:0.81	batchsize: 1	lr: 0.005	hidsize:[16, 16]
# acc:0.815	batchsize: 1	lr: 0.005	hidsize:[32, 32]
# acc:0.812	batchsize: 1	lr: 0.005	hidsize:[64, 64]
# acc:0.807	batchsize: 1	lr:  0.01	hidsize:[8, 8]
# acc:0.798	batchsize: 1	lr:  0.01	hidsize:[16, 16]
# acc:0.771	batchsize: 1	lr:  0.01	hidsize:[32, 32]
# acc:0.807	batchsize: 1	lr:  0.01	hidsize:[64, 64]
# acc:0.699	batchsize: 1	lr:  0.05	hidsize:[8, 8]
# acc:0.726	batchsize: 1	lr:  0.05	hidsize:[16, 16]
# acc:0.771	batchsize: 1	lr:  0.05	hidsize:[32, 32]
# acc:0.768	batchsize: 1	lr:  0.05	hidsize:[64, 64]
# acc:0.818	batchsize: 4	lr:0.0007	hidsize:[8, 8]
# acc:0.807	batchsize: 4	lr:0.0007	hidsize:[16, 16]
# acc:0.804	batchsize: 4	lr:0.0007	hidsize:[32, 32]
# acc:0.812	batchsize: 4	lr:0.0007	hidsize:[64, 64]
# acc:0.818	batchsize: 4	lr: 0.001	hidsize:[8, 8]
# acc:0.815	batchsize: 4	lr: 0.001	hidsize:[16, 16]
# acc:0.812	batchsize: 4	lr: 0.001	hidsize:[32, 32]
# acc:0.812	batchsize: 4	lr: 0.001	hidsize:[64, 64]
# acc:0.81	batchsize: 4	lr: 0.005	hidsize:[8, 8]
# acc:0.812	batchsize: 4	lr: 0.005	hidsize:[16, 16]
# acc:0.804	batchsize: 4	lr: 0.005	hidsize:[32, 32]
# acc:0.815	batchsize: 4	lr: 0.005	hidsize:[64, 64]
# acc:0.807	batchsize: 4	lr:  0.01	hidsize:[8, 8]
# acc:0.807	batchsize: 4	lr:  0.01	hidsize:[16, 16]
# acc:0.807	batchsize: 4	lr:  0.01	hidsize:[32, 32]
# acc:0.807	batchsize: 4	lr:  0.01	hidsize:[64, 64]
# acc:0.812	batchsize: 4	lr:  0.05	hidsize:[8, 8]
# acc:0.815	batchsize: 4	lr:  0.05	hidsize:[16, 16]
# acc:0.815	batchsize: 4	lr:  0.05	hidsize:[32, 32]
# acc:0.818	batchsize: 4	lr:  0.05	hidsize:[64, 64]
# acc:0.821	batchsize:16	lr:0.0007	hidsize:[8, 8]
# acc:0.818	batchsize:16	lr:0.0007	hidsize:[16, 16]
# acc:0.818	batchsize:16	lr:0.0007	hidsize:[32, 32]
# acc:0.815	batchsize:16	lr:0.0007	hidsize:[64, 64]
# acc:0.824	batchsize:16	lr: 0.001	hidsize:[8, 8]
# acc:0.815	batchsize:16	lr: 0.001	hidsize:[16, 16]
# acc:0.821	batchsize:16	lr: 0.001	hidsize:[32, 32]
# acc:0.815	batchsize:16	lr: 0.001	hidsize:[64, 64]
# acc:0.824	batchsize:16	lr: 0.005	hidsize:[8, 8]
# acc:0.813	batchsize:16	lr: 0.005	hidsize:[16, 16]
# acc:0.812	batchsize:16	lr: 0.005	hidsize:[32, 32]
# acc:0.81	batchsize:16	lr: 0.005	hidsize:[64, 64]
# acc:0.824	batchsize:16	lr:  0.01	hidsize:[8, 8]
# acc:0.81	batchsize:16	lr:  0.01	hidsize:[16, 16]
# acc:0.812	batchsize:16	lr:  0.01	hidsize:[32, 32]
# acc:0.812	batchsize:16	lr:  0.01	hidsize:[64, 64]
# acc:0.812	batchsize:16	lr:  0.05	hidsize:[8, 8]
# acc:0.821	batchsize:16	lr:  0.05	hidsize:[16, 16]
# acc:0.804	batchsize:16	lr:  0.05	hidsize:[32, 32]
# acc:0.812	batchsize:16	lr:  0.05	hidsize:[64, 64]
# acc:0.83	batchsize:32	lr:0.0007	hidsize:[8, 8]
# acc:0.824	batchsize:32	lr:0.0007	hidsize:[16, 16]
# acc:0.821	batchsize:32	lr:0.0007	hidsize:[32, 32]
# acc:0.818	batchsize:32	lr:0.0007	hidsize:[64, 64]
# acc:0.83	batchsize:32	lr: 0.001	hidsize:[8, 8]
# acc:0.821	batchsize:32	lr: 0.001	hidsize:[16, 16]
# acc:0.818	batchsize:32	lr: 0.001	hidsize:[32, 32]
# acc:0.815	batchsize:32	lr: 0.001	hidsize:[64, 64]
# acc:0.827	batchsize:32	lr: 0.005	hidsize:[8, 8]
# acc:0.821	batchsize:32	lr: 0.005	hidsize:[16, 16]
# acc:0.818	batchsize:32	lr: 0.005	hidsize:[32, 32]
# acc:0.818	batchsize:32	lr: 0.005	hidsize:[64, 64]
# acc:0.824	batchsize:32	lr:  0.01	hidsize:[8, 8]
# acc:0.818	batchsize:32	lr:  0.01	hidsize:[16, 16]
# acc:0.824	batchsize:32	lr:  0.01	hidsize:[32, 32]
# acc:0.821	batchsize:32	lr:  0.01	hidsize:[64, 64]
# acc:0.827	batchsize:32	lr:  0.05	hidsize:[8, 8]
# acc:0.815	batchsize:32	lr:  0.05	hidsize:[16, 16]
# acc:0.818	batchsize:32	lr:  0.05	hidsize:[32, 32]
# acc:0.818	batchsize:32	lr:  0.05	hidsize:[64, 64]
# acc:0.833	batchsize:64	lr:0.0007	hidsize:[8, 8]
# acc:0.827	batchsize:64	lr:0.0007	hidsize:[16, 16]
# acc:0.824	batchsize:64	lr:0.0007	hidsize:[32, 32]
# acc:0.818	batchsize:64	lr:0.0007	hidsize:[64, 64]
# acc:0.833	batchsize:64	lr: 0.001	hidsize:[8, 8]
# acc:0.827	batchsize:64	lr: 0.001	hidsize:[16, 16]
# acc:0.818	batchsize:64	lr: 0.001	hidsize:[32, 32]
# acc:0.815	batchsize:64	lr: 0.001	hidsize:[64, 64]
# acc:0.827	batchsize:64	lr: 0.005	hidsize:[8, 8]
# acc:0.821	batchsize:64	lr: 0.005	hidsize:[16, 16]
# acc:0.815	batchsize:64	lr: 0.005	hidsize:[32, 32]
# acc:0.821	batchsize:64	lr: 0.005	hidsize:[64, 64]
# acc:0.83	batchsize:64	lr:  0.01	hidsize:[8, 8]
# acc:0.821	batchsize:64	lr:  0.01	hidsize:[16, 16]
# acc:0.818	batchsize:64	lr:  0.01	hidsize:[32, 32]
# acc:0.815	batchsize:64	lr:  0.01	hidsize:[64, 64]
# acc:0.833	batchsize:64	lr:  0.05	hidsize:[8, 8]
# acc:0.815	batchsize:64	lr:  0.05	hidsize:[16, 16]
# acc:0.821	batchsize:64	lr:  0.05	hidsize:[32, 32]
# acc:0.821	batchsize:64	lr:  0.05	hidsize:[64, 64]
# --------------------------------------
# | [PEER] best batchsize   | 64       |
# | [PEER] best hidsize     | [8, 8]   |
# | [PEER] best learning... | 0.0007   |
# --------------------------------------
# --------------------------------------
# | [NN] with bce loss      | 0.756    |
# | [NN] with peer loss     | 0.833    |
# | [NN] with surrogate ... | 0.78     |
# --------------------------------------
# Logging to logs/svm/19-08-28-11-04-20
# {'dataset': 'heart', 'e0': 0.1, 'e1': 0.3, 'episodes': 1000, 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'equalize_prior': True, 'alpha': 1.0, 'loss': 'bce', 'activation': 'relu', 'verbose': True}
# --------------------------------
# | [C-SVM] C1 = 0.1  | 0.562    |
# | [C-SVM] C1 = 0.2  | 0.562    |
# | [C-SVM] C1 = 0.25 | 0.562    |
# | [C-SVM] C1 = 0.33 | 0.562    |
# | [C-SVM] C1 = 0.5  | 0.598    |
# | [C-SVM] C1 = 1.0  | 0.665    |
# | [C-SVM] C1 = 10.0 | 0.603    |
# | [C-SVM] C1 = 2.0  | 0.661    |
# | [C-SVM] C1 = 3.0  | 0.634    |
# | [C-SVM] C1 = 4.0  | 0.621    |
# | [C-SVM] C1 = 5.0  | 0.621    |
# --------------------------------
# ------------------------------------
# | [C-SVM] accuracy max  | 0.81     |
# | [C-SVM] accuracy mean | 0.753    |
# | [C-SVM] accuracy min  | 0.619    |
# | [C-SVM] accuracy std  | 0.0629   |
# | [C-SVM] best C1       | 1        |
# ------------------------------------
# Logging to logs/pam/19-08-28-11-04-21
# {'dataset': 'heart', 'e0': 0.1, 'e1': 0.3, 'episodes': 1000, 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'equalize_prior': True, 'alpha': 1.0, 'loss': 'bce', 'activation': 'relu', 'verbose': True}
# -----------------------------------
# | [PAM] margin = 0     | 0.589    |
# | [PAM] margin = 0.125 | 0.683    |
# | [PAM] margin = 0.25  | 0.674    |
# | [PAM] margin = 0.5   | 0.67     |
# | [PAM] margin = 1     | 0.665    |
# -----------------------------------
# ----------------------------------
# | [PAM] accuracy max  | 0.881    |
# | [PAM] accuracy mean | 0.783    |
# | [PAM] accuracy min  | 0.667    |
# | [PAM] accuracy std  | 0.0728   |
# | [PAM] best margin   | 0.125    |
# ----------------------------------

# %% [markdown]
# ### $e_0 = 0.2, e_1 = 0.2$

# %%
from runner import run
args = default_args.copy()
args.update({
    'e0': 0.2, 'e1': 0.2, 
    'equalize_prior': True, 
    'episodes': 1000, 
    'batchsize': 64, 
    'hidsize': [8, 8], 
    'lr': 0.0007, 
    'alpha': 1.
})
run(args)
# Out:
# Logging to logs/nn/19-08-30-15-42-44
# {'dataset': 'heart', 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'e0': 0.2, 'e1': 0.2, 'equalize_prior': True, 'episodes': 1000, 'batchsize': 64, 'hidsize': [8, 8], 'lr': 0.0007, 'alpha': 1.0}
# --------------------------------------
# | [NN] with bce loss      | 0.75     |
# | [NN] with peer loss     | 0.821    |
# | [NN] with surrogate ... | 0.762    |
# --------------------------------------
# Logging to logs/svm/19-08-30-15-42-52
# {'dataset': 'heart', 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'e0': 0.2, 'e1': 0.2, 'equalize_prior': True, 'episodes': 1000, 'batchsize': 64, 'hidsize': [8, 8], 'lr': 0.0007, 'alpha': 1.0}
# --------------------------------
# | [C-SVM] C1 = 0.1  | 0.46     |
# | [C-SVM] C1 = 0.2  | 0.464    |
# | [C-SVM] C1 = 0.25 | 0.469    |
# | [C-SVM] C1 = 0.33 | 0.496    |
# | [C-SVM] C1 = 0.5  | 0.612    |
# | [C-SVM] C1 = 1.0  | 0.674    |
# | [C-SVM] C1 = 10.0 | 0.594    |
# | [C-SVM] C1 = 2.0  | 0.683    |
# | [C-SVM] C1 = 3.0  | 0.643    |
# | [C-SVM] C1 = 4.0  | 0.612    |
# | [C-SVM] C1 = 5.0  | 0.607    |
# --------------------------------
# ------------------------------------
# | [C-SVM] accuracy max  | 0.857    |
# | [C-SVM] accuracy mean | 0.717    |
# | [C-SVM] accuracy min  | 0.619    |
# | [C-SVM] accuracy std  | 0.0948   |
# | [C-SVM] best C1       | 2        |
# ------------------------------------
# Logging to logs/pam/19-08-30-15-42-52
# {'dataset': 'heart', 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'e0': 0.2, 'e1': 0.2, 'equalize_prior': True, 'episodes': 1000, 'batchsize': 64, 'hidsize': [8, 8], 'lr': 0.0007, 'alpha': 1.0}
# -----------------------------------
# | [PAM] margin = 0     | 0.629    |
# | [PAM] margin = 0.125 | 0.656    |
# | [PAM] margin = 0.25  | 0.665    |
# | [PAM] margin = 0.5   | 0.665    |
# | [PAM] margin = 1     | 0.679    |
# -----------------------------------
# ----------------------------------
# | [PAM] accuracy max  | 0.881    |
# | [PAM] accuracy mean | 0.762    |
# | [PAM] accuracy min  | 0.619    |
# | [PAM] accuracy std  | 0.0922   |
# | [PAM] best margin   | 1        |
# ----------------------------------

# %%
from runner import run
run({
    'dataset': 'heart', 
    'e0': 0.2, 'e1': 0.2,
    'episodes': 1000,
#     'batchsize': 4,
#     'hidsize': [32, 32],
#     'lr': 0.005,
    'test_size': 0.15,
    'val_size': 0.1,
    'dropout': 0, 
    'normalize': True,
    'equalize_prior': True,
    'alpha': 1.,
    'loss': 'bce',
    'activation': 'relu',
    'verbose': True,
})
# Out:
# Logging to logs/nn/19-08-28-11-04-24
# {'dataset': 'heart', 'e0': 0.2, 'e1': 0.2, 'episodes': 1000, 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'equalize_prior': True, 'alpha': 1.0, 'loss': 'bce', 'activation': 'relu', 'verbose': True}
# acc:0.753	batchsize: 1	lr:0.0007	hidsize:[8, 8]
# acc:0.798	batchsize: 1	lr:0.0007	hidsize:[16, 16]
# acc:0.824	batchsize: 1	lr:0.0007	hidsize:[32, 32]
# acc:0.824	batchsize: 1	lr:0.0007	hidsize:[64, 64]
# acc:0.815	batchsize: 1	lr: 0.001	hidsize:[8, 8]
# acc:0.818	batchsize: 1	lr: 0.001	hidsize:[16, 16]
# acc:0.824	batchsize: 1	lr: 0.001	hidsize:[32, 32]
# acc:0.833	batchsize: 1	lr: 0.001	hidsize:[64, 64]
# acc:0.824	batchsize: 1	lr: 0.005	hidsize:[8, 8]
# acc:0.818	batchsize: 1	lr: 0.005	hidsize:[16, 16]
# acc:0.818	batchsize: 1	lr: 0.005	hidsize:[32, 32]
# acc:0.821	batchsize: 1	lr: 0.005	hidsize:[64, 64]
# acc:0.827	batchsize: 1	lr:  0.01	hidsize:[8, 8]
# acc:0.807	batchsize: 1	lr:  0.01	hidsize:[16, 16]
# acc:0.815	batchsize: 1	lr:  0.01	hidsize:[32, 32]
# acc:0.827	batchsize: 1	lr:  0.01	hidsize:[64, 64]
# acc:0.726	batchsize: 1	lr:  0.05	hidsize:[8, 8]
# acc:0.78	batchsize: 1	lr:  0.05	hidsize:[16, 16]
# acc:0.771	batchsize: 1	lr:  0.05	hidsize:[32, 32]
# acc:0.804	batchsize: 1	lr:  0.05	hidsize:[64, 64]
# acc:0.821	batchsize: 4	lr:0.0007	hidsize:[8, 8]
# acc:0.81	batchsize: 4	lr:0.0007	hidsize:[16, 16]
# acc:0.801	batchsize: 4	lr:0.0007	hidsize:[32, 32]
# acc:0.801	batchsize: 4	lr:0.0007	hidsize:[64, 64]
# acc:0.824	batchsize: 4	lr: 0.001	hidsize:[8, 8]
# acc:0.804	batchsize: 4	lr: 0.001	hidsize:[16, 16]
# acc:0.795	batchsize: 4	lr: 0.001	hidsize:[32, 32]
# acc:0.804	batchsize: 4	lr: 0.001	hidsize:[64, 64]
# acc:0.801	batchsize: 4	lr: 0.005	hidsize:[8, 8]
# acc:0.804	batchsize: 4	lr: 0.005	hidsize:[16, 16]
# acc:0.789	batchsize: 4	lr: 0.005	hidsize:[32, 32]
# acc:0.804	batchsize: 4	lr: 0.005	hidsize:[64, 64]
# acc:0.807	batchsize: 4	lr:  0.01	hidsize:[8, 8]
# acc:0.798	batchsize: 4	lr:  0.01	hidsize:[16, 16]
# acc:0.798	batchsize: 4	lr:  0.01	hidsize:[32, 32]
# acc:0.801	batchsize: 4	lr:  0.01	hidsize:[64, 64]
# acc:0.744	batchsize: 4	lr:  0.05	hidsize:[8, 8]
# acc:0.729	batchsize: 4	lr:  0.05	hidsize:[16, 16]
# acc:0.762	batchsize: 4	lr:  0.05	hidsize:[32, 32]
# acc:0.798	batchsize: 4	lr:  0.05	hidsize:[64, 64]
# acc:0.821	batchsize:16	lr:0.0007	hidsize:[8, 8]
# acc:0.812	batchsize:16	lr:0.0007	hidsize:[16, 16]
# acc:0.812	batchsize:16	lr:0.0007	hidsize:[32, 32]
# acc:0.812	batchsize:16	lr:0.0007	hidsize:[64, 64]
# acc:0.821	batchsize:16	lr: 0.001	hidsize:[8, 8]
# acc:0.81	batchsize:16	lr: 0.001	hidsize:[16, 16]
# acc:0.81	batchsize:16	lr: 0.001	hidsize:[32, 32]
# acc:0.81	batchsize:16	lr: 0.001	hidsize:[64, 64]
# acc:0.821	batchsize:16	lr: 0.005	hidsize:[8, 8]
# acc:0.807	batchsize:16	lr: 0.005	hidsize:[16, 16]
# acc:0.804	batchsize:16	lr: 0.005	hidsize:[32, 32]
# acc:0.81	batchsize:16	lr: 0.005	hidsize:[64, 64]
# acc:0.804	batchsize:16	lr:  0.01	hidsize:[8, 8]
# acc:0.801	batchsize:16	lr:  0.01	hidsize:[16, 16]
# acc:0.81	batchsize:16	lr:  0.01	hidsize:[32, 32]
# acc:0.807	batchsize:16	lr:  0.01	hidsize:[64, 64]
# acc:0.804	batchsize:16	lr:  0.05	hidsize:[8, 8]
# acc:0.804	batchsize:16	lr:  0.05	hidsize:[16, 16]
# acc:0.801	batchsize:16	lr:  0.05	hidsize:[32, 32]
# acc:0.81	batchsize:16	lr:  0.05	hidsize:[64, 64]
# acc:0.827	batchsize:32	lr:0.0007	hidsize:[8, 8]
# acc:0.81	batchsize:32	lr:0.0007	hidsize:[16, 16]
# acc:0.821	batchsize:32	lr:0.0007	hidsize:[32, 32]
# acc:0.818	batchsize:32	lr:0.0007	hidsize:[64, 64]
# acc:0.833	batchsize:32	lr: 0.001	hidsize:[8, 8]
# acc:0.812	batchsize:32	lr: 0.001	hidsize:[16, 16]
# acc:0.815	batchsize:32	lr: 0.001	hidsize:[32, 32]
# acc:0.815	batchsize:32	lr: 0.001	hidsize:[64, 64]
# acc:0.824	batchsize:32	lr: 0.005	hidsize:[8, 8]
# acc:0.81	batchsize:32	lr: 0.005	hidsize:[16, 16]
# acc:0.824	batchsize:32	lr: 0.005	hidsize:[32, 32]
# acc:0.818	batchsize:32	lr: 0.005	hidsize:[64, 64]
# acc:0.821	batchsize:32	lr:  0.01	hidsize:[8, 8]
# acc:0.807	batchsize:32	lr:  0.01	hidsize:[16, 16]
# acc:0.81	batchsize:32	lr:  0.01	hidsize:[32, 32]
# acc:0.815	batchsize:32	lr:  0.01	hidsize:[64, 64]
# acc:0.815	batchsize:32	lr:  0.05	hidsize:[8, 8]
# acc:0.795	batchsize:32	lr:  0.05	hidsize:[16, 16]
# acc:0.81	batchsize:32	lr:  0.05	hidsize:[32, 32]
# acc:0.81	batchsize:32	lr:  0.05	hidsize:[64, 64]
# acc:0.821	batchsize:64	lr:0.0007	hidsize:[8, 8]
# acc:0.821	batchsize:64	lr:0.0007	hidsize:[16, 16]
# acc:0.818	batchsize:64	lr:0.0007	hidsize:[32, 32]
# acc:0.81	batchsize:64	lr:0.0007	hidsize:[64, 64]
# acc:0.818	batchsize:64	lr: 0.001	hidsize:[8, 8]
# acc:0.815	batchsize:64	lr: 0.001	hidsize:[16, 16]
# acc:0.813	batchsize:64	lr: 0.001	hidsize:[32, 32]
# acc:0.815	batchsize:64	lr: 0.001	hidsize:[64, 64]
# acc:0.821	batchsize:64	lr: 0.005	hidsize:[8, 8]
# acc:0.812	batchsize:64	lr: 0.005	hidsize:[16, 16]
# acc:0.815	batchsize:64	lr: 0.005	hidsize:[32, 32]
# acc:0.81	batchsize:64	lr: 0.005	hidsize:[64, 64]
# acc:0.815	batchsize:64	lr:  0.01	hidsize:[8, 8]
# acc:0.818	batchsize:64	lr:  0.01	hidsize:[16, 16]
# acc:0.815	batchsize:64	lr:  0.01	hidsize:[32, 32]
# acc:0.81	batchsize:64	lr:  0.01	hidsize:[64, 64]
# acc:0.815	batchsize:64	lr:  0.05	hidsize:[8, 8]
# acc:0.81	batchsize:64	lr:  0.05	hidsize:[16, 16]
# acc:0.815	batchsize:64	lr:  0.05	hidsize:[32, 32]
# acc:0.818	batchsize:64	lr:  0.05	hidsize:[64, 64]
# --------------------------------------
# | [PEER] best batchsize   | 32       |
# | [PEER] best hidsize     | [8, 8]   |
# | [PEER] best learning... | 0.001    |
# --------------------------------------
# --------------------------------------
# | [NN] with bce loss      | 0.747    |
# | [NN] with peer loss     | 0.833    |
# | [NN] with surrogate ... | 0.768    |
# --------------------------------------
# Logging to logs/svm/19-08-28-11-09-10
# {'dataset': 'heart', 'e0': 0.2, 'e1': 0.2, 'episodes': 1000, 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'equalize_prior': True, 'alpha': 1.0, 'loss': 'bce', 'activation': 'relu', 'verbose': True}
# --------------------------------
# | [C-SVM] C1 = 0.1  | 0.46     |
# | [C-SVM] C1 = 0.2  | 0.464    |
# | [C-SVM] C1 = 0.25 | 0.469    |
# | [C-SVM] C1 = 0.33 | 0.496    |
# | [C-SVM] C1 = 0.5  | 0.612    |
# | [C-SVM] C1 = 1.0  | 0.674    |
# | [C-SVM] C1 = 10.0 | 0.594    |
# | [C-SVM] C1 = 2.0  | 0.683    |
# | [C-SVM] C1 = 3.0  | 0.643    |
# | [C-SVM] C1 = 4.0  | 0.612    |
# | [C-SVM] C1 = 5.0  | 0.607    |
# --------------------------------
# ------------------------------------
# | [C-SVM] accuracy max  | 0.857    |
# | [C-SVM] accuracy mean | 0.717    |
# | [C-SVM] accuracy min  | 0.619    |
# | [C-SVM] accuracy std  | 0.0948   |
# | [C-SVM] best C1       | 2        |
# ------------------------------------
# Logging to logs/pam/19-08-28-11-09-10
# {'dataset': 'heart', 'e0': 0.2, 'e1': 0.2, 'episodes': 1000, 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'equalize_prior': True, 'alpha': 1.0, 'loss': 'bce', 'activation': 'relu', 'verbose': True}
# -----------------------------------
# | [PAM] margin = 0     | 0.629    |
# | [PAM] margin = 0.125 | 0.656    |
# | [PAM] margin = 0.25  | 0.665    |
# | [PAM] margin = 0.5   | 0.665    |
# | [PAM] margin = 1     | 0.679    |
# -----------------------------------
# ----------------------------------
# | [PAM] accuracy max  | 0.881    |
# | [PAM] accuracy mean | 0.762    |
# | [PAM] accuracy min  | 0.619    |
# | [PAM] accuracy std  | 0.0922   |
# | [PAM] best margin   | 1        |
# ----------------------------------

# %% [markdown]
# ### $e_0=0.1, e_1=0.4$

# %%
from runner import run
args = default_args.copy()
args.update({
    'e0': 0.1, 'e1': 0.4, 
    'equalize_prior': True, 
    'episodes': 1000, 
    'batchsize': 64, 
    'hidsize': [8, 8], 
    'lr': 0.0007, 
    'alpha': 1.
})
run(args)
# Out:
# Logging to logs/nn/19-08-30-15-42-35
# {'dataset': 'heart', 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'e0': 0.1, 'e1': 0.4, 'equalize_prior': True, 'episodes': 1000, 'batchsize': 64, 'hidsize': [8, 8], 'lr': 0.0007, 'alpha': 1.0}
# --------------------------------------
# | [NN] with bce loss      | 0.717    |
# | [NN] with peer loss     | 0.827    |
# | [NN] with surrogate ... | 0.777    |
# --------------------------------------
# Logging to logs/svm/19-08-30-15-42-41
# {'dataset': 'heart', 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'e0': 0.1, 'e1': 0.4, 'equalize_prior': True, 'episodes': 1000, 'batchsize': 64, 'hidsize': [8, 8], 'lr': 0.0007, 'alpha': 1.0}
# --------------------------------
# | [C-SVM] C1 = 0.1  | 0.616    |
# | [C-SVM] C1 = 0.2  | 0.616    |
# | [C-SVM] C1 = 0.25 | 0.616    |
# | [C-SVM] C1 = 0.33 | 0.616    |
# | [C-SVM] C1 = 0.5  | 0.616    |
# | [C-SVM] C1 = 1.0  | 0.625    |
# | [C-SVM] C1 = 10.0 | 0.594    |
# | [C-SVM] C1 = 2.0  | 0.656    |
# | [C-SVM] C1 = 3.0  | 0.621    |
# | [C-SVM] C1 = 4.0  | 0.612    |
# | [C-SVM] C1 = 5.0  | 0.607    |
# --------------------------------
# ------------------------------------
# | [C-SVM] accuracy max  | 0.905    |
# | [C-SVM] accuracy mean | 0.744    |
# | [C-SVM] accuracy min  | 0.619    |
# | [C-SVM] accuracy std  | 0.0787   |
# | [C-SVM] best C1       | 2        |
# ------------------------------------
# Logging to logs/pam/19-08-30-15-42-41
# {'dataset': 'heart', 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'e0': 0.1, 'e1': 0.4, 'equalize_prior': True, 'episodes': 1000, 'batchsize': 64, 'hidsize': [8, 8], 'lr': 0.0007, 'alpha': 1.0}
# -----------------------------------
# | [PAM] margin = 0     | 0.594    |
# | [PAM] margin = 0.125 | 0.674    |
# | [PAM] margin = 0.25  | 0.661    |
# | [PAM] margin = 0.5   | 0.665    |
# | [PAM] margin = 1     | 0.665    |
# -----------------------------------
# ----------------------------------
# | [PAM] accuracy max  | 0.786    |
# | [PAM] accuracy mean | 0.723    |
# | [PAM] accuracy min  | 0.643    |
# | [PAM] accuracy std  | 0.0532   |
# | [PAM] best margin   | 0.125    |
# ----------------------------------

# %%
from runner import run
run({
    'dataset': 'heart', 
    'e0': 0.1, 'e1': 0.4,
    'episodes': 1000,
#     'batchsize': 4,
#     'hidsize': [32, 32],
#     'lr': 0.005,
    'test_size': 0.15,
    'val_size': 0.1,
    'dropout': 0, 
    'normalize': True,
    'equalize_prior': True,
    'alpha': 1.,
    'loss': 'bce',
    'activation': 'relu',
    'verbose': True,
})
# Out:
# Logging to logs/nn/19-08-28-11-09-14
# {'dataset': 'heart', 'e0': 0.1, 'e1': 0.4, 'episodes': 1000, 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'equalize_prior': True, 'alpha': 1.0, 'loss': 'bce', 'activation': 'relu', 'verbose': True}
# acc:0.682	batchsize: 1	lr:0.0007	hidsize:[8, 8]
# acc:0.768	batchsize: 1	lr:0.0007	hidsize:[16, 16]
# acc:0.815	batchsize: 1	lr:0.0007	hidsize:[32, 32]
# acc:0.801	batchsize: 1	lr:0.0007	hidsize:[64, 64]
# acc:0.777	batchsize: 1	lr: 0.001	hidsize:[8, 8]
# acc:0.786	batchsize: 1	lr: 0.001	hidsize:[16, 16]
# acc:0.818	batchsize: 1	lr: 0.001	hidsize:[32, 32]
# acc:0.798	batchsize: 1	lr: 0.001	hidsize:[64, 64]
# acc:0.789	batchsize: 1	lr: 0.005	hidsize:[8, 8]
# acc:0.801	batchsize: 1	lr: 0.005	hidsize:[16, 16]
# acc:0.81	batchsize: 1	lr: 0.005	hidsize:[32, 32]
# acc:0.807	batchsize: 1	lr: 0.005	hidsize:[64, 64]
# acc:0.81	batchsize: 1	lr:  0.01	hidsize:[8, 8]
# acc:0.789	batchsize: 1	lr:  0.01	hidsize:[16, 16]
# acc:0.786	batchsize: 1	lr:  0.01	hidsize:[32, 32]
# acc:0.804	batchsize: 1	lr:  0.01	hidsize:[64, 64]
# acc:0.673	batchsize: 1	lr:  0.05	hidsize:[8, 8]
# acc:0.682	batchsize: 1	lr:  0.05	hidsize:[16, 16]
# acc:0.801	batchsize: 1	lr:  0.05	hidsize:[32, 32]
# acc:0.774	batchsize: 1	lr:  0.05	hidsize:[64, 64]
# acc:0.807	batchsize: 4	lr:0.0007	hidsize:[8, 8]
# acc:0.801	batchsize: 4	lr:0.0007	hidsize:[16, 16]
# acc:0.807	batchsize: 4	lr:0.0007	hidsize:[32, 32]
# acc:0.795	batchsize: 4	lr:0.0007	hidsize:[64, 64]
# acc:0.81	batchsize: 4	lr: 0.001	hidsize:[8, 8]
# acc:0.801	batchsize: 4	lr: 0.001	hidsize:[16, 16]
# acc:0.81	batchsize: 4	lr: 0.001	hidsize:[32, 32]
# acc:0.798	batchsize: 4	lr: 0.001	hidsize:[64, 64]
# acc:0.804	batchsize: 4	lr: 0.005	hidsize:[8, 8]
# acc:0.804	batchsize: 4	lr: 0.005	hidsize:[16, 16]
# acc:0.801	batchsize: 4	lr: 0.005	hidsize:[32, 32]
# acc:0.801	batchsize: 4	lr: 0.005	hidsize:[64, 64]
# acc:0.792	batchsize: 4	lr:  0.01	hidsize:[8, 8]
# acc:0.81	batchsize: 4	lr:  0.01	hidsize:[16, 16]
# acc:0.804	batchsize: 4	lr:  0.01	hidsize:[32, 32]
# acc:0.807	batchsize: 4	lr:  0.01	hidsize:[64, 64]
# acc:0.711	batchsize: 4	lr:  0.05	hidsize:[8, 8]
# acc:0.708	batchsize: 4	lr:  0.05	hidsize:[16, 16]
# acc:0.807	batchsize: 4	lr:  0.05	hidsize:[32, 32]
# acc:0.81	batchsize: 4	lr:  0.05	hidsize:[64, 64]
# acc:0.83	batchsize:16	lr:0.0007	hidsize:[8, 8]
# acc:0.815	batchsize:16	lr:0.0007	hidsize:[16, 16]
# acc:0.818	batchsize:16	lr:0.0007	hidsize:[32, 32]
# acc:0.818	batchsize:16	lr:0.0007	hidsize:[64, 64]
# acc:0.824	batchsize:16	lr: 0.001	hidsize:[8, 8]
# acc:0.812	batchsize:16	lr: 0.001	hidsize:[16, 16]
# acc:0.818	batchsize:16	lr: 0.001	hidsize:[32, 32]
# acc:0.815	batchsize:16	lr: 0.001	hidsize:[64, 64]
# acc:0.815	batchsize:16	lr: 0.005	hidsize:[8, 8]
# acc:0.807	batchsize:16	lr: 0.005	hidsize:[16, 16]
# acc:0.81	batchsize:16	lr: 0.005	hidsize:[32, 32]
# acc:0.807	batchsize:16	lr: 0.005	hidsize:[64, 64]
# acc:0.815	batchsize:16	lr:  0.01	hidsize:[8, 8]
# acc:0.807	batchsize:16	lr:  0.01	hidsize:[16, 16]
# acc:0.818	batchsize:16	lr:  0.01	hidsize:[32, 32]
# acc:0.807	batchsize:16	lr:  0.01	hidsize:[64, 64]
# acc:0.804	batchsize:16	lr:  0.05	hidsize:[8, 8]
# acc:0.812	batchsize:16	lr:  0.05	hidsize:[16, 16]
# acc:0.807	batchsize:16	lr:  0.05	hidsize:[32, 32]
# acc:0.815	batchsize:16	lr:  0.05	hidsize:[64, 64]
# acc:0.824	batchsize:32	lr:0.0007	hidsize:[8, 8]
# acc:0.812	batchsize:32	lr:0.0007	hidsize:[16, 16]
# acc:0.818	batchsize:32	lr:0.0007	hidsize:[32, 32]
# acc:0.812	batchsize:32	lr:0.0007	hidsize:[64, 64]
# acc:0.827	batchsize:32	lr: 0.001	hidsize:[8, 8]
# acc:0.812	batchsize:32	lr: 0.001	hidsize:[16, 16]
# acc:0.815	batchsize:32	lr: 0.001	hidsize:[32, 32]
# acc:0.818	batchsize:32	lr: 0.001	hidsize:[64, 64]
# acc:0.815	batchsize:32	lr: 0.005	hidsize:[8, 8]
# acc:0.812	batchsize:32	lr: 0.005	hidsize:[16, 16]
# acc:0.815	batchsize:32	lr: 0.005	hidsize:[32, 32]
# acc:0.807	batchsize:32	lr: 0.005	hidsize:[64, 64]
# acc:0.815	batchsize:32	lr:  0.01	hidsize:[8, 8]
# acc:0.815	batchsize:32	lr:  0.01	hidsize:[16, 16]
# acc:0.824	batchsize:32	lr:  0.01	hidsize:[32, 32]
# acc:0.81	batchsize:32	lr:  0.01	hidsize:[64, 64]
# acc:0.81	batchsize:32	lr:  0.05	hidsize:[8, 8]
# acc:0.81	batchsize:32	lr:  0.05	hidsize:[16, 16]
# acc:0.818	batchsize:32	lr:  0.05	hidsize:[32, 32]
# acc:0.813	batchsize:32	lr:  0.05	hidsize:[64, 64]
# acc:0.827	batchsize:64	lr:0.0007	hidsize:[8, 8]
# acc:0.815	batchsize:64	lr:0.0007	hidsize:[16, 16]
# acc:0.818	batchsize:64	lr:0.0007	hidsize:[32, 32]
# acc:0.818	batchsize:64	lr:0.0007	hidsize:[64, 64]
# acc:0.821	batchsize:64	lr: 0.001	hidsize:[8, 8]
# acc:0.812	batchsize:64	lr: 0.001	hidsize:[16, 16]
# acc:0.818	batchsize:64	lr: 0.001	hidsize:[32, 32]
# acc:0.818	batchsize:64	lr: 0.001	hidsize:[64, 64]
# acc:0.81	batchsize:64	lr: 0.005	hidsize:[8, 8]
# acc:0.818	batchsize:64	lr: 0.005	hidsize:[16, 16]
# acc:0.821	batchsize:64	lr: 0.005	hidsize:[32, 32]
# acc:0.818	batchsize:64	lr: 0.005	hidsize:[64, 64]
# acc:0.815	batchsize:64	lr:  0.01	hidsize:[8, 8]
# acc:0.818	batchsize:64	lr:  0.01	hidsize:[16, 16]
# acc:0.818	batchsize:64	lr:  0.01	hidsize:[32, 32]
# acc:0.818	batchsize:64	lr:  0.01	hidsize:[64, 64]
# acc:0.824	batchsize:64	lr:  0.05	hidsize:[8, 8]
# acc:0.812	batchsize:64	lr:  0.05	hidsize:[16, 16]
# acc:0.821	batchsize:64	lr:  0.05	hidsize:[32, 32]
# acc:0.821	batchsize:64	lr:  0.05	hidsize:[64, 64]
# --------------------------------------
# | [PEER] best batchsize   | 16       |
# | [PEER] best hidsize     | [8, 8]   |
# | [PEER] best learning... | 0.0007   |
# --------------------------------------
# --------------------------------------
# | [NN] with bce loss      | 0.72     |
# | [NN] with peer loss     | 0.83     |
# | [NN] with surrogate ... | 0.792    |
# --------------------------------------
# Logging to logs/svm/19-08-28-11-13-55
# {'dataset': 'heart', 'e0': 0.1, 'e1': 0.4, 'episodes': 1000, 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'equalize_prior': True, 'alpha': 1.0, 'loss': 'bce', 'activation': 'relu', 'verbose': True}
# --------------------------------
# | [C-SVM] C1 = 0.1  | 0.616    |
# | [C-SVM] C1 = 0.2  | 0.616    |
# | [C-SVM] C1 = 0.25 | 0.616    |
# | [C-SVM] C1 = 0.33 | 0.616    |
# | [C-SVM] C1 = 0.5  | 0.616    |
# | [C-SVM] C1 = 1.0  | 0.625    |
# | [C-SVM] C1 = 10.0 | 0.594    |
# | [C-SVM] C1 = 2.0  | 0.656    |
# | [C-SVM] C1 = 3.0  | 0.621    |
# | [C-SVM] C1 = 4.0  | 0.612    |
# | [C-SVM] C1 = 5.0  | 0.607    |
# --------------------------------
# ------------------------------------
# | [C-SVM] accuracy max  | 0.905    |
# | [C-SVM] accuracy mean | 0.744    |
# | [C-SVM] accuracy min  | 0.619    |
# | [C-SVM] accuracy std  | 0.0787   |
# | [C-SVM] best C1       | 2        |
# ------------------------------------
# Logging to logs/pam/19-08-28-11-13-55
# {'dataset': 'heart', 'e0': 0.1, 'e1': 0.4, 'episodes': 1000, 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'equalize_prior': True, 'alpha': 1.0, 'loss': 'bce', 'activation': 'relu', 'verbose': True}
# -----------------------------------
# | [PAM] margin = 0     | 0.594    |
# | [PAM] margin = 0.125 | 0.674    |
# | [PAM] margin = 0.25  | 0.661    |
# | [PAM] margin = 0.5   | 0.665    |
# | [PAM] margin = 1     | 0.665    |
# -----------------------------------
# ----------------------------------
# | [PAM] accuracy max  | 0.786    |
# | [PAM] accuracy mean | 0.723    |
# | [PAM] accuracy min  | 0.643    |
# | [PAM] accuracy std  | 0.0532   |
# | [PAM] best margin   | 0.125    |
# ----------------------------------

# %% [markdown]
# ### $e_0 = 0.2, e_1 = 0.4$

# %%
from runner import run
args = default_args.copy()
args.update({
    'e0': 0.2, 'e1': 0.4, 
    'equalize_prior': True, 
    'episodes': 1000, 
    'batchsize': 64, 
    'hidsize': [8, 8], 
    'lr': 0.0007, 
    'alpha': 1.
})
run(args)
# Out:
# Logging to logs/nn/19-08-30-15-43-06
# {'dataset': 'heart', 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'e0': 0.2, 'e1': 0.4, 'equalize_prior': True, 'episodes': 1000, 'batchsize': 64, 'hidsize': [8, 8], 'lr': 0.0007, 'alpha': 1.0}
# --------------------------------------
# | [NN] with bce loss      | 0.679    |
# | [NN] with peer loss     | 0.812    |
# | [NN] with surrogate ... | 0.768    |
# --------------------------------------
# Logging to logs/svm/19-08-30-15-43-13
# {'dataset': 'heart', 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'e0': 0.2, 'e1': 0.4, 'equalize_prior': True, 'episodes': 1000, 'batchsize': 64, 'hidsize': [8, 8], 'lr': 0.0007, 'alpha': 1.0}
# --------------------------------
# | [C-SVM] C1 = 0.1  | 0.567    |
# | [C-SVM] C1 = 0.2  | 0.567    |
# | [C-SVM] C1 = 0.25 | 0.567    |
# | [C-SVM] C1 = 0.33 | 0.567    |
# | [C-SVM] C1 = 0.5  | 0.567    |
# | [C-SVM] C1 = 1.0  | 0.598    |
# | [C-SVM] C1 = 10.0 | 0.554    |
# | [C-SVM] C1 = 2.0  | 0.603    |
# | [C-SVM] C1 = 3.0  | 0.571    |
# | [C-SVM] C1 = 4.0  | 0.562    |
# | [C-SVM] C1 = 5.0  | 0.549    |
# --------------------------------
# ------------------------------------
# | [C-SVM] accuracy max  | 0.857    |
# | [C-SVM] accuracy mean | 0.714    |
# | [C-SVM] accuracy min  | 0.571    |
# | [C-SVM] accuracy std  | 0.102    |
# | [C-SVM] best C1       | 2        |
# ------------------------------------
# Logging to logs/pam/19-08-30-15-43-13
# {'dataset': 'heart', 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'e0': 0.2, 'e1': 0.4, 'equalize_prior': True, 'episodes': 1000, 'batchsize': 64, 'hidsize': [8, 8], 'lr': 0.0007, 'alpha': 1.0}
# -----------------------------------
# | [PAM] margin = 0     | 0.585    |
# | [PAM] margin = 0.125 | 0.603    |
# | [PAM] margin = 0.25  | 0.603    |
# | [PAM] margin = 0.5   | 0.603    |
# | [PAM] margin = 1     | 0.589    |
# -----------------------------------
# ----------------------------------
# | [PAM] accuracy max  | 0.81     |
# | [PAM] accuracy mean | 0.741    |
# | [PAM] accuracy min  | 0.667    |
# | [PAM] accuracy std  | 0.0576   |
# | [PAM] best margin   | 0.125    |
# ----------------------------------

# %%
from runner import run
run({
    'dataset': 'heart', 
    'e0': 0.2, 'e1': 0.4,
    'episodes': 1000,
#     'batchsize': 4,
#     'hidsize': [32, 32],
#     'lr': 0.005,
    'test_size': 0.15,
    'val_size': 0.1,
    'dropout': 0, 
    'normalize': True,
    'equalize_prior': True,
    'alpha': 1.,
    'loss': 'bce',
    'activation': 'relu',
    'verbose': True,
})
# Out:
# Logging to logs/nn/19-08-28-11-13-59
# {'dataset': 'heart', 'e0': 0.2, 'e1': 0.4, 'episodes': 1000, 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'equalize_prior': True, 'alpha': 1.0, 'loss': 'bce', 'activation': 'relu', 'verbose': True}
# acc:0.658	batchsize: 1	lr:0.0007	hidsize:[8, 8]
# acc:0.717	batchsize: 1	lr:0.0007	hidsize:[16, 16]
# acc:0.798	batchsize: 1	lr:0.0007	hidsize:[32, 32]
# acc:0.801	batchsize: 1	lr:0.0007	hidsize:[64, 64]
# acc:0.735	batchsize: 1	lr: 0.001	hidsize:[8, 8]
# acc:0.75	batchsize: 1	lr: 0.001	hidsize:[16, 16]
# acc:0.807	batchsize: 1	lr: 0.001	hidsize:[32, 32]
# acc:0.807	batchsize: 1	lr: 0.001	hidsize:[64, 64]
# acc:0.804	batchsize: 1	lr: 0.005	hidsize:[8, 8]
# acc:0.783	batchsize: 1	lr: 0.005	hidsize:[16, 16]
# acc:0.81	batchsize: 1	lr: 0.005	hidsize:[32, 32]
# acc:0.801	batchsize: 1	lr: 0.005	hidsize:[64, 64]
# acc:0.804	batchsize: 1	lr:  0.01	hidsize:[8, 8]
# acc:0.804	batchsize: 1	lr:  0.01	hidsize:[16, 16]
# acc:0.783	batchsize: 1	lr:  0.01	hidsize:[32, 32]
# acc:0.783	batchsize: 1	lr:  0.01	hidsize:[64, 64]
# acc:0.649	batchsize: 1	lr:  0.05	hidsize:[8, 8]
# acc:0.753	batchsize: 1	lr:  0.05	hidsize:[16, 16]
# acc:0.747	batchsize: 1	lr:  0.05	hidsize:[32, 32]
# acc:0.72	batchsize: 1	lr:  0.05	hidsize:[64, 64]
# acc:0.78	batchsize: 4	lr:0.0007	hidsize:[8, 8]
# acc:0.792	batchsize: 4	lr:0.0007	hidsize:[16, 16]
# acc:0.792	batchsize: 4	lr:0.0007	hidsize:[32, 32]
# acc:0.801	batchsize: 4	lr:0.0007	hidsize:[64, 64]
# acc:0.804	batchsize: 4	lr: 0.001	hidsize:[8, 8]
# acc:0.795	batchsize: 4	lr: 0.001	hidsize:[16, 16]
# acc:0.783	batchsize: 4	lr: 0.001	hidsize:[32, 32]
# acc:0.807	batchsize: 4	lr: 0.001	hidsize:[64, 64]
# acc:0.786	batchsize: 4	lr: 0.005	hidsize:[8, 8]
# acc:0.798	batchsize: 4	lr: 0.005	hidsize:[16, 16]
# acc:0.786	batchsize: 4	lr: 0.005	hidsize:[32, 32]
# acc:0.804	batchsize: 4	lr: 0.005	hidsize:[64, 64]
# acc:0.786	batchsize: 4	lr:  0.01	hidsize:[8, 8]
# acc:0.801	batchsize: 4	lr:  0.01	hidsize:[16, 16]
# acc:0.801	batchsize: 4	lr:  0.01	hidsize:[32, 32]
# acc:0.815	batchsize: 4	lr:  0.01	hidsize:[64, 64]
# acc:0.714	batchsize: 4	lr:  0.05	hidsize:[8, 8]
# acc:0.741	batchsize: 4	lr:  0.05	hidsize:[16, 16]
# acc:0.771	batchsize: 4	lr:  0.05	hidsize:[32, 32]
# acc:0.812	batchsize: 4	lr:  0.05	hidsize:[64, 64]
# acc:0.815	batchsize:16	lr:0.0007	hidsize:[8, 8]
# acc:0.815	batchsize:16	lr:0.0007	hidsize:[16, 16]
# acc:0.815	batchsize:16	lr:0.0007	hidsize:[32, 32]
# acc:0.81	batchsize:16	lr:0.0007	hidsize:[64, 64]
# acc:0.812	batchsize:16	lr: 0.001	hidsize:[8, 8]
# acc:0.812	batchsize:16	lr: 0.001	hidsize:[16, 16]
# acc:0.815	batchsize:16	lr: 0.001	hidsize:[32, 32]
# acc:0.81	batchsize:16	lr: 0.001	hidsize:[64, 64]
# acc:0.807	batchsize:16	lr: 0.005	hidsize:[8, 8]
# acc:0.798	batchsize:16	lr: 0.005	hidsize:[16, 16]
# acc:0.798	batchsize:16	lr: 0.005	hidsize:[32, 32]
# acc:0.801	batchsize:16	lr: 0.005	hidsize:[64, 64]
# acc:0.798	batchsize:16	lr:  0.01	hidsize:[8, 8]
# acc:0.792	batchsize:16	lr:  0.01	hidsize:[16, 16]
# acc:0.81	batchsize:16	lr:  0.01	hidsize:[32, 32]
# acc:0.804	batchsize:16	lr:  0.01	hidsize:[64, 64]
# acc:0.804	batchsize:16	lr:  0.05	hidsize:[8, 8]
# acc:0.777	batchsize:16	lr:  0.05	hidsize:[16, 16]
# acc:0.792	batchsize:16	lr:  0.05	hidsize:[32, 32]
# acc:0.798	batchsize:16	lr:  0.05	hidsize:[64, 64]
# acc:0.81	batchsize:32	lr:0.0007	hidsize:[8, 8]
# acc:0.812	batchsize:32	lr:0.0007	hidsize:[16, 16]
# acc:0.81	batchsize:32	lr:0.0007	hidsize:[32, 32]
# acc:0.815	batchsize:32	lr:0.0007	hidsize:[64, 64]
# acc:0.804	batchsize:32	lr: 0.001	hidsize:[8, 8]
# acc:0.807	batchsize:32	lr: 0.001	hidsize:[16, 16]
# acc:0.812	batchsize:32	lr: 0.001	hidsize:[32, 32]
# acc:0.818	batchsize:32	lr: 0.001	hidsize:[64, 64]
# acc:0.807	batchsize:32	lr: 0.005	hidsize:[8, 8]
# acc:0.795	batchsize:32	lr: 0.005	hidsize:[16, 16]
# acc:0.807	batchsize:32	lr: 0.005	hidsize:[32, 32]
# acc:0.798	batchsize:32	lr: 0.005	hidsize:[64, 64]
# acc:0.804	batchsize:32	lr:  0.01	hidsize:[8, 8]
# acc:0.798	batchsize:32	lr:  0.01	hidsize:[16, 16]
# acc:0.807	batchsize:32	lr:  0.01	hidsize:[32, 32]
# acc:0.81	batchsize:32	lr:  0.01	hidsize:[64, 64]
# acc:0.795	batchsize:32	lr:  0.05	hidsize:[8, 8]
# acc:0.804	batchsize:32	lr:  0.05	hidsize:[16, 16]
# acc:0.807	batchsize:32	lr:  0.05	hidsize:[32, 32]
# acc:0.807	batchsize:32	lr:  0.05	hidsize:[64, 64]
# acc:0.812	batchsize:64	lr:0.0007	hidsize:[8, 8]
# acc:0.807	batchsize:64	lr:0.0007	hidsize:[16, 16]
# acc:0.815	batchsize:64	lr:0.0007	hidsize:[32, 32]
# acc:0.815	batchsize:64	lr:0.0007	hidsize:[64, 64]
# acc:0.815	batchsize:64	lr: 0.001	hidsize:[8, 8]
# acc:0.81	batchsize:64	lr: 0.001	hidsize:[16, 16]
# acc:0.818	batchsize:64	lr: 0.001	hidsize:[32, 32]
# acc:0.815	batchsize:64	lr: 0.001	hidsize:[64, 64]
# acc:0.812	batchsize:64	lr: 0.005	hidsize:[8, 8]
# acc:0.804	batchsize:64	lr: 0.005	hidsize:[16, 16]
# acc:0.812	batchsize:64	lr: 0.005	hidsize:[32, 32]
# acc:0.824	batchsize:64	lr: 0.005	hidsize:[64, 64]
# acc:0.795	batchsize:64	lr:  0.01	hidsize:[8, 8]
# acc:0.807	batchsize:64	lr:  0.01	hidsize:[16, 16]
# acc:0.807	batchsize:64	lr:  0.01	hidsize:[32, 32]
# acc:0.818	batchsize:64	lr:  0.01	hidsize:[64, 64]
# acc:0.801	batchsize:64	lr:  0.05	hidsize:[8, 8]
# acc:0.824	batchsize:64	lr:  0.05	hidsize:[16, 16]
# acc:0.818	batchsize:64	lr:  0.05	hidsize:[32, 32]
# acc:0.821	batchsize:64	lr:  0.05	hidsize:[64, 64]
# --------------------------------------
# | [PEER] best batchsize   | 64       |
# | [PEER] best hidsize     | [16, 16] |
# | [PEER] best learning... | 0.05     |
# --------------------------------------
# --------------------------------------
# | [NN] with bce loss      | 0.613    |
# | [NN] with peer loss     | 0.824    |
# | [NN] with surrogate ... | 0.747    |
# --------------------------------------
# Logging to logs/svm/19-08-28-11-18-37
# {'dataset': 'heart', 'e0': 0.2, 'e1': 0.4, 'episodes': 1000, 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'equalize_prior': True, 'alpha': 1.0, 'loss': 'bce', 'activation': 'relu', 'verbose': True}
# --------------------------------
# | [C-SVM] C1 = 0.1  | 0.567    |
# | [C-SVM] C1 = 0.2  | 0.567    |
# | [C-SVM] C1 = 0.25 | 0.567    |
# | [C-SVM] C1 = 0.33 | 0.567    |
# | [C-SVM] C1 = 0.5  | 0.567    |
# | [C-SVM] C1 = 1.0  | 0.598    |
# | [C-SVM] C1 = 10.0 | 0.554    |
# | [C-SVM] C1 = 2.0  | 0.603    |
# | [C-SVM] C1 = 3.0  | 0.571    |
# | [C-SVM] C1 = 4.0  | 0.562    |
# | [C-SVM] C1 = 5.0  | 0.549    |
# --------------------------------
# ------------------------------------
# | [C-SVM] accuracy max  | 0.857    |
# | [C-SVM] accuracy mean | 0.714    |
# | [C-SVM] accuracy min  | 0.571    |
# | [C-SVM] accuracy std  | 0.102    |
# | [C-SVM] best C1       | 2        |
# ------------------------------------
# Logging to logs/pam/19-08-28-11-18-37
# {'dataset': 'heart', 'e0': 0.2, 'e1': 0.4, 'episodes': 1000, 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'equalize_prior': True, 'alpha': 1.0, 'loss': 'bce', 'activation': 'relu', 'verbose': True}
# -----------------------------------
# | [PAM] margin = 0     | 0.585    |
# | [PAM] margin = 0.125 | 0.603    |
# | [PAM] margin = 0.25  | 0.603    |
# | [PAM] margin = 0.5   | 0.603    |
# | [PAM] margin = 1     | 0.589    |
# -----------------------------------
# ----------------------------------
# | [PAM] accuracy max  | 0.81     |
# | [PAM] accuracy mean | 0.741    |
# | [PAM] accuracy min  | 0.667    |
# | [PAM] accuracy std  | 0.0576   |
# | [PAM] best margin   | 0.125    |
# ----------------------------------

# %% [markdown]
# ### $e_0=0.4, e_1=0.4$

# %%
from runner import run
args = default_args.copy()
args.update({
    'e0': 0.4, 'e1': 0.4, 
    'equalize_prior': True, 
    'episodes': 1000, 
    'batchsize': 64, 
    'hidsize': [8, 8], 
    'lr': 0.0007, 
    'alpha': 1.
})
run(args)
# Out:
# Logging to logs/nn/19-08-30-15-43-16
# {'dataset': 'heart', 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'e0': 0.4, 'e1': 0.4, 'equalize_prior': True, 'episodes': 1000, 'batchsize': 64, 'hidsize': [8, 8], 'lr': 0.0007, 'alpha': 1.0}
# --------------------------------------
# | [NN] with bce loss      | 0.595    |
# | [NN] with peer loss     | 0.75     |
# | [NN] with surrogate ... | 0.729    |
# --------------------------------------
# Logging to logs/svm/19-08-30-15-43-24
# {'dataset': 'heart', 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'e0': 0.4, 'e1': 0.4, 'equalize_prior': True, 'episodes': 1000, 'batchsize': 64, 'hidsize': [8, 8], 'lr': 0.0007, 'alpha': 1.0}
# --------------------------------
# | [C-SVM] C1 = 0.1  | 0.482    |
# | [C-SVM] C1 = 0.2  | 0.482    |
# | [C-SVM] C1 = 0.25 | 0.482    |
# | [C-SVM] C1 = 0.33 | 0.482    |
# | [C-SVM] C1 = 0.5  | 0.513    |
# | [C-SVM] C1 = 1.0  | 0.562    |
# | [C-SVM] C1 = 10.0 | 0.549    |
# | [C-SVM] C1 = 2.0  | 0.531    |
# | [C-SVM] C1 = 3.0  | 0.549    |
# | [C-SVM] C1 = 4.0  | 0.549    |
# | [C-SVM] C1 = 5.0  | 0.549    |
# --------------------------------
# ------------------------------------
# | [C-SVM] accuracy max  | 0.81     |
# | [C-SVM] accuracy mean | 0.688    |
# | [C-SVM] accuracy min  | 0.5      |
# | [C-SVM] accuracy std  | 0.0985   |
# | [C-SVM] best C1       | 1        |
# ------------------------------------
# Logging to logs/pam/19-08-30-15-43-24
# {'dataset': 'heart', 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'e0': 0.4, 'e1': 0.4, 'equalize_prior': True, 'episodes': 1000, 'batchsize': 64, 'hidsize': [8, 8], 'lr': 0.0007, 'alpha': 1.0}
# -----------------------------------
# | [PAM] margin = 0     | 0.54     |
# | [PAM] margin = 0.125 | 0.54     |
# | [PAM] margin = 0.25  | 0.54     |
# | [PAM] margin = 0.5   | 0.536    |
# | [PAM] margin = 1     | 0.531    |
# -----------------------------------
# ----------------------------------
# | [PAM] accuracy max  | 0.667    |
# | [PAM] accuracy mean | 0.583    |
# | [PAM] accuracy min  | 0.5      |
# | [PAM] accuracy std  | 0.0641   |
# | [PAM] best margin   | 0        |
# ----------------------------------

# %%
from runner import run
run({
    'dataset': 'heart', 
    'e0': 0.4, 'e1': 0.4,
    'episodes': 2000,
#     'batchsize': 4,
#     'hidsize': [32, 32],
#     'lr': 0.005,
    'test_size': 0.15,
    'val_size': 0.1,
    'dropout': 0, 
    'normalize': True,
    'equalize_prior': True,
    'alpha': 1.,
    'loss': 'bce',
    'activation': 'relu',
    'verbose': True,
})
# Out:
# Logging to logs/nn/19-08-28-11-18-41
# {'dataset': 'heart', 'e0': 0.4, 'e1': 0.4, 'episodes': 2000, 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'equalize_prior': True, 'alpha': 1.0, 'loss': 'bce', 'activation': 'relu', 'verbose': True}
# acc:0.682	batchsize: 1	lr:0.0007	hidsize:[8, 8]
# acc:0.723	batchsize: 1	lr:0.0007	hidsize:[16, 16]
# acc:0.765	batchsize: 1	lr:0.0007	hidsize:[32, 32]
# acc:0.774	batchsize: 1	lr:0.0007	hidsize:[64, 64]
# acc:0.729	batchsize: 1	lr: 0.001	hidsize:[8, 8]
# acc:0.738	batchsize: 1	lr: 0.001	hidsize:[16, 16]
# acc:0.771	batchsize: 1	lr: 0.001	hidsize:[32, 32]
# acc:0.768	batchsize: 1	lr: 0.001	hidsize:[64, 64]
# acc:0.726	batchsize: 1	lr: 0.005	hidsize:[8, 8]
# acc:0.765	batchsize: 1	lr: 0.005	hidsize:[16, 16]
# acc:0.735	batchsize: 1	lr: 0.005	hidsize:[32, 32]
# acc:0.774	batchsize: 1	lr: 0.005	hidsize:[64, 64]
# acc:0.744	batchsize: 1	lr:  0.01	hidsize:[8, 8]
# acc:0.69	batchsize: 1	lr:  0.01	hidsize:[16, 16]
# acc:0.741	batchsize: 1	lr:  0.01	hidsize:[32, 32]
# acc:0.753	batchsize: 1	lr:  0.01	hidsize:[64, 64]
# acc:0.661	batchsize: 1	lr:  0.05	hidsize:[8, 8]
# acc:0.554	batchsize: 1	lr:  0.05	hidsize:[16, 16]
# acc:0.646	batchsize: 1	lr:  0.05	hidsize:[32, 32]
# acc:0.735	batchsize: 1	lr:  0.05	hidsize:[64, 64]
# acc:0.738	batchsize: 4	lr:0.0007	hidsize:[8, 8]
# acc:0.759	batchsize: 4	lr:0.0007	hidsize:[16, 16]
# acc:0.759	batchsize: 4	lr:0.0007	hidsize:[32, 32]
# acc:0.768	batchsize: 4	lr:0.0007	hidsize:[64, 64]
# acc:0.735	batchsize: 4	lr: 0.001	hidsize:[8, 8]
# acc:0.75	batchsize: 4	lr: 0.001	hidsize:[16, 16]
# acc:0.762	batchsize: 4	lr: 0.001	hidsize:[32, 32]
# acc:0.768	batchsize: 4	lr: 0.001	hidsize:[64, 64]
# acc:0.768	batchsize: 4	lr: 0.005	hidsize:[8, 8]
# acc:0.771	batchsize: 4	lr: 0.005	hidsize:[16, 16]
# acc:0.759	batchsize: 4	lr: 0.005	hidsize:[32, 32]
# acc:0.759	batchsize: 4	lr: 0.005	hidsize:[64, 64]
# acc:0.765	batchsize: 4	lr:  0.01	hidsize:[8, 8]
# acc:0.759	batchsize: 4	lr:  0.01	hidsize:[16, 16]
# acc:0.753	batchsize: 4	lr:  0.01	hidsize:[32, 32]
# acc:0.765	batchsize: 4	lr:  0.01	hidsize:[64, 64]
# acc:0.687	batchsize: 4	lr:  0.05	hidsize:[8, 8]
# acc:0.717	batchsize: 4	lr:  0.05	hidsize:[16, 16]
# acc:0.771	batchsize: 4	lr:  0.05	hidsize:[32, 32]
# acc:0.762	batchsize: 4	lr:  0.05	hidsize:[64, 64]
# acc:0.741	batchsize:16	lr:0.0007	hidsize:[8, 8]
# acc:0.762	batchsize:16	lr:0.0007	hidsize:[16, 16]
# acc:0.771	batchsize:16	lr:0.0007	hidsize:[32, 32]
# acc:0.777	batchsize:16	lr:0.0007	hidsize:[64, 64]
# acc:0.771	batchsize:16	lr: 0.001	hidsize:[8, 8]
# acc:0.768	batchsize:16	lr: 0.001	hidsize:[16, 16]
# acc:0.768	batchsize:16	lr: 0.001	hidsize:[32, 32]
# acc:0.78	batchsize:16	lr: 0.001	hidsize:[64, 64]
# acc:0.765	batchsize:16	lr: 0.005	hidsize:[8, 8]
# acc:0.768	batchsize:16	lr: 0.005	hidsize:[16, 16]
# acc:0.768	batchsize:16	lr: 0.005	hidsize:[32, 32]
# acc:0.762	batchsize:16	lr: 0.005	hidsize:[64, 64]
# acc:0.759	batchsize:16	lr:  0.01	hidsize:[8, 8]
# acc:0.771	batchsize:16	lr:  0.01	hidsize:[16, 16]
# acc:0.771	batchsize:16	lr:  0.01	hidsize:[32, 32]
# acc:0.774	batchsize:16	lr:  0.01	hidsize:[64, 64]
# acc:0.747	batchsize:16	lr:  0.05	hidsize:[8, 8]
# acc:0.753	batchsize:16	lr:  0.05	hidsize:[16, 16]
# acc:0.75	batchsize:16	lr:  0.05	hidsize:[32, 32]
# acc:0.756	batchsize:16	lr:  0.05	hidsize:[64, 64]
# acc:0.756	batchsize:32	lr:0.0007	hidsize:[8, 8]
# acc:0.771	batchsize:32	lr:0.0007	hidsize:[16, 16]
# acc:0.777	batchsize:32	lr:0.0007	hidsize:[32, 32]
# acc:0.78	batchsize:32	lr:0.0007	hidsize:[64, 64]
# acc:0.759	batchsize:32	lr: 0.001	hidsize:[8, 8]
# acc:0.777	batchsize:32	lr: 0.001	hidsize:[16, 16]
# acc:0.768	batchsize:32	lr: 0.001	hidsize:[32, 32]
# acc:0.78	batchsize:32	lr: 0.001	hidsize:[64, 64]
# acc:0.756	batchsize:32	lr: 0.005	hidsize:[8, 8]
# acc:0.768	batchsize:32	lr: 0.005	hidsize:[16, 16]
# acc:0.777	batchsize:32	lr: 0.005	hidsize:[32, 32]
# acc:0.771	batchsize:32	lr: 0.005	hidsize:[64, 64]
# acc:0.756	batchsize:32	lr:  0.01	hidsize:[8, 8]
# acc:0.765	batchsize:32	lr:  0.01	hidsize:[16, 16]
# acc:0.771	batchsize:32	lr:  0.01	hidsize:[32, 32]
# acc:0.765	batchsize:32	lr:  0.01	hidsize:[64, 64]
# acc:0.762	batchsize:32	lr:  0.05	hidsize:[8, 8]
# acc:0.756	batchsize:32	lr:  0.05	hidsize:[16, 16]
# acc:0.759	batchsize:32	lr:  0.05	hidsize:[32, 32]
# acc:0.747	batchsize:32	lr:  0.05	hidsize:[64, 64]
# acc:0.765	batchsize:64	lr:0.0007	hidsize:[8, 8]
# acc:0.771	batchsize:64	lr:0.0007	hidsize:[16, 16]
# acc:0.786	batchsize:64	lr:0.0007	hidsize:[32, 32]
# acc:0.789	batchsize:64	lr:0.0007	hidsize:[64, 64]
# acc:0.762	batchsize:64	lr: 0.001	hidsize:[8, 8]
# acc:0.774	batchsize:64	lr: 0.001	hidsize:[16, 16]
# acc:0.78	batchsize:64	lr: 0.001	hidsize:[32, 32]
# acc:0.795	batchsize:64	lr: 0.001	hidsize:[64, 64]
# acc:0.738	batchsize:64	lr: 0.005	hidsize:[8, 8]
# acc:0.78	batchsize:64	lr: 0.005	hidsize:[16, 16]
# acc:0.786	batchsize:64	lr: 0.005	hidsize:[32, 32]
# acc:0.777	batchsize:64	lr: 0.005	hidsize:[64, 64]
# acc:0.747	batchsize:64	lr:  0.01	hidsize:[8, 8]
# acc:0.777	batchsize:64	lr:  0.01	hidsize:[16, 16]
# acc:0.792	batchsize:64	lr:  0.01	hidsize:[32, 32]
# acc:0.777	batchsize:64	lr:  0.01	hidsize:[64, 64]
# acc:0.771	batchsize:64	lr:  0.05	hidsize:[8, 8]
# acc:0.771	batchsize:64	lr:  0.05	hidsize:[16, 16]
# acc:0.759	batchsize:64	lr:  0.05	hidsize:[32, 32]
# acc:0.774	batchsize:64	lr:  0.05	hidsize:[64, 64]
# --------------------------------------
# | [PEER] best batchsize   | 64       |
# | [PEER] best hidsize     | [64, 64] |
# | [PEER] best learning... | 0.001    |
# --------------------------------------
# --------------------------------------
# | [NN] with bce loss      | 0.527    |
# | [NN] with peer loss     | 0.795    |
# | [NN] with surrogate ... | 0.708    |
# --------------------------------------
# Logging to logs/svm/19-08-28-11-28-38
# {'dataset': 'heart', 'e0': 0.4, 'e1': 0.4, 'episodes': 2000, 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'equalize_prior': True, 'alpha': 1.0, 'loss': 'bce', 'activation': 'relu', 'verbose': True}
# --------------------------------
# | [C-SVM] C1 = 0.1  | 0.482    |
# | [C-SVM] C1 = 0.2  | 0.482    |
# | [C-SVM] C1 = 0.25 | 0.482    |
# | [C-SVM] C1 = 0.33 | 0.482    |
# | [C-SVM] C1 = 0.5  | 0.513    |
# | [C-SVM] C1 = 1.0  | 0.562    |
# | [C-SVM] C1 = 10.0 | 0.549    |
# | [C-SVM] C1 = 2.0  | 0.531    |
# | [C-SVM] C1 = 3.0  | 0.549    |
# | [C-SVM] C1 = 4.0  | 0.549    |
# | [C-SVM] C1 = 5.0  | 0.549    |
# --------------------------------
# ------------------------------------
# | [C-SVM] accuracy max  | 0.81     |
# | [C-SVM] accuracy mean | 0.688    |
# | [C-SVM] accuracy min  | 0.5      |
# | [C-SVM] accuracy std  | 0.0985   |
# | [C-SVM] best C1       | 1        |
# ------------------------------------
# Logging to logs/pam/19-08-28-11-28-39
# {'dataset': 'heart', 'e0': 0.4, 'e1': 0.4, 'episodes': 2000, 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'equalize_prior': True, 'alpha': 1.0, 'loss': 'bce', 'activation': 'relu', 'verbose': True}
# -----------------------------------
# | [PAM] margin = 0     | 0.54     |
# | [PAM] margin = 0.125 | 0.54     |
# | [PAM] margin = 0.25  | 0.54     |
# | [PAM] margin = 0.5   | 0.536    |
# | [PAM] margin = 1     | 0.531    |
# -----------------------------------
# ----------------------------------
# | [PAM] accuracy max  | 0.667    |
# | [PAM] accuracy mean | 0.583    |
# | [PAM] accuracy min  | 0.5      |
# | [PAM] accuracy std  | 0.0641   |
# | [PAM] best margin   | 0        |
# ----------------------------------

# %% [markdown]
# ## Without Prior Equalization

# %% [markdown]
# ### $e_0 = 0.1, e_1 = 0.3$

# %%
from runner import run
args = default_args.copy()
args.update({
    'e0': 0.1, 'e1': 0.3, 
    'equalize_prior': False, 
    'episodes': 1000, 
    'batchsize': 64, 
    'hidsize': [8, 8], 
    'lr': 0.0007, 
#     'alpha': 1.
})
run(args)
# Out:
# Logging to logs/nn/19-08-30-15-32-07
# {'dataset': 'heart', 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'e0': 0.1, 'e1': 0.3, 'equalize_prior': False, 'episodes': 1000, 'batchsize': 64, 'hidsize': [8, 8], 'lr': 0.0007}
# ---------------------------------
# | [PEER] alpha = -5  | 0.589    |
# | [PEER] alpha = 0.4 | 0.657    |
# | [PEER] alpha = 0.5 | 0.673    |
# | [PEER] alpha = 0.6 | 0.69     |
# | [PEER] alpha = 0.7 | 0.714    |
# | [PEER] alpha = 0.8 | 0.702    |
# | [PEER] alpha = 0.9 | 0.71     |
# | [PEER] alpha = 1.0 | 0.722    |
# | [PEER] alpha = 2.0 | 0.613    |
# | [PEER] alpha = 3.0 | 0.496    |
# | [PEER] alpha = 4.0 | 0.468    |
# | [PEER] alpha = 5.0 | 0.468    |
# ---------------------------------
# --------------------------------------
# | [NN] with bce loss      | 0.75     |
# | [NN] with peer loss     | 0.856    |
# | [NN] with surrogate ... | 0.802    |
# | [PEER] best alpha       | 1        |
# --------------------------------------
# Logging to logs/svm/19-08-30-15-32-44
# {'dataset': 'heart', 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'e0': 0.1, 'e1': 0.3, 'equalize_prior': False, 'episodes': 1000, 'batchsize': 64, 'hidsize': [8, 8], 'lr': 0.0007}
# --------------------------------
# | [C-SVM] C1 = 0.1  | 0.589    |
# | [C-SVM] C1 = 0.2  | 0.589    |
# | [C-SVM] C1 = 0.25 | 0.589    |
# | [C-SVM] C1 = 0.33 | 0.589    |
# | [C-SVM] C1 = 0.5  | 0.625    |
# | [C-SVM] C1 = 1.0  | 0.685    |
# | [C-SVM] C1 = 10.0 | 0.573    |
# | [C-SVM] C1 = 2.0  | 0.657    |
# | [C-SVM] C1 = 3.0  | 0.629    |
# | [C-SVM] C1 = 4.0  | 0.601    |
# | [C-SVM] C1 = 5.0  | 0.601    |
# --------------------------------
# ------------------------------------
# | [C-SVM] accuracy max  | 0.891    |
# | [C-SVM] accuracy mean | 0.788    |
# | [C-SVM] accuracy min  | 0.739    |
# | [C-SVM] accuracy std  | 0.0562   |
# | [C-SVM] best C1       | 1        |
# ------------------------------------
# Logging to logs/pam/19-08-30-15-32-44
# {'dataset': 'heart', 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'e0': 0.1, 'e1': 0.3, 'equalize_prior': False, 'episodes': 1000, 'batchsize': 64, 'hidsize': [8, 8], 'lr': 0.0007}
# -----------------------------------
# | [PAM] margin = 0     | 0.706    |
# | [PAM] margin = 0.125 | 0.673    |
# | [PAM] margin = 0.25  | 0.694    |
# | [PAM] margin = 0.5   | 0.69     |
# | [PAM] margin = 1     | 0.702    |
# -----------------------------------
# ----------------------------------
# | [PAM] accuracy max  | 0.804    |
# | [PAM] accuracy mean | 0.698    |
# | [PAM] accuracy min  | 0.565    |
# | [PAM] accuracy std  | 0.0725   |
# | [PAM] best margin   | 0        |
# ----------------------------------

# %%
from runner import run
args = default_args.copy()
args.update({
    'e0': 0.1, 'e1': 0.3, 
    'equalize_prior': False, 
    'episodes': 2000, 
    'batchsize': 32, 
    'hidsize': [8, 8], 
    'lr': 0.0007, 
#     'alpha': 1.
})
run(args)
# Out:
# Logging to logs/nn/19-08-30-15-21-49
# {'dataset': 'heart', 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'e0': 0.1, 'e1': 0.3, 'equalize_prior': False, 'episodes': 2000, 'batchsize': 32, 'hidsize': [8, 8], 'lr': 0.0007}
# ---------------------------------
# | [PEER] alpha = -5  | 0.609    |
# | [PEER] alpha = 0.4 | 0.677    |
# | [PEER] alpha = 0.5 | 0.677    |
# | [PEER] alpha = 0.6 | 0.698    |
# | [PEER] alpha = 0.7 | 0.706    |
# | [PEER] alpha = 0.8 | 0.722    |
# | [PEER] alpha = 0.9 | 0.726    |
# | [PEER] alpha = 1.0 | 0.734    |
# | [PEER] alpha = 2.0 | 0.565    |
# | [PEER] alpha = 3.0 | 0.496    |
# | [PEER] alpha = 4.0 | 0.468    |
# | [PEER] alpha = 5.0 | 0.468    |
# ---------------------------------
# --------------------------------------
# | [NN] with bce loss      | 0.731    |
# | [NN] with peer loss     | 0.848    |
# | [NN] with surrogate ... | 0.804    |
# | [PEER] best alpha       | 1        |
# --------------------------------------
# Logging to logs/svm/19-08-30-15-22-55
# {'dataset': 'heart', 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'e0': 0.1, 'e1': 0.3, 'equalize_prior': False, 'episodes': 2000, 'batchsize': 32, 'hidsize': [8, 8], 'lr': 0.0007}
# --------------------------------
# | [C-SVM] C1 = 0.1  | 0.589    |
# | [C-SVM] C1 = 0.2  | 0.589    |
# | [C-SVM] C1 = 0.25 | 0.589    |
# | [C-SVM] C1 = 0.33 | 0.589    |
# | [C-SVM] C1 = 0.5  | 0.625    |
# | [C-SVM] C1 = 1.0  | 0.685    |
# | [C-SVM] C1 = 10.0 | 0.573    |
# | [C-SVM] C1 = 2.0  | 0.657    |
# | [C-SVM] C1 = 3.0  | 0.629    |
# | [C-SVM] C1 = 4.0  | 0.601    |
# | [C-SVM] C1 = 5.0  | 0.601    |
# --------------------------------
# ------------------------------------
# | [C-SVM] accuracy max  | 0.891    |
# | [C-SVM] accuracy mean | 0.788    |
# | [C-SVM] accuracy min  | 0.739    |
# | [C-SVM] accuracy std  | 0.0562   |
# | [C-SVM] best C1       | 1        |
# ------------------------------------
# Logging to logs/pam/19-08-30-15-22-56
# {'dataset': 'heart', 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'e0': 0.1, 'e1': 0.3, 'equalize_prior': False, 'episodes': 2000, 'batchsize': 32, 'hidsize': [8, 8], 'lr': 0.0007}
# -----------------------------------
# | [PAM] margin = 0     | 0.706    |
# | [PAM] margin = 0.125 | 0.673    |
# | [PAM] margin = 0.25  | 0.694    |
# | [PAM] margin = 0.5   | 0.69     |
# | [PAM] margin = 1     | 0.702    |
# -----------------------------------
# ----------------------------------
# | [PAM] accuracy max  | 0.804    |
# | [PAM] accuracy mean | 0.698    |
# | [PAM] accuracy min  | 0.565    |
# | [PAM] accuracy std  | 0.0725   |
# | [PAM] best margin   | 0        |
# ----------------------------------

# %%
from runner import run
args = default_args.copy()
args.update({
    'dataset': 'heart', 
    'e0': 0.1, 'e1': 0.3, 
    'equalize_prior': False, 
    'episodes': 1000, 
#     'batchsize': 4, 
#     'hidsize': [32, 32], 
#     'lr': 0.005, 
#     'alpha': 1.
})
run(args)
# Out:
# Logging to logs/nn/19-08-28-11-28-42
# {'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'dataset': 'heart', 'e0': 0.1, 'e1': 0.3, 'equalize_prior': False, 'episodes': 1000}
# acc:0.726	batchsize: 1	lr:0.0007	hidsize:[8, 8]
# acc:0.772	batchsize: 1	lr:0.0007	hidsize:[16, 16]
# acc:0.856	batchsize: 1	lr:0.0007	hidsize:[32, 32]
# acc:0.853	batchsize: 1	lr:0.0007	hidsize:[64, 64]
# acc:0.772	batchsize: 1	lr: 0.001	hidsize:[8, 8]
# acc:0.823	batchsize: 1	lr: 0.001	hidsize:[16, 16]
# acc:0.853	batchsize: 1	lr: 0.001	hidsize:[32, 32]
# acc:0.851	batchsize: 1	lr: 0.001	hidsize:[64, 64]
# acc:0.845	batchsize: 1	lr: 0.005	hidsize:[8, 8]
# acc:0.859	batchsize: 1	lr: 0.005	hidsize:[16, 16]
# acc:0.856	batchsize: 1	lr: 0.005	hidsize:[32, 32]
# acc:0.856	batchsize: 1	lr: 0.005	hidsize:[64, 64]
# acc:0.856	batchsize: 1	lr:  0.01	hidsize:[8, 8]
# acc:0.842	batchsize: 1	lr:  0.01	hidsize:[16, 16]
# acc:0.845	batchsize: 1	lr:  0.01	hidsize:[32, 32]
# acc:0.84	batchsize: 1	lr:  0.01	hidsize:[64, 64]
# acc:0.658	batchsize: 1	lr:  0.05	hidsize:[8, 8]
# acc:0.791	batchsize: 1	lr:  0.05	hidsize:[16, 16]
# acc:0.848	batchsize: 1	lr:  0.05	hidsize:[32, 32]
# acc:0.821	batchsize: 1	lr:  0.05	hidsize:[64, 64]
# acc:0.793	batchsize: 4	lr:0.0007	hidsize:[8, 8]
# acc:0.851	batchsize: 4	lr:0.0007	hidsize:[16, 16]
# acc:0.845	batchsize: 4	lr:0.0007	hidsize:[32, 32]
# acc:0.851	batchsize: 4	lr:0.0007	hidsize:[64, 64]
# acc:0.829	batchsize: 4	lr: 0.001	hidsize:[8, 8]
# acc:0.848	batchsize: 4	lr: 0.001	hidsize:[16, 16]
# acc:0.853	batchsize: 4	lr: 0.001	hidsize:[32, 32]
# acc:0.845	batchsize: 4	lr: 0.001	hidsize:[64, 64]
# acc:0.842	batchsize: 4	lr: 0.005	hidsize:[8, 8]
# acc:0.845	batchsize: 4	lr: 0.005	hidsize:[16, 16]
# acc:0.832	batchsize: 4	lr: 0.005	hidsize:[32, 32]
# acc:0.84	batchsize: 4	lr: 0.005	hidsize:[64, 64]
# acc:0.845	batchsize: 4	lr:  0.01	hidsize:[8, 8]
# acc:0.848	batchsize: 4	lr:  0.01	hidsize:[16, 16]
# acc:0.837	batchsize: 4	lr:  0.01	hidsize:[32, 32]
# acc:0.834	batchsize: 4	lr:  0.01	hidsize:[64, 64]
# acc:0.783	batchsize: 4	lr:  0.05	hidsize:[8, 8]
# acc:0.788	batchsize: 4	lr:  0.05	hidsize:[16, 16]
# acc:0.823	batchsize: 4	lr:  0.05	hidsize:[32, 32]
# acc:0.832	batchsize: 4	lr:  0.05	hidsize:[64, 64]
# acc:0.842	batchsize:16	lr:0.0007	hidsize:[8, 8]
# acc:0.848	batchsize:16	lr:0.0007	hidsize:[16, 16]
# acc:0.84	batchsize:16	lr:0.0007	hidsize:[32, 32]
# acc:0.848	batchsize:16	lr:0.0007	hidsize:[64, 64]
# acc:0.848	batchsize:16	lr: 0.001	hidsize:[8, 8]
# acc:0.851	batchsize:16	lr: 0.001	hidsize:[16, 16]
# acc:0.84	batchsize:16	lr: 0.001	hidsize:[32, 32]
# acc:0.848	batchsize:16	lr: 0.001	hidsize:[64, 64]
# acc:0.853	batchsize:16	lr: 0.005	hidsize:[8, 8]
# acc:0.851	batchsize:16	lr: 0.005	hidsize:[16, 16]
# acc:0.845	batchsize:16	lr: 0.005	hidsize:[32, 32]
# acc:0.842	batchsize:16	lr: 0.005	hidsize:[64, 64]
# acc:0.851	batchsize:16	lr:  0.01	hidsize:[8, 8]
# acc:0.851	batchsize:16	lr:  0.01	hidsize:[16, 16]
# acc:0.842	batchsize:16	lr:  0.01	hidsize:[32, 32]
# acc:0.848	batchsize:16	lr:  0.01	hidsize:[64, 64]
# acc:0.842	batchsize:16	lr:  0.05	hidsize:[8, 8]
# acc:0.851	batchsize:16	lr:  0.05	hidsize:[16, 16]
# acc:0.845	batchsize:16	lr:  0.05	hidsize:[32, 32]
# acc:0.845	batchsize:16	lr:  0.05	hidsize:[64, 64]
# acc:0.853	batchsize:32	lr:0.0007	hidsize:[8, 8]
# acc:0.848	batchsize:32	lr:0.0007	hidsize:[16, 16]
# acc:0.842	batchsize:32	lr:0.0007	hidsize:[32, 32]
# acc:0.853	batchsize:32	lr:0.0007	hidsize:[64, 64]
# acc:0.853	batchsize:32	lr: 0.001	hidsize:[8, 8]
# acc:0.848	batchsize:32	lr: 0.001	hidsize:[16, 16]
# acc:0.845	batchsize:32	lr: 0.001	hidsize:[32, 32]
# acc:0.853	batchsize:32	lr: 0.001	hidsize:[64, 64]
# acc:0.856	batchsize:32	lr: 0.005	hidsize:[8, 8]
# acc:0.848	batchsize:32	lr: 0.005	hidsize:[16, 16]
# acc:0.848	batchsize:32	lr: 0.005	hidsize:[32, 32]
# acc:0.848	batchsize:32	lr: 0.005	hidsize:[64, 64]
# acc:0.851	batchsize:32	lr:  0.01	hidsize:[8, 8]
# acc:0.851	batchsize:32	lr:  0.01	hidsize:[16, 16]
# acc:0.845	batchsize:32	lr:  0.01	hidsize:[32, 32]
# acc:0.84	batchsize:32	lr:  0.01	hidsize:[64, 64]
# acc:0.851	batchsize:32	lr:  0.05	hidsize:[8, 8]
# acc:0.848	batchsize:32	lr:  0.05	hidsize:[16, 16]
# acc:0.834	batchsize:32	lr:  0.05	hidsize:[32, 32]
# acc:0.834	batchsize:32	lr:  0.05	hidsize:[64, 64]
# acc:0.856	batchsize:64	lr:0.0007	hidsize:[8, 8]
# acc:0.851	batchsize:64	lr:0.0007	hidsize:[16, 16]
# acc:0.845	batchsize:64	lr:0.0007	hidsize:[32, 32]
# acc:0.851	batchsize:64	lr:0.0007	hidsize:[64, 64]
# acc:0.856	batchsize:64	lr: 0.001	hidsize:[8, 8]
# acc:0.851	batchsize:64	lr: 0.001	hidsize:[16, 16]
# acc:0.845	batchsize:64	lr: 0.001	hidsize:[32, 32]
# acc:0.848	batchsize:64	lr: 0.001	hidsize:[64, 64]
# acc:0.853	batchsize:64	lr: 0.005	hidsize:[8, 8]
# acc:0.851	batchsize:64	lr: 0.005	hidsize:[16, 16]
# acc:0.848	batchsize:64	lr: 0.005	hidsize:[32, 32]
# acc:0.845	batchsize:64	lr: 0.005	hidsize:[64, 64]
# acc:0.856	batchsize:64	lr:  0.01	hidsize:[8, 8]
# acc:0.851	batchsize:64	lr:  0.01	hidsize:[16, 16]
# acc:0.842	batchsize:64	lr:  0.01	hidsize:[32, 32]
# acc:0.845	batchsize:64	lr:  0.01	hidsize:[64, 64]
# acc:0.853	batchsize:64	lr:  0.05	hidsize:[8, 8]
# acc:0.851	batchsize:64	lr:  0.05	hidsize:[16, 16]
# acc:0.842	batchsize:64	lr:  0.05	hidsize:[32, 32]
# acc:0.84	batchsize:64	lr:  0.05	hidsize:[64, 64]
# --------------------------------------
# | [PEER] best batchsize   | 1        |
# | [PEER] best hidsize     | [16, 16] |
# | [PEER] best learning... | 0.005    |
# --------------------------------------
# ---------------------------------
# | [PEER] alpha = 0.1 | 0.653    |
# | [PEER] alpha = 0.2 | 0.641    |
# | [PEER] alpha = 0.3 | 0.69     |
# | [PEER] alpha = 0.4 | 0.706    |
# | [PEER] alpha = 0.5 | 0.69     |
# | [PEER] alpha = 0.6 | 0.694    |
# | [PEER] alpha = 0.7 | 0.702    |
# | [PEER] alpha = 0.8 | 0.706    |
# | [PEER] alpha = 0.9 | 0.718    |
# | [PEER] alpha = 1.0 | 0.746    |
# ---------------------------------
# --------------------------------------
# | [NN] with bce loss      | 0.728    |
# | [NN] with peer loss     | 0.859    |
# | [NN] with surrogate ... | 0.793    |
# | [PEER] best alpha       | 1        |
# --------------------------------------
# Logging to logs/svm/19-08-28-11-33-58
# {'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'dataset': 'heart', 'e0': 0.1, 'e1': 0.3, 'equalize_prior': False, 'episodes': 1000}
# --------------------------------
# | [C-SVM] C1 = 0.1  | 0.589    |
# | [C-SVM] C1 = 0.2  | 0.589    |
# | [C-SVM] C1 = 0.25 | 0.589    |
# | [C-SVM] C1 = 0.33 | 0.589    |
# | [C-SVM] C1 = 0.5  | 0.625    |
# | [C-SVM] C1 = 1.0  | 0.685    |
# | [C-SVM] C1 = 10.0 | 0.573    |
# | [C-SVM] C1 = 2.0  | 0.657    |
# | [C-SVM] C1 = 3.0  | 0.629    |
# | [C-SVM] C1 = 4.0  | 0.601    |
# | [C-SVM] C1 = 5.0  | 0.601    |
# --------------------------------
# ------------------------------------
# | [C-SVM] accuracy max  | 0.891    |
# | [C-SVM] accuracy mean | 0.788    |
# | [C-SVM] accuracy min  | 0.739    |
# | [C-SVM] accuracy std  | 0.0562   |
# | [C-SVM] best C1       | 1        |
# ------------------------------------
# Logging to logs/pam/19-08-28-11-33-58
# {'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'dataset': 'heart', 'e0': 0.1, 'e1': 0.3, 'equalize_prior': False, 'episodes': 1000}
# -----------------------------------
# | [PAM] margin = 0     | 0.706    |
# | [PAM] margin = 0.125 | 0.673    |
# | [PAM] margin = 0.25  | 0.694    |
# | [PAM] margin = 0.5   | 0.69     |
# | [PAM] margin = 1     | 0.702    |
# -----------------------------------
# ----------------------------------
# | [PAM] accuracy max  | 0.804    |
# | [PAM] accuracy mean | 0.698    |
# | [PAM] accuracy min  | 0.565    |
# | [PAM] accuracy std  | 0.0725   |
# | [PAM] best margin   | 0        |
# ----------------------------------

# %% [markdown]
# ### $e_0 = 0.2, e_1 = 0.2$

# %%
from runner import run
args = default_args.copy()
args.update({
    'e0': 0.2, 'e1': 0.2, 
    'equalize_prior': False, 
    'episodes': 1000, 
    'batchsize': 64, 
    'hidsize': [8, 8], 
    'lr': 0.0007, 
#     'alpha': 1.
})
run(args)
# Out:
# Logging to logs/nn/19-08-30-15-31-28
# {'dataset': 'heart', 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'e0': 0.2, 'e1': 0.2, 'equalize_prior': False, 'episodes': 1000, 'batchsize': 64, 'hidsize': [8, 8], 'lr': 0.0007}
# ---------------------------------
# | [PEER] alpha = -5  | 0.613    |
# | [PEER] alpha = 0.4 | 0.645    |
# | [PEER] alpha = 0.5 | 0.645    |
# | [PEER] alpha = 0.6 | 0.677    |
# | [PEER] alpha = 0.7 | 0.694    |
# | [PEER] alpha = 0.8 | 0.698    |
# | [PEER] alpha = 0.9 | 0.702    |
# | [PEER] alpha = 1.0 | 0.71     |
# | [PEER] alpha = 2.0 | 0.625    |
# | [PEER] alpha = 3.0 | 0.605    |
# | [PEER] alpha = 4.0 | 0.565    |
# | [PEER] alpha = 5.0 | 0.52     |
# ---------------------------------
# --------------------------------------
# | [NN] with bce loss      | 0.769    |
# | [NN] with peer loss     | 0.856    |
# | [NN] with surrogate ... | 0.813    |
# | [PEER] best alpha       | 1        |
# --------------------------------------
# Logging to logs/svm/19-08-30-15-32-04
# {'dataset': 'heart', 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'e0': 0.2, 'e1': 0.2, 'equalize_prior': False, 'episodes': 1000, 'batchsize': 64, 'hidsize': [8, 8], 'lr': 0.0007}
# --------------------------------
# | [C-SVM] C1 = 0.1  | 0.488    |
# | [C-SVM] C1 = 0.2  | 0.488    |
# | [C-SVM] C1 = 0.25 | 0.492    |
# | [C-SVM] C1 = 0.33 | 0.536    |
# | [C-SVM] C1 = 0.5  | 0.645    |
# | [C-SVM] C1 = 1.0  | 0.649    |
# | [C-SVM] C1 = 10.0 | 0.556    |
# | [C-SVM] C1 = 2.0  | 0.621    |
# | [C-SVM] C1 = 3.0  | 0.589    |
# | [C-SVM] C1 = 4.0  | 0.573    |
# | [C-SVM] C1 = 5.0  | 0.569    |
# --------------------------------
# ------------------------------------
# | [C-SVM] accuracy max  | 0.848    |
# | [C-SVM] accuracy mean | 0.796    |
# | [C-SVM] accuracy min  | 0.739    |
# | [C-SVM] accuracy std  | 0.0391   |
# | [C-SVM] best C1       | 1        |
# ------------------------------------
# Logging to logs/pam/19-08-30-15-32-04
# {'dataset': 'heart', 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'e0': 0.2, 'e1': 0.2, 'equalize_prior': False, 'episodes': 1000, 'batchsize': 64, 'hidsize': [8, 8], 'lr': 0.0007}
# -----------------------------------
# | [PAM] margin = 0     | 0.657    |
# | [PAM] margin = 0.125 | 0.645    |
# | [PAM] margin = 0.25  | 0.633    |
# | [PAM] margin = 0.5   | 0.661    |
# | [PAM] margin = 1     | 0.653    |
# -----------------------------------
# ----------------------------------
# | [PAM] accuracy max  | 0.87     |
# | [PAM] accuracy mean | 0.783    |
# | [PAM] accuracy min  | 0.674    |
# | [PAM] accuracy std  | 0.0704   |
# | [PAM] best margin   | 0.5      |
# ----------------------------------

# %%
from runner import run
args = default_args.copy()
args.update({
    'e0': 0.2, 'e1': 0.2, 
    'equalize_prior': False, 
    'episodes': 2000, 
    'batchsize': 32, 
    'hidsize': [8, 8], 
    'lr': 0.0007, 
#     'alpha': 1.
})
run(args)
# Out:
# Logging to logs/nn/19-08-30-15-20-40
# {'dataset': 'heart', 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'e0': 0.2, 'e1': 0.2, 'equalize_prior': False, 'episodes': 2000, 'batchsize': 32, 'hidsize': [8, 8], 'lr': 0.0007}
# ---------------------------------
# | [PEER] alpha = -5  | 0.613    |
# | [PEER] alpha = 0.4 | 0.649    |
# | [PEER] alpha = 0.5 | 0.649    |
# | [PEER] alpha = 0.6 | 0.69     |
# | [PEER] alpha = 0.7 | 0.694    |
# | [PEER] alpha = 0.8 | 0.706    |
# | [PEER] alpha = 0.9 | 0.706    |
# | [PEER] alpha = 1.0 | 0.714    |
# | [PEER] alpha = 2.0 | 0.625    |
# | [PEER] alpha = 3.0 | 0.601    |
# | [PEER] alpha = 4.0 | 0.52     |
# | [PEER] alpha = 5.0 | 0.52     |
# ---------------------------------
# --------------------------------------
# | [NN] with bce loss      | 0.758    |
# | [NN] with peer loss     | 0.861    |
# | [NN] with surrogate ... | 0.807    |
# | [PEER] best alpha       | 1        |
# --------------------------------------
# Logging to logs/svm/19-08-30-15-21-46
# {'dataset': 'heart', 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'e0': 0.2, 'e1': 0.2, 'equalize_prior': False, 'episodes': 2000, 'batchsize': 32, 'hidsize': [8, 8], 'lr': 0.0007}
# --------------------------------
# | [C-SVM] C1 = 0.1  | 0.488    |
# | [C-SVM] C1 = 0.2  | 0.488    |
# | [C-SVM] C1 = 0.25 | 0.492    |
# | [C-SVM] C1 = 0.33 | 0.536    |
# | [C-SVM] C1 = 0.5  | 0.645    |
# | [C-SVM] C1 = 1.0  | 0.649    |
# | [C-SVM] C1 = 10.0 | 0.556    |
# | [C-SVM] C1 = 2.0  | 0.621    |
# | [C-SVM] C1 = 3.0  | 0.589    |
# | [C-SVM] C1 = 4.0  | 0.573    |
# | [C-SVM] C1 = 5.0  | 0.569    |
# --------------------------------
# ------------------------------------
# | [C-SVM] accuracy max  | 0.848    |
# | [C-SVM] accuracy mean | 0.796    |
# | [C-SVM] accuracy min  | 0.739    |
# | [C-SVM] accuracy std  | 0.0391   |
# | [C-SVM] best C1       | 1        |
# ------------------------------------
# Logging to logs/pam/19-08-30-15-21-46
# {'dataset': 'heart', 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'e0': 0.2, 'e1': 0.2, 'equalize_prior': False, 'episodes': 2000, 'batchsize': 32, 'hidsize': [8, 8], 'lr': 0.0007}
# -----------------------------------
# | [PAM] margin = 0     | 0.657    |
# | [PAM] margin = 0.125 | 0.645    |
# | [PAM] margin = 0.25  | 0.633    |
# | [PAM] margin = 0.5   | 0.661    |
# | [PAM] margin = 1     | 0.653    |
# -----------------------------------
# ----------------------------------
# | [PAM] accuracy max  | 0.87     |
# | [PAM] accuracy mean | 0.783    |
# | [PAM] accuracy min  | 0.674    |
# | [PAM] accuracy std  | 0.0704   |
# | [PAM] best margin   | 0.5      |
# ----------------------------------

# %%
from runner import run
args = default_args.copy()
args.update({
    'dataset': 'heart', 
    'e0': 0.2, 'e1': 0.2, 
    'equalize_prior': False, 
    'episodes': 1000, 
#     'batchsize': 4, 
#     'hidsize': [32, 32], 
#     'lr': 0.005, 
#     'alpha': 1.
})
run(args)
# Out:
# Logging to logs/nn/19-08-28-11-34-02
# {'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'dataset': 'heart', 'e0': 0.2, 'e1': 0.2, 'equalize_prior': False, 'episodes': 1000}
# acc:0.709	batchsize: 1	lr:0.0007	hidsize:[8, 8]
# acc:0.791	batchsize: 1	lr:0.0007	hidsize:[16, 16]
# acc:0.84	batchsize: 1	lr:0.0007	hidsize:[32, 32]
# acc:0.834	batchsize: 1	lr:0.0007	hidsize:[64, 64]
# acc:0.791	batchsize: 1	lr: 0.001	hidsize:[8, 8]
# acc:0.815	batchsize: 1	lr: 0.001	hidsize:[16, 16]
# acc:0.84	batchsize: 1	lr: 0.001	hidsize:[32, 32]
# acc:0.837	batchsize: 1	lr: 0.001	hidsize:[64, 64]
# acc:0.853	batchsize: 1	lr: 0.005	hidsize:[8, 8]
# acc:0.859	batchsize: 1	lr: 0.005	hidsize:[16, 16]
# acc:0.842	batchsize: 1	lr: 0.005	hidsize:[32, 32]
# acc:0.859	batchsize: 1	lr: 0.005	hidsize:[64, 64]
# acc:0.842	batchsize: 1	lr:  0.01	hidsize:[8, 8]
# acc:0.861	batchsize: 1	lr:  0.01	hidsize:[16, 16]
# acc:0.851	batchsize: 1	lr:  0.01	hidsize:[32, 32]
# acc:0.851	batchsize: 1	lr:  0.01	hidsize:[64, 64]
# acc:0.851	batchsize: 1	lr:  0.05	hidsize:[8, 8]
# acc:0.791	batchsize: 1	lr:  0.05	hidsize:[16, 16]
# acc:0.851	batchsize: 1	lr:  0.05	hidsize:[32, 32]
# acc:0.842	batchsize: 1	lr:  0.05	hidsize:[64, 64]
# acc:0.791	batchsize: 4	lr:0.0007	hidsize:[8, 8]
# acc:0.845	batchsize: 4	lr:0.0007	hidsize:[16, 16]
# acc:0.845	batchsize: 4	lr:0.0007	hidsize:[32, 32]
# acc:0.853	batchsize: 4	lr:0.0007	hidsize:[64, 64]
# acc:0.834	batchsize: 4	lr: 0.001	hidsize:[8, 8]
# acc:0.853	batchsize: 4	lr: 0.001	hidsize:[16, 16]
# acc:0.851	batchsize: 4	lr: 0.001	hidsize:[32, 32]
# acc:0.851	batchsize: 4	lr: 0.001	hidsize:[64, 64]
# acc:0.848	batchsize: 4	lr: 0.005	hidsize:[8, 8]
# acc:0.856	batchsize: 4	lr: 0.005	hidsize:[16, 16]
# acc:0.845	batchsize: 4	lr: 0.005	hidsize:[32, 32]
# acc:0.845	batchsize: 4	lr: 0.005	hidsize:[64, 64]
# acc:0.856	batchsize: 4	lr:  0.01	hidsize:[8, 8]
# acc:0.851	batchsize: 4	lr:  0.01	hidsize:[16, 16]
# acc:0.845	batchsize: 4	lr:  0.01	hidsize:[32, 32]
# acc:0.842	batchsize: 4	lr:  0.01	hidsize:[64, 64]
# acc:0.796	batchsize: 4	lr:  0.05	hidsize:[8, 8]
# acc:0.81	batchsize: 4	lr:  0.05	hidsize:[16, 16]
# acc:0.851	batchsize: 4	lr:  0.05	hidsize:[32, 32]
# acc:0.853	batchsize: 4	lr:  0.05	hidsize:[64, 64]
# acc:0.851	batchsize:16	lr:0.0007	hidsize:[8, 8]
# acc:0.853	batchsize:16	lr:0.0007	hidsize:[16, 16]
# acc:0.842	batchsize:16	lr:0.0007	hidsize:[32, 32]
# acc:0.848	batchsize:16	lr:0.0007	hidsize:[64, 64]
# acc:0.848	batchsize:16	lr: 0.001	hidsize:[8, 8]
# acc:0.856	batchsize:16	lr: 0.001	hidsize:[16, 16]
# acc:0.845	batchsize:16	lr: 0.001	hidsize:[32, 32]
# acc:0.851	batchsize:16	lr: 0.001	hidsize:[64, 64]
# acc:0.859	batchsize:16	lr: 0.005	hidsize:[8, 8]
# acc:0.853	batchsize:16	lr: 0.005	hidsize:[16, 16]
# acc:0.851	batchsize:16	lr: 0.005	hidsize:[32, 32]
# acc:0.861	batchsize:16	lr: 0.005	hidsize:[64, 64]
# acc:0.859	batchsize:16	lr:  0.01	hidsize:[8, 8]
# acc:0.851	batchsize:16	lr:  0.01	hidsize:[16, 16]
# acc:0.856	batchsize:16	lr:  0.01	hidsize:[32, 32]
# acc:0.856	batchsize:16	lr:  0.01	hidsize:[64, 64]
# acc:0.796	batchsize:16	lr:  0.05	hidsize:[8, 8]
# acc:0.845	batchsize:16	lr:  0.05	hidsize:[16, 16]
# acc:0.859	batchsize:16	lr:  0.05	hidsize:[32, 32]
# acc:0.856	batchsize:16	lr:  0.05	hidsize:[64, 64]
# acc:0.856	batchsize:32	lr:0.0007	hidsize:[8, 8]
# acc:0.856	batchsize:32	lr:0.0007	hidsize:[16, 16]
# acc:0.845	batchsize:32	lr:0.0007	hidsize:[32, 32]
# acc:0.851	batchsize:32	lr:0.0007	hidsize:[64, 64]
# acc:0.856	batchsize:32	lr: 0.001	hidsize:[8, 8]
# acc:0.859	batchsize:32	lr: 0.001	hidsize:[16, 16]
# acc:0.845	batchsize:32	lr: 0.001	hidsize:[32, 32]
# acc:0.853	batchsize:32	lr: 0.001	hidsize:[64, 64]
# acc:0.856	batchsize:32	lr: 0.005	hidsize:[8, 8]
# acc:0.853	batchsize:32	lr: 0.005	hidsize:[16, 16]
# acc:0.853	batchsize:32	lr: 0.005	hidsize:[32, 32]
# acc:0.859	batchsize:32	lr: 0.005	hidsize:[64, 64]
# acc:0.864	batchsize:32	lr:  0.01	hidsize:[8, 8]
# acc:0.861	batchsize:32	lr:  0.01	hidsize:[16, 16]
# acc:0.861	batchsize:32	lr:  0.01	hidsize:[32, 32]
# acc:0.856	batchsize:32	lr:  0.01	hidsize:[64, 64]
# acc:0.864	batchsize:32	lr:  0.05	hidsize:[8, 8]
# acc:0.861	batchsize:32	lr:  0.05	hidsize:[16, 16]
# acc:0.859	batchsize:32	lr:  0.05	hidsize:[32, 32]
# acc:0.845	batchsize:32	lr:  0.05	hidsize:[64, 64]
# acc:0.856	batchsize:64	lr:0.0007	hidsize:[8, 8]
# acc:0.859	batchsize:64	lr:0.0007	hidsize:[16, 16]
# acc:0.853	batchsize:64	lr:0.0007	hidsize:[32, 32]
# acc:0.859	batchsize:64	lr:0.0007	hidsize:[64, 64]
# acc:0.859	batchsize:64	lr: 0.001	hidsize:[8, 8]
# acc:0.859	batchsize:64	lr: 0.001	hidsize:[16, 16]
# acc:0.856	batchsize:64	lr: 0.001	hidsize:[32, 32]
# acc:0.859	batchsize:64	lr: 0.001	hidsize:[64, 64]
# acc:0.859	batchsize:64	lr: 0.005	hidsize:[8, 8]
# acc:0.853	batchsize:64	lr: 0.005	hidsize:[16, 16]
# acc:0.853	batchsize:64	lr: 0.005	hidsize:[32, 32]
# acc:0.864	batchsize:64	lr: 0.005	hidsize:[64, 64]
# acc:0.859	batchsize:64	lr:  0.01	hidsize:[8, 8]
# acc:0.853	batchsize:64	lr:  0.01	hidsize:[16, 16]
# acc:0.851	batchsize:64	lr:  0.01	hidsize:[32, 32]
# acc:0.853	batchsize:64	lr:  0.01	hidsize:[64, 64]
# acc:0.856	batchsize:64	lr:  0.05	hidsize:[8, 8]
# acc:0.859	batchsize:64	lr:  0.05	hidsize:[16, 16]
# acc:0.851	batchsize:64	lr:  0.05	hidsize:[32, 32]
# acc:0.851	batchsize:64	lr:  0.05	hidsize:[64, 64]
# --------------------------------------
# | [PEER] best batchsize   | 32       |
# | [PEER] best hidsize     | [8, 8]   |
# | [PEER] best learning... | 0.01     |
# --------------------------------------
# ---------------------------------
# | [PEER] alpha = 0.1 | 0.645    |
# | [PEER] alpha = 0.2 | 0.641    |
# | [PEER] alpha = 0.3 | 0.601    |
# | [PEER] alpha = 0.4 | 0.633    |
# | [PEER] alpha = 0.5 | 0.633    |
# | [PEER] alpha = 0.6 | 0.69     |
# | [PEER] alpha = 0.7 | 0.677    |
# | [PEER] alpha = 0.8 | 0.694    |
# | [PEER] alpha = 0.9 | 0.698    |
# | [PEER] alpha = 1.0 | 0.714    |
# ---------------------------------
# --------------------------------------
# | [NN] with bce loss      | 0.66     |
# | [NN] with peer loss     | 0.864    |
# | [NN] with surrogate ... | 0.783    |
# | [PEER] best alpha       | 1        |
# --------------------------------------
# Logging to logs/svm/19-08-28-11-39-17
# {'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'dataset': 'heart', 'e0': 0.2, 'e1': 0.2, 'equalize_prior': False, 'episodes': 1000}
# --------------------------------
# | [C-SVM] C1 = 0.1  | 0.488    |
# | [C-SVM] C1 = 0.2  | 0.488    |
# | [C-SVM] C1 = 0.25 | 0.492    |
# | [C-SVM] C1 = 0.33 | 0.536    |
# | [C-SVM] C1 = 0.5  | 0.645    |
# | [C-SVM] C1 = 1.0  | 0.649    |
# | [C-SVM] C1 = 10.0 | 0.556    |
# | [C-SVM] C1 = 2.0  | 0.621    |
# | [C-SVM] C1 = 3.0  | 0.589    |
# | [C-SVM] C1 = 4.0  | 0.573    |
# | [C-SVM] C1 = 5.0  | 0.569    |
# --------------------------------
# ------------------------------------
# | [C-SVM] accuracy max  | 0.848    |
# | [C-SVM] accuracy mean | 0.796    |
# | [C-SVM] accuracy min  | 0.739    |
# | [C-SVM] accuracy std  | 0.0391   |
# | [C-SVM] best C1       | 1        |
# ------------------------------------
# Logging to logs/pam/19-08-28-11-39-18
# {'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'dataset': 'heart', 'e0': 0.2, 'e1': 0.2, 'equalize_prior': False, 'episodes': 1000}
# -----------------------------------
# | [PAM] margin = 0     | 0.657    |
# | [PAM] margin = 0.125 | 0.645    |
# | [PAM] margin = 0.25  | 0.633    |
# | [PAM] margin = 0.5   | 0.661    |
# | [PAM] margin = 1     | 0.653    |
# -----------------------------------
# ----------------------------------
# | [PAM] accuracy max  | 0.87     |
# | [PAM] accuracy mean | 0.783    |
# | [PAM] accuracy min  | 0.674    |
# | [PAM] accuracy std  | 0.0704   |
# | [PAM] best margin   | 0.5      |
# ----------------------------------

# %% [markdown]
# ### $e_0 = 0.1, e_1 = 0.4$

# %%
from runner import run
args = default_args.copy()
args.update({
    'e0': 0.1, 'e1': 0.4, 
    'equalize_prior': False, 
    'episodes': 1000, 
    'batchsize': 64, 
    'hidsize': [8, 8], 
    'lr': 0.0007, 
#     'alpha': 1.
})
run(args)
# Out:
# Logging to logs/nn/19-08-30-15-30-48
# {'dataset': 'heart', 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'e0': 0.1, 'e1': 0.4, 'equalize_prior': False, 'episodes': 1000, 'batchsize': 64, 'hidsize': [8, 8], 'lr': 0.0007}
# ---------------------------------
# | [PEER] alpha = -5  | 0.637    |
# | [PEER] alpha = 0.4 | 0.629    |
# | [PEER] alpha = 0.5 | 0.653    |
# | [PEER] alpha = 0.6 | 0.629    |
# | [PEER] alpha = 0.7 | 0.637    |
# | [PEER] alpha = 0.8 | 0.637    |
# | [PEER] alpha = 0.9 | 0.657    |
# | [PEER] alpha = 1.0 | 0.661    |
# | [PEER] alpha = 2.0 | 0.476    |
# | [PEER] alpha = 3.0 | 0.44     |
# | [PEER] alpha = 4.0 | 0.407    |
# | [PEER] alpha = 5.0 | 0.363    |
# ---------------------------------
# --------------------------------------
# | [NN] with bce loss      | 0.723    |
# | [NN] with peer loss     | 0.859    |
# | [NN] with surrogate ... | 0.815    |
# | [PEER] best alpha       | 1        |
# --------------------------------------
# Logging to logs/svm/19-08-30-15-31-25
# {'dataset': 'heart', 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'e0': 0.1, 'e1': 0.4, 'equalize_prior': False, 'episodes': 1000, 'batchsize': 64, 'hidsize': [8, 8], 'lr': 0.0007}
# --------------------------------
# | [C-SVM] C1 = 0.1  | 0.637    |
# | [C-SVM] C1 = 0.2  | 0.637    |
# | [C-SVM] C1 = 0.25 | 0.637    |
# | [C-SVM] C1 = 0.33 | 0.637    |
# | [C-SVM] C1 = 0.5  | 0.633    |
# | [C-SVM] C1 = 1.0  | 0.685    |
# | [C-SVM] C1 = 10.0 | 0.532    |
# | [C-SVM] C1 = 2.0  | 0.641    |
# | [C-SVM] C1 = 3.0  | 0.573    |
# | [C-SVM] C1 = 4.0  | 0.56     |
# | [C-SVM] C1 = 5.0  | 0.552    |
# --------------------------------
# ------------------------------------
# | [C-SVM] accuracy max  | 0.783    |
# | [C-SVM] accuracy mean | 0.677    |
# | [C-SVM] accuracy min  | 0.609    |
# | [C-SVM] accuracy std  | 0.0479   |
# | [C-SVM] best C1       | 1        |
# ------------------------------------
# Logging to logs/pam/19-08-30-15-31-25
# {'dataset': 'heart', 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'e0': 0.1, 'e1': 0.4, 'equalize_prior': False, 'episodes': 1000, 'batchsize': 64, 'hidsize': [8, 8], 'lr': 0.0007}
# -----------------------------------
# | [PAM] margin = 0     | 0.597    |
# | [PAM] margin = 0.125 | 0.633    |
# | [PAM] margin = 0.25  | 0.653    |
# | [PAM] margin = 0.5   | 0.661    |
# | [PAM] margin = 1     | 0.665    |
# -----------------------------------
# ----------------------------------
# | [PAM] accuracy max  | 0.848    |
# | [PAM] accuracy mean | 0.742    |
# | [PAM] accuracy min  | 0.63     |
# | [PAM] accuracy std  | 0.0749   |
# | [PAM] best margin   | 1        |
# ----------------------------------

# %%
from runner import run
args = default_args.copy()
args.update({
    'e0': 0.1, 'e1': 0.4, 
    'equalize_prior': False, 
    'episodes': 2000, 
    'batchsize': 32, 
    'hidsize': [8, 8], 
    'lr': 0.0007, 
#     'alpha': 1.
})
run(args)
# Out:
# Logging to logs/nn/19-08-30-15-19-28
# {'dataset': 'heart', 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'e0': 0.1, 'e1': 0.4, 'equalize_prior': False, 'episodes': 2000, 'batchsize': 32, 'hidsize': [8, 8], 'lr': 0.0007}
# ---------------------------------
# | [PEER] alpha = -5  | 0.637    |
# | [PEER] alpha = 0.4 | 0.633    |
# | [PEER] alpha = 0.5 | 0.637    |
# | [PEER] alpha = 0.6 | 0.645    |
# | [PEER] alpha = 0.7 | 0.657    |
# | [PEER] alpha = 0.8 | 0.653    |
# | [PEER] alpha = 0.9 | 0.661    |
# | [PEER] alpha = 1.0 | 0.677    |
# | [PEER] alpha = 2.0 | 0.456    |
# | [PEER] alpha = 3.0 | 0.403    |
# | [PEER] alpha = 4.0 | 0.407    |
# | [PEER] alpha = 5.0 | 0.363    |
# ---------------------------------
# --------------------------------------
# | [NN] with bce loss      | 0.693    |
# | [NN] with peer loss     | 0.851    |
# | [NN] with surrogate ... | 0.799    |
# | [PEER] best alpha       | 1        |
# --------------------------------------
# Logging to logs/svm/19-08-30-15-20-37
# {'dataset': 'heart', 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'e0': 0.1, 'e1': 0.4, 'equalize_prior': False, 'episodes': 2000, 'batchsize': 32, 'hidsize': [8, 8], 'lr': 0.0007}
# --------------------------------
# | [C-SVM] C1 = 0.1  | 0.637    |
# | [C-SVM] C1 = 0.2  | 0.637    |
# | [C-SVM] C1 = 0.25 | 0.637    |
# | [C-SVM] C1 = 0.33 | 0.637    |
# | [C-SVM] C1 = 0.5  | 0.633    |
# | [C-SVM] C1 = 1.0  | 0.685    |
# | [C-SVM] C1 = 10.0 | 0.532    |
# | [C-SVM] C1 = 2.0  | 0.641    |
# | [C-SVM] C1 = 3.0  | 0.573    |
# | [C-SVM] C1 = 4.0  | 0.56     |
# | [C-SVM] C1 = 5.0  | 0.552    |
# --------------------------------
# ------------------------------------
# | [C-SVM] accuracy max  | 0.783    |
# | [C-SVM] accuracy mean | 0.677    |
# | [C-SVM] accuracy min  | 0.609    |
# | [C-SVM] accuracy std  | 0.0479   |
# | [C-SVM] best C1       | 1        |
# ------------------------------------
# Logging to logs/pam/19-08-30-15-20-37
# {'dataset': 'heart', 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'e0': 0.1, 'e1': 0.4, 'equalize_prior': False, 'episodes': 2000, 'batchsize': 32, 'hidsize': [8, 8], 'lr': 0.0007}
# -----------------------------------
# | [PAM] margin = 0     | 0.597    |
# | [PAM] margin = 0.125 | 0.633    |
# | [PAM] margin = 0.25  | 0.653    |
# | [PAM] margin = 0.5   | 0.661    |
# | [PAM] margin = 1     | 0.665    |
# -----------------------------------
# ----------------------------------
# | [PAM] accuracy max  | 0.848    |
# | [PAM] accuracy mean | 0.742    |
# | [PAM] accuracy min  | 0.63     |
# | [PAM] accuracy std  | 0.0749   |
# | [PAM] best margin   | 1        |
# ----------------------------------

# %%
from runner import run
args = default_args.copy()
args.update({
    'dataset': 'heart', 
    'e0': 0.1, 'e1': 0.4, 
    'equalize_prior': False, 
    'episodes': 1000, 
#     'batchsize': 4, 
#     'hidsize': [32, 32], 
#     'lr': 0.005, 
#     'alpha': 1.
})
run(args)
# Out:
# Logging to logs/nn/19-08-28-11-39-22
# {'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'dataset': 'heart', 'e0': 0.1, 'e1': 0.4, 'equalize_prior': False, 'episodes': 1000}
# acc:0.636	batchsize: 1	lr:0.0007	hidsize:[8, 8]
# acc:0.75	batchsize: 1	lr:0.0007	hidsize:[16, 16]
# acc:0.837	batchsize: 1	lr:0.0007	hidsize:[32, 32]
# acc:0.826	batchsize: 1	lr:0.0007	hidsize:[64, 64]
# acc:0.707	batchsize: 1	lr: 0.001	hidsize:[8, 8]
# acc:0.785	batchsize: 1	lr: 0.001	hidsize:[16, 16]
# acc:0.84	batchsize: 1	lr: 0.001	hidsize:[32, 32]
# acc:0.832	batchsize: 1	lr: 0.001	hidsize:[64, 64]
# acc:0.815	batchsize: 1	lr: 0.005	hidsize:[8, 8]
# acc:0.807	batchsize: 1	lr: 0.005	hidsize:[16, 16]
# acc:0.829	batchsize: 1	lr: 0.005	hidsize:[32, 32]
# acc:0.834	batchsize: 1	lr: 0.005	hidsize:[64, 64]
# acc:0.804	batchsize: 1	lr:  0.01	hidsize:[8, 8]
# acc:0.813	batchsize: 1	lr:  0.01	hidsize:[16, 16]
# acc:0.815	batchsize: 1	lr:  0.01	hidsize:[32, 32]
# acc:0.823	batchsize: 1	lr:  0.01	hidsize:[64, 64]
# acc:0.693	batchsize: 1	lr:  0.05	hidsize:[8, 8]
# acc:0.758	batchsize: 1	lr:  0.05	hidsize:[16, 16]
# acc:0.717	batchsize: 1	lr:  0.05	hidsize:[32, 32]
# acc:0.826	batchsize: 1	lr:  0.05	hidsize:[64, 64]
# acc:0.78	batchsize: 4	lr:0.0007	hidsize:[8, 8]
# acc:0.832	batchsize: 4	lr:0.0007	hidsize:[16, 16]
# acc:0.832	batchsize: 4	lr:0.0007	hidsize:[32, 32]
# acc:0.842	batchsize: 4	lr:0.0007	hidsize:[64, 64]
# acc:0.832	batchsize: 4	lr: 0.001	hidsize:[8, 8]
# acc:0.834	batchsize: 4	lr: 0.001	hidsize:[16, 16]
# acc:0.84	batchsize: 4	lr: 0.001	hidsize:[32, 32]
# acc:0.842	batchsize: 4	lr: 0.001	hidsize:[64, 64]
# acc:0.842	batchsize: 4	lr: 0.005	hidsize:[8, 8]
# acc:0.84	batchsize: 4	lr: 0.005	hidsize:[16, 16]
# acc:0.842	batchsize: 4	lr: 0.005	hidsize:[32, 32]
# acc:0.84	batchsize: 4	lr: 0.005	hidsize:[64, 64]
# acc:0.845	batchsize: 4	lr:  0.01	hidsize:[8, 8]
# acc:0.853	batchsize: 4	lr:  0.01	hidsize:[16, 16]
# acc:0.837	batchsize: 4	lr:  0.01	hidsize:[32, 32]
# acc:0.834	batchsize: 4	lr:  0.01	hidsize:[64, 64]
# acc:0.728	batchsize: 4	lr:  0.05	hidsize:[8, 8]
# acc:0.747	batchsize: 4	lr:  0.05	hidsize:[16, 16]
# acc:0.84	batchsize: 4	lr:  0.05	hidsize:[32, 32]
# acc:0.826	batchsize: 4	lr:  0.05	hidsize:[64, 64]
# acc:0.845	batchsize:16	lr:0.0007	hidsize:[8, 8]
# acc:0.832	batchsize:16	lr:0.0007	hidsize:[16, 16]
# acc:0.84	batchsize:16	lr:0.0007	hidsize:[32, 32]
# acc:0.837	batchsize:16	lr:0.0007	hidsize:[64, 64]
# acc:0.845	batchsize:16	lr: 0.001	hidsize:[8, 8]
# acc:0.845	batchsize:16	lr: 0.001	hidsize:[16, 16]
# acc:0.84	batchsize:16	lr: 0.001	hidsize:[32, 32]
# acc:0.84	batchsize:16	lr: 0.001	hidsize:[64, 64]
# acc:0.842	batchsize:16	lr: 0.005	hidsize:[8, 8]
# acc:0.845	batchsize:16	lr: 0.005	hidsize:[16, 16]
# acc:0.848	batchsize:16	lr: 0.005	hidsize:[32, 32]
# acc:0.842	batchsize:16	lr: 0.005	hidsize:[64, 64]
# acc:0.845	batchsize:16	lr:  0.01	hidsize:[8, 8]
# acc:0.842	batchsize:16	lr:  0.01	hidsize:[16, 16]
# acc:0.84	batchsize:16	lr:  0.01	hidsize:[32, 32]
# acc:0.84	batchsize:16	lr:  0.01	hidsize:[64, 64]
# acc:0.842	batchsize:16	lr:  0.05	hidsize:[8, 8]
# acc:0.837	batchsize:16	lr:  0.05	hidsize:[16, 16]
# acc:0.834	batchsize:16	lr:  0.05	hidsize:[32, 32]
# acc:0.834	batchsize:16	lr:  0.05	hidsize:[64, 64]
# acc:0.851	batchsize:32	lr:0.0007	hidsize:[8, 8]
# acc:0.842	batchsize:32	lr:0.0007	hidsize:[16, 16]
# acc:0.837	batchsize:32	lr:0.0007	hidsize:[32, 32]
# acc:0.845	batchsize:32	lr:0.0007	hidsize:[64, 64]
# acc:0.851	batchsize:32	lr: 0.001	hidsize:[8, 8]
# acc:0.842	batchsize:32	lr: 0.001	hidsize:[16, 16]
# acc:0.84	batchsize:32	lr: 0.001	hidsize:[32, 32]
# acc:0.845	batchsize:32	lr: 0.001	hidsize:[64, 64]
# acc:0.851	batchsize:32	lr: 0.005	hidsize:[8, 8]
# acc:0.842	batchsize:32	lr: 0.005	hidsize:[16, 16]
# acc:0.842	batchsize:32	lr: 0.005	hidsize:[32, 32]
# acc:0.845	batchsize:32	lr: 0.005	hidsize:[64, 64]
# acc:0.851	batchsize:32	lr:  0.01	hidsize:[8, 8]
# acc:0.842	batchsize:32	lr:  0.01	hidsize:[16, 16]
# acc:0.842	batchsize:32	lr:  0.01	hidsize:[32, 32]
# acc:0.84	batchsize:32	lr:  0.01	hidsize:[64, 64]
# acc:0.842	batchsize:32	lr:  0.05	hidsize:[8, 8]
# acc:0.848	batchsize:32	lr:  0.05	hidsize:[16, 16]
# acc:0.832	batchsize:32	lr:  0.05	hidsize:[32, 32]
# acc:0.84	batchsize:32	lr:  0.05	hidsize:[64, 64]
# acc:0.859	batchsize:64	lr:0.0007	hidsize:[8, 8]
# acc:0.845	batchsize:64	lr:0.0007	hidsize:[16, 16]
# acc:0.842	batchsize:64	lr:0.0007	hidsize:[32, 32]
# acc:0.842	batchsize:64	lr:0.0007	hidsize:[64, 64]
# acc:0.856	batchsize:64	lr: 0.001	hidsize:[8, 8]
# acc:0.845	batchsize:64	lr: 0.001	hidsize:[16, 16]
# acc:0.842	batchsize:64	lr: 0.001	hidsize:[32, 32]
# acc:0.842	batchsize:64	lr: 0.001	hidsize:[64, 64]
# acc:0.851	batchsize:64	lr: 0.005	hidsize:[8, 8]
# acc:0.845	batchsize:64	lr: 0.005	hidsize:[16, 16]
# acc:0.84	batchsize:64	lr: 0.005	hidsize:[32, 32]
# acc:0.84	batchsize:64	lr: 0.005	hidsize:[64, 64]
# acc:0.851	batchsize:64	lr:  0.01	hidsize:[8, 8]
# acc:0.845	batchsize:64	lr:  0.01	hidsize:[16, 16]
# acc:0.834	batchsize:64	lr:  0.01	hidsize:[32, 32]
# acc:0.84	batchsize:64	lr:  0.01	hidsize:[64, 64]
# acc:0.848	batchsize:64	lr:  0.05	hidsize:[8, 8]
# acc:0.84	batchsize:64	lr:  0.05	hidsize:[16, 16]
# acc:0.837	batchsize:64	lr:  0.05	hidsize:[32, 32]
# acc:0.832	batchsize:64	lr:  0.05	hidsize:[64, 64]
# --------------------------------------
# | [PEER] best batchsize   | 64       |
# | [PEER] best hidsize     | [8, 8]   |
# | [PEER] best learning... | 0.0007   |
# --------------------------------------
# ---------------------------------
# | [PEER] alpha = 0.1 | 0.625    |
# | [PEER] alpha = 0.2 | 0.645    |
# | [PEER] alpha = 0.3 | 0.625    |
# | [PEER] alpha = 0.4 | 0.629    |
# | [PEER] alpha = 0.5 | 0.653    |
# | [PEER] alpha = 0.6 | 0.629    |
# | [PEER] alpha = 0.7 | 0.637    |
# | [PEER] alpha = 0.8 | 0.637    |
# | [PEER] alpha = 0.9 | 0.657    |
# | [PEER] alpha = 1.0 | 0.661    |
# ---------------------------------
# --------------------------------------
# | [NN] with bce loss      | 0.723    |
# | [NN] with peer loss     | 0.859    |
# | [NN] with surrogate ... | 0.815    |
# | [PEER] best alpha       | 1        |
# --------------------------------------
# Logging to logs/svm/19-08-28-11-44-42
# {'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'dataset': 'heart', 'e0': 0.1, 'e1': 0.4, 'equalize_prior': False, 'episodes': 1000}
# --------------------------------
# | [C-SVM] C1 = 0.1  | 0.637    |
# | [C-SVM] C1 = 0.2  | 0.637    |
# | [C-SVM] C1 = 0.25 | 0.637    |
# | [C-SVM] C1 = 0.33 | 0.637    |
# | [C-SVM] C1 = 0.5  | 0.633    |
# | [C-SVM] C1 = 1.0  | 0.685    |
# | [C-SVM] C1 = 10.0 | 0.532    |
# | [C-SVM] C1 = 2.0  | 0.641    |
# | [C-SVM] C1 = 3.0  | 0.573    |
# | [C-SVM] C1 = 4.0  | 0.56     |
# | [C-SVM] C1 = 5.0  | 0.552    |
# --------------------------------
# ------------------------------------
# | [C-SVM] accuracy max  | 0.783    |
# | [C-SVM] accuracy mean | 0.677    |
# | [C-SVM] accuracy min  | 0.609    |
# | [C-SVM] accuracy std  | 0.0479   |
# | [C-SVM] best C1       | 1        |
# ------------------------------------
# Logging to logs/pam/19-08-28-11-44-43
# {'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'dataset': 'heart', 'e0': 0.1, 'e1': 0.4, 'equalize_prior': False, 'episodes': 1000}
# -----------------------------------
# | [PAM] margin = 0     | 0.597    |
# | [PAM] margin = 0.125 | 0.633    |
# | [PAM] margin = 0.25  | 0.653    |
# | [PAM] margin = 0.5   | 0.661    |
# | [PAM] margin = 1     | 0.665    |
# -----------------------------------
# ----------------------------------
# | [PAM] accuracy max  | 0.848    |
# | [PAM] accuracy mean | 0.742    |
# | [PAM] accuracy min  | 0.63     |
# | [PAM] accuracy std  | 0.0749   |
# | [PAM] best margin   | 1        |
# ----------------------------------

# %% [markdown]
# ### $e_0 = 0.2, e_1 = 0.4$

# %%
from runner import run
args = default_args.copy()
args.update({
    'e0': 0.2, 'e1': 0.4, 
    'equalize_prior': False, 
    'episodes': 1000, 
    'batchsize': 64, 
    'hidsize': [8, 8], 
    'lr': 0.0007, 
#     'alpha': 1.
})
run(args)
# Out:
# Logging to logs/nn/19-08-30-15-29-06
# {'dataset': 'heart', 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'e0': 0.2, 'e1': 0.4, 'equalize_prior': False, 'episodes': 1000, 'batchsize': 64, 'hidsize': [8, 8], 'lr': 0.0007}
# ---------------------------------
# | [PEER] alpha = -5  | 0.593    |
# | [PEER] alpha = 0.4 | 0.581    |
# | [PEER] alpha = 0.5 | 0.577    |
# | [PEER] alpha = 0.6 | 0.585    |
# | [PEER] alpha = 0.7 | 0.597    |
# | [PEER] alpha = 0.8 | 0.609    |
# | [PEER] alpha = 0.9 | 0.613    |
# | [PEER] alpha = 1.0 | 0.637    |
# | [PEER] alpha = 2.0 | 0.48     |
# | [PEER] alpha = 3.0 | 0.456    |
# | [PEER] alpha = 4.0 | 0.456    |
# | [PEER] alpha = 5.0 | 0.456    |
# ---------------------------------
# --------------------------------------
# | [NN] with bce loss      | 0.693    |
# | [NN] with peer loss     | 0.856    |
# | [NN] with surrogate ... | 0.758    |
# | [PEER] best alpha       | 1        |
# --------------------------------------
# Logging to logs/svm/19-08-30-15-29-41
# {'dataset': 'heart', 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'e0': 0.2, 'e1': 0.4, 'equalize_prior': False, 'episodes': 1000, 'batchsize': 64, 'hidsize': [8, 8], 'lr': 0.0007}
# --------------------------------
# | [C-SVM] C1 = 0.1  | 0.593    |
# | [C-SVM] C1 = 0.2  | 0.593    |
# | [C-SVM] C1 = 0.25 | 0.593    |
# | [C-SVM] C1 = 0.33 | 0.593    |
# | [C-SVM] C1 = 0.5  | 0.593    |
# | [C-SVM] C1 = 1.0  | 0.657    |
# | [C-SVM] C1 = 10.0 | 0.476    |
# | [C-SVM] C1 = 2.0  | 0.544    |
# | [C-SVM] C1 = 3.0  | 0.496    |
# | [C-SVM] C1 = 4.0  | 0.484    |
# | [C-SVM] C1 = 5.0  | 0.488    |
# --------------------------------
# ------------------------------------
# | [C-SVM] accuracy max  | 0.783    |
# | [C-SVM] accuracy mean | 0.704    |
# | [C-SVM] accuracy min  | 0.63     |
# | [C-SVM] accuracy std  | 0.046    |
# | [C-SVM] best C1       | 1        |
# ------------------------------------
# Logging to logs/pam/19-08-30-15-29-41
# {'dataset': 'heart', 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'e0': 0.2, 'e1': 0.4, 'equalize_prior': False, 'episodes': 1000, 'batchsize': 64, 'hidsize': [8, 8], 'lr': 0.0007}
# -----------------------------------
# | [PAM] margin = 0     | 0.577    |
# | [PAM] margin = 0.125 | 0.593    |
# | [PAM] margin = 0.25  | 0.593    |
# | [PAM] margin = 0.5   | 0.589    |
# | [PAM] margin = 1     | 0.593    |
# -----------------------------------
# ----------------------------------
# | [PAM] accuracy max  | 0.804    |
# | [PAM] accuracy mean | 0.715    |
# | [PAM] accuracy min  | 0.63     |
# | [PAM] accuracy std  | 0.0515   |
# | [PAM] best margin   | 0.125    |
# ----------------------------------

# %%
from runner import run
args = default_args.copy()
args.update({
    'dataset': 'heart', 
    'e0': 0.2, 'e1': 0.4, 
    'equalize_prior': False, 
    'episodes': 1000, 
#     'batchsize': 4, 
#     'hidsize': [32, 32], 
#     'lr': 0.005, 
#     'alpha': 1.
})
run(args)
# Out:
# Logging to logs/nn/19-08-28-11-44-46
# {'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'dataset': 'heart', 'e0': 0.2, 'e1': 0.4, 'equalize_prior': False, 'episodes': 1000}
# acc:0.611	batchsize: 1	lr:0.0007	hidsize:[8, 8]
# acc:0.728	batchsize: 1	lr:0.0007	hidsize:[16, 16]
# acc:0.823	batchsize: 1	lr:0.0007	hidsize:[32, 32]
# acc:0.821	batchsize: 1	lr:0.0007	hidsize:[64, 64]
# acc:0.652	batchsize: 1	lr: 0.001	hidsize:[8, 8]
# acc:0.75	batchsize: 1	lr: 0.001	hidsize:[16, 16]
# acc:0.823	batchsize: 1	lr: 0.001	hidsize:[32, 32]
# acc:0.81	batchsize: 1	lr: 0.001	hidsize:[64, 64]
# acc:0.766	batchsize: 1	lr: 0.005	hidsize:[8, 8]
# acc:0.799	batchsize: 1	lr: 0.005	hidsize:[16, 16]
# acc:0.818	batchsize: 1	lr: 0.005	hidsize:[32, 32]
# acc:0.812	batchsize: 1	lr: 0.005	hidsize:[64, 64]
# acc:0.791	batchsize: 1	lr:  0.01	hidsize:[8, 8]
# acc:0.802	batchsize: 1	lr:  0.01	hidsize:[16, 16]
# acc:0.793	batchsize: 1	lr:  0.01	hidsize:[32, 32]
# acc:0.804	batchsize: 1	lr:  0.01	hidsize:[64, 64]
# acc:0.609	batchsize: 1	lr:  0.05	hidsize:[8, 8]
# acc:0.693	batchsize: 1	lr:  0.05	hidsize:[16, 16]
# acc:0.791	batchsize: 1	lr:  0.05	hidsize:[32, 32]
# acc:0.739	batchsize: 1	lr:  0.05	hidsize:[64, 64]
# acc:0.791	batchsize: 4	lr:0.0007	hidsize:[8, 8]
# acc:0.826	batchsize: 4	lr:0.0007	hidsize:[16, 16]
# acc:0.829	batchsize: 4	lr:0.0007	hidsize:[32, 32]
# acc:0.826	batchsize: 4	lr:0.0007	hidsize:[64, 64]
# acc:0.823	batchsize: 4	lr: 0.001	hidsize:[8, 8]
# acc:0.829	batchsize: 4	lr: 0.001	hidsize:[16, 16]
# acc:0.829	batchsize: 4	lr: 0.001	hidsize:[32, 32]
# acc:0.834	batchsize: 4	lr: 0.001	hidsize:[64, 64]
# acc:0.832	batchsize: 4	lr: 0.005	hidsize:[8, 8]
# acc:0.832	batchsize: 4	lr: 0.005	hidsize:[16, 16]
# acc:0.834	batchsize: 4	lr: 0.005	hidsize:[32, 32]
# acc:0.832	batchsize: 4	lr: 0.005	hidsize:[64, 64]
# acc:0.837	batchsize: 4	lr:  0.01	hidsize:[8, 8]
# acc:0.842	batchsize: 4	lr:  0.01	hidsize:[16, 16]
# acc:0.837	batchsize: 4	lr:  0.01	hidsize:[32, 32]
# acc:0.84	batchsize: 4	lr:  0.01	hidsize:[64, 64]
# acc:0.788	batchsize: 4	lr:  0.05	hidsize:[8, 8]
# acc:0.747	batchsize: 4	lr:  0.05	hidsize:[16, 16]
# acc:0.829	batchsize: 4	lr:  0.05	hidsize:[32, 32]
# acc:0.837	batchsize: 4	lr:  0.05	hidsize:[64, 64]
# acc:0.837	batchsize:16	lr:0.0007	hidsize:[8, 8]
# acc:0.823	batchsize:16	lr:0.0007	hidsize:[16, 16]
# acc:0.826	batchsize:16	lr:0.0007	hidsize:[32, 32]
# acc:0.837	batchsize:16	lr:0.0007	hidsize:[64, 64]
# acc:0.842	batchsize:16	lr: 0.001	hidsize:[8, 8]
# acc:0.826	batchsize:16	lr: 0.001	hidsize:[16, 16]
# acc:0.829	batchsize:16	lr: 0.001	hidsize:[32, 32]
# acc:0.837	batchsize:16	lr: 0.001	hidsize:[64, 64]
# acc:0.84	batchsize:16	lr: 0.005	hidsize:[8, 8]
# acc:0.845	batchsize:16	lr: 0.005	hidsize:[16, 16]
# acc:0.834	batchsize:16	lr: 0.005	hidsize:[32, 32]
# acc:0.842	batchsize:16	lr: 0.005	hidsize:[64, 64]
# acc:0.845	batchsize:16	lr:  0.01	hidsize:[8, 8]
# acc:0.84	batchsize:16	lr:  0.01	hidsize:[16, 16]
# acc:0.837	batchsize:16	lr:  0.01	hidsize:[32, 32]
# acc:0.848	batchsize:16	lr:  0.01	hidsize:[64, 64]
# acc:0.826	batchsize:16	lr:  0.05	hidsize:[8, 8]
# acc:0.832	batchsize:16	lr:  0.05	hidsize:[16, 16]
# acc:0.832	batchsize:16	lr:  0.05	hidsize:[32, 32]
# acc:0.829	batchsize:16	lr:  0.05	hidsize:[64, 64]
# acc:0.851	batchsize:32	lr:0.0007	hidsize:[8, 8]
# acc:0.832	batchsize:32	lr:0.0007	hidsize:[16, 16]
# acc:0.834	batchsize:32	lr:0.0007	hidsize:[32, 32]
# acc:0.842	batchsize:32	lr:0.0007	hidsize:[64, 64]
# acc:0.851	batchsize:32	lr: 0.001	hidsize:[8, 8]
# acc:0.834	batchsize:32	lr: 0.001	hidsize:[16, 16]
# acc:0.834	batchsize:32	lr: 0.001	hidsize:[32, 32]
# acc:0.84	batchsize:32	lr: 0.001	hidsize:[64, 64]
# acc:0.842	batchsize:32	lr: 0.005	hidsize:[8, 8]
# acc:0.84	batchsize:32	lr: 0.005	hidsize:[16, 16]
# acc:0.84	batchsize:32	lr: 0.005	hidsize:[32, 32]
# acc:0.851	batchsize:32	lr: 0.005	hidsize:[64, 64]
# acc:0.837	batchsize:32	lr:  0.01	hidsize:[8, 8]
# acc:0.848	batchsize:32	lr:  0.01	hidsize:[16, 16]
# acc:0.845	batchsize:32	lr:  0.01	hidsize:[32, 32]
# acc:0.848	batchsize:32	lr:  0.01	hidsize:[64, 64]
# acc:0.837	batchsize:32	lr:  0.05	hidsize:[8, 8]
# acc:0.84	batchsize:32	lr:  0.05	hidsize:[16, 16]
# acc:0.848	batchsize:32	lr:  0.05	hidsize:[32, 32]
# acc:0.848	batchsize:32	lr:  0.05	hidsize:[64, 64]
# acc:0.856	batchsize:64	lr:0.0007	hidsize:[8, 8]
# acc:0.84	batchsize:64	lr:0.0007	hidsize:[16, 16]
# acc:0.842	batchsize:64	lr:0.0007	hidsize:[32, 32]
# acc:0.842	batchsize:64	lr:0.0007	hidsize:[64, 64]
# acc:0.856	batchsize:64	lr: 0.001	hidsize:[8, 8]
# acc:0.842	batchsize:64	lr: 0.001	hidsize:[16, 16]
# acc:0.84	batchsize:64	lr: 0.001	hidsize:[32, 32]
# acc:0.842	batchsize:64	lr: 0.001	hidsize:[64, 64]
# acc:0.851	batchsize:64	lr: 0.005	hidsize:[8, 8]
# acc:0.853	batchsize:64	lr: 0.005	hidsize:[16, 16]
# acc:0.834	batchsize:64	lr: 0.005	hidsize:[32, 32]
# acc:0.842	batchsize:64	lr: 0.005	hidsize:[64, 64]
# acc:0.848	batchsize:64	lr:  0.01	hidsize:[8, 8]
# acc:0.853	batchsize:64	lr:  0.01	hidsize:[16, 16]
# acc:0.834	batchsize:64	lr:  0.01	hidsize:[32, 32]
# acc:0.84	batchsize:64	lr:  0.01	hidsize:[64, 64]
# acc:0.842	batchsize:64	lr:  0.05	hidsize:[8, 8]
# acc:0.84	batchsize:64	lr:  0.05	hidsize:[16, 16]
# acc:0.832	batchsize:64	lr:  0.05	hidsize:[32, 32]
# acc:0.84	batchsize:64	lr:  0.05	hidsize:[64, 64]
# --------------------------------------
# | [PEER] best batchsize   | 64       |
# | [PEER] best hidsize     | [8, 8]   |
# | [PEER] best learning... | 0.0007   |
# --------------------------------------
# ---------------------------------
# | [PEER] alpha = 0.1 | 0.569    |
# | [PEER] alpha = 0.2 | 0.585    |
# | [PEER] alpha = 0.3 | 0.565    |
# | [PEER] alpha = 0.4 | 0.581    |
# | [PEER] alpha = 0.5 | 0.577    |
# | [PEER] alpha = 0.6 | 0.585    |
# | [PEER] alpha = 0.7 | 0.597    |
# | [PEER] alpha = 0.8 | 0.609    |
# | [PEER] alpha = 0.9 | 0.613    |
# | [PEER] alpha = 1.0 | 0.637    |
# ---------------------------------
# --------------------------------------
# | [NN] with bce loss      | 0.693    |
# | [NN] with peer loss     | 0.856    |
# | [NN] with surrogate ... | 0.758    |
# | [PEER] best alpha       | 1        |
# --------------------------------------
# Logging to logs/svm/19-08-28-11-50-17
# {'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'dataset': 'heart', 'e0': 0.2, 'e1': 0.4, 'equalize_prior': False, 'episodes': 1000}
# --------------------------------
# | [C-SVM] C1 = 0.1  | 0.593    |
# | [C-SVM] C1 = 0.2  | 0.593    |
# | [C-SVM] C1 = 0.25 | 0.593    |
# | [C-SVM] C1 = 0.33 | 0.593    |
# | [C-SVM] C1 = 0.5  | 0.593    |
# | [C-SVM] C1 = 1.0  | 0.657    |
# | [C-SVM] C1 = 10.0 | 0.476    |
# | [C-SVM] C1 = 2.0  | 0.544    |
# | [C-SVM] C1 = 3.0  | 0.496    |
# | [C-SVM] C1 = 4.0  | 0.484    |
# | [C-SVM] C1 = 5.0  | 0.488    |
# --------------------------------
# ------------------------------------
# | [C-SVM] accuracy max  | 0.783    |
# | [C-SVM] accuracy mean | 0.704    |
# | [C-SVM] accuracy min  | 0.63     |
# | [C-SVM] accuracy std  | 0.046    |
# | [C-SVM] best C1       | 1        |
# ------------------------------------
# Logging to logs/pam/19-08-28-11-50-17
# {'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'dataset': 'heart', 'e0': 0.2, 'e1': 0.4, 'equalize_prior': False, 'episodes': 1000}
# -----------------------------------
# | [PAM] margin = 0     | 0.577    |
# | [PAM] margin = 0.125 | 0.593    |
# | [PAM] margin = 0.25  | 0.593    |
# | [PAM] margin = 0.5   | 0.589    |
# | [PAM] margin = 1     | 0.593    |
# -----------------------------------
# ----------------------------------
# | [PAM] accuracy max  | 0.804    |
# | [PAM] accuracy mean | 0.715    |
# | [PAM] accuracy min  | 0.63     |
# | [PAM] accuracy std  | 0.0515   |
# | [PAM] best margin   | 0.125    |
# ----------------------------------

# %% [markdown]
# ### $e_0=0.4, e_1=0.4$

# %%
from runner import run
args = default_args.copy()
args.update({
    'e0': 0.4, 'e1': 0.4, 
    'equalize_prior': False, 
    'episodes': 2000, 
    'batchsize': 64, 
    'hidsize': [8, 8], 
    'lr': 0.0007, 
#     'alpha': 1.
})
run(args)
# Out:
# Logging to logs/nn/19-08-30-15-27-54
# {'dataset': 'heart', 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'e0': 0.4, 'e1': 0.4, 'equalize_prior': False, 'episodes': 2000, 'batchsize': 64, 'hidsize': [8, 8], 'lr': 0.0007}
# ---------------------------------
# | [PEER] alpha = -5  | 0.512    |
# | [PEER] alpha = 0.4 | 0.48     |
# | [PEER] alpha = 0.5 | 0.496    |
# | [PEER] alpha = 0.6 | 0.516    |
# | [PEER] alpha = 0.7 | 0.528    |
# | [PEER] alpha = 0.8 | 0.548    |
# | [PEER] alpha = 0.9 | 0.577    |
# | [PEER] alpha = 1.0 | 0.581    |
# | [PEER] alpha = 2.0 | 0.5      |
# | [PEER] alpha = 3.0 | 0.5      |
# | [PEER] alpha = 4.0 | 0.5      |
# | [PEER] alpha = 5.0 | 0.5      |
# ---------------------------------
# --------------------------------------
# | [NN] with bce loss      | 0.554    |
# | [NN] with peer loss     | 0.785    |
# | [NN] with surrogate ... | 0.728    |
# | [PEER] best alpha       | 1        |
# --------------------------------------
# Logging to logs/svm/19-08-30-15-29-02
# {'dataset': 'heart', 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'e0': 0.4, 'e1': 0.4, 'equalize_prior': False, 'episodes': 2000, 'batchsize': 64, 'hidsize': [8, 8], 'lr': 0.0007}
# --------------------------------
# | [C-SVM] C1 = 0.1  | 0.496    |
# | [C-SVM] C1 = 0.2  | 0.496    |
# | [C-SVM] C1 = 0.25 | 0.496    |
# | [C-SVM] C1 = 0.33 | 0.496    |
# | [C-SVM] C1 = 0.5  | 0.508    |
# | [C-SVM] C1 = 1.0  | 0.556    |
# | [C-SVM] C1 = 10.0 | 0.504    |
# | [C-SVM] C1 = 2.0  | 0.528    |
# | [C-SVM] C1 = 3.0  | 0.492    |
# | [C-SVM] C1 = 4.0  | 0.508    |
# | [C-SVM] C1 = 5.0  | 0.508    |
# --------------------------------
# ------------------------------------
# | [C-SVM] accuracy max  | 0.783    |
# | [C-SVM] accuracy mean | 0.698    |
# | [C-SVM] accuracy min  | 0.609    |
# | [C-SVM] accuracy std  | 0.0665   |
# | [C-SVM] best C1       | 1        |
# ------------------------------------
# Logging to logs/pam/19-08-30-15-29-02
# {'dataset': 'heart', 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'e0': 0.4, 'e1': 0.4, 'equalize_prior': False, 'episodes': 2000, 'batchsize': 64, 'hidsize': [8, 8], 'lr': 0.0007}
# -----------------------------------
# | [PAM] margin = 0     | 0.516    |
# | [PAM] margin = 0.125 | 0.54     |
# | [PAM] margin = 0.25  | 0.548    |
# | [PAM] margin = 0.5   | 0.552    |
# | [PAM] margin = 1     | 0.577    |
# -----------------------------------
# ----------------------------------
# | [PAM] accuracy max  | 0.783    |
# | [PAM] accuracy mean | 0.69     |
# | [PAM] accuracy min  | 0.565    |
# | [PAM] accuracy std  | 0.0735   |
# | [PAM] best margin   | 1        |
# ----------------------------------

# %%
from runner import run
args = default_args.copy()
args.update({
    'dataset': 'heart', 
    'e0': 0.4, 'e1': 0.4, 
    'equalize_prior': False, 
    'episodes': 2000, 
#     'batchsize': 4, 
#     'hidsize': [32, 32], 
#     'lr': 0.005, 
#     'alpha': 1.
})
run(args)
# Out:
# Logging to logs/nn/19-08-28-11-50-21
# {'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'dataset': 'heart', 'e0': 0.4, 'e1': 0.4, 'equalize_prior': False, 'episodes': 2000}
# acc:0.66	batchsize: 1	lr:0.0007	hidsize:[8, 8]
# acc:0.736	batchsize: 1	lr:0.0007	hidsize:[16, 16]
# acc:0.783	batchsize: 1	lr:0.0007	hidsize:[32, 32]
# acc:0.785	batchsize: 1	lr:0.0007	hidsize:[64, 64]
# acc:0.707	batchsize: 1	lr: 0.001	hidsize:[8, 8]
# acc:0.753	batchsize: 1	lr: 0.001	hidsize:[16, 16]
# acc:0.783	batchsize: 1	lr: 0.001	hidsize:[32, 32]
# acc:0.793	batchsize: 1	lr: 0.001	hidsize:[64, 64]
# acc:0.755	batchsize: 1	lr: 0.005	hidsize:[8, 8]
# acc:0.772	batchsize: 1	lr: 0.005	hidsize:[16, 16]
# acc:0.761	batchsize: 1	lr: 0.005	hidsize:[32, 32]
# acc:0.783	batchsize: 1	lr: 0.005	hidsize:[64, 64]
# acc:0.712	batchsize: 1	lr:  0.01	hidsize:[8, 8]
# acc:0.755	batchsize: 1	lr:  0.01	hidsize:[16, 16]
# acc:0.761	batchsize: 1	lr:  0.01	hidsize:[32, 32]
# acc:0.755	batchsize: 1	lr:  0.01	hidsize:[64, 64]
# acc:0.595	batchsize: 1	lr:  0.05	hidsize:[8, 8]
# acc:0.769	batchsize: 1	lr:  0.05	hidsize:[16, 16]
# acc:0.736	batchsize: 1	lr:  0.05	hidsize:[32, 32]
# acc:0.753	batchsize: 1	lr:  0.05	hidsize:[64, 64]
# acc:0.774	batchsize: 4	lr:0.0007	hidsize:[8, 8]
# acc:0.753	batchsize: 4	lr:0.0007	hidsize:[16, 16]
# acc:0.78	batchsize: 4	lr:0.0007	hidsize:[32, 32]
# acc:0.777	batchsize: 4	lr:0.0007	hidsize:[64, 64]
# acc:0.764	batchsize: 4	lr: 0.001	hidsize:[8, 8]
# acc:0.772	batchsize: 4	lr: 0.001	hidsize:[16, 16]
# acc:0.785	batchsize: 4	lr: 0.001	hidsize:[32, 32]
# acc:0.788	batchsize: 4	lr: 0.001	hidsize:[64, 64]
# acc:0.783	batchsize: 4	lr: 0.005	hidsize:[8, 8]
# acc:0.783	batchsize: 4	lr: 0.005	hidsize:[16, 16]
# acc:0.783	batchsize: 4	lr: 0.005	hidsize:[32, 32]
# acc:0.785	batchsize: 4	lr: 0.005	hidsize:[64, 64]
# acc:0.774	batchsize: 4	lr:  0.01	hidsize:[8, 8]
# acc:0.753	batchsize: 4	lr:  0.01	hidsize:[16, 16]
# acc:0.791	batchsize: 4	lr:  0.01	hidsize:[32, 32]
# acc:0.747	batchsize: 4	lr:  0.01	hidsize:[64, 64]
# acc:0.745	batchsize: 4	lr:  0.05	hidsize:[8, 8]
# acc:0.726	batchsize: 4	lr:  0.05	hidsize:[16, 16]
# acc:0.736	batchsize: 4	lr:  0.05	hidsize:[32, 32]
# acc:0.717	batchsize: 4	lr:  0.05	hidsize:[64, 64]
# acc:0.78	batchsize:16	lr:0.0007	hidsize:[8, 8]
# acc:0.774	batchsize:16	lr:0.0007	hidsize:[16, 16]
# acc:0.785	batchsize:16	lr:0.0007	hidsize:[32, 32]
# acc:0.804	batchsize:16	lr:0.0007	hidsize:[64, 64]
# acc:0.783	batchsize:16	lr: 0.001	hidsize:[8, 8]
# acc:0.78	batchsize:16	lr: 0.001	hidsize:[16, 16]
# acc:0.793	batchsize:16	lr: 0.001	hidsize:[32, 32]
# acc:0.799	batchsize:16	lr: 0.001	hidsize:[64, 64]
# acc:0.78	batchsize:16	lr: 0.005	hidsize:[8, 8]
# acc:0.774	batchsize:16	lr: 0.005	hidsize:[16, 16]
# acc:0.799	batchsize:16	lr: 0.005	hidsize:[32, 32]
# acc:0.802	batchsize:16	lr: 0.005	hidsize:[64, 64]
# acc:0.777	batchsize:16	lr:  0.01	hidsize:[8, 8]
# acc:0.774	batchsize:16	lr:  0.01	hidsize:[16, 16]
# acc:0.796	batchsize:16	lr:  0.01	hidsize:[32, 32]
# acc:0.785	batchsize:16	lr:  0.01	hidsize:[64, 64]
# acc:0.715	batchsize:16	lr:  0.05	hidsize:[8, 8]
# acc:0.791	batchsize:16	lr:  0.05	hidsize:[16, 16]
# acc:0.783	batchsize:16	lr:  0.05	hidsize:[32, 32]
# acc:0.796	batchsize:16	lr:  0.05	hidsize:[64, 64]
# acc:0.766	batchsize:32	lr:0.0007	hidsize:[8, 8]
# acc:0.78	batchsize:32	lr:0.0007	hidsize:[16, 16]
# acc:0.796	batchsize:32	lr:0.0007	hidsize:[32, 32]
# acc:0.793	batchsize:32	lr:0.0007	hidsize:[64, 64]
# acc:0.772	batchsize:32	lr: 0.001	hidsize:[8, 8]
# acc:0.788	batchsize:32	lr: 0.001	hidsize:[16, 16]
# acc:0.796	batchsize:32	lr: 0.001	hidsize:[32, 32]
# acc:0.799	batchsize:32	lr: 0.001	hidsize:[64, 64]
# acc:0.785	batchsize:32	lr: 0.005	hidsize:[8, 8]
# acc:0.804	batchsize:32	lr: 0.005	hidsize:[16, 16]
# acc:0.793	batchsize:32	lr: 0.005	hidsize:[32, 32]
# acc:0.802	batchsize:32	lr: 0.005	hidsize:[64, 64]
# acc:0.78	batchsize:32	lr:  0.01	hidsize:[8, 8]
# acc:0.796	batchsize:32	lr:  0.01	hidsize:[16, 16]
# acc:0.807	batchsize:32	lr:  0.01	hidsize:[32, 32]
# acc:0.807	batchsize:32	lr:  0.01	hidsize:[64, 64]
# acc:0.788	batchsize:32	lr:  0.05	hidsize:[8, 8]
# acc:0.812	batchsize:32	lr:  0.05	hidsize:[16, 16]
# acc:0.796	batchsize:32	lr:  0.05	hidsize:[32, 32]
# acc:0.815	batchsize:32	lr:  0.05	hidsize:[64, 64]
# acc:0.785	batchsize:64	lr:0.0007	hidsize:[8, 8]
# acc:0.766	batchsize:64	lr:0.0007	hidsize:[16, 16]
# acc:0.802	batchsize:64	lr:0.0007	hidsize:[32, 32]
# acc:0.802	batchsize:64	lr:0.0007	hidsize:[64, 64]
# acc:0.793	batchsize:64	lr: 0.001	hidsize:[8, 8]
# acc:0.761	batchsize:64	lr: 0.001	hidsize:[16, 16]
# acc:0.793	batchsize:64	lr: 0.001	hidsize:[32, 32]
# acc:0.802	batchsize:64	lr: 0.001	hidsize:[64, 64]
# acc:0.802	batchsize:64	lr: 0.005	hidsize:[8, 8]
# acc:0.785	batchsize:64	lr: 0.005	hidsize:[16, 16]
# acc:0.799	batchsize:64	lr: 0.005	hidsize:[32, 32]
# acc:0.796	batchsize:64	lr: 0.005	hidsize:[64, 64]
# acc:0.812	batchsize:64	lr:  0.01	hidsize:[8, 8]
# acc:0.785	batchsize:64	lr:  0.01	hidsize:[16, 16]
# acc:0.793	batchsize:64	lr:  0.01	hidsize:[32, 32]
# acc:0.81	batchsize:64	lr:  0.01	hidsize:[64, 64]
# acc:0.758	batchsize:64	lr:  0.05	hidsize:[8, 8]
# acc:0.807	batchsize:64	lr:  0.05	hidsize:[16, 16]
# acc:0.796	batchsize:64	lr:  0.05	hidsize:[32, 32]
# acc:0.802	batchsize:64	lr:  0.05	hidsize:[64, 64]
# --------------------------------------
# | [PEER] best batchsize   | 32       |
# | [PEER] best hidsize     | [64, 64] |
# | [PEER] best learning... | 0.05     |
# --------------------------------------
# ---------------------------------
# | [PEER] alpha = 0.1 | 0.484    |
# | [PEER] alpha = 0.2 | 0.492    |
# | [PEER] alpha = 0.3 | 0.524    |
# | [PEER] alpha = 0.4 | 0.488    |
# | [PEER] alpha = 0.5 | 0.488    |
# | [PEER] alpha = 0.6 | 0.524    |
# | [PEER] alpha = 0.7 | 0.528    |
# | [PEER] alpha = 0.8 | 0.548    |
# | [PEER] alpha = 0.9 | 0.573    |
# | [PEER] alpha = 1.0 | 0.556    |
# ---------------------------------
# --------------------------------------
# | [NN] with bce loss      | 0.554    |
# | [NN] with peer loss     | 0.78     |
# | [NN] with surrogate ... | 0.72     |
# | [PEER] best alpha       | 0.9      |
# --------------------------------------
# Logging to logs/svm/19-08-28-12-03-33
# {'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'dataset': 'heart', 'e0': 0.4, 'e1': 0.4, 'equalize_prior': False, 'episodes': 2000}
# --------------------------------
# | [C-SVM] C1 = 0.1  | 0.496    |
# | [C-SVM] C1 = 0.2  | 0.496    |
# | [C-SVM] C1 = 0.25 | 0.496    |
# | [C-SVM] C1 = 0.33 | 0.496    |
# | [C-SVM] C1 = 0.5  | 0.508    |
# | [C-SVM] C1 = 1.0  | 0.556    |
# | [C-SVM] C1 = 10.0 | 0.504    |
# | [C-SVM] C1 = 2.0  | 0.528    |
# | [C-SVM] C1 = 3.0  | 0.492    |
# | [C-SVM] C1 = 4.0  | 0.508    |
# | [C-SVM] C1 = 5.0  | 0.508    |
# --------------------------------
# ------------------------------------
# | [C-SVM] accuracy max  | 0.783    |
# | [C-SVM] accuracy mean | 0.698    |
# | [C-SVM] accuracy min  | 0.609    |
# | [C-SVM] accuracy std  | 0.0665   |
# | [C-SVM] best C1       | 1        |
# ------------------------------------
# Logging to logs/pam/19-08-28-12-03-33
# {'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'dataset': 'heart', 'e0': 0.4, 'e1': 0.4, 'equalize_prior': False, 'episodes': 2000}
# -----------------------------------
# | [PAM] margin = 0     | 0.516    |
# | [PAM] margin = 0.125 | 0.54     |
# | [PAM] margin = 0.25  | 0.548    |
# | [PAM] margin = 0.5   | 0.552    |
# | [PAM] margin = 1     | 0.577    |
# -----------------------------------
# ----------------------------------
# | [PAM] accuracy max  | 0.783    |
# | [PAM] accuracy mean | 0.69     |
# | [PAM] accuracy min  | 0.565    |
# | [PAM] accuracy std  | 0.0735   |
# | [PAM] best margin   | 1        |
# ----------------------------------

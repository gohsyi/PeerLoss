# %% [markdown]
# # Heart Disease Dataset

# %% [markdown]
# ## Summary
#
# 1. With prior equalization
#
# |      Dataset      | nn with peer loss |   nn  |   lr  |  svm  |  knn  | random forest |
# |:-----------------:|:-----------------:|:-----:|:-----:|:-----:|:-----:|:-------------:|
# |  Heart (0.2, 0.2) |       0.810       | 0.789 | 0.783 | 0.739 | 0.783 |     0.783     |
# |  Heart (0.1, 0.3) |       0.777       | 0.726 | 0.725 | 0.739 | 0.768 |     0.667     |
# |  Heart (0.2, 0.4) |       0.748       | 0.686 | 0.841 | 0.855 | 0.739 |     0.725     |
# |  Heart (0.4, 0.4) |       0.658       | 0.628 | 0.623 | 0.71  | 0.536 |     0.681     |
#
# 2. No prior equalization
#
# |      Dataset      | nn with peer loss |   nn  |   lr  |  svm  |  knn  | random forest |
# |:-----------------:|:-----------------:|:-----:|:-----:|:-----:|:-----:|:-------------:|
# |  Heart (0.2, 0.2) |       0.810       | 0.803 | 0.82  | 0.808 | 0.818 |     0.816     |
# |  Heart (0.1, 0.3) |       0.781       | 0.733 | 0.75  | 0.75  | 0.727 |     0.727     |
# |  Heart (0.2, 0.4) |       0.749       | 0.683 | 0.684 | 0.675 | 0.648 |     0.666     |
# |  Heart (0.4, 0.4) |       0.668       | 0.652 | 0.657 | 0.666 | 0.583 |     0.626     |

# %% [markdown]
# ## Describe
#
# | Total | Positive | Attributes | Normalized |
# |:-----:|:--------:|:----------:|:----------:|
# |  303  |   54.5%  |     13     |     Not    |

# %%
from utils.dataloader import DataLoader

dataset = DataLoader('heart')
dataset.df.target.describe()
# Out:
# count    303.000000
# mean       0.544554
# std        0.498835
# min        0.000000
# 25%        0.000000
# 50%        1.000000
# 75%        1.000000
# max        1.000000
# Name: target, dtype: float64

# %%
dataset.df.describe()
# Out:
#               age         sex    trestbps  ...           0           1           2
# count  303.000000  303.000000  303.000000  ...  303.000000  303.000000  303.000000
# mean    54.366337    0.683168  131.623762  ...    0.485149    0.501650    0.013201
# std      9.082101    0.466011   17.538143  ...    0.500606    0.500824    0.114325
# min     29.000000    0.000000   94.000000  ...    0.000000    0.000000    0.000000
# 25%     47.500000    0.000000  120.000000  ...    0.000000    0.000000    0.000000
# 50%     55.000000    1.000000  130.000000  ...    0.000000    1.000000    0.000000
# 75%     61.000000    1.000000  140.000000  ...    1.000000    1.000000    0.000000
# max     77.000000    1.000000  200.000000  ...    1.000000    1.000000    1.000000
#
# [8 rows x 24 columns]

# %% [markdown]
# ## With piror equalization

# %%
from runner import run

arg_dict = {
    'dataset': 'heart', 
    'lr': 0.001, 
    'hidsize': 8, 
    'episodes': 150, 
    'batchsize': 10, 
    'test_size': 0.80,
    'dropout': 0.,
    'normalize': True,
    'equalize_prior': True,
}

# %% [markdown]
# $e_0 = 0, e_1 = 0$

# %%
arg_dict.update({'e0': 0, 'e1': 0})
run(arg_dict.copy())
# Out:
# {'dataset': 'heart', 'lr': 0.001, 'hidsize': 8, 'episodes': 150, 'batchsize': 10, 'test_size': 0.8, 'dropout': 0.0, 'e0': 0, 'e1': 0}
# --------------------------------------
# | knn                     | 0.812    |
# | logistic regression     | 0.884    |
# | nn                      | 0.798    |
# | nn with peer prediction | 0.81     |
# | random forest           | 0.841    |
# | svm                     | 0.841    |
# --------------------------------------

# %% [markdown]
# $e_0 = 0.2, e_1 = 0.2$

# %%
arg_dict.update({'e0': 0.2, 'e1': 0.2})
run(arg_dict.copy())
# Out:
# {'dataset': 'heart', 'lr': 0.001, 'hidsize': 8, 'episodes': 150, 'batchsize': 10, 'test_size': 0.8, 'dropout': 0.0, 'normalize': True, 'equalize_prior': True, 'e0': 0.2, 'e1': 0.2}
# --------------------------------------
# | knn                     | 0.735    |
# | logistic regression     | 0.772    |
# | nn                      | 0.762    |
# | nn with peer prediction | 0.78     |
# | random forest           | 0.768    |
# | svm                     | 0.776    |
# --------------------------------------

# %% [markdown]
# $e_0 = 0.1, e_1 = 0.3$

# %%
arg_dict.update({'e0': 0.1, 'e1': 0.3})
run(arg_dict.copy())
# Out:
# {'dataset': 'heart', 'lr': 0.001, 'hidsize': 8, 'episodes': 150, 'batchsize': 10, 'test_size': 0.8, 'dropout': 0.0, 'e0': 0.1, 'e1': 0.3}
# --------------------------------------
# | knn                     | 0.768    |
# | logistic regression     | 0.725    |
# | nn                      | 0.726    |
# | nn with peer prediction | 0.777    |
# | random forest           | 0.667    |
# | svm                     | 0.739    |
# --------------------------------------

# %% [markdown]
# $e_0 = 0.2, e_1 = 0.4$

# %%
arg_dict.update({'e0': 0.2, 'e1': 0.4})
run(arg_dict.copy())
# Out:
# {'dataset': 'heart', 'lr': 0.001, 'hidsize': 8, 'episodes': 150, 'batchsize': 10, 'test_size': 0.8, 'dropout': 0.0, 'e0': 0.2, 'e1': 0.4}
# --------------------------------------
# | knn                     | 0.739    |
# | logistic regression     | 0.841    |
# | nn                      | 0.686    |
# | nn with peer prediction | 0.748    |
# | random forest           | 0.725    |
# | svm                     | 0.855    |
# --------------------------------------

# %% [markdown]
# $e_0=0.4, e_1=0.4$

# %%
arg_dict.update({'e0': 0.4, 'e1': 0.4})
run(arg_dict.copy())
# Out:
# {'dataset': 'heart', 'lr': 0.001, 'hidsize': 8, 'episodes': 150, 'batchsize': 10, 'test_size': 0.8, 'dropout': 0.0, 'e0': 0.4, 'e1': 0.4}
# --------------------------------------
# | knn                     | 0.536    |
# | logistic regression     | 0.623    |
# | nn                      | 0.628    |
# | nn with peer prediction | 0.658    |
# | random forest           | 0.681    |
# | svm                     | 0.71     |
# --------------------------------------

# %% [markdown]
# ## No prior equalization

# %%
from runner import run

arg_dict = {
    'dataset': 'heart', 
    'lr': 0.001, 
    'hidsize': 8, 
    'episodes': 150, 
    'batchsize': 10, 
    'test_size': 0.80,
    'dropout': 0.,
    'normalize': True,
    'equalize_prior': False,
}

# %% [markdown]
# $e_0 = 0, e_1 = 0$

# %%
arg_dict.update({'e0': 0, 'e1': 0})
run(arg_dict.copy())
# Out:
# {'dataset': 'heart', 'lr': 0.001, 'hidsize': 8, 'episodes': 150, 'batchsize': 10, 'test_size': 0.8, 'dropout': 0.0, 'normalize': True, 'equalize_prior': False, 'e0': 0, 'e1': 0}
# --------------------------------------
# | knn                     | 0.818    |
# | logistic regression     | 0.82     |
# | nn                      | 0.803    |
# | nn with peer prediction | 0.81     |
# | random forest           | 0.816    |
# | svm                     | 0.808    |
# --------------------------------------

# %% [markdown]
# $e_0 = 0.2, e_1 = 0.2$

# %%
arg_dict.update({'e0': 0.2, 'e1': 0.2})
run(arg_dict.copy())
# Out:
# {'dataset': 'heart', 'lr': 0.001, 'hidsize': 8, 'episodes': 150, 'batchsize': 10, 'test_size': 0.8, 'dropout': 0.0, 'normalize': True, 'equalize_prior': True, 'e0': 0.2, 'e1': 0.2}
# --------------------------------------
# | knn                     | 0.735    |
# | logistic regression     | 0.772    |
# | nn                      | 0.762    |
# | nn with peer prediction | 0.78     |
# | random forest           | 0.768    |
# | svm                     | 0.776    |
# --------------------------------------

# %% [markdown]
# $e_0 = 0.1, e_1 = 0.3$

# %%
arg_dict.update({'e0': 0.1, 'e1': 0.3})
run(arg_dict.copy())
# Out:
# {'dataset': 'heart', 'lr': 0.001, 'hidsize': 8, 'episodes': 150, 'batchsize': 10, 'test_size': 0.8, 'dropout': 0.0, 'normalize': True, 'equalize_prior': False, 'e0': 0.1, 'e1': 0.3}
# --------------------------------------
# | knn                     | 0.727    |
# | logistic regression     | 0.75     |
# | nn                      | 0.733    |
# | nn with peer prediction | 0.781    |
# | random forest           | 0.727    |
# | svm                     | 0.75     |
# --------------------------------------

# %% [markdown]
# $e_0 = 0.2, e_1 = 0.4$

# %%
arg_dict.update({'e0': 0.2, 'e1': 0.4})
run(arg_dict.copy())
# Out:
# {'dataset': 'heart', 'lr': 0.001, 'hidsize': 8, 'episodes': 150, 'batchsize': 10, 'test_size': 0.8, 'dropout': 0.0, 'normalize': True, 'equalize_prior': False, 'e0': 0.2, 'e1': 0.4}
# --------------------------------------
# | knn                     | 0.648    |
# | logistic regression     | 0.684    |
# | nn                      | 0.683    |
# | nn with peer prediction | 0.749    |
# | random forest           | 0.666    |
# | svm                     | 0.675    |
# --------------------------------------

# %% [markdown]
# $e_0=0.4, e_1=0.4$

# %%
arg_dict.update({'e0': 0.4, 'e1': 0.4})
run(arg_dict.copy())
# Out:
# {'dataset': 'heart', 'lr': 0.001, 'hidsize': 8, 'episodes': 150, 'batchsize': 10, 'test_size': 0.8, 'dropout': 0.0, 'normalize': True, 'equalize_prior': False, 'e0': 0.4, 'e1': 0.4}
# --------------------------------------
# | knn                     | 0.583    |
# | logistic regression     | 0.657    |
# | nn                      | 0.652    |
# | nn with peer prediction | 0.668    |
# | random forest           | 0.626    |
# | svm                     | 0.666    |
# --------------------------------------

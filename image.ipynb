# %% [markdown]
# # Image (18,1320,990)

# %% [markdown]
# ## Describe
#
# | Total | Positive | Attributes | Normalized |
# |:-----:|:--------:|:----------:|:----------:|
# | 2310  |  57.1%   |     18     |     Yes    |

# %%
default_args = {
    'dataset': 'image',
    'test_size': 0.15,
    'val_size': 0.1,
    'dropout': 0, 
    'normalize': True,
    'loss': 'bce',
    'activation': 'relu',
    'verbose': True,
}

# %% [markdown]
# ## With Prior Equalization

# %% [markdown]
# ### $e_0 = 0.1, e_1 = 0.3$

# %%
from run_nn import find_best_alpha
args = default_args.copy()
args.update({
    'e0': 0.1, 'e1': 0.3,
    'episodes': 3000,
    'equalize_prior': True,
    'batchsize': 64,
    'hidsize': [32, 32],
    'lr': 0.005,
})
find_best_alpha(args)
# Out:
# ---------------------------------
# | [PEER] alpha = 0.1 | 0.856    |
# | [PEER] alpha = 0.2 | 0.828    |
# | [PEER] alpha = 0.3 | 0.802    |
# | [PEER] alpha = 0.4 | 0.793    |
# | [PEER] alpha = 0.5 | 0.788    |
# | [PEER] alpha = 0.6 | 0.8      |
# | [PEER] alpha = 0.7 | 0.771    |
# | [PEER] alpha = 0.8 | 0.729    |
# | [PEER] alpha = 0.9 | 0.714    |
# | [PEER] alpha = 1.0 | 0.7      |
# ---------------------------------
# {'alpha': 0.1}

# %%
from runner import run
args = default_args.copy()
args.update({
    'e0': 0.1, 'e1': 0.3,
    'episodes': 3000,
    'equalize_prior': True,
})
run(args)
# Out:
# Logging to logs/nn/19-08-29-15-00-02
# {'dataset': 'image', 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'e0': 0.1, 'e1': 0.3, 'episodes': 3000, 'equalize_prior': True}
# acc:0.672	batchsize: 1	lr:0.0007	hidsize:[8, 8]
# acc:0.66	batchsize: 1	lr:0.0007	hidsize:[16, 16]
# acc:0.657	batchsize: 1	lr:0.0007	hidsize:[32, 32]
# acc:0.672	batchsize: 1	lr:0.0007	hidsize:[64, 64]
# acc:0.671	batchsize: 1	lr: 0.001	hidsize:[8, 8]
# acc:0.662	batchsize: 1	lr: 0.001	hidsize:[16, 16]
# acc:0.657	batchsize: 1	lr: 0.001	hidsize:[32, 32]
# acc:0.666	batchsize: 1	lr: 0.001	hidsize:[64, 64]
# acc:0.647	batchsize: 1	lr: 0.005	hidsize:[8, 8]
# acc:0.642	batchsize: 1	lr: 0.005	hidsize:[16, 16]
# acc:0.642	batchsize: 1	lr: 0.005	hidsize:[32, 32]
# acc:0.647	batchsize: 1	lr: 0.005	hidsize:[64, 64]
# acc:0.618	batchsize: 1	lr:  0.01	hidsize:[8, 8]
# acc:0.623	batchsize: 1	lr:  0.01	hidsize:[16, 16]
# acc:0.636	batchsize: 1	lr:  0.01	hidsize:[32, 32]
# acc:0.652	batchsize: 1	lr:  0.01	hidsize:[64, 64]
# acc:0.519	batchsize: 1	lr:  0.05	hidsize:[8, 8]
# acc:0.621	batchsize: 1	lr:  0.05	hidsize:[16, 16]
# acc:0.628	batchsize: 1	lr:  0.05	hidsize:[32, 32]
# acc:0.643	batchsize: 1	lr:  0.05	hidsize:[64, 64]
# acc:0.689	batchsize: 4	lr:0.0007	hidsize:[8, 8]
# acc:0.672	batchsize: 4	lr:0.0007	hidsize:[16, 16]
# acc:0.68	batchsize: 4	lr:0.0007	hidsize:[32, 32]
# acc:0.68	batchsize: 4	lr:0.0007	hidsize:[64, 64]
# acc:0.684	batchsize: 4	lr: 0.001	hidsize:[8, 8]
# acc:0.672	batchsize: 4	lr: 0.001	hidsize:[16, 16]
# acc:0.679	batchsize: 4	lr: 0.001	hidsize:[32, 32]
# acc:0.675	batchsize: 4	lr: 0.001	hidsize:[64, 64]
# acc:0.654	batchsize: 4	lr: 0.005	hidsize:[8, 8]
# acc:0.664	batchsize: 4	lr: 0.005	hidsize:[16, 16]
# acc:0.665	batchsize: 4	lr: 0.005	hidsize:[32, 32]
# acc:0.673	batchsize: 4	lr: 0.005	hidsize:[64, 64]
# acc:0.645	batchsize: 4	lr:  0.01	hidsize:[8, 8]
# acc:0.661	batchsize: 4	lr:  0.01	hidsize:[16, 16]
# acc:0.674	batchsize: 4	lr:  0.01	hidsize:[32, 32]
# acc:0.67	batchsize: 4	lr:  0.01	hidsize:[64, 64]
# acc:0.616	batchsize: 4	lr:  0.05	hidsize:[8, 8]
# acc:0.637	batchsize: 4	lr:  0.05	hidsize:[16, 16]
# acc:0.623	batchsize: 4	lr:  0.05	hidsize:[32, 32]
# acc:0.639	batchsize: 4	lr:  0.05	hidsize:[64, 64]
# acc:0.681	batchsize:16	lr:0.0007	hidsize:[8, 8]
# acc:0.668	batchsize:16	lr:0.0007	hidsize:[16, 16]
# acc:0.684	batchsize:16	lr:0.0007	hidsize:[32, 32]
# acc:0.684	batchsize:16	lr:0.0007	hidsize:[64, 64]
# acc:0.681	batchsize:16	lr: 0.001	hidsize:[8, 8]
# acc:0.67	batchsize:16	lr: 0.001	hidsize:[16, 16]
# acc:0.684	batchsize:16	lr: 0.001	hidsize:[32, 32]
# acc:0.684	batchsize:16	lr: 0.001	hidsize:[64, 64]
# acc:0.678	batchsize:16	lr: 0.005	hidsize:[8, 8]
# acc:0.68	batchsize:16	lr: 0.005	hidsize:[16, 16]
# acc:0.675	batchsize:16	lr: 0.005	hidsize:[32, 32]
# acc:0.675	batchsize:16	lr: 0.005	hidsize:[64, 64]
# acc:0.671	batchsize:16	lr:  0.01	hidsize:[8, 8]
# acc:0.681	batchsize:16	lr:  0.01	hidsize:[16, 16]
# acc:0.673	batchsize:16	lr:  0.01	hidsize:[32, 32]
# acc:0.674	batchsize:16	lr:  0.01	hidsize:[64, 64]
# acc:0.653	batchsize:16	lr:  0.05	hidsize:[8, 8]
# acc:0.634	batchsize:16	lr:  0.05	hidsize:[16, 16]
# acc:0.671	batchsize:16	lr:  0.05	hidsize:[32, 32]
# acc:0.655	batchsize:16	lr:  0.05	hidsize:[64, 64]
# acc:0.694	batchsize:32	lr:0.0007	hidsize:[8, 8]
# acc:0.673	batchsize:32	lr:0.0007	hidsize:[16, 16]
# acc:0.686	batchsize:32	lr:0.0007	hidsize:[32, 32]
# acc:0.688	batchsize:32	lr:0.0007	hidsize:[64, 64]
# acc:0.689	batchsize:32	lr: 0.001	hidsize:[8, 8]
# acc:0.67	batchsize:32	lr: 0.001	hidsize:[16, 16]
# acc:0.685	batchsize:32	lr: 0.001	hidsize:[32, 32]
# acc:0.689	batchsize:32	lr: 0.001	hidsize:[64, 64]
# acc:0.686	batchsize:32	lr: 0.005	hidsize:[8, 8]
# acc:0.677	batchsize:32	lr: 0.005	hidsize:[16, 16]
# acc:0.69	batchsize:32	lr: 0.005	hidsize:[32, 32]
# acc:0.681	batchsize:32	lr: 0.005	hidsize:[64, 64]
# acc:0.691	batchsize:32	lr:  0.01	hidsize:[8, 8]
# acc:0.678	batchsize:32	lr:  0.01	hidsize:[16, 16]
# acc:0.689	batchsize:32	lr:  0.01	hidsize:[32, 32]
# acc:0.676	batchsize:32	lr:  0.01	hidsize:[64, 64]
# acc:0.666	batchsize:32	lr:  0.05	hidsize:[8, 8]
# acc:0.675	batchsize:32	lr:  0.05	hidsize:[16, 16]
# acc:0.679	batchsize:32	lr:  0.05	hidsize:[32, 32]
# acc:0.667	batchsize:32	lr:  0.05	hidsize:[64, 64]
# acc:0.696	batchsize:64	lr:0.0007	hidsize:[8, 8]
# acc:0.683	batchsize:64	lr:0.0007	hidsize:[16, 16]
# acc:0.694	batchsize:64	lr:0.0007	hidsize:[32, 32]
# acc:0.69	batchsize:64	lr:0.0007	hidsize:[64, 64]
# acc:0.689	batchsize:64	lr: 0.001	hidsize:[8, 8]
# acc:0.685	batchsize:64	lr: 0.001	hidsize:[16, 16]
# acc:0.696	batchsize:64	lr: 0.001	hidsize:[32, 32]
# acc:0.688	batchsize:64	lr: 0.001	hidsize:[64, 64]
# acc:0.689	batchsize:64	lr: 0.005	hidsize:[8, 8]
# acc:0.681	batchsize:64	lr: 0.005	hidsize:[16, 16]
# acc: 0.7	batchsize:64	lr: 0.005	hidsize:[32, 32]
# acc:0.688	batchsize:64	lr: 0.005	hidsize:[64, 64]
# acc:0.696	batchsize:64	lr:  0.01	hidsize:[8, 8]
# acc:0.679	batchsize:64	lr:  0.01	hidsize:[16, 16]
# acc:0.691	batchsize:64	lr:  0.01	hidsize:[32, 32]
# acc:0.69	batchsize:64	lr:  0.01	hidsize:[64, 64]
# acc:0.693	batchsize:64	lr:  0.05	hidsize:[8, 8]
# acc:0.69	batchsize:64	lr:  0.05	hidsize:[16, 16]
# acc:0.683	batchsize:64	lr:  0.05	hidsize:[32, 32]
# acc:0.681	batchsize:64	lr:  0.05	hidsize:[64, 64]
# --------------------------------------
# | [PEER] best batchsize   | 64       |
# | [PEER] best hidsize     | [32, 32] |
# | [PEER] best learning... | 0.005    |
# --------------------------------------
# ---------------------------------
# | [PEER] alpha = 0.1 | 0.722    |
# | [PEER] alpha = 0.2 | 0.722    |
# | [PEER] alpha = 0.3 | 0.698    |
# | [PEER] alpha = 0.4 | 0.697    |
# | [PEER] alpha = 0.5 | 0.715    |
# | [PEER] alpha = 0.6 | 0.709    |
# | [PEER] alpha = 0.7 | 0.679    |
# | [PEER] alpha = 0.8 | 0.626    |
# | [PEER] alpha = 0.9 | 0.611    |
# | [PEER] alpha = 1.0 | 0.597    |
# ---------------------------------
# --------------------------------------
# | [NN] with bce loss      | 0.866    |
# | [NN] with peer loss     | 0.856    |
# | [NN] with surrogate ... | 0.875    |
# | [PEER] best alpha       | 0.1      |
# --------------------------------------
# Logging to logs/svm/19-08-29-15-23-09
# {'dataset': 'image', 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'e0': 0.1, 'e1': 0.3, 'episodes': 3000, 'equalize_prior': True}
# --------------------------------
# | [C-SVM] C1 = 0.1  | 0.607    |
# | [C-SVM] C1 = 0.2  | 0.607    |
# | [C-SVM] C1 = 0.25 | 0.607    |
# | [C-SVM] C1 = 0.33 | 0.606    |
# | [C-SVM] C1 = 0.5  | 0.653    |
# | [C-SVM] C1 = 1.0  | 0.755    |
# | [C-SVM] C1 = 10.0 | 0.509    |
# | [C-SVM] C1 = 2.0  | 0.742    |
# | [C-SVM] C1 = 3.0  | 0.719    |
# | [C-SVM] C1 = 4.0  | 0.696    |
# | [C-SVM] C1 = 5.0  | 0.661    |
# --------------------------------
# ------------------------------------
# | [C-SVM] accuracy max  | 0.909    |
# | [C-SVM] accuracy mean | 0.892    |
# | [C-SVM] accuracy min  | 0.869    |
# | [C-SVM] accuracy std  | 0.0118   |
# | [C-SVM] best C1       | 1        |
# ------------------------------------
# Logging to logs/pam/19-08-29-15-23-10
# {'dataset': 'image', 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'e0': 0.1, 'e1': 0.3, 'episodes': 3000, 'equalize_prior': True}
# -----------------------------------
# | [PAM] margin = 0     | 0.601    |
# | [PAM] margin = 0.125 | 0.676    |
# | [PAM] margin = 0.25  | 0.682    |
# | [PAM] margin = 0.5   | 0.676    |
# | [PAM] margin = 1     | 0.68     |
# -----------------------------------
# ----------------------------------
# | [PAM] accuracy max  | 0.798    |
# | [PAM] accuracy mean | 0.743    |
# | [PAM] accuracy min  | 0.623    |
# | [PAM] accuracy std  | 0.0484   |
# | [PAM] best margin   | 0.25     |
# ----------------------------------

# %% [markdown]
# ### $e_0 = 0.2, e_1 = 0.2$

# %%
from run_nn import find_best_alpha
args = default_args.copy()
args.update({
    'e0': 0.2, 'e1': 0.2,
    'episodes': 3000,
    'equalize_prior': True,
    'batchsize': 64,
    'hidsize': [8, 8],
    'lr': 0.005,
})
find_best_alpha(args)
# Out:
# ---------------------------------
# | [PEER] alpha = 0.1 | 0.9      |
# | [PEER] alpha = 0.2 | 0.879    |
# | [PEER] alpha = 0.3 | 0.84     |
# | [PEER] alpha = 0.4 | 0.853    |
# | [PEER] alpha = 0.5 | 0.829    |
# | [PEER] alpha = 0.6 | 0.793    |
# | [PEER] alpha = 0.7 | 0.755    |
# | [PEER] alpha = 0.8 | 0.733    |
# | [PEER] alpha = 0.9 | 0.714    |
# | [PEER] alpha = 1.0 | 0.695    |
# ---------------------------------
# {'alpha': 0.1}

# %%
from runner import run
args = default_args.copy()
args.update({
    'e0': 0.2, 'e1': 0.2,
    'episodes': 3000,
    'equalize_prior': True,
})
run(args)
# Out:
# Logging to logs/nn/19-08-29-15-23-30
# {'dataset': 'image', 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'e0': 0.2, 'e1': 0.2, 'episodes': 3000, 'equalize_prior': True}
# acc:0.669	batchsize: 1	lr:0.0007	hidsize:[8, 8]
# acc:0.653	batchsize: 1	lr:0.0007	hidsize:[16, 16]
# acc:0.658	batchsize: 1	lr:0.0007	hidsize:[32, 32]
# acc:0.667	batchsize: 1	lr:0.0007	hidsize:[64, 64]
# acc:0.659	batchsize: 1	lr: 0.001	hidsize:[8, 8]
# acc:0.643	batchsize: 1	lr: 0.001	hidsize:[16, 16]
# acc:0.66	batchsize: 1	lr: 0.001	hidsize:[32, 32]
# acc:0.66	batchsize: 1	lr: 0.001	hidsize:[64, 64]
# acc:0.646	batchsize: 1	lr: 0.005	hidsize:[8, 8]
# acc:0.639	batchsize: 1	lr: 0.005	hidsize:[16, 16]
# acc:0.643	batchsize: 1	lr: 0.005	hidsize:[32, 32]
# acc:0.646	batchsize: 1	lr: 0.005	hidsize:[64, 64]
# acc:0.599	batchsize: 1	lr:  0.01	hidsize:[8, 8]
# acc:0.641	batchsize: 1	lr:  0.01	hidsize:[16, 16]
# acc:0.634	batchsize: 1	lr:  0.01	hidsize:[32, 32]
# acc:0.643	batchsize: 1	lr:  0.01	hidsize:[64, 64]
# acc:0.611	batchsize: 1	lr:  0.05	hidsize:[8, 8]
# acc:0.58	batchsize: 1	lr:  0.05	hidsize:[16, 16]
# acc:0.643	batchsize: 1	lr:  0.05	hidsize:[32, 32]
# acc:0.623	batchsize: 1	lr:  0.05	hidsize:[64, 64]
# acc:0.683	batchsize: 4	lr:0.0007	hidsize:[8, 8]
# acc:0.669	batchsize: 4	lr:0.0007	hidsize:[16, 16]
# acc:0.682	batchsize: 4	lr:0.0007	hidsize:[32, 32]
# acc:0.675	batchsize: 4	lr:0.0007	hidsize:[64, 64]
# acc:0.682	batchsize: 4	lr: 0.001	hidsize:[8, 8]
# acc:0.675	batchsize: 4	lr: 0.001	hidsize:[16, 16]
# acc:0.683	batchsize: 4	lr: 0.001	hidsize:[32, 32]
# acc:0.675	batchsize: 4	lr: 0.001	hidsize:[64, 64]
# acc:0.665	batchsize: 4	lr: 0.005	hidsize:[8, 8]
# acc:0.661	batchsize: 4	lr: 0.005	hidsize:[16, 16]
# acc:0.659	batchsize: 4	lr: 0.005	hidsize:[32, 32]
# acc:0.669	batchsize: 4	lr: 0.005	hidsize:[64, 64]
# acc:0.663	batchsize: 4	lr:  0.01	hidsize:[8, 8]
# acc:0.666	batchsize: 4	lr:  0.01	hidsize:[16, 16]
# acc:0.664	batchsize: 4	lr:  0.01	hidsize:[32, 32]
# acc:0.667	batchsize: 4	lr:  0.01	hidsize:[64, 64]
# acc:0.646	batchsize: 4	lr:  0.05	hidsize:[8, 8]
# acc:0.623	batchsize: 4	lr:  0.05	hidsize:[16, 16]
# acc:0.63	batchsize: 4	lr:  0.05	hidsize:[32, 32]
# acc:0.636	batchsize: 4	lr:  0.05	hidsize:[64, 64]
# acc:0.684	batchsize:16	lr:0.0007	hidsize:[8, 8]
# acc:0.67	batchsize:16	lr:0.0007	hidsize:[16, 16]
# acc:0.681	batchsize:16	lr:0.0007	hidsize:[32, 32]
# acc:0.679	batchsize:16	lr:0.0007	hidsize:[64, 64]
# acc:0.682	batchsize:16	lr: 0.001	hidsize:[8, 8]
# acc:0.672	batchsize:16	lr: 0.001	hidsize:[16, 16]
# acc:0.68	batchsize:16	lr: 0.001	hidsize:[32, 32]
# acc:0.678	batchsize:16	lr: 0.001	hidsize:[64, 64]
# acc:0.664	batchsize:16	lr: 0.005	hidsize:[8, 8]
# acc:0.678	batchsize:16	lr: 0.005	hidsize:[16, 16]
# acc:0.679	batchsize:16	lr: 0.005	hidsize:[32, 32]
# acc:0.671	batchsize:16	lr: 0.005	hidsize:[64, 64]
# acc:0.67	batchsize:16	lr:  0.01	hidsize:[8, 8]
# acc:0.675	batchsize:16	lr:  0.01	hidsize:[16, 16]
# acc:0.672	batchsize:16	lr:  0.01	hidsize:[32, 32]
# acc:0.672	batchsize:16	lr:  0.01	hidsize:[64, 64]
# acc:0.636	batchsize:16	lr:  0.05	hidsize:[8, 8]
# acc:0.621	batchsize:16	lr:  0.05	hidsize:[16, 16]
# acc:0.658	batchsize:16	lr:  0.05	hidsize:[32, 32]
# acc:0.663	batchsize:16	lr:  0.05	hidsize:[64, 64]
# acc:0.684	batchsize:32	lr:0.0007	hidsize:[8, 8]
# acc:0.67	batchsize:32	lr:0.0007	hidsize:[16, 16]
# acc:0.689	batchsize:32	lr:0.0007	hidsize:[32, 32]
# acc:0.684	batchsize:32	lr:0.0007	hidsize:[64, 64]
# acc:0.683	batchsize:32	lr: 0.001	hidsize:[8, 8]
# acc:0.673	batchsize:32	lr: 0.001	hidsize:[16, 16]
# acc:0.688	batchsize:32	lr: 0.001	hidsize:[32, 32]
# acc:0.681	batchsize:32	lr: 0.001	hidsize:[64, 64]
# acc:0.676	batchsize:32	lr: 0.005	hidsize:[8, 8]
# acc:0.662	batchsize:32	lr: 0.005	hidsize:[16, 16]
# acc:0.677	batchsize:32	lr: 0.005	hidsize:[32, 32]
# acc:0.677	batchsize:32	lr: 0.005	hidsize:[64, 64]
# acc:0.676	batchsize:32	lr:  0.01	hidsize:[8, 8]
# acc:0.668	batchsize:32	lr:  0.01	hidsize:[16, 16]
# acc:0.678	batchsize:32	lr:  0.01	hidsize:[32, 32]
# acc:0.673	batchsize:32	lr:  0.01	hidsize:[64, 64]
# acc:0.657	batchsize:32	lr:  0.05	hidsize:[8, 8]
# acc:0.66	batchsize:32	lr:  0.05	hidsize:[16, 16]
# acc:0.661	batchsize:32	lr:  0.05	hidsize:[32, 32]
# acc:0.666	batchsize:32	lr:  0.05	hidsize:[64, 64]
# acc:0.683	batchsize:64	lr:0.0007	hidsize:[8, 8]
# acc:0.672	batchsize:64	lr:0.0007	hidsize:[16, 16]
# acc:0.687	batchsize:64	lr:0.0007	hidsize:[32, 32]
# acc:0.691	batchsize:64	lr:0.0007	hidsize:[64, 64]
# acc:0.689	batchsize:64	lr: 0.001	hidsize:[8, 8]
# acc:0.672	batchsize:64	lr: 0.001	hidsize:[16, 16]
# acc:0.691	batchsize:64	lr: 0.001	hidsize:[32, 32]
# acc:0.689	batchsize:64	lr: 0.001	hidsize:[64, 64]
# acc:0.695	batchsize:64	lr: 0.005	hidsize:[8, 8]
# acc:0.672	batchsize:64	lr: 0.005	hidsize:[16, 16]
# acc:0.684	batchsize:64	lr: 0.005	hidsize:[32, 32]
# acc:0.68	batchsize:64	lr: 0.005	hidsize:[64, 64]
# acc:0.69	batchsize:64	lr:  0.01	hidsize:[8, 8]
# acc:0.678	batchsize:64	lr:  0.01	hidsize:[16, 16]
# acc:0.685	batchsize:64	lr:  0.01	hidsize:[32, 32]
# acc:0.676	batchsize:64	lr:  0.01	hidsize:[64, 64]
# acc:0.652	batchsize:64	lr:  0.05	hidsize:[8, 8]
# acc:0.677	batchsize:64	lr:  0.05	hidsize:[16, 16]
# acc:0.684	batchsize:64	lr:  0.05	hidsize:[32, 32]
# acc:0.675	batchsize:64	lr:  0.05	hidsize:[64, 64]
# --------------------------------------
# | [PEER] best batchsize   | 64       |
# | [PEER] best hidsize     | [8, 8]   |
# | [PEER] best learning... | 0.005    |
# --------------------------------------
# ---------------------------------
# | [PEER] alpha = 0.1 | 0.747    |
# | [PEER] alpha = 0.2 | 0.732    |
# | [PEER] alpha = 0.3 | 0.716    |
# | [PEER] alpha = 0.4 | 0.708    |
# | [PEER] alpha = 0.5 | 0.693    |
# | [PEER] alpha = 0.6 | 0.685    |
# | [PEER] alpha = 0.7 | 0.658    |
# | [PEER] alpha = 0.8 | 0.636    |
# | [PEER] alpha = 0.9 | 0.617    |
# | [PEER] alpha = 1.0 | 0.602    |
# ---------------------------------
# --------------------------------------
# | [NN] with bce loss      | 0.908    |
# | [NN] with peer loss     | 0.9      |
# | [NN] with surrogate ... | 0.835    |
# | [PEER] best alpha       | 0.1      |
# --------------------------------------
# Logging to logs/svm/19-08-29-15-43-56
# {'dataset': 'image', 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'e0': 0.2, 'e1': 0.2, 'episodes': 3000, 'equalize_prior': True}
# --------------------------------
# | [C-SVM] C1 = 0.1  | 0.508    |
# | [C-SVM] C1 = 0.2  | 0.508    |
# | [C-SVM] C1 = 0.25 | 0.546    |
# | [C-SVM] C1 = 0.33 | 0.584    |
# | [C-SVM] C1 = 0.5  | 0.678    |
# | [C-SVM] C1 = 1.0  | 0.751    |
# | [C-SVM] C1 = 10.0 | 0.495    |
# | [C-SVM] C1 = 2.0  | 0.722    |
# | [C-SVM] C1 = 3.0  | 0.649    |
# | [C-SVM] C1 = 4.0  | 0.596    |
# | [C-SVM] C1 = 5.0  | 0.541    |
# --------------------------------
# ------------------------------------
# | [C-SVM] accuracy max  | 0.949    |
# | [C-SVM] accuracy mean | 0.912    |
# | [C-SVM] accuracy min  | 0.889    |
# | [C-SVM] accuracy std  | 0.0209   |
# | [C-SVM] best C1       | 1        |
# ------------------------------------
# Logging to logs/pam/19-08-29-15-43-58
# {'dataset': 'image', 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'e0': 0.2, 'e1': 0.2, 'episodes': 3000, 'equalize_prior': True}
# -----------------------------------
# | [PAM] margin = 0     | 0.546    |
# | [PAM] margin = 0.125 | 0.674    |
# | [PAM] margin = 0.25  | 0.683    |
# | [PAM] margin = 0.5   | 0.68     |
# | [PAM] margin = 1     | 0.683    |
# -----------------------------------
# ----------------------------------
# | [PAM] accuracy max  | 0.855    |
# | [PAM] accuracy mean | 0.816    |
# | [PAM] accuracy min  | 0.758    |
# | [PAM] accuracy std  | 0.0326   |
# | [PAM] best margin   | 0.25     |
# ----------------------------------

# %% [markdown]
# ### $e_0 = 0.1, e_1 = 0.4$

# %%
from run_nn import find_best_alpha
args = default_args.copy()
args.update({
    'e0': 0.1, 'e1': 0.4,
    'episodes': 3000,
    'equalize_prior': True,
    'batchsize': 64,
    'hidsize': [32, 32],
    'lr': 0.01,
})
find_best_alpha(args)
# Out:
# ---------------------------------
# | [PEER] alpha = 0.1 | 0.761    |
# | [PEER] alpha = 0.2 | 0.734    |
# | [PEER] alpha = 0.3 | 0.723    |
# | [PEER] alpha = 0.4 | 0.727    |
# | [PEER] alpha = 0.5 | 0.695    |
# | [PEER] alpha = 0.6 | 0.732    |
# | [PEER] alpha = 0.7 | 0.742    |
# | [PEER] alpha = 0.8 | 0.742    |
# | [PEER] alpha = 0.9 | 0.699    |
# | [PEER] alpha = 1.0 | 0.693    |
# ---------------------------------
# {'alpha': 0.1}

# %%
from runner import run
args = default_args.copy()
args.update({
    'e0': 0.1, 'e1': 0.4,
    'episodes': 3000,
    'equalize_prior': True,
})
run(args)
# Out:
# Logging to logs/nn/19-08-29-16-24-57
# {'dataset': 'image', 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'e0': 0.1, 'e1': 0.4, 'episodes': 3000, 'equalize_prior': True}
# acc:0.669	batchsize: 1	lr:0.0007	hidsize:[8, 8]
# acc:0.656	batchsize: 1	lr:0.0007	hidsize:[16, 16]
# acc:0.666	batchsize: 1	lr:0.0007	hidsize:[32, 32]
# acc:0.67	batchsize: 1	lr:0.0007	hidsize:[64, 64]
# acc:0.67	batchsize: 1	lr: 0.001	hidsize:[8, 8]
# acc:0.657	batchsize: 1	lr: 0.001	hidsize:[16, 16]
# acc:0.667	batchsize: 1	lr: 0.001	hidsize:[32, 32]
# acc:0.665	batchsize: 1	lr: 0.001	hidsize:[64, 64]
# acc:0.633	batchsize: 1	lr: 0.005	hidsize:[8, 8]
# acc:0.649	batchsize: 1	lr: 0.005	hidsize:[16, 16]
# acc:0.647	batchsize: 1	lr: 0.005	hidsize:[32, 32]
# acc:0.654	batchsize: 1	lr: 0.005	hidsize:[64, 64]
# acc:0.622	batchsize: 1	lr:  0.01	hidsize:[8, 8]
# acc:0.634	batchsize: 1	lr:  0.01	hidsize:[16, 16]
# acc:0.648	batchsize: 1	lr:  0.01	hidsize:[32, 32]
# acc:0.65	batchsize: 1	lr:  0.01	hidsize:[64, 64]
# acc:0.545	batchsize: 1	lr:  0.05	hidsize:[8, 8]
# acc:0.624	batchsize: 1	lr:  0.05	hidsize:[16, 16]
# acc:0.652	batchsize: 1	lr:  0.05	hidsize:[32, 32]
# acc:0.617	batchsize: 1	lr:  0.05	hidsize:[64, 64]
# acc:0.687	batchsize: 4	lr:0.0007	hidsize:[8, 8]
# acc:0.669	batchsize: 4	lr:0.0007	hidsize:[16, 16]
# acc:0.682	batchsize: 4	lr:0.0007	hidsize:[32, 32]
# acc:0.678	batchsize: 4	lr:0.0007	hidsize:[64, 64]
# acc:0.682	batchsize: 4	lr: 0.001	hidsize:[8, 8]
# acc:0.664	batchsize: 4	lr: 0.001	hidsize:[16, 16]
# acc:0.68	batchsize: 4	lr: 0.001	hidsize:[32, 32]
# acc:0.678	batchsize: 4	lr: 0.001	hidsize:[64, 64]
# acc:0.665	batchsize: 4	lr: 0.005	hidsize:[8, 8]
# acc:0.658	batchsize: 4	lr: 0.005	hidsize:[16, 16]
# acc:0.67	batchsize: 4	lr: 0.005	hidsize:[32, 32]
# acc:0.666	batchsize: 4	lr: 0.005	hidsize:[64, 64]
# acc:0.654	batchsize: 4	lr:  0.01	hidsize:[8, 8]
# acc:0.66	batchsize: 4	lr:  0.01	hidsize:[16, 16]
# acc:0.67	batchsize: 4	lr:  0.01	hidsize:[32, 32]
# acc:0.664	batchsize: 4	lr:  0.01	hidsize:[64, 64]
# acc:0.583	batchsize: 4	lr:  0.05	hidsize:[8, 8]
# acc:0.623	batchsize: 4	lr:  0.05	hidsize:[16, 16]
# acc:0.657	batchsize: 4	lr:  0.05	hidsize:[32, 32]
# acc:0.677	batchsize: 4	lr:  0.05	hidsize:[64, 64]
# acc:0.684	batchsize:16	lr:0.0007	hidsize:[8, 8]
# acc:0.668	batchsize:16	lr:0.0007	hidsize:[16, 16]
# acc:0.682	batchsize:16	lr:0.0007	hidsize:[32, 32]
# acc:0.677	batchsize:16	lr:0.0007	hidsize:[64, 64]
# acc:0.681	batchsize:16	lr: 0.001	hidsize:[8, 8]
# acc:0.668	batchsize:16	lr: 0.001	hidsize:[16, 16]
# acc:0.677	batchsize:16	lr: 0.001	hidsize:[32, 32]
# acc:0.675	batchsize:16	lr: 0.001	hidsize:[64, 64]
# acc:0.669	batchsize:16	lr: 0.005	hidsize:[8, 8]
# acc:0.673	batchsize:16	lr: 0.005	hidsize:[16, 16]
# acc:0.678	batchsize:16	lr: 0.005	hidsize:[32, 32]
# acc:0.67	batchsize:16	lr: 0.005	hidsize:[64, 64]
# acc:0.683	batchsize:16	lr:  0.01	hidsize:[8, 8]
# acc:0.673	batchsize:16	lr:  0.01	hidsize:[16, 16]
# acc:0.672	batchsize:16	lr:  0.01	hidsize:[32, 32]
# acc:0.665	batchsize:16	lr:  0.01	hidsize:[64, 64]
# acc:0.646	batchsize:16	lr:  0.05	hidsize:[8, 8]
# acc:0.654	batchsize:16	lr:  0.05	hidsize:[16, 16]
# acc:0.668	batchsize:16	lr:  0.05	hidsize:[32, 32]
# acc:0.667	batchsize:16	lr:  0.05	hidsize:[64, 64]
# acc:0.689	batchsize:32	lr:0.0007	hidsize:[8, 8]
# acc:0.678	batchsize:32	lr:0.0007	hidsize:[16, 16]
# acc:0.688	batchsize:32	lr:0.0007	hidsize:[32, 32]
# acc:0.684	batchsize:32	lr:0.0007	hidsize:[64, 64]
# acc:0.689	batchsize:32	lr: 0.001	hidsize:[8, 8]
# acc:0.674	batchsize:32	lr: 0.001	hidsize:[16, 16]
# acc:0.685	batchsize:32	lr: 0.001	hidsize:[32, 32]
# acc:0.687	batchsize:32	lr: 0.001	hidsize:[64, 64]
# acc:0.677	batchsize:32	lr: 0.005	hidsize:[8, 8]
# acc:0.678	batchsize:32	lr: 0.005	hidsize:[16, 16]
# acc:0.679	batchsize:32	lr: 0.005	hidsize:[32, 32]
# acc:0.68	batchsize:32	lr: 0.005	hidsize:[64, 64]
# acc:0.682	batchsize:32	lr:  0.01	hidsize:[8, 8]
# acc:0.67	batchsize:32	lr:  0.01	hidsize:[16, 16]
# acc:0.681	batchsize:32	lr:  0.01	hidsize:[32, 32]
# acc:0.677	batchsize:32	lr:  0.01	hidsize:[64, 64]
# acc:0.649	batchsize:32	lr:  0.05	hidsize:[8, 8]
# acc:0.67	batchsize:32	lr:  0.05	hidsize:[16, 16]
# acc:0.677	batchsize:32	lr:  0.05	hidsize:[32, 32]
# acc:0.66	batchsize:32	lr:  0.05	hidsize:[64, 64]
# acc:0.692	batchsize:64	lr:0.0007	hidsize:[8, 8]
# acc:0.682	batchsize:64	lr:0.0007	hidsize:[16, 16]
# acc:0.692	batchsize:64	lr:0.0007	hidsize:[32, 32]
# acc:0.69	batchsize:64	lr:0.0007	hidsize:[64, 64]
# acc:0.689	batchsize:64	lr: 0.001	hidsize:[8, 8]
# acc:0.676	batchsize:64	lr: 0.001	hidsize:[16, 16]
# acc:0.691	batchsize:64	lr: 0.001	hidsize:[32, 32]
# acc:0.686	batchsize:64	lr: 0.001	hidsize:[64, 64]
# acc:0.677	batchsize:64	lr: 0.005	hidsize:[8, 8]
# acc:0.68	batchsize:64	lr: 0.005	hidsize:[16, 16]
# acc:0.687	batchsize:64	lr: 0.005	hidsize:[32, 32]
# acc:0.689	batchsize:64	lr: 0.005	hidsize:[64, 64]
# acc:0.689	batchsize:64	lr:  0.01	hidsize:[8, 8]
# acc:0.683	batchsize:64	lr:  0.01	hidsize:[16, 16]
# acc:0.693	batchsize:64	lr:  0.01	hidsize:[32, 32]
# acc:0.689	batchsize:64	lr:  0.01	hidsize:[64, 64]
# acc:0.684	batchsize:64	lr:  0.05	hidsize:[8, 8]
# acc:0.687	batchsize:64	lr:  0.05	hidsize:[16, 16]
# acc:0.684	batchsize:64	lr:  0.05	hidsize:[32, 32]
# acc:0.682	batchsize:64	lr:  0.05	hidsize:[64, 64]
# --------------------------------------
# | [PEER] best batchsize   | 64       |
# | [PEER] best hidsize     | [32, 32] |
# | [PEER] best learning... | 0.01     |
# --------------------------------------
# ---------------------------------
# | [PEER] alpha = 0.1 | 0.688    |
# | [PEER] alpha = 0.2 | 0.68     |
# | [PEER] alpha = 0.3 | 0.689    |
# | [PEER] alpha = 0.4 | 0.658    |
# | [PEER] alpha = 0.5 | 0.647    |
# | [PEER] alpha = 0.6 | 0.661    |
# | [PEER] alpha = 0.7 | 0.655    |
# | [PEER] alpha = 0.8 | 0.626    |
# | [PEER] alpha = 0.9 | 0.588    |
# | [PEER] alpha = 1.0 | 0.577    |
# ---------------------------------
# --------------------------------------
# | [NN] with bce loss      | 0.799    |
# | [NN] with peer loss     | 0.723    |
# | [NN] with surrogate ... | 0.841    |
# | [PEER] best alpha       | 0.3      |
# --------------------------------------
# Logging to logs/svm/19-08-29-16-43-31
# {'dataset': 'image', 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'e0': 0.1, 'e1': 0.4, 'episodes': 3000, 'equalize_prior': True}
# --------------------------------
# | [C-SVM] C1 = 0.1  | 0.656    |
# | [C-SVM] C1 = 0.2  | 0.656    |
# | [C-SVM] C1 = 0.25 | 0.656    |
# | [C-SVM] C1 = 0.33 | 0.656    |
# | [C-SVM] C1 = 0.5  | 0.656    |
# | [C-SVM] C1 = 1.0  | 0.705    |
# | [C-SVM] C1 = 10.0 | 0.457    |
# | [C-SVM] C1 = 2.0  | 0.704    |
# | [C-SVM] C1 = 3.0  | 0.675    |
# | [C-SVM] C1 = 4.0  | 0.652    |
# | [C-SVM] C1 = 5.0  | 0.621    |
# --------------------------------
# ------------------------------------
# | [C-SVM] accuracy max  | 0.845    |
# | [C-SVM] accuracy mean | 0.785    |
# | [C-SVM] accuracy min  | 0.663    |
# | [C-SVM] accuracy std  | 0.0535   |
# | [C-SVM] best C1       | 1        |
# ------------------------------------
# Logging to logs/pam/19-08-29-16-43-32
# {'dataset': 'image', 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'e0': 0.1, 'e1': 0.4, 'episodes': 3000, 'equalize_prior': True}
# -----------------------------------
# | [PAM] margin = 0     | 0.594    |
# | [PAM] margin = 0.125 | 0.673    |
# | [PAM] margin = 0.25  | 0.671    |
# | [PAM] margin = 0.5   | 0.675    |
# | [PAM] margin = 1     | 0.677    |
# -----------------------------------
# ----------------------------------
# | [PAM] accuracy max  | 0.626    |
# | [PAM] accuracy mean | 0.585    |
# | [PAM] accuracy min  | 0.552    |
# | [PAM] accuracy std  | 0.027    |
# | [PAM] best margin   | 1        |
# ----------------------------------

# %% [markdown]
# ### $e_0 = 0.2, e_1 = 0.4$

# %%
from run_nn import find_best_alpha
args = default_args.copy()
args.update({
    'e0': 0.2, 'e1': 0.4,
    'episodes': 3000,
    'equalize_prior': True,
    'batchsize': 64,
    'hidsize': [32, 32],
    'lr': 0.001,
})
find_best_alpha(args)
# Out:
# ---------------------------------
# | [PEER] alpha = 0.1 | 0.836    |
# | [PEER] alpha = 0.2 | 0.845    |
# | [PEER] alpha = 0.3 | 0.846    |
# | [PEER] alpha = 0.4 | 0.851    |
# | [PEER] alpha = 0.5 | 0.838    |
# | [PEER] alpha = 0.6 | 0.822    |
# | [PEER] alpha = 0.7 | 0.817    |
# | [PEER] alpha = 0.8 | 0.79     |
# | [PEER] alpha = 0.9 | 0.722    |
# | [PEER] alpha = 1.0 | 0.695    |
# ---------------------------------
# {'alpha': 0.4}

# %%
from runner import run
args = default_args.copy()
args.update({
    'e0': 0.2, 'e1': 0.4,
    'episodes': 3000,
    'equalize_prior': True,
})
run(args)
# Out:
# Logging to logs/nn/19-08-29-15-44-15
# {'dataset': 'image', 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'e0': 0.2, 'e1': 0.4, 'episodes': 3000, 'equalize_prior': True}
# acc:0.653	batchsize: 1	lr:0.0007	hidsize:[8, 8]
# acc:0.663	batchsize: 1	lr:0.0007	hidsize:[16, 16]
# acc:0.663	batchsize: 1	lr:0.0007	hidsize:[32, 32]
# acc:0.665	batchsize: 1	lr:0.0007	hidsize:[64, 64]
# acc:0.639	batchsize: 1	lr: 0.001	hidsize:[8, 8]
# acc:0.665	batchsize: 1	lr: 0.001	hidsize:[16, 16]
# acc:0.666	batchsize: 1	lr: 0.001	hidsize:[32, 32]
# acc:0.662	batchsize: 1	lr: 0.001	hidsize:[64, 64]
# acc:0.633	batchsize: 1	lr: 0.005	hidsize:[8, 8]
# acc:0.654	batchsize: 1	lr: 0.005	hidsize:[16, 16]
# acc:0.65	batchsize: 1	lr: 0.005	hidsize:[32, 32]
# acc:0.649	batchsize: 1	lr: 0.005	hidsize:[64, 64]
# acc:0.608	batchsize: 1	lr:  0.01	hidsize:[8, 8]
# acc:0.652	batchsize: 1	lr:  0.01	hidsize:[16, 16]
# acc:0.647	batchsize: 1	lr:  0.01	hidsize:[32, 32]
# acc:0.646	batchsize: 1	lr:  0.01	hidsize:[64, 64]
# acc:0.53	batchsize: 1	lr:  0.05	hidsize:[8, 8]
# acc:0.641	batchsize: 1	lr:  0.05	hidsize:[16, 16]
# acc:0.631	batchsize: 1	lr:  0.05	hidsize:[32, 32]
# acc:0.608	batchsize: 1	lr:  0.05	hidsize:[64, 64]
# acc:0.691	batchsize: 4	lr:0.0007	hidsize:[8, 8]
# acc:0.678	batchsize: 4	lr:0.0007	hidsize:[16, 16]
# acc:0.687	batchsize: 4	lr:0.0007	hidsize:[32, 32]
# acc:0.683	batchsize: 4	lr:0.0007	hidsize:[64, 64]
# acc:0.691	batchsize: 4	lr: 0.001	hidsize:[8, 8]
# acc:0.673	batchsize: 4	lr: 0.001	hidsize:[16, 16]
# acc:0.684	batchsize: 4	lr: 0.001	hidsize:[32, 32]
# acc:0.68	batchsize: 4	lr: 0.001	hidsize:[64, 64]
# acc:0.673	batchsize: 4	lr: 0.005	hidsize:[8, 8]
# acc:0.657	batchsize: 4	lr: 0.005	hidsize:[16, 16]
# acc:0.668	batchsize: 4	lr: 0.005	hidsize:[32, 32]
# acc:0.67	batchsize: 4	lr: 0.005	hidsize:[64, 64]
# acc:0.66	batchsize: 4	lr:  0.01	hidsize:[8, 8]
# acc:0.671	batchsize: 4	lr:  0.01	hidsize:[16, 16]
# acc:0.674	batchsize: 4	lr:  0.01	hidsize:[32, 32]
# acc:0.673	batchsize: 4	lr:  0.01	hidsize:[64, 64]
# acc:0.659	batchsize: 4	lr:  0.05	hidsize:[8, 8]
# acc:0.593	batchsize: 4	lr:  0.05	hidsize:[16, 16]
# acc:0.645	batchsize: 4	lr:  0.05	hidsize:[32, 32]
# acc:0.676	batchsize: 4	lr:  0.05	hidsize:[64, 64]
# acc:0.694	batchsize:16	lr:0.0007	hidsize:[8, 8]
# acc:0.687	batchsize:16	lr:0.0007	hidsize:[16, 16]
# acc:0.687	batchsize:16	lr:0.0007	hidsize:[32, 32]
# acc:0.684	batchsize:16	lr:0.0007	hidsize:[64, 64]
# acc:0.686	batchsize:16	lr: 0.001	hidsize:[8, 8]
# acc:0.676	batchsize:16	lr: 0.001	hidsize:[16, 16]
# acc:0.686	batchsize:16	lr: 0.001	hidsize:[32, 32]
# acc:0.682	batchsize:16	lr: 0.001	hidsize:[64, 64]
# acc:0.673	batchsize:16	lr: 0.005	hidsize:[8, 8]
# acc:0.679	batchsize:16	lr: 0.005	hidsize:[16, 16]
# acc:0.675	batchsize:16	lr: 0.005	hidsize:[32, 32]
# acc:0.679	batchsize:16	lr: 0.005	hidsize:[64, 64]
# acc:0.658	batchsize:16	lr:  0.01	hidsize:[8, 8]
# acc:0.676	batchsize:16	lr:  0.01	hidsize:[16, 16]
# acc:0.671	batchsize:16	lr:  0.01	hidsize:[32, 32]
# acc:0.68	batchsize:16	lr:  0.01	hidsize:[64, 64]
# acc:0.668	batchsize:16	lr:  0.05	hidsize:[8, 8]
# acc:0.654	batchsize:16	lr:  0.05	hidsize:[16, 16]
# acc:0.662	batchsize:16	lr:  0.05	hidsize:[32, 32]
# acc:0.667	batchsize:16	lr:  0.05	hidsize:[64, 64]
# acc:0.69	batchsize:32	lr:0.0007	hidsize:[8, 8]
# acc:0.68	batchsize:32	lr:0.0007	hidsize:[16, 16]
# acc:0.692	batchsize:32	lr:0.0007	hidsize:[32, 32]
# acc:0.684	batchsize:32	lr:0.0007	hidsize:[64, 64]
# acc:0.684	batchsize:32	lr: 0.001	hidsize:[8, 8]
# acc:0.678	batchsize:32	lr: 0.001	hidsize:[16, 16]
# acc:0.687	batchsize:32	lr: 0.001	hidsize:[32, 32]
# acc:0.686	batchsize:32	lr: 0.001	hidsize:[64, 64]
# acc:0.673	batchsize:32	lr: 0.005	hidsize:[8, 8]
# acc:0.672	batchsize:32	lr: 0.005	hidsize:[16, 16]
# acc:0.685	batchsize:32	lr: 0.005	hidsize:[32, 32]
# acc:0.684	batchsize:32	lr: 0.005	hidsize:[64, 64]
# acc:0.678	batchsize:32	lr:  0.01	hidsize:[8, 8]
# acc:0.67	batchsize:32	lr:  0.01	hidsize:[16, 16]
# acc:0.68	batchsize:32	lr:  0.01	hidsize:[32, 32]
# acc:0.67	batchsize:32	lr:  0.01	hidsize:[64, 64]
# acc:0.644	batchsize:32	lr:  0.05	hidsize:[8, 8]
# acc:0.659	batchsize:32	lr:  0.05	hidsize:[16, 16]
# acc:0.657	batchsize:32	lr:  0.05	hidsize:[32, 32]
# acc:0.664	batchsize:32	lr:  0.05	hidsize:[64, 64]
# acc:0.689	batchsize:64	lr:0.0007	hidsize:[8, 8]
# acc:0.686	batchsize:64	lr:0.0007	hidsize:[16, 16]
# acc:0.693	batchsize:64	lr:0.0007	hidsize:[32, 32]
# acc:0.691	batchsize:64	lr:0.0007	hidsize:[64, 64]
# acc:0.68	batchsize:64	lr: 0.001	hidsize:[8, 8]
# acc:0.68	batchsize:64	lr: 0.001	hidsize:[16, 16]
# acc:0.695	batchsize:64	lr: 0.001	hidsize:[32, 32]
# acc:0.692	batchsize:64	lr: 0.001	hidsize:[64, 64]
# acc:0.674	batchsize:64	lr: 0.005	hidsize:[8, 8]
# acc:0.681	batchsize:64	lr: 0.005	hidsize:[16, 16]
# acc:0.687	batchsize:64	lr: 0.005	hidsize:[32, 32]
# acc:0.684	batchsize:64	lr: 0.005	hidsize:[64, 64]
# acc:0.685	batchsize:64	lr:  0.01	hidsize:[8, 8]
# acc:0.678	batchsize:64	lr:  0.01	hidsize:[16, 16]
# acc:0.68	batchsize:64	lr:  0.01	hidsize:[32, 32]
# acc:0.68	batchsize:64	lr:  0.01	hidsize:[64, 64]
# acc:0.652	batchsize:64	lr:  0.05	hidsize:[8, 8]
# acc:0.678	batchsize:64	lr:  0.05	hidsize:[16, 16]
# acc:0.676	batchsize:64	lr:  0.05	hidsize:[32, 32]
# acc:0.677	batchsize:64	lr:  0.05	hidsize:[64, 64]
# --------------------------------------
# | [PEER] best batchsize   | 64       |
# | [PEER] best hidsize     | [32, 32] |
# | [PEER] best learning... | 0.001    |
# --------------------------------------
# ---------------------------------
# | [PEER] alpha = 0.1 | 0.671    |
# | [PEER] alpha = 0.2 | 0.668    |
# | [PEER] alpha = 0.3 | 0.665    |
# | [PEER] alpha = 0.4 | 0.659    |
# | [PEER] alpha = 0.5 | 0.651    |
# | [PEER] alpha = 0.6 | 0.653    |
# | [PEER] alpha = 0.7 | 0.637    |
# | [PEER] alpha = 0.8 | 0.609    |
# | [PEER] alpha = 0.9 | 0.585    |
# | [PEER] alpha = 1.0 | 0.567    |
# ---------------------------------
# --------------------------------------
# | [NN] with bce loss      | 0.832    |
# | [NN] with peer loss     | 0.836    |
# | [NN] with surrogate ... | 0.862    |
# | [PEER] best alpha       | 0.1      |
# --------------------------------------
# Logging to logs/svm/19-08-29-16-04-44
# {'dataset': 'image', 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'e0': 0.2, 'e1': 0.4, 'episodes': 3000, 'equalize_prior': True}
# --------------------------------
# | [C-SVM] C1 = 0.1  | 0.606    |
# | [C-SVM] C1 = 0.2  | 0.606    |
# | [C-SVM] C1 = 0.25 | 0.606    |
# | [C-SVM] C1 = 0.33 | 0.606    |
# | [C-SVM] C1 = 0.5  | 0.606    |
# | [C-SVM] C1 = 1.0  | 0.659    |
# | [C-SVM] C1 = 10.0 | 0.398    |
# | [C-SVM] C1 = 2.0  | 0.635    |
# | [C-SVM] C1 = 3.0  | 0.561    |
# | [C-SVM] C1 = 4.0  | 0.499    |
# | [C-SVM] C1 = 5.0  | 0.441    |
# --------------------------------
# ------------------------------------
# | [C-SVM] accuracy max  | 0.865    |
# | [C-SVM] accuracy mean | 0.802    |
# | [C-SVM] accuracy min  | 0.7      |
# | [C-SVM] accuracy std  | 0.0506   |
# | [C-SVM] best C1       | 1        |
# ------------------------------------
# Logging to logs/pam/19-08-29-16-04-45
# {'dataset': 'image', 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'e0': 0.2, 'e1': 0.4, 'episodes': 3000, 'equalize_prior': True}
# -----------------------------------
# | [PAM] margin = 0     | 0.538    |
# | [PAM] margin = 0.125 | 0.626    |
# | [PAM] margin = 0.25  | 0.622    |
# | [PAM] margin = 0.5   | 0.631    |
# | [PAM] margin = 1     | 0.629    |
# -----------------------------------
# ----------------------------------
# | [PAM] accuracy max  | 0.707    |
# | [PAM] accuracy mean | 0.623    |
# | [PAM] accuracy min  | 0.552    |
# | [PAM] accuracy std  | 0.0507   |
# | [PAM] best margin   | 0.5      |
# ----------------------------------

# %% [markdown]
# ### $e_0=0.4, e_1=0.4$

# %%
from run_nn import find_best_alpha
args = default_args.copy()
args.update({
    'e0': 0.4, 'e1': 0.4,
    'episodes': 3000,
    'equalize_prior': True,
    'batchsize': 4,
    'hidsize': [16, 16],
    'lr': 0.0007,
})
find_best_alpha(args)
# Out:
# ---------------------------------
# | [PEER] alpha = 0.1 | 0.758    |
# | [PEER] alpha = 0.2 | 0.757    |
# | [PEER] alpha = 0.3 | 0.757    |
# | [PEER] alpha = 0.4 | 0.751    |
# | [PEER] alpha = 0.5 | 0.741    |
# | [PEER] alpha = 0.6 | 0.747    |
# | [PEER] alpha = 0.7 | 0.737    |
# | [PEER] alpha = 0.8 | 0.727    |
# | [PEER] alpha = 0.9 | 0.712    |
# | [PEER] alpha = 1.0 | 0.693    |
# ---------------------------------
# {'alpha': 0.1}

# %%
from runner import run
args = default_args.copy()
args.update({
    'e0': 0.4, 'e1': 0.4,
    'episodes': 3000,
    'equalize_prior': True,
})
run(args)
# Out:
# Logging to logs/nn/19-08-29-17-33-37
# {'dataset': 'image', 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'e0': 0.4, 'e1': 0.4, 'episodes': 3000, 'equalize_prior': True}
# acc:0.581	batchsize: 1	lr:0.0007	hidsize:[8, 8]
# acc:0.614	batchsize: 1	lr:0.0007	hidsize:[16, 16]
# acc:0.637	batchsize: 1	lr:0.0007	hidsize:[32, 32]
# acc:0.635	batchsize: 1	lr:0.0007	hidsize:[64, 64]
# acc:0.604	batchsize: 1	lr: 0.001	hidsize:[8, 8]
# acc:0.623	batchsize: 1	lr: 0.001	hidsize:[16, 16]
# acc:0.638	batchsize: 1	lr: 0.001	hidsize:[32, 32]
# acc:0.641	batchsize: 1	lr: 0.001	hidsize:[64, 64]
# acc:0.604	batchsize: 1	lr: 0.005	hidsize:[8, 8]
# acc:0.618	batchsize: 1	lr: 0.005	hidsize:[16, 16]
# acc:0.641	batchsize: 1	lr: 0.005	hidsize:[32, 32]
# acc:0.627	batchsize: 1	lr: 0.005	hidsize:[64, 64]
# acc:0.597	batchsize: 1	lr:  0.01	hidsize:[8, 8]
# acc:0.617	batchsize: 1	lr:  0.01	hidsize:[16, 16]
# acc:0.574	batchsize: 1	lr:  0.01	hidsize:[32, 32]
# acc:0.609	batchsize: 1	lr:  0.01	hidsize:[64, 64]
# acc:0.514	batchsize: 1	lr:  0.05	hidsize:[8, 8]
# acc:0.561	batchsize: 1	lr:  0.05	hidsize:[16, 16]
# acc:0.562	batchsize: 1	lr:  0.05	hidsize:[32, 32]
# acc:0.554	batchsize: 1	lr:  0.05	hidsize:[64, 64]
# acc:0.673	batchsize: 4	lr:0.0007	hidsize:[8, 8]
# acc:0.693	batchsize: 4	lr:0.0007	hidsize:[16, 16]
# acc:0.686	batchsize: 4	lr:0.0007	hidsize:[32, 32]
# acc:0.678	batchsize: 4	lr:0.0007	hidsize:[64, 64]
# acc:0.685	batchsize: 4	lr: 0.001	hidsize:[8, 8]
# acc:0.686	batchsize: 4	lr: 0.001	hidsize:[16, 16]
# acc:0.689	batchsize: 4	lr: 0.001	hidsize:[32, 32]
# acc:0.676	batchsize: 4	lr: 0.001	hidsize:[64, 64]
# acc:0.676	batchsize: 4	lr: 0.005	hidsize:[8, 8]
# acc:0.671	batchsize: 4	lr: 0.005	hidsize:[16, 16]
# acc:0.65	batchsize: 4	lr: 0.005	hidsize:[32, 32]
# acc:0.659	batchsize: 4	lr: 0.005	hidsize:[64, 64]
# acc:0.673	batchsize: 4	lr:  0.01	hidsize:[8, 8]
# acc:0.651	batchsize: 4	lr:  0.01	hidsize:[16, 16]
# acc:0.63	batchsize: 4	lr:  0.01	hidsize:[32, 32]
# acc:0.649	batchsize: 4	lr:  0.01	hidsize:[64, 64]
# acc:0.575	batchsize: 4	lr:  0.05	hidsize:[8, 8]
# acc:0.582	batchsize: 4	lr:  0.05	hidsize:[16, 16]
# acc:0.639	batchsize: 4	lr:  0.05	hidsize:[32, 32]
# acc:0.665	batchsize: 4	lr:  0.05	hidsize:[64, 64]
# acc:0.687	batchsize:16	lr:0.0007	hidsize:[8, 8]
# acc:0.684	batchsize:16	lr:0.0007	hidsize:[16, 16]
# acc:0.684	batchsize:16	lr:0.0007	hidsize:[32, 32]
# acc:0.683	batchsize:16	lr:0.0007	hidsize:[64, 64]
# acc:0.681	batchsize:16	lr: 0.001	hidsize:[8, 8]
# acc:0.688	batchsize:16	lr: 0.001	hidsize:[16, 16]
# acc:0.686	batchsize:16	lr: 0.001	hidsize:[32, 32]
# acc:0.686	batchsize:16	lr: 0.001	hidsize:[64, 64]
# acc:0.667	batchsize:16	lr: 0.005	hidsize:[8, 8]
# acc:0.675	batchsize:16	lr: 0.005	hidsize:[16, 16]
# acc:0.675	batchsize:16	lr: 0.005	hidsize:[32, 32]
# acc:0.674	batchsize:16	lr: 0.005	hidsize:[64, 64]
# acc:0.66	batchsize:16	lr:  0.01	hidsize:[8, 8]
# acc:0.678	batchsize:16	lr:  0.01	hidsize:[16, 16]
# acc:0.659	batchsize:16	lr:  0.01	hidsize:[32, 32]
# acc:0.666	batchsize:16	lr:  0.01	hidsize:[64, 64]
# acc:0.58	batchsize:16	lr:  0.05	hidsize:[8, 8]
# acc:0.666	batchsize:16	lr:  0.05	hidsize:[16, 16]
# acc:0.643	batchsize:16	lr:  0.05	hidsize:[32, 32]
# acc:0.685	batchsize:16	lr:  0.05	hidsize:[64, 64]
# acc:0.687	batchsize:32	lr:0.0007	hidsize:[8, 8]
# acc:0.68	batchsize:32	lr:0.0007	hidsize:[16, 16]
# acc:0.688	batchsize:32	lr:0.0007	hidsize:[32, 32]
# acc:0.679	batchsize:32	lr:0.0007	hidsize:[64, 64]
# acc:0.689	batchsize:32	lr: 0.001	hidsize:[8, 8]
# acc:0.681	batchsize:32	lr: 0.001	hidsize:[16, 16]
# acc:0.685	batchsize:32	lr: 0.001	hidsize:[32, 32]
# acc:0.675	batchsize:32	lr: 0.001	hidsize:[64, 64]
# acc:0.674	batchsize:32	lr: 0.005	hidsize:[8, 8]
# acc:0.668	batchsize:32	lr: 0.005	hidsize:[16, 16]
# acc:0.684	batchsize:32	lr: 0.005	hidsize:[32, 32]
# acc:0.667	batchsize:32	lr: 0.005	hidsize:[64, 64]
# acc:0.658	batchsize:32	lr:  0.01	hidsize:[8, 8]
# acc:0.638	batchsize:32	lr:  0.01	hidsize:[16, 16]
# acc:0.677	batchsize:32	lr:  0.01	hidsize:[32, 32]
# acc:0.67	batchsize:32	lr:  0.01	hidsize:[64, 64]
# acc:0.579	batchsize:32	lr:  0.05	hidsize:[8, 8]
# acc:0.634	batchsize:32	lr:  0.05	hidsize:[16, 16]
# acc:0.642	batchsize:32	lr:  0.05	hidsize:[32, 32]
# acc:0.66	batchsize:32	lr:  0.05	hidsize:[64, 64]
# acc:0.681	batchsize:64	lr:0.0007	hidsize:[8, 8]
# acc:0.676	batchsize:64	lr:0.0007	hidsize:[16, 16]
# acc:0.691	batchsize:64	lr:0.0007	hidsize:[32, 32]
# acc:0.673	batchsize:64	lr:0.0007	hidsize:[64, 64]
# acc:0.687	batchsize:64	lr: 0.001	hidsize:[8, 8]
# acc:0.677	batchsize:64	lr: 0.001	hidsize:[16, 16]
# acc:0.688	batchsize:64	lr: 0.001	hidsize:[32, 32]
# acc:0.675	batchsize:64	lr: 0.001	hidsize:[64, 64]
# acc:0.668	batchsize:64	lr: 0.005	hidsize:[8, 8]
# acc:0.673	batchsize:64	lr: 0.005	hidsize:[16, 16]
# acc:0.68	batchsize:64	lr: 0.005	hidsize:[32, 32]
# acc:0.674	batchsize:64	lr: 0.005	hidsize:[64, 64]
# acc:0.677	batchsize:64	lr:  0.01	hidsize:[8, 8]
# acc:0.676	batchsize:64	lr:  0.01	hidsize:[16, 16]
# acc:0.674	batchsize:64	lr:  0.01	hidsize:[32, 32]
# acc:0.67	batchsize:64	lr:  0.01	hidsize:[64, 64]
# acc:0.616	batchsize:64	lr:  0.05	hidsize:[8, 8]
# acc:0.662	batchsize:64	lr:  0.05	hidsize:[16, 16]
# acc:0.679	batchsize:64	lr:  0.05	hidsize:[32, 32]
# acc:0.668	batchsize:64	lr:  0.05	hidsize:[64, 64]
# --------------------------------------
# | [PEER] best batchsize   | 4        |
# | [PEER] best hidsize     | [16, 16] |
# | [PEER] best learning... | 0.0007   |
# --------------------------------------
# ---------------------------------
# | [PEER] alpha = 0.1 | 0.55     |
# | [PEER] alpha = 0.2 | 0.553    |
# | [PEER] alpha = 0.3 | 0.555    |
# | [PEER] alpha = 0.4 | 0.552    |
# | [PEER] alpha = 0.5 | 0.56     |
# | [PEER] alpha = 0.6 | 0.556    |
# | [PEER] alpha = 0.7 | 0.557    |
# | [PEER] alpha = 0.8 | 0.546    |
# | [PEER] alpha = 0.9 | 0.548    |
# | [PEER] alpha = 1.0 | 0.542    |
# ---------------------------------
# --------------------------------------
# | [NN] with bce loss      | 0.732    |
# | [NN] with peer loss     | 0.741    |
# | [NN] with surrogate ... | 0.72     |
# | [PEER] best alpha       | 0.5      |
# --------------------------------------
# Logging to logs/svm/19-08-29-17-51-30
# {'dataset': 'image', 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'e0': 0.4, 'e1': 0.4, 'episodes': 3000, 'equalize_prior': True}
# --------------------------------
# | [C-SVM] C1 = 0.1  | 0.503    |
# | [C-SVM] C1 = 0.2  | 0.503    |
# | [C-SVM] C1 = 0.25 | 0.503    |
# | [C-SVM] C1 = 0.33 | 0.503    |
# | [C-SVM] C1 = 0.5  | 0.504    |
# | [C-SVM] C1 = 1.0  | 0.571    |
# | [C-SVM] C1 = 10.0 | 0.497    |
# | [C-SVM] C1 = 2.0  | 0.508    |
# | [C-SVM] C1 = 3.0  | 0.499    |
# | [C-SVM] C1 = 4.0  | 0.496    |
# | [C-SVM] C1 = 5.0  | 0.497    |
# --------------------------------
# ------------------------------------
# | [C-SVM] accuracy max  | 0.896    |
# | [C-SVM] accuracy mean | 0.834    |
# | [C-SVM] accuracy min  | 0.791    |
# | [C-SVM] accuracy std  | 0.0295   |
# | [C-SVM] best C1       | 1        |
# ------------------------------------
# Logging to logs/pam/19-08-29-17-51-32
# {'dataset': 'image', 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'e0': 0.4, 'e1': 0.4, 'episodes': 3000, 'equalize_prior': True}
# -----------------------------------
# | [PAM] margin = 0     | 0.503    |
# | [PAM] margin = 0.125 | 0.534    |
# | [PAM] margin = 0.25  | 0.537    |
# | [PAM] margin = 0.5   | 0.55     |
# | [PAM] margin = 1     | 0.543    |
# -----------------------------------
# ----------------------------------
# | [PAM] accuracy max  | 0.754    |
# | [PAM] accuracy mean | 0.724    |
# | [PAM] accuracy min  | 0.687    |
# | [PAM] accuracy std  | 0.0197   |
# | [PAM] best margin   | 0.5      |
# ----------------------------------

# %% [markdown]
# ## Without Prior Equalization

# %% [markdown]
# ### $e_0 = 0.1, e_1 = 0.3$

# %%
from run_nn import find_best_alpha
args = default_args.copy()
args.update({
    'e0': 0.1, 'e1': 0.3,
    'episodes': 3000,
    'equalize_prior': False,
    'batchsize': 64,
    'hidsize': [32, 32],
    'lr': 0.01,
})
find_best_alpha(args)
# Out:
# ---------------------------------
# | [PEER] alpha = 0.1 | 0.836    |
# | [PEER] alpha = 0.2 | 0.796    |
# | [PEER] alpha = 0.3 | 0.802    |
# | [PEER] alpha = 0.4 | 0.751    |
# | [PEER] alpha = 0.5 | 0.758    |
# | [PEER] alpha = 0.6 | 0.764    |
# | [PEER] alpha = 0.7 | 0.783    |
# | [PEER] alpha = 0.8 | 0.747    |
# | [PEER] alpha = 0.9 | 0.717    |
# | [PEER] alpha = 1.0 | 0.703    |
# ---------------------------------
# {'alpha': 0.1}

# %%
from runner import run
args = default_args.copy()
args.update({
    'e0': 0.1, 'e1': 0.3,
    'episodes': 3000,
    'equalize_prior': False,
})
run(args)
# Out:
# Logging to logs/nn/19-08-29-18-08-18
# {'dataset': 'image', 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'e0': 0.1, 'e1': 0.3, 'episodes': 3000, 'equalize_prior': False}
# acc:0.681	hidsize:[8, 8]  	batchsize: 1	lr:0.0007
# acc:0.687	hidsize:[8, 8]  	batchsize: 1	lr: 0.001
# acc:0.67	hidsize:[8, 8]  	batchsize: 1	lr: 0.005
# acc:0.646	hidsize:[8, 8]  	batchsize: 1	lr:  0.01
# acc:0.602	hidsize:[8, 8]  	batchsize: 1	lr:  0.05
# acc:0.67	hidsize:[8, 8]  	batchsize: 4	lr:0.0007
# acc:0.667	hidsize:[8, 8]  	batchsize: 4	lr: 0.001
# acc:0.669	hidsize:[8, 8]  	batchsize: 4	lr: 0.005
# acc:0.668	hidsize:[8, 8]  	batchsize: 4	lr:  0.01
# acc:0.616	hidsize:[8, 8]  	batchsize: 4	lr:  0.05
# acc:0.672	hidsize:[8, 8]  	batchsize:16	lr:0.0007
# acc:0.661	hidsize:[8, 8]  	batchsize:16	lr: 0.001
# acc:0.653	hidsize:[8, 8]  	batchsize:16	lr: 0.005
# acc:0.673	hidsize:[8, 8]  	batchsize:16	lr:  0.01
# acc:0.655	hidsize:[8, 8]  	batchsize:16	lr:  0.05
# acc:0.678	hidsize:[8, 8]  	batchsize:32	lr:0.0007
# acc:0.674	hidsize:[8, 8]  	batchsize:32	lr: 0.001
# acc:0.682	hidsize:[8, 8]  	batchsize:32	lr: 0.005
# acc:0.687	hidsize:[8, 8]  	batchsize:32	lr:  0.01
# acc:0.662	hidsize:[8, 8]  	batchsize:32	lr:  0.05
# acc:0.682	hidsize:[8, 8]  	batchsize:64	lr:0.0007
# acc:0.681	hidsize:[8, 8]  	batchsize:64	lr: 0.001
# acc:0.686	hidsize:[8, 8]  	batchsize:64	lr: 0.005
# acc:0.687	hidsize:[8, 8]  	batchsize:64	lr:  0.01
# acc:0.679	hidsize:[8, 8]  	batchsize:64	lr:  0.05
# acc:0.678	hidsize:[16, 16]	batchsize: 1	lr:0.0007
# acc:0.675	hidsize:[16, 16]	batchsize: 1	lr: 0.001
# acc:0.667	hidsize:[16, 16]	batchsize: 1	lr: 0.005
# acc:0.63	hidsize:[16, 16]	batchsize: 1	lr:  0.01
# acc:0.651	hidsize:[16, 16]	batchsize: 1	lr:  0.05
# acc:0.661	hidsize:[16, 16]	batchsize: 4	lr:0.0007
# acc:0.663	hidsize:[16, 16]	batchsize: 4	lr: 0.001
# acc:0.661	hidsize:[16, 16]	batchsize: 4	lr: 0.005
# acc:0.666	hidsize:[16, 16]	batchsize: 4	lr:  0.01
# acc:0.612	hidsize:[16, 16]	batchsize: 4	lr:  0.05
# acc:0.67	hidsize:[16, 16]	batchsize:16	lr:0.0007
# acc:0.671	hidsize:[16, 16]	batchsize:16	lr: 0.001
# acc:0.661	hidsize:[16, 16]	batchsize:16	lr: 0.005
# acc:0.666	hidsize:[16, 16]	batchsize:16	lr:  0.01
# acc:0.652	hidsize:[16, 16]	batchsize:16	lr:  0.05
# acc:0.675	hidsize:[16, 16]	batchsize:32	lr:0.0007
# acc:0.677	hidsize:[16, 16]	batchsize:32	lr: 0.001
# acc:0.671	hidsize:[16, 16]	batchsize:32	lr: 0.005
# acc:0.68	hidsize:[16, 16]	batchsize:32	lr:  0.01
# acc:0.643	hidsize:[16, 16]	batchsize:32	lr:  0.05
# acc:0.677	hidsize:[16, 16]	batchsize:64	lr:0.0007
# acc:0.676	hidsize:[16, 16]	batchsize:64	lr: 0.001
# acc:0.687	hidsize:[16, 16]	batchsize:64	lr: 0.005
# acc:0.694	hidsize:[16, 16]	batchsize:64	lr:  0.01
# acc:0.684	hidsize:[16, 16]	batchsize:64	lr:  0.05
# acc:0.688	hidsize:[32, 32]	batchsize: 1	lr:0.0007
# acc:0.692	hidsize:[32, 32]	batchsize: 1	lr: 0.001
# acc:0.678	hidsize:[32, 32]	batchsize: 1	lr: 0.005
# acc:0.672	hidsize:[32, 32]	batchsize: 1	lr:  0.01
# acc:0.66	hidsize:[32, 32]	batchsize: 1	lr:  0.05
# acc:0.678	hidsize:[32, 32]	batchsize: 4	lr:0.0007
# acc:0.672	hidsize:[32, 32]	batchsize: 4	lr: 0.001
# acc:0.66	hidsize:[32, 32]	batchsize: 4	lr: 0.005
# acc:0.658	hidsize:[32, 32]	batchsize: 4	lr:  0.01
# acc:0.633	hidsize:[32, 32]	batchsize: 4	lr:  0.05
# acc:0.688	hidsize:[32, 32]	batchsize:16	lr:0.0007
# acc:0.682	hidsize:[32, 32]	batchsize:16	lr: 0.001
# acc:0.68	hidsize:[32, 32]	batchsize:16	lr: 0.005
# acc:0.675	hidsize:[32, 32]	batchsize:16	lr:  0.01
# acc:0.674	hidsize:[32, 32]	batchsize:16	lr:  0.05
# acc:0.684	hidsize:[32, 32]	batchsize:32	lr:0.0007
# acc:0.685	hidsize:[32, 32]	batchsize:32	lr: 0.001
# acc:0.687	hidsize:[32, 32]	batchsize:32	lr: 0.005
# acc:0.675	hidsize:[32, 32]	batchsize:32	lr:  0.01
# acc:0.663	hidsize:[32, 32]	batchsize:32	lr:  0.05
# acc:0.694	hidsize:[32, 32]	batchsize:64	lr:0.0007
# acc:0.695	hidsize:[32, 32]	batchsize:64	lr: 0.001
# acc:0.702	hidsize:[32, 32]	batchsize:64	lr: 0.005
# acc:0.703	hidsize:[32, 32]	batchsize:64	lr:  0.01
# acc:0.692	hidsize:[32, 32]	batchsize:64	lr:  0.05
# acc:0.679	hidsize:[64, 64]	batchsize: 1	lr:0.0007
# acc:0.677	hidsize:[64, 64]	batchsize: 1	lr: 0.001
# acc:0.67	hidsize:[64, 64]	batchsize: 1	lr: 0.005
# acc:0.654	hidsize:[64, 64]	batchsize: 1	lr:  0.01
# acc:0.674	hidsize:[64, 64]	batchsize: 1	lr:  0.05
# acc:0.669	hidsize:[64, 64]	batchsize: 4	lr:0.0007
# acc:0.666	hidsize:[64, 64]	batchsize: 4	lr: 0.001
# acc:0.66	hidsize:[64, 64]	batchsize: 4	lr: 0.005
# acc:0.657	hidsize:[64, 64]	batchsize: 4	lr:  0.01
# acc:0.629	hidsize:[64, 64]	batchsize: 4	lr:  0.05
# acc:0.673	hidsize:[64, 64]	batchsize:16	lr:0.0007
# acc:0.671	hidsize:[64, 64]	batchsize:16	lr: 0.001
# acc:0.665	hidsize:[64, 64]	batchsize:16	lr: 0.005
# acc:0.664	hidsize:[64, 64]	batchsize:16	lr:  0.01
# acc:0.656	hidsize:[64, 64]	batchsize:16	lr:  0.05
# acc:0.678	hidsize:[64, 64]	batchsize:32	lr:0.0007
# acc:0.677	hidsize:[64, 64]	batchsize:32	lr: 0.001
# acc:0.673	hidsize:[64, 64]	batchsize:32	lr: 0.005
# acc:0.668	hidsize:[64, 64]	batchsize:32	lr:  0.01
# acc:0.664	hidsize:[64, 64]	batchsize:32	lr:  0.05
# acc:0.684	hidsize:[64, 64]	batchsize:64	lr:0.0007
# acc:0.682	hidsize:[64, 64]	batchsize:64	lr: 0.001
# acc:0.68	hidsize:[64, 64]	batchsize:64	lr: 0.005
# acc:0.675	hidsize:[64, 64]	batchsize:64	lr:  0.01
# acc:0.679	hidsize:[64, 64]	batchsize:64	lr:  0.05
# --------------------------------------
# | [PEER] best batchsize   | 64       |
# | [PEER] best hidsize     | [32, 32] |
# | [PEER] best learning... | 0.01     |
# --------------------------------------
# ---------------------------------
# | [PEER] alpha = 0.1 | 0.683    |
# | [PEER] alpha = 0.2 | 0.691    |
# | [PEER] alpha = 0.3 | 0.688    |
# | [PEER] alpha = 0.4 | 0.678    |
# | [PEER] alpha = 0.5 | 0.679    |
# | [PEER] alpha = 0.6 | 0.673    |
# | [PEER] alpha = 0.7 | 0.678    |
# | [PEER] alpha = 0.8 | 0.636    |
# | [PEER] alpha = 0.9 | 0.62     |
# | [PEER] alpha = 1.0 | 0.619    |
# ---------------------------------
# --------------------------------------
# | [NN] with bce loss      | 0.878    |
# | [NN] with peer loss     | 0.796    |
# | [NN] with surrogate ... | 0.835    |
# | [PEER] best alpha       | 0.2      |
# --------------------------------------
# Logging to logs/svm/19-08-29-18-29-23
# {'dataset': 'image', 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'e0': 0.1, 'e1': 0.3, 'episodes': 3000, 'equalize_prior': False}
# --------------------------------
# | [C-SVM] C1 = 0.1  | 0.553    |
# | [C-SVM] C1 = 0.2  | 0.553    |
# | [C-SVM] C1 = 0.25 | 0.553    |
# | [C-SVM] C1 = 0.33 | 0.552    |
# | [C-SVM] C1 = 0.5  | 0.622    |
# | [C-SVM] C1 = 1.0  | 0.738    |
# | [C-SVM] C1 = 10.0 | 0.511    |
# | [C-SVM] C1 = 2.0  | 0.713    |
# | [C-SVM] C1 = 3.0  | 0.698    |
# | [C-SVM] C1 = 4.0  | 0.684    |
# | [C-SVM] C1 = 5.0  | 0.659    |
# --------------------------------
# ------------------------------------
# | [C-SVM] accuracy max  | 0.916    |
# | [C-SVM] accuracy mean | 0.892    |
# | [C-SVM] accuracy min  | 0.867    |
# | [C-SVM] accuracy std  | 0.0169   |
# | [C-SVM] best C1       | 1        |
# ------------------------------------
# Logging to logs/pam/19-08-29-18-29-25
# {'dataset': 'image', 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'e0': 0.1, 'e1': 0.3, 'episodes': 3000, 'equalize_prior': False}
# -----------------------------------
# | [PAM] margin = 0     | 0.604    |
# | [PAM] margin = 0.125 | 0.653    |
# | [PAM] margin = 0.25  | 0.652    |
# | [PAM] margin = 0.5   | 0.659    |
# | [PAM] margin = 1     | 0.655    |
# -----------------------------------
# ----------------------------------
# | [PAM] accuracy max  | 0.801    |
# | [PAM] accuracy mean | 0.762    |
# | [PAM] accuracy min  | 0.738    |
# | [PAM] accuracy std  | 0.0179   |
# | [PAM] best margin   | 0.5      |
# ----------------------------------

# %% [markdown]
# ### $e_0 = 0.2, e_1 = 0.2$

# %%
from run_nn import find_best_alpha
args = default_args.copy()
args.update({
    'e0': 0.2, 'e1': 0.2,
    'episodes': 3000,
    'equalize_prior': False,
    'batchsize': 64,
    'hidsize': [32, 32],
    'lr': 0.001,
})
find_best_alpha(args)
# Out:
# ---------------------------------
# | [PEER] alpha = 0.1 | 0.931    |
# | [PEER] alpha = 0.2 | 0.923    |
# | [PEER] alpha = 0.3 | 0.905    |
# | [PEER] alpha = 0.4 | 0.886    |
# | [PEER] alpha = 0.5 | 0.86     |
# | [PEER] alpha = 0.6 | 0.827    |
# | [PEER] alpha = 0.7 | 0.784    |
# | [PEER] alpha = 0.8 | 0.75     |
# | [PEER] alpha = 0.9 | 0.735    |
# | [PEER] alpha = 1.0 | 0.704    |
# ---------------------------------
# {'alpha': 0.1}

# %%
from runner import run
args = default_args.copy()
args.update({
    'e0': 0.2, 'e1': 0.2,
    'episodes': 3000,
    'equalize_prior': False,
})
run(args)
# Out:
# Logging to logs/nn/19-08-29-18-39-12
# {'dataset': 'image', 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'e0': 0.2, 'e1': 0.2, 'episodes': 3000, 'equalize_prior': False}
# acc:0.688	hidsize:[8, 8]  	batchsize: 1	lr:0.0007
# acc:0.684	hidsize:[8, 8]  	batchsize: 1	lr: 0.001
# acc:0.661	hidsize:[8, 8]  	batchsize: 1	lr: 0.005
# acc:0.629	hidsize:[8, 8]  	batchsize: 1	lr:  0.01
# acc:0.579	hidsize:[8, 8]  	batchsize: 1	lr:  0.05
# acc:0.677	hidsize:[8, 8]  	batchsize: 4	lr:0.0007
# acc:0.664	hidsize:[8, 8]  	batchsize: 4	lr: 0.001
# acc:0.67	hidsize:[8, 8]  	batchsize: 4	lr: 0.005
# acc:0.644	hidsize:[8, 8]  	batchsize: 4	lr:  0.01
# acc:0.64	hidsize:[8, 8]  	batchsize: 4	lr:  0.05
# acc:0.673	hidsize:[8, 8]  	batchsize:16	lr:0.0007
# acc:0.648	hidsize:[8, 8]  	batchsize:16	lr: 0.001
# acc:0.679	hidsize:[8, 8]  	batchsize:16	lr: 0.005
# acc:0.669	hidsize:[8, 8]  	batchsize:16	lr:  0.01
# acc:0.658	hidsize:[8, 8]  	batchsize:16	lr:  0.05
# acc:0.673	hidsize:[8, 8]  	batchsize:32	lr:0.0007
# acc:0.679	hidsize:[8, 8]  	batchsize:32	lr: 0.001
# acc:0.69	hidsize:[8, 8]  	batchsize:32	lr: 0.005
# acc:0.678	hidsize:[8, 8]  	batchsize:32	lr:  0.01
# acc:0.661	hidsize:[8, 8]  	batchsize:32	lr:  0.05
# acc:0.682	hidsize:[8, 8]  	batchsize:64	lr:0.0007
# acc:0.676	hidsize:[8, 8]  	batchsize:64	lr: 0.001
# acc:0.699	hidsize:[8, 8]  	batchsize:64	lr: 0.005
# acc:0.687	hidsize:[8, 8]  	batchsize:64	lr:  0.01
# acc:0.686	hidsize:[8, 8]  	batchsize:64	lr:  0.05
# acc:0.68	hidsize:[16, 16]	batchsize: 1	lr:0.0007
# acc:0.678	hidsize:[16, 16]	batchsize: 1	lr: 0.001
# acc:0.671	hidsize:[16, 16]	batchsize: 1	lr: 0.005
# acc:0.674	hidsize:[16, 16]	batchsize: 1	lr:  0.01
# acc:0.578	hidsize:[16, 16]	batchsize: 1	lr:  0.05
# acc:0.662	hidsize:[16, 16]	batchsize: 4	lr:0.0007
# acc:0.664	hidsize:[16, 16]	batchsize: 4	lr: 0.001
# acc:0.643	hidsize:[16, 16]	batchsize: 4	lr: 0.005
# acc:0.648	hidsize:[16, 16]	batchsize: 4	lr:  0.01
# acc:0.631	hidsize:[16, 16]	batchsize: 4	lr:  0.05
# acc:0.679	hidsize:[16, 16]	batchsize:16	lr:0.0007
# acc:0.678	hidsize:[16, 16]	batchsize:16	lr: 0.001
# acc:0.668	hidsize:[16, 16]	batchsize:16	lr: 0.005
# acc:0.671	hidsize:[16, 16]	batchsize:16	lr:  0.01
# acc:0.655	hidsize:[16, 16]	batchsize:16	lr:  0.05
# acc:0.679	hidsize:[16, 16]	batchsize:32	lr:0.0007
# acc:0.674	hidsize:[16, 16]	batchsize:32	lr: 0.001
# acc:0.667	hidsize:[16, 16]	batchsize:32	lr: 0.005
# acc:0.671	hidsize:[16, 16]	batchsize:32	lr:  0.01
# acc:0.664	hidsize:[16, 16]	batchsize:32	lr:  0.05
# acc:0.678	hidsize:[16, 16]	batchsize:64	lr:0.0007
# acc:0.676	hidsize:[16, 16]	batchsize:64	lr: 0.001
# acc:0.683	hidsize:[16, 16]	batchsize:64	lr: 0.005
# acc:0.691	hidsize:[16, 16]	batchsize:64	lr:  0.01
# acc:0.68	hidsize:[16, 16]	batchsize:64	lr:  0.05
# acc:0.689	hidsize:[32, 32]	batchsize: 1	lr:0.0007
# acc:0.688	hidsize:[32, 32]	batchsize: 1	lr: 0.001
# acc:0.681	hidsize:[32, 32]	batchsize: 1	lr: 0.005
# acc:0.635	hidsize:[32, 32]	batchsize: 1	lr:  0.01
# acc:0.624	hidsize:[32, 32]	batchsize: 1	lr:  0.05
# acc:0.688	hidsize:[32, 32]	batchsize: 4	lr:0.0007
# acc:0.682	hidsize:[32, 32]	batchsize: 4	lr: 0.001
# acc:0.671	hidsize:[32, 32]	batchsize: 4	lr: 0.005
# acc:0.653	hidsize:[32, 32]	batchsize: 4	lr:  0.01
# acc:0.643	hidsize:[32, 32]	batchsize: 4	lr:  0.05
# acc:0.693	hidsize:[32, 32]	batchsize:16	lr:0.0007
# acc:0.689	hidsize:[32, 32]	batchsize:16	lr: 0.001
# acc:0.68	hidsize:[32, 32]	batchsize:16	lr: 0.005
# acc:0.681	hidsize:[32, 32]	batchsize:16	lr:  0.01
# acc:0.664	hidsize:[32, 32]	batchsize:16	lr:  0.05
# acc:0.691	hidsize:[32, 32]	batchsize:32	lr:0.0007
# acc:0.693	hidsize:[32, 32]	batchsize:32	lr: 0.001
# acc:0.687	hidsize:[32, 32]	batchsize:32	lr: 0.005
# acc:0.689	hidsize:[32, 32]	batchsize:32	lr:  0.01
# acc:0.677	hidsize:[32, 32]	batchsize:32	lr:  0.05
# acc:0.703	hidsize:[32, 32]	batchsize:64	lr:0.0007
# acc:0.704	hidsize:[32, 32]	batchsize:64	lr: 0.001
# acc:0.703	hidsize:[32, 32]	batchsize:64	lr: 0.005
# acc:0.697	hidsize:[32, 32]	batchsize:64	lr:  0.01
# acc:0.675	hidsize:[32, 32]	batchsize:64	lr:  0.05
# acc:0.692	hidsize:[64, 64]	batchsize: 1	lr:0.0007
# acc:0.683	hidsize:[64, 64]	batchsize: 1	lr: 0.001
# acc:0.67	hidsize:[64, 64]	batchsize: 1	lr: 0.005
# acc:0.653	hidsize:[64, 64]	batchsize: 1	lr:  0.01
# acc:0.659	hidsize:[64, 64]	batchsize: 1	lr:  0.05
# acc:0.668	hidsize:[64, 64]	batchsize: 4	lr:0.0007
# acc:0.668	hidsize:[64, 64]	batchsize: 4	lr: 0.001
# acc:0.662	hidsize:[64, 64]	batchsize: 4	lr: 0.005
# acc:0.652	hidsize:[64, 64]	batchsize: 4	lr:  0.01
# acc:0.637	hidsize:[64, 64]	batchsize: 4	lr:  0.05
# acc:0.686	hidsize:[64, 64]	batchsize:16	lr:0.0007
# acc:0.684	hidsize:[64, 64]	batchsize:16	lr: 0.001
# acc:0.682	hidsize:[64, 64]	batchsize:16	lr: 0.005
# acc:0.675	hidsize:[64, 64]	batchsize:16	lr:  0.01
# acc:0.663	hidsize:[64, 64]	batchsize:16	lr:  0.05
# acc:0.684	hidsize:[64, 64]	batchsize:32	lr:0.0007
# acc:0.68	hidsize:[64, 64]	batchsize:32	lr: 0.001
# acc:0.674	hidsize:[64, 64]	batchsize:32	lr: 0.005
# acc:0.675	hidsize:[64, 64]	batchsize:32	lr:  0.01
# acc:0.665	hidsize:[64, 64]	batchsize:32	lr:  0.05
# acc:0.691	hidsize:[64, 64]	batchsize:64	lr:0.0007
# acc:0.691	hidsize:[64, 64]	batchsize:64	lr: 0.001
# acc:0.688	hidsize:[64, 64]	batchsize:64	lr: 0.005
# acc:0.684	hidsize:[64, 64]	batchsize:64	lr:  0.01
# acc:0.683	hidsize:[64, 64]	batchsize:64	lr:  0.05
# --------------------------------------
# | [PEER] best batchsize   | 64       |
# | [PEER] best hidsize     | [32, 32] |
# | [PEER] best learning... | 0.001    |
# --------------------------------------
# ---------------------------------
# | [PEER] alpha = 0.1 | 0.76     |
# | [PEER] alpha = 0.2 | 0.755    |
# | [PEER] alpha = 0.3 | 0.744    |
# | [PEER] alpha = 0.4 | 0.728    |
# | [PEER] alpha = 0.5 | 0.719    |
# | [PEER] alpha = 0.6 | 0.699    |
# | [PEER] alpha = 0.7 | 0.67     |
# | [PEER] alpha = 0.8 | 0.651    |
# | [PEER] alpha = 0.9 | 0.637    |
# | [PEER] alpha = 1.0 | 0.632    |
# ---------------------------------
# --------------------------------------
# | [NN] with bce loss      | 0.934    |
# | [NN] with peer loss     | 0.931    |
# | [NN] with surrogate ... | 0.896    |
# | [PEER] best alpha       | 0.1      |
# --------------------------------------
# Logging to logs/svm/19-08-29-19-00-33
# {'dataset': 'image', 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'e0': 0.2, 'e1': 0.2, 'episodes': 3000, 'equalize_prior': False}
# --------------------------------
# | [C-SVM] C1 = 0.1  | 0.452    |
# | [C-SVM] C1 = 0.2  | 0.452    |
# | [C-SVM] C1 = 0.25 | 0.486    |
# | [C-SVM] C1 = 0.33 | 0.551    |
# | [C-SVM] C1 = 0.5  | 0.711    |
# | [C-SVM] C1 = 1.0  | 0.752    |
# | [C-SVM] C1 = 10.0 | 0.552    |
# | [C-SVM] C1 = 2.0  | 0.727    |
# | [C-SVM] C1 = 3.0  | 0.654    |
# | [C-SVM] C1 = 4.0  | 0.585    |
# | [C-SVM] C1 = 5.0  | 0.553    |
# --------------------------------
# ------------------------------------
# | [C-SVM] accuracy max  | 0.925    |
# | [C-SVM] accuracy mean | 0.908    |
# | [C-SVM] accuracy min  | 0.885    |
# | [C-SVM] accuracy std  | 0.0119   |
# | [C-SVM] best C1       | 1        |
# ------------------------------------
# Logging to logs/pam/19-08-29-19-00-35
# {'dataset': 'image', 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'e0': 0.2, 'e1': 0.2, 'episodes': 3000, 'equalize_prior': False}
# -----------------------------------
# | [PAM] margin = 0     | 0.632    |
# | [PAM] margin = 0.125 | 0.668    |
# | [PAM] margin = 0.25  | 0.678    |
# | [PAM] margin = 0.5   | 0.668    |
# | [PAM] margin = 1     | 0.666    |
# -----------------------------------
# ----------------------------------
# | [PAM] accuracy max  | 0.867    |
# | [PAM] accuracy mean | 0.805    |
# | [PAM] accuracy min  | 0.738    |
# | [PAM] accuracy std  | 0.0447   |
# | [PAM] best margin   | 0.25     |
# ----------------------------------

# %% [markdown]
# ### $e_0 = 0.1, e_1 = 0.4$

# %%
from run_nn import find_best_alpha
args = default_args.copy()
args.update({
    'e0': 0.1, 'e1': 0.4,
    'episodes': 3000,
    'equalize_prior': False,
    'batchsize': 64,
    'hidsize': [32, 32],
    'lr': 0.001,
})
find_best_alpha(args)
# Out:
# ---------------------------------
# | [PEER] alpha = -5  | 0.432    |
# | [PEER] alpha = 0.4 | 0.777    |
# | [PEER] alpha = 0.5 | 0.764    |
# | [PEER] alpha = 0.6 | 0.769    |
# | [PEER] alpha = 0.7 | 0.786    |
# | [PEER] alpha = 0.8 | 0.763    |
# | [PEER] alpha = 0.9 | 0.707    |
# | [PEER] alpha = 1.0 | 0.688    |
# | [PEER] alpha = 2.0 | 0.587    |
# | [PEER] alpha = 3.0 | 0.569    |
# | [PEER] alpha = 4.0 | 0.569    |
# | [PEER] alpha = 5.0 | 0.569    |
# ---------------------------------
# {'alpha': 0.7}

# %%
from run_nn import find_best_alpha
args = default_args.copy()
args.update({
    'e0': 0.1, 'e1': 0.4,
    'episodes': 3000,
    'equalize_prior': False,
    'batchsize': 64,
    'hidsize': [8, 8],
    'lr': 0.01,
})
find_best_alpha(args)
# Out:
# ---------------------------------
# | [PEER] alpha = 0.1 | 0.834    |
# | [PEER] alpha = 0.2 | 0.713    |
# | [PEER] alpha = 0.3 | 0.717    |
# | [PEER] alpha = 0.4 | 0.73     |
# | [PEER] alpha = 0.5 | 0.706    |
# | [PEER] alpha = 0.6 | 0.712    |
# | [PEER] alpha = 0.7 | 0.77     |
# | [PEER] alpha = 0.8 | 0.747    |
# | [PEER] alpha = 0.9 | 0.699    |
# | [PEER] alpha = 1.0 | 0.69     |
# ---------------------------------
# {'alpha': 0.1}

# %%
from runner import run
args = default_args.copy()
args.update({
    'e0': 0.1, 'e1': 0.4,
    'episodes': 3000,
    'equalize_prior': False,
    'batchsize': 64,
    'hidsize': [32, 32],
    'lr': 0.001,
})
run(args)
# Out:
# Logging to logs/nn/19-08-30-16-28-14
# {'dataset': 'image', 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'e0': 0.1, 'e1': 0.4, 'episodes': 3000, 'equalize_prior': False, 'batchsize': 64, 'hidsize': [32, 32], 'lr': 0.001}
# ---------------------------------
# | [PEER] alpha = -5  | 0.611    |
# | [PEER] alpha = 0.4 | 0.649    |
# | [PEER] alpha = 0.5 | 0.648    |
# | [PEER] alpha = 0.6 | 0.657    |
# | [PEER] alpha = 0.7 | 0.647    |
# | [PEER] alpha = 0.8 | 0.633    |
# | [PEER] alpha = 0.9 | 0.586    |
# | [PEER] alpha = 1.0 | 0.579    |
# | [PEER] alpha = 2.0 | 0.404    |
# | [PEER] alpha = 3.0 | 0.389    |
# | [PEER] alpha = 4.0 | 0.389    |
# | [PEER] alpha = 5.0 | 0.389    |
# ---------------------------------
# --------------------------------------
# | [NN] with bce loss      | 0.817    |
# | [NN] with peer loss     | 0.769    |
# | [NN] with surrogate ... | 0.875    |
# | [PEER] best alpha       | 0.6      |
# --------------------------------------
# Logging to logs/svm/19-08-30-16-31-15
# {'dataset': 'image', 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'e0': 0.1, 'e1': 0.4, 'episodes': 3000, 'equalize_prior': False, 'batchsize': 64, 'hidsize': [32, 32], 'lr': 0.001}
# --------------------------------
# | [C-SVM] C1 = 0.1  | 0.611    |
# | [C-SVM] C1 = 0.2  | 0.611    |
# | [C-SVM] C1 = 0.25 | 0.611    |
# | [C-SVM] C1 = 0.33 | 0.611    |
# | [C-SVM] C1 = 0.5  | 0.609    |
# | [C-SVM] C1 = 1.0  | 0.696    |
# | [C-SVM] C1 = 10.0 | 0.456    |
# | [C-SVM] C1 = 2.0  | 0.665    |
# | [C-SVM] C1 = 3.0  | 0.649    |
# | [C-SVM] C1 = 4.0  | 0.63     |
# | [C-SVM] C1 = 5.0  | 0.606    |
# --------------------------------
# ------------------------------------
# | [C-SVM] accuracy max  | 0.867    |
# | [C-SVM] accuracy mean | 0.808    |
# | [C-SVM] accuracy min  | 0.772    |
# | [C-SVM] accuracy std  | 0.029    |
# | [C-SVM] best C1       | 1        |
# ------------------------------------
# Logging to logs/pam/19-08-30-16-31-18
# {'dataset': 'image', 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'e0': 0.1, 'e1': 0.4, 'episodes': 3000, 'equalize_prior': False, 'batchsize': 64, 'hidsize': [32, 32], 'lr': 0.001}
# -----------------------------------
# | [PAM] margin = 0     | 0.596    |
# | [PAM] margin = 0.125 | 0.63     |
# | [PAM] margin = 0.25  | 0.628    |
# | [PAM] margin = 0.5   | 0.647    |
# | [PAM] margin = 1     | 0.647    |
# -----------------------------------
# ----------------------------------
# | [PAM] accuracy max  | 0.637    |
# | [PAM] accuracy mean | 0.589    |
# | [PAM] accuracy min  | 0.548    |
# | [PAM] accuracy std  | 0.0374   |
# | [PAM] best margin   | 1        |
# ----------------------------------

# %%
from runner import run
args = default_args.copy()
args.update({
    'e0': 0.1, 'e1': 0.4,
    'episodes': 3000,
    'equalize_prior': False,
    'batchsize': 64,
    'hidsize': [32, 32],
    'lr': 0.001,
    'alpha': 0.1,
})
run(args)
# Out:
# Logging to logs/nn/19-08-30-16-31-39
# {'dataset': 'image', 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'e0': 0.1, 'e1': 0.4, 'episodes': 3000, 'equalize_prior': False, 'batchsize': 64, 'hidsize': [32, 32], 'lr': 0.001, 'alpha': 0.1}
# --------------------------------------
# | [NN] with bce loss      | 0.817    |
# | [NN] with peer loss     | 0.812    |
# | [NN] with surrogate ... | 0.875    |
# --------------------------------------
# Logging to logs/svm/19-08-30-16-32-12
# {'dataset': 'image', 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'e0': 0.1, 'e1': 0.4, 'episodes': 3000, 'equalize_prior': False, 'batchsize': 64, 'hidsize': [32, 32], 'lr': 0.001, 'alpha': 0.1}
# --------------------------------
# | [C-SVM] C1 = 0.1  | 0.611    |
# | [C-SVM] C1 = 0.2  | 0.611    |
# | [C-SVM] C1 = 0.25 | 0.611    |
# | [C-SVM] C1 = 0.33 | 0.611    |
# | [C-SVM] C1 = 0.5  | 0.609    |
# | [C-SVM] C1 = 1.0  | 0.696    |
# | [C-SVM] C1 = 10.0 | 0.456    |
# | [C-SVM] C1 = 2.0  | 0.665    |
# | [C-SVM] C1 = 3.0  | 0.649    |
# | [C-SVM] C1 = 4.0  | 0.63     |
# | [C-SVM] C1 = 5.0  | 0.606    |
# --------------------------------
# ------------------------------------
# | [C-SVM] accuracy max  | 0.867    |
# | [C-SVM] accuracy mean | 0.808    |
# | [C-SVM] accuracy min  | 0.772    |
# | [C-SVM] accuracy std  | 0.029    |
# | [C-SVM] best C1       | 1        |
# ------------------------------------
# Logging to logs/pam/19-08-30-16-32-14
# {'dataset': 'image', 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'e0': 0.1, 'e1': 0.4, 'episodes': 3000, 'equalize_prior': False, 'batchsize': 64, 'hidsize': [32, 32], 'lr': 0.001, 'alpha': 0.1}
# -----------------------------------
# | [PAM] margin = 0     | 0.596    |
# | [PAM] margin = 0.125 | 0.63     |
# | [PAM] margin = 0.25  | 0.628    |
# | [PAM] margin = 0.5   | 0.647    |
# | [PAM] margin = 1     | 0.647    |
# -----------------------------------
# ----------------------------------
# | [PAM] accuracy max  | 0.637    |
# | [PAM] accuracy mean | 0.589    |
# | [PAM] accuracy min  | 0.548    |
# | [PAM] accuracy std  | 0.0374   |
# | [PAM] best margin   | 1        |
# ----------------------------------

# %%
from runner import run
args = default_args.copy()
args.update({
    'e0': 0.1, 'e1': 0.4,
    'episodes': 3000,
    'equalize_prior': False,
})
run(args)
# Out:
# Logging to logs/nn/19-08-29-19-00-55
# {'dataset': 'image', 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'e0': 0.1, 'e1': 0.4, 'episodes': 3000, 'equalize_prior': False}
# acc:0.689	hidsize:[8, 8]  	batchsize: 1	lr:0.0007
# acc:0.675	hidsize:[8, 8]  	batchsize: 1	lr: 0.001
# acc:0.643	hidsize:[8, 8]  	batchsize: 1	lr: 0.005
# acc:0.617	hidsize:[8, 8]  	batchsize: 1	lr:  0.01
# acc:0.586	hidsize:[8, 8]  	batchsize: 1	lr:  0.05
# acc:0.673	hidsize:[8, 8]  	batchsize: 4	lr:0.0007
# acc:0.672	hidsize:[8, 8]  	batchsize: 4	lr: 0.001
# acc:0.663	hidsize:[8, 8]  	batchsize: 4	lr: 0.005
# acc:0.643	hidsize:[8, 8]  	batchsize: 4	lr:  0.01
# acc:0.565	hidsize:[8, 8]  	batchsize: 4	lr:  0.05
# acc:0.662	hidsize:[8, 8]  	batchsize:16	lr:0.0007
# acc:0.657	hidsize:[8, 8]  	batchsize:16	lr: 0.001
# acc:0.67	hidsize:[8, 8]  	batchsize:16	lr: 0.005
# acc:0.655	hidsize:[8, 8]  	batchsize:16	lr:  0.01
# acc:0.628	hidsize:[8, 8]  	batchsize:16	lr:  0.05
# acc:0.673	hidsize:[8, 8]  	batchsize:32	lr:0.0007
# acc:0.668	hidsize:[8, 8]  	batchsize:32	lr: 0.001
# acc:0.677	hidsize:[8, 8]  	batchsize:32	lr: 0.005
# acc:0.678	hidsize:[8, 8]  	batchsize:32	lr:  0.01
# acc:0.683	hidsize:[8, 8]  	batchsize:32	lr:  0.05
# acc:0.675	hidsize:[8, 8]  	batchsize:64	lr:0.0007
# acc:0.677	hidsize:[8, 8]  	batchsize:64	lr: 0.001
# acc:0.674	hidsize:[8, 8]  	batchsize:64	lr: 0.005
# acc:0.69	hidsize:[8, 8]  	batchsize:64	lr:  0.01
# acc:0.687	hidsize:[8, 8]  	batchsize:64	lr:  0.05
# acc:0.686	hidsize:[16, 16]	batchsize: 1	lr:0.0007
# acc:0.674	hidsize:[16, 16]	batchsize: 1	lr: 0.001
# acc:0.629	hidsize:[16, 16]	batchsize: 1	lr: 0.005
# acc:0.684	hidsize:[16, 16]	batchsize: 1	lr:  0.01
# acc:0.648	hidsize:[16, 16]	batchsize: 1	lr:  0.05
# acc:0.662	hidsize:[16, 16]	batchsize: 4	lr:0.0007
# acc:0.661	hidsize:[16, 16]	batchsize: 4	lr: 0.001
# acc:0.65	hidsize:[16, 16]	batchsize: 4	lr: 0.005
# acc:0.656	hidsize:[16, 16]	batchsize: 4	lr:  0.01
# acc:0.611	hidsize:[16, 16]	batchsize: 4	lr:  0.05
# acc:0.663	hidsize:[16, 16]	batchsize:16	lr:0.0007
# acc:0.664	hidsize:[16, 16]	batchsize:16	lr: 0.001
# acc:0.656	hidsize:[16, 16]	batchsize:16	lr: 0.005
# acc:0.651	hidsize:[16, 16]	batchsize:16	lr:  0.01
# acc:0.649	hidsize:[16, 16]	batchsize:16	lr:  0.05
# acc:0.664	hidsize:[16, 16]	batchsize:32	lr:0.0007
# acc:0.663	hidsize:[16, 16]	batchsize:32	lr: 0.001
# acc:0.666	hidsize:[16, 16]	batchsize:32	lr: 0.005
# acc:0.657	hidsize:[16, 16]	batchsize:32	lr:  0.01
# acc:0.663	hidsize:[16, 16]	batchsize:32	lr:  0.05
# acc:0.668	hidsize:[16, 16]	batchsize:64	lr:0.0007
# acc:0.668	hidsize:[16, 16]	batchsize:64	lr: 0.001
# acc:0.668	hidsize:[16, 16]	batchsize:64	lr: 0.005
# acc:0.675	hidsize:[16, 16]	batchsize:64	lr:  0.01
# acc:0.678	hidsize:[16, 16]	batchsize:64	lr:  0.05
# acc:0.68	hidsize:[32, 32]	batchsize: 1	lr:0.0007
# acc:0.684	hidsize:[32, 32]	batchsize: 1	lr: 0.001
# acc:0.675	hidsize:[32, 32]	batchsize: 1	lr: 0.005
# acc:0.667	hidsize:[32, 32]	batchsize: 1	lr:  0.01
# acc:0.649	hidsize:[32, 32]	batchsize: 1	lr:  0.05
# acc:0.662	hidsize:[32, 32]	batchsize: 4	lr:0.0007
# acc:0.665	hidsize:[32, 32]	batchsize: 4	lr: 0.001
# acc:0.653	hidsize:[32, 32]	batchsize: 4	lr: 0.005
# acc:0.653	hidsize:[32, 32]	batchsize: 4	lr:  0.01
# acc:0.638	hidsize:[32, 32]	batchsize: 4	lr:  0.05
# acc:0.676	hidsize:[32, 32]	batchsize:16	lr:0.0007
# acc:0.675	hidsize:[32, 32]	batchsize:16	lr: 0.001
# acc:0.668	hidsize:[32, 32]	batchsize:16	lr: 0.005
# acc:0.67	hidsize:[32, 32]	batchsize:16	lr:  0.01
# acc:0.656	hidsize:[32, 32]	batchsize:16	lr:  0.05
# acc:0.675	hidsize:[32, 32]	batchsize:32	lr:0.0007
# acc:0.675	hidsize:[32, 32]	batchsize:32	lr: 0.001
# acc:0.671	hidsize:[32, 32]	batchsize:32	lr: 0.005
# acc:0.668	hidsize:[32, 32]	batchsize:32	lr:  0.01
# acc:0.67	hidsize:[32, 32]	batchsize:32	lr:  0.05
# acc:0.688	hidsize:[32, 32]	batchsize:64	lr:0.0007
# acc:0.688	hidsize:[32, 32]	batchsize:64	lr: 0.001
# acc:0.683	hidsize:[32, 32]	batchsize:64	lr: 0.005
# acc:0.679	hidsize:[32, 32]	batchsize:64	lr:  0.01
# acc:0.676	hidsize:[32, 32]	batchsize:64	lr:  0.05
# acc:0.682	hidsize:[64, 64]	batchsize: 1	lr:0.0007
# acc:0.679	hidsize:[64, 64]	batchsize: 1	lr: 0.001
# acc:0.666	hidsize:[64, 64]	batchsize: 1	lr: 0.005
# acc:0.668	hidsize:[64, 64]	batchsize: 1	lr:  0.01
# acc:0.661	hidsize:[64, 64]	batchsize: 1	lr:  0.05
# acc:0.665	hidsize:[64, 64]	batchsize: 4	lr:0.0007
# acc:0.66	hidsize:[64, 64]	batchsize: 4	lr: 0.001
# acc:0.651	hidsize:[64, 64]	batchsize: 4	lr: 0.005
# acc:0.648	hidsize:[64, 64]	batchsize: 4	lr:  0.01
# acc:0.641	hidsize:[64, 64]	batchsize: 4	lr:  0.05
# acc:0.669	hidsize:[64, 64]	batchsize:16	lr:0.0007
# acc:0.666	hidsize:[64, 64]	batchsize:16	lr: 0.001
# acc:0.662	hidsize:[64, 64]	batchsize:16	lr: 0.005
# acc:0.667	hidsize:[64, 64]	batchsize:16	lr:  0.01
# acc:0.656	hidsize:[64, 64]	batchsize:16	lr:  0.05
# acc:0.669	hidsize:[64, 64]	batchsize:32	lr:0.0007
# acc:0.664	hidsize:[64, 64]	batchsize:32	lr: 0.001
# acc:0.664	hidsize:[64, 64]	batchsize:32	lr: 0.005
# acc:0.661	hidsize:[64, 64]	batchsize:32	lr:  0.01
# acc:0.663	hidsize:[64, 64]	batchsize:32	lr:  0.05
# acc:0.674	hidsize:[64, 64]	batchsize:64	lr:0.0007
# acc:0.672	hidsize:[64, 64]	batchsize:64	lr: 0.001
# acc:0.667	hidsize:[64, 64]	batchsize:64	lr: 0.005
# acc:0.668	hidsize:[64, 64]	batchsize:64	lr:  0.01
# acc:0.673	hidsize:[64, 64]	batchsize:64	lr:  0.05
# --------------------------------------
# | [PEER] best batchsize   | 64       |
# | [PEER] best hidsize     | [8, 8]   |
# | [PEER] best learning... | 0.01     |
# --------------------------------------
# ---------------------------------
# | [PEER] alpha = 0.1 | 0.675    |
# | [PEER] alpha = 0.2 | 0.655    |
# | [PEER] alpha = 0.3 | 0.683    |
# | [PEER] alpha = 0.4 | 0.647    |
# | [PEER] alpha = 0.5 | 0.632    |
# | [PEER] alpha = 0.6 | 0.621    |
# | [PEER] alpha = 0.7 | 0.635    |
# | [PEER] alpha = 0.8 | 0.624    |
# | [PEER] alpha = 0.9 | 0.587    |
# | [PEER] alpha = 1.0 | 0.582    |
# ---------------------------------
# --------------------------------------
# | [NN] with bce loss      | 0.825    |
# | [NN] with peer loss     | 0.717    |
# | [NN] with surrogate ... | 0.806    |
# | [PEER] best alpha       | 0.3      |
# --------------------------------------
# Logging to logs/svm/19-08-29-19-19-53
# {'dataset': 'image', 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'e0': 0.1, 'e1': 0.4, 'episodes': 3000, 'equalize_prior': False}
# --------------------------------
# | [C-SVM] C1 = 0.1  | 0.611    |
# | [C-SVM] C1 = 0.2  | 0.611    |
# | [C-SVM] C1 = 0.25 | 0.611    |
# | [C-SVM] C1 = 0.33 | 0.611    |
# | [C-SVM] C1 = 0.5  | 0.609    |
# | [C-SVM] C1 = 1.0  | 0.696    |
# | [C-SVM] C1 = 10.0 | 0.456    |
# | [C-SVM] C1 = 2.0  | 0.665    |
# | [C-SVM] C1 = 3.0  | 0.649    |
# | [C-SVM] C1 = 4.0  | 0.63     |
# | [C-SVM] C1 = 5.0  | 0.606    |
# --------------------------------
# ------------------------------------
# | [C-SVM] accuracy max  | 0.867    |
# | [C-SVM] accuracy mean | 0.808    |
# | [C-SVM] accuracy min  | 0.772    |
# | [C-SVM] accuracy std  | 0.029    |
# | [C-SVM] best C1       | 1        |
# ------------------------------------
# Logging to logs/pam/19-08-29-19-19-55
# {'dataset': 'image', 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'e0': 0.1, 'e1': 0.4, 'episodes': 3000, 'equalize_prior': False}
# -----------------------------------
# | [PAM] margin = 0     | 0.596    |
# | [PAM] margin = 0.125 | 0.63     |
# | [PAM] margin = 0.25  | 0.628    |
# | [PAM] margin = 0.5   | 0.647    |
# | [PAM] margin = 1     | 0.647    |
# -----------------------------------
# ----------------------------------
# | [PAM] accuracy max  | 0.637    |
# | [PAM] accuracy mean | 0.589    |
# | [PAM] accuracy min  | 0.548    |
# | [PAM] accuracy std  | 0.0374   |
# | [PAM] best margin   | 1        |
# ----------------------------------

# %% [markdown]
# ### $e_0 = 0.2, e_1 = 0.4$

# %%
from run_nn import find_best_alpha
args = default_args.copy()
args.update({
    'e0': 0.2, 'e1': 0.4,
    'episodes': 3000,
    'equalize_prior': False,
    'batchsize': 1,
    'hidsize': [8, 8],
    'lr': 0.0007,
})
find_best_alpha(args)
# Out:
# ---------------------------------
# | [PEER] alpha = 0.1 | 0.638    |
# | [PEER] alpha = 0.2 | 0.642    |
# | [PEER] alpha = 0.3 | 0.672    |
# | [PEER] alpha = 0.4 | 0.677    |
# | [PEER] alpha = 0.5 | 0.68     |
# | [PEER] alpha = 0.6 | 0.675    |
# | [PEER] alpha = 0.7 | 0.674    |
# | [PEER] alpha = 0.8 | 0.679    |
# | [PEER] alpha = 0.9 | 0.69     |
# | [PEER] alpha = 1.0 | 0.693    |
# ---------------------------------
# {'alpha': 1.0}

# %%
from run_nn import find_best_alpha
args = default_args.copy()
args.update({
    'e0': 0.2, 'e1': 0.4,
    'episodes': 3000,
    'equalize_prior': False,
    'batchsize': 64,
    'hidsize': [32, 32],
    'lr': 0.001,
})
find_best_alpha(args)
# Out:
# ---------------------------------
# | [PEER] alpha = -5  | 0.437    |
# | [PEER] alpha = 0.4 | 0.812    |
# | [PEER] alpha = 0.5 | 0.803    |
# | [PEER] alpha = 0.6 | 0.787    |
# | [PEER] alpha = 0.7 | 0.782    |
# | [PEER] alpha = 0.8 | 0.777    |
# | [PEER] alpha = 0.9 | 0.72     |
# | [PEER] alpha = 1.0 | 0.691    |
# | [PEER] alpha = 2.0 | 0.552    |
# | [PEER] alpha = 3.0 | 0.552    |
# | [PEER] alpha = 4.0 | 0.552    |
# | [PEER] alpha = 5.0 | 0.552    |
# ---------------------------------
# {'alpha': 0.4}

# %%
from runner import run
args = default_args.copy()
args.update({
    'e0': 0.2, 'e1': 0.4,
    'episodes': 3000,
    'equalize_prior': False,
})
run(args)
# Out:
# Logging to logs/nn/19-08-29-19-20-15
# {'dataset': 'image', 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'e0': 0.2, 'e1': 0.4, 'episodes': 3000, 'equalize_prior': False}
# acc:0.693	hidsize:[8, 8]  	batchsize: 1	lr:0.0007
# acc:0.67	hidsize:[8, 8]  	batchsize: 1	lr: 0.001
# acc:0.648	hidsize:[8, 8]  	batchsize: 1	lr: 0.005
# acc:0.637	hidsize:[8, 8]  	batchsize: 1	lr:  0.01
# acc:0.598	hidsize:[8, 8]  	batchsize: 1	lr:  0.05
# acc:0.676	hidsize:[8, 8]  	batchsize: 4	lr:0.0007
# acc:0.666	hidsize:[8, 8]  	batchsize: 4	lr: 0.001
# acc:0.653	hidsize:[8, 8]  	batchsize: 4	lr: 0.005
# acc:0.642	hidsize:[8, 8]  	batchsize: 4	lr:  0.01
# acc:0.598	hidsize:[8, 8]  	batchsize: 4	lr:  0.05
# acc:0.665	hidsize:[8, 8]  	batchsize:16	lr:0.0007
# acc:0.665	hidsize:[8, 8]  	batchsize:16	lr: 0.001
# acc:0.679	hidsize:[8, 8]  	batchsize:16	lr: 0.005
# acc:0.667	hidsize:[8, 8]  	batchsize:16	lr:  0.01
# acc:0.641	hidsize:[8, 8]  	batchsize:16	lr:  0.05
# acc:0.673	hidsize:[8, 8]  	batchsize:32	lr:0.0007
# acc:0.659	hidsize:[8, 8]  	batchsize:32	lr: 0.001
# acc:0.681	hidsize:[8, 8]  	batchsize:32	lr: 0.005
# acc:0.677	hidsize:[8, 8]  	batchsize:32	lr:  0.01
# acc:0.664	hidsize:[8, 8]  	batchsize:32	lr:  0.05
# acc:0.669	hidsize:[8, 8]  	batchsize:64	lr:0.0007
# acc:0.676	hidsize:[8, 8]  	batchsize:64	lr: 0.001
# acc:0.68	hidsize:[8, 8]  	batchsize:64	lr: 0.005
# acc:0.668	hidsize:[8, 8]  	batchsize:64	lr:  0.01
# acc:0.654	hidsize:[8, 8]  	batchsize:64	lr:  0.05
# acc:0.662	hidsize:[16, 16]	batchsize: 1	lr:0.0007
# acc:0.658	hidsize:[16, 16]	batchsize: 1	lr: 0.001
# acc:0.662	hidsize:[16, 16]	batchsize: 1	lr: 0.005
# acc:0.659	hidsize:[16, 16]	batchsize: 1	lr:  0.01
# acc:0.58	hidsize:[16, 16]	batchsize: 1	lr:  0.05
# acc:0.656	hidsize:[16, 16]	batchsize: 4	lr:0.0007
# acc:0.66	hidsize:[16, 16]	batchsize: 4	lr: 0.001
# acc:0.656	hidsize:[16, 16]	batchsize: 4	lr: 0.005
# acc:0.615	hidsize:[16, 16]	batchsize: 4	lr:  0.01
# acc:0.548	hidsize:[16, 16]	batchsize: 4	lr:  0.05
# acc:0.666	hidsize:[16, 16]	batchsize:16	lr:0.0007
# acc:0.661	hidsize:[16, 16]	batchsize:16	lr: 0.001
# acc:0.659	hidsize:[16, 16]	batchsize:16	lr: 0.005
# acc:0.667	hidsize:[16, 16]	batchsize:16	lr:  0.01
# acc:0.661	hidsize:[16, 16]	batchsize:16	lr:  0.05
# acc:0.669	hidsize:[16, 16]	batchsize:32	lr:0.0007
# acc:0.665	hidsize:[16, 16]	batchsize:32	lr: 0.001
# acc:0.668	hidsize:[16, 16]	batchsize:32	lr: 0.005
# acc:0.656	hidsize:[16, 16]	batchsize:32	lr:  0.01
# acc:0.67	hidsize:[16, 16]	batchsize:32	lr:  0.05
# acc:0.67	hidsize:[16, 16]	batchsize:64	lr:0.0007
# acc:0.671	hidsize:[16, 16]	batchsize:64	lr: 0.001
# acc:0.671	hidsize:[16, 16]	batchsize:64	lr: 0.005
# acc:0.671	hidsize:[16, 16]	batchsize:64	lr:  0.01
# acc:0.669	hidsize:[16, 16]	batchsize:64	lr:  0.05
# acc:0.677	hidsize:[32, 32]	batchsize: 1	lr:0.0007
# acc:0.671	hidsize:[32, 32]	batchsize: 1	lr: 0.001
# acc:0.682	hidsize:[32, 32]	batchsize: 1	lr: 0.005
# acc:0.655	hidsize:[32, 32]	batchsize: 1	lr:  0.01
# acc:0.592	hidsize:[32, 32]	batchsize: 1	lr:  0.05
# acc:0.665	hidsize:[32, 32]	batchsize: 4	lr:0.0007
# acc:0.665	hidsize:[32, 32]	batchsize: 4	lr: 0.001
# acc:0.654	hidsize:[32, 32]	batchsize: 4	lr: 0.005
# acc:0.653	hidsize:[32, 32]	batchsize: 4	lr:  0.01
# acc:0.613	hidsize:[32, 32]	batchsize: 4	lr:  0.05
# acc:0.682	hidsize:[32, 32]	batchsize:16	lr:0.0007
# acc:0.677	hidsize:[32, 32]	batchsize:16	lr: 0.001
# acc:0.677	hidsize:[32, 32]	batchsize:16	lr: 0.005
# acc:0.674	hidsize:[32, 32]	batchsize:16	lr:  0.01
# acc:0.679	hidsize:[32, 32]	batchsize:16	lr:  0.05
# acc:0.682	hidsize:[32, 32]	batchsize:32	lr:0.0007
# acc:0.677	hidsize:[32, 32]	batchsize:32	lr: 0.001
# acc:0.674	hidsize:[32, 32]	batchsize:32	lr: 0.005
# acc:0.675	hidsize:[32, 32]	batchsize:32	lr:  0.01
# acc:0.669	hidsize:[32, 32]	batchsize:32	lr:  0.05
# acc:0.689	hidsize:[32, 32]	batchsize:64	lr:0.0007
# acc:0.691	hidsize:[32, 32]	batchsize:64	lr: 0.001
# acc:0.687	hidsize:[32, 32]	batchsize:64	lr: 0.005
# acc:0.687	hidsize:[32, 32]	batchsize:64	lr:  0.01
# acc:0.638	hidsize:[32, 32]	batchsize:64	lr:  0.05
# acc:0.666	hidsize:[64, 64]	batchsize: 1	lr:0.0007
# acc:0.665	hidsize:[64, 64]	batchsize: 1	lr: 0.001
# acc:0.673	hidsize:[64, 64]	batchsize: 1	lr: 0.005
# acc:0.657	hidsize:[64, 64]	batchsize: 1	lr:  0.01
# acc:0.66	hidsize:[64, 64]	batchsize: 1	lr:  0.05
# acc:0.659	hidsize:[64, 64]	batchsize: 4	lr:0.0007
# acc:0.659	hidsize:[64, 64]	batchsize: 4	lr: 0.001
# acc:0.65	hidsize:[64, 64]	batchsize: 4	lr: 0.005
# acc:0.644	hidsize:[64, 64]	batchsize: 4	lr:  0.01
# acc:0.649	hidsize:[64, 64]	batchsize: 4	lr:  0.05
# acc:0.674	hidsize:[64, 64]	batchsize:16	lr:0.0007
# acc:0.678	hidsize:[64, 64]	batchsize:16	lr: 0.001
# acc:0.672	hidsize:[64, 64]	batchsize:16	lr: 0.005
# acc:0.669	hidsize:[64, 64]	batchsize:16	lr:  0.01
# acc:0.648	hidsize:[64, 64]	batchsize:16	lr:  0.05
# acc:0.671	hidsize:[64, 64]	batchsize:32	lr:0.0007
# acc:0.669	hidsize:[64, 64]	batchsize:32	lr: 0.001
# acc:0.664	hidsize:[64, 64]	batchsize:32	lr: 0.005
# acc:0.66	hidsize:[64, 64]	batchsize:32	lr:  0.01
# acc:0.666	hidsize:[64, 64]	batchsize:32	lr:  0.05
# acc:0.674	hidsize:[64, 64]	batchsize:64	lr:0.0007
# acc:0.676	hidsize:[64, 64]	batchsize:64	lr: 0.001
# acc:0.673	hidsize:[64, 64]	batchsize:64	lr: 0.005
# acc:0.671	hidsize:[64, 64]	batchsize:64	lr:  0.01
# acc:0.673	hidsize:[64, 64]	batchsize:64	lr:  0.05
# --------------------------------------
# | [PEER] best batchsize   | 1        |
# | [PEER] best hidsize     | [8, 8]   |
# | [PEER] best learning... | 0.0007   |
# --------------------------------------
# ---------------------------------
# | [PEER] alpha = 0.1 | 0.604    |
# | [PEER] alpha = 0.2 | 0.602    |
# | [PEER] alpha = 0.3 | 0.609    |
# | [PEER] alpha = 0.4 | 0.604    |
# | [PEER] alpha = 0.5 | 0.596    |
# | [PEER] alpha = 0.6 | 0.587    |
# | [PEER] alpha = 0.7 | 0.573    |
# | [PEER] alpha = 0.8 | 0.569    |
# | [PEER] alpha = 0.9 | 0.546    |
# | [PEER] alpha = 1.0 | 0.537    |
# ---------------------------------
# --------------------------------------
# | [NN] with bce loss      | 0.599    |
# | [NN] with peer loss     | 0.672    |
# | [NN] with surrogate ... | 0.755    |
# | [PEER] best alpha       | 0.3      |
# --------------------------------------
# Logging to logs/svm/19-08-29-19-39-12
# {'dataset': 'image', 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'e0': 0.2, 'e1': 0.4, 'episodes': 3000, 'equalize_prior': False}
# --------------------------------
# | [C-SVM] C1 = 0.1  | 0.568    |
# | [C-SVM] C1 = 0.2  | 0.568    |
# | [C-SVM] C1 = 0.25 | 0.568    |
# | [C-SVM] C1 = 0.33 | 0.568    |
# | [C-SVM] C1 = 0.5  | 0.567    |
# | [C-SVM] C1 = 1.0  | 0.646    |
# | [C-SVM] C1 = 10.0 | 0.437    |
# | [C-SVM] C1 = 2.0  | 0.624    |
# | [C-SVM] C1 = 3.0  | 0.544    |
# | [C-SVM] C1 = 4.0  | 0.469    |
# | [C-SVM] C1 = 5.0  | 0.436    |
# --------------------------------
# ------------------------------------
# | [C-SVM] accuracy max  | 0.885    |
# | [C-SVM] accuracy mean | 0.825    |
# | [C-SVM] accuracy min  | 0.781    |
# | [C-SVM] accuracy std  | 0.0353   |
# | [C-SVM] best C1       | 1        |
# ------------------------------------
# Logging to logs/pam/19-08-29-19-39-14
# {'dataset': 'image', 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'e0': 0.2, 'e1': 0.4, 'episodes': 3000, 'equalize_prior': False}
# -----------------------------------
# | [PAM] margin = 0     | 0.563    |
# | [PAM] margin = 0.125 | 0.578    |
# | [PAM] margin = 0.25  | 0.583    |
# | [PAM] margin = 0.5   | 0.604    |
# | [PAM] margin = 1     | 0.602    |
# -----------------------------------
# ----------------------------------
# | [PAM] accuracy max  | 0.683    |
# | [PAM] accuracy mean | 0.609    |
# | [PAM] accuracy min  | 0.559    |
# | [PAM] accuracy std  | 0.0404   |
# | [PAM] best margin   | 0.5      |
# ----------------------------------

# %% [markdown]
# ### $e_0=0.4, e_1=0.4$

# %%
from run_nn import find_best_alpha
args = default_args.copy()
args.update({
    'e0': 0.4, 'e1': 0.4,
    'episodes': 3000,
    'equalize_prior': False,
    'batchsize': 16,
    'hidsize': [32, 32],
    'lr': 0.001,
})
find_best_alpha(args)
# Out:
# ---------------------------------
# | [PEER] alpha = 0.1 | 0.792    |
# | [PEER] alpha = 0.2 | 0.79     |
# | [PEER] alpha = 0.3 | 0.796    |
# | [PEER] alpha = 0.4 | 0.792    |
# | [PEER] alpha = 0.5 | 0.806    |
# | [PEER] alpha = 0.6 | 0.803    |
# | [PEER] alpha = 0.7 | 0.802    |
# | [PEER] alpha = 0.8 | 0.767    |
# | [PEER] alpha = 0.9 | 0.749    |
# | [PEER] alpha = 1.0 | 0.713    |
# ---------------------------------
# {'alpha': 0.5}

# %%
from runner import run
args = default_args.copy()
args.update({
    'e0': 0.4, 'e1': 0.4,
    'episodes': 3000,
    'equalize_prior': False,
})
run(args)
# Out:
# Logging to logs/nn/19-08-29-19-39-35
# {'dataset': 'image', 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'e0': 0.4, 'e1': 0.4, 'episodes': 3000, 'equalize_prior': False}
# acc:0.653	hidsize:[8, 8]  	batchsize: 1	lr:0.0007
# acc:0.669	hidsize:[8, 8]  	batchsize: 1	lr: 0.001
# acc:0.553	hidsize:[8, 8]  	batchsize: 1	lr: 0.005
# acc:0.581	hidsize:[8, 8]  	batchsize: 1	lr:  0.01
# acc:0.57	hidsize:[8, 8]  	batchsize: 1	lr:  0.05
# acc:0.657	hidsize:[8, 8]  	batchsize: 4	lr:0.0007
# acc:0.648	hidsize:[8, 8]  	batchsize: 4	lr: 0.001
# acc:0.626	hidsize:[8, 8]  	batchsize: 4	lr: 0.005
# acc:0.643	hidsize:[8, 8]  	batchsize: 4	lr:  0.01
# acc:0.577	hidsize:[8, 8]  	batchsize: 4	lr:  0.05
# acc:0.686	hidsize:[8, 8]  	batchsize:16	lr:0.0007
# acc:0.672	hidsize:[8, 8]  	batchsize:16	lr: 0.001
# acc:0.689	hidsize:[8, 8]  	batchsize:16	lr: 0.005
# acc:0.655	hidsize:[8, 8]  	batchsize:16	lr:  0.01
# acc:0.653	hidsize:[8, 8]  	batchsize:16	lr:  0.05
# acc:0.675	hidsize:[8, 8]  	batchsize:32	lr:0.0007
# acc:0.669	hidsize:[8, 8]  	batchsize:32	lr: 0.001
# acc:0.677	hidsize:[8, 8]  	batchsize:32	lr: 0.005
# acc:0.671	hidsize:[8, 8]  	batchsize:32	lr:  0.01
# acc:0.674	hidsize:[8, 8]  	batchsize:32	lr:  0.05
# acc:0.692	hidsize:[8, 8]  	batchsize:64	lr:0.0007
# acc:0.693	hidsize:[8, 8]  	batchsize:64	lr: 0.001
# acc:0.695	hidsize:[8, 8]  	batchsize:64	lr: 0.005
# acc:0.695	hidsize:[8, 8]  	batchsize:64	lr:  0.01
# acc:0.595	hidsize:[8, 8]  	batchsize:64	lr:  0.05
# acc:0.638	hidsize:[16, 16]	batchsize: 1	lr:0.0007
# acc:0.634	hidsize:[16, 16]	batchsize: 1	lr: 0.001
# acc:0.589	hidsize:[16, 16]	batchsize: 1	lr: 0.005
# acc:0.596	hidsize:[16, 16]	batchsize: 1	lr:  0.01
# acc:0.565	hidsize:[16, 16]	batchsize: 1	lr:  0.05
# acc:0.658	hidsize:[16, 16]	batchsize: 4	lr:0.0007
# acc:0.662	hidsize:[16, 16]	batchsize: 4	lr: 0.001
# acc:0.65	hidsize:[16, 16]	batchsize: 4	lr: 0.005
# acc:0.649	hidsize:[16, 16]	batchsize: 4	lr:  0.01
# acc:0.545	hidsize:[16, 16]	batchsize: 4	lr:  0.05
# acc:0.686	hidsize:[16, 16]	batchsize:16	lr:0.0007
# acc:0.677	hidsize:[16, 16]	batchsize:16	lr: 0.001
# acc:0.689	hidsize:[16, 16]	batchsize:16	lr: 0.005
# acc:0.66	hidsize:[16, 16]	batchsize:16	lr:  0.01
# acc:0.663	hidsize:[16, 16]	batchsize:16	lr:  0.05
# acc:0.676	hidsize:[16, 16]	batchsize:32	lr:0.0007
# acc:0.678	hidsize:[16, 16]	batchsize:32	lr: 0.001
# acc:0.674	hidsize:[16, 16]	batchsize:32	lr: 0.005
# acc:0.663	hidsize:[16, 16]	batchsize:32	lr:  0.01
# acc:0.629	hidsize:[16, 16]	batchsize:32	lr:  0.05
# acc:0.677	hidsize:[16, 16]	batchsize:64	lr:0.0007
# acc:0.677	hidsize:[16, 16]	batchsize:64	lr: 0.001
# acc:0.672	hidsize:[16, 16]	batchsize:64	lr: 0.005
# acc:0.664	hidsize:[16, 16]	batchsize:64	lr:  0.01
# acc:0.619	hidsize:[16, 16]	batchsize:64	lr:  0.05
# acc:0.663	hidsize:[32, 32]	batchsize: 1	lr:0.0007
# acc:0.665	hidsize:[32, 32]	batchsize: 1	lr: 0.001
# acc:0.593	hidsize:[32, 32]	batchsize: 1	lr: 0.005
# acc:0.627	hidsize:[32, 32]	batchsize: 1	lr:  0.01
# acc:0.551	hidsize:[32, 32]	batchsize: 1	lr:  0.05
# acc:0.67	hidsize:[32, 32]	batchsize: 4	lr:0.0007
# acc:0.666	hidsize:[32, 32]	batchsize: 4	lr: 0.001
# acc:0.652	hidsize:[32, 32]	batchsize: 4	lr: 0.005
# acc:0.631	hidsize:[32, 32]	batchsize: 4	lr:  0.01
# acc:0.639	hidsize:[32, 32]	batchsize: 4	lr:  0.05
# acc:0.71	hidsize:[32, 32]	batchsize:16	lr:0.0007
# acc:0.713	hidsize:[32, 32]	batchsize:16	lr: 0.001
# acc:0.703	hidsize:[32, 32]	batchsize:16	lr: 0.005
# acc:0.712	hidsize:[32, 32]	batchsize:16	lr:  0.01
# acc:0.632	hidsize:[32, 32]	batchsize:16	lr:  0.05
# acc:0.699	hidsize:[32, 32]	batchsize:32	lr:0.0007
# acc:0.697	hidsize:[32, 32]	batchsize:32	lr: 0.001
# acc:0.695	hidsize:[32, 32]	batchsize:32	lr: 0.005
# acc:0.684	hidsize:[32, 32]	batchsize:32	lr:  0.01
# acc:0.668	hidsize:[32, 32]	batchsize:32	lr:  0.05
# acc:0.699	hidsize:[32, 32]	batchsize:64	lr:0.0007
# acc:0.701	hidsize:[32, 32]	batchsize:64	lr: 0.001
# acc:0.695	hidsize:[32, 32]	batchsize:64	lr: 0.005
# acc:0.693	hidsize:[32, 32]	batchsize:64	lr:  0.01
# acc:0.627	hidsize:[32, 32]	batchsize:64	lr:  0.05
# acc:0.648	hidsize:[64, 64]	batchsize: 1	lr:0.0007
# acc:0.646	hidsize:[64, 64]	batchsize: 1	lr: 0.001
# acc:0.547	hidsize:[64, 64]	batchsize: 1	lr: 0.005
# acc:0.598	hidsize:[64, 64]	batchsize: 1	lr:  0.01
# acc:0.662	hidsize:[64, 64]	batchsize: 1	lr:  0.05
# acc:0.664	hidsize:[64, 64]	batchsize: 4	lr:0.0007
# acc:0.655	hidsize:[64, 64]	batchsize: 4	lr: 0.001
# acc:0.647	hidsize:[64, 64]	batchsize: 4	lr: 0.005
# acc:0.635	hidsize:[64, 64]	batchsize: 4	lr:  0.01
# acc:0.639	hidsize:[64, 64]	batchsize: 4	lr:  0.05
# acc:0.707	hidsize:[64, 64]	batchsize:16	lr:0.0007
# acc:0.707	hidsize:[64, 64]	batchsize:16	lr: 0.001
# acc: 0.7	hidsize:[64, 64]	batchsize:16	lr: 0.005
# acc:0.699	hidsize:[64, 64]	batchsize:16	lr:  0.01
# acc:0.683	hidsize:[64, 64]	batchsize:16	lr:  0.05
# acc: 0.7	hidsize:[64, 64]	batchsize:32	lr:0.0007
# acc:0.687	hidsize:[64, 64]	batchsize:32	lr: 0.001
# acc:0.683	hidsize:[64, 64]	batchsize:32	lr: 0.005
# acc:0.682	hidsize:[64, 64]	batchsize:32	lr:  0.01
# acc:0.682	hidsize:[64, 64]	batchsize:32	lr:  0.05
# acc:0.693	hidsize:[64, 64]	batchsize:64	lr:0.0007
# acc:0.691	hidsize:[64, 64]	batchsize:64	lr: 0.001
# acc:0.687	hidsize:[64, 64]	batchsize:64	lr: 0.005
# acc:0.671	hidsize:[64, 64]	batchsize:64	lr:  0.01
# acc:0.647	hidsize:[64, 64]	batchsize:64	lr:  0.05
# --------------------------------------
# | [PEER] best batchsize   | 16       |
# | [PEER] best hidsize     | [32, 32] |
# | [PEER] best learning... | 0.001    |
# --------------------------------------
# ---------------------------------
# | [PEER] alpha = 0.1 | 0.552    |
# | [PEER] alpha = 0.2 | 0.555    |
# | [PEER] alpha = 0.3 | 0.555    |
# | [PEER] alpha = 0.4 | 0.554    |
# | [PEER] alpha = 0.5 | 0.558    |
# | [PEER] alpha = 0.6 | 0.557    |
# | [PEER] alpha = 0.7 | 0.555    |
# | [PEER] alpha = 0.8 | 0.531    |
# | [PEER] alpha = 0.9 | 0.542    |
# | [PEER] alpha = 1.0 | 0.533    |
# ---------------------------------
# --------------------------------------
# | [NN] with bce loss      | 0.8      |
# | [NN] with peer loss     | 0.806    |
# | [NN] with surrogate ... | 0.803    |
# | [PEER] best alpha       | 0.5      |
# --------------------------------------
# Logging to logs/svm/19-08-29-19-59-50
# {'dataset': 'image', 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'e0': 0.4, 'e1': 0.4, 'episodes': 3000, 'equalize_prior': False}
# --------------------------------
# | [C-SVM] C1 = 0.1  | 0.484    |
# | [C-SVM] C1 = 0.2  | 0.484    |
# | [C-SVM] C1 = 0.25 | 0.484    |
# | [C-SVM] C1 = 0.33 | 0.484    |
# | [C-SVM] C1 = 0.5  | 0.484    |
# | [C-SVM] C1 = 1.0  | 0.562    |
# | [C-SVM] C1 = 10.0 | 0.518    |
# | [C-SVM] C1 = 2.0  | 0.518    |
# | [C-SVM] C1 = 3.0  | 0.518    |
# | [C-SVM] C1 = 4.0  | 0.518    |
# | [C-SVM] C1 = 5.0  | 0.518    |
# --------------------------------
# ------------------------------------
# | [C-SVM] accuracy max  | 0.905    |
# | [C-SVM] accuracy mean | 0.86     |
# | [C-SVM] accuracy min  | 0.818    |
# | [C-SVM] accuracy std  | 0.0268   |
# | [C-SVM] best C1       | 1        |
# ------------------------------------
# Logging to logs/pam/19-08-29-19-59-53
# {'dataset': 'image', 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'e0': 0.4, 'e1': 0.4, 'episodes': 3000, 'equalize_prior': False}
# -----------------------------------
# | [PAM] margin = 0     | 0.506    |
# | [PAM] margin = 0.125 | 0.522    |
# | [PAM] margin = 0.25  | 0.549    |
# | [PAM] margin = 0.5   | 0.551    |
# | [PAM] margin = 1     | 0.545    |
# -----------------------------------
# ----------------------------------
# | [PAM] accuracy max  | 0.816    |
# | [PAM] accuracy mean | 0.749    |
# | [PAM] accuracy min  | 0.651    |
# | [PAM] accuracy std  | 0.0433   |
# | [PAM] best margin   | 0.5      |
# ----------------------------------

# %% [markdown]
# # Image Segmentation Task

# %% [markdown]
# ## Describe
#
# | Total | Positive | Attributes | Normalized |
# |:-----:|:--------:|:----------:|:----------:|
# | 2310  |  57.1%   |     18     |     Not    |

# %%
from utils.dataloader import DataLoader

df = DataLoader('image').df
df.target.describe()
# Out:
# count    2310.000000
# mean        0.571429
# std         0.494979
# min         0.000000
# 25%         0.000000
# 50%         1.000000
# 75%         1.000000
# max         1.000000
# Name: target, dtype: float64

# %%
df.describe()
# Out:
#             target             1             2             3             4  \
# count  2310.000000  2.310000e+03  2.310000e+03  2.310000e+03  2.310000e+03
# mean      0.571429  6.839826e-11  7.774026e-10 -5.177489e-09 -4.935065e-09
# std       0.494979  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# min       0.000000 -1.698461e+00 -1.955633e+00 -3.569700e-01 -1.945096e-01
# 25%       0.000000 -8.623471e-01 -7.378997e-01 -3.569700e-01 -1.945096e-01
# 50%       1.000000 -5.364637e-02 -2.465590e-02 -3.569700e-01 -1.945096e-01
# 75%       1.000000  8.784155e-01  8.451536e-01 -3.569700e-01 -1.945096e-01
# max       1.000000  1.769357e+00  2.219453e+00  7.944380e+00  8.975228e+00
#
#                   5             6             7             8             9  \
# count  2.310000e+03  2.310000e+03  2.310000e+03  2.310000e+03  2.310000e+03
# mean  -1.774893e-12 -8.193506e-11  3.165801e-10  3.478528e-10  2.182251e-10
# std    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# min   -7.017429e-01 -1.273082e-01 -6.716530e-01 -1.401714e-01 -9.705364e-01
# 25%   -4.341452e-01 -1.193799e-01 -4.562064e-01 -1.330021e-01 -7.794159e-01
# 50%   -2.488842e-01 -1.087262e-01 -2.715392e-01 -1.237977e-01 -4.049360e-01
# 75%    1.010511e-01 -8.702923e-02  3.624077e-02 -1.030482e-01  4.233339e-01
# max    1.012568e+01  2.198633e+01  1.171649e+01  2.343224e+01  2.786874e+00
#
#                  10            11            12            13            14  \
# count  2.310000e+03  2.310000e+03  2.310000e+03  2.310000e+03  2.310000e+03
# mean   6.687013e-10  4.393117e-10 -1.359741e-11  3.504329e-10  8.375758e-10
# std    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# min   -9.367674e-01 -1.015172e+00 -9.389746e-01 -3.192093e+00 -1.729696e+00
# 25%   -7.369773e-01 -7.956431e-01 -7.732159e-01 -5.062945e-01 -8.823892e-01
# 50%   -3.786237e-01 -3.795584e-01 -3.798254e-01  1.555629e-01 -8.901494e-02
# 75%    4.141940e-01  4.755851e-01  3.397354e-01  7.310911e-01  7.341642e-01
# max    2.976581e+00  2.451349e+00  2.981181e+00  1.949292e+00  3.095836e+00
#
#                  15            16            17            18
# count  2.310000e+03  2.310000e+03  2.310000e+03  2.310000e+03
# mean   1.333333e-10 -5.170563e-10  7.432684e-10 -4.766234e-11
# std    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# min   -2.178991e+00 -1.051622e+00 -1.869800e+00 -1.087970e+00
# 25%   -6.977189e-01 -7.823983e-01 -6.248455e-01 -5.339683e-01
# 50%   -1.879302e-01 -3.837402e-01 -2.281546e-01 -4.454069e-01
# 75%    4.757569e-01  4.601726e-01  4.959519e-01 -1.290408e-01
# max    2.890039e+00  2.463818e+00  2.510221e+00  2.766634e+00

# %%
from runner import run

args = {
    'dataset': 'image', 
    'lr': 0.01, 
    'hidsize': 16, 
    'episodes': 100, 
    'batchsize': 10, 
    'test_size': 0.25,
    'dropout': 0.,
    'normalize': True,
    'equalize_prior': False
}

# %% [markdown]
# $e_0 = 0, e_1 = 0$

# %%
args.update({'e0': 0, 'e1': 0})
run(args.copy())
# Out:
# {'dataset': 'image', 'lr': 0.01, 'hidsize': 16, 'episodes': 100, 'batchsize': 10, 'test_size': 0.25, 'dropout': 0.0, 'normalize': True, 'equalize_prior': False, 'e0': 0, 'e1': 0}
# --------------------------------------
# | knn                     | 0.953    |
# | logistic regression     | 0.83     |
# | nn                      | 0.975    |
# | nn with peer prediction | 0.69     |
# | random forest           | 0.985    |
# | svm                     | 0.927    |
# --------------------------------------
# Process ForkPoolWorker-150:
# Process ForkPoolWorker-149:
# Process ForkPoolWorker-147:
# Process ForkPoolWorker-148:
# Process ForkPoolWorker-145:
# Process ForkPoolWorker-151:
# Process ForkPoolWorker-146:
# Process ForkPoolWorker-152:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/queues.py", line 335, in get
#     res = self._reader.recv_bytes()
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
# KeyboardInterrupt
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
# KeyboardInterrupt

# %%
args.update({'e0': 0, 'e1': 0})
run(args.copy())
# Out:
# {'dataset': 'image', 'lr': 0.01, 'hidsize': 16, 'episodes': 100, 'batchsize': 10, 'test_size': 0.25, 'dropout': 0.0, 'normalize': True, 'equalize_prior': False, 'e0': 0, 'e1': 0}
# --------------------------------------
# | knn                     | 0.953    |
# | logistic regression     | 0.83     |
# | nn                      | 0.975    |
# | nn with peer prediction | 0.69     |
# | random forest           | 0.985    |
# | svm                     | 0.927    |
# --------------------------------------
# Process ForkPoolWorker-158:
# Process ForkPoolWorker-154:
# Process ForkPoolWorker-156:
# Process ForkPoolWorker-155:
# Process ForkPoolWorker-157:
# Process ForkPoolWorker-153:
# Process ForkPoolWorker-159:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Process ForkPoolWorker-160:
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/queues.py", line 335, in get
#     res = self._reader.recv_bytes()
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
# KeyboardInterrupt

# %% [markdown]
# $e_0 = 0.2, e_1 = 0.2$

# %%
args.update({'e0': 0.2, 'e1': 0.2})
run(args.copy())
# Out:
# {'dataset': 'image', 'lr': 0.01, 'hidsize': 16, 'episodes': 100, 'batchsize': 10, 'test_size': 0.25, 'dropout': 0.0, 'normalize': True, 'equalize_prior': False, 'e0': 0.2, 'e1': 0.2}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-17-83717e861aa8> in <module>
#       1 args.update({'e0': 0.2, 'e1': 0.2})
# ----> 2 run(args.copy())
#
# ~/Desktop/learning-with-noisy-labels/runner.py in run(arg_dict)
#     107         arg_dict.update({'seed': seed})
#     108         args.append(arg_dict.copy())
# --> 109     results_bce = pool.map(run_nn, args)
#     110
#     111     # logistic regression
#
# ~/anaconda3/envs/py36/lib/python3.6/multiprocessing/pool.py in map(self, func, iterable, chunksize)
#     264         in a list that is returned.
#     265         '''
# --> 266         return self._map_async(func, iterable, mapstar, chunksize).get()
#     267
#     268     def starmap(self, func, iterable, chunksize=None):
#
# ~/anaconda3/envs/py36/lib/python3.6/multiprocessing/pool.py in get(self, timeout)
#     636
#     637     def get(self, timeout=None):
# --> 638         self.wait(timeout)
#     639         if not self.ready():
#     640             raise TimeoutError
#
# ~/anaconda3/envs/py36/lib/python3.6/multiprocessing/pool.py in wait(self, timeout)
#     633
#     634     def wait(self, timeout=None):
# --> 635         self._event.wait(timeout)
#     636
#     637     def get(self, timeout=None):
#
# ~/anaconda3/envs/py36/lib/python3.6/threading.py in wait(self, timeout)
#     549             signaled = self._flag
#     550             if not signaled:
# --> 551                 signaled = self._cond.wait(timeout)
#     552             return signaled
#     553
#
# ~/anaconda3/envs/py36/lib/python3.6/threading.py in wait(self, timeout)
#     293         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     294             if timeout is None:
# --> 295                 waiter.acquire()
#     296                 gotit = True
#     297             else:
#
# KeyboardInterrupt:
# Process ForkPoolWorker-165:
# Process ForkPoolWorker-162:
# Process ForkPoolWorker-167:
# Process ForkPoolWorker-163:
# Process ForkPoolWorker-164:
# Process ForkPoolWorker-161:
# Process ForkPoolWorker-166:
# Process ForkPoolWorker-168:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/Users/henryguo/Desktop/learning-with-noisy-labels/runner.py", line 34, in run_nn
#     episodes=kargs['episodes'],
#   File "/Users/henryguo/Desktop/learning-with-noisy-labels/runner.py", line 34, in run_nn
#     episodes=kargs['episodes'],
#   File "/Users/henryguo/Desktop/learning-with-noisy-labels/runner.py", line 34, in run_nn
#     episodes=kargs['episodes'],
#   File "/Users/henryguo/Desktop/learning-with-noisy-labels/runner.py", line 34, in run_nn
#     episodes=kargs['episodes'],
#   File "/Users/henryguo/Desktop/learning-with-noisy-labels/runner.py", line 34, in run_nn
#     episodes=kargs['episodes'],
#   File "/Users/henryguo/Desktop/learning-with-noisy-labels/runner.py", line 34, in run_nn
#     episodes=kargs['episodes'],
#   File "/Users/henryguo/Desktop/learning-with-noisy-labels/runner.py", line 34, in run_nn
#     episodes=kargs['episodes'],
#   File "/Users/henryguo/Desktop/learning-with-noisy-labels/runner.py", line 34, in run_nn
#     episodes=kargs['episodes'],
#   File "/Users/henryguo/Desktop/learning-with-noisy-labels/model.py", line 82, in fit
#     loss = self.train(mb_X_train, mb_y_train)
#   File "/Users/henryguo/Desktop/learning-with-noisy-labels/model.py", line 82, in fit
#     loss = self.train(mb_X_train, mb_y_train)
#   File "/Users/henryguo/Desktop/learning-with-noisy-labels/model.py", line 82, in fit
#     loss = self.train(mb_X_train, mb_y_train)
#   File "/Users/henryguo/Desktop/learning-with-noisy-labels/model.py", line 82, in fit
#     loss = self.train(mb_X_train, mb_y_train)
#   File "/Users/henryguo/Desktop/learning-with-noisy-labels/model.py", line 82, in fit
#     loss = self.train(mb_X_train, mb_y_train)
#   File "/Users/henryguo/Desktop/learning-with-noisy-labels/model.py", line 82, in fit
#     loss = self.train(mb_X_train, mb_y_train)
#   File "/Users/henryguo/Desktop/learning-with-noisy-labels/model.py", line 82, in fit
#     loss = self.train(mb_X_train, mb_y_train)
#   File "/Users/henryguo/Desktop/learning-with-noisy-labels/model.py", line 82, in fit
#     loss = self.train(mb_X_train, mb_y_train)
#   File "/Users/henryguo/Desktop/learning-with-noisy-labels/model.py", line 57, in train
#     loss.backward()
#   File "/Users/henryguo/Desktop/learning-with-noisy-labels/model.py", line 57, in train
#     loss.backward()
#   File "/Users/henryguo/Desktop/learning-with-noisy-labels/model.py", line 57, in train
#     loss.backward()
#   File "/Users/henryguo/Desktop/learning-with-noisy-labels/model.py", line 57, in train
#     loss.backward()
#   File "/Users/henryguo/Desktop/learning-with-noisy-labels/model.py", line 57, in train
#     loss.backward()
#   File "/Users/henryguo/Desktop/learning-with-noisy-labels/model.py", line 58, in train
#     self.optimizer.step()
#   File "/Users/henryguo/Desktop/learning-with-noisy-labels/model.py", line 57, in train
#     loss.backward()
#   File "/Users/henryguo/Desktop/learning-with-noisy-labels/model.py", line 57, in train
#     loss.backward()
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/site-packages/torch/tensor.py", line 107, in backward
#     torch.autograd.backward(self, gradient, retain_graph, create_graph)
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/site-packages/torch/tensor.py", line 107, in backward
#     torch.autograd.backward(self, gradient, retain_graph, create_graph)
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/site-packages/torch/tensor.py", line 107, in backward
#     torch.autograd.backward(self, gradient, retain_graph, create_graph)
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/site-packages/torch/tensor.py", line 107, in backward
#     torch.autograd.backward(self, gradient, retain_graph, create_graph)
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/site-packages/torch/tensor.py", line 107, in backward
#     torch.autograd.backward(self, gradient, retain_graph, create_graph)
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/site-packages/torch/optim/adam.py", line 94, in step
#     exp_avg_sq.mul_(beta2).addcmul_(1 - beta2, grad, grad)
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/site-packages/torch/tensor.py", line 107, in backward
#     torch.autograd.backward(self, gradient, retain_graph, create_graph)
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/site-packages/torch/tensor.py", line 107, in backward
#     torch.autograd.backward(self, gradient, retain_graph, create_graph)
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/site-packages/torch/autograd/__init__.py", line 93, in backward
#     allow_unreachable=True)  # allow_unreachable flag
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/site-packages/torch/autograd/__init__.py", line 93, in backward
#     allow_unreachable=True)  # allow_unreachable flag
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/site-packages/torch/autograd/__init__.py", line 93, in backward
#     allow_unreachable=True)  # allow_unreachable flag
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/site-packages/torch/autograd/__init__.py", line 93, in backward
#     allow_unreachable=True)  # allow_unreachable flag
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/site-packages/torch/autograd/__init__.py", line 93, in backward
#     allow_unreachable=True)  # allow_unreachable flag
# KeyboardInterrupt
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/site-packages/torch/autograd/__init__.py", line 93, in backward
#     allow_unreachable=True)  # allow_unreachable flag
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/site-packages/torch/autograd/__init__.py", line 93, in backward
#     allow_unreachable=True)  # allow_unreachable flag
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt

# %% [markdown]
# $e_0 = 0.1, e_1 = 0.3$

# %%
args.update({'e0': 0.1, 'e1': 0.3})
run(args.copy())

# %% [markdown]
# $e_0 = 0.2, e_1 = 0.4$

# %%
args.update({'e0': 0.2, 'e1': 0.4})
run(args.copy())

# %% [markdown]
# $e_0 = 0.4, e_1 = 0.4$

# %%
args.update({'e0': 0.4, 'e1': 0.4})
run(args.copy())

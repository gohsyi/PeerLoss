# %% [markdown]
# # Splice (60,1527,1648)

# %% [markdown]
# ## Describe
#
# | Total | Positive | Attributes | Normalized |
# |:-----:|:--------:|:----------:|:----------:|
# | 3175  |  48.1%   |     60     |   Onehot   |

# %%
default_args = {
    'dataset': 'splice',
    'test_size': 0.15,
    'val_size': 0.1,
    'dropout': 0, 
    'normalize': True,
    'loss': 'bce',
    'activation': 'relu',
    'verbose': True,
}

# %% [markdown]
# ## Without Prior Equalization

# %% [markdown]
# ### $e_0 = 0.1, e_1 = 0.3$

# %%
from run_nn import find_best_alpha
args = default_args.copy()
args.update({
    'dataset': 'splice', 
    'e0': 0.1, 'e1': 0.3, 
    'equalize_prior': True, 
    'episodes': 1000, 
    'batchsize': 32, 
    'hidsize': [64, 64], 
    'lr': 0.0007, 
#     'alpha': 1.
})
find_best_alpha(args)
# Out:
# ---------------------------------
# | [PEER] alpha = 0.1 | 0.815    |
# | [PEER] alpha = 0.2 | 0.825    |
# | [PEER] alpha = 0.3 | 0.87     |
# | [PEER] alpha = 0.4 | 0.885    |
# | [PEER] alpha = 0.5 | 0.9      |
# | [PEER] alpha = 0.6 | 0.913    |
# | [PEER] alpha = 0.7 | 0.919    |
# | [PEER] alpha = 0.8 | 0.918    |
# | [PEER] alpha = 0.9 | 0.917    |
# | [PEER] alpha = 1.0 | 0.913    |
# ---------------------------------
# {'alpha': 0.7}

# %%
from run_nn import find_best_alpha
args = default_args.copy()
args.update({
    'dataset': 'splice', 
    'e0': 0.1, 'e1': 0.3, 
    'equalize_prior': True, 
    'episodes': 1000, 
    'batchsize': 32, 
    'hidsize': [64, 64], 
    'lr': 0.0007, 
#     'alpha': 1.
})
find_best_alpha(args)
# Out:
# ---------------------------------
# | [PEER] alpha = 0.4 | 0.885    |
# | [PEER] alpha = 0.5 | 0.9      |
# | [PEER] alpha = 0.6 | 0.913    |
# | [PEER] alpha = 0.7 | 0.919    |
# | [PEER] alpha = 0.8 | 0.918    |
# | [PEER] alpha = 0.9 | 0.917    |
# | [PEER] alpha = 1.0 | 0.913    |
# | [PEER] alpha = 2.0 | 0.541    |
# | [PEER] alpha = 3.0 | 0.501    |
# | [PEER] alpha = 4.0 | 0.501    |
# | [PEER] alpha = 5.0 | 0.501    |
# ---------------------------------
# {'alpha': 0.7}

# %%
from runner import run
args = default_args.copy()
args.update({
    'dataset': 'splice', 
    'e0': 0.1, 'e1': 0.3, 
    'equalize_prior': True, 
    'episodes': 1000, 
    'batchsize': 32, 
    'hidsize': [64, 64], 
    'lr': 0.0007, 
#     'alpha': 1.0,
})
run(args)
# Out:
# Logging to logs/nn/19-08-28-19-50-57
# {'dataset': 'splice', 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'e0': 0.1, 'e1': 0.3, 'equalize_prior': True, 'episodes': 1000, 'batchsize': 32, 'hidsize': [64, 64], 'lr': 0.0007}
# ---------------------------------
# | [PEER] alpha = 0.1 | 0.712    |
# | [PEER] alpha = 0.2 | 0.717    |
# | [PEER] alpha = 0.3 | 0.739    |
# | [PEER] alpha = 0.4 | 0.746    |
# | [PEER] alpha = 0.5 | 0.747    |
# | [PEER] alpha = 0.6 | 0.752    |
# | [PEER] alpha = 0.7 | 0.754    |
# | [PEER] alpha = 0.8 | 0.752    |
# | [PEER] alpha = 0.9 | 0.749    |
# | [PEER] alpha = 1.0 | 0.752    |
# ---------------------------------
# --------------------------------------
# | [NN] with bce loss      | 0.811    |
# | [NN] with peer loss     | 0.919    |
# | [NN] with surrogate ... | 0.878    |
# | [PEER] best alpha       | 0.7      |
# --------------------------------------
# Logging to logs/svm/19-08-28-19-52-29
# {'dataset': 'splice', 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'e0': 0.1, 'e1': 0.3, 'equalize_prior': True, 'episodes': 1000, 'batchsize': 32, 'hidsize': [64, 64], 'lr': 0.0007}
# --------------------------------
# | [C-SVM] C1 = 0.1  | 0.598    |
# | [C-SVM] C1 = 0.2  | 0.598    |
# | [C-SVM] C1 = 0.25 | 0.599    |
# | [C-SVM] C1 = 0.33 | 0.6      |
# | [C-SVM] C1 = 0.5  | 0.649    |
# | [C-SVM] C1 = 1.0  | 0.753    |
# | [C-SVM] C1 = 10.0 | 0.758    |
# | [C-SVM] C1 = 2.0  | 0.757    |
# | [C-SVM] C1 = 3.0  | 0.758    |
# | [C-SVM] C1 = 4.0  | 0.758    |
# | [C-SVM] C1 = 5.0  | 0.758    |
# --------------------------------
# ------------------------------------
# | [C-SVM] accuracy max  | 0.948    |
# | [C-SVM] accuracy mean | 0.928    |
# | [C-SVM] accuracy min  | 0.911    |
# | [C-SVM] accuracy std  | 0.012    |
# | [C-SVM] best C1       | 4        |
# ------------------------------------
# Logging to logs/pam/19-08-28-19-52-56
# {'dataset': 'splice', 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'e0': 0.1, 'e1': 0.3, 'equalize_prior': True, 'episodes': 1000, 'batchsize': 32, 'hidsize': [64, 64], 'lr': 0.0007}
# -----------------------------------
# | [PAM] margin = 0     | 0.656    |
# | [PAM] margin = 0.125 | 0.703    |
# | [PAM] margin = 0.25  | 0.732    |
# | [PAM] margin = 0.5   | 0.739    |
# | [PAM] margin = 1     | 0.744    |
# -----------------------------------
# ----------------------------------
# | [PAM] accuracy max  | 0.893    |
# | [PAM] accuracy mean | 0.875    |
# | [PAM] accuracy min  | 0.856    |
# | [PAM] accuracy std  | 0.0134   |
# | [PAM] best margin   | 1        |
# ----------------------------------

# %% [markdown]
# ### $e_0 = 0.2, e_1 = 0.2$

# %%
from run_nn import find_best_alpha
args = default_args.copy()
args.update({
    'dataset': 'splice', 
    'e0': 0.2, 'e1': 0.2, 
    'equalize_prior': True, 
    'episodes': 1000, 
    'batchsize': 32, 
    'hidsize': [64, 64], 
    'lr': 0.0007, 
#     'alpha': 1.
})
find_best_alpha(args)
# Out:
# ---------------------------------
# | [PEER] alpha = 0.1 | 0.825    |
# | [PEER] alpha = 0.2 | 0.842    |
# | [PEER] alpha = 0.3 | 0.856    |
# | [PEER] alpha = 0.4 | 0.877    |
# | [PEER] alpha = 0.5 | 0.898    |
# | [PEER] alpha = 0.6 | 0.912    |
# | [PEER] alpha = 0.7 | 0.916    |
# | [PEER] alpha = 0.8 | 0.918    |
# | [PEER] alpha = 0.9 | 0.917    |
# | [PEER] alpha = 1.0 | 0.917    |
# ---------------------------------
# {'alpha': 0.8}

# %%
from runner import run
args = default_args.copy()
args.update({
    'dataset': 'splice', 
    'e0': 0.2, 'e1': 0.2, 
    'equalize_prior': True, 
    'episodes': 1000, 
    'batchsize': 32, 
    'hidsize': [64, 64], 
    'lr': 0.0007, 
#     'alpha': 1.
})
run(args)
# Out:
# Logging to logs/nn/19-08-28-19-44-31
# {'dataset': 'splice', 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'e0': 0.2, 'e1': 0.2, 'equalize_prior': True, 'episodes': 1000, 'batchsize': 32, 'hidsize': [64, 64], 'lr': 0.0007}
# ---------------------------------
# | [PEER] alpha = 0.1 | 0.689    |
# | [PEER] alpha = 0.2 | 0.704    |
# | [PEER] alpha = 0.3 | 0.721    |
# | [PEER] alpha = 0.4 | 0.733    |
# | [PEER] alpha = 0.5 | 0.742    |
# | [PEER] alpha = 0.6 | 0.744    |
# | [PEER] alpha = 0.7 | 0.75     |
# | [PEER] alpha = 0.8 | 0.751    |
# | [PEER] alpha = 0.9 | 0.751    |
# | [PEER] alpha = 1.0 | 0.75     |
# ---------------------------------
# --------------------------------------
# | [NN] with bce loss      | 0.819    |
# | [NN] with peer loss     | 0.918    |
# | [NN] with surrogate ... | 0.874    |
# | [PEER] best alpha       | 0.8      |
# --------------------------------------
# Logging to logs/svm/19-08-28-19-46-12
# {'dataset': 'splice', 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'e0': 0.2, 'e1': 0.2, 'equalize_prior': True, 'episodes': 1000, 'batchsize': 32, 'hidsize': [64, 64], 'lr': 0.0007}
# --------------------------------
# | [C-SVM] C1 = 0.1  | 0.498    |
# | [C-SVM] C1 = 0.2  | 0.5      |
# | [C-SVM] C1 = 0.25 | 0.508    |
# | [C-SVM] C1 = 0.33 | 0.572    |
# | [C-SVM] C1 = 0.5  | 0.731    |
# | [C-SVM] C1 = 1.0  | 0.757    |
# | [C-SVM] C1 = 10.0 | 0.73     |
# | [C-SVM] C1 = 2.0  | 0.739    |
# | [C-SVM] C1 = 3.0  | 0.73     |
# | [C-SVM] C1 = 4.0  | 0.73     |
# | [C-SVM] C1 = 5.0  | 0.73     |
# --------------------------------
# ------------------------------------
# | [C-SVM] accuracy max  | 0.952    |
# | [C-SVM] accuracy mean | 0.931    |
# | [C-SVM] accuracy min  | 0.915    |
# | [C-SVM] accuracy std  | 0.0139   |
# | [C-SVM] best C1       | 1        |
# ------------------------------------
# Logging to logs/pam/19-08-28-19-46-39
# {'dataset': 'splice', 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'e0': 0.2, 'e1': 0.2, 'equalize_prior': True, 'episodes': 1000, 'batchsize': 32, 'hidsize': [64, 64], 'lr': 0.0007}
# -----------------------------------
# | [PAM] margin = 0     | 0.639    |
# | [PAM] margin = 0.125 | 0.692    |
# | [PAM] margin = 0.25  | 0.721    |
# | [PAM] margin = 0.5   | 0.726    |
# | [PAM] margin = 1     | 0.743    |
# -----------------------------------
# ----------------------------------
# | [PAM] accuracy max  | 0.917    |
# | [PAM] accuracy mean | 0.898    |
# | [PAM] accuracy min  | 0.88     |
# | [PAM] accuracy std  | 0.0123   |
# | [PAM] best margin   | 1        |
# ----------------------------------

# %% [markdown]
# ### $e_0 = 0.1, e_1 = 0.4$

# %%
from run_nn import find_best_alpha
args = default_args.copy()
args.update({
    'dataset': 'splice', 
    'e0': 0.1, 'e1': 0.4, 
    'equalize_prior': True, 
    'episodes': 1000, 
    'batchsize': 32, 
    'hidsize': [64, 64], 
    'lr': 0.0007, 
#     'alpha': 1.
})
find_best_alpha(args)
# Out:
# ---------------------------------
# | [PEER] alpha = 0.1 | 0.757    |
# | [PEER] alpha = 0.2 | 0.777    |
# | [PEER] alpha = 0.3 | 0.816    |
# | [PEER] alpha = 0.4 | 0.85     |
# | [PEER] alpha = 0.5 | 0.866    |
# | [PEER] alpha = 0.6 | 0.885    |
# | [PEER] alpha = 0.7 | 0.898    |
# | [PEER] alpha = 0.8 | 0.908    |
# | [PEER] alpha = 0.9 | 0.911    |
# | [PEER] alpha = 1.0 | 0.914    |
# ---------------------------------
# {'alpha': 1.0}

# %%
from runner import run
args = default_args.copy()
args.update({
    'dataset': 'splice', 
    'e0': 0.1, 'e1': 0.4, 
    'equalize_prior': True, 
    'episodes': 1000, 
    'batchsize': 32, 
    'hidsize': [64, 64], 
    'lr': 0.0007, 
})
run(args)
# Out:
# Logging to logs/nn/19-08-28-19-53-26
# {'dataset': 'splice', 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'e0': 0.1, 'e1': 0.4, 'equalize_prior': True, 'episodes': 1000, 'batchsize': 32, 'hidsize': [64, 64], 'lr': 0.0007}
# ---------------------------------
# | [PEER] alpha = 0.1 | 0.691    |
# | [PEER] alpha = 0.2 | 0.696    |
# | [PEER] alpha = 0.3 | 0.705    |
# | [PEER] alpha = 0.4 | 0.721    |
# | [PEER] alpha = 0.5 | 0.725    |
# | [PEER] alpha = 0.6 | 0.728    |
# | [PEER] alpha = 0.7 | 0.722    |
# | [PEER] alpha = 0.8 | 0.717    |
# | [PEER] alpha = 0.9 | 0.715    |
# | [PEER] alpha = 1.0 | 0.712    |
# ---------------------------------
# --------------------------------------
# | [NN] with bce loss      | 0.743    |
# | [NN] with peer loss     | 0.885    |
# | [NN] with surrogate ... | 0.86     |
# | [PEER] best alpha       | 0.6      |
# --------------------------------------
# Logging to logs/svm/19-08-28-19-54-56
# {'dataset': 'splice', 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'e0': 0.1, 'e1': 0.4, 'equalize_prior': True, 'episodes': 1000, 'batchsize': 32, 'hidsize': [64, 64], 'lr': 0.0007}
# --------------------------------
# | [C-SVM] C1 = 0.1  | 0.649    |
# | [C-SVM] C1 = 0.2  | 0.649    |
# | [C-SVM] C1 = 0.25 | 0.649    |
# | [C-SVM] C1 = 0.33 | 0.65     |
# | [C-SVM] C1 = 0.5  | 0.654    |
# | [C-SVM] C1 = 1.0  | 0.713    |
# | [C-SVM] C1 = 10.0 | 0.721    |
# | [C-SVM] C1 = 2.0  | 0.723    |
# | [C-SVM] C1 = 3.0  | 0.721    |
# | [C-SVM] C1 = 4.0  | 0.721    |
# | [C-SVM] C1 = 5.0  | 0.721    |
# --------------------------------
# ------------------------------------
# | [C-SVM] accuracy max  | 0.917    |
# | [C-SVM] accuracy mean | 0.891    |
# | [C-SVM] accuracy min  | 0.865    |
# | [C-SVM] accuracy std  | 0.0198   |
# | [C-SVM] best C1       | 2        |
# ------------------------------------
# Logging to logs/pam/19-08-28-19-55-22
# {'dataset': 'splice', 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'e0': 0.1, 'e1': 0.4, 'equalize_prior': True, 'episodes': 1000, 'batchsize': 32, 'hidsize': [64, 64], 'lr': 0.0007}
# -----------------------------------
# | [PAM] margin = 0     | 0.648    |
# | [PAM] margin = 0.125 | 0.681    |
# | [PAM] margin = 0.25  | 0.697    |
# | [PAM] margin = 0.5   | 0.705    |
# | [PAM] margin = 1     | 0.701    |
# -----------------------------------
# ----------------------------------
# | [PAM] accuracy max  | 0.81     |
# | [PAM] accuracy mean | 0.791    |
# | [PAM] accuracy min  | 0.78     |
# | [PAM] accuracy std  | 0.011    |
# | [PAM] best margin   | 0.5      |
# ----------------------------------

# %% [markdown]
# ### $e_0 = 0.2, e_1 = 0.4$

# %%
from run_nn import find_best_alpha
args = default_args.copy()
args.update({
    'dataset': 'splice', 
    'e0': 0.2, 'e1': 0.4, 
    'equalize_prior': True, 
    'episodes': 1000, 
    'batchsize': 32, 
    'hidsize': [64, 64], 
    'lr': 0.0007, 
#     'alpha': 1.
})
find_best_alpha(args)
# Out:
# ---------------------------------
# | [PEER] alpha = 0.1 | 0.725    |
# | [PEER] alpha = 0.2 | 0.739    |
# | [PEER] alpha = 0.3 | 0.756    |
# | [PEER] alpha = 0.4 | 0.767    |
# | [PEER] alpha = 0.5 | 0.807    |
# | [PEER] alpha = 0.6 | 0.839    |
# | [PEER] alpha = 0.7 | 0.868    |
# | [PEER] alpha = 0.8 | 0.885    |
# | [PEER] alpha = 0.9 | 0.898    |
# | [PEER] alpha = 1.0 | 0.901    |
# ---------------------------------
# {'alpha': 1.0}

# %%
from runner import run
args = default_args.copy()
args.update({
    'dataset': 'splice', 
    'e0': 0.2, 'e1': 0.4, 
    'equalize_prior': True, 
    'episodes': 1000, 
    'batchsize': 32, 
    'hidsize': [64, 64], 
    'lr': 0.0007, 
})
run(args)
# Out:
# Logging to logs/nn/19-08-28-19-57-12
# {'dataset': 'splice', 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'e0': 0.2, 'e1': 0.4, 'equalize_prior': True, 'episodes': 1000, 'batchsize': 32, 'hidsize': [64, 64], 'lr': 0.0007}
# ---------------------------------
# | [PEER] alpha = 0.1 | 0.62     |
# | [PEER] alpha = 0.2 | 0.628    |
# | [PEER] alpha = 0.3 | 0.631    |
# | [PEER] alpha = 0.4 | 0.633    |
# | [PEER] alpha = 0.5 | 0.642    |
# | [PEER] alpha = 0.6 | 0.656    |
# | [PEER] alpha = 0.7 | 0.661    |
# | [PEER] alpha = 0.8 | 0.663    |
# | [PEER] alpha = 0.9 | 0.666    |
# | [PEER] alpha = 1.0 | 0.665    |
# ---------------------------------
# --------------------------------------
# | [NN] with bce loss      | 0.714    |
# | [NN] with peer loss     | 0.898    |
# | [NN] with surrogate ... | 0.832    |
# | [PEER] best alpha       | 0.9      |
# --------------------------------------
# Logging to logs/svm/19-08-28-19-58-45
# {'dataset': 'splice', 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'e0': 0.2, 'e1': 0.4, 'equalize_prior': True, 'episodes': 1000, 'batchsize': 32, 'hidsize': [64, 64], 'lr': 0.0007}
# --------------------------------
# | [C-SVM] C1 = 0.1  | 0.599    |
# | [C-SVM] C1 = 0.2  | 0.599    |
# | [C-SVM] C1 = 0.25 | 0.599    |
# | [C-SVM] C1 = 0.33 | 0.6      |
# | [C-SVM] C1 = 0.5  | 0.603    |
# | [C-SVM] C1 = 1.0  | 0.658    |
# | [C-SVM] C1 = 10.0 | 0.646    |
# | [C-SVM] C1 = 2.0  | 0.654    |
# | [C-SVM] C1 = 3.0  | 0.646    |
# | [C-SVM] C1 = 4.0  | 0.645    |
# | [C-SVM] C1 = 5.0  | 0.646    |
# --------------------------------
# ------------------------------------
# | [C-SVM] accuracy max  | 0.847    |
# | [C-SVM] accuracy mean | 0.807    |
# | [C-SVM] accuracy min  | 0.778    |
# | [C-SVM] accuracy std  | 0.0246   |
# | [C-SVM] best C1       | 1        |
# ------------------------------------
# Logging to logs/pam/19-08-28-19-59-13
# {'dataset': 'splice', 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'e0': 0.2, 'e1': 0.4, 'equalize_prior': True, 'episodes': 1000, 'batchsize': 32, 'hidsize': [64, 64], 'lr': 0.0007}
# -----------------------------------
# | [PAM] margin = 0     | 0.596    |
# | [PAM] margin = 0.125 | 0.607    |
# | [PAM] margin = 0.25  | 0.627    |
# | [PAM] margin = 0.5   | 0.647    |
# | [PAM] margin = 1     | 0.643    |
# -----------------------------------
# ----------------------------------
# | [PAM] accuracy max  | 0.817    |
# | [PAM] accuracy mean | 0.778    |
# | [PAM] accuracy min  | 0.76     |
# | [PAM] accuracy std  | 0.0161   |
# | [PAM] best margin   | 0.5      |
# ----------------------------------

# %% [markdown]
# ### $e_0=0.4, e_1=0.4$

# %%
from run_nn import find_best_alpha
args = default_args.copy()
args.update({
    'dataset': 'splice', 
    'e0': 0.4, 'e1': 0.4, 
    'equalize_prior': True, 
    'episodes': 1000, 
    'batchsize': 64, 
    'hidsize': [64, 64], 
    'lr': 0.0007, 
#     'alpha': 1.
})
find_best_alpha(args)
# Out:
# ---------------------------------
# | [PEER] alpha = 0.1 | 0.655    |
# | [PEER] alpha = 0.2 | 0.661    |
# | [PEER] alpha = 0.3 | 0.66     |
# | [PEER] alpha = 0.4 | 0.668    |
# | [PEER] alpha = 0.5 | 0.689    |
# | [PEER] alpha = 0.6 | 0.693    |
# | [PEER] alpha = 0.7 | 0.721    |
# | [PEER] alpha = 0.8 | 0.758    |
# | [PEER] alpha = 0.9 | 0.806    |
# | [PEER] alpha = 1.0 | 0.829    |
# ---------------------------------
# {'alpha': 1.0}

# %%
from run_nn import find_best_alpha
args = default_args.copy()
args.update({
    'dataset': 'splice', 
    'e0': 0.4, 'e1': 0.4, 
    'equalize_prior': True, 
    'episodes': 1000, 
    'batchsize': 32, 
    'hidsize': [64, 64], 
    'lr': 0.0007, 
#     'alpha': 1.
})
find_best_alpha(args)
# Out:
# ---------------------------------
# | [PEER] alpha = 0.4 | 0.668    |
# | [PEER] alpha = 0.5 | 0.683    |
# | [PEER] alpha = 0.6 | 0.691    |
# | [PEER] alpha = 0.7 | 0.709    |
# | [PEER] alpha = 0.8 | 0.754    |
# | [PEER] alpha = 0.9 | 0.79     |
# | [PEER] alpha = 1.0 | 0.819    |
# | [PEER] alpha = 2.0 | 0.491    |
# | [PEER] alpha = 3.0 | 0.491    |
# | [PEER] alpha = 4.0 | 0.486    |
# | [PEER] alpha = 5.0 | 0.486    |
# ---------------------------------
# {'alpha': 1.0}

# %%
from runner import run
args = default_args.copy()
args.update({
    'dataset': 'splice', 
    'e0': 0.4, 'e1': 0.4, 
    'equalize_prior': True, 
    'episodes': 1000, 
    'batchsize': 64, 
    'hidsize': [64, 64], 
    'lr': 0.0007, 
})
run(args)
# Out:
# Logging to logs/nn/19-08-28-20-01-03
# {'dataset': 'splice', 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'e0': 0.4, 'e1': 0.4, 'equalize_prior': True, 'episodes': 1000, 'batchsize': 64, 'hidsize': [64, 64], 'lr': 0.0007}
# ---------------------------------
# | [PEER] alpha = 0.1 | 0.535    |
# | [PEER] alpha = 0.2 | 0.535    |
# | [PEER] alpha = 0.3 | 0.538    |
# | [PEER] alpha = 0.4 | 0.536    |
# | [PEER] alpha = 0.5 | 0.536    |
# | [PEER] alpha = 0.6 | 0.555    |
# | [PEER] alpha = 0.7 | 0.559    |
# | [PEER] alpha = 0.8 | 0.573    |
# | [PEER] alpha = 0.9 | 0.571    |
# | [PEER] alpha = 1.0 | 0.577    |
# ---------------------------------
# --------------------------------------
# | [NN] with bce loss      | 0.626    |
# | [NN] with peer loss     | 0.829    |
# | [NN] with surrogate ... | 0.754    |
# | [PEER] best alpha       | 1        |
# --------------------------------------
# Logging to logs/svm/19-08-28-20-02-47
# {'dataset': 'splice', 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'e0': 0.4, 'e1': 0.4, 'equalize_prior': True, 'episodes': 1000, 'batchsize': 64, 'hidsize': [64, 64], 'lr': 0.0007}
# --------------------------------
# | [C-SVM] C1 = 0.1  | 0.5      |
# | [C-SVM] C1 = 0.2  | 0.5      |
# | [C-SVM] C1 = 0.25 | 0.5      |
# | [C-SVM] C1 = 0.33 | 0.5      |
# | [C-SVM] C1 = 0.5  | 0.503    |
# | [C-SVM] C1 = 1.0  | 0.557    |
# | [C-SVM] C1 = 10.0 | 0.527    |
# | [C-SVM] C1 = 2.0  | 0.529    |
# | [C-SVM] C1 = 3.0  | 0.525    |
# | [C-SVM] C1 = 4.0  | 0.527    |
# | [C-SVM] C1 = 5.0  | 0.527    |
# --------------------------------
# ------------------------------------
# | [C-SVM] accuracy max  | 0.793    |
# | [C-SVM] accuracy mean | 0.767    |
# | [C-SVM] accuracy min  | 0.728    |
# | [C-SVM] accuracy std  | 0.0249   |
# | [C-SVM] best C1       | 1        |
# ------------------------------------
# Logging to logs/pam/19-08-28-20-03-17
# {'dataset': 'splice', 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'e0': 0.4, 'e1': 0.4, 'equalize_prior': True, 'episodes': 1000, 'batchsize': 64, 'hidsize': [64, 64], 'lr': 0.0007}
# -----------------------------------
# | [PAM] margin = 0     | 0.515    |
# | [PAM] margin = 0.125 | 0.522    |
# | [PAM] margin = 0.25  | 0.537    |
# | [PAM] margin = 0.5   | 0.543    |
# | [PAM] margin = 1     | 0.535    |
# -----------------------------------
# ----------------------------------
# | [PAM] accuracy max  | 0.745    |
# | [PAM] accuracy mean | 0.687    |
# | [PAM] accuracy min  | 0.656    |
# | [PAM] accuracy std  | 0.0256   |
# | [PAM] best margin   | 0.5      |
# ----------------------------------

# %%
from run_nn import find_best_alpha
args = default_args.copy()
args.update({
    'dataset': 'splice', 
    'e0': 0.4, 'e1': 0.4, 
    'equalize_prior': True, 
    'episodes': 1000, 
    'batchsize': 32, 
    'hidsize': [64, 64], 
    'lr': 0.0007, 
#     'alpha': 1.
})
find_best_alpha(args)
# Out:
# ---------------------------------
# | [PEER] alpha = 0.1 | 0.627    |
# | [PEER] alpha = 0.2 | 0.633    |
# | [PEER] alpha = 0.3 | 0.644    |
# | [PEER] alpha = 0.4 | 0.668    |
# | [PEER] alpha = 0.5 | 0.683    |
# | [PEER] alpha = 0.6 | 0.691    |
# | [PEER] alpha = 0.7 | 0.709    |
# | [PEER] alpha = 0.8 | 0.754    |
# | [PEER] alpha = 0.9 | 0.79     |
# | [PEER] alpha = 1.0 | 0.819    |
# ---------------------------------
# {'alpha': 1.0}

# %%
from runner import run
args = default_args.copy()
args.update({
    'dataset': 'splice', 
    'e0': 0.4, 'e1': 0.4, 
    'equalize_prior': True, 
    'episodes': 1000, 
    'batchsize': 32, 
    'hidsize': [64, 64], 
    'lr': 0.0007, 
})
run(args)
# Out:
# Logging to logs/nn/19-08-28-20-37-44
# {'dataset': 'splice', 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'e0': 0.4, 'e1': 0.4, 'equalize_prior': True, 'episodes': 1000, 'batchsize': 32, 'hidsize': [64, 64], 'lr': 0.0007}
# ---------------------------------
# | [PEER] alpha = 0.1 | 0.522    |
# | [PEER] alpha = 0.2 | 0.531    |
# | [PEER] alpha = 0.3 | 0.536    |
# | [PEER] alpha = 0.4 | 0.528    |
# | [PEER] alpha = 0.5 | 0.54     |
# | [PEER] alpha = 0.6 | 0.542    |
# | [PEER] alpha = 0.7 | 0.557    |
# | [PEER] alpha = 0.8 | 0.557    |
# | [PEER] alpha = 0.9 | 0.569    |
# | [PEER] alpha = 1.0 | 0.565    |
# ---------------------------------
# --------------------------------------
# | [NN] with bce loss      | 0.617    |
# | [NN] with peer loss     | 0.79     |
# | [NN] with surrogate ... | 0.752    |
# | [PEER] best alpha       | 0.9      |
# --------------------------------------
# Logging to logs/svm/19-08-28-20-39-08
# {'dataset': 'splice', 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'e0': 0.4, 'e1': 0.4, 'equalize_prior': True, 'episodes': 1000, 'batchsize': 32, 'hidsize': [64, 64], 'lr': 0.0007}
# --------------------------------
# | [C-SVM] C1 = 0.1  | 0.5      |
# | [C-SVM] C1 = 0.2  | 0.5      |
# | [C-SVM] C1 = 0.25 | 0.5      |
# | [C-SVM] C1 = 0.33 | 0.5      |
# | [C-SVM] C1 = 0.5  | 0.503    |
# | [C-SVM] C1 = 1.0  | 0.557    |
# | [C-SVM] C1 = 10.0 | 0.527    |
# | [C-SVM] C1 = 2.0  | 0.529    |
# | [C-SVM] C1 = 3.0  | 0.525    |
# | [C-SVM] C1 = 4.0  | 0.527    |
# | [C-SVM] C1 = 5.0  | 0.527    |
# --------------------------------
# ------------------------------------
# | [C-SVM] accuracy max  | 0.793    |
# | [C-SVM] accuracy mean | 0.767    |
# | [C-SVM] accuracy min  | 0.728    |
# | [C-SVM] accuracy std  | 0.0249   |
# | [C-SVM] best C1       | 1        |
# ------------------------------------
# Logging to logs/pam/19-08-28-20-39-39
# {'dataset': 'splice', 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'e0': 0.4, 'e1': 0.4, 'equalize_prior': True, 'episodes': 1000, 'batchsize': 32, 'hidsize': [64, 64], 'lr': 0.0007}
# -----------------------------------
# | [PAM] margin = 0     | 0.515    |
# | [PAM] margin = 0.125 | 0.522    |
# | [PAM] margin = 0.25  | 0.537    |
# | [PAM] margin = 0.5   | 0.543    |
# | [PAM] margin = 1     | 0.535    |
# -----------------------------------
# ----------------------------------
# | [PAM] accuracy max  | 0.745    |
# | [PAM] accuracy mean | 0.687    |
# | [PAM] accuracy min  | 0.656    |
# | [PAM] accuracy std  | 0.0256   |
# | [PAM] best margin   | 0.5      |
# ----------------------------------

# %% [markdown]
# ## Without Prior Equalization

# %% [markdown]
# ### $e_0 = 0.1, e_1 = 0.3$

# %%
from run_nn import find_best_alpha
args = default_args.copy()
args.update({
    'dataset': 'splice', 
    'e0': 0.1, 'e1': 0.3, 
    'equalize_prior': False, 
    'episodes': 1000, 
    'batchsize': 32, 
    'hidsize': [64, 64], 
    'lr': 0.0007, 
#     'alpha': 1.
})
find_best_alpha(args)
# Out:
# ---------------------------------
# | [PEER] alpha = 0.1 | 0.809    |
# | [PEER] alpha = 0.2 | 0.834    |
# | [PEER] alpha = 0.3 | 0.86     |
# | [PEER] alpha = 0.4 | 0.888    |
# | [PEER] alpha = 0.5 | 0.908    |
# | [PEER] alpha = 0.6 | 0.921    |
# | [PEER] alpha = 0.7 | 0.925    |
# | [PEER] alpha = 0.8 | 0.928    |
# | [PEER] alpha = 0.9 | 0.929    |
# | [PEER] alpha = 1.0 | 0.925    |
# ---------------------------------
# {'alpha': 0.9}

# %%
from run_nn import find_best_alpha
args = default_args.copy()
args.update({
    'dataset': 'splice', 
    'e0': 0.1, 'e1': 0.3, 
    'equalize_prior': False, 
    'episodes': 1000, 
    'batchsize': 32, 
    'hidsize': [64, 64], 
    'lr': 0.0007, 
#     'alpha': 1.
})
find_best_alpha(args)
# Out:
# ---------------------------------
# | [PEER] alpha = 0.4 | 0.888    |
# | [PEER] alpha = 0.5 | 0.908    |
# | [PEER] alpha = 0.6 | 0.921    |
# | [PEER] alpha = 0.7 | 0.925    |
# | [PEER] alpha = 0.8 | 0.928    |
# | [PEER] alpha = 0.9 | 0.929    |
# | [PEER] alpha = 1.0 | 0.925    |
# | [PEER] alpha = 2.0 | 0.534    |
# | [PEER] alpha = 3.0 | 0.481    |
# | [PEER] alpha = 4.0 | 0.481    |
# | [PEER] alpha = 5.0 | 0.481    |
# ---------------------------------
# {'alpha': 0.9}

# %%
from runner import run
args = default_args.copy()
args.update({
    'dataset': 'splice', 
    'e0': 0.1, 'e1': 0.3, 
    'equalize_prior': False, 
    'episodes': 1000, 
    'batchsize': 32, 
    'hidsize': [64, 64], 
    'lr': 0.0007, 
    'alpha': 1.0,
})
run(args)
# Out:
# Logging to logs/nn/19-08-28-19-20-06
# {'dataset': 'splice', 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'e0': 0.1, 'e1': 0.3, 'equalize_prior': False, 'episodes': 1000, 'batchsize': 32, 'hidsize': [64, 64], 'lr': 0.0007, 'alpha': 1.0}
# --------------------------------------
# | [NN] with bce loss      | 0.809    |
# | [NN] with peer loss     | 0.925    |
# | [NN] with surrogate ... | 0.885    |
# --------------------------------------
# Logging to logs/svm/19-08-28-19-20-27
# {'dataset': 'splice', 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'e0': 0.1, 'e1': 0.3, 'equalize_prior': False, 'episodes': 1000, 'batchsize': 32, 'hidsize': [64, 64], 'lr': 0.0007, 'alpha': 1.0}
# --------------------------------
# | [C-SVM] C1 = 0.1  | 0.614    |
# | [C-SVM] C1 = 0.2  | 0.614    |
# | [C-SVM] C1 = 0.25 | 0.614    |
# | [C-SVM] C1 = 0.33 | 0.617    |
# | [C-SVM] C1 = 0.5  | 0.659    |
# | [C-SVM] C1 = 1.0  | 0.771    |
# | [C-SVM] C1 = 10.0 | 0.766    |
# | [C-SVM] C1 = 2.0  | 0.771    |
# | [C-SVM] C1 = 3.0  | 0.765    |
# | [C-SVM] C1 = 4.0  | 0.766    |
# | [C-SVM] C1 = 5.0  | 0.766    |
# --------------------------------
# ------------------------------------
# | [C-SVM] accuracy max  | 0.95     |
# | [C-SVM] accuracy mean | 0.933    |
# | [C-SVM] accuracy min  | 0.912    |
# | [C-SVM] accuracy std  | 0.0126   |
# | [C-SVM] best C1       | 2        |
# ------------------------------------
# Logging to logs/pam/19-08-28-19-20-56
# {'dataset': 'splice', 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'e0': 0.1, 'e1': 0.3, 'equalize_prior': False, 'episodes': 1000, 'batchsize': 32, 'hidsize': [64, 64], 'lr': 0.0007, 'alpha': 1.0}
# -----------------------------------
# | [PAM] margin = 0     | 0.657    |
# | [PAM] margin = 0.125 | 0.712    |
# | [PAM] margin = 0.25  | 0.728    |
# | [PAM] margin = 0.5   | 0.744    |
# | [PAM] margin = 1     | 0.754    |
# -----------------------------------
# ----------------------------------
# | [PAM] accuracy max  | 0.889    |
# | [PAM] accuracy mean | 0.873    |
# | [PAM] accuracy min  | 0.857    |
# | [PAM] accuracy std  | 0.0115   |
# | [PAM] best margin   | 1        |
# ----------------------------------

# %%
from runner import run
args = default_args.copy()
args.update({
    'dataset': 'splice', 
    'e0': 0.1, 'e1': 0.3, 
    'equalize_prior': False, 
    'episodes': 1000, 
#     'batchsize': 4, 
#     'hidsize': [32, 32], 
#     'lr': 0.005, 
#     'alpha': 1.
})
run(args)
# Out:
# Logging to logs/nn/19-08-28-17-42-28
# {'dataset': 'splice', 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'e0': 0.1, 'e1': 0.3, 'equalize_prior': False, 'episodes': 1000}
# acc:0.822	batchsize: 1	lr:0.0007	hidsize:[8, 8]
# acc:0.819	batchsize: 1	lr:0.0007	hidsize:[16, 16]
# acc:0.853	batchsize: 1	lr:0.0007	hidsize:[32, 32]
# acc:0.834	batchsize: 1	lr:0.0007	hidsize:[64, 64]
# acc:0.843	batchsize: 1	lr: 0.001	hidsize:[8, 8]
# acc:0.833	batchsize: 1	lr: 0.001	hidsize:[16, 16]
# acc:0.847	batchsize: 1	lr: 0.001	hidsize:[32, 32]
# acc:0.831	batchsize: 1	lr: 0.001	hidsize:[64, 64]
# acc:0.818	batchsize: 1	lr: 0.005	hidsize:[8, 8]
# acc:0.829	batchsize: 1	lr: 0.005	hidsize:[16, 16]
# acc:0.829	batchsize: 1	lr: 0.005	hidsize:[32, 32]
# acc:0.819	batchsize: 1	lr: 0.005	hidsize:[64, 64]
# acc:0.807	batchsize: 1	lr:  0.01	hidsize:[8, 8]
# acc:0.784	batchsize: 1	lr:  0.01	hidsize:[16, 16]
# acc:0.788	batchsize: 1	lr:  0.01	hidsize:[32, 32]
# acc:0.777	batchsize: 1	lr:  0.01	hidsize:[64, 64]
# acc:0.58	batchsize: 1	lr:  0.05	hidsize:[8, 8]
# acc:0.729	batchsize: 1	lr:  0.05	hidsize:[16, 16]
# acc:0.762	batchsize: 1	lr:  0.05	hidsize:[32, 32]
# acc: 0.8	batchsize: 1	lr:  0.05	hidsize:[64, 64]
# acc:0.897	batchsize: 4	lr:0.0007	hidsize:[8, 8]
# acc:0.891	batchsize: 4	lr:0.0007	hidsize:[16, 16]
# acc:0.912	batchsize: 4	lr:0.0007	hidsize:[32, 32]
# acc:0.912	batchsize: 4	lr:0.0007	hidsize:[64, 64]
# acc:0.903	batchsize: 4	lr: 0.001	hidsize:[8, 8]
# acc:0.899	batchsize: 4	lr: 0.001	hidsize:[16, 16]
# acc:0.91	batchsize: 4	lr: 0.001	hidsize:[32, 32]
# acc:0.912	batchsize: 4	lr: 0.001	hidsize:[64, 64]
# acc:0.907	batchsize: 4	lr: 0.005	hidsize:[8, 8]
# acc: 0.9	batchsize: 4	lr: 0.005	hidsize:[16, 16]
# acc:0.908	batchsize: 4	lr: 0.005	hidsize:[32, 32]
# acc:0.909	batchsize: 4	lr: 0.005	hidsize:[64, 64]
# acc:0.901	batchsize: 4	lr:  0.01	hidsize:[8, 8]
# acc:0.906	batchsize: 4	lr:  0.01	hidsize:[16, 16]
# acc:0.912	batchsize: 4	lr:  0.01	hidsize:[32, 32]
# acc:0.91	batchsize: 4	lr:  0.01	hidsize:[64, 64]
# acc:0.791	batchsize: 4	lr:  0.05	hidsize:[8, 8]
# acc:0.895	batchsize: 4	lr:  0.05	hidsize:[16, 16]
# acc:0.885	batchsize: 4	lr:  0.05	hidsize:[32, 32]
# acc:0.888	batchsize: 4	lr:  0.05	hidsize:[64, 64]
# acc:0.917	batchsize:16	lr:0.0007	hidsize:[8, 8]
# acc:0.914	batchsize:16	lr:0.0007	hidsize:[16, 16]
# acc:0.923	batchsize:16	lr:0.0007	hidsize:[32, 32]
# acc:0.925	batchsize:16	lr:0.0007	hidsize:[64, 64]
# acc:0.919	batchsize:16	lr: 0.001	hidsize:[8, 8]
# acc:0.916	batchsize:16	lr: 0.001	hidsize:[16, 16]
# acc:0.923	batchsize:16	lr: 0.001	hidsize:[32, 32]
# acc:0.923	batchsize:16	lr: 0.001	hidsize:[64, 64]
# acc:0.917	batchsize:16	lr: 0.005	hidsize:[8, 8]
# acc:0.916	batchsize:16	lr: 0.005	hidsize:[16, 16]
# acc:0.92	batchsize:16	lr: 0.005	hidsize:[32, 32]
# acc:0.922	batchsize:16	lr: 0.005	hidsize:[64, 64]
# acc:0.916	batchsize:16	lr:  0.01	hidsize:[8, 8]
# acc:0.921	batchsize:16	lr:  0.01	hidsize:[16, 16]
# acc:0.919	batchsize:16	lr:  0.01	hidsize:[32, 32]
# acc:0.919	batchsize:16	lr:  0.01	hidsize:[64, 64]
# acc:0.919	batchsize:16	lr:  0.05	hidsize:[8, 8]
# acc:0.904	batchsize:16	lr:  0.05	hidsize:[16, 16]
# acc:0.917	batchsize:16	lr:  0.05	hidsize:[32, 32]
# acc:0.918	batchsize:16	lr:  0.05	hidsize:[64, 64]
# acc:0.922	batchsize:32	lr:0.0007	hidsize:[8, 8]
# acc:0.917	batchsize:32	lr:0.0007	hidsize:[16, 16]
# acc:0.923	batchsize:32	lr:0.0007	hidsize:[32, 32]
# acc:0.925	batchsize:32	lr:0.0007	hidsize:[64, 64]
# acc:0.922	batchsize:32	lr: 0.001	hidsize:[8, 8]
# acc:0.916	batchsize:32	lr: 0.001	hidsize:[16, 16]
# acc:0.922	batchsize:32	lr: 0.001	hidsize:[32, 32]
# acc:0.922	batchsize:32	lr: 0.001	hidsize:[64, 64]
# acc:0.921	batchsize:32	lr: 0.005	hidsize:[8, 8]
# acc:0.919	batchsize:32	lr: 0.005	hidsize:[16, 16]
# acc:0.922	batchsize:32	lr: 0.005	hidsize:[32, 32]
# acc:0.919	batchsize:32	lr: 0.005	hidsize:[64, 64]
# acc:0.921	batchsize:32	lr:  0.01	hidsize:[8, 8]
# acc:0.919	batchsize:32	lr:  0.01	hidsize:[16, 16]
# acc:0.921	batchsize:32	lr:  0.01	hidsize:[32, 32]
# acc:0.916	batchsize:32	lr:  0.01	hidsize:[64, 64]
# acc:0.913	batchsize:32	lr:  0.05	hidsize:[8, 8]
# acc:0.922	batchsize:32	lr:  0.05	hidsize:[16, 16]
# acc:0.916	batchsize:32	lr:  0.05	hidsize:[32, 32]
# acc:0.917	batchsize:32	lr:  0.05	hidsize:[64, 64]
# acc:0.92	batchsize:64	lr:0.0007	hidsize:[8, 8]
# acc:0.913	batchsize:64	lr:0.0007	hidsize:[16, 16]
# acc:0.916	batchsize:64	lr:0.0007	hidsize:[32, 32]
# acc:0.919	batchsize:64	lr:0.0007	hidsize:[64, 64]
# acc:0.917	batchsize:64	lr: 0.001	hidsize:[8, 8]
# acc:0.914	batchsize:64	lr: 0.001	hidsize:[16, 16]
# acc:0.916	batchsize:64	lr: 0.001	hidsize:[32, 32]
# acc:0.918	batchsize:64	lr: 0.001	hidsize:[64, 64]
# acc:0.917	batchsize:64	lr: 0.005	hidsize:[8, 8]
# acc:0.913	batchsize:64	lr: 0.005	hidsize:[16, 16]
# acc:0.916	batchsize:64	lr: 0.005	hidsize:[32, 32]
# acc:0.916	batchsize:64	lr: 0.005	hidsize:[64, 64]
# acc:0.916	batchsize:64	lr:  0.01	hidsize:[8, 8]
# acc:0.913	batchsize:64	lr:  0.01	hidsize:[16, 16]
# acc:0.914	batchsize:64	lr:  0.01	hidsize:[32, 32]
# acc:0.914	batchsize:64	lr:  0.01	hidsize:[64, 64]
# acc:0.91	batchsize:64	lr:  0.05	hidsize:[8, 8]
# acc:0.916	batchsize:64	lr:  0.05	hidsize:[16, 16]
# acc:0.913	batchsize:64	lr:  0.05	hidsize:[32, 32]
# acc:0.912	batchsize:64	lr:  0.05	hidsize:[64, 64]
# --------------------------------------
# | [PEER] best batchsize   | 32       |
# | [PEER] best hidsize     | [64, 64] |
# | [PEER] best learning... | 0.0007   |
# --------------------------------------
# ---------------------------------
# | [PEER] alpha = 0.1 | 0.722    |
# | [PEER] alpha = 0.2 | 0.737    |
# | [PEER] alpha = 0.3 | 0.749    |
# | [PEER] alpha = 0.4 | 0.757    |
# | [PEER] alpha = 0.5 | 0.768    |
# | [PEER] alpha = 0.6 | 0.768    |
# | [PEER] alpha = 0.7 | 0.768    |
# | [PEER] alpha = 0.8 | 0.764    |
# | [PEER] alpha = 0.9 | 0.758    |
# | [PEER] alpha = 1.0 | 0.758    |
# ---------------------------------
# --------------------------------------
# | [NN] with bce loss      | 0.809    |
# | [NN] with peer loss     | 0.908    |
# | [NN] with surrogate ... | 0.885    |
# | [PEER] best alpha       | 0.5      |
# --------------------------------------
# Logging to logs/svm/19-08-28-17-53-44
# {'dataset': 'splice', 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'e0': 0.1, 'e1': 0.3, 'equalize_prior': False, 'episodes': 1000}
# --------------------------------
# | [C-SVM] C1 = 0.1  | 0.614    |
# | [C-SVM] C1 = 0.2  | 0.614    |
# | [C-SVM] C1 = 0.25 | 0.614    |
# | [C-SVM] C1 = 0.33 | 0.617    |
# | [C-SVM] C1 = 0.5  | 0.659    |
# | [C-SVM] C1 = 1.0  | 0.771    |
# | [C-SVM] C1 = 10.0 | 0.766    |
# | [C-SVM] C1 = 2.0  | 0.771    |
# | [C-SVM] C1 = 3.0  | 0.765    |
# | [C-SVM] C1 = 4.0  | 0.766    |
# | [C-SVM] C1 = 5.0  | 0.766    |
# --------------------------------
# ------------------------------------
# | [C-SVM] accuracy max  | 0.95     |
# | [C-SVM] accuracy mean | 0.933    |
# | [C-SVM] accuracy min  | 0.912    |
# | [C-SVM] accuracy std  | 0.0126   |
# | [C-SVM] best C1       | 2        |
# ------------------------------------
# Logging to logs/pam/19-08-28-17-54-11
# {'dataset': 'splice', 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'e0': 0.1, 'e1': 0.3, 'equalize_prior': False, 'episodes': 1000}
# -----------------------------------
# | [PAM] margin = 0     | 0.657    |
# | [PAM] margin = 0.125 | 0.712    |
# | [PAM] margin = 0.25  | 0.728    |
# | [PAM] margin = 0.5   | 0.744    |
# | [PAM] margin = 1     | 0.754    |
# -----------------------------------
# ----------------------------------
# | [PAM] accuracy max  | 0.889    |
# | [PAM] accuracy mean | 0.873    |
# | [PAM] accuracy min  | 0.857    |
# | [PAM] accuracy std  | 0.0115   |
# | [PAM] best margin   | 1        |
# ----------------------------------

# %% [markdown]
# ### $e_0 = 0.2, e_1 = 0.2$

# %%
from run_nn import find_best_alpha
args = default_args.copy()
args.update({
    'dataset': 'splice', 
    'e0': 0.2, 'e1': 0.2, 
    'equalize_prior': False, 
    'episodes': 1000, 
    'batchsize': 32, 
    'hidsize': [64, 64], 
    'lr': 0.0007, 
#     'alpha': 1.
})
find_best_alpha(args)
# Out:
# ---------------------------------
# | [PEER] alpha = 0.1 | 0.837    |
# | [PEER] alpha = 0.2 | 0.848    |
# | [PEER] alpha = 0.3 | 0.863    |
# | [PEER] alpha = 0.4 | 0.883    |
# | [PEER] alpha = 0.5 | 0.901    |
# | [PEER] alpha = 0.6 | 0.914    |
# | [PEER] alpha = 0.7 | 0.924    |
# | [PEER] alpha = 0.8 | 0.927    |
# | [PEER] alpha = 0.9 | 0.927    |
# | [PEER] alpha = 1.0 | 0.926    |
# ---------------------------------
# {'alpha': 0.9}

# %%
from run_nn import find_best_alpha
args = default_args.copy()
args.update({
    'dataset': 'splice', 
    'e0': 0.2, 'e1': 0.2, 
    'equalize_prior': False, 
    'episodes': 1000, 
    'batchsize': 32, 
    'hidsize': [64, 64], 
    'lr': 0.0007, 
#     'alpha': 1.
})
find_best_alpha(args)
# Out:
# ---------------------------------
# | [PEER] alpha = 0.4 | 0.883    |
# | [PEER] alpha = 0.5 | 0.901    |
# | [PEER] alpha = 0.6 | 0.914    |
# | [PEER] alpha = 0.7 | 0.924    |
# | [PEER] alpha = 0.8 | 0.927    |
# | [PEER] alpha = 0.9 | 0.927    |
# | [PEER] alpha = 1.0 | 0.926    |
# | [PEER] alpha = 2.0 | 0.703    |
# | [PEER] alpha = 3.0 | 0.56     |
# | [PEER] alpha = 4.0 | 0.559    |
# | [PEER] alpha = 5.0 | 0.559    |
# ---------------------------------
# {'alpha': 0.9}

# %%
from runner import run
args = default_args.copy()
args.update({
    'dataset': 'splice', 
    'e0': 0.2, 'e1': 0.2, 
    'equalize_prior': False, 
    'episodes': 1000, 
#     'batchsize': 4, 
#     'hidsize': [32, 32], 
#     'lr': 0.005, 
#     'alpha': 1.
})
run(args)
# Out:
# Logging to logs/nn/19-08-28-17-54-39
# {'dataset': 'splice', 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'e0': 0.2, 'e1': 0.2, 'equalize_prior': False, 'episodes': 1000}
# acc:0.781	batchsize: 1	lr:0.0007	hidsize:[8, 8]
# acc:0.817	batchsize: 1	lr:0.0007	hidsize:[16, 16]
# acc:0.853	batchsize: 1	lr:0.0007	hidsize:[32, 32]
# acc:0.834	batchsize: 1	lr:0.0007	hidsize:[64, 64]
# acc:0.825	batchsize: 1	lr: 0.001	hidsize:[8, 8]
# acc:0.833	batchsize: 1	lr: 0.001	hidsize:[16, 16]
# acc:0.84	batchsize: 1	lr: 0.001	hidsize:[32, 32]
# acc:0.824	batchsize: 1	lr: 0.001	hidsize:[64, 64]
# acc:0.796	batchsize: 1	lr: 0.005	hidsize:[8, 8]
# acc:0.801	batchsize: 1	lr: 0.005	hidsize:[16, 16]
# acc:0.826	batchsize: 1	lr: 0.005	hidsize:[32, 32]
# acc:0.812	batchsize: 1	lr: 0.005	hidsize:[64, 64]
# acc:0.794	batchsize: 1	lr:  0.01	hidsize:[8, 8]
# acc:0.802	batchsize: 1	lr:  0.01	hidsize:[16, 16]
# acc:0.808	batchsize: 1	lr:  0.01	hidsize:[32, 32]
# acc:0.806	batchsize: 1	lr:  0.01	hidsize:[64, 64]
# acc:0.65	batchsize: 1	lr:  0.05	hidsize:[8, 8]
# acc:0.691	batchsize: 1	lr:  0.05	hidsize:[16, 16]
# acc:0.776	batchsize: 1	lr:  0.05	hidsize:[32, 32]
# acc:0.776	batchsize: 1	lr:  0.05	hidsize:[64, 64]
# acc:0.886	batchsize: 4	lr:0.0007	hidsize:[8, 8]
# acc:0.886	batchsize: 4	lr:0.0007	hidsize:[16, 16]
# acc:0.903	batchsize: 4	lr:0.0007	hidsize:[32, 32]
# acc:0.903	batchsize: 4	lr:0.0007	hidsize:[64, 64]
# acc:0.89	batchsize: 4	lr: 0.001	hidsize:[8, 8]
# acc:0.887	batchsize: 4	lr: 0.001	hidsize:[16, 16]
# acc:0.903	batchsize: 4	lr: 0.001	hidsize:[32, 32]
# acc:0.907	batchsize: 4	lr: 0.001	hidsize:[64, 64]
# acc:0.899	batchsize: 4	lr: 0.005	hidsize:[8, 8]
# acc:0.889	batchsize: 4	lr: 0.005	hidsize:[16, 16]
# acc:0.898	batchsize: 4	lr: 0.005	hidsize:[32, 32]
# acc:0.898	batchsize: 4	lr: 0.005	hidsize:[64, 64]
# acc:0.899	batchsize: 4	lr:  0.01	hidsize:[8, 8]
# acc:0.89	batchsize: 4	lr:  0.01	hidsize:[16, 16]
# acc:0.891	batchsize: 4	lr:  0.01	hidsize:[32, 32]
# acc:0.892	batchsize: 4	lr:  0.01	hidsize:[64, 64]
# acc:0.881	batchsize: 4	lr:  0.05	hidsize:[8, 8]
# acc:0.877	batchsize: 4	lr:  0.05	hidsize:[16, 16]
# acc:0.877	batchsize: 4	lr:  0.05	hidsize:[32, 32]
# acc:0.866	batchsize: 4	lr:  0.05	hidsize:[64, 64]
# acc:0.909	batchsize:16	lr:0.0007	hidsize:[8, 8]
# acc:0.911	batchsize:16	lr:0.0007	hidsize:[16, 16]
# acc:0.921	batchsize:16	lr:0.0007	hidsize:[32, 32]
# acc:0.923	batchsize:16	lr:0.0007	hidsize:[64, 64]
# acc:0.913	batchsize:16	lr: 0.001	hidsize:[8, 8]
# acc:0.914	batchsize:16	lr: 0.001	hidsize:[16, 16]
# acc:0.92	batchsize:16	lr: 0.001	hidsize:[32, 32]
# acc:0.92	batchsize:16	lr: 0.001	hidsize:[64, 64]
# acc:0.913	batchsize:16	lr: 0.005	hidsize:[8, 8]
# acc:0.914	batchsize:16	lr: 0.005	hidsize:[16, 16]
# acc:0.916	batchsize:16	lr: 0.005	hidsize:[32, 32]
# acc:0.917	batchsize:16	lr: 0.005	hidsize:[64, 64]
# acc:0.911	batchsize:16	lr:  0.01	hidsize:[8, 8]
# acc:0.916	batchsize:16	lr:  0.01	hidsize:[16, 16]
# acc:0.918	batchsize:16	lr:  0.01	hidsize:[32, 32]
# acc:0.915	batchsize:16	lr:  0.01	hidsize:[64, 64]
# acc:0.911	batchsize:16	lr:  0.05	hidsize:[8, 8]
# acc:0.911	batchsize:16	lr:  0.05	hidsize:[16, 16]
# acc:0.909	batchsize:16	lr:  0.05	hidsize:[32, 32]
# acc:0.915	batchsize:16	lr:  0.05	hidsize:[64, 64]
# acc:0.92	batchsize:32	lr:0.0007	hidsize:[8, 8]
# acc:0.917	batchsize:32	lr:0.0007	hidsize:[16, 16]
# acc:0.924	batchsize:32	lr:0.0007	hidsize:[32, 32]
# acc:0.926	batchsize:32	lr:0.0007	hidsize:[64, 64]
# acc:0.917	batchsize:32	lr: 0.001	hidsize:[8, 8]
# acc:0.916	batchsize:32	lr: 0.001	hidsize:[16, 16]
# acc:0.925	batchsize:32	lr: 0.001	hidsize:[32, 32]
# acc:0.925	batchsize:32	lr: 0.001	hidsize:[64, 64]
# acc:0.917	batchsize:32	lr: 0.005	hidsize:[8, 8]
# acc:0.919	batchsize:32	lr: 0.005	hidsize:[16, 16]
# acc:0.922	batchsize:32	lr: 0.005	hidsize:[32, 32]
# acc:0.92	batchsize:32	lr: 0.005	hidsize:[64, 64]
# acc:0.919	batchsize:32	lr:  0.01	hidsize:[8, 8]
# acc:0.919	batchsize:32	lr:  0.01	hidsize:[16, 16]
# acc:0.92	batchsize:32	lr:  0.01	hidsize:[32, 32]
# acc:0.917	batchsize:32	lr:  0.01	hidsize:[64, 64]
# acc:0.91	batchsize:32	lr:  0.05	hidsize:[8, 8]
# acc:0.92	batchsize:32	lr:  0.05	hidsize:[16, 16]
# acc:0.918	batchsize:32	lr:  0.05	hidsize:[32, 32]
# acc:0.916	batchsize:32	lr:  0.05	hidsize:[64, 64]
# acc:0.918	batchsize:64	lr:0.0007	hidsize:[8, 8]
# acc:0.913	batchsize:64	lr:0.0007	hidsize:[16, 16]
# acc:0.918	batchsize:64	lr:0.0007	hidsize:[32, 32]
# acc:0.917	batchsize:64	lr:0.0007	hidsize:[64, 64]
# acc:0.919	batchsize:64	lr: 0.001	hidsize:[8, 8]
# acc:0.915	batchsize:64	lr: 0.001	hidsize:[16, 16]
# acc:0.918	batchsize:64	lr: 0.001	hidsize:[32, 32]
# acc:0.918	batchsize:64	lr: 0.001	hidsize:[64, 64]
# acc:0.917	batchsize:64	lr: 0.005	hidsize:[8, 8]
# acc:0.918	batchsize:64	lr: 0.005	hidsize:[16, 16]
# acc:0.92	batchsize:64	lr: 0.005	hidsize:[32, 32]
# acc:0.916	batchsize:64	lr: 0.005	hidsize:[64, 64]
# acc:0.92	batchsize:64	lr:  0.01	hidsize:[8, 8]
# acc:0.917	batchsize:64	lr:  0.01	hidsize:[16, 16]
# acc:0.919	batchsize:64	lr:  0.01	hidsize:[32, 32]
# acc:0.916	batchsize:64	lr:  0.01	hidsize:[64, 64]
# acc:0.863	batchsize:64	lr:  0.05	hidsize:[8, 8]
# acc:0.92	batchsize:64	lr:  0.05	hidsize:[16, 16]
# acc:0.912	batchsize:64	lr:  0.05	hidsize:[32, 32]
# acc:0.917	batchsize:64	lr:  0.05	hidsize:[64, 64]
# --------------------------------------
# | [PEER] best batchsize   | 32       |
# | [PEER] best hidsize     | [64, 64] |
# | [PEER] best learning... | 0.0007   |
# --------------------------------------
# ---------------------------------
# | [PEER] alpha = 0.1 | 0.71     |
# | [PEER] alpha = 0.2 | 0.716    |
# | [PEER] alpha = 0.3 | 0.721    |
# | [PEER] alpha = 0.4 | 0.722    |
# | [PEER] alpha = 0.5 | 0.738    |
# | [PEER] alpha = 0.6 | 0.746    |
# | [PEER] alpha = 0.7 | 0.748    |
# | [PEER] alpha = 0.8 | 0.752    |
# | [PEER] alpha = 0.9 | 0.755    |
# | [PEER] alpha = 1.0 | 0.754    |
# ---------------------------------
# --------------------------------------
# | [NN] with bce loss      | 0.812    |
# | [NN] with peer loss     | 0.927    |
# | [NN] with surrogate ... | 0.876    |
# | [PEER] best alpha       | 0.9      |
# --------------------------------------
# Logging to logs/svm/19-08-28-18-04-53
# {'dataset': 'splice', 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'e0': 0.2, 'e1': 0.2, 'equalize_prior': False, 'episodes': 1000}
# --------------------------------
# | [C-SVM] C1 = 0.1  | 0.513    |
# | [C-SVM] C1 = 0.2  | 0.514    |
# | [C-SVM] C1 = 0.25 | 0.519    |
# | [C-SVM] C1 = 0.33 | 0.579    |
# | [C-SVM] C1 = 0.5  | 0.742    |
# | [C-SVM] C1 = 1.0  | 0.766    |
# | [C-SVM] C1 = 10.0 | 0.728    |
# | [C-SVM] C1 = 2.0  | 0.735    |
# | [C-SVM] C1 = 3.0  | 0.728    |
# | [C-SVM] C1 = 4.0  | 0.728    |
# | [C-SVM] C1 = 5.0  | 0.728    |
# --------------------------------
# ------------------------------------
# | [C-SVM] accuracy max  | 0.962    |
# | [C-SVM] accuracy mean | 0.941    |
# | [C-SVM] accuracy min  | 0.929    |
# | [C-SVM] accuracy std  | 0.00976  |
# | [C-SVM] best C1       | 1        |
# ------------------------------------
# Logging to logs/pam/19-08-28-18-05-21
# {'dataset': 'splice', 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'e0': 0.2, 'e1': 0.2, 'equalize_prior': False, 'episodes': 1000}
# -----------------------------------
# | [PAM] margin = 0     | 0.634    |
# | [PAM] margin = 0.125 | 0.687    |
# | [PAM] margin = 0.25  | 0.708    |
# | [PAM] margin = 0.5   | 0.728    |
# | [PAM] margin = 1     | 0.738    |
# -----------------------------------
# ----------------------------------
# | [PAM] accuracy max  | 0.931    |
# | [PAM] accuracy mean | 0.91     |
# | [PAM] accuracy min  | 0.876    |
# | [PAM] accuracy std  | 0.0178   |
# | [PAM] best margin   | 1        |
# ----------------------------------

# %% [markdown]
# ### $e_0 = 0.1, e_1 = 0.4$

# %%
from run_nn import find_best_alpha
args = default_args.copy()
args.update({
    'dataset': 'splice', 
    'e0': 0.1, 'e1': 0.4, 
    'equalize_prior': False, 
    'episodes': 1000, 
    'batchsize': 32, 
    'hidsize': [64, 64], 
    'lr': 0.0007, 
#     'alpha': 1.
})
find_best_alpha(args)
# Out:
# ---------------------------------
# | [PEER] alpha = 0.1 | 0.751    |
# | [PEER] alpha = 0.2 | 0.786    |
# | [PEER] alpha = 0.3 | 0.812    |
# | [PEER] alpha = 0.4 | 0.843    |
# | [PEER] alpha = 0.5 | 0.866    |
# | [PEER] alpha = 0.6 | 0.882    |
# | [PEER] alpha = 0.7 | 0.904    |
# | [PEER] alpha = 0.8 | 0.915    |
# | [PEER] alpha = 0.9 | 0.922    |
# | [PEER] alpha = 1.0 | 0.925    |
# ---------------------------------
# {'alpha': 1.0}

# %%
from run_nn import find_best_alpha
args = default_args.copy()
args.update({
    'dataset': 'splice', 
    'e0': 0.1, 'e1': 0.4, 
    'equalize_prior': False, 
    'episodes': 1000, 
    'batchsize': 32, 
    'hidsize': [64, 64], 
    'lr': 0.0007, 
#     'alpha': 1.
})
find_best_alpha(args)
# Out:
# ---------------------------------
# | [PEER] alpha = 0.4 | 0.843    |
# | [PEER] alpha = 0.5 | 0.866    |
# | [PEER] alpha = 0.6 | 0.882    |
# | [PEER] alpha = 0.7 | 0.904    |
# | [PEER] alpha = 0.8 | 0.915    |
# | [PEER] alpha = 0.9 | 0.922    |
# | [PEER] alpha = 1.0 | 0.925    |
# | [PEER] alpha = 2.0 | 0.481    |
# | [PEER] alpha = 3.0 | 0.481    |
# | [PEER] alpha = 4.0 | 0.481    |
# | [PEER] alpha = 5.0 | 0.481    |
# ---------------------------------
# {'alpha': 1.0}

# %%
from runner import run
args = default_args.copy()
args.update({
    'dataset': 'splice', 
    'e0': 0.1, 'e1': 0.4, 
    'equalize_prior': False, 
    'episodes': 1000, 
#     'batchsize': 4, 
#     'hidsize': [32, 32], 
#     'lr': 0.005, 
#     'alpha': 1.
})
run(args)
# Out:
# Logging to logs/nn/19-08-28-18-29-32
# {'dataset': 'splice', 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'e0': 0.1, 'e1': 0.4, 'equalize_prior': False, 'episodes': 1000}
# acc:0.772	batchsize: 1	lr:0.0007	hidsize:[8, 8]
# acc:0.801	batchsize: 1	lr:0.0007	hidsize:[16, 16]
# acc:0.838	batchsize: 1	lr:0.0007	hidsize:[32, 32]
# acc:0.814	batchsize: 1	lr:0.0007	hidsize:[64, 64]
# acc:0.802	batchsize: 1	lr: 0.001	hidsize:[8, 8]
# acc:0.814	batchsize: 1	lr: 0.001	hidsize:[16, 16]
# acc:0.83	batchsize: 1	lr: 0.001	hidsize:[32, 32]
# acc:0.81	batchsize: 1	lr: 0.001	hidsize:[64, 64]
# acc:0.801	batchsize: 1	lr: 0.005	hidsize:[8, 8]
# acc:0.794	batchsize: 1	lr: 0.005	hidsize:[16, 16]
# acc:0.806	batchsize: 1	lr: 0.005	hidsize:[32, 32]
# acc:0.763	batchsize: 1	lr: 0.005	hidsize:[64, 64]
# acc:0.744	batchsize: 1	lr:  0.01	hidsize:[8, 8]
# acc:0.773	batchsize: 1	lr:  0.01	hidsize:[16, 16]
# acc:0.783	batchsize: 1	lr:  0.01	hidsize:[32, 32]
# acc:0.762	batchsize: 1	lr:  0.01	hidsize:[64, 64]
# acc:0.616	batchsize: 1	lr:  0.05	hidsize:[8, 8]
# acc:0.745	batchsize: 1	lr:  0.05	hidsize:[16, 16]
# acc:0.681	batchsize: 1	lr:  0.05	hidsize:[32, 32]
# acc:0.698	batchsize: 1	lr:  0.05	hidsize:[64, 64]
# acc:0.87	batchsize: 4	lr:0.0007	hidsize:[8, 8]
# acc:0.868	batchsize: 4	lr:0.0007	hidsize:[16, 16]
# acc:0.889	batchsize: 4	lr:0.0007	hidsize:[32, 32]
# acc:0.895	batchsize: 4	lr:0.0007	hidsize:[64, 64]
# acc:0.884	batchsize: 4	lr: 0.001	hidsize:[8, 8]
# acc:0.88	batchsize: 4	lr: 0.001	hidsize:[16, 16]
# acc:0.895	batchsize: 4	lr: 0.001	hidsize:[32, 32]
# acc:0.904	batchsize: 4	lr: 0.001	hidsize:[64, 64]
# acc:0.888	batchsize: 4	lr: 0.005	hidsize:[8, 8]
# acc:0.891	batchsize: 4	lr: 0.005	hidsize:[16, 16]
# acc:0.901	batchsize: 4	lr: 0.005	hidsize:[32, 32]
# acc:0.895	batchsize: 4	lr: 0.005	hidsize:[64, 64]
# acc:0.888	batchsize: 4	lr:  0.01	hidsize:[8, 8]
# acc:0.883	batchsize: 4	lr:  0.01	hidsize:[16, 16]
# acc:0.898	batchsize: 4	lr:  0.01	hidsize:[32, 32]
# acc:0.881	batchsize: 4	lr:  0.01	hidsize:[64, 64]
# acc:0.789	batchsize: 4	lr:  0.05	hidsize:[8, 8]
# acc:0.865	batchsize: 4	lr:  0.05	hidsize:[16, 16]
# acc:0.865	batchsize: 4	lr:  0.05	hidsize:[32, 32]
# acc:0.849	batchsize: 4	lr:  0.05	hidsize:[64, 64]
# acc:0.907	batchsize:16	lr:0.0007	hidsize:[8, 8]
# acc:0.907	batchsize:16	lr:0.0007	hidsize:[16, 16]
# acc:0.918	batchsize:16	lr:0.0007	hidsize:[32, 32]
# acc:0.917	batchsize:16	lr:0.0007	hidsize:[64, 64]
# acc:0.911	batchsize:16	lr: 0.001	hidsize:[8, 8]
# acc:0.91	batchsize:16	lr: 0.001	hidsize:[16, 16]
# acc:0.917	batchsize:16	lr: 0.001	hidsize:[32, 32]
# acc:0.919	batchsize:16	lr: 0.001	hidsize:[64, 64]
# acc:0.917	batchsize:16	lr: 0.005	hidsize:[8, 8]
# acc:0.91	batchsize:16	lr: 0.005	hidsize:[16, 16]
# acc:0.913	batchsize:16	lr: 0.005	hidsize:[32, 32]
# acc:0.914	batchsize:16	lr: 0.005	hidsize:[64, 64]
# acc:0.909	batchsize:16	lr:  0.01	hidsize:[8, 8]
# acc:0.912	batchsize:16	lr:  0.01	hidsize:[16, 16]
# acc:0.916	batchsize:16	lr:  0.01	hidsize:[32, 32]
# acc:0.913	batchsize:16	lr:  0.01	hidsize:[64, 64]
# acc:0.893	batchsize:16	lr:  0.05	hidsize:[8, 8]
# acc:0.909	batchsize:16	lr:  0.05	hidsize:[16, 16]
# acc:0.911	batchsize:16	lr:  0.05	hidsize:[32, 32]
# acc:0.905	batchsize:16	lr:  0.05	hidsize:[64, 64]
# acc:0.915	batchsize:32	lr:0.0007	hidsize:[8, 8]
# acc:0.914	batchsize:32	lr:0.0007	hidsize:[16, 16]
# acc:0.922	batchsize:32	lr:0.0007	hidsize:[32, 32]
# acc:0.925	batchsize:32	lr:0.0007	hidsize:[64, 64]
# acc:0.916	batchsize:32	lr: 0.001	hidsize:[8, 8]
# acc:0.915	batchsize:32	lr: 0.001	hidsize:[16, 16]
# acc:0.923	batchsize:32	lr: 0.001	hidsize:[32, 32]
# acc:0.922	batchsize:32	lr: 0.001	hidsize:[64, 64]
# acc:0.914	batchsize:32	lr: 0.005	hidsize:[8, 8]
# acc:0.913	batchsize:32	lr: 0.005	hidsize:[16, 16]
# acc:0.918	batchsize:32	lr: 0.005	hidsize:[32, 32]
# acc:0.916	batchsize:32	lr: 0.005	hidsize:[64, 64]
# acc:0.915	batchsize:32	lr:  0.01	hidsize:[8, 8]
# acc:0.914	batchsize:32	lr:  0.01	hidsize:[16, 16]
# acc:0.912	batchsize:32	lr:  0.01	hidsize:[32, 32]
# acc:0.913	batchsize:32	lr:  0.01	hidsize:[64, 64]
# acc:0.905	batchsize:32	lr:  0.05	hidsize:[8, 8]
# acc:0.916	batchsize:32	lr:  0.05	hidsize:[16, 16]
# acc:0.907	batchsize:32	lr:  0.05	hidsize:[32, 32]
# acc:0.909	batchsize:32	lr:  0.05	hidsize:[64, 64]
# acc:0.914	batchsize:64	lr:0.0007	hidsize:[8, 8]
# acc:0.909	batchsize:64	lr:0.0007	hidsize:[16, 16]
# acc:0.916	batchsize:64	lr:0.0007	hidsize:[32, 32]
# acc:0.918	batchsize:64	lr:0.0007	hidsize:[64, 64]
# acc:0.915	batchsize:64	lr: 0.001	hidsize:[8, 8]
# acc:0.911	batchsize:64	lr: 0.001	hidsize:[16, 16]
# acc:0.916	batchsize:64	lr: 0.001	hidsize:[32, 32]
# acc:0.916	batchsize:64	lr: 0.001	hidsize:[64, 64]
# acc:0.912	batchsize:64	lr: 0.005	hidsize:[8, 8]
# acc:0.912	batchsize:64	lr: 0.005	hidsize:[16, 16]
# acc:0.914	batchsize:64	lr: 0.005	hidsize:[32, 32]
# acc:0.913	batchsize:64	lr: 0.005	hidsize:[64, 64]
# acc:0.915	batchsize:64	lr:  0.01	hidsize:[8, 8]
# acc:0.913	batchsize:64	lr:  0.01	hidsize:[16, 16]
# acc:0.912	batchsize:64	lr:  0.01	hidsize:[32, 32]
# acc:0.911	batchsize:64	lr:  0.01	hidsize:[64, 64]
# acc:0.907	batchsize:64	lr:  0.05	hidsize:[8, 8]
# acc:0.911	batchsize:64	lr:  0.05	hidsize:[16, 16]
# acc:0.909	batchsize:64	lr:  0.05	hidsize:[32, 32]
# acc:0.907	batchsize:64	lr:  0.05	hidsize:[64, 64]
# --------------------------------------
# | [PEER] best batchsize   | 32       |
# | [PEER] best hidsize     | [64, 64] |
# | [PEER] best learning... | 0.0007   |
# --------------------------------------
# ---------------------------------
# | [PEER] alpha = 0.1 | 0.69     |
# | [PEER] alpha = 0.2 | 0.706    |
# | [PEER] alpha = 0.3 | 0.706    |
# | [PEER] alpha = 0.4 | 0.717    |
# | [PEER] alpha = 0.5 | 0.725    |
# | [PEER] alpha = 0.6 | 0.735    |
# | [PEER] alpha = 0.7 | 0.734    |
# | [PEER] alpha = 0.8 | 0.728    |
# | [PEER] alpha = 0.9 | 0.721    |
# | [PEER] alpha = 1.0 | 0.713    |
# ---------------------------------
# --------------------------------------
# | [NN] with bce loss      | 0.754    |
# | [NN] with peer loss     | 0.882    |
# | [NN] with surrogate ... | 0.862    |
# | [PEER] best alpha       | 0.6      |
# --------------------------------------
# Logging to logs/svm/19-08-28-18-41-09
# {'dataset': 'splice', 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'e0': 0.1, 'e1': 0.4, 'equalize_prior': False, 'episodes': 1000}
# --------------------------------
# | [C-SVM] C1 = 0.1  | 0.661    |
# | [C-SVM] C1 = 0.2  | 0.661    |
# | [C-SVM] C1 = 0.25 | 0.661    |
# | [C-SVM] C1 = 0.33 | 0.662    |
# | [C-SVM] C1 = 0.5  | 0.668    |
# | [C-SVM] C1 = 1.0  | 0.714    |
# | [C-SVM] C1 = 10.0 | 0.72     |
# | [C-SVM] C1 = 2.0  | 0.726    |
# | [C-SVM] C1 = 3.0  | 0.721    |
# | [C-SVM] C1 = 4.0  | 0.719    |
# | [C-SVM] C1 = 5.0  | 0.72     |
# --------------------------------
# ------------------------------------
# | [C-SVM] accuracy max  | 0.914    |
# | [C-SVM] accuracy mean | 0.898    |
# | [C-SVM] accuracy min  | 0.889    |
# | [C-SVM] accuracy std  | 0.00942  |
# | [C-SVM] best C1       | 2        |
# ------------------------------------
# Logging to logs/pam/19-08-28-18-41-36
# {'dataset': 'splice', 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'e0': 0.1, 'e1': 0.4, 'equalize_prior': False, 'episodes': 1000}
# -----------------------------------
# | [PAM] margin = 0     | 0.651    |
# | [PAM] margin = 0.125 | 0.684    |
# | [PAM] margin = 0.25  | 0.693    |
# | [PAM] margin = 0.5   | 0.703    |
# | [PAM] margin = 1     | 0.704    |
# -----------------------------------
# ----------------------------------
# | [PAM] accuracy max  | 0.822    |
# | [PAM] accuracy mean | 0.798    |
# | [PAM] accuracy min  | 0.774    |
# | [PAM] accuracy std  | 0.0136   |
# | [PAM] best margin   | 1        |
# ----------------------------------

# %% [markdown]
# ### $e_0 = 0.2, e_1 = 0.4$

# %%
from run_nn import find_best_alpha
args = default_args.copy()
args.update({
    'dataset': 'splice', 
    'e0': 0.2, 'e1': 0.4, 
    'equalize_prior': False, 
    'episodes': 1000, 
    'batchsize': 32, 
    'hidsize': [64, 64], 
    'lr': 0.0007, 
#     'alpha': 1.
})
find_best_alpha(args)
# Out:
# ---------------------------------
# | [PEER] alpha = 0.1 | 0.743    |
# | [PEER] alpha = 0.2 | 0.76     |
# | [PEER] alpha = 0.3 | 0.773    |
# | [PEER] alpha = 0.4 | 0.778    |
# | [PEER] alpha = 0.5 | 0.802    |
# | [PEER] alpha = 0.6 | 0.836    |
# | [PEER] alpha = 0.7 | 0.856    |
# | [PEER] alpha = 0.8 | 0.883    |
# | [PEER] alpha = 0.9 | 0.905    |
# | [PEER] alpha = 1.0 | 0.912    |
# ---------------------------------
# {'alpha': 1.0}

# %%
from run_nn import find_best_alpha
args = default_args.copy()
args.update({
    'dataset': 'splice', 
    'e0': 0.2, 'e1': 0.4, 
    'equalize_prior': False, 
    'episodes': 1000, 
    'batchsize': 32, 
    'hidsize': [64, 64], 
    'lr': 0.0007, 
#     'alpha': 1.
})
find_best_alpha(args)
# Out:
# ---------------------------------
# | [PEER] alpha = 0.4 | 0.778    |
# | [PEER] alpha = 0.5 | 0.802    |
# | [PEER] alpha = 0.6 | 0.836    |
# | [PEER] alpha = 0.7 | 0.856    |
# | [PEER] alpha = 0.8 | 0.883    |
# | [PEER] alpha = 0.9 | 0.905    |
# | [PEER] alpha = 1.0 | 0.912    |
# | [PEER] alpha = 2.0 | 0.481    |
# | [PEER] alpha = 3.0 | 0.481    |
# | [PEER] alpha = 4.0 | 0.481    |
# | [PEER] alpha = 5.0 | 0.481    |
# ---------------------------------
# {'alpha': 1.0}

# %%
from runner import run
args = default_args.copy()
args.update({
    'dataset': 'splice', 
    'e0': 0.2, 'e1': 0.4, 
    'equalize_prior': False, 
    'episodes': 1000, 
#     'batchsize': 4, 
#     'hidsize': [32, 32], 
#     'lr': 0.005, 
#     'alpha': 1.
})
run(args)
# Out:
# Logging to logs/nn/19-08-28-18-05-48
# {'dataset': 'splice', 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'e0': 0.2, 'e1': 0.4, 'equalize_prior': False, 'episodes': 1000}
# acc:0.711	batchsize: 1	lr:0.0007	hidsize:[8, 8]
# acc:0.739	batchsize: 1	lr:0.0007	hidsize:[16, 16]
# acc:0.769	batchsize: 1	lr:0.0007	hidsize:[32, 32]
# acc:0.736	batchsize: 1	lr:0.0007	hidsize:[64, 64]
# acc:0.759	batchsize: 1	lr: 0.001	hidsize:[8, 8]
# acc:0.767	batchsize: 1	lr: 0.001	hidsize:[16, 16]
# acc:0.753	batchsize: 1	lr: 0.001	hidsize:[32, 32]
# acc:0.728	batchsize: 1	lr: 0.001	hidsize:[64, 64]
# acc:0.737	batchsize: 1	lr: 0.005	hidsize:[8, 8]
# acc:0.722	batchsize: 1	lr: 0.005	hidsize:[16, 16]
# acc:0.715	batchsize: 1	lr: 0.005	hidsize:[32, 32]
# acc:0.712	batchsize: 1	lr: 0.005	hidsize:[64, 64]
# acc:0.719	batchsize: 1	lr:  0.01	hidsize:[8, 8]
# acc:0.706	batchsize: 1	lr:  0.01	hidsize:[16, 16]
# acc:0.727	batchsize: 1	lr:  0.01	hidsize:[32, 32]
# acc:0.688	batchsize: 1	lr:  0.01	hidsize:[64, 64]
# acc:0.569	batchsize: 1	lr:  0.05	hidsize:[8, 8]
# acc:0.629	batchsize: 1	lr:  0.05	hidsize:[16, 16]
# acc:0.619	batchsize: 1	lr:  0.05	hidsize:[32, 32]
# acc:0.678	batchsize: 1	lr:  0.05	hidsize:[64, 64]
# acc:0.827	batchsize: 4	lr:0.0007	hidsize:[8, 8]
# acc:0.83	batchsize: 4	lr:0.0007	hidsize:[16, 16]
# acc:0.867	batchsize: 4	lr:0.0007	hidsize:[32, 32]
# acc:0.864	batchsize: 4	lr:0.0007	hidsize:[64, 64]
# acc:0.844	batchsize: 4	lr: 0.001	hidsize:[8, 8]
# acc:0.836	batchsize: 4	lr: 0.001	hidsize:[16, 16]
# acc:0.866	batchsize: 4	lr: 0.001	hidsize:[32, 32]
# acc:0.867	batchsize: 4	lr: 0.001	hidsize:[64, 64]
# acc:0.849	batchsize: 4	lr: 0.005	hidsize:[8, 8]
# acc:0.854	batchsize: 4	lr: 0.005	hidsize:[16, 16]
# acc:0.863	batchsize: 4	lr: 0.005	hidsize:[32, 32]
# acc:0.868	batchsize: 4	lr: 0.005	hidsize:[64, 64]
# acc:0.847	batchsize: 4	lr:  0.01	hidsize:[8, 8]
# acc:0.853	batchsize: 4	lr:  0.01	hidsize:[16, 16]
# acc:0.854	batchsize: 4	lr:  0.01	hidsize:[32, 32]
# acc:0.853	batchsize: 4	lr:  0.01	hidsize:[64, 64]
# acc:0.74	batchsize: 4	lr:  0.05	hidsize:[8, 8]
# acc:0.738	batchsize: 4	lr:  0.05	hidsize:[16, 16]
# acc:0.79	batchsize: 4	lr:  0.05	hidsize:[32, 32]
# acc:0.809	batchsize: 4	lr:  0.05	hidsize:[64, 64]
# acc:0.886	batchsize:16	lr:0.0007	hidsize:[8, 8]
# acc:0.885	batchsize:16	lr:0.0007	hidsize:[16, 16]
# acc: 0.9	batchsize:16	lr:0.0007	hidsize:[32, 32]
# acc:0.903	batchsize:16	lr:0.0007	hidsize:[64, 64]
# acc:0.891	batchsize:16	lr: 0.001	hidsize:[8, 8]
# acc:0.897	batchsize:16	lr: 0.001	hidsize:[16, 16]
# acc: 0.9	batchsize:16	lr: 0.001	hidsize:[32, 32]
# acc:0.902	batchsize:16	lr: 0.001	hidsize:[64, 64]
# acc:0.895	batchsize:16	lr: 0.005	hidsize:[8, 8]
# acc:0.899	batchsize:16	lr: 0.005	hidsize:[16, 16]
# acc:0.901	batchsize:16	lr: 0.005	hidsize:[32, 32]
# acc: 0.9	batchsize:16	lr: 0.005	hidsize:[64, 64]
# acc:0.898	batchsize:16	lr:  0.01	hidsize:[8, 8]
# acc:0.893	batchsize:16	lr:  0.01	hidsize:[16, 16]
# acc:0.897	batchsize:16	lr:  0.01	hidsize:[32, 32]
# acc:0.898	batchsize:16	lr:  0.01	hidsize:[64, 64]
# acc:0.885	batchsize:16	lr:  0.05	hidsize:[8, 8]
# acc:0.891	batchsize:16	lr:  0.05	hidsize:[16, 16]
# acc:0.889	batchsize:16	lr:  0.05	hidsize:[32, 32]
# acc:0.896	batchsize:16	lr:  0.05	hidsize:[64, 64]
# acc:0.899	batchsize:32	lr:0.0007	hidsize:[8, 8]
# acc:0.903	batchsize:32	lr:0.0007	hidsize:[16, 16]
# acc:0.907	batchsize:32	lr:0.0007	hidsize:[32, 32]
# acc:0.912	batchsize:32	lr:0.0007	hidsize:[64, 64]
# acc: 0.9	batchsize:32	lr: 0.001	hidsize:[8, 8]
# acc:0.906	batchsize:32	lr: 0.001	hidsize:[16, 16]
# acc:0.908	batchsize:32	lr: 0.001	hidsize:[32, 32]
# acc:0.911	batchsize:32	lr: 0.001	hidsize:[64, 64]
# acc:0.905	batchsize:32	lr: 0.005	hidsize:[8, 8]
# acc:0.903	batchsize:32	lr: 0.005	hidsize:[16, 16]
# acc:0.907	batchsize:32	lr: 0.005	hidsize:[32, 32]
# acc:0.906	batchsize:32	lr: 0.005	hidsize:[64, 64]
# acc:0.903	batchsize:32	lr:  0.01	hidsize:[8, 8]
# acc:0.903	batchsize:32	lr:  0.01	hidsize:[16, 16]
# acc:0.906	batchsize:32	lr:  0.01	hidsize:[32, 32]
# acc:0.903	batchsize:32	lr:  0.01	hidsize:[64, 64]
# acc:0.882	batchsize:32	lr:  0.05	hidsize:[8, 8]
# acc:0.898	batchsize:32	lr:  0.05	hidsize:[16, 16]
# acc:0.903	batchsize:32	lr:  0.05	hidsize:[32, 32]
# acc:0.894	batchsize:32	lr:  0.05	hidsize:[64, 64]
# acc:0.905	batchsize:64	lr:0.0007	hidsize:[8, 8]
# acc:0.902	batchsize:64	lr:0.0007	hidsize:[16, 16]
# acc:0.91	batchsize:64	lr:0.0007	hidsize:[32, 32]
# acc:0.909	batchsize:64	lr:0.0007	hidsize:[64, 64]
# acc:0.904	batchsize:64	lr: 0.001	hidsize:[8, 8]
# acc:0.908	batchsize:64	lr: 0.001	hidsize:[16, 16]
# acc:0.909	batchsize:64	lr: 0.001	hidsize:[32, 32]
# acc:0.909	batchsize:64	lr: 0.001	hidsize:[64, 64]
# acc:0.903	batchsize:64	lr: 0.005	hidsize:[8, 8]
# acc:0.904	batchsize:64	lr: 0.005	hidsize:[16, 16]
# acc:0.905	batchsize:64	lr: 0.005	hidsize:[32, 32]
# acc:0.906	batchsize:64	lr: 0.005	hidsize:[64, 64]
# acc:0.904	batchsize:64	lr:  0.01	hidsize:[8, 8]
# acc:0.905	batchsize:64	lr:  0.01	hidsize:[16, 16]
# acc:0.906	batchsize:64	lr:  0.01	hidsize:[32, 32]
# acc:0.906	batchsize:64	lr:  0.01	hidsize:[64, 64]
# acc:0.848	batchsize:64	lr:  0.05	hidsize:[8, 8]
# acc:0.902	batchsize:64	lr:  0.05	hidsize:[16, 16]
# acc:0.902	batchsize:64	lr:  0.05	hidsize:[32, 32]
# acc:0.899	batchsize:64	lr:  0.05	hidsize:[64, 64]
# --------------------------------------
# | [PEER] best batchsize   | 32       |
# | [PEER] best hidsize     | [64, 64] |
# | [PEER] best learning... | 0.0007   |
# --------------------------------------
# ---------------------------------
# | [PEER] alpha = 0.1 | 0.627    |
# | [PEER] alpha = 0.2 | 0.633    |
# | [PEER] alpha = 0.3 | 0.642    |
# | [PEER] alpha = 0.4 | 0.647    |
# | [PEER] alpha = 0.5 | 0.652    |
# | [PEER] alpha = 0.6 | 0.661    |
# | [PEER] alpha = 0.7 | 0.67     |
# | [PEER] alpha = 0.8 | 0.673    |
# | [PEER] alpha = 0.9 | 0.67     |
# | [PEER] alpha = 1.0 | 0.667    |
# ---------------------------------
# --------------------------------------
# | [NN] with bce loss      | 0.725    |
# | [NN] with peer loss     | 0.883    |
# | [NN] with surrogate ... | 0.84     |
# | [PEER] best alpha       | 0.8      |
# --------------------------------------
# Logging to logs/svm/19-08-28-18-16-54
# {'dataset': 'splice', 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'e0': 0.2, 'e1': 0.4, 'equalize_prior': False, 'episodes': 1000}
# --------------------------------
# | [C-SVM] C1 = 0.1  | 0.609    |
# | [C-SVM] C1 = 0.2  | 0.609    |
# | [C-SVM] C1 = 0.25 | 0.609    |
# | [C-SVM] C1 = 0.33 | 0.61     |
# | [C-SVM] C1 = 0.5  | 0.615    |
# | [C-SVM] C1 = 1.0  | 0.663    |
# | [C-SVM] C1 = 10.0 | 0.649    |
# | [C-SVM] C1 = 2.0  | 0.65     |
# | [C-SVM] C1 = 3.0  | 0.649    |
# | [C-SVM] C1 = 4.0  | 0.649    |
# | [C-SVM] C1 = 5.0  | 0.649    |
# --------------------------------
# ------------------------------------
# | [C-SVM] accuracy max  | 0.847    |
# | [C-SVM] accuracy mean | 0.824    |
# | [C-SVM] accuracy min  | 0.801    |
# | [C-SVM] accuracy std  | 0.0153   |
# | [C-SVM] best C1       | 1        |
# ------------------------------------
# Logging to logs/pam/19-08-28-18-17-23
# {'dataset': 'splice', 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'e0': 0.2, 'e1': 0.4, 'equalize_prior': False, 'episodes': 1000}
# -----------------------------------
# | [PAM] margin = 0     | 0.603    |
# | [PAM] margin = 0.125 | 0.622    |
# | [PAM] margin = 0.25  | 0.616    |
# | [PAM] margin = 0.5   | 0.64     |
# | [PAM] margin = 1     | 0.65     |
# -----------------------------------
# ----------------------------------
# | [PAM] accuracy max  | 0.816    |
# | [PAM] accuracy mean | 0.795    |
# | [PAM] accuracy min  | 0.763    |
# | [PAM] accuracy std  | 0.0153   |
# | [PAM] best margin   | 1        |
# ----------------------------------

# %% [markdown]
# ### $e_0=0.4, e_1=0.4$

# %%
from run_nn import find_best_alpha
args = default_args.copy()
args.update({
    'dataset': 'splice', 
    'e0': 0.4, 'e1': 0.4, 
    'equalize_prior': False, 
    'episodes': 1000, 
    'batchsize': 64, 
    'hidsize': [64, 64], 
    'lr': 0.0007, 
#     'alpha': 1.
})
find_best_alpha(args)
# Out:
# ---------------------------------
# | [PEER] alpha = 0.1 | 0.63     |
# | [PEER] alpha = 0.2 | 0.652    |
# | [PEER] alpha = 0.3 | 0.658    |
# | [PEER] alpha = 0.4 | 0.668    |
# | [PEER] alpha = 0.5 | 0.676    |
# | [PEER] alpha = 0.6 | 0.683    |
# | [PEER] alpha = 0.7 | 0.713    |
# | [PEER] alpha = 0.8 | 0.749    |
# | [PEER] alpha = 0.9 | 0.788    |
# | [PEER] alpha = 1.0 | 0.831    |
# ---------------------------------
# {'alpha': 1.0}

# %%
from run_nn import find_best_alpha
args = default_args.copy()
args.update({
    'dataset': 'splice', 
    'e0': 0.4, 'e1': 0.4, 
    'equalize_prior': False, 
    'episodes': 1000, 
    'batchsize': 32, 
    'hidsize': [64, 64], 
    'lr': 0.0007, 
#     'alpha': 1.
})
find_best_alpha(args)
# Out:
# ---------------------------------
# | [PEER] alpha = 0.4 | 0.656    |
# | [PEER] alpha = 0.5 | 0.67     |
# | [PEER] alpha = 0.6 | 0.681    |
# | [PEER] alpha = 0.7 | 0.708    |
# | [PEER] alpha = 0.8 | 0.733    |
# | [PEER] alpha = 0.9 | 0.787    |
# | [PEER] alpha = 1.0 | 0.822    |
# | [PEER] alpha = 2.0 | 0.562    |
# | [PEER] alpha = 3.0 | 0.516    |
# | [PEER] alpha = 4.0 | 0.516    |
# | [PEER] alpha = 5.0 | 0.516    |
# ---------------------------------
# {'alpha': 1.0}

# %%
from run_nn import find_best_alpha
args = default_args.copy()
args.update({
    'dataset': 'splice', 
    'e0': 0.4, 'e1': 0.4, 
    'equalize_prior': False, 
    'episodes': 1000, 
    'batchsize': 64, 
    'hidsize': [64, 64], 
    'lr': 0.0007, 
#     'alpha': 1.
})
find_best_alpha(args)
# Out:
# ---------------------------------
# | [PEER] alpha = 0.4 | 0.668    |
# | [PEER] alpha = 0.5 | 0.676    |
# | [PEER] alpha = 0.6 | 0.683    |
# | [PEER] alpha = 0.7 | 0.713    |
# | [PEER] alpha = 0.8 | 0.749    |
# | [PEER] alpha = 0.9 | 0.788    |
# | [PEER] alpha = 1.0 | 0.831    |
# | [PEER] alpha = 2.0 | 0.516    |
# | [PEER] alpha = 3.0 | 0.516    |
# | [PEER] alpha = 4.0 | 0.548    |
# | [PEER] alpha = 5.0 | 0.513    |
# ---------------------------------
# {'alpha': 1.0}

# %%
from runner import run
args = default_args.copy()
args.update({
    'dataset': 'splice', 
    'e0': 0.4, 'e1': 0.4, 
    'equalize_prior': False, 
    'episodes': 1000, 
#     'batchsize': 4, 
#     'hidsize': [32, 32], 
#     'lr': 0.005, 
#     'alpha': 1.
})
run(args)
# Out:
# Logging to logs/nn/19-08-28-18-17-52
# {'dataset': 'splice', 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'e0': 0.4, 'e1': 0.4, 'equalize_prior': False, 'episodes': 1000}
# acc:0.618	batchsize: 1	lr:0.0007	hidsize:[8, 8]
# acc:0.617	batchsize: 1	lr:0.0007	hidsize:[16, 16]
# acc:0.613	batchsize: 1	lr:0.0007	hidsize:[32, 32]
# acc:0.623	batchsize: 1	lr:0.0007	hidsize:[64, 64]
# acc:0.614	batchsize: 1	lr: 0.001	hidsize:[8, 8]
# acc:0.634	batchsize: 1	lr: 0.001	hidsize:[16, 16]
# acc:0.637	batchsize: 1	lr: 0.001	hidsize:[32, 32]
# acc:0.619	batchsize: 1	lr: 0.001	hidsize:[64, 64]
# acc:0.582	batchsize: 1	lr: 0.005	hidsize:[8, 8]
# acc:0.606	batchsize: 1	lr: 0.005	hidsize:[16, 16]
# acc:0.582	batchsize: 1	lr: 0.005	hidsize:[32, 32]
# acc:0.565	batchsize: 1	lr: 0.005	hidsize:[64, 64]
# acc:0.555	batchsize: 1	lr:  0.01	hidsize:[8, 8]
# acc:0.559	batchsize: 1	lr:  0.01	hidsize:[16, 16]
# acc:0.593	batchsize: 1	lr:  0.01	hidsize:[32, 32]
# acc:0.559	batchsize: 1	lr:  0.01	hidsize:[64, 64]
# acc:0.514	batchsize: 1	lr:  0.05	hidsize:[8, 8]
# acc:0.512	batchsize: 1	lr:  0.05	hidsize:[16, 16]
# acc:0.522	batchsize: 1	lr:  0.05	hidsize:[32, 32]
# acc:0.535	batchsize: 1	lr:  0.05	hidsize:[64, 64]
# acc:0.683	batchsize: 4	lr:0.0007	hidsize:[8, 8]
# acc:0.698	batchsize: 4	lr:0.0007	hidsize:[16, 16]
# acc:0.742	batchsize: 4	lr:0.0007	hidsize:[32, 32]
# acc:0.72	batchsize: 4	lr:0.0007	hidsize:[64, 64]
# acc:0.705	batchsize: 4	lr: 0.001	hidsize:[8, 8]
# acc:0.71	batchsize: 4	lr: 0.001	hidsize:[16, 16]
# acc:0.741	batchsize: 4	lr: 0.001	hidsize:[32, 32]
# acc:0.729	batchsize: 4	lr: 0.001	hidsize:[64, 64]
# acc:0.72	batchsize: 4	lr: 0.005	hidsize:[8, 8]
# acc:0.704	batchsize: 4	lr: 0.005	hidsize:[16, 16]
# acc:0.709	batchsize: 4	lr: 0.005	hidsize:[32, 32]
# acc:0.71	batchsize: 4	lr: 0.005	hidsize:[64, 64]
# acc:0.707	batchsize: 4	lr:  0.01	hidsize:[8, 8]
# acc:0.687	batchsize: 4	lr:  0.01	hidsize:[16, 16]
# acc:0.68	batchsize: 4	lr:  0.01	hidsize:[32, 32]
# acc:0.71	batchsize: 4	lr:  0.01	hidsize:[64, 64]
# acc:0.672	batchsize: 4	lr:  0.05	hidsize:[8, 8]
# acc:0.621	batchsize: 4	lr:  0.05	hidsize:[16, 16]
# acc:0.643	batchsize: 4	lr:  0.05	hidsize:[32, 32]
# acc:0.676	batchsize: 4	lr:  0.05	hidsize:[64, 64]
# acc:0.76	batchsize:16	lr:0.0007	hidsize:[8, 8]
# acc:0.776	batchsize:16	lr:0.0007	hidsize:[16, 16]
# acc:0.794	batchsize:16	lr:0.0007	hidsize:[32, 32]
# acc:0.814	batchsize:16	lr:0.0007	hidsize:[64, 64]
# acc:0.772	batchsize:16	lr: 0.001	hidsize:[8, 8]
# acc:0.791	batchsize:16	lr: 0.001	hidsize:[16, 16]
# acc: 0.8	batchsize:16	lr: 0.001	hidsize:[32, 32]
# acc:0.814	batchsize:16	lr: 0.001	hidsize:[64, 64]
# acc:0.804	batchsize:16	lr: 0.005	hidsize:[8, 8]
# acc:0.799	batchsize:16	lr: 0.005	hidsize:[16, 16]
# acc:0.815	batchsize:16	lr: 0.005	hidsize:[32, 32]
# acc:0.817	batchsize:16	lr: 0.005	hidsize:[64, 64]
# acc: 0.8	batchsize:16	lr:  0.01	hidsize:[8, 8]
# acc:0.801	batchsize:16	lr:  0.01	hidsize:[16, 16]
# acc:0.814	batchsize:16	lr:  0.01	hidsize:[32, 32]
# acc:0.809	batchsize:16	lr:  0.01	hidsize:[64, 64]
# acc:0.787	batchsize:16	lr:  0.05	hidsize:[8, 8]
# acc:0.805	batchsize:16	lr:  0.05	hidsize:[16, 16]
# acc:0.798	batchsize:16	lr:  0.05	hidsize:[32, 32]
# acc:0.77	batchsize:16	lr:  0.05	hidsize:[64, 64]
# acc:0.78	batchsize:32	lr:0.0007	hidsize:[8, 8]
# acc:0.797	batchsize:32	lr:0.0007	hidsize:[16, 16]
# acc:0.817	batchsize:32	lr:0.0007	hidsize:[32, 32]
# acc:0.822	batchsize:32	lr:0.0007	hidsize:[64, 64]
# acc:0.786	batchsize:32	lr: 0.001	hidsize:[8, 8]
# acc:0.802	batchsize:32	lr: 0.001	hidsize:[16, 16]
# acc:0.821	batchsize:32	lr: 0.001	hidsize:[32, 32]
# acc:0.828	batchsize:32	lr: 0.001	hidsize:[64, 64]
# acc:0.802	batchsize:32	lr: 0.005	hidsize:[8, 8]
# acc:0.819	batchsize:32	lr: 0.005	hidsize:[16, 16]
# acc:0.829	batchsize:32	lr: 0.005	hidsize:[32, 32]
# acc:0.837	batchsize:32	lr: 0.005	hidsize:[64, 64]
# acc:0.816	batchsize:32	lr:  0.01	hidsize:[8, 8]
# acc:0.828	batchsize:32	lr:  0.01	hidsize:[16, 16]
# acc:0.835	batchsize:32	lr:  0.01	hidsize:[32, 32]
# acc:0.828	batchsize:32	lr:  0.01	hidsize:[64, 64]
# acc:0.814	batchsize:32	lr:  0.05	hidsize:[8, 8]
# acc:0.82	batchsize:32	lr:  0.05	hidsize:[16, 16]
# acc:0.819	batchsize:32	lr:  0.05	hidsize:[32, 32]
# acc:0.826	batchsize:32	lr:  0.05	hidsize:[64, 64]
# acc:0.794	batchsize:64	lr:0.0007	hidsize:[8, 8]
# acc:0.81	batchsize:64	lr:0.0007	hidsize:[16, 16]
# acc:0.829	batchsize:64	lr:0.0007	hidsize:[32, 32]
# acc:0.831	batchsize:64	lr:0.0007	hidsize:[64, 64]
# acc:0.803	batchsize:64	lr: 0.001	hidsize:[8, 8]
# acc:0.814	batchsize:64	lr: 0.001	hidsize:[16, 16]
# acc:0.829	batchsize:64	lr: 0.001	hidsize:[32, 32]
# acc:0.835	batchsize:64	lr: 0.001	hidsize:[64, 64]
# acc:0.835	batchsize:64	lr: 0.005	hidsize:[8, 8]
# acc:0.834	batchsize:64	lr: 0.005	hidsize:[16, 16]
# acc:0.843	batchsize:64	lr: 0.005	hidsize:[32, 32]
# acc:0.844	batchsize:64	lr: 0.005	hidsize:[64, 64]
# acc:0.836	batchsize:64	lr:  0.01	hidsize:[8, 8]
# acc:0.825	batchsize:64	lr:  0.01	hidsize:[16, 16]
# acc:0.84	batchsize:64	lr:  0.01	hidsize:[32, 32]
# acc:0.834	batchsize:64	lr:  0.01	hidsize:[64, 64]
# acc:0.813	batchsize:64	lr:  0.05	hidsize:[8, 8]
# acc:0.838	batchsize:64	lr:  0.05	hidsize:[16, 16]
# acc:0.834	batchsize:64	lr:  0.05	hidsize:[32, 32]
# acc:0.833	batchsize:64	lr:  0.05	hidsize:[64, 64]
# --------------------------------------
# | [PEER] best batchsize   | 64       |
# | [PEER] best hidsize     | [64, 64] |
# | [PEER] best learning... | 0.005    |
# --------------------------------------
# ---------------------------------
# | [PEER] alpha = 0.1 | 0.516    |
# | [PEER] alpha = 0.2 | 0.527    |
# | [PEER] alpha = 0.3 | 0.539    |
# | [PEER] alpha = 0.4 | 0.527    |
# | [PEER] alpha = 0.5 | 0.544    |
# | [PEER] alpha = 0.6 | 0.529    |
# | [PEER] alpha = 0.7 | 0.533    |
# | [PEER] alpha = 0.8 | 0.546    |
# | [PEER] alpha = 0.9 | 0.555    |
# | [PEER] alpha = 1.0 | 0.559    |
# ---------------------------------
# --------------------------------------
# | [NN] with bce loss      | 0.601    |
# | [NN] with peer loss     | 0.844    |
# | [NN] with surrogate ... | 0.755    |
# | [PEER] best alpha       | 1        |
# --------------------------------------
# Logging to logs/svm/19-08-28-18-28-32
# {'dataset': 'splice', 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'e0': 0.4, 'e1': 0.4, 'equalize_prior': False, 'episodes': 1000}
# --------------------------------
# | [C-SVM] C1 = 0.1  | 0.504    |
# | [C-SVM] C1 = 0.2  | 0.504    |
# | [C-SVM] C1 = 0.25 | 0.505    |
# | [C-SVM] C1 = 0.33 | 0.506    |
# | [C-SVM] C1 = 0.5  | 0.51     |
# | [C-SVM] C1 = 1.0  | 0.544    |
# | [C-SVM] C1 = 10.0 | 0.528    |
# | [C-SVM] C1 = 2.0  | 0.524    |
# | [C-SVM] C1 = 3.0  | 0.528    |
# | [C-SVM] C1 = 4.0  | 0.527    |
# | [C-SVM] C1 = 5.0  | 0.528    |
# --------------------------------
# ------------------------------------
# | [C-SVM] accuracy max  | 0.788    |
# | [C-SVM] accuracy mean | 0.76     |
# | [C-SVM] accuracy min  | 0.73     |
# | [C-SVM] accuracy std  | 0.0166   |
# | [C-SVM] best C1       | 1        |
# ------------------------------------
# Logging to logs/pam/19-08-28-18-29-03
# {'dataset': 'splice', 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'e0': 0.4, 'e1': 0.4, 'equalize_prior': False, 'episodes': 1000}
# -----------------------------------
# | [PAM] margin = 0     | 0.53     |
# | [PAM] margin = 0.125 | 0.542    |
# | [PAM] margin = 0.25  | 0.52     |
# | [PAM] margin = 0.5   | 0.536    |
# | [PAM] margin = 1     | 0.537    |
# -----------------------------------
# ----------------------------------
# | [PAM] accuracy max  | 0.683    |
# | [PAM] accuracy mean | 0.631    |
# | [PAM] accuracy min  | 0.509    |
# | [PAM] accuracy std  | 0.0518   |
# | [PAM] best margin   | 0.125    |
# ----------------------------------

# %%
from run_nn import find_best_alpha
args = default_args.copy()
args.update({
    'dataset': 'splice', 
    'e0': 0.4, 'e1': 0.4, 
    'equalize_prior': False, 
    'episodes': 1000, 
    'batchsize': 32, 
    'hidsize': [64, 64], 
    'lr': 0.0007, 
#     'alpha': 1.
})
find_best_alpha(args)
# Out:
# ---------------------------------
# | [PEER] alpha = 0.1 | 0.615    |
# | [PEER] alpha = 0.2 | 0.643    |
# | [PEER] alpha = 0.3 | 0.644    |
# | [PEER] alpha = 0.4 | 0.656    |
# | [PEER] alpha = 0.5 | 0.67     |
# | [PEER] alpha = 0.6 | 0.681    |
# | [PEER] alpha = 0.7 | 0.708    |
# | [PEER] alpha = 0.8 | 0.733    |
# | [PEER] alpha = 0.9 | 0.787    |
# | [PEER] alpha = 1.0 | 0.822    |
# ---------------------------------
# {'alpha': 1.0}

# %%
from runner import run
args = default_args.copy()
args.update({
    'dataset': 'splice', 
    'e0': 0.4, 'e1': 0.4, 
    'equalize_prior': False, 
    'episodes': 1000, 
    'batchsize': 32, 
    'hidsize': [32, 32], 
    'lr': 0.0007, 
    'alpha': 1.
})
run(args)
# Out:
# Logging to logs/nn/19-08-28-20-41-28
# {'dataset': 'splice', 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'e0': 0.4, 'e1': 0.4, 'equalize_prior': False, 'episodes': 1000, 'batchsize': 32, 'hidsize': [32, 32], 'lr': 0.0007, 'alpha': 1.0}
# --------------------------------------
# | [NN] with bce loss      | 0.6      |
# | [NN] with peer loss     | 0.817    |
# | [NN] with surrogate ... | 0.744    |
# --------------------------------------
# Logging to logs/svm/19-08-28-20-41-46
# {'dataset': 'splice', 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'e0': 0.4, 'e1': 0.4, 'equalize_prior': False, 'episodes': 1000, 'batchsize': 32, 'hidsize': [32, 32], 'lr': 0.0007, 'alpha': 1.0}
# --------------------------------
# | [C-SVM] C1 = 0.1  | 0.504    |
# | [C-SVM] C1 = 0.2  | 0.504    |
# | [C-SVM] C1 = 0.25 | 0.505    |
# | [C-SVM] C1 = 0.33 | 0.506    |
# | [C-SVM] C1 = 0.5  | 0.51     |
# | [C-SVM] C1 = 1.0  | 0.544    |
# | [C-SVM] C1 = 10.0 | 0.528    |
# | [C-SVM] C1 = 2.0  | 0.524    |
# | [C-SVM] C1 = 3.0  | 0.528    |
# | [C-SVM] C1 = 4.0  | 0.527    |
# | [C-SVM] C1 = 5.0  | 0.528    |
# --------------------------------
# ------------------------------------
# | [C-SVM] accuracy max  | 0.788    |
# | [C-SVM] accuracy mean | 0.76     |
# | [C-SVM] accuracy min  | 0.73     |
# | [C-SVM] accuracy std  | 0.0166   |
# | [C-SVM] best C1       | 1        |
# ------------------------------------
# Logging to logs/pam/19-08-28-20-42-20
# {'dataset': 'splice', 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'e0': 0.4, 'e1': 0.4, 'equalize_prior': False, 'episodes': 1000, 'batchsize': 32, 'hidsize': [32, 32], 'lr': 0.0007, 'alpha': 1.0}
# -----------------------------------
# | [PAM] margin = 0     | 0.53     |
# | [PAM] margin = 0.125 | 0.542    |
# | [PAM] margin = 0.25  | 0.52     |
# | [PAM] margin = 0.5   | 0.536    |
# | [PAM] margin = 1     | 0.537    |
# -----------------------------------
# ----------------------------------
# | [PAM] accuracy max  | 0.683    |
# | [PAM] accuracy mean | 0.631    |
# | [PAM] accuracy min  | 0.509    |
# | [PAM] accuracy std  | 0.0518   |
# | [PAM] best margin   | 0.125    |
# ----------------------------------

# %% [markdown]
# # Summary

# %% [markdown]
# ### Experiments
#
# |      Dataset      | nn with peer loss |   nn  |   lr  |  svm  |  knn  | random forest | Rank |
# |:-----------------:|:-----------------:|:-----:|:-----:|:-----:|:-----:|:-------------:|------|
# |  Heart (0.2, 0.2) |       **0.810**       | 0.789 | 0.783 | 0.739 | 0.783 |     0.783     | *1*    |
# |  Heart (0.1, 0.3) |       **0.777**       | 0.726 | 0.725 | 0.739 | 0.768 |     0.667     | *1*    |
# |  Heart (0.2, 0.4) |       0.748       | 0.686 | 0.841 | **0.855** | 0.739 |     0.725     | *3*    |
# |  Heart (0.4, 0.4) |       0.658       | 0.628 | 0.623 |  **0.71** | 0.536 |     0.681     | *3*    |
# |                   |                   |       |       |       |       |               |      |
# | Breast (0.2, 0.2) |       0.923       | 0.958 | 0.906 | **0.991** | 0.906 |     0.962     | *4*    |
# | Breast (0.1, 0.3) |        0.92       | **0.934** | 0.830 | 0.915 | 0.840 |     0.849     | *2*    |
# | Breast (0.2, 0.4) |       **0.919**       | 0.862 | 0.783 | 0.802 | 0.708 |     0.792     | *1*    |
# | Breast (0.4, 0.4) |       **0.912**       | 0.852 | 0.745 | 0.792 | 0.726 |     0.717     | *1*    |
# |                   |                   |       |       |       |       |               |      |
# | German (0.2, 0.2) |       0.797       | 0.784 |  **0.87** | 0.826 | 0.768 |     0.812     | *4*    |
# | German (0.1, 0.3) |       0.797       | 0.765 | 0.739 | 0.783 | 0.681 |     **0.855**     | *2*    |
# | German (0.2, 0.4) |       **0.784**       | 0.707 | 0.696 | 0.638 | 0.594 |     0.681     | *1*    |
# | German (0.4, 0.4) |       **0.719**       | 0.688 | 0.638 | 0.623 | 0.652 |     0.623     | *1*    |

# %% [markdown]
# ### Conslusion
#
# 1. Neural Networks with peer prediction loss have the best overall performance, and outperforms regular neural networks on almost all tasks.
# 1. The neural networks have more potential because I used the same parameters for all tasks. The performance could be further improved by tuning parameters.
# 1. NN with peer prediction loss is very robust to perturbation, which is why it performs relevantly better on harder tasks.
# 1. The term we added in the loss, can somehow prevent overfitting. See one typical example from experiments on German dataset below.

# %%
# Out:
# {'dataset': 'german', 'lr': 0.001, 'hidsize': 8, 'episodes': 100, 'batchsize': 10, 'test_size': 0.25, 'dropout': 0, 'e0': 0.4, 'e1': 0.4}
# --------------------------------------
# | knn                     | 0.652    |
# | logistic regression     | 0.638    |
# | nn                      | 0.688    |
# | nn with peer prediction | 0.719    |
# | random forest           | 0.623    |
# | svm                     | 0.623    |
# --------------------------------------

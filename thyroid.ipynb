# %% [markdown]
# # Thyroid (5,65,150)

# %% [markdown]
# ## Describe
#
# | Total | Positive | Attributes | Normalized |
# |:-----:|:--------:|:----------:|:----------:|
# |  215  |  30.2%   |     5      |   Almost   |

# %%
default_args = {
    'dataset': 'thyroid',
    'test_size': 0.15,
    'val_size': 0.1,
    'dropout': 0, 
    'normalize': True,
    'loss': 'bce',
    'activation': 'relu',
    'verbose': True,
}

# %% [markdown]
# ## With Prior Equalization

# %% [markdown]
# ### $e_0 = 0.1, e_1 = 0.3$

# %%
from run_nn import find_best_alpha
args = default_args.copy()
args.update({
    'e0': 0.1, 'e1': 0.3, 
    'equalize_prior': True, 
    'episodes': 1000, 
    'batchsize': 32, 
    'hidsize': [32, 32], 
    'lr': 0.0007, 
#     'alpha': 1.,
})
find_best_alpha(args)
# Out:
# ---------------------------------
# | [PEER] alpha = 0.1 | 0.869    |
# | [PEER] alpha = 0.2 | 0.894    |
# | [PEER] alpha = 0.3 | 0.894    |
# | [PEER] alpha = 0.4 | 0.894    |
# | [PEER] alpha = 0.5 | 0.894    |
# | [PEER] alpha = 0.6 | 0.9      |
# | [PEER] alpha = 0.7 | 0.906    |
# | [PEER] alpha = 0.8 | 0.919    |
# | [PEER] alpha = 0.9 | 0.887    |
# | [PEER] alpha = 1.0 | 0.856    |
# ---------------------------------
# {'alpha': 0.8}

# %% [markdown]
# Tune alpha from 0.5

# %%
from run_nn import run
args = default_args.copy()
args.update({
    'e0': 0.1, 'e1': 0.3, 
    'equalize_prior': True, 
    'episodes': 1000, 
    'batchsize': 32, 
    'hidsize': [32, 32], 
    'lr': 0.0007, 
#     'alpha': 1.,
})
run(args)
# Out:
# Logging to logs/nn/19-08-29-14-08-20
# {'dataset': 'thyroid', 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'e0': 0.1, 'e1': 0.3, 'equalize_prior': True, 'episodes': 1000, 'batchsize': 32, 'hidsize': [32, 32], 'lr': 0.0007}
# ---------------------------------
# | [PEER] alpha = 0.1 | 0.788    |
# | [PEER] alpha = 0.2 | 0.779    |
# | [PEER] alpha = 0.3 | 0.798    |
# | [PEER] alpha = 0.4 | 0.808    |
# | [PEER] alpha = 0.5 | 0.788    |
# | [PEER] alpha = 0.6 | 0.798    |
# | [PEER] alpha = 0.7 | 0.817    |
# | [PEER] alpha = 0.8 | 0.808    |
# | [PEER] alpha = 0.9 | 0.788    |
# | [PEER] alpha = 1.0 | 0.721    |
# ---------------------------------
# --------------------------------------
# | [NN] with bce loss      | 0.863    |
# | [NN] with peer loss     | 0.906    |
# | [NN] with surrogate ... | 0.9      |
# | [PEER] best alpha       | 0.7      |
# --------------------------------------

# %%
from runner import run
args = default_args.copy()
args.update({
    'e0': 0.1, 'e1': 0.3, 
    'equalize_prior': True, 
    'episodes': 1000, 
#     'batchsize': 64, 
#     'hidsize': [64, 64], 
#     'lr': 0.001, 
    'alpha': 1.,
})
run(args)
# Out:
# Logging to logs/nn/19-08-29-13-34-00
# {'dataset': 'thyroid', 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'e0': 0.1, 'e1': 0.3, 'equalize_prior': True, 'episodes': 1000, 'alpha': 1.0}
# acc:0.694	batchsize: 1	lr:0.0007	hidsize:[8, 8]
# acc:0.763	batchsize: 1	lr:0.0007	hidsize:[16, 16]
# acc:0.769	batchsize: 1	lr:0.0007	hidsize:[32, 32]
# acc: 0.8	batchsize: 1	lr:0.0007	hidsize:[64, 64]
# acc:0.75	batchsize: 1	lr: 0.001	hidsize:[8, 8]
# acc:0.744	batchsize: 1	lr: 0.001	hidsize:[16, 16]
# acc:0.787	batchsize: 1	lr: 0.001	hidsize:[32, 32]
# acc:0.756	batchsize: 1	lr: 0.001	hidsize:[64, 64]
# acc:0.75	batchsize: 1	lr: 0.005	hidsize:[8, 8]
# acc:0.75	batchsize: 1	lr: 0.005	hidsize:[16, 16]
# acc:0.794	batchsize: 1	lr: 0.005	hidsize:[32, 32]
# acc:0.719	batchsize: 1	lr: 0.005	hidsize:[64, 64]
# acc:0.719	batchsize: 1	lr:  0.01	hidsize:[8, 8]
# acc: 0.7	batchsize: 1	lr:  0.01	hidsize:[16, 16]
# acc:0.719	batchsize: 1	lr:  0.01	hidsize:[32, 32]
# acc:0.694	batchsize: 1	lr:  0.01	hidsize:[64, 64]
# acc:0.631	batchsize: 1	lr:  0.05	hidsize:[8, 8]
# acc:0.681	batchsize: 1	lr:  0.05	hidsize:[16, 16]
# acc:0.625	batchsize: 1	lr:  0.05	hidsize:[32, 32]
# acc:0.662	batchsize: 1	lr:  0.05	hidsize:[64, 64]
# acc:0.744	batchsize: 4	lr:0.0007	hidsize:[8, 8]
# acc:0.812	batchsize: 4	lr:0.0007	hidsize:[16, 16]
# acc:0.819	batchsize: 4	lr:0.0007	hidsize:[32, 32]
# acc:0.781	batchsize: 4	lr:0.0007	hidsize:[64, 64]
# acc:0.775	batchsize: 4	lr: 0.001	hidsize:[8, 8]
# acc:0.806	batchsize: 4	lr: 0.001	hidsize:[16, 16]
# acc:0.831	batchsize: 4	lr: 0.001	hidsize:[32, 32]
# acc:0.763	batchsize: 4	lr: 0.001	hidsize:[64, 64]
# acc:0.738	batchsize: 4	lr: 0.005	hidsize:[8, 8]
# acc: 0.8	batchsize: 4	lr: 0.005	hidsize:[16, 16]
# acc:0.812	batchsize: 4	lr: 0.005	hidsize:[32, 32]
# acc:0.744	batchsize: 4	lr: 0.005	hidsize:[64, 64]
# acc:0.738	batchsize: 4	lr:  0.01	hidsize:[8, 8]
# acc:0.788	batchsize: 4	lr:  0.01	hidsize:[16, 16]
# acc:0.781	batchsize: 4	lr:  0.01	hidsize:[32, 32]
# acc:0.756	batchsize: 4	lr:  0.01	hidsize:[64, 64]
# acc:0.681	batchsize: 4	lr:  0.05	hidsize:[8, 8]
# acc:0.719	batchsize: 4	lr:  0.05	hidsize:[16, 16]
# acc:0.706	batchsize: 4	lr:  0.05	hidsize:[32, 32]
# acc:0.75	batchsize: 4	lr:  0.05	hidsize:[64, 64]
# acc:0.763	batchsize:16	lr:0.0007	hidsize:[8, 8]
# acc:0.806	batchsize:16	lr:0.0007	hidsize:[16, 16]
# acc:0.812	batchsize:16	lr:0.0007	hidsize:[32, 32]
# acc:0.769	batchsize:16	lr:0.0007	hidsize:[64, 64]
# acc:0.781	batchsize:16	lr: 0.001	hidsize:[8, 8]
# acc:0.794	batchsize:16	lr: 0.001	hidsize:[16, 16]
# acc:0.812	batchsize:16	lr: 0.001	hidsize:[32, 32]
# acc:0.769	batchsize:16	lr: 0.001	hidsize:[64, 64]
# acc: 0.8	batchsize:16	lr: 0.005	hidsize:[8, 8]
# acc:0.775	batchsize:16	lr: 0.005	hidsize:[16, 16]
# acc:0.825	batchsize:16	lr: 0.005	hidsize:[32, 32]
# acc:0.75	batchsize:16	lr: 0.005	hidsize:[64, 64]
# acc: 0.8	batchsize:16	lr:  0.01	hidsize:[8, 8]
# acc:0.794	batchsize:16	lr:  0.01	hidsize:[16, 16]
# acc:0.775	batchsize:16	lr:  0.01	hidsize:[32, 32]
# acc:0.744	batchsize:16	lr:  0.01	hidsize:[64, 64]
# acc:0.75	batchsize:16	lr:  0.05	hidsize:[8, 8]
# acc:0.775	batchsize:16	lr:  0.05	hidsize:[16, 16]
# acc:0.719	batchsize:16	lr:  0.05	hidsize:[32, 32]
# acc:0.725	batchsize:16	lr:  0.05	hidsize:[64, 64]
# acc:0.781	batchsize:32	lr:0.0007	hidsize:[8, 8]
# acc:0.794	batchsize:32	lr:0.0007	hidsize:[16, 16]
# acc:0.856	batchsize:32	lr:0.0007	hidsize:[32, 32]
# acc: 0.8	batchsize:32	lr:0.0007	hidsize:[64, 64]
# acc:0.813	batchsize:32	lr: 0.001	hidsize:[8, 8]
# acc:0.806	batchsize:32	lr: 0.001	hidsize:[16, 16]
# acc:0.85	batchsize:32	lr: 0.001	hidsize:[32, 32]
# acc:0.806	batchsize:32	lr: 0.001	hidsize:[64, 64]
# acc:0.831	batchsize:32	lr: 0.005	hidsize:[8, 8]
# acc:0.781	batchsize:32	lr: 0.005	hidsize:[16, 16]
# acc:0.794	batchsize:32	lr: 0.005	hidsize:[32, 32]
# acc:0.806	batchsize:32	lr: 0.005	hidsize:[64, 64]
# acc:0.819	batchsize:32	lr:  0.01	hidsize:[8, 8]
# acc:0.819	batchsize:32	lr:  0.01	hidsize:[16, 16]
# acc:0.838	batchsize:32	lr:  0.01	hidsize:[32, 32]
# acc:0.788	batchsize:32	lr:  0.01	hidsize:[64, 64]
# acc:0.825	batchsize:32	lr:  0.05	hidsize:[8, 8]
# acc:0.812	batchsize:32	lr:  0.05	hidsize:[16, 16]
# acc:0.781	batchsize:32	lr:  0.05	hidsize:[32, 32]
# acc: 0.8	batchsize:32	lr:  0.05	hidsize:[64, 64]
# acc:0.794	batchsize:64	lr:0.0007	hidsize:[8, 8]
# acc:0.812	batchsize:64	lr:0.0007	hidsize:[16, 16]
# acc:0.85	batchsize:64	lr:0.0007	hidsize:[32, 32]
# acc:0.806	batchsize:64	lr:0.0007	hidsize:[64, 64]
# acc:0.819	batchsize:64	lr: 0.001	hidsize:[8, 8]
# acc:0.819	batchsize:64	lr: 0.001	hidsize:[16, 16]
# acc:0.844	batchsize:64	lr: 0.001	hidsize:[32, 32]
# acc:0.831	batchsize:64	lr: 0.001	hidsize:[64, 64]
# acc:0.825	batchsize:64	lr: 0.005	hidsize:[8, 8]
# acc:0.831	batchsize:64	lr: 0.005	hidsize:[16, 16]
# acc:0.856	batchsize:64	lr: 0.005	hidsize:[32, 32]
# acc: 0.8	batchsize:64	lr: 0.005	hidsize:[64, 64]
# acc:0.812	batchsize:64	lr:  0.01	hidsize:[8, 8]
# acc:0.825	batchsize:64	lr:  0.01	hidsize:[16, 16]
# acc:0.838	batchsize:64	lr:  0.01	hidsize:[32, 32]
# acc:0.794	batchsize:64	lr:  0.01	hidsize:[64, 64]
# acc:0.75	batchsize:64	lr:  0.05	hidsize:[8, 8]
# acc:0.769	batchsize:64	lr:  0.05	hidsize:[16, 16]
# acc:0.725	batchsize:64	lr:  0.05	hidsize:[32, 32]
# acc:0.781	batchsize:64	lr:  0.05	hidsize:[64, 64]
# --------------------------------------
# | [PEER] best batchsize   | 32       |
# | [PEER] best hidsize     | [32, 32] |
# | [PEER] best learning... | 0.0007   |
# --------------------------------------
# --------------------------------------
# | [NN] with bce loss      | 0.863    |
# | [NN] with peer loss     | 0.856    |
# | [NN] with surrogate ... | 0.9      |
# --------------------------------------
# Logging to logs/svm/19-08-29-13-39-24
# {'dataset': 'thyroid', 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'e0': 0.1, 'e1': 0.3, 'equalize_prior': True, 'episodes': 1000, 'alpha': 1.0}
# --------------------------------
# | [C-SVM] C1 = 0.1  | 0.606    |
# | [C-SVM] C1 = 0.2  | 0.625    |
# | [C-SVM] C1 = 0.25 | 0.625    |
# | [C-SVM] C1 = 0.33 | 0.673    |
# | [C-SVM] C1 = 0.5  | 0.76     |
# | [C-SVM] C1 = 1.0  | 0.846    |
# | [C-SVM] C1 = 10.0 | 0.413    |
# | [C-SVM] C1 = 2.0  | 0.827    |
# | [C-SVM] C1 = 3.0  | 0.808    |
# | [C-SVM] C1 = 4.0  | 0.808    |
# | [C-SVM] C1 = 5.0  | 0.673    |
# --------------------------------
# ------------------------------------
# | [C-SVM] accuracy max  | 1        |
# | [C-SVM] accuracy mean | 0.881    |
# | [C-SVM] accuracy min  | 0.8      |
# | [C-SVM] accuracy std  | 0.0658   |
# | [C-SVM] best C1       | 1        |
# ------------------------------------
# Logging to logs/pam/19-08-29-13-39-24
# {'dataset': 'thyroid', 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'e0': 0.1, 'e1': 0.3, 'equalize_prior': True, 'episodes': 1000, 'alpha': 1.0}
# -----------------------------------
# | [PAM] margin = 0     | 0.596    |
# | [PAM] margin = 0.125 | 0.798    |
# | [PAM] margin = 0.25  | 0.788    |
# | [PAM] margin = 0.5   | 0.779    |
# | [PAM] margin = 1     | 0.769    |
# -----------------------------------
# ----------------------------------
# | [PAM] accuracy max  | 0.95     |
# | [PAM] accuracy mean | 0.781    |
# | [PAM] accuracy min  | 0.7      |
# | [PAM] accuracy std  | 0.0827   |
# | [PAM] best margin   | 0.125    |
# ----------------------------------

# %% [markdown]
# ### $e_0 = 0.2, e_1 = 0.2$

# %%
from run_nn import find_best_alpha
args = default_args.copy()
args.update({
    'e0': 0.2, 'e1': 0.2, 
    'equalize_prior': True, 
    'episodes': 1000, 
    'batchsize': 32, 
    'hidsize': [32, 32], 
    'lr': 0.01, 
#     'alpha': 1.,
})
find_best_alpha(args)
# Out:
# ---------------------------------
# | [PEER] alpha = 0.1 | 0.825    |
# | [PEER] alpha = 0.2 | 0.863    |
# | [PEER] alpha = 0.3 | 0.913    |
# | [PEER] alpha = 0.4 | 0.9      |
# | [PEER] alpha = 0.5 | 0.906    |
# | [PEER] alpha = 0.6 | 0.856    |
# | [PEER] alpha = 0.7 | 0.863    |
# | [PEER] alpha = 0.8 | 0.844    |
# | [PEER] alpha = 0.9 | 0.831    |
# | [PEER] alpha = 1.0 | 0.781    |
# ---------------------------------
# {'alpha': 0.3}

# %%
from run_nn import run
args = default_args.copy()
args.update({
    'e0': 0.2, 'e1': 0.2, 
    'equalize_prior': True, 
    'episodes': 1000, 
    'batchsize': 32, 
    'hidsize': [32, 32], 
    'lr': 0.01, 
#     'alpha': 1.,
})
run(args)
# Out:
# Logging to logs/nn/19-08-29-14-14-52
# {'dataset': 'thyroid', 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'e0': 0.2, 'e1': 0.2, 'equalize_prior': True, 'episodes': 1000, 'batchsize': 32, 'hidsize': [32, 32], 'lr': 0.01}
# ---------------------------------
# | [PEER] alpha = 0.1 | 0.712    |
# | [PEER] alpha = 0.2 | 0.76     |
# | [PEER] alpha = 0.3 | 0.798    |
# | [PEER] alpha = 0.4 | 0.75     |
# | [PEER] alpha = 0.5 | 0.731    |
# | [PEER] alpha = 0.6 | 0.721    |
# | [PEER] alpha = 0.7 | 0.721    |
# | [PEER] alpha = 0.8 | 0.692    |
# | [PEER] alpha = 0.9 | 0.683    |
# | [PEER] alpha = 1.0 | 0.673    |
# ---------------------------------
# --------------------------------------
# | [NN] with bce loss      | 0.85     |
# | [NN] with peer loss     | 0.913    |
# | [NN] with surrogate ... | 0.894    |
# | [PEER] best alpha       | 0.3      |
# --------------------------------------

# %%
from runner import run
args = default_args.copy()
args.update({
    'e0': 0.2, 'e1': 0.2, 
    'equalize_prior': True, 
    'episodes': 1000, 
#     'batchsize': 64, 
#     'hidsize': [64, 64], 
#     'lr': 0.001, 
    'alpha': 1.,
})
run(args)
# Out:
# Logging to logs/nn/19-08-29-13-39-25
# {'dataset': 'thyroid', 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'e0': 0.2, 'e1': 0.2, 'equalize_prior': True, 'episodes': 1000, 'alpha': 1.0}
# acc:0.719	batchsize: 1	lr:0.0007	hidsize:[8, 8]
# acc:0.794	batchsize: 1	lr:0.0007	hidsize:[16, 16]
# acc:0.806	batchsize: 1	lr:0.0007	hidsize:[32, 32]
# acc:0.794	batchsize: 1	lr:0.0007	hidsize:[64, 64]
# acc:0.75	batchsize: 1	lr: 0.001	hidsize:[8, 8]
# acc:0.819	batchsize: 1	lr: 0.001	hidsize:[16, 16]
# acc:0.819	batchsize: 1	lr: 0.001	hidsize:[32, 32]
# acc:0.788	batchsize: 1	lr: 0.001	hidsize:[64, 64]
# acc:0.731	batchsize: 1	lr: 0.005	hidsize:[8, 8]
# acc:0.763	batchsize: 1	lr: 0.005	hidsize:[16, 16]
# acc:0.769	batchsize: 1	lr: 0.005	hidsize:[32, 32]
# acc:0.769	batchsize: 1	lr: 0.005	hidsize:[64, 64]
# acc:0.769	batchsize: 1	lr:  0.01	hidsize:[8, 8]
# acc:0.706	batchsize: 1	lr:  0.01	hidsize:[16, 16]
# acc:0.694	batchsize: 1	lr:  0.01	hidsize:[32, 32]
# acc:0.744	batchsize: 1	lr:  0.01	hidsize:[64, 64]
# acc:0.613	batchsize: 1	lr:  0.05	hidsize:[8, 8]
# acc:0.613	batchsize: 1	lr:  0.05	hidsize:[16, 16]
# acc:0.719	batchsize: 1	lr:  0.05	hidsize:[32, 32]
# acc:0.644	batchsize: 1	lr:  0.05	hidsize:[64, 64]
# acc:0.731	batchsize: 4	lr:0.0007	hidsize:[8, 8]
# acc:0.812	batchsize: 4	lr:0.0007	hidsize:[16, 16]
# acc:0.825	batchsize: 4	lr:0.0007	hidsize:[32, 32]
# acc:0.806	batchsize: 4	lr:0.0007	hidsize:[64, 64]
# acc:0.75	batchsize: 4	lr: 0.001	hidsize:[8, 8]
# acc:0.812	batchsize: 4	lr: 0.001	hidsize:[16, 16]
# acc:0.812	batchsize: 4	lr: 0.001	hidsize:[32, 32]
# acc:0.806	batchsize: 4	lr: 0.001	hidsize:[64, 64]
# acc:0.763	batchsize: 4	lr: 0.005	hidsize:[8, 8]
# acc:0.812	batchsize: 4	lr: 0.005	hidsize:[16, 16]
# acc:0.737	batchsize: 4	lr: 0.005	hidsize:[32, 32]
# acc:0.744	batchsize: 4	lr: 0.005	hidsize:[64, 64]
# acc:0.725	batchsize: 4	lr:  0.01	hidsize:[8, 8]
# acc:0.794	batchsize: 4	lr:  0.01	hidsize:[16, 16]
# acc:0.762	batchsize: 4	lr:  0.01	hidsize:[32, 32]
# acc:0.756	batchsize: 4	lr:  0.01	hidsize:[64, 64]
# acc:0.725	batchsize: 4	lr:  0.05	hidsize:[8, 8]
# acc:0.775	batchsize: 4	lr:  0.05	hidsize:[16, 16]
# acc:0.725	batchsize: 4	lr:  0.05	hidsize:[32, 32]
# acc:0.713	batchsize: 4	lr:  0.05	hidsize:[64, 64]
# acc:0.756	batchsize:16	lr:0.0007	hidsize:[8, 8]
# acc:0.813	batchsize:16	lr:0.0007	hidsize:[16, 16]
# acc:0.794	batchsize:16	lr:0.0007	hidsize:[32, 32]
# acc:0.794	batchsize:16	lr:0.0007	hidsize:[64, 64]
# acc:0.756	batchsize:16	lr: 0.001	hidsize:[8, 8]
# acc: 0.8	batchsize:16	lr: 0.001	hidsize:[16, 16]
# acc:0.781	batchsize:16	lr: 0.001	hidsize:[32, 32]
# acc:0.787	batchsize:16	lr: 0.001	hidsize:[64, 64]
# acc:0.775	batchsize:16	lr: 0.005	hidsize:[8, 8]
# acc:0.769	batchsize:16	lr: 0.005	hidsize:[16, 16]
# acc:0.787	batchsize:16	lr: 0.005	hidsize:[32, 32]
# acc:0.775	batchsize:16	lr: 0.005	hidsize:[64, 64]
# acc:0.775	batchsize:16	lr:  0.01	hidsize:[8, 8]
# acc:0.794	batchsize:16	lr:  0.01	hidsize:[16, 16]
# acc:0.775	batchsize:16	lr:  0.01	hidsize:[32, 32]
# acc:0.781	batchsize:16	lr:  0.01	hidsize:[64, 64]
# acc:0.719	batchsize:16	lr:  0.05	hidsize:[8, 8]
# acc:0.775	batchsize:16	lr:  0.05	hidsize:[16, 16]
# acc:0.75	batchsize:16	lr:  0.05	hidsize:[32, 32]
# acc:0.719	batchsize:16	lr:  0.05	hidsize:[64, 64]
# acc:0.775	batchsize:32	lr:0.0007	hidsize:[8, 8]
# acc:0.819	batchsize:32	lr:0.0007	hidsize:[16, 16]
# acc:0.825	batchsize:32	lr:0.0007	hidsize:[32, 32]
# acc:0.806	batchsize:32	lr:0.0007	hidsize:[64, 64]
# acc:0.756	batchsize:32	lr: 0.001	hidsize:[8, 8]
# acc:0.812	batchsize:32	lr: 0.001	hidsize:[16, 16]
# acc:0.812	batchsize:32	lr: 0.001	hidsize:[32, 32]
# acc: 0.8	batchsize:32	lr: 0.001	hidsize:[64, 64]
# acc:0.806	batchsize:32	lr: 0.005	hidsize:[8, 8]
# acc: 0.8	batchsize:32	lr: 0.005	hidsize:[16, 16]
# acc:0.794	batchsize:32	lr: 0.005	hidsize:[32, 32]
# acc:0.787	batchsize:32	lr: 0.005	hidsize:[64, 64]
# acc:0.794	batchsize:32	lr:  0.01	hidsize:[8, 8]
# acc:0.806	batchsize:32	lr:  0.01	hidsize:[16, 16]
# acc:0.781	batchsize:32	lr:  0.01	hidsize:[32, 32]
# acc: 0.8	batchsize:32	lr:  0.01	hidsize:[64, 64]
# acc:0.769	batchsize:32	lr:  0.05	hidsize:[8, 8]
# acc:0.806	batchsize:32	lr:  0.05	hidsize:[16, 16]
# acc:0.769	batchsize:32	lr:  0.05	hidsize:[32, 32]
# acc:0.769	batchsize:32	lr:  0.05	hidsize:[64, 64]
# acc:0.781	batchsize:64	lr:0.0007	hidsize:[8, 8]
# acc:0.812	batchsize:64	lr:0.0007	hidsize:[16, 16]
# acc:0.819	batchsize:64	lr:0.0007	hidsize:[32, 32]
# acc:0.819	batchsize:64	lr:0.0007	hidsize:[64, 64]
# acc: 0.8	batchsize:64	lr: 0.001	hidsize:[8, 8]
# acc:0.819	batchsize:64	lr: 0.001	hidsize:[16, 16]
# acc:0.812	batchsize:64	lr: 0.001	hidsize:[32, 32]
# acc:0.825	batchsize:64	lr: 0.001	hidsize:[64, 64]
# acc:0.788	batchsize:64	lr: 0.005	hidsize:[8, 8]
# acc:0.831	batchsize:64	lr: 0.005	hidsize:[16, 16]
# acc:0.812	batchsize:64	lr: 0.005	hidsize:[32, 32]
# acc:0.812	batchsize:64	lr: 0.005	hidsize:[64, 64]
# acc:0.744	batchsize:64	lr:  0.01	hidsize:[8, 8]
# acc:0.825	batchsize:64	lr:  0.01	hidsize:[16, 16]
# acc:0.806	batchsize:64	lr:  0.01	hidsize:[32, 32]
# acc:0.781	batchsize:64	lr:  0.01	hidsize:[64, 64]
# acc:0.719	batchsize:64	lr:  0.05	hidsize:[8, 8]
# acc:0.794	batchsize:64	lr:  0.05	hidsize:[16, 16]
# acc: 0.8	batchsize:64	lr:  0.05	hidsize:[32, 32]
# acc:0.775	batchsize:64	lr:  0.05	hidsize:[64, 64]
# --------------------------------------
# | [PEER] best batchsize   | 64       |
# | [PEER] best hidsize     | [16, 16] |
# | [PEER] best learning... | 0.005    |
# --------------------------------------
# --------------------------------------
# | [NN] with bce loss      | 0.856    |
# | [NN] with peer loss     | 0.831    |
# | [NN] with surrogate ... | 0.894    |
# --------------------------------------
# Logging to logs/svm/19-08-29-13-44-57
# {'dataset': 'thyroid', 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'e0': 0.2, 'e1': 0.2, 'equalize_prior': True, 'episodes': 1000, 'alpha': 1.0}
# --------------------------------
# | [C-SVM] C1 = 0.1  | 0.5      |
# | [C-SVM] C1 = 0.2  | 0.567    |
# | [C-SVM] C1 = 0.25 | 0.606    |
# | [C-SVM] C1 = 0.33 | 0.663    |
# | [C-SVM] C1 = 0.5  | 0.769    |
# | [C-SVM] C1 = 1.0  | 0.788    |
# | [C-SVM] C1 = 10.0 | 0.5      |
# | [C-SVM] C1 = 2.0  | 0.808    |
# | [C-SVM] C1 = 3.0  | 0.663    |
# | [C-SVM] C1 = 4.0  | 0.5      |
# | [C-SVM] C1 = 5.0  | 0.5      |
# --------------------------------
# ------------------------------------
# | [C-SVM] accuracy max  | 1        |
# | [C-SVM] accuracy mean | 0.887    |
# | [C-SVM] accuracy min  | 0.75     |
# | [C-SVM] accuracy std  | 0.074    |
# | [C-SVM] best C1       | 2        |
# ------------------------------------
# Logging to logs/pam/19-08-29-13-44-57
# {'dataset': 'thyroid', 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'e0': 0.2, 'e1': 0.2, 'equalize_prior': True, 'episodes': 1000, 'alpha': 1.0}
# -----------------------------------
# | [PAM] margin = 0     | 0.635    |
# | [PAM] margin = 0.125 | 0.74     |
# | [PAM] margin = 0.25  | 0.74     |
# | [PAM] margin = 0.5   | 0.721    |
# | [PAM] margin = 1     | 0.712    |
# -----------------------------------
# ----------------------------------
# | [PAM] accuracy max  | 1        |
# | [PAM] accuracy mean | 0.831    |
# | [PAM] accuracy min  | 0.65     |
# | [PAM] accuracy std  | 0.0998   |
# | [PAM] best margin   | 0.25     |
# ----------------------------------

# %% [markdown]
# ### $e_0 = 0.1, e_1 = 0.4$

# %%
from run_nn import find_best_alpha
args = default_args.copy()
args.update({
    'e0': 0.1, 'e1': 0.4, 
    'equalize_prior': True, 
    'episodes': 1000, 
    'batchsize': 32, 
    'hidsize': [32, 32], 
    'lr': 0.01, 
#     'alpha': 1.,
})
find_best_alpha(args)
# Out:
# ---------------------------------
# | [PEER] alpha = 0.1 | 0.781    |
# | [PEER] alpha = 0.2 | 0.806    |
# | [PEER] alpha = 0.3 | 0.819    |
# | [PEER] alpha = 0.4 | 0.844    |
# | [PEER] alpha = 0.5 | 0.869    |
# | [PEER] alpha = 0.6 | 0.875    |
# | [PEER] alpha = 0.7 | 0.856    |
# | [PEER] alpha = 0.8 | 0.875    |
# | [PEER] alpha = 0.9 | 0.862    |
# | [PEER] alpha = 1.0 | 0.838    |
# ---------------------------------
# {'alpha': 0.6}

# %%
from run_nn import run
args = default_args.copy()
args.update({
    'e0': 0.1, 'e1': 0.4, 
    'equalize_prior': True, 
    'episodes': 1000, 
    'batchsize': 32, 
    'hidsize': [32, 32], 
    'lr': 0.01, 
#     'alpha': 1.,
})
run(args)
# Out:
# Logging to logs/nn/19-08-29-14-15-51
# {'dataset': 'thyroid', 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'e0': 0.1, 'e1': 0.4, 'equalize_prior': True, 'episodes': 1000, 'batchsize': 32, 'hidsize': [32, 32], 'lr': 0.01}
# ---------------------------------
# | [PEER] alpha = 0.1 | 0.75     |
# | [PEER] alpha = 0.2 | 0.74     |
# | [PEER] alpha = 0.3 | 0.75     |
# | [PEER] alpha = 0.4 | 0.76     |
# | [PEER] alpha = 0.5 | 0.76     |
# | [PEER] alpha = 0.6 | 0.769    |
# | [PEER] alpha = 0.7 | 0.76     |
# | [PEER] alpha = 0.8 | 0.76     |
# | [PEER] alpha = 0.9 | 0.75     |
# | [PEER] alpha = 1.0 | 0.683    |
# ---------------------------------
# --------------------------------------
# | [NN] with bce loss      | 0.75     |
# | [NN] with peer loss     | 0.875    |
# | [NN] with surrogate ... | 0.862    |
# | [PEER] best alpha       | 0.6      |
# --------------------------------------

# %%
from runner import run
args = default_args.copy()
args.update({ 
    'e0': 0.1, 'e1': 0.4, 
    'equalize_prior': True, 
    'episodes': 1000, 
#     'batchsize': 64, 
#     'hidsize': [64, 64], 
#     'lr': 0.001, 
    'alpha': 1.,
})
run(args)
# Out:
# Logging to logs/nn/19-08-29-13-55-26
# {'dataset': 'thyroid', 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'e0': 0.1, 'e1': 0.4, 'equalize_prior': True, 'episodes': 1000, 'alpha': 1.0}
# acc:0.644	batchsize: 1	lr:0.0007	hidsize:[8, 8]
# acc:0.756	batchsize: 1	lr:0.0007	hidsize:[16, 16]
# acc:0.719	batchsize: 1	lr:0.0007	hidsize:[32, 32]
# acc:0.806	batchsize: 1	lr:0.0007	hidsize:[64, 64]
# acc:0.681	batchsize: 1	lr: 0.001	hidsize:[8, 8]
# acc:0.75	batchsize: 1	lr: 0.001	hidsize:[16, 16]
# acc:0.775	batchsize: 1	lr: 0.001	hidsize:[32, 32]
# acc: 0.8	batchsize: 1	lr: 0.001	hidsize:[64, 64]
# acc:0.763	batchsize: 1	lr: 0.005	hidsize:[8, 8]
# acc:0.706	batchsize: 1	lr: 0.005	hidsize:[16, 16]
# acc:0.738	batchsize: 1	lr: 0.005	hidsize:[32, 32]
# acc:0.675	batchsize: 1	lr: 0.005	hidsize:[64, 64]
# acc:0.706	batchsize: 1	lr:  0.01	hidsize:[8, 8]
# acc:0.706	batchsize: 1	lr:  0.01	hidsize:[16, 16]
# acc:0.731	batchsize: 1	lr:  0.01	hidsize:[32, 32]
# acc:0.656	batchsize: 1	lr:  0.01	hidsize:[64, 64]
# acc:0.669	batchsize: 1	lr:  0.05	hidsize:[8, 8]
# acc:0.631	batchsize: 1	lr:  0.05	hidsize:[16, 16]
# acc: 0.6	batchsize: 1	lr:  0.05	hidsize:[32, 32]
# acc:0.569	batchsize: 1	lr:  0.05	hidsize:[64, 64]
# acc:0.681	batchsize: 4	lr:0.0007	hidsize:[8, 8]
# acc:0.762	batchsize: 4	lr:0.0007	hidsize:[16, 16]
# acc:0.775	batchsize: 4	lr:0.0007	hidsize:[32, 32]
# acc:0.813	batchsize: 4	lr:0.0007	hidsize:[64, 64]
# acc:0.687	batchsize: 4	lr: 0.001	hidsize:[8, 8]
# acc:0.781	batchsize: 4	lr: 0.001	hidsize:[16, 16]
# acc:0.794	batchsize: 4	lr: 0.001	hidsize:[32, 32]
# acc:0.806	batchsize: 4	lr: 0.001	hidsize:[64, 64]
# acc:0.731	batchsize: 4	lr: 0.005	hidsize:[8, 8]
# acc:0.763	batchsize: 4	lr: 0.005	hidsize:[16, 16]
# acc:0.819	batchsize: 4	lr: 0.005	hidsize:[32, 32]
# acc: 0.8	batchsize: 4	lr: 0.005	hidsize:[64, 64]
# acc:0.744	batchsize: 4	lr:  0.01	hidsize:[8, 8]
# acc:0.75	batchsize: 4	lr:  0.01	hidsize:[16, 16]
# acc:0.788	batchsize: 4	lr:  0.01	hidsize:[32, 32]
# acc:0.813	batchsize: 4	lr:  0.01	hidsize:[64, 64]
# acc:0.688	batchsize: 4	lr:  0.05	hidsize:[8, 8]
# acc:0.656	batchsize: 4	lr:  0.05	hidsize:[16, 16]
# acc:0.688	batchsize: 4	lr:  0.05	hidsize:[32, 32]
# acc:0.744	batchsize: 4	lr:  0.05	hidsize:[64, 64]
# acc:0.688	batchsize:16	lr:0.0007	hidsize:[8, 8]
# acc:0.794	batchsize:16	lr:0.0007	hidsize:[16, 16]
# acc:0.756	batchsize:16	lr:0.0007	hidsize:[32, 32]
# acc:0.787	batchsize:16	lr:0.0007	hidsize:[64, 64]
# acc:0.756	batchsize:16	lr: 0.001	hidsize:[8, 8]
# acc: 0.8	batchsize:16	lr: 0.001	hidsize:[16, 16]
# acc:0.763	batchsize:16	lr: 0.001	hidsize:[32, 32]
# acc:0.788	batchsize:16	lr: 0.001	hidsize:[64, 64]
# acc:0.725	batchsize:16	lr: 0.005	hidsize:[8, 8]
# acc:0.769	batchsize:16	lr: 0.005	hidsize:[16, 16]
# acc:0.781	batchsize:16	lr: 0.005	hidsize:[32, 32]
# acc:0.756	batchsize:16	lr: 0.005	hidsize:[64, 64]
# acc:0.731	batchsize:16	lr:  0.01	hidsize:[8, 8]
# acc:0.762	batchsize:16	lr:  0.01	hidsize:[16, 16]
# acc:0.744	batchsize:16	lr:  0.01	hidsize:[32, 32]
# acc:0.713	batchsize:16	lr:  0.01	hidsize:[64, 64]
# acc:0.725	batchsize:16	lr:  0.05	hidsize:[8, 8]
# acc:0.712	batchsize:16	lr:  0.05	hidsize:[16, 16]
# acc:0.694	batchsize:16	lr:  0.05	hidsize:[32, 32]
# acc:0.688	batchsize:16	lr:  0.05	hidsize:[64, 64]
# acc:0.744	batchsize:32	lr:0.0007	hidsize:[8, 8]
# acc:0.769	batchsize:32	lr:0.0007	hidsize:[16, 16]
# acc:0.787	batchsize:32	lr:0.0007	hidsize:[32, 32]
# acc:0.812	batchsize:32	lr:0.0007	hidsize:[64, 64]
# acc:0.756	batchsize:32	lr: 0.001	hidsize:[8, 8]
# acc:0.787	batchsize:32	lr: 0.001	hidsize:[16, 16]
# acc:0.794	batchsize:32	lr: 0.001	hidsize:[32, 32]
# acc:0.806	batchsize:32	lr: 0.001	hidsize:[64, 64]
# acc:0.787	batchsize:32	lr: 0.005	hidsize:[8, 8]
# acc:0.769	batchsize:32	lr: 0.005	hidsize:[16, 16]
# acc:0.806	batchsize:32	lr: 0.005	hidsize:[32, 32]
# acc:0.806	batchsize:32	lr: 0.005	hidsize:[64, 64]
# acc:0.731	batchsize:32	lr:  0.01	hidsize:[8, 8]
# acc:0.787	batchsize:32	lr:  0.01	hidsize:[16, 16]
# acc:0.838	batchsize:32	lr:  0.01	hidsize:[32, 32]
# acc:0.781	batchsize:32	lr:  0.01	hidsize:[64, 64]
# acc:0.737	batchsize:32	lr:  0.05	hidsize:[8, 8]
# acc:0.756	batchsize:32	lr:  0.05	hidsize:[16, 16]
# acc:0.75	batchsize:32	lr:  0.05	hidsize:[32, 32]
# acc:0.731	batchsize:32	lr:  0.05	hidsize:[64, 64]
# acc:0.756	batchsize:64	lr:0.0007	hidsize:[8, 8]
# acc:0.787	batchsize:64	lr:0.0007	hidsize:[16, 16]
# acc:0.781	batchsize:64	lr:0.0007	hidsize:[32, 32]
# acc: 0.8	batchsize:64	lr:0.0007	hidsize:[64, 64]
# acc:0.769	batchsize:64	lr: 0.001	hidsize:[8, 8]
# acc:0.787	batchsize:64	lr: 0.001	hidsize:[16, 16]
# acc:0.775	batchsize:64	lr: 0.001	hidsize:[32, 32]
# acc:0.806	batchsize:64	lr: 0.001	hidsize:[64, 64]
# acc:0.725	batchsize:64	lr: 0.005	hidsize:[8, 8]
# acc:0.787	batchsize:64	lr: 0.005	hidsize:[16, 16]
# acc:0.787	batchsize:64	lr: 0.005	hidsize:[32, 32]
# acc: 0.8	batchsize:64	lr: 0.005	hidsize:[64, 64]
# acc:0.725	batchsize:64	lr:  0.01	hidsize:[8, 8]
# acc:0.756	batchsize:64	lr:  0.01	hidsize:[16, 16]
# acc:0.775	batchsize:64	lr:  0.01	hidsize:[32, 32]
# acc:0.756	batchsize:64	lr:  0.01	hidsize:[64, 64]
# acc:0.681	batchsize:64	lr:  0.05	hidsize:[8, 8]
# acc:0.75	batchsize:64	lr:  0.05	hidsize:[16, 16]
# acc:0.719	batchsize:64	lr:  0.05	hidsize:[32, 32]
# acc:0.719	batchsize:64	lr:  0.05	hidsize:[64, 64]
# --------------------------------------
# | [PEER] best batchsize   | 32       |
# | [PEER] best hidsize     | [32, 32] |
# | [PEER] best learning... | 0.01     |
# --------------------------------------
# --------------------------------------
# | [NN] with bce loss      | 0.75     |
# | [NN] with peer loss     | 0.838    |
# | [NN] with surrogate ... | 0.862    |
# --------------------------------------
# Logging to logs/svm/19-08-29-14-00-45
# {'dataset': 'thyroid', 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'e0': 0.1, 'e1': 0.4, 'equalize_prior': True, 'episodes': 1000, 'alpha': 1.0}
# --------------------------------
# | [C-SVM] C1 = 0.1  | 0.663    |
# | [C-SVM] C1 = 0.2  | 0.663    |
# | [C-SVM] C1 = 0.25 | 0.663    |
# | [C-SVM] C1 = 0.33 | 0.663    |
# | [C-SVM] C1 = 0.5  | 0.702    |
# | [C-SVM] C1 = 1.0  | 0.788    |
# | [C-SVM] C1 = 10.0 | 0.385    |
# | [C-SVM] C1 = 2.0  | 0.798    |
# | [C-SVM] C1 = 3.0  | 0.788    |
# | [C-SVM] C1 = 4.0  | 0.769    |
# | [C-SVM] C1 = 5.0  | 0.663    |
# --------------------------------
# ------------------------------------
# | [C-SVM] accuracy max  | 1        |
# | [C-SVM] accuracy mean | 0.869    |
# | [C-SVM] accuracy min  | 0.8      |
# | [C-SVM] accuracy std  | 0.0609   |
# | [C-SVM] best C1       | 2        |
# ------------------------------------
# Logging to logs/pam/19-08-29-14-00-45
# {'dataset': 'thyroid', 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'e0': 0.1, 'e1': 0.4, 'equalize_prior': True, 'episodes': 1000, 'alpha': 1.0}
# -----------------------------------
# | [PAM] margin = 0     | 0.596    |
# | [PAM] margin = 0.125 | 0.75     |
# | [PAM] margin = 0.25  | 0.74     |
# | [PAM] margin = 0.5   | 0.74     |
# | [PAM] margin = 1     | 0.731    |
# -----------------------------------
# ----------------------------------
# | [PAM] accuracy max  | 0.85     |
# | [PAM] accuracy mean | 0.7      |
# | [PAM] accuracy min  | 0.6      |
# | [PAM] accuracy std  | 0.0791   |
# | [PAM] best margin   | 0.125    |
# ----------------------------------

# %% [markdown]
# ### $e_0 = 0.2, e_1 = 0.4$

# %%
from run_nn import find_best_alpha
args = default_args.copy()
args.update({
    'e0': 0.2, 'e1': 0.4, 
    'equalize_prior': True, 
    'episodes': 1000, 
    'batchsize': 4, 
    'hidsize': [32, 32], 
    'lr': 0.005, 
#     'alpha': 1.,
})
find_best_alpha(args)
# Out:
# ---------------------------------
# | [PEER] alpha = 0.1 | 0.781    |
# | [PEER] alpha = 0.2 | 0.806    |
# | [PEER] alpha = 0.3 | 0.794    |
# | [PEER] alpha = 0.4 | 0.781    |
# | [PEER] alpha = 0.5 | 0.825    |
# | [PEER] alpha = 0.6 | 0.838    |
# | [PEER] alpha = 0.7 | 0.844    |
# | [PEER] alpha = 0.8 | 0.863    |
# | [PEER] alpha = 0.9 | 0.825    |
# | [PEER] alpha = 1.0 | 0.806    |
# ---------------------------------
# {'alpha': 0.8}

# %% [markdown]
# Tune alpha from 0.7

# %%
from run_nn import run
args = default_args.copy()
args.update({
    'e0': 0.2, 'e1': 0.4, 
    'equalize_prior': True, 
    'episodes': 1000, 
    'batchsize': 4, 
    'hidsize': [32, 32], 
    'lr': 0.005, 
#     'alpha': 1.,
})
run(args)
# Out:
# Logging to logs/nn/19-08-29-14-20-21
# {'dataset': 'thyroid', 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'e0': 0.2, 'e1': 0.4, 'equalize_prior': True, 'episodes': 1000, 'batchsize': 4, 'hidsize': [32, 32], 'lr': 0.005}
# ---------------------------------
# | [PEER] alpha = 0.1 | 0.74     |
# | [PEER] alpha = 0.2 | 0.769    |
# | [PEER] alpha = 0.3 | 0.74     |
# | [PEER] alpha = 0.4 | 0.712    |
# | [PEER] alpha = 0.5 | 0.712    |
# | [PEER] alpha = 0.6 | 0.692    |
# | [PEER] alpha = 0.7 | 0.673    |
# | [PEER] alpha = 0.8 | 0.683    |
# | [PEER] alpha = 0.9 | 0.644    |
# | [PEER] alpha = 1.0 | 0.625    |
# ---------------------------------
# --------------------------------------
# | [NN] with bce loss      | 0.812    |
# | [NN] with peer loss     | 0.806    |
# | [NN] with surrogate ... | 0.862    |
# | [PEER] best alpha       | 0.2      |
# --------------------------------------

# %%
from runner import run
args = default_args.copy()
args.update({ 
    'e0': 0.2, 'e1': 0.4, 
    'equalize_prior': True, 
    'episodes': 1000, 
#     'batchsize': 64, 
#     'hidsize': [64, 64], 
#     'lr': 0.001, 
    'alpha': 1.,
})
run(args)
# Out:
# Logging to logs/nn/19-08-29-13-44-58
# {'dataset': 'thyroid', 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'e0': 0.2, 'e1': 0.4, 'equalize_prior': True, 'episodes': 1000, 'alpha': 1.0}
# acc:0.637	batchsize: 1	lr:0.0007	hidsize:[8, 8]
# acc:0.756	batchsize: 1	lr:0.0007	hidsize:[16, 16]
# acc:0.688	batchsize: 1	lr:0.0007	hidsize:[32, 32]
# acc:0.781	batchsize: 1	lr:0.0007	hidsize:[64, 64]
# acc:0.662	batchsize: 1	lr: 0.001	hidsize:[8, 8]
# acc:0.744	batchsize: 1	lr: 0.001	hidsize:[16, 16]
# acc:0.737	batchsize: 1	lr: 0.001	hidsize:[32, 32]
# acc:0.769	batchsize: 1	lr: 0.001	hidsize:[64, 64]
# acc:0.731	batchsize: 1	lr: 0.005	hidsize:[8, 8]
# acc:0.656	batchsize: 1	lr: 0.005	hidsize:[16, 16]
# acc:0.625	batchsize: 1	lr: 0.005	hidsize:[32, 32]
# acc:0.675	batchsize: 1	lr: 0.005	hidsize:[64, 64]
# acc:0.65	batchsize: 1	lr:  0.01	hidsize:[8, 8]
# acc:0.625	batchsize: 1	lr:  0.01	hidsize:[16, 16]
# acc:0.681	batchsize: 1	lr:  0.01	hidsize:[32, 32]
# acc:0.588	batchsize: 1	lr:  0.01	hidsize:[64, 64]
# acc:0.581	batchsize: 1	lr:  0.05	hidsize:[8, 8]
# acc:0.575	batchsize: 1	lr:  0.05	hidsize:[16, 16]
# acc:0.544	batchsize: 1	lr:  0.05	hidsize:[32, 32]
# acc:0.506	batchsize: 1	lr:  0.05	hidsize:[64, 64]
# acc:0.688	batchsize: 4	lr:0.0007	hidsize:[8, 8]
# acc:0.725	batchsize: 4	lr:0.0007	hidsize:[16, 16]
# acc:0.756	batchsize: 4	lr:0.0007	hidsize:[32, 32]
# acc:0.738	batchsize: 4	lr:0.0007	hidsize:[64, 64]
# acc:0.675	batchsize: 4	lr: 0.001	hidsize:[8, 8]
# acc:0.731	batchsize: 4	lr: 0.001	hidsize:[16, 16]
# acc:0.763	batchsize: 4	lr: 0.001	hidsize:[32, 32]
# acc:0.738	batchsize: 4	lr: 0.001	hidsize:[64, 64]
# acc:0.713	batchsize: 4	lr: 0.005	hidsize:[8, 8]
# acc:0.725	batchsize: 4	lr: 0.005	hidsize:[16, 16]
# acc:0.806	batchsize: 4	lr: 0.005	hidsize:[32, 32]
# acc: 0.8	batchsize: 4	lr: 0.005	hidsize:[64, 64]
# acc:0.737	batchsize: 4	lr:  0.01	hidsize:[8, 8]
# acc:0.706	batchsize: 4	lr:  0.01	hidsize:[16, 16]
# acc:0.769	batchsize: 4	lr:  0.01	hidsize:[32, 32]
# acc:0.763	batchsize: 4	lr:  0.01	hidsize:[64, 64]
# acc:0.606	batchsize: 4	lr:  0.05	hidsize:[8, 8]
# acc:0.644	batchsize: 4	lr:  0.05	hidsize:[16, 16]
# acc:0.669	batchsize: 4	lr:  0.05	hidsize:[32, 32]
# acc:0.556	batchsize: 4	lr:  0.05	hidsize:[64, 64]
# acc:0.681	batchsize:16	lr:0.0007	hidsize:[8, 8]
# acc:0.756	batchsize:16	lr:0.0007	hidsize:[16, 16]
# acc:0.719	batchsize:16	lr:0.0007	hidsize:[32, 32]
# acc:0.75	batchsize:16	lr:0.0007	hidsize:[64, 64]
# acc:0.688	batchsize:16	lr: 0.001	hidsize:[8, 8]
# acc:0.75	batchsize:16	lr: 0.001	hidsize:[16, 16]
# acc:0.719	batchsize:16	lr: 0.001	hidsize:[32, 32]
# acc:0.738	batchsize:16	lr: 0.001	hidsize:[64, 64]
# acc:0.675	batchsize:16	lr: 0.005	hidsize:[8, 8]
# acc:0.713	batchsize:16	lr: 0.005	hidsize:[16, 16]
# acc:0.719	batchsize:16	lr: 0.005	hidsize:[32, 32]
# acc:0.675	batchsize:16	lr: 0.005	hidsize:[64, 64]
# acc: 0.7	batchsize:16	lr:  0.01	hidsize:[8, 8]
# acc: 0.7	batchsize:16	lr:  0.01	hidsize:[16, 16]
# acc:0.719	batchsize:16	lr:  0.01	hidsize:[32, 32]
# acc:0.662	batchsize:16	lr:  0.01	hidsize:[64, 64]
# acc:0.663	batchsize:16	lr:  0.05	hidsize:[8, 8]
# acc:0.694	batchsize:16	lr:  0.05	hidsize:[16, 16]
# acc:0.619	batchsize:16	lr:  0.05	hidsize:[32, 32]
# acc:0.588	batchsize:16	lr:  0.05	hidsize:[64, 64]
# acc:0.694	batchsize:32	lr:0.0007	hidsize:[8, 8]
# acc:0.75	batchsize:32	lr:0.0007	hidsize:[16, 16]
# acc:0.744	batchsize:32	lr:0.0007	hidsize:[32, 32]
# acc:0.744	batchsize:32	lr:0.0007	hidsize:[64, 64]
# acc:0.706	batchsize:32	lr: 0.001	hidsize:[8, 8]
# acc:0.763	batchsize:32	lr: 0.001	hidsize:[16, 16]
# acc:0.75	batchsize:32	lr: 0.001	hidsize:[32, 32]
# acc:0.756	batchsize:32	lr: 0.001	hidsize:[64, 64]
# acc:0.719	batchsize:32	lr: 0.005	hidsize:[8, 8]
# acc:0.75	batchsize:32	lr: 0.005	hidsize:[16, 16]
# acc:0.756	batchsize:32	lr: 0.005	hidsize:[32, 32]
# acc:0.756	batchsize:32	lr: 0.005	hidsize:[64, 64]
# acc:0.737	batchsize:32	lr:  0.01	hidsize:[8, 8]
# acc:0.712	batchsize:32	lr:  0.01	hidsize:[16, 16]
# acc:0.744	batchsize:32	lr:  0.01	hidsize:[32, 32]
# acc:0.75	batchsize:32	lr:  0.01	hidsize:[64, 64]
# acc:0.787	batchsize:32	lr:  0.05	hidsize:[8, 8]
# acc:0.713	batchsize:32	lr:  0.05	hidsize:[16, 16]
# acc:0.713	batchsize:32	lr:  0.05	hidsize:[32, 32]
# acc:0.719	batchsize:32	lr:  0.05	hidsize:[64, 64]
# acc:0.719	batchsize:64	lr:0.0007	hidsize:[8, 8]
# acc:0.731	batchsize:64	lr:0.0007	hidsize:[16, 16]
# acc:0.737	batchsize:64	lr:0.0007	hidsize:[32, 32]
# acc:0.75	batchsize:64	lr:0.0007	hidsize:[64, 64]
# acc:0.713	batchsize:64	lr: 0.001	hidsize:[8, 8]
# acc:0.744	batchsize:64	lr: 0.001	hidsize:[16, 16]
# acc:0.744	batchsize:64	lr: 0.001	hidsize:[32, 32]
# acc:0.744	batchsize:64	lr: 0.001	hidsize:[64, 64]
# acc:0.725	batchsize:64	lr: 0.005	hidsize:[8, 8]
# acc:0.725	batchsize:64	lr: 0.005	hidsize:[16, 16]
# acc:0.719	batchsize:64	lr: 0.005	hidsize:[32, 32]
# acc:0.706	batchsize:64	lr: 0.005	hidsize:[64, 64]
# acc:0.694	batchsize:64	lr:  0.01	hidsize:[8, 8]
# acc:0.737	batchsize:64	lr:  0.01	hidsize:[16, 16]
# acc:0.706	batchsize:64	lr:  0.01	hidsize:[32, 32]
# acc:0.688	batchsize:64	lr:  0.01	hidsize:[64, 64]
# acc:0.719	batchsize:64	lr:  0.05	hidsize:[8, 8]
# acc:0.713	batchsize:64	lr:  0.05	hidsize:[16, 16]
# acc:0.675	batchsize:64	lr:  0.05	hidsize:[32, 32]
# acc:0.638	batchsize:64	lr:  0.05	hidsize:[64, 64]
# --------------------------------------
# | [PEER] best batchsize   | 4        |
# | [PEER] best hidsize     | [32, 32] |
# | [PEER] best learning... | 0.005    |
# --------------------------------------
# --------------------------------------
# | [NN] with bce loss      | 0.812    |
# | [NN] with peer loss     | 0.806    |
# | [NN] with surrogate ... | 0.862    |
# --------------------------------------
# Logging to logs/svm/19-08-29-13-50-10
# {'dataset': 'thyroid', 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'e0': 0.2, 'e1': 0.4, 'equalize_prior': True, 'episodes': 1000, 'alpha': 1.0}
# --------------------------------
# | [C-SVM] C1 = 0.1  | 0.596    |
# | [C-SVM] C1 = 0.2  | 0.596    |
# | [C-SVM] C1 = 0.25 | 0.596    |
# | [C-SVM] C1 = 0.33 | 0.596    |
# | [C-SVM] C1 = 0.5  | 0.644    |
# | [C-SVM] C1 = 1.0  | 0.731    |
# | [C-SVM] C1 = 10.0 | 0.404    |
# | [C-SVM] C1 = 2.0  | 0.731    |
# | [C-SVM] C1 = 3.0  | 0.635    |
# | [C-SVM] C1 = 4.0  | 0.452    |
# | [C-SVM] C1 = 5.0  | 0.404    |
# --------------------------------
# ------------------------------------
# | [C-SVM] accuracy max  | 0.85     |
# | [C-SVM] accuracy mean | 0.781    |
# | [C-SVM] accuracy min  | 0.7      |
# | [C-SVM] accuracy std  | 0.0556   |
# | [C-SVM] best C1       | 1        |
# ------------------------------------
# Logging to logs/pam/19-08-29-13-50-10
# {'dataset': 'thyroid', 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'e0': 0.2, 'e1': 0.4, 'equalize_prior': True, 'episodes': 1000, 'alpha': 1.0}
# -----------------------------------
# | [PAM] margin = 0     | 0.577    |
# | [PAM] margin = 0.125 | 0.702    |
# | [PAM] margin = 0.25  | 0.712    |
# | [PAM] margin = 0.5   | 0.702    |
# | [PAM] margin = 1     | 0.692    |
# -----------------------------------
# ----------------------------------
# | [PAM] accuracy max  | 0.8      |
# | [PAM] accuracy mean | 0.681    |
# | [PAM] accuracy min  | 0.6      |
# | [PAM] accuracy std  | 0.0747   |
# | [PAM] best margin   | 0.25     |
# ----------------------------------

# %% [markdown]
# ### $e_0=0.4, e_1=0.4$

# %%
from run_nn import find_best_alpha
args = default_args.copy()
args.update({
    'e0': 0.4, 'e1': 0.4, 
    'equalize_prior': True, 
    'episodes': 1000, 
    'batchsize': 4, 
    'hidsize': [32, 32], 
    'lr': 0.005, 
#     'alpha': 1.,
})
find_best_alpha(args)
# Out:
# ---------------------------------
# | [PEER] alpha = 0.1 | 0.619    |
# | [PEER] alpha = 0.2 | 0.6      |
# | [PEER] alpha = 0.3 | 0.619    |
# | [PEER] alpha = 0.4 | 0.613    |
# | [PEER] alpha = 0.5 | 0.613    |
# | [PEER] alpha = 0.6 | 0.675    |
# | [PEER] alpha = 0.7 | 0.762    |
# | [PEER] alpha = 0.8 | 0.731    |
# | [PEER] alpha = 0.9 | 0.706    |
# | [PEER] alpha = 1.0 | 0.713    |
# ---------------------------------
# {'alpha': 0.7}

# %%
from run_nn import run
args = default_args.copy()
args.update({
    'e0': 0.4, 'e1': 0.4, 
    'equalize_prior': True, 
    'episodes': 1000, 
    'batchsize': 4, 
    'hidsize': [32, 32], 
    'lr': 0.005, 
#     'alpha': 1.,
})
run(args)
# Out:
# Logging to logs/nn/19-08-29-14-17-21
# {'dataset': 'thyroid', 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'e0': 0.4, 'e1': 0.4, 'equalize_prior': True, 'episodes': 1000, 'batchsize': 4, 'hidsize': [32, 32], 'lr': 0.005}
# ---------------------------------
# | [PEER] alpha = 0.1 | 0.519    |
# | [PEER] alpha = 0.2 | 0.538    |
# | [PEER] alpha = 0.3 | 0.519    |
# | [PEER] alpha = 0.4 | 0.577    |
# | [PEER] alpha = 0.5 | 0.558    |
# | [PEER] alpha = 0.6 | 0.558    |
# | [PEER] alpha = 0.7 | 0.635    |
# | [PEER] alpha = 0.8 | 0.567    |
# | [PEER] alpha = 0.9 | 0.5      |
# | [PEER] alpha = 1.0 | 0.51     |
# ---------------------------------
# --------------------------------------
# | [NN] with bce loss      | 0.669    |
# | [NN] with peer loss     | 0.762    |
# | [NN] with surrogate ... | 0.738    |
# | [PEER] best alpha       | 0.7      |
# --------------------------------------

# %%
from runner import run
args = default_args.copy()
args.update({
    'e0': 0.4, 'e1': 0.4, 
    'equalize_prior': True, 
    'episodes': 1000, 
#     'batchsize': 64, 
#     'hidsize': [64, 64], 
#     'lr': 0.001, 
    'alpha': 1.,
})
run(args)
# Out:
# Logging to logs/nn/19-08-29-13-50-12
# {'dataset': 'thyroid', 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'e0': 0.4, 'e1': 0.4, 'equalize_prior': True, 'episodes': 1000, 'alpha': 1.0}
# acc:0.631	batchsize: 1	lr:0.0007	hidsize:[8, 8]
# acc:0.688	batchsize: 1	lr:0.0007	hidsize:[16, 16]
# acc:0.619	batchsize: 1	lr:0.0007	hidsize:[32, 32]
# acc:0.688	batchsize: 1	lr:0.0007	hidsize:[64, 64]
# acc: 0.6	batchsize: 1	lr: 0.001	hidsize:[8, 8]
# acc:0.669	batchsize: 1	lr: 0.001	hidsize:[16, 16]
# acc:0.606	batchsize: 1	lr: 0.001	hidsize:[32, 32]
# acc:0.669	batchsize: 1	lr: 0.001	hidsize:[64, 64]
# acc:0.688	batchsize: 1	lr: 0.005	hidsize:[8, 8]
# acc:0.675	batchsize: 1	lr: 0.005	hidsize:[16, 16]
# acc:0.625	batchsize: 1	lr: 0.005	hidsize:[32, 32]
# acc:0.594	batchsize: 1	lr: 0.005	hidsize:[64, 64]
# acc:0.662	batchsize: 1	lr:  0.01	hidsize:[8, 8]
# acc:0.638	batchsize: 1	lr:  0.01	hidsize:[16, 16]
# acc:0.556	batchsize: 1	lr:  0.01	hidsize:[32, 32]
# acc:0.575	batchsize: 1	lr:  0.01	hidsize:[64, 64]
# acc: 0.5	batchsize: 1	lr:  0.05	hidsize:[8, 8]
# acc:0.488	batchsize: 1	lr:  0.05	hidsize:[16, 16]
# acc:0.525	batchsize: 1	lr:  0.05	hidsize:[32, 32]
# acc:0.469	batchsize: 1	lr:  0.05	hidsize:[64, 64]
# acc:0.644	batchsize: 4	lr:0.0007	hidsize:[8, 8]
# acc: 0.6	batchsize: 4	lr:0.0007	hidsize:[16, 16]
# acc:0.606	batchsize: 4	lr:0.0007	hidsize:[32, 32]
# acc:0.656	batchsize: 4	lr:0.0007	hidsize:[64, 64]
# acc:0.631	batchsize: 4	lr: 0.001	hidsize:[8, 8]
# acc:0.588	batchsize: 4	lr: 0.001	hidsize:[16, 16]
# acc:0.644	batchsize: 4	lr: 0.001	hidsize:[32, 32]
# acc:0.688	batchsize: 4	lr: 0.001	hidsize:[64, 64]
# acc:0.625	batchsize: 4	lr: 0.005	hidsize:[8, 8]
# acc:0.681	batchsize: 4	lr: 0.005	hidsize:[16, 16]
# acc:0.713	batchsize: 4	lr: 0.005	hidsize:[32, 32]
# acc:0.631	batchsize: 4	lr: 0.005	hidsize:[64, 64]
# acc:0.681	batchsize: 4	lr:  0.01	hidsize:[8, 8]
# acc:0.619	batchsize: 4	lr:  0.01	hidsize:[16, 16]
# acc:0.625	batchsize: 4	lr:  0.01	hidsize:[32, 32]
# acc:0.644	batchsize: 4	lr:  0.01	hidsize:[64, 64]
# acc:0.619	batchsize: 4	lr:  0.05	hidsize:[8, 8]
# acc:0.575	batchsize: 4	lr:  0.05	hidsize:[16, 16]
# acc:0.637	batchsize: 4	lr:  0.05	hidsize:[32, 32]
# acc:0.612	batchsize: 4	lr:  0.05	hidsize:[64, 64]
# acc: 0.6	batchsize:16	lr:0.0007	hidsize:[8, 8]
# acc:0.631	batchsize:16	lr:0.0007	hidsize:[16, 16]
# acc:0.606	batchsize:16	lr:0.0007	hidsize:[32, 32]
# acc:0.681	batchsize:16	lr:0.0007	hidsize:[64, 64]
# acc:0.613	batchsize:16	lr: 0.001	hidsize:[8, 8]
# acc:0.662	batchsize:16	lr: 0.001	hidsize:[16, 16]
# acc:0.612	batchsize:16	lr: 0.001	hidsize:[32, 32]
# acc:0.669	batchsize:16	lr: 0.001	hidsize:[64, 64]
# acc:0.662	batchsize:16	lr: 0.005	hidsize:[8, 8]
# acc:0.662	batchsize:16	lr: 0.005	hidsize:[16, 16]
# acc:0.625	batchsize:16	lr: 0.005	hidsize:[32, 32]
# acc:0.669	batchsize:16	lr: 0.005	hidsize:[64, 64]
# acc:0.662	batchsize:16	lr:  0.01	hidsize:[8, 8]
# acc:0.637	batchsize:16	lr:  0.01	hidsize:[16, 16]
# acc:0.644	batchsize:16	lr:  0.01	hidsize:[32, 32]
# acc:0.662	batchsize:16	lr:  0.01	hidsize:[64, 64]
# acc:0.662	batchsize:16	lr:  0.05	hidsize:[8, 8]
# acc:0.638	batchsize:16	lr:  0.05	hidsize:[16, 16]
# acc:0.625	batchsize:16	lr:  0.05	hidsize:[32, 32]
# acc:0.612	batchsize:16	lr:  0.05	hidsize:[64, 64]
# acc:0.606	batchsize:32	lr:0.0007	hidsize:[8, 8]
# acc:0.675	batchsize:32	lr:0.0007	hidsize:[16, 16]
# acc:0.637	batchsize:32	lr:0.0007	hidsize:[32, 32]
# acc:0.688	batchsize:32	lr:0.0007	hidsize:[64, 64]
# acc:0.619	batchsize:32	lr: 0.001	hidsize:[8, 8]
# acc:0.662	batchsize:32	lr: 0.001	hidsize:[16, 16]
# acc:0.662	batchsize:32	lr: 0.001	hidsize:[32, 32]
# acc:0.706	batchsize:32	lr: 0.001	hidsize:[64, 64]
# acc:0.662	batchsize:32	lr: 0.005	hidsize:[8, 8]
# acc:0.656	batchsize:32	lr: 0.005	hidsize:[16, 16]
# acc:0.65	batchsize:32	lr: 0.005	hidsize:[32, 32]
# acc:0.669	batchsize:32	lr: 0.005	hidsize:[64, 64]
# acc:0.625	batchsize:32	lr:  0.01	hidsize:[8, 8]
# acc:0.644	batchsize:32	lr:  0.01	hidsize:[16, 16]
# acc:0.65	batchsize:32	lr:  0.01	hidsize:[32, 32]
# acc:0.656	batchsize:32	lr:  0.01	hidsize:[64, 64]
# acc:0.637	batchsize:32	lr:  0.05	hidsize:[8, 8]
# acc:0.637	batchsize:32	lr:  0.05	hidsize:[16, 16]
# acc:0.637	batchsize:32	lr:  0.05	hidsize:[32, 32]
# acc:0.613	batchsize:32	lr:  0.05	hidsize:[64, 64]
# acc: 0.6	batchsize:64	lr:0.0007	hidsize:[8, 8]
# acc:0.663	batchsize:64	lr:0.0007	hidsize:[16, 16]
# acc:0.65	batchsize:64	lr:0.0007	hidsize:[32, 32]
# acc:0.675	batchsize:64	lr:0.0007	hidsize:[64, 64]
# acc:0.638	batchsize:64	lr: 0.001	hidsize:[8, 8]
# acc:0.669	batchsize:64	lr: 0.001	hidsize:[16, 16]
# acc:0.656	batchsize:64	lr: 0.001	hidsize:[32, 32]
# acc:0.681	batchsize:64	lr: 0.001	hidsize:[64, 64]
# acc:0.644	batchsize:64	lr: 0.005	hidsize:[8, 8]
# acc:0.669	batchsize:64	lr: 0.005	hidsize:[16, 16]
# acc:0.675	batchsize:64	lr: 0.005	hidsize:[32, 32]
# acc:0.662	batchsize:64	lr: 0.005	hidsize:[64, 64]
# acc:0.613	batchsize:64	lr:  0.01	hidsize:[8, 8]
# acc:0.669	batchsize:64	lr:  0.01	hidsize:[16, 16]
# acc:0.65	batchsize:64	lr:  0.01	hidsize:[32, 32]
# acc:0.637	batchsize:64	lr:  0.01	hidsize:[64, 64]
# acc:0.625	batchsize:64	lr:  0.05	hidsize:[8, 8]
# acc:0.631	batchsize:64	lr:  0.05	hidsize:[16, 16]
# acc:0.619	batchsize:64	lr:  0.05	hidsize:[32, 32]
# acc:0.619	batchsize:64	lr:  0.05	hidsize:[64, 64]
# --------------------------------------
# | [PEER] best batchsize   | 4        |
# | [PEER] best hidsize     | [32, 32] |
# | [PEER] best learning... | 0.005    |
# --------------------------------------
# --------------------------------------
# | [NN] with bce loss      | 0.669    |
# | [NN] with peer loss     | 0.713    |
# | [NN] with surrogate ... | 0.738    |
# --------------------------------------
# Logging to logs/svm/19-08-29-13-55-25
# {'dataset': 'thyroid', 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'e0': 0.4, 'e1': 0.4, 'equalize_prior': True, 'episodes': 1000, 'alpha': 1.0}
# --------------------------------
# | [C-SVM] C1 = 0.1  | 0.5      |
# | [C-SVM] C1 = 0.2  | 0.5      |
# | [C-SVM] C1 = 0.25 | 0.5      |
# | [C-SVM] C1 = 0.33 | 0.5      |
# | [C-SVM] C1 = 0.5  | 0.548    |
# | [C-SVM] C1 = 1.0  | 0.663    |
# | [C-SVM] C1 = 10.0 | 0.5      |
# | [C-SVM] C1 = 2.0  | 0.49     |
# | [C-SVM] C1 = 3.0  | 0.5      |
# | [C-SVM] C1 = 4.0  | 0.5      |
# | [C-SVM] C1 = 5.0  | 0.5      |
# --------------------------------
# ------------------------------------
# | [C-SVM] accuracy max  | 0.9      |
# | [C-SVM] accuracy mean | 0.781    |
# | [C-SVM] accuracy min  | 0.7      |
# | [C-SVM] accuracy std  | 0.0747   |
# | [C-SVM] best C1       | 1        |
# ------------------------------------
# Logging to logs/pam/19-08-29-13-55-25
# {'dataset': 'thyroid', 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'e0': 0.4, 'e1': 0.4, 'equalize_prior': True, 'episodes': 1000, 'alpha': 1.0}
# -----------------------------------
# | [PAM] margin = 0     | 0.538    |
# | [PAM] margin = 0.125 | 0.615    |
# | [PAM] margin = 0.25  | 0.587    |
# | [PAM] margin = 0.5   | 0.577    |
# | [PAM] margin = 1     | 0.587    |
# -----------------------------------
# ----------------------------------
# | [PAM] accuracy max  | 0.8      |
# | [PAM] accuracy mean | 0.663    |
# | [PAM] accuracy min  | 0.35     |
# | [PAM] accuracy std  | 0.145    |
# | [PAM] best margin   | 0.125    |
# ----------------------------------

# %%
from runner import run
args = default_args.copy()
args.update({
    'e0': 0.4, 'e1': 0.4, 
    'equalize_prior': True, 
    'episodes': 1000, 
    'batchsize': 4, 
    'hidsize': [32, 32], 
    'lr': 0.005, 
#     'alpha': 1.,
})
run(args)
# Out:
# Logging to logs/nn/19-08-29-14-06-07
# {'dataset': 'thyroid', 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'e0': 0.4, 'e1': 0.4, 'equalize_prior': True, 'episodes': 1000, 'batchsize': 4, 'hidsize': [32, 32], 'lr': 0.005}
# ---------------------------------
# | [PEER] alpha = 0.1 | 0.519    |
# | [PEER] alpha = 0.2 | 0.538    |
# | [PEER] alpha = 0.3 | 0.519    |
# | [PEER] alpha = 0.4 | 0.577    |
# | [PEER] alpha = 0.5 | 0.558    |
# | [PEER] alpha = 0.6 | 0.558    |
# | [PEER] alpha = 0.7 | 0.635    |
# | [PEER] alpha = 0.8 | 0.567    |
# | [PEER] alpha = 0.9 | 0.5      |
# | [PEER] alpha = 1.0 | 0.51     |
# ---------------------------------
# --------------------------------------
# | [NN] with bce loss      | 0.669    |
# | [NN] with peer loss     | 0.762    |
# | [NN] with surrogate ... | 0.738    |
# | [PEER] best alpha       | 0.7      |
# --------------------------------------
# Logging to logs/svm/19-08-29-14-06-38
# {'dataset': 'thyroid', 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'e0': 0.4, 'e1': 0.4, 'equalize_prior': True, 'episodes': 1000, 'batchsize': 4, 'hidsize': [32, 32], 'lr': 0.005}
# --------------------------------
# | [C-SVM] C1 = 0.1  | 0.5      |
# | [C-SVM] C1 = 0.2  | 0.5      |
# | [C-SVM] C1 = 0.25 | 0.5      |
# | [C-SVM] C1 = 0.33 | 0.5      |
# | [C-SVM] C1 = 0.5  | 0.548    |
# | [C-SVM] C1 = 1.0  | 0.663    |
# | [C-SVM] C1 = 10.0 | 0.5      |
# | [C-SVM] C1 = 2.0  | 0.49     |
# | [C-SVM] C1 = 3.0  | 0.5      |
# | [C-SVM] C1 = 4.0  | 0.5      |
# | [C-SVM] C1 = 5.0  | 0.5      |
# --------------------------------
# ------------------------------------
# | [C-SVM] accuracy max  | 0.9      |
# | [C-SVM] accuracy mean | 0.781    |
# | [C-SVM] accuracy min  | 0.7      |
# | [C-SVM] accuracy std  | 0.0747   |
# | [C-SVM] best C1       | 1        |
# ------------------------------------
# Logging to logs/pam/19-08-29-14-06-39
# {'dataset': 'thyroid', 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'e0': 0.4, 'e1': 0.4, 'equalize_prior': True, 'episodes': 1000, 'batchsize': 4, 'hidsize': [32, 32], 'lr': 0.005}
# -----------------------------------
# | [PAM] margin = 0     | 0.538    |
# | [PAM] margin = 0.125 | 0.615    |
# | [PAM] margin = 0.25  | 0.587    |
# | [PAM] margin = 0.5   | 0.577    |
# | [PAM] margin = 1     | 0.587    |
# -----------------------------------
# ----------------------------------
# | [PAM] accuracy max  | 0.8      |
# | [PAM] accuracy mean | 0.663    |
# | [PAM] accuracy min  | 0.35     |
# | [PAM] accuracy std  | 0.145    |
# | [PAM] best margin   | 0.125    |
# ----------------------------------

# %% [markdown]
# ## Without Prior Equalization

# %% [markdown]
# ### $e_0 = 0.1, e_1 = 0.3$

# %%
from run_nn import find_best_alpha

args = default_args.copy()
args.update({
    'dataset': 'thyroid', 
    'e0': 0.1, 'e1': 0.3, 
    'equalize_prior': False, 
    'episodes': 1000, 
    'batchsize': 4, 
    'hidsize': [64, 64], 
    'lr': 0.0007,
})
find_best_alpha(args)
# Out:
# ---------------------------------
# | [PEER] alpha = 0.1 | 0.879    |
# | [PEER] alpha = 0.2 | 0.898    |
# | [PEER] alpha = 0.3 | 0.909    |
# | [PEER] alpha = 0.4 | 0.924    |
# | [PEER] alpha = 0.5 | 0.943    |
# | [PEER] alpha = 0.6 | 0.936    |
# | [PEER] alpha = 0.7 | 0.936    |
# | [PEER] alpha = 0.8 | 0.936    |
# | [PEER] alpha = 0.9 | 0.909    |
# | [PEER] alpha = 1.0 | 0.803    |
# ---------------------------------
# {'alpha': 0.5}

# %%
from runner import run
args = default_args.copy()
args.update({
    'e0': 0.1, 'e1': 0.3, 
    'equalize_prior': False, 
    'episodes': 1000
})
run(args)
# Out:
# Logging to logs/nn/19-08-29-14-50-27
# {'dataset': 'thyroid', 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'e0': 0.1, 'e1': 0.3, 'equalize_prior': False, 'episodes': 1000}
# acc:0.678	batchsize: 1	lr:0.0007	hidsize:[8, 8]
# acc:0.735	batchsize: 1	lr:0.0007	hidsize:[16, 16]
# acc:0.636	batchsize: 1	lr:0.0007	hidsize:[32, 32]
# acc:0.705	batchsize: 1	lr:0.0007	hidsize:[64, 64]
# acc:0.678	batchsize: 1	lr: 0.001	hidsize:[8, 8]
# acc:0.723	batchsize: 1	lr: 0.001	hidsize:[16, 16]
# acc:0.674	batchsize: 1	lr: 0.001	hidsize:[32, 32]
# acc:0.705	batchsize: 1	lr: 0.001	hidsize:[64, 64]
# acc:0.72	batchsize: 1	lr: 0.005	hidsize:[8, 8]
# acc:0.742	batchsize: 1	lr: 0.005	hidsize:[16, 16]
# acc:0.636	batchsize: 1	lr: 0.005	hidsize:[32, 32]
# acc:0.708	batchsize: 1	lr: 0.005	hidsize:[64, 64]
# acc:0.735	batchsize: 1	lr:  0.01	hidsize:[8, 8]
# acc:0.727	batchsize: 1	lr:  0.01	hidsize:[16, 16]
# acc:0.731	batchsize: 1	lr:  0.01	hidsize:[32, 32]
# acc:0.682	batchsize: 1	lr:  0.01	hidsize:[64, 64]
# acc:0.629	batchsize: 1	lr:  0.05	hidsize:[8, 8]
# acc:0.663	batchsize: 1	lr:  0.05	hidsize:[16, 16]
# acc:0.625	batchsize: 1	lr:  0.05	hidsize:[32, 32]
# acc:0.633	batchsize: 1	lr:  0.05	hidsize:[64, 64]
# acc:0.67	batchsize: 4	lr:0.0007	hidsize:[8, 8]
# acc:0.769	batchsize: 4	lr:0.0007	hidsize:[16, 16]
# acc:0.705	batchsize: 4	lr:0.0007	hidsize:[32, 32]
# acc:0.803	batchsize: 4	lr:0.0007	hidsize:[64, 64]
# acc:0.64	batchsize: 4	lr: 0.001	hidsize:[8, 8]
# acc:0.765	batchsize: 4	lr: 0.001	hidsize:[16, 16]
# acc:0.716	batchsize: 4	lr: 0.001	hidsize:[32, 32]
# acc:0.803	batchsize: 4	lr: 0.001	hidsize:[64, 64]
# acc:0.799	batchsize: 4	lr: 0.005	hidsize:[8, 8]
# acc:0.777	batchsize: 4	lr: 0.005	hidsize:[16, 16]
# acc:0.708	batchsize: 4	lr: 0.005	hidsize:[32, 32]
# acc:0.769	batchsize: 4	lr: 0.005	hidsize:[64, 64]
# acc:0.799	batchsize: 4	lr:  0.01	hidsize:[8, 8]
# acc:0.758	batchsize: 4	lr:  0.01	hidsize:[16, 16]
# acc:0.75	batchsize: 4	lr:  0.01	hidsize:[32, 32]
# acc:0.746	batchsize: 4	lr:  0.01	hidsize:[64, 64]
# acc:0.64	batchsize: 4	lr:  0.05	hidsize:[8, 8]
# acc:0.705	batchsize: 4	lr:  0.05	hidsize:[16, 16]
# acc:0.682	batchsize: 4	lr:  0.05	hidsize:[32, 32]
# acc:0.636	batchsize: 4	lr:  0.05	hidsize:[64, 64]
# acc:0.686	batchsize:16	lr:0.0007	hidsize:[8, 8]
# acc:0.754	batchsize:16	lr:0.0007	hidsize:[16, 16]
# acc:0.705	batchsize:16	lr:0.0007	hidsize:[32, 32]
# acc:0.765	batchsize:16	lr:0.0007	hidsize:[64, 64]
# acc:0.705	batchsize:16	lr: 0.001	hidsize:[8, 8]
# acc:0.75	batchsize:16	lr: 0.001	hidsize:[16, 16]
# acc:0.693	batchsize:16	lr: 0.001	hidsize:[32, 32]
# acc:0.75	batchsize:16	lr: 0.001	hidsize:[64, 64]
# acc:0.723	batchsize:16	lr: 0.005	hidsize:[8, 8]
# acc:0.682	batchsize:16	lr: 0.005	hidsize:[16, 16]
# acc:0.663	batchsize:16	lr: 0.005	hidsize:[32, 32]
# acc:0.655	batchsize:16	lr: 0.005	hidsize:[64, 64]
# acc:0.701	batchsize:16	lr:  0.01	hidsize:[8, 8]
# acc:0.708	batchsize:16	lr:  0.01	hidsize:[16, 16]
# acc:0.629	batchsize:16	lr:  0.01	hidsize:[32, 32]
# acc:0.648	batchsize:16	lr:  0.01	hidsize:[64, 64]
# acc:0.67	batchsize:16	lr:  0.05	hidsize:[8, 8]
# acc:0.663	batchsize:16	lr:  0.05	hidsize:[16, 16]
# acc:0.576	batchsize:16	lr:  0.05	hidsize:[32, 32]
# acc:0.625	batchsize:16	lr:  0.05	hidsize:[64, 64]
# acc:0.701	batchsize:32	lr:0.0007	hidsize:[8, 8]
# acc:0.735	batchsize:32	lr:0.0007	hidsize:[16, 16]
# acc:0.742	batchsize:32	lr:0.0007	hidsize:[32, 32]
# acc:0.75	batchsize:32	lr:0.0007	hidsize:[64, 64]
# acc:0.731	batchsize:32	lr: 0.001	hidsize:[8, 8]
# acc:0.735	batchsize:32	lr: 0.001	hidsize:[16, 16]
# acc:0.739	batchsize:32	lr: 0.001	hidsize:[32, 32]
# acc:0.727	batchsize:32	lr: 0.001	hidsize:[64, 64]
# acc:0.727	batchsize:32	lr: 0.005	hidsize:[8, 8]
# acc:0.697	batchsize:32	lr: 0.005	hidsize:[16, 16]
# acc:0.678	batchsize:32	lr: 0.005	hidsize:[32, 32]
# acc:0.689	batchsize:32	lr: 0.005	hidsize:[64, 64]
# acc:0.693	batchsize:32	lr:  0.01	hidsize:[8, 8]
# acc:0.667	batchsize:32	lr:  0.01	hidsize:[16, 16]
# acc:0.652	batchsize:32	lr:  0.01	hidsize:[32, 32]
# acc:0.667	batchsize:32	lr:  0.01	hidsize:[64, 64]
# acc:0.621	batchsize:32	lr:  0.05	hidsize:[8, 8]
# acc:0.636	batchsize:32	lr:  0.05	hidsize:[16, 16]
# acc:0.587	batchsize:32	lr:  0.05	hidsize:[32, 32]
# acc:0.598	batchsize:32	lr:  0.05	hidsize:[64, 64]
# acc:0.723	batchsize:64	lr:0.0007	hidsize:[8, 8]
# acc:0.723	batchsize:64	lr:0.0007	hidsize:[16, 16]
# acc:0.731	batchsize:64	lr:0.0007	hidsize:[32, 32]
# acc:0.75	batchsize:64	lr:0.0007	hidsize:[64, 64]
# acc:0.712	batchsize:64	lr: 0.001	hidsize:[8, 8]
# acc:0.746	batchsize:64	lr: 0.001	hidsize:[16, 16]
# acc:0.742	batchsize:64	lr: 0.001	hidsize:[32, 32]
# acc:0.746	batchsize:64	lr: 0.001	hidsize:[64, 64]
# acc:0.708	batchsize:64	lr: 0.005	hidsize:[8, 8]
# acc:0.708	batchsize:64	lr: 0.005	hidsize:[16, 16]
# acc:0.705	batchsize:64	lr: 0.005	hidsize:[32, 32]
# acc:0.708	batchsize:64	lr: 0.005	hidsize:[64, 64]
# acc:0.705	batchsize:64	lr:  0.01	hidsize:[8, 8]
# acc:0.705	batchsize:64	lr:  0.01	hidsize:[16, 16]
# acc:0.705	batchsize:64	lr:  0.01	hidsize:[32, 32]
# acc:0.705	batchsize:64	lr:  0.01	hidsize:[64, 64]
# acc:0.678	batchsize:64	lr:  0.05	hidsize:[8, 8]
# acc:0.636	batchsize:64	lr:  0.05	hidsize:[16, 16]
# acc:0.667	batchsize:64	lr:  0.05	hidsize:[32, 32]
# acc:0.686	batchsize:64	lr:  0.05	hidsize:[64, 64]
# --------------------------------------
# | [PEER] best batchsize   | 4        |
# | [PEER] best hidsize     | [64, 64] |
# | [PEER] best learning... | 0.0007   |
# --------------------------------------
# ---------------------------------
# | [PEER] alpha = 0.1 | 0.847    |
# | [PEER] alpha = 0.2 | 0.841    |
# | [PEER] alpha = 0.3 | 0.858    |
# | [PEER] alpha = 0.4 | 0.858    |
# | [PEER] alpha = 0.5 | 0.864    |
# | [PEER] alpha = 0.6 | 0.835    |
# | [PEER] alpha = 0.7 | 0.852    |
# | [PEER] alpha = 0.8 | 0.824    |
# | [PEER] alpha = 0.9 | 0.807    |
# | [PEER] alpha = 1.0 | 0.705    |
# ---------------------------------
# --------------------------------------
# | [NN] with bce loss      | 0.856    |
# | [NN] with peer loss     | 0.943    |
# | [NN] with surrogate ... | 0.909    |
# | [PEER] best alpha       | 0.5      |
# --------------------------------------
# Logging to logs/svm/19-08-29-14-56-31
# {'dataset': 'thyroid', 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'e0': 0.1, 'e1': 0.3, 'equalize_prior': False, 'episodes': 1000}
# --------------------------------
# | [C-SVM] C1 = 0.1  | 0.705    |
# | [C-SVM] C1 = 0.2  | 0.705    |
# | [C-SVM] C1 = 0.25 | 0.705    |
# | [C-SVM] C1 = 0.33 | 0.71     |
# | [C-SVM] C1 = 0.5  | 0.778    |
# | [C-SVM] C1 = 1.0  | 0.841    |
# | [C-SVM] C1 = 10.0 | 0.477    |
# | [C-SVM] C1 = 2.0  | 0.852    |
# | [C-SVM] C1 = 3.0  | 0.858    |
# | [C-SVM] C1 = 4.0  | 0.835    |
# | [C-SVM] C1 = 5.0  | 0.784    |
# --------------------------------
# ------------------------------------
# | [C-SVM] accuracy max  | 1        |
# | [C-SVM] accuracy mean | 0.924    |
# | [C-SVM] accuracy min  | 0.848    |
# | [C-SVM] accuracy std  | 0.0525   |
# | [C-SVM] best C1       | 3        |
# ------------------------------------
# Logging to logs/pam/19-08-29-14-56-31
# {'dataset': 'thyroid', 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'e0': 0.1, 'e1': 0.3, 'equalize_prior': False, 'episodes': 1000}
# -----------------------------------
# | [PAM] margin = 0     | 0.739    |
# | [PAM] margin = 0.125 | 0.756    |
# | [PAM] margin = 0.25  | 0.756    |
# | [PAM] margin = 0.5   | 0.744    |
# | [PAM] margin = 1     | 0.744    |
# -----------------------------------
# ----------------------------------
# | [PAM] accuracy max  | 0.848    |
# | [PAM] accuracy mean | 0.761    |
# | [PAM] accuracy min  | 0.636    |
# | [PAM] accuracy std  | 0.0685   |
# | [PAM] best margin   | 0.125    |
# ----------------------------------

# %% [markdown]
# ### $e_0 = 0.2, e_1 = 0.2$

# %%
from run_nn import find_best_alpha

args = default_args.copy()
args.update({
    'dataset': 'thyroid', 
    'e0': 0.2, 'e1': 0.2, 
    'equalize_prior': False, 
    'episodes': 1000, 
    'batchsize': 64, 
    'hidsize': [8, 8], 
    'lr': 0.01,
})
find_best_alpha(args)
# Out:
# ---------------------------------
# | [PEER] alpha = 0.1 | 0.792    |
# | [PEER] alpha = 0.2 | 0.773    |
# | [PEER] alpha = 0.3 | 0.875    |
# | [PEER] alpha = 0.4 | 0.845    |
# | [PEER] alpha = 0.5 | 0.905    |
# | [PEER] alpha = 0.6 | 0.902    |
# | [PEER] alpha = 0.7 | 0.883    |
# | [PEER] alpha = 0.8 | 0.852    |
# | [PEER] alpha = 0.9 | 0.845    |
# | [PEER] alpha = 1.0 | 0.754    |
# ---------------------------------
# {'alpha': 0.5}

# %%
from runner import run

args = default_args.copy()
args.update({
    'e0': 0.2, 'e1': 0.2, 
    'equalize_prior': False, 
    'episodes': 1000
})
run(args)
# Out:
# Logging to logs/nn/19-08-29-14-44-50
# {'dataset': 'thyroid', 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'e0': 0.2, 'e1': 0.2, 'equalize_prior': False, 'episodes': 1000}
# acc:0.693	batchsize: 1	lr:0.0007	hidsize:[8, 8]
# acc:0.686	batchsize: 1	lr:0.0007	hidsize:[16, 16]
# acc:0.58	batchsize: 1	lr:0.0007	hidsize:[32, 32]
# acc:0.686	batchsize: 1	lr:0.0007	hidsize:[64, 64]
# acc:0.625	batchsize: 1	lr: 0.001	hidsize:[8, 8]
# acc:0.667	batchsize: 1	lr: 0.001	hidsize:[16, 16]
# acc:0.614	batchsize: 1	lr: 0.001	hidsize:[32, 32]
# acc:0.712	batchsize: 1	lr: 0.001	hidsize:[64, 64]
# acc:0.678	batchsize: 1	lr: 0.005	hidsize:[8, 8]
# acc:0.686	batchsize: 1	lr: 0.005	hidsize:[16, 16]
# acc:0.701	batchsize: 1	lr: 0.005	hidsize:[32, 32]
# acc:0.697	batchsize: 1	lr: 0.005	hidsize:[64, 64]
# acc:0.625	batchsize: 1	lr:  0.01	hidsize:[8, 8]
# acc:0.716	batchsize: 1	lr:  0.01	hidsize:[16, 16]
# acc:0.723	batchsize: 1	lr:  0.01	hidsize:[32, 32]
# acc:0.731	batchsize: 1	lr:  0.01	hidsize:[64, 64]
# acc:0.511	batchsize: 1	lr:  0.05	hidsize:[8, 8]
# acc:0.636	batchsize: 1	lr:  0.05	hidsize:[16, 16]
# acc:0.655	batchsize: 1	lr:  0.05	hidsize:[32, 32]
# acc:0.64	batchsize: 1	lr:  0.05	hidsize:[64, 64]
# acc:0.659	batchsize: 4	lr:0.0007	hidsize:[8, 8]
# acc:0.652	batchsize: 4	lr:0.0007	hidsize:[16, 16]
# acc:0.663	batchsize: 4	lr:0.0007	hidsize:[32, 32]
# acc:0.689	batchsize: 4	lr:0.0007	hidsize:[64, 64]
# acc:0.655	batchsize: 4	lr: 0.001	hidsize:[8, 8]
# acc:0.678	batchsize: 4	lr: 0.001	hidsize:[16, 16]
# acc:0.655	batchsize: 4	lr: 0.001	hidsize:[32, 32]
# acc:0.652	batchsize: 4	lr: 0.001	hidsize:[64, 64]
# acc:0.61	batchsize: 4	lr: 0.005	hidsize:[8, 8]
# acc:0.64	batchsize: 4	lr: 0.005	hidsize:[16, 16]
# acc:0.648	batchsize: 4	lr: 0.005	hidsize:[32, 32]
# acc:0.701	batchsize: 4	lr: 0.005	hidsize:[64, 64]
# acc:0.697	batchsize: 4	lr:  0.01	hidsize:[8, 8]
# acc:0.652	batchsize: 4	lr:  0.01	hidsize:[16, 16]
# acc:0.727	batchsize: 4	lr:  0.01	hidsize:[32, 32]
# acc:0.723	batchsize: 4	lr:  0.01	hidsize:[64, 64]
# acc:0.519	batchsize: 4	lr:  0.05	hidsize:[8, 8]
# acc:0.67	batchsize: 4	lr:  0.05	hidsize:[16, 16]
# acc:0.674	batchsize: 4	lr:  0.05	hidsize:[32, 32]
# acc:0.504	batchsize: 4	lr:  0.05	hidsize:[64, 64]
# acc:0.701	batchsize:16	lr:0.0007	hidsize:[8, 8]
# acc:0.674	batchsize:16	lr:0.0007	hidsize:[16, 16]
# acc:0.674	batchsize:16	lr:0.0007	hidsize:[32, 32]
# acc:0.701	batchsize:16	lr:0.0007	hidsize:[64, 64]
# acc:0.727	batchsize:16	lr: 0.001	hidsize:[8, 8]
# acc:0.678	batchsize:16	lr: 0.001	hidsize:[16, 16]
# acc:0.648	batchsize:16	lr: 0.001	hidsize:[32, 32]
# acc:0.705	batchsize:16	lr: 0.001	hidsize:[64, 64]
# acc:0.746	batchsize:16	lr: 0.005	hidsize:[8, 8]
# acc:0.644	batchsize:16	lr: 0.005	hidsize:[16, 16]
# acc:0.64	batchsize:16	lr: 0.005	hidsize:[32, 32]
# acc:0.644	batchsize:16	lr: 0.005	hidsize:[64, 64]
# acc:0.708	batchsize:16	lr:  0.01	hidsize:[8, 8]
# acc:0.663	batchsize:16	lr:  0.01	hidsize:[16, 16]
# acc:0.633	batchsize:16	lr:  0.01	hidsize:[32, 32]
# acc:0.636	batchsize:16	lr:  0.01	hidsize:[64, 64]
# acc:0.617	batchsize:16	lr:  0.05	hidsize:[8, 8]
# acc:0.629	batchsize:16	lr:  0.05	hidsize:[16, 16]
# acc:0.602	batchsize:16	lr:  0.05	hidsize:[32, 32]
# acc:0.587	batchsize:16	lr:  0.05	hidsize:[64, 64]
# acc:0.701	batchsize:32	lr:0.0007	hidsize:[8, 8]
# acc:0.659	batchsize:32	lr:0.0007	hidsize:[16, 16]
# acc:0.663	batchsize:32	lr:0.0007	hidsize:[32, 32]
# acc:0.674	batchsize:32	lr:0.0007	hidsize:[64, 64]
# acc:0.708	batchsize:32	lr: 0.001	hidsize:[8, 8]
# acc:0.64	batchsize:32	lr: 0.001	hidsize:[16, 16]
# acc:0.667	batchsize:32	lr: 0.001	hidsize:[32, 32]
# acc:0.678	batchsize:32	lr: 0.001	hidsize:[64, 64]
# acc:0.697	batchsize:32	lr: 0.005	hidsize:[8, 8]
# acc:0.617	batchsize:32	lr: 0.005	hidsize:[16, 16]
# acc:0.652	batchsize:32	lr: 0.005	hidsize:[32, 32]
# acc:0.652	batchsize:32	lr: 0.005	hidsize:[64, 64]
# acc:0.686	batchsize:32	lr:  0.01	hidsize:[8, 8]
# acc:0.636	batchsize:32	lr:  0.01	hidsize:[16, 16]
# acc:0.67	batchsize:32	lr:  0.01	hidsize:[32, 32]
# acc:0.617	batchsize:32	lr:  0.01	hidsize:[64, 64]
# acc:0.617	batchsize:32	lr:  0.05	hidsize:[8, 8]
# acc:0.561	batchsize:32	lr:  0.05	hidsize:[16, 16]
# acc:0.625	batchsize:32	lr:  0.05	hidsize:[32, 32]
# acc:0.617	batchsize:32	lr:  0.05	hidsize:[64, 64]
# acc:0.697	batchsize:64	lr:0.0007	hidsize:[8, 8]
# acc:0.659	batchsize:64	lr:0.0007	hidsize:[16, 16]
# acc:0.686	batchsize:64	lr:0.0007	hidsize:[32, 32]
# acc:0.731	batchsize:64	lr:0.0007	hidsize:[64, 64]
# acc:0.701	batchsize:64	lr: 0.001	hidsize:[8, 8]
# acc:0.648	batchsize:64	lr: 0.001	hidsize:[16, 16]
# acc:0.678	batchsize:64	lr: 0.001	hidsize:[32, 32]
# acc:0.723	batchsize:64	lr: 0.001	hidsize:[64, 64]
# acc:0.75	batchsize:64	lr: 0.005	hidsize:[8, 8]
# acc:0.633	batchsize:64	lr: 0.005	hidsize:[16, 16]
# acc:0.697	batchsize:64	lr: 0.005	hidsize:[32, 32]
# acc:0.701	batchsize:64	lr: 0.005	hidsize:[64, 64]
# acc:0.754	batchsize:64	lr:  0.01	hidsize:[8, 8]
# acc:0.644	batchsize:64	lr:  0.01	hidsize:[16, 16]
# acc:0.727	batchsize:64	lr:  0.01	hidsize:[32, 32]
# acc:0.705	batchsize:64	lr:  0.01	hidsize:[64, 64]
# acc:0.708	batchsize:64	lr:  0.05	hidsize:[8, 8]
# acc:0.663	batchsize:64	lr:  0.05	hidsize:[16, 16]
# acc:0.663	batchsize:64	lr:  0.05	hidsize:[32, 32]
# acc:0.686	batchsize:64	lr:  0.05	hidsize:[64, 64]
# --------------------------------------
# | [PEER] best batchsize   | 64       |
# | [PEER] best hidsize     | [8, 8]   |
# | [PEER] best learning... | 0.01     |
# --------------------------------------
# ---------------------------------
# | [PEER] alpha = 0.1 | 0.761    |
# | [PEER] alpha = 0.2 | 0.767    |
# | [PEER] alpha = 0.3 | 0.761    |
# | [PEER] alpha = 0.4 | 0.756    |
# | [PEER] alpha = 0.5 | 0.778    |
# | [PEER] alpha = 0.6 | 0.773    |
# | [PEER] alpha = 0.7 | 0.756    |
# | [PEER] alpha = 0.8 | 0.75     |
# | [PEER] alpha = 0.9 | 0.716    |
# | [PEER] alpha = 1.0 | 0.67     |
# ---------------------------------
# --------------------------------------
# | [NN] with bce loss      | 0.826    |
# | [NN] with peer loss     | 0.905    |
# | [NN] with surrogate ... | 0.905    |
# | [PEER] best alpha       | 0.5      |
# --------------------------------------
# Logging to logs/svm/19-08-29-14-50-24
# {'dataset': 'thyroid', 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'e0': 0.2, 'e1': 0.2, 'equalize_prior': False, 'episodes': 1000}
# --------------------------------
# | [C-SVM] C1 = 0.1  | 0.608    |
# | [C-SVM] C1 = 0.2  | 0.614    |
# | [C-SVM] C1 = 0.25 | 0.625    |
# | [C-SVM] C1 = 0.33 | 0.705    |
# | [C-SVM] C1 = 0.5  | 0.767    |
# | [C-SVM] C1 = 1.0  | 0.795    |
# | [C-SVM] C1 = 10.0 | 0.392    |
# | [C-SVM] C1 = 2.0  | 0.807    |
# | [C-SVM] C1 = 3.0  | 0.744    |
# | [C-SVM] C1 = 4.0  | 0.562    |
# | [C-SVM] C1 = 5.0  | 0.46     |
# --------------------------------
# ------------------------------------
# | [C-SVM] accuracy max  | 1        |
# | [C-SVM] accuracy mean | 0.936    |
# | [C-SVM] accuracy min  | 0.879    |
# | [C-SVM] accuracy std  | 0.0413   |
# | [C-SVM] best C1       | 2        |
# ------------------------------------
# Logging to logs/pam/19-08-29-14-50-25
# {'dataset': 'thyroid', 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'e0': 0.2, 'e1': 0.2, 'equalize_prior': False, 'episodes': 1000}
# -----------------------------------
# | [PAM] margin = 0     | 0.608    |
# | [PAM] margin = 0.125 | 0.739    |
# | [PAM] margin = 0.25  | 0.733    |
# | [PAM] margin = 0.5   | 0.727    |
# | [PAM] margin = 1     | 0.722    |
# -----------------------------------
# ----------------------------------
# | [PAM] accuracy max  | 0.879    |
# | [PAM] accuracy mean | 0.799    |
# | [PAM] accuracy min  | 0.667    |
# | [PAM] accuracy std  | 0.071    |
# | [PAM] best margin   | 0.125    |
# ----------------------------------

# %% [markdown]
# ### $e_0 = 0.1, e_1 = 0.4$

# %%
from run_nn import find_best_alpha

args = default_args.copy()
args.update({
    'e0': 0.1, 'e1': 0.4, 
    'equalize_prior': False, 
    'episodes': 1000, 
    'batchsize': 32, 
    'hidsize': [16, 16], 
    'lr': 0.0007, 
})
find_best_alpha(args)
# Out:
# ---------------------------------
# | [PEER] alpha = 0.1 | 0.837    |
# | [PEER] alpha = 0.2 | 0.86     |
# | [PEER] alpha = 0.3 | 0.879    |
# | [PEER] alpha = 0.4 | 0.898    |
# | [PEER] alpha = 0.5 | 0.902    |
# | [PEER] alpha = 0.6 | 0.913    |
# | [PEER] alpha = 0.7 | 0.902    |
# | [PEER] alpha = 0.8 | 0.913    |
# | [PEER] alpha = 0.9 | 0.879    |
# | [PEER] alpha = 1.0 | 0.799    |
# ---------------------------------
# {'alpha': 0.6}

# %%
from runner import run

args = default_args.copy()
args.update({
    'e0': 0.1, 'e1': 0.4, 
    'equalize_prior': False, 
    'episodes': 1000, 
})
run(args)
# Out:
# Logging to logs/nn/19-08-29-14-38-53
# {'dataset': 'thyroid', 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'e0': 0.1, 'e1': 0.4, 'equalize_prior': False, 'episodes': 1000}
# acc:0.678	batchsize: 1	lr:0.0007	hidsize:[8, 8]
# acc:0.723	batchsize: 1	lr:0.0007	hidsize:[16, 16]
# acc:0.678	batchsize: 1	lr:0.0007	hidsize:[32, 32]
# acc:0.716	batchsize: 1	lr:0.0007	hidsize:[64, 64]
# acc:0.701	batchsize: 1	lr: 0.001	hidsize:[8, 8]
# acc:0.731	batchsize: 1	lr: 0.001	hidsize:[16, 16]
# acc:0.697	batchsize: 1	lr: 0.001	hidsize:[32, 32]
# acc:0.701	batchsize: 1	lr: 0.001	hidsize:[64, 64]
# acc:0.636	batchsize: 1	lr: 0.005	hidsize:[8, 8]
# acc:0.746	batchsize: 1	lr: 0.005	hidsize:[16, 16]
# acc:0.731	batchsize: 1	lr: 0.005	hidsize:[32, 32]
# acc:0.674	batchsize: 1	lr: 0.005	hidsize:[64, 64]
# acc:0.712	batchsize: 1	lr:  0.01	hidsize:[8, 8]
# acc:0.735	batchsize: 1	lr:  0.01	hidsize:[16, 16]
# acc:0.693	batchsize: 1	lr:  0.01	hidsize:[32, 32]
# acc:0.716	batchsize: 1	lr:  0.01	hidsize:[64, 64]
# acc:0.663	batchsize: 1	lr:  0.05	hidsize:[8, 8]
# acc:0.644	batchsize: 1	lr:  0.05	hidsize:[16, 16]
# acc:0.708	batchsize: 1	lr:  0.05	hidsize:[32, 32]
# acc:0.784	batchsize: 1	lr:  0.05	hidsize:[64, 64]
# acc:0.72	batchsize: 4	lr:0.0007	hidsize:[8, 8]
# acc:0.795	batchsize: 4	lr:0.0007	hidsize:[16, 16]
# acc:0.693	batchsize: 4	lr:0.0007	hidsize:[32, 32]
# acc:0.773	batchsize: 4	lr:0.0007	hidsize:[64, 64]
# acc:0.636	batchsize: 4	lr: 0.001	hidsize:[8, 8]
# acc:0.777	batchsize: 4	lr: 0.001	hidsize:[16, 16]
# acc:0.697	batchsize: 4	lr: 0.001	hidsize:[32, 32]
# acc:0.777	batchsize: 4	lr: 0.001	hidsize:[64, 64]
# acc:0.765	batchsize: 4	lr: 0.005	hidsize:[8, 8]
# acc:0.761	batchsize: 4	lr: 0.005	hidsize:[16, 16]
# acc:0.72	batchsize: 4	lr: 0.005	hidsize:[32, 32]
# acc:0.739	batchsize: 4	lr: 0.005	hidsize:[64, 64]
# acc:0.705	batchsize: 4	lr:  0.01	hidsize:[8, 8]
# acc:0.78	batchsize: 4	lr:  0.01	hidsize:[16, 16]
# acc:0.693	batchsize: 4	lr:  0.01	hidsize:[32, 32]
# acc:0.731	batchsize: 4	lr:  0.01	hidsize:[64, 64]
# acc:0.723	batchsize: 4	lr:  0.05	hidsize:[8, 8]
# acc:0.739	batchsize: 4	lr:  0.05	hidsize:[16, 16]
# acc:0.708	batchsize: 4	lr:  0.05	hidsize:[32, 32]
# acc:0.67	batchsize: 4	lr:  0.05	hidsize:[64, 64]
# acc:0.674	batchsize:16	lr:0.0007	hidsize:[8, 8]
# acc:0.792	batchsize:16	lr:0.0007	hidsize:[16, 16]
# acc:0.735	batchsize:16	lr:0.0007	hidsize:[32, 32]
# acc:0.72	batchsize:16	lr:0.0007	hidsize:[64, 64]
# acc:0.689	batchsize:16	lr: 0.001	hidsize:[8, 8]
# acc:0.769	batchsize:16	lr: 0.001	hidsize:[16, 16]
# acc:0.739	batchsize:16	lr: 0.001	hidsize:[32, 32]
# acc:0.716	batchsize:16	lr: 0.001	hidsize:[64, 64]
# acc:0.686	batchsize:16	lr: 0.005	hidsize:[8, 8]
# acc:0.761	batchsize:16	lr: 0.005	hidsize:[16, 16]
# acc:0.659	batchsize:16	lr: 0.005	hidsize:[32, 32]
# acc:0.682	batchsize:16	lr: 0.005	hidsize:[64, 64]
# acc:0.674	batchsize:16	lr:  0.01	hidsize:[8, 8]
# acc:0.686	batchsize:16	lr:  0.01	hidsize:[16, 16]
# acc:0.655	batchsize:16	lr:  0.01	hidsize:[32, 32]
# acc:0.689	batchsize:16	lr:  0.01	hidsize:[64, 64]
# acc:0.598	batchsize:16	lr:  0.05	hidsize:[8, 8]
# acc:0.72	batchsize:16	lr:  0.05	hidsize:[16, 16]
# acc:0.655	batchsize:16	lr:  0.05	hidsize:[32, 32]
# acc:0.67	batchsize:16	lr:  0.05	hidsize:[64, 64]
# acc:0.682	batchsize:32	lr:0.0007	hidsize:[8, 8]
# acc:0.799	batchsize:32	lr:0.0007	hidsize:[16, 16]
# acc:0.754	batchsize:32	lr:0.0007	hidsize:[32, 32]
# acc:0.742	batchsize:32	lr:0.0007	hidsize:[64, 64]
# acc:0.693	batchsize:32	lr: 0.001	hidsize:[8, 8]
# acc:0.788	batchsize:32	lr: 0.001	hidsize:[16, 16]
# acc:0.731	batchsize:32	lr: 0.001	hidsize:[32, 32]
# acc:0.712	batchsize:32	lr: 0.001	hidsize:[64, 64]
# acc:0.686	batchsize:32	lr: 0.005	hidsize:[8, 8]
# acc:0.731	batchsize:32	lr: 0.005	hidsize:[16, 16]
# acc:0.663	batchsize:32	lr: 0.005	hidsize:[32, 32]
# acc:0.663	batchsize:32	lr: 0.005	hidsize:[64, 64]
# acc:0.693	batchsize:32	lr:  0.01	hidsize:[8, 8]
# acc:0.678	batchsize:32	lr:  0.01	hidsize:[16, 16]
# acc:0.648	batchsize:32	lr:  0.01	hidsize:[32, 32]
# acc:0.655	batchsize:32	lr:  0.01	hidsize:[64, 64]
# acc:0.633	batchsize:32	lr:  0.05	hidsize:[8, 8]
# acc:0.674	batchsize:32	lr:  0.05	hidsize:[16, 16]
# acc:0.61	batchsize:32	lr:  0.05	hidsize:[32, 32]
# acc:0.576	batchsize:32	lr:  0.05	hidsize:[64, 64]
# acc:0.693	batchsize:64	lr:0.0007	hidsize:[8, 8]
# acc:0.731	batchsize:64	lr:0.0007	hidsize:[16, 16]
# acc:0.754	batchsize:64	lr:0.0007	hidsize:[32, 32]
# acc:0.735	batchsize:64	lr:0.0007	hidsize:[64, 64]
# acc:0.72	batchsize:64	lr: 0.001	hidsize:[8, 8]
# acc:0.735	batchsize:64	lr: 0.001	hidsize:[16, 16]
# acc:0.746	batchsize:64	lr: 0.001	hidsize:[32, 32]
# acc:0.731	batchsize:64	lr: 0.001	hidsize:[64, 64]
# acc:0.731	batchsize:64	lr: 0.005	hidsize:[8, 8]
# acc:0.739	batchsize:64	lr: 0.005	hidsize:[16, 16]
# acc:0.723	batchsize:64	lr: 0.005	hidsize:[32, 32]
# acc:0.705	batchsize:64	lr: 0.005	hidsize:[64, 64]
# acc:0.712	batchsize:64	lr:  0.01	hidsize:[8, 8]
# acc:0.693	batchsize:64	lr:  0.01	hidsize:[16, 16]
# acc:0.723	batchsize:64	lr:  0.01	hidsize:[32, 32]
# acc:0.712	batchsize:64	lr:  0.01	hidsize:[64, 64]
# acc:0.682	batchsize:64	lr:  0.05	hidsize:[8, 8]
# acc:0.629	batchsize:64	lr:  0.05	hidsize:[16, 16]
# acc:0.686	batchsize:64	lr:  0.05	hidsize:[32, 32]
# acc:0.652	batchsize:64	lr:  0.05	hidsize:[64, 64]
# --------------------------------------
# | [PEER] best batchsize   | 32       |
# | [PEER] best hidsize     | [16, 16] |
# | [PEER] best learning... | 0.0007   |
# --------------------------------------
# ---------------------------------
# | [PEER] alpha = 0.1 | 0.807    |
# | [PEER] alpha = 0.2 | 0.801    |
# | [PEER] alpha = 0.3 | 0.801    |
# | [PEER] alpha = 0.4 | 0.812    |
# | [PEER] alpha = 0.5 | 0.812    |
# | [PEER] alpha = 0.6 | 0.818    |
# | [PEER] alpha = 0.7 | 0.824    |
# | [PEER] alpha = 0.8 | 0.812    |
# | [PEER] alpha = 0.9 | 0.784    |
# | [PEER] alpha = 1.0 | 0.67     |
# ---------------------------------
# --------------------------------------
# | [NN] with bce loss      | 0.799    |
# | [NN] with peer loss     | 0.902    |
# | [NN] with surrogate ... | 0.924    |
# | [PEER] best alpha       | 0.7      |
# --------------------------------------
# Logging to logs/svm/19-08-29-14-44-48
# {'dataset': 'thyroid', 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'e0': 0.1, 'e1': 0.4, 'equalize_prior': False, 'episodes': 1000}
# --------------------------------
# | [C-SVM] C1 = 0.1  | 0.744    |
# | [C-SVM] C1 = 0.2  | 0.744    |
# | [C-SVM] C1 = 0.25 | 0.744    |
# | [C-SVM] C1 = 0.33 | 0.75     |
# | [C-SVM] C1 = 0.5  | 0.778    |
# | [C-SVM] C1 = 1.0  | 0.79     |
# | [C-SVM] C1 = 10.0 | 0.443    |
# | [C-SVM] C1 = 2.0  | 0.818    |
# | [C-SVM] C1 = 3.0  | 0.824    |
# | [C-SVM] C1 = 4.0  | 0.824    |
# | [C-SVM] C1 = 5.0  | 0.773    |
# --------------------------------
# ------------------------------------
# | [C-SVM] accuracy max  | 1        |
# | [C-SVM] accuracy mean | 0.917    |
# | [C-SVM] accuracy min  | 0.848    |
# | [C-SVM] accuracy std  | 0.0519   |
# | [C-SVM] best C1       | 3        |
# ------------------------------------
# Logging to logs/pam/19-08-29-14-44-48
# {'dataset': 'thyroid', 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'e0': 0.1, 'e1': 0.4, 'equalize_prior': False, 'episodes': 1000}
# -----------------------------------
# | [PAM] margin = 0     | 0.722    |
# | [PAM] margin = 0.125 | 0.778    |
# | [PAM] margin = 0.25  | 0.773    |
# | [PAM] margin = 0.5   | 0.767    |
# | [PAM] margin = 1     | 0.767    |
# -----------------------------------
# ----------------------------------
# | [PAM] accuracy max  | 0.848    |
# | [PAM] accuracy mean | 0.731    |
# | [PAM] accuracy min  | 0.636    |
# | [PAM] accuracy std  | 0.0734   |
# | [PAM] best margin   | 0.125    |
# ----------------------------------

# %% [markdown]
# ### $e_0 = 0.2, e_1 = 0.4$

# %%
from run_nn import find_best_alpha

args = default_args.copy()
args.update({
    'e0': 0.2, 'e1': 0.4, 
    'equalize_prior': False, 
    'episodes': 1000, 
    'batchsize': 64, 
    'hidsize': [64, 64], 
    'lr': 0.0007, 
})
find_best_alpha(args)
# Out:
# ---------------------------------
# | [PEER] alpha = 0.1 | 0.814    |
# | [PEER] alpha = 0.2 | 0.822    |
# | [PEER] alpha = 0.3 | 0.814    |
# | [PEER] alpha = 0.4 | 0.837    |
# | [PEER] alpha = 0.5 | 0.856    |
# | [PEER] alpha = 0.6 | 0.898    |
# | [PEER] alpha = 0.7 | 0.905    |
# | [PEER] alpha = 0.8 | 0.894    |
# | [PEER] alpha = 0.9 | 0.852    |
# | [PEER] alpha = 1.0 | 0.746    |
# ---------------------------------
# {'alpha': 0.7}

# %%
from runner import run

args = default_args.copy()
args.update({
    'e0': 0.2, 'e1': 0.4, 
    'equalize_prior': False, 
    'episodes': 1000,
})
run(args)
# Out:
# Logging to logs/nn/19-08-29-14-32-11
# {'dataset': 'thyroid', 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'e0': 0.2, 'e1': 0.4, 'equalize_prior': False, 'episodes': 1000}
# acc:0.689	batchsize: 1	lr:0.0007	hidsize:[8, 8]
# acc:0.697	batchsize: 1	lr:0.0007	hidsize:[16, 16]
# acc:0.583	batchsize: 1	lr:0.0007	hidsize:[32, 32]
# acc:0.629	batchsize: 1	lr:0.0007	hidsize:[64, 64]
# acc:0.735	batchsize: 1	lr: 0.001	hidsize:[8, 8]
# acc:0.693	batchsize: 1	lr: 0.001	hidsize:[16, 16]
# acc:0.614	batchsize: 1	lr: 0.001	hidsize:[32, 32]
# acc:0.614	batchsize: 1	lr: 0.001	hidsize:[64, 64]
# acc:0.591	batchsize: 1	lr: 0.005	hidsize:[8, 8]
# acc:0.648	batchsize: 1	lr: 0.005	hidsize:[16, 16]
# acc:0.617	batchsize: 1	lr: 0.005	hidsize:[32, 32]
# acc:0.598	batchsize: 1	lr: 0.005	hidsize:[64, 64]
# acc:0.61	batchsize: 1	lr:  0.01	hidsize:[8, 8]
# acc:0.614	batchsize: 1	lr:  0.01	hidsize:[16, 16]
# acc:0.549	batchsize: 1	lr:  0.01	hidsize:[32, 32]
# acc:0.534	batchsize: 1	lr:  0.01	hidsize:[64, 64]
# acc:0.58	batchsize: 1	lr:  0.05	hidsize:[8, 8]
# acc:0.447	batchsize: 1	lr:  0.05	hidsize:[16, 16]
# acc:0.606	batchsize: 1	lr:  0.05	hidsize:[32, 32]
# acc:0.549	batchsize: 1	lr:  0.05	hidsize:[64, 64]
# acc:0.693	batchsize: 4	lr:0.0007	hidsize:[8, 8]
# acc:0.689	batchsize: 4	lr:0.0007	hidsize:[16, 16]
# acc:0.617	batchsize: 4	lr:0.0007	hidsize:[32, 32]
# acc:0.67	batchsize: 4	lr:0.0007	hidsize:[64, 64]
# acc:0.591	batchsize: 4	lr: 0.001	hidsize:[8, 8]
# acc:0.686	batchsize: 4	lr: 0.001	hidsize:[16, 16]
# acc:0.633	batchsize: 4	lr: 0.001	hidsize:[32, 32]
# acc:0.686	batchsize: 4	lr: 0.001	hidsize:[64, 64]
# acc:0.614	batchsize: 4	lr: 0.005	hidsize:[8, 8]
# acc:0.674	batchsize: 4	lr: 0.005	hidsize:[16, 16]
# acc:0.659	batchsize: 4	lr: 0.005	hidsize:[32, 32]
# acc:0.663	batchsize: 4	lr: 0.005	hidsize:[64, 64]
# acc:0.621	batchsize: 4	lr:  0.01	hidsize:[8, 8]
# acc:0.644	batchsize: 4	lr:  0.01	hidsize:[16, 16]
# acc:0.67	batchsize: 4	lr:  0.01	hidsize:[32, 32]
# acc:0.636	batchsize: 4	lr:  0.01	hidsize:[64, 64]
# acc:0.636	batchsize: 4	lr:  0.05	hidsize:[8, 8]
# acc:0.652	batchsize: 4	lr:  0.05	hidsize:[16, 16]
# acc:0.648	batchsize: 4	lr:  0.05	hidsize:[32, 32]
# acc:0.583	batchsize: 4	lr:  0.05	hidsize:[64, 64]
# acc:0.648	batchsize:16	lr:0.0007	hidsize:[8, 8]
# acc:0.667	batchsize:16	lr:0.0007	hidsize:[16, 16]
# acc:0.655	batchsize:16	lr:0.0007	hidsize:[32, 32]
# acc:0.686	batchsize:16	lr:0.0007	hidsize:[64, 64]
# acc:0.644	batchsize:16	lr: 0.001	hidsize:[8, 8]
# acc:0.678	batchsize:16	lr: 0.001	hidsize:[16, 16]
# acc:0.72	batchsize:16	lr: 0.001	hidsize:[32, 32]
# acc:0.682	batchsize:16	lr: 0.001	hidsize:[64, 64]
# acc:0.614	batchsize:16	lr: 0.005	hidsize:[8, 8]
# acc:0.686	batchsize:16	lr: 0.005	hidsize:[16, 16]
# acc:0.659	batchsize:16	lr: 0.005	hidsize:[32, 32]
# acc:0.633	batchsize:16	lr: 0.005	hidsize:[64, 64]
# acc:0.67	batchsize:16	lr:  0.01	hidsize:[8, 8]
# acc:0.67	batchsize:16	lr:  0.01	hidsize:[16, 16]
# acc:0.659	batchsize:16	lr:  0.01	hidsize:[32, 32]
# acc:0.625	batchsize:16	lr:  0.01	hidsize:[64, 64]
# acc:0.697	batchsize:16	lr:  0.05	hidsize:[8, 8]
# acc:0.701	batchsize:16	lr:  0.05	hidsize:[16, 16]
# acc:0.621	batchsize:16	lr:  0.05	hidsize:[32, 32]
# acc:0.625	batchsize:16	lr:  0.05	hidsize:[64, 64]
# acc:0.648	batchsize:32	lr:0.0007	hidsize:[8, 8]
# acc:0.712	batchsize:32	lr:0.0007	hidsize:[16, 16]
# acc:0.705	batchsize:32	lr:0.0007	hidsize:[32, 32]
# acc:0.705	batchsize:32	lr:0.0007	hidsize:[64, 64]
# acc:0.617	batchsize:32	lr: 0.001	hidsize:[8, 8]
# acc:0.705	batchsize:32	lr: 0.001	hidsize:[16, 16]
# acc:0.689	batchsize:32	lr: 0.001	hidsize:[32, 32]
# acc:0.689	batchsize:32	lr: 0.001	hidsize:[64, 64]
# acc:0.682	batchsize:32	lr: 0.005	hidsize:[8, 8]
# acc:0.652	batchsize:32	lr: 0.005	hidsize:[16, 16]
# acc:0.659	batchsize:32	lr: 0.005	hidsize:[32, 32]
# acc:0.686	batchsize:32	lr: 0.005	hidsize:[64, 64]
# acc:0.636	batchsize:32	lr:  0.01	hidsize:[8, 8]
# acc:0.67	batchsize:32	lr:  0.01	hidsize:[16, 16]
# acc:0.659	batchsize:32	lr:  0.01	hidsize:[32, 32]
# acc:0.648	batchsize:32	lr:  0.01	hidsize:[64, 64]
# acc:0.629	batchsize:32	lr:  0.05	hidsize:[8, 8]
# acc:0.602	batchsize:32	lr:  0.05	hidsize:[16, 16]
# acc:0.602	batchsize:32	lr:  0.05	hidsize:[32, 32]
# acc:0.633	batchsize:32	lr:  0.05	hidsize:[64, 64]
# acc:0.636	batchsize:64	lr:0.0007	hidsize:[8, 8]
# acc:0.716	batchsize:64	lr:0.0007	hidsize:[16, 16]
# acc:0.723	batchsize:64	lr:0.0007	hidsize:[32, 32]
# acc:0.746	batchsize:64	lr:0.0007	hidsize:[64, 64]
# acc:0.64	batchsize:64	lr: 0.001	hidsize:[8, 8]
# acc:0.701	batchsize:64	lr: 0.001	hidsize:[16, 16]
# acc:0.701	batchsize:64	lr: 0.001	hidsize:[32, 32]
# acc:0.72	batchsize:64	lr: 0.001	hidsize:[64, 64]
# acc:0.652	batchsize:64	lr: 0.005	hidsize:[8, 8]
# acc:0.663	batchsize:64	lr: 0.005	hidsize:[16, 16]
# acc:0.678	batchsize:64	lr: 0.005	hidsize:[32, 32]
# acc:0.693	batchsize:64	lr: 0.005	hidsize:[64, 64]
# acc:0.678	batchsize:64	lr:  0.01	hidsize:[8, 8]
# acc:0.625	batchsize:64	lr:  0.01	hidsize:[16, 16]
# acc:0.663	batchsize:64	lr:  0.01	hidsize:[32, 32]
# acc:0.697	batchsize:64	lr:  0.01	hidsize:[64, 64]
# acc:0.731	batchsize:64	lr:  0.05	hidsize:[8, 8]
# acc:0.663	batchsize:64	lr:  0.05	hidsize:[16, 16]
# acc:0.652	batchsize:64	lr:  0.05	hidsize:[32, 32]
# acc:0.629	batchsize:64	lr:  0.05	hidsize:[64, 64]
# --------------------------------------
# | [PEER] best batchsize   | 64       |
# | [PEER] best hidsize     | [64, 64] |
# | [PEER] best learning... | 0.0007   |
# --------------------------------------
# ---------------------------------
# | [PEER] alpha = 0.1 | 0.688    |
# | [PEER] alpha = 0.2 | 0.699    |
# | [PEER] alpha = 0.3 | 0.716    |
# | [PEER] alpha = 0.4 | 0.716    |
# | [PEER] alpha = 0.5 | 0.705    |
# | [PEER] alpha = 0.6 | 0.71     |
# | [PEER] alpha = 0.7 | 0.71     |
# | [PEER] alpha = 0.8 | 0.705    |
# | [PEER] alpha = 0.9 | 0.682    |
# | [PEER] alpha = 1.0 | 0.591    |
# ---------------------------------
# --------------------------------------
# | [NN] with bce loss      | 0.78     |
# | [NN] with peer loss     | 0.814    |
# | [NN] with surrogate ... | 0.898    |
# | [PEER] best alpha       | 0.3      |
# --------------------------------------
# Logging to logs/svm/19-08-29-14-38-51
# {'dataset': 'thyroid', 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'e0': 0.2, 'e1': 0.4, 'equalize_prior': False, 'episodes': 1000}
# --------------------------------
# | [C-SVM] C1 = 0.1  | 0.665    |
# | [C-SVM] C1 = 0.2  | 0.665    |
# | [C-SVM] C1 = 0.25 | 0.665    |
# | [C-SVM] C1 = 0.33 | 0.67     |
# | [C-SVM] C1 = 0.5  | 0.693    |
# | [C-SVM] C1 = 1.0  | 0.716    |
# | [C-SVM] C1 = 10.0 | 0.33     |
# | [C-SVM] C1 = 2.0  | 0.739    |
# | [C-SVM] C1 = 3.0  | 0.727    |
# | [C-SVM] C1 = 4.0  | 0.494    |
# | [C-SVM] C1 = 5.0  | 0.398    |
# --------------------------------
# ------------------------------------
# | [C-SVM] accuracy max  | 1        |
# | [C-SVM] accuracy mean | 0.92     |
# | [C-SVM] accuracy min  | 0.848    |
# | [C-SVM] accuracy std  | 0.0478   |
# | [C-SVM] best C1       | 2        |
# ------------------------------------
# Logging to logs/pam/19-08-29-14-38-51
# {'dataset': 'thyroid', 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'e0': 0.2, 'e1': 0.4, 'equalize_prior': False, 'episodes': 1000}
# -----------------------------------
# | [PAM] margin = 0     | 0.636    |
# | [PAM] margin = 0.125 | 0.693    |
# | [PAM] margin = 0.25  | 0.688    |
# | [PAM] margin = 0.5   | 0.688    |
# | [PAM] margin = 1     | 0.688    |
# -----------------------------------
# ----------------------------------
# | [PAM] accuracy max  | 0.848    |
# | [PAM] accuracy mean | 0.727    |
# | [PAM] accuracy min  | 0.636    |
# | [PAM] accuracy std  | 0.0773   |
# | [PAM] best margin   | 0.125    |
# ----------------------------------

# %% [markdown]
# ### $e_0=0.4, e_1=0.4$

# %%
from run_nn import find_best_alpha

args = default_args.copy()
args.update({
    'e0': 0.4, 'e1': 0.4, 
    'equalize_prior': False, 
    'episodes': 1000, 
    'batchsize': 64, 
    'hidsize': [8, 8], 
    'lr': 0.01, 
})
find_best_alpha(args)
# Out:
# ---------------------------------
# | [PEER] alpha = 0.1 | 0.621    |
# | [PEER] alpha = 0.2 | 0.576    |
# | [PEER] alpha = 0.3 | 0.652    |
# | [PEER] alpha = 0.4 | 0.659    |
# | [PEER] alpha = 0.5 | 0.655    |
# | [PEER] alpha = 0.6 | 0.689    |
# | [PEER] alpha = 0.7 | 0.75     |
# | [PEER] alpha = 0.8 | 0.769    |
# | [PEER] alpha = 0.9 | 0.739    |
# | [PEER] alpha = 1.0 | 0.735    |
# ---------------------------------
# {'alpha': 0.8}

# %%
from runner import run
args = default_args.copy()
args.update({
    'dataset': 'thyroid', 
    'e0': 0.4, 'e1': 0.4, 
    'equalize_prior': False, 
    'episodes': 1000
})
run(args)
# Out:
# Logging to logs/nn/19-08-29-14-26-29
# {'dataset': 'thyroid', 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'e0': 0.4, 'e1': 0.4, 'equalize_prior': False, 'episodes': 1000}
# acc:0.602	batchsize: 1	lr:0.0007	hidsize:[8, 8]
# acc:0.583	batchsize: 1	lr:0.0007	hidsize:[16, 16]
# acc: 0.5	batchsize: 1	lr:0.0007	hidsize:[32, 32]
# acc:0.519	batchsize: 1	lr:0.0007	hidsize:[64, 64]
# acc:0.583	batchsize: 1	lr: 0.001	hidsize:[8, 8]
# acc:0.598	batchsize: 1	lr: 0.001	hidsize:[16, 16]
# acc:0.492	batchsize: 1	lr: 0.001	hidsize:[32, 32]
# acc:0.508	batchsize: 1	lr: 0.001	hidsize:[64, 64]
# acc:0.58	batchsize: 1	lr: 0.005	hidsize:[8, 8]
# acc:0.561	batchsize: 1	lr: 0.005	hidsize:[16, 16]
# acc:0.527	batchsize: 1	lr: 0.005	hidsize:[32, 32]
# acc:0.492	batchsize: 1	lr: 0.005	hidsize:[64, 64]
# acc:0.545	batchsize: 1	lr:  0.01	hidsize:[8, 8]
# acc:0.466	batchsize: 1	lr:  0.01	hidsize:[16, 16]
# acc:0.508	batchsize: 1	lr:  0.01	hidsize:[32, 32]
# acc:0.485	batchsize: 1	lr:  0.01	hidsize:[64, 64]
# acc:0.477	batchsize: 1	lr:  0.05	hidsize:[8, 8]
# acc:0.496	batchsize: 1	lr:  0.05	hidsize:[16, 16]
# acc:0.447	batchsize: 1	lr:  0.05	hidsize:[32, 32]
# acc:0.504	batchsize: 1	lr:  0.05	hidsize:[64, 64]
# acc:0.67	batchsize: 4	lr:0.0007	hidsize:[8, 8]
# acc:0.652	batchsize: 4	lr:0.0007	hidsize:[16, 16]
# acc:0.523	batchsize: 4	lr:0.0007	hidsize:[32, 32]
# acc:0.53	batchsize: 4	lr:0.0007	hidsize:[64, 64]
# acc:0.617	batchsize: 4	lr: 0.001	hidsize:[8, 8]
# acc:0.591	batchsize: 4	lr: 0.001	hidsize:[16, 16]
# acc:0.504	batchsize: 4	lr: 0.001	hidsize:[32, 32]
# acc:0.527	batchsize: 4	lr: 0.001	hidsize:[64, 64]
# acc:0.538	batchsize: 4	lr: 0.005	hidsize:[8, 8]
# acc:0.564	batchsize: 4	lr: 0.005	hidsize:[16, 16]
# acc:0.511	batchsize: 4	lr: 0.005	hidsize:[32, 32]
# acc:0.542	batchsize: 4	lr: 0.005	hidsize:[64, 64]
# acc:0.545	batchsize: 4	lr:  0.01	hidsize:[8, 8]
# acc:0.568	batchsize: 4	lr:  0.01	hidsize:[16, 16]
# acc: 0.5	batchsize: 4	lr:  0.01	hidsize:[32, 32]
# acc:0.58	batchsize: 4	lr:  0.01	hidsize:[64, 64]
# acc:0.519	batchsize: 4	lr:  0.05	hidsize:[8, 8]
# acc:0.598	batchsize: 4	lr:  0.05	hidsize:[16, 16]
# acc:0.481	batchsize: 4	lr:  0.05	hidsize:[32, 32]
# acc:0.523	batchsize: 4	lr:  0.05	hidsize:[64, 64]
# acc:0.568	batchsize:16	lr:0.0007	hidsize:[8, 8]
# acc:0.625	batchsize:16	lr:0.0007	hidsize:[16, 16]
# acc:0.561	batchsize:16	lr:0.0007	hidsize:[32, 32]
# acc:0.602	batchsize:16	lr:0.0007	hidsize:[64, 64]
# acc:0.553	batchsize:16	lr: 0.001	hidsize:[8, 8]
# acc:0.614	batchsize:16	lr: 0.001	hidsize:[16, 16]
# acc:0.549	batchsize:16	lr: 0.001	hidsize:[32, 32]
# acc:0.58	batchsize:16	lr: 0.001	hidsize:[64, 64]
# acc:0.61	batchsize:16	lr: 0.005	hidsize:[8, 8]
# acc:0.602	batchsize:16	lr: 0.005	hidsize:[16, 16]
# acc:0.549	batchsize:16	lr: 0.005	hidsize:[32, 32]
# acc:0.561	batchsize:16	lr: 0.005	hidsize:[64, 64]
# acc:0.625	batchsize:16	lr:  0.01	hidsize:[8, 8]
# acc:0.617	batchsize:16	lr:  0.01	hidsize:[16, 16]
# acc:0.511	batchsize:16	lr:  0.01	hidsize:[32, 32]
# acc:0.557	batchsize:16	lr:  0.01	hidsize:[64, 64]
# acc:0.515	batchsize:16	lr:  0.05	hidsize:[8, 8]
# acc:0.617	batchsize:16	lr:  0.05	hidsize:[16, 16]
# acc: 0.5	batchsize:16	lr:  0.05	hidsize:[32, 32]
# acc:0.496	batchsize:16	lr:  0.05	hidsize:[64, 64]
# acc:0.591	batchsize:32	lr:0.0007	hidsize:[8, 8]
# acc:0.629	batchsize:32	lr:0.0007	hidsize:[16, 16]
# acc:0.591	batchsize:32	lr:0.0007	hidsize:[32, 32]
# acc:0.583	batchsize:32	lr:0.0007	hidsize:[64, 64]
# acc:0.549	batchsize:32	lr: 0.001	hidsize:[8, 8]
# acc:0.621	batchsize:32	lr: 0.001	hidsize:[16, 16]
# acc:0.61	batchsize:32	lr: 0.001	hidsize:[32, 32]
# acc:0.587	batchsize:32	lr: 0.001	hidsize:[64, 64]
# acc:0.629	batchsize:32	lr: 0.005	hidsize:[8, 8]
# acc:0.655	batchsize:32	lr: 0.005	hidsize:[16, 16]
# acc:0.564	batchsize:32	lr: 0.005	hidsize:[32, 32]
# acc:0.549	batchsize:32	lr: 0.005	hidsize:[64, 64]
# acc:0.614	batchsize:32	lr:  0.01	hidsize:[8, 8]
# acc:0.636	batchsize:32	lr:  0.01	hidsize:[16, 16]
# acc:0.557	batchsize:32	lr:  0.01	hidsize:[32, 32]
# acc:0.542	batchsize:32	lr:  0.01	hidsize:[64, 64]
# acc:0.538	batchsize:32	lr:  0.05	hidsize:[8, 8]
# acc:0.561	batchsize:32	lr:  0.05	hidsize:[16, 16]
# acc:0.527	batchsize:32	lr:  0.05	hidsize:[32, 32]
# acc:0.545	batchsize:32	lr:  0.05	hidsize:[64, 64]
# acc:0.629	batchsize:64	lr:0.0007	hidsize:[8, 8]
# acc:0.663	batchsize:64	lr:0.0007	hidsize:[16, 16]
# acc:0.595	batchsize:64	lr:0.0007	hidsize:[32, 32]
# acc:0.629	batchsize:64	lr:0.0007	hidsize:[64, 64]
# acc:0.67	batchsize:64	lr: 0.001	hidsize:[8, 8]
# acc:0.644	batchsize:64	lr: 0.001	hidsize:[16, 16]
# acc:0.583	batchsize:64	lr: 0.001	hidsize:[32, 32]
# acc:0.621	batchsize:64	lr: 0.001	hidsize:[64, 64]
# acc:0.689	batchsize:64	lr: 0.005	hidsize:[8, 8]
# acc:0.602	batchsize:64	lr: 0.005	hidsize:[16, 16]
# acc:0.591	batchsize:64	lr: 0.005	hidsize:[32, 32]
# acc:0.561	batchsize:64	lr: 0.005	hidsize:[64, 64]
# acc:0.735	batchsize:64	lr:  0.01	hidsize:[8, 8]
# acc:0.602	batchsize:64	lr:  0.01	hidsize:[16, 16]
# acc:0.549	batchsize:64	lr:  0.01	hidsize:[32, 32]
# acc:0.572	batchsize:64	lr:  0.01	hidsize:[64, 64]
# acc:0.663	batchsize:64	lr:  0.05	hidsize:[8, 8]
# acc:0.591	batchsize:64	lr:  0.05	hidsize:[16, 16]
# acc:0.572	batchsize:64	lr:  0.05	hidsize:[32, 32]
# acc:0.534	batchsize:64	lr:  0.05	hidsize:[64, 64]
# --------------------------------------
# | [PEER] best batchsize   | 64       |
# | [PEER] best hidsize     | [8, 8]   |
# | [PEER] best learning... | 0.01     |
# --------------------------------------
# ---------------------------------
# | [PEER] alpha = 0.1 | 0.5      |
# | [PEER] alpha = 0.2 | 0.483    |
# | [PEER] alpha = 0.3 | 0.517    |
# | [PEER] alpha = 0.4 | 0.545    |
# | [PEER] alpha = 0.5 | 0.54     |
# | [PEER] alpha = 0.6 | 0.58     |
# | [PEER] alpha = 0.7 | 0.574    |
# | [PEER] alpha = 0.8 | 0.545    |
# | [PEER] alpha = 0.9 | 0.523    |
# | [PEER] alpha = 1.0 | 0.511    |
# ---------------------------------
# --------------------------------------
# | [NN] with bce loss      | 0.587    |
# | [NN] with peer loss     | 0.689    |
# | [NN] with surrogate ... | 0.818    |
# | [PEER] best alpha       | 0.6      |
# --------------------------------------
# Logging to logs/svm/19-08-29-14-32-08
# {'dataset': 'thyroid', 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'e0': 0.4, 'e1': 0.4, 'equalize_prior': False, 'episodes': 1000}
# --------------------------------
# | [C-SVM] C1 = 0.1  | 0.54     |
# | [C-SVM] C1 = 0.2  | 0.54     |
# | [C-SVM] C1 = 0.25 | 0.54     |
# | [C-SVM] C1 = 0.33 | 0.545    |
# | [C-SVM] C1 = 0.5  | 0.562    |
# | [C-SVM] C1 = 1.0  | 0.619    |
# | [C-SVM] C1 = 10.0 | 0.46     |
# | [C-SVM] C1 = 2.0  | 0.455    |
# | [C-SVM] C1 = 3.0  | 0.46     |
# | [C-SVM] C1 = 4.0  | 0.46     |
# | [C-SVM] C1 = 5.0  | 0.46     |
# --------------------------------
# ------------------------------------
# | [C-SVM] accuracy max  | 0.909    |
# | [C-SVM] accuracy mean | 0.837    |
# | [C-SVM] accuracy min  | 0.758    |
# | [C-SVM] accuracy std  | 0.0501   |
# | [C-SVM] best C1       | 1        |
# ------------------------------------
# Logging to logs/pam/19-08-29-14-32-08
# {'dataset': 'thyroid', 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'e0': 0.4, 'e1': 0.4, 'equalize_prior': False, 'episodes': 1000}
# -----------------------------------
# | [PAM] margin = 0     | 0.562    |
# | [PAM] margin = 0.125 | 0.608    |
# | [PAM] margin = 0.25  | 0.608    |
# | [PAM] margin = 0.5   | 0.608    |
# | [PAM] margin = 1     | 0.602    |
# -----------------------------------
# ----------------------------------
# | [PAM] accuracy max  | 0.848    |
# | [PAM] accuracy mean | 0.78     |
# | [PAM] accuracy min  | 0.697    |
# | [PAM] accuracy std  | 0.0473   |
# | [PAM] best margin   | 0.125    |
# ----------------------------------

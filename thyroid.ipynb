# %% [markdown]
# # Thyroid Dataset

# %% [markdown]
# ## Describe
#
# | Total | Positive | Attributes | Normalized |
# |:-----:|:--------:|:----------:|:----------:|
# |  215  |  30.2%   |     5      | Don't need |

# %%
from utils.dataloader import DataLoader

df = DataLoader('thyroid').df
df.target.describe()
# Out:
# count    215.000000
# mean       0.302326
# std        0.460337
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        1.000000
# max        1.000000
# Name: target, dtype: float64

# %%
df.describe()
# Out:
#            target           1           2           3           4           5
# count  215.000000  215.000000  215.000000  215.000000  215.000000  215.000000
# mean     0.302326    0.018667   -0.016492    0.134549    0.003500    0.003912
# std      0.460337    1.139484    1.014673    1.288456    0.892120    0.984362
# min      0.000000   -3.846984   -2.026382   -1.544891   -0.401875   -0.593628
# 25%      0.000000   -0.553036   -0.600721   -0.501046   -0.270639   -0.441166
# 50%      0.000000    0.053743   -0.147102   -0.183354   -0.226893   -0.264309
# 75%      1.000000    0.703865    0.306517    0.270492   -0.168566   -0.008172
# max      1.000000    3.000959    3.330645    7.350487    7.807690    6.358666

# %%
from runner import run

args = {
    'dataset': 'thyroid', 
    'lr': 0.0005, 
    'hidsize': 8, 
    'episodes': 500, 
    'batchsize': 10, 
    'test_size': 0.2,
    'dropout': 0.,
    'normalize': True,
    'equalize_prior': False
}

# %% [markdown]
# $e_0 = 0, e_1 = 0$

# %%
args.update({'e0': 0, 'e1': 0})
run(args.copy())
# Out:
# {'dataset': 'thyroid', 'lr': 0.001, 'hidsize': 8, 'episodes': 500, 'batchsize': 10, 'test_size': 0.2, 'dropout': 0.0, 'normalize': True, 'equalize_prior': False, 'e0': 0, 'e1': 0}
# --------------------------------------
# | knn                     | 0.932    |
# | logistic regression     | 0.878    |
# | nn                      | 0.962    |
# | nn with peer prediction | 0.714    |
# | random forest           | 0.953    |
# | svm                     | 0.95     |
# --------------------------------------

# %% [markdown]
# $e_0 = 0.2, e_1 = 0.2$

# %%
args.update({'e0': 0.2, 'e1': 0.2})
run(args.copy())
# Out:
# {'dataset': 'thyroid', 'lr': 0.001, 'hidsize': 8, 'episodes': 500, 'batchsize': 10, 'test_size': 0.2, 'dropout': 0.0, 'normalize': True, 'equalize_prior': False, 'e0': 0.2, 'e1': 0.2}
# --------------------------------------
# | knn                     | 0.887    |
# | logistic regression     | 0.852    |
# | nn                      | 0.923    |
# | nn with peer prediction | 0.681    |
# | random forest           | 0.902    |
# | svm                     | 0.932    |
# --------------------------------------

# %% [markdown]
# $e_0 = 0.1, e_1 = 0.3$

# %%
args.update({'e0': 0.1, 'e1': 0.3})
run(args.copy())
# Out:
# {'dataset': 'thyroid', 'lr': 0.001, 'hidsize': 8, 'episodes': 500, 'batchsize': 10, 'test_size': 0.2, 'dropout': 0.0, 'normalize': True, 'equalize_prior': False, 'e0': 0.1, 'e1': 0.3}
# --------------------------------------
# | knn                     | 0.878    |
# | logistic regression     | 0.824    |
# | nn                      | 0.905    |
# | nn with peer prediction | 0.753    |
# | random forest           | 0.9      |
# | svm                     | 0.894    |
# --------------------------------------

# %% [markdown]
# $e_0 = 0.2, e_1 = 0.4$

# %%
args.update({'e0': 0.2, 'e1': 0.4})
run(args.copy())
# Out:
# {'dataset': 'thyroid', 'lr': 0.001, 'hidsize': 8, 'episodes': 500, 'batchsize': 10, 'test_size': 0.2, 'dropout': 0.0, 'normalize': True, 'equalize_prior': False, 'e0': 0.2, 'e1': 0.4}
# --------------------------------------
# | knn                     | 0.831    |
# | logistic regression     | 0.8      |
# | nn                      | 0.857    |
# | nn with peer prediction | 0.724    |
# | random forest           | 0.848    |
# | svm                     | 0.84     |
# --------------------------------------

# %% [markdown]
# $e_0 = 0.4, e_1 = 0.4$

# %%
args.update({'e0': 0.4, 'e1': 0.4})
run(args.copy())
# Out:
# {'dataset': 'thyroid', 'lr': 0.001, 'hidsize': 8, 'episodes': 500, 'batchsize': 10, 'test_size': 0.2, 'dropout': 0.0, 'normalize': True, 'equalize_prior': False, 'e0': 0.4, 'e1': 0.4}
# --------------------------------------
# | knn                     | 0.677    |
# | logistic regression     | 0.785    |
# | nn                      | 0.825    |
# | nn with peer prediction | 0.658    |
# | random forest           | 0.703    |
# | svm                     | 0.861    |
# --------------------------------------

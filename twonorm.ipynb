# %% [markdown]
# # Twonorm (20,3700,3700)

# %% [markdown]
# ## Describe
#
# | Total | Positive | Attributes | Normalized |
# |:-----:|:--------:|:----------:|:----------:|
# | 7400  |  50.0%   |     20     |     Yes    |

# %% [markdown]
# ## Without Prior Equalization

# %% [markdown]
# ### $e_0 = 0, e_1 = 0$

# %%
from runner import run
run({
    'dataset': 'twonorm', 
    'e0': 0., 'e1': 0.,
    'episodes': 100,
    'batchsize': 4,
    'lr': 0.005,
    'hidsize': [32, 32],
    'test_size': 0.8, 
    'dropout': 0, 
    'normalize': True, 
    'equalize_prior': False,
    'alpha': 1.,
})
# Out:
# Logging to logs/nn/19-08-18-20-03-39
# {'dataset': 'twonorm', 'e0': 0.0, 'e1': 0.0, 'episodes': 100, 'batchsize': 4, 'lr': 0.005, 'hidsize': [32, 32], 'test_size': 0.8, 'dropout': 0, 'normalize': True, 'equalize_prior': False, 'alpha': 1.0}
# --------------------------------------
# | [NN] with cross entr... | 0.941    |
# | [NN] with peer loss     | 0.914    |
# | [NN] with surrogate ... | 0.941    |
# --------------------------------------
# Logging to logs/svm/19-08-18-20-03-49
# {'dataset': 'twonorm', 'e0': 0.0, 'e1': 0.0, 'episodes': 100, 'batchsize': 4, 'lr': 0.005, 'hidsize': [32, 32], 'test_size': 0.8, 'dropout': 0, 'normalize': True, 'equalize_prior': False, 'alpha': 1.0}
# ------------------------------------
# | [C-SVM] accuracy max  | 0.977    |
# | [C-SVM] accuracy mean | 0.975    |
# | [C-SVM] accuracy min  | 0.973    |
# | [C-SVM] accuracy std  | 0.00135  |
# | [C-SVM] best C1       | 0.6      |
# ------------------------------------
# Logging to logs/pam/19-08-18-20-03-52
# {'dataset': 'twonorm', 'e0': 0.0, 'e1': 0.0, 'episodes': 100, 'batchsize': 4, 'lr': 0.005, 'hidsize': [32, 32], 'test_size': 0.8, 'dropout': 0, 'normalize': True, 'equalize_prior': False, 'alpha': 1.0}
# ----------------------------------
# | [PAM] accuracy max  | 0.979    |
# | [PAM] accuracy mean | 0.976    |
# | [PAM] accuracy min  | 0.974    |
# | [PAM] accuracy std  | 0.00164  |
# | [PAM] best margin   | 0.5      |
# ----------------------------------

# %% [markdown]
# ### $e_0 = 0.1, e_1 = 0.3$

# %%
from runner import run
run({
    'dataset': 'twonorm', 
    'e0': 0.1, 'e1': 0.3,
    'episodes': 500,
    'batchsize': 4,
    'lr': 0.005,
    'hidsize': [32, 32],
    'test_size': 0.7,
    'val_size': 0.1,
    'dropout': 0, 
    'normalize': True, 
    'equalize_prior': False,
    'alpha': 1.,
    'loss': 'bce',
    'activation': 'relu'
})
# Out:
# Logging to logs/nn/19-08-21-13-30-48
# {'dataset': 'twonorm', 'e0': 0.1, 'e1': 0.3, 'episodes': 500, 'batchsize': 4, 'lr': 0.005, 'hidsize': [32, 32], 'test_size': 0.7, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'equalize_prior': False, 'alpha': 1.0, 'loss': 'bce', 'activation': 'relu'}
# --------------------------------------
# | [NN] with bce loss      | 0.933    |
# | [NN] with peer loss     | 0.973    |
# | [NN] with surrogate ... | 0.941    |
# --------------------------------------
# Logging to logs/svm/19-08-21-13-31-03
# {'dataset': 'twonorm', 'e0': 0.1, 'e1': 0.3, 'episodes': 500, 'batchsize': 4, 'lr': 0.005, 'hidsize': [32, 32], 'test_size': 0.7, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'equalize_prior': False, 'alpha': 1.0, 'loss': 'bce', 'activation': 'relu'}
# ------------------------------------
# | [C-SVM] accuracy max  | 0.969    |
# | [C-SVM] accuracy mean | 0.966    |
# | [C-SVM] accuracy min  | 0.962    |
# | [C-SVM] accuracy std  | 0.00219  |
# | [C-SVM] best C1       | 2        |
# ------------------------------------
# Logging to logs/pam/19-08-21-13-31-08
# {'dataset': 'twonorm', 'e0': 0.1, 'e1': 0.3, 'episodes': 500, 'batchsize': 4, 'lr': 0.005, 'hidsize': [32, 32], 'test_size': 0.7, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'equalize_prior': False, 'alpha': 1.0, 'loss': 'bce', 'activation': 'relu'}
# ----------------------------------
# | [PAM] accuracy max  | 0.965    |
# | [PAM] accuracy mean | 0.957    |
# | [PAM] accuracy min  | 0.949    |
# | [PAM] accuracy std  | 0.00469  |
# | [PAM] best margin   | 0.5      |
# ----------------------------------

# %% [markdown]
# ### $e_0 = 0.2, e_1 = 0.2$

# %%
from runner import run
run({
    'dataset': 'twonorm', 
    'e0': 0.2, 'e1': 0.2,
    'episodes': 500,
    'batchsize': 4,
    'lr': 0.005,
    'hidsize': [32, 32],
    'test_size': 0.7,
    'val_size': 0.1,
    'dropout': 0, 
    'normalize': True, 
    'equalize_prior': False,
    'alpha': 1.,
    'loss': 'bce',
    'activation': 'relu'
})
# Out:
# Logging to logs/nn/19-08-21-13-32-45
# {'dataset': 'twonorm', 'e0': 0.2, 'e1': 0.2, 'episodes': 500, 'batchsize': 4, 'lr': 0.005, 'hidsize': [32, 32], 'test_size': 0.7, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'equalize_prior': False, 'alpha': 1.0, 'loss': 'bce', 'activation': 'relu'}
# --------------------------------------
# | [NN] with bce loss      | 0.945    |
# | [NN] with peer loss     | 0.973    |
# | [NN] with surrogate ... | 0.942    |
# --------------------------------------
# Logging to logs/svm/19-08-21-13-33-04
# {'dataset': 'twonorm', 'e0': 0.2, 'e1': 0.2, 'episodes': 500, 'batchsize': 4, 'lr': 0.005, 'hidsize': [32, 32], 'test_size': 0.7, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'equalize_prior': False, 'alpha': 1.0, 'loss': 'bce', 'activation': 'relu'}
# ------------------------------------
# | [C-SVM] accuracy max  | 0.975    |
# | [C-SVM] accuracy mean | 0.969    |
# | [C-SVM] accuracy min  | 0.966    |
# | [C-SVM] accuracy std  | 0.00252  |
# | [C-SVM] best C1       | 1        |
# ------------------------------------
# Logging to logs/pam/19-08-21-13-33-09
# {'dataset': 'twonorm', 'e0': 0.2, 'e1': 0.2, 'episodes': 500, 'batchsize': 4, 'lr': 0.005, 'hidsize': [32, 32], 'test_size': 0.7, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'equalize_prior': False, 'alpha': 1.0, 'loss': 'bce', 'activation': 'relu'}
# ----------------------------------
# | [PAM] accuracy max  | 0.976    |
# | [PAM] accuracy mean | 0.973    |
# | [PAM] accuracy min  | 0.969    |
# | [PAM] accuracy std  | 0.00214  |
# | [PAM] best margin   | 0.3      |
# ----------------------------------

# %% [markdown]
# ### $e_0 = 0.2, e_1 = 0.4$

# %%
from runner import run
run({
    'dataset': 'twonorm', 
    'e0': 0.2, 'e1': 0.4,
    'episodes': 1000,
    'batchsize': 4,
    'lr': 0.005,
    'hidsize': [32, 32],
    'test_size': 0.7,
    'val_size': 0.1,
    'dropout': 0, 
    'normalize': True, 
    'equalize_prior': False,
    'alpha': 1.,
    'loss': 'bce',
    'activation': 'relu'
})
# Out:
# Logging to logs/nn/19-08-21-13-37-34
# {'dataset': 'twonorm', 'e0': 0.2, 'e1': 0.4, 'episodes': 1000, 'batchsize': 4, 'lr': 0.005, 'hidsize': [32, 32], 'test_size': 0.7, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'equalize_prior': False, 'alpha': 1.0, 'loss': 'bce', 'activation': 'relu'}
# --------------------------------------
# | [NN] with bce loss      | 0.867    |
# | [NN] with peer loss     | 0.97     |
# | [NN] with surrogate ... | 0.919    |
# --------------------------------------
# Logging to logs/svm/19-08-21-13-38-19
# {'dataset': 'twonorm', 'e0': 0.2, 'e1': 0.4, 'episodes': 1000, 'batchsize': 4, 'lr': 0.005, 'hidsize': [32, 32], 'test_size': 0.7, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'equalize_prior': False, 'alpha': 1.0, 'loss': 'bce', 'activation': 'relu'}
# ------------------------------------
# | [C-SVM] accuracy max  | 0.946    |
# | [C-SVM] accuracy mean | 0.935    |
# | [C-SVM] accuracy min  | 0.929    |
# | [C-SVM] accuracy std  | 0.00541  |
# | [C-SVM] best C1       | 2        |
# ------------------------------------
# Logging to logs/pam/19-08-21-13-38-25
# {'dataset': 'twonorm', 'e0': 0.2, 'e1': 0.4, 'episodes': 1000, 'batchsize': 4, 'lr': 0.005, 'hidsize': [32, 32], 'test_size': 0.7, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'equalize_prior': False, 'alpha': 1.0, 'loss': 'bce', 'activation': 'relu'}
# ----------------------------------
# | [PAM] accuracy max  | 0.953    |
# | [PAM] accuracy mean | 0.937    |
# | [PAM] accuracy min  | 0.929    |
# | [PAM] accuracy std  | 0.00806  |
# | [PAM] best margin   | 0.5      |
# ----------------------------------

# %% [markdown]
# ### $e_0=0.4, e_1=0.4$

# %%
from runner import run
run({
    'dataset': 'twonorm', 
    'e0': 0.4, 'e1': 0.4,
    'episodes': 2000,
    'batchsize': 4,
    'lr': 0.005,
    'hidsize': [32, 32],
    'test_size': 0.7,
    'val_size': 0.1,
    'dropout': 0, 
    'normalize': True, 
    'equalize_prior': False,
    'alpha': 1.,
    'loss': 'bce',
    'activation': 'relu'
})
# Out:
# Logging to logs/nn/19-08-21-13-36-12
# {'dataset': 'twonorm', 'e0': 0.4, 'e1': 0.4, 'episodes': 2000, 'batchsize': 4, 'lr': 0.005, 'hidsize': [32, 32], 'test_size': 0.7, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'equalize_prior': False, 'alpha': 1.0, 'loss': 'bce', 'activation': 'relu'}
# --------------------------------------
# | [NN] with bce loss      | 0.724    |
# | [NN] with peer loss     | 0.963    |
# | [NN] with surrogate ... | 0.867    |
# --------------------------------------
# Logging to logs/svm/19-08-21-13-37-25
# {'dataset': 'twonorm', 'e0': 0.4, 'e1': 0.4, 'episodes': 2000, 'batchsize': 4, 'lr': 0.005, 'hidsize': [32, 32], 'test_size': 0.7, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'equalize_prior': False, 'alpha': 1.0, 'loss': 'bce', 'activation': 'relu'}
# ------------------------------------
# | [C-SVM] accuracy max  | 0.897    |
# | [C-SVM] accuracy mean | 0.875    |
# | [C-SVM] accuracy min  | 0.861    |
# | [C-SVM] accuracy std  | 0.0125   |
# | [C-SVM] best C1       | 1        |
# ------------------------------------
# Logging to logs/pam/19-08-21-13-37-31
# {'dataset': 'twonorm', 'e0': 0.4, 'e1': 0.4, 'episodes': 2000, 'batchsize': 4, 'lr': 0.005, 'hidsize': [32, 32], 'test_size': 0.7, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'equalize_prior': False, 'alpha': 1.0, 'loss': 'bce', 'activation': 'relu'}
# ----------------------------------
# | [PAM] accuracy max  | 0.964    |
# | [PAM] accuracy mean | 0.957    |
# | [PAM] accuracy min  | 0.948    |
# | [PAM] accuracy std  | 0.00509  |
# | [PAM] best margin   | 0.5      |
# ----------------------------------

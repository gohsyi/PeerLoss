# %% [markdown]
# # Waveform (21,1647,3353)

# %% [markdown]
# ## Describe
#
# | Total | Positive | Attributes | Normalized |
# |:-----:|:--------:|:----------:|:----------:|
# |  5000 |  32.9%   |     21     |     Yes    |

# %%
default_args = {
    'dataset': 'waveform',
    'test_size': 0.15,
    'val_size': 0.1,
    'dropout': 0, 
    'normalize': True,
    'loss': 'bce',
    'activation': 'relu',
    'verbose': True,
}

# %% [markdown]
# ## With Prior Equalization

# %% [markdown]
# ### $e_0 = 0.1, e_1 = 0.3$

# %%
from runner import run
args = default_args.copy()
args.update({
    'dataset': 'waveform', 
    'e0': 0.1, 'e1': 0.3, 
    'equalize_prior': True, 
    'episodes': 1000,  
    'batchsize': 4, 
    'hidsize': [16, 16], 
    'lr': 0.001, 
    'alpha': 1.
})
run(args)
# Out:
# Logging to logs/nn/19-08-30-16-54-35
# {'dataset': 'waveform', 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'e0': 0.1, 'e1': 0.3, 'equalize_prior': True, 'episodes': 1000, 'batchsize': 4, 'hidsize': [16, 16], 'lr': 0.001, 'alpha': 1.0}
# --------------------------------------
# | [NN] with bce loss      | 0.87     |
# | [NN] with peer loss     | 0.874    |
# | [NN] with surrogate ... | 0.897    |
# --------------------------------------
# Logging to logs/svm/19-08-30-16-54-47
# {'dataset': 'waveform', 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'e0': 0.1, 'e1': 0.3, 'equalize_prior': True, 'episodes': 1000, 'batchsize': 4, 'hidsize': [16, 16], 'lr': 0.001, 'alpha': 1.0}
# --------------------------------
# | [C-SVM] C1 = 0.1  | 0.599    |
# | [C-SVM] C1 = 0.2  | 0.599    |
# | [C-SVM] C1 = 0.25 | 0.599    |
# | [C-SVM] C1 = 0.33 | 0.6      |
# | [C-SVM] C1 = 0.5  | 0.656    |
# | [C-SVM] C1 = 1.0  | 0.745    |
# | [C-SVM] C1 = 10.0 | 0.618    |
# | [C-SVM] C1 = 2.0  | 0.733    |
# | [C-SVM] C1 = 3.0  | 0.713    |
# | [C-SVM] C1 = 4.0  | 0.694    |
# | [C-SVM] C1 = 5.0  | 0.677    |
# --------------------------------
# ------------------------------------
# | [C-SVM] accuracy max  | 0.907    |
# | [C-SVM] accuracy mean | 0.876    |
# | [C-SVM] accuracy min  | 0.861    |
# | [C-SVM] accuracy std  | 0.016    |
# | [C-SVM] best C1       | 1        |
# ------------------------------------
# Logging to logs/pam/19-08-30-16-54-52
# {'dataset': 'waveform', 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'e0': 0.1, 'e1': 0.3, 'equalize_prior': True, 'episodes': 1000, 'batchsize': 4, 'hidsize': [16, 16], 'lr': 0.001, 'alpha': 1.0}
# -----------------------------------
# | [PAM] margin = 0     | 0.619    |
# | [PAM] margin = 0.125 | 0.72     |
# | [PAM] margin = 0.25  | 0.725    |
# | [PAM] margin = 0.5   | 0.727    |
# | [PAM] margin = 1     | 0.73     |
# -----------------------------------
# ----------------------------------
# | [PAM] accuracy max  | 0.905    |
# | [PAM] accuracy mean | 0.879    |
# | [PAM] accuracy min  | 0.842    |
# | [PAM] accuracy std  | 0.021    |
# | [PAM] best margin   | 1        |
# ----------------------------------

# %%
from runner import run
args = default_args.copy()
args.update({
    'dataset': 'waveform', 
    'e0': 0.1, 'e1': 0.3, 
    'equalize_prior': True, 
    'episodes': 2000, 
    'batchsize': 4, 
    'hidsize': [32, 32], 
    'lr': 0.005, 
    'alpha': 1.,
    'test_size': 0.75,
    'val_size': 0.05,
})
run(args)
# Out:
# Logging to logs/nn/19-08-24-18-28-10
# {'test_size': 0.75, 'val_size': 0.05, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'dataset': 'waveform', 'e0': 0.1, 'e1': 0.3, 'equalize_prior': True, 'episodes': 2000, 'batchsize': 4, 'hidsize': [32, 32], 'lr': 0.005, 'alpha': 1.0}
# --------------------------------------
# | [NN] with bce loss      | 0.795    |
# | [NN] with peer loss     | 0.87     |
# | [NN] with surrogate ... | 0.859    |
# --------------------------------------
# Logging to logs/svm/19-08-24-18-29-12
# {'test_size': 0.75, 'val_size': 0.05, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'dataset': 'waveform', 'e0': 0.1, 'e1': 0.3, 'equalize_prior': True, 'episodes': 2000, 'batchsize': 4, 'hidsize': [32, 32], 'lr': 0.005, 'alpha': 1.0}
# --------------------------------
# | [C-SVM] C1 = 0.1  | 0.605    |
# | [C-SVM] C1 = 0.2  | 0.605    |
# | [C-SVM] C1 = 0.25 | 0.605    |
# | [C-SVM] C1 = 0.33 | 0.605    |
# | [C-SVM] C1 = 0.5  | 0.651    |
# | [C-SVM] C1 = 1.0  | 0.731    |
# | [C-SVM] C1 = 10.0 | 0.653    |
# | [C-SVM] C1 = 2.0  | 0.715    |
# | [C-SVM] C1 = 3.0  | 0.709    |
# | [C-SVM] C1 = 4.0  | 0.695    |
# | [C-SVM] C1 = 5.0  | 0.68     |
# --------------------------------
# ------------------------------------
# | [C-SVM] accuracy max  | 0.883    |
# | [C-SVM] accuracy mean | 0.862    |
# | [C-SVM] accuracy min  | 0.847    |
# | [C-SVM] accuracy std  | 0.0107   |
# | [C-SVM] best C1       | 1        |
# ------------------------------------
# Logging to logs/pam/19-08-24-18-29-13
# {'test_size': 0.75, 'val_size': 0.05, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'dataset': 'waveform', 'e0': 0.1, 'e1': 0.3, 'equalize_prior': True, 'episodes': 2000, 'batchsize': 4, 'hidsize': [32, 32], 'lr': 0.005, 'alpha': 1.0}
# ---------------------------------
# | [PAM] margin = 0.0 | 0.608    |
# | [PAM] margin = 0.1 | 0.695    |
# | [PAM] margin = 0.2 | 0.711    |
# | [PAM] margin = 0.3 | 0.713    |
# | [PAM] margin = 0.4 | 0.721    |
# | [PAM] margin = 0.5 | 0.72     |
# | [PAM] margin = 0.6 | 0.712    |
# | [PAM] margin = 0.7 | 0.72     |
# | [PAM] margin = 0.8 | 0.725    |
# | [PAM] margin = 0.9 | 0.717    |
# ---------------------------------
# ----------------------------------
# | [PAM] accuracy max  | 0.894    |
# | [PAM] accuracy mean | 0.875    |
# | [PAM] accuracy min  | 0.862    |
# | [PAM] accuracy std  | 0.0102   |
# | [PAM] best margin   | 0.8      |
# ----------------------------------
# Process ForkPoolWorker-90:
# Process ForkPoolWorker-89:
# Process ForkPoolWorker-92:
# Process ForkPoolWorker-98:
# Process ForkPoolWorker-104:
# Process ForkPoolWorker-106:
# Process ForkPoolWorker-95:
# Process ForkPoolWorker-101:
# Process ForkPoolWorker-110:
# Process ForkPoolWorker-108:
# Process ForkPoolWorker-103:
# Process ForkPoolWorker-91:
# Process ForkPoolWorker-96:
# Process ForkPoolWorker-93:
# Process ForkPoolWorker-111:
# Process ForkPoolWorker-100:
# Process ForkPoolWorker-102:
# Traceback (most recent call last):
# Process ForkPoolWorker-99:
# Traceback (most recent call last):
# Process ForkPoolWorker-109:
# Process ForkPoolWorker-105:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Process ForkPoolWorker-94:
# Traceback (most recent call last):
# Process ForkPoolWorker-107:
# Traceback (most recent call last):
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
# Process ForkPoolWorker-97:
# Traceback (most recent call last):
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
# Process ForkPoolWorker-112:
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
# Traceback (most recent call last):
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
# Traceback (most recent call last):
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/queues.py", line 335, in get
#     res = self._reader.recv_bytes()
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
# KeyboardInterrupt
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# Traceback (most recent call last):
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
# KeyboardInterrupt
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
# KeyboardInterrupt
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
# KeyboardInterrupt
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
# KeyboardInterrupt
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
# KeyboardInterrupt
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
# KeyboardInterrupt
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/queues.py", line 335, in get
#     res = self._reader.recv_bytes()
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
# Traceback (most recent call last):
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/queues.py", line 335, in get
#     res = self._reader.recv_bytes()
# KeyboardInterrupt
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
# KeyboardInterrupt
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
# KeyboardInterrupt
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
# KeyboardInterrupt
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# KeyboardInterrupt

# %% [markdown]
# ### $e_0 = 0.2, e_1 = 0.2$

# %%
from runner import run
args = default_args.copy()
args.update({
    'e0': 0.2, 'e1': 0.2, 
    'equalize_prior': True, 
    'episodes': 2000,  
    'batchsize': 4, 
    'hidsize': [16, 16], 
    'lr': 0.001, 
    'alpha': 1.,
})
run(args)
# Out:
# Logging to logs/nn/19-08-30-16-55-25
# {'dataset': 'waveform', 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'e0': 0.2, 'e1': 0.2, 'equalize_prior': True, 'episodes': 2000, 'batchsize': 4, 'hidsize': [16, 16], 'lr': 0.001, 'alpha': 1.0}
# --------------------------------------
# | [NN] with bce loss      | 0.903    |
# | [NN] with peer loss     | 0.87     |
# | [NN] with surrogate ... | 0.903    |
# --------------------------------------
# Logging to logs/svm/19-08-30-16-55-48
# {'dataset': 'waveform', 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'e0': 0.2, 'e1': 0.2, 'equalize_prior': True, 'episodes': 2000, 'batchsize': 4, 'hidsize': [16, 16], 'lr': 0.001, 'alpha': 1.0}
# --------------------------------
# | [C-SVM] C1 = 0.1  | 0.5      |
# | [C-SVM] C1 = 0.2  | 0.5      |
# | [C-SVM] C1 = 0.25 | 0.51     |
# | [C-SVM] C1 = 0.33 | 0.62     |
# | [C-SVM] C1 = 0.5  | 0.716    |
# | [C-SVM] C1 = 1.0  | 0.752    |
# | [C-SVM] C1 = 10.0 | 0.577    |
# | [C-SVM] C1 = 2.0  | 0.723    |
# | [C-SVM] C1 = 3.0  | 0.681    |
# | [C-SVM] C1 = 4.0  | 0.642    |
# | [C-SVM] C1 = 5.0  | 0.611    |
# --------------------------------
# ------------------------------------
# | [C-SVM] accuracy max  | 0.921    |
# | [C-SVM] accuracy mean | 0.9      |
# | [C-SVM] accuracy min  | 0.879    |
# | [C-SVM] accuracy std  | 0.0142   |
# | [C-SVM] best C1       | 1        |
# ------------------------------------
# Logging to logs/pam/19-08-30-16-55-52
# {'dataset': 'waveform', 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'e0': 0.2, 'e1': 0.2, 'equalize_prior': True, 'episodes': 2000, 'batchsize': 4, 'hidsize': [16, 16], 'lr': 0.001, 'alpha': 1.0}
# -----------------------------------
# | [PAM] margin = 0     | 0.598    |
# | [PAM] margin = 0.125 | 0.731    |
# | [PAM] margin = 0.25  | 0.73     |
# | [PAM] margin = 0.5   | 0.729    |
# | [PAM] margin = 1     | 0.729    |
# -----------------------------------
# ----------------------------------
# | [PAM] accuracy max  | 0.885    |
# | [PAM] accuracy mean | 0.857    |
# | [PAM] accuracy min  | 0.834    |
# | [PAM] accuracy std  | 0.0165   |
# | [PAM] best margin   | 0.125    |
# ----------------------------------

# %% [markdown]
# ### $e_0 = 0.2, e_1 = 0.4$

# %%
from runner import run
args = default_args.copy()
args.update({
    'e0': 0.2, 'e1': 0.4, 
    'equalize_prior': True, 
    'episodes': 2000,  
    'batchsize': 4, 
    'hidsize': [16, 16], 
    'lr': 0.001, 
    'alpha': 1.,
})
run(args)
# Out:
# Logging to logs/nn/19-08-30-16-56-22
# {'dataset': 'waveform', 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'e0': 0.2, 'e1': 0.4, 'equalize_prior': True, 'episodes': 2000, 'batchsize': 4, 'hidsize': [16, 16], 'lr': 0.001, 'alpha': 1.0}
# --------------------------------------
# | [NN] with bce loss      | 0.825    |
# | [NN] with peer loss     | 0.871    |
# | [NN] with surrogate ... | 0.895    |
# --------------------------------------
# Logging to logs/svm/19-08-30-16-56-42
# {'dataset': 'waveform', 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'e0': 0.2, 'e1': 0.4, 'equalize_prior': True, 'episodes': 2000, 'batchsize': 4, 'hidsize': [16, 16], 'lr': 0.001, 'alpha': 1.0}
# --------------------------------
# | [C-SVM] C1 = 0.1  | 0.6      |
# | [C-SVM] C1 = 0.2  | 0.6      |
# | [C-SVM] C1 = 0.25 | 0.6      |
# | [C-SVM] C1 = 0.33 | 0.6      |
# | [C-SVM] C1 = 0.5  | 0.6      |
# | [C-SVM] C1 = 1.0  | 0.664    |
# | [C-SVM] C1 = 10.0 | 0.48     |
# | [C-SVM] C1 = 2.0  | 0.631    |
# | [C-SVM] C1 = 3.0  | 0.581    |
# | [C-SVM] C1 = 4.0  | 0.547    |
# | [C-SVM] C1 = 5.0  | 0.512    |
# --------------------------------
# ------------------------------------
# | [C-SVM] accuracy max  | 0.842    |
# | [C-SVM] accuracy mean | 0.821    |
# | [C-SVM] accuracy min  | 0.786    |
# | [C-SVM] accuracy std  | 0.0174   |
# | [C-SVM] best C1       | 1        |
# ------------------------------------
# Logging to logs/pam/19-08-30-16-56-48
# {'dataset': 'waveform', 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'e0': 0.2, 'e1': 0.4, 'equalize_prior': True, 'episodes': 2000, 'batchsize': 4, 'hidsize': [16, 16], 'lr': 0.001, 'alpha': 1.0}
# -----------------------------------
# | [PAM] margin = 0     | 0.556    |
# | [PAM] margin = 0.125 | 0.632    |
# | [PAM] margin = 0.25  | 0.63     |
# | [PAM] margin = 0.5   | 0.631    |
# | [PAM] margin = 1     | 0.635    |
# -----------------------------------
# ----------------------------------
# | [PAM] accuracy max  | 0.82     |
# | [PAM] accuracy mean | 0.745    |
# | [PAM] accuracy min  | 0.657    |
# | [PAM] accuracy std  | 0.0429   |
# | [PAM] best margin   | 1        |
# ----------------------------------

# %% [markdown]
# ### $e_0=0.4, e_1=0.4$

# %%
from runner import run
args = default_args.copy()
args.update({
    'dataset': 'waveform', 
    'e0': 0.4, 'e1': 0.4, 
    'equalize_prior': True, 
    'episodes': 2000, 
    'batchsize': 4, 
    'hidsize': [32, 32], 
    'lr': 0.005, 
    'alpha': 1.,
    'test_size': 0.75,
    'val_size': 0.05,
})
run(args)
# Out:
# Logging to logs/nn/19-08-24-18-36-51
# {'test_size': 0.75, 'val_size': 0.05, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'dataset': 'waveform', 'e0': 0.4, 'e1': 0.4, 'equalize_prior': True, 'episodes': 2000, 'batchsize': 4, 'hidsize': [32, 32], 'lr': 0.005, 'alpha': 1.0}
# --------------------------------------
# | [NN] with bce loss      | 0.629    |
# | [NN] with peer loss     | 0.87     |
# | [NN] with surrogate ... | 0.805    |
# --------------------------------------
# Logging to logs/svm/19-08-24-18-38-06
# {'test_size': 0.75, 'val_size': 0.05, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'dataset': 'waveform', 'e0': 0.4, 'e1': 0.4, 'equalize_prior': True, 'episodes': 2000, 'batchsize': 4, 'hidsize': [32, 32], 'lr': 0.005, 'alpha': 1.0}
# --------------------------------
# | [C-SVM] C1 = 0.1  | 0.502    |
# | [C-SVM] C1 = 0.2  | 0.502    |
# | [C-SVM] C1 = 0.25 | 0.502    |
# | [C-SVM] C1 = 0.33 | 0.502    |
# | [C-SVM] C1 = 0.5  | 0.502    |
# | [C-SVM] C1 = 1.0  | 0.555    |
# | [C-SVM] C1 = 10.0 | 0.514    |
# | [C-SVM] C1 = 2.0  | 0.528    |
# | [C-SVM] C1 = 3.0  | 0.516    |
# | [C-SVM] C1 = 4.0  | 0.516    |
# | [C-SVM] C1 = 5.0  | 0.517    |
# --------------------------------
# ------------------------------------
# | [C-SVM] accuracy max  | 0.82     |
# | [C-SVM] accuracy mean | 0.776    |
# | [C-SVM] accuracy min  | 0.72     |
# | [C-SVM] accuracy std  | 0.0348   |
# | [C-SVM] best C1       | 1        |
# ------------------------------------
# Logging to logs/pam/19-08-24-18-38-06
# {'test_size': 0.75, 'val_size': 0.05, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'dataset': 'waveform', 'e0': 0.4, 'e1': 0.4, 'equalize_prior': True, 'episodes': 2000, 'batchsize': 4, 'hidsize': [32, 32], 'lr': 0.005, 'alpha': 1.0}
# ---------------------------------
# | [PAM] margin = 0.0 | 0.509    |
# | [PAM] margin = 0.1 | 0.53     |
# | [PAM] margin = 0.2 | 0.519    |
# | [PAM] margin = 0.3 | 0.54     |
# | [PAM] margin = 0.4 | 0.549    |
# | [PAM] margin = 0.5 | 0.554    |
# | [PAM] margin = 0.6 | 0.546    |
# | [PAM] margin = 0.7 | 0.545    |
# | [PAM] margin = 0.8 | 0.561    |
# | [PAM] margin = 0.9 | 0.557    |
# ---------------------------------
# ----------------------------------
# | [PAM] accuracy max  | 0.828    |
# | [PAM] accuracy mean | 0.807    |
# | [PAM] accuracy min  | 0.742    |
# | [PAM] accuracy std  | 0.0274   |
# | [PAM] best margin   | 0.8      |
# ----------------------------------
# Process ForkPoolWorker-164:
# Process ForkPoolWorker-168:
# Process ForkPoolWorker-172:
# Process ForkPoolWorker-169:
# Process ForkPoolWorker-166:
# Process ForkPoolWorker-180:
# Process ForkPoolWorker-161:
# Process ForkPoolWorker-184:
# Process ForkPoolWorker-173:
# Process ForkPoolWorker-163:
# Process ForkPoolWorker-175:
# Process ForkPoolWorker-170:
# Process ForkPoolWorker-167:
# Process ForkPoolWorker-181:
# Process ForkPoolWorker-178:
# Process ForkPoolWorker-179:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Process ForkPoolWorker-162:
# Process ForkPoolWorker-183:
# Process ForkPoolWorker-176:
# Process ForkPoolWorker-174:
# Process ForkPoolWorker-171:
# Process ForkPoolWorker-182:
# Process ForkPoolWorker-177:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Process ForkPoolWorker-165:
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/queues.py", line 335, in get
#     res = self._reader.recv_bytes()
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
# Traceback (most recent call last):
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
# KeyboardInterrupt
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/queues.py", line 335, in get
#     res = self._reader.recv_bytes()
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
# KeyboardInterrupt
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
# KeyboardInterrupt
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
# KeyboardInterrupt
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
# KeyboardInterrupt
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/queues.py", line 335, in get
#     res = self._reader.recv_bytes()
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
# KeyboardInterrupt
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
# KeyboardInterrupt
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
# KeyboardInterrupt
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
# KeyboardInterrupt
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/Users/henryguo/anaconda3/envs/py36/lib/python3.6/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()

# %% [markdown]
# ## Without Prior Equalization

# %% [markdown]
# ### $e_0 = 0.1, e_1 = 0.3$

# %%
from run_nn import find_best_alpha

args = default_args.copy()
args.update({
    'dataset': 'waveform', 
    'e0': 0.1, 'e1': 0.3, 
    'equalize_prior': False, 
    'episodes': 1000, 
    'batchsize': 4, 
    'hidsize': [16, 16], 
    'lr': 0.001, 
})
find_best_alpha(args)
# Out:
# ---------------------------------
# | [PEER] alpha = 0.4 | 0.894    |
# | [PEER] alpha = 0.5 | 0.893    |
# | [PEER] alpha = 0.6 | 0.89     |
# | [PEER] alpha = 0.7 | 0.879    |
# | [PEER] alpha = 0.8 | 0.86     |
# | [PEER] alpha = 0.9 | 0.832    |
# | [PEER] alpha = 1.0 | 0.818    |
# | [PEER] alpha = 1.1 | 0.799    |
# | [PEER] alpha = 1.2 | 0.788    |
# ---------------------------------
# {'alpha': 0.4}

# %%
from runner import run

args = default_args.copy()
args.update({
    'dataset': 'waveform', 
    'e0': 0.1, 'e1': 0.3, 
    'equalize_prior': False, 
    'episodes': 1000, 
    'batchsize': 4, 
    'hidsize': [16, 16], 
    'lr': 0.001, 
#     'alpha': 0.6,
})
run(args)
# Out:
# Logging to logs/nn/19-08-27-15-25-45
# {'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'dataset': 'waveform', 'e0': 0.1, 'e1': 0.3, 'equalize_prior': False, 'episodes': 1000, 'batchsize': 4, 'hidsize': [16, 16], 'lr': 0.001}
# ---------------------------------
# | [PEER] alpha = 0.4 | 0.777    |
# | [PEER] alpha = 0.5 | 0.778    |
# | [PEER] alpha = 0.6 | 0.775    |
# | [PEER] alpha = 0.7 | 0.763    |
# | [PEER] alpha = 0.8 | 0.738    |
# | [PEER] alpha = 0.9 | 0.714    |
# | [PEER] alpha = 1.0 | 0.696    |
# | [PEER] alpha = 1.1 | 0.678    |
# | [PEER] alpha = 1.2 | 0.665    |
# ---------------------------------
# --------------------------------------
# | [NN] with bce loss      | 0.863    |
# | [NN] with peer loss     | 0.893    |
# | [NN] with surrogate ... | 0.898    |
# | [PEER] best alpha       | 0.5      |
# --------------------------------------
# Logging to logs/svm/19-08-27-15-28-16
# {'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'dataset': 'waveform', 'e0': 0.1, 'e1': 0.3, 'equalize_prior': False, 'episodes': 1000, 'batchsize': 4, 'hidsize': [16, 16], 'lr': 0.001}
# --------------------------------
# | [C-SVM] C1 = 0.1  | 0.703    |
# | [C-SVM] C1 = 0.2  | 0.703    |
# | [C-SVM] C1 = 0.25 | 0.703    |
# | [C-SVM] C1 = 0.33 | 0.703    |
# | [C-SVM] C1 = 0.5  | 0.721    |
# | [C-SVM] C1 = 1.0  | 0.788    |
# | [C-SVM] C1 = 10.0 | 0.584    |
# | [C-SVM] C1 = 2.0  | 0.774    |
# | [C-SVM] C1 = 3.0  | 0.749    |
# | [C-SVM] C1 = 4.0  | 0.723    |
# | [C-SVM] C1 = 5.0  | 0.688    |
# --------------------------------
# ------------------------------------
# | [C-SVM] accuracy max  | 0.892    |
# | [C-SVM] accuracy mean | 0.878    |
# | [C-SVM] accuracy min  | 0.856    |
# | [C-SVM] accuracy std  | 0.011    |
# | [C-SVM] best C1       | 1        |
# ------------------------------------
# Logging to logs/pam/19-08-27-15-28-27
# {'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'dataset': 'waveform', 'e0': 0.1, 'e1': 0.3, 'equalize_prior': False, 'episodes': 1000, 'batchsize': 4, 'hidsize': [16, 16], 'lr': 0.001}
# -----------------------------------
# | [PAM] margin = 0     | 0.661    |
# | [PAM] margin = 0.125 | 0.74     |
# | [PAM] margin = 0.25  | 0.728    |
# | [PAM] margin = 0.5   | 0.711    |
# | [PAM] margin = 1     | 0.707    |
# -----------------------------------
# ----------------------------------
# | [PAM] accuracy max  | 0.86     |
# | [PAM] accuracy mean | 0.765    |
# | [PAM] accuracy min  | 0.656    |
# | [PAM] accuracy std  | 0.0678   |
# | [PAM] best margin   | 0.125    |
# ----------------------------------

# %%
from runner import run
run({
    'dataset': 'waveform', 
    'e0': 0.1, 'e1': 0.3,
    'episodes': 1000,
#     'batchsize': 16,
#     'hidsize': [16, 16],
#     'lr': 0.005,
    'test_size': 0.15,
    'val_size': 0.1,
    'dropout': 0, 
    'normalize': True,
    'equalize_prior': False,
    'alpha': 1.,
    'loss': 'bce',
    'activation': 'relu',
    'verbose': True,
})
# Out:
# Logging to logs/nn/19-08-21-15-48-03
# {'dataset': 'waveform', 'e0': 0.1, 'e1': 0.3, 'episodes': 1000, 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'equalize_prior': False, 'alpha': 1.0, 'loss': 'bce', 'activation': 'relu', 'verbose': True}
# batchsize: 4	lr:0.0007	hidsize:  8	acc:0.745
# batchsize: 4	lr:0.0007	hidsize: 16	acc:0.818
# batchsize: 4	lr:0.0007	hidsize: 32	acc:0.806
# batchsize: 4	lr:0.0007	hidsize: 64	acc:0.814
# batchsize: 4	lr: 0.001	hidsize:  8	acc:0.764
# batchsize: 4	lr: 0.001	hidsize: 16	acc:0.818
# batchsize: 4	lr: 0.001	hidsize: 32	acc:0.809
# batchsize: 4	lr: 0.001	hidsize: 64	acc:0.812
# batchsize: 4	lr: 0.005	hidsize:  8	acc:0.812
# batchsize: 4	lr: 0.005	hidsize: 16	acc:0.812
# batchsize: 4	lr: 0.005	hidsize: 32	acc:0.806
# batchsize: 4	lr: 0.005	hidsize: 64	acc:0.811
# batchsize: 4	lr:  0.01	hidsize:  8	acc:0.81
# batchsize: 4	lr:  0.01	hidsize: 16	acc:0.81
# batchsize: 4	lr:  0.01	hidsize: 32	acc:0.805
# batchsize: 4	lr:  0.01	hidsize: 64	acc:0.811
# batchsize: 4	lr:  0.05	hidsize:  8	acc:0.771
# batchsize: 4	lr:  0.05	hidsize: 16	acc:0.805
# batchsize: 4	lr:  0.05	hidsize: 32	acc:0.806
# batchsize: 4	lr:  0.05	hidsize: 64	acc:0.809
# batchsize:16	lr:0.0007	hidsize:  8	acc:0.765
# batchsize:16	lr:0.0007	hidsize: 16	acc:0.811
# batchsize:16	lr:0.0007	hidsize: 32	acc:0.804
# batchsize:16	lr:0.0007	hidsize: 64	acc:0.806
# batchsize:16	lr: 0.001	hidsize:  8	acc:0.761
# batchsize:16	lr: 0.001	hidsize: 16	acc:0.811
# batchsize:16	lr: 0.001	hidsize: 32	acc:0.805
# batchsize:16	lr: 0.001	hidsize: 64	acc:0.806
# batchsize:16	lr: 0.005	hidsize:  8	acc:0.756
# batchsize:16	lr: 0.005	hidsize: 16	acc:0.808
# batchsize:16	lr: 0.005	hidsize: 32	acc:0.805
# batchsize:16	lr: 0.005	hidsize: 64	acc:0.807
# batchsize:16	lr:  0.01	hidsize:  8	acc:0.754
# batchsize:16	lr:  0.01	hidsize: 16	acc:0.808
# batchsize:16	lr:  0.01	hidsize: 32	acc:0.804
# batchsize:16	lr:  0.01	hidsize: 64	acc:0.809
# batchsize:16	lr:  0.05	hidsize:  8	acc:0.756
# batchsize:16	lr:  0.05	hidsize: 16	acc:0.807
# batchsize:16	lr:  0.05	hidsize: 32	acc:0.812
# batchsize:16	lr:  0.05	hidsize: 64	acc:0.806
# batchsize:32	lr:0.0007	hidsize:  8	acc:0.763
# batchsize:32	lr:0.0007	hidsize: 16	acc:0.809
# batchsize:32	lr:0.0007	hidsize: 32	acc:0.801
# batchsize:32	lr:0.0007	hidsize: 64	acc:0.804
# batchsize:32	lr: 0.001	hidsize:  8	acc:0.762
# batchsize:32	lr: 0.001	hidsize: 16	acc:0.809
# batchsize:32	lr: 0.001	hidsize: 32	acc:0.802
# batchsize:32	lr: 0.001	hidsize: 64	acc:0.804
# batchsize:32	lr: 0.005	hidsize:  8	acc:0.757
# batchsize:32	lr: 0.005	hidsize: 16	acc:0.804
# batchsize:32	lr: 0.005	hidsize: 32	acc:0.8
# batchsize:32	lr: 0.005	hidsize: 64	acc:0.804
# batchsize:32	lr:  0.01	hidsize:  8	acc:0.756
# batchsize:32	lr:  0.01	hidsize: 16	acc:0.806
# batchsize:32	lr:  0.01	hidsize: 32	acc:0.797
# batchsize:32	lr:  0.01	hidsize: 64	acc:0.802
# batchsize:32	lr:  0.05	hidsize:  8	acc:0.805
# batchsize:32	lr:  0.05	hidsize: 16	acc:0.8
# batchsize:32	lr:  0.05	hidsize: 32	acc:0.794
# batchsize:32	lr:  0.05	hidsize: 64	acc:0.801
# batchsize:64	lr:0.0007	hidsize:  8	acc:0.764
# batchsize:64	lr:0.0007	hidsize: 16	acc:0.809
# batchsize:64	lr:0.0007	hidsize: 32	acc:0.799
# batchsize:64	lr:0.0007	hidsize: 64	acc:0.803
# batchsize:64	lr: 0.001	hidsize:  8	acc:0.761
# batchsize:64	lr: 0.001	hidsize: 16	acc:0.807
# batchsize:64	lr: 0.001	hidsize: 32	acc:0.799
# batchsize:64	lr: 0.001	hidsize: 64	acc:0.803
# batchsize:64	lr: 0.005	hidsize:  8	acc:0.806
# batchsize:64	lr: 0.005	hidsize: 16	acc:0.804
# batchsize:64	lr: 0.005	hidsize: 32	acc:0.797
# batchsize:64	lr: 0.005	hidsize: 64	acc:0.803
# batchsize:64	lr:  0.01	hidsize:  8	acc:0.754
# batchsize:64	lr:  0.01	hidsize: 16	acc:0.805
# batchsize:64	lr:  0.01	hidsize: 32	acc:0.795
# batchsize:64	lr:  0.01	hidsize: 64	acc:0.8
# batchsize:64	lr:  0.05	hidsize:  8	acc:0.752
# batchsize:64	lr:  0.05	hidsize: 16	acc:0.802
# batchsize:64	lr:  0.05	hidsize: 32	acc:0.796
# batchsize:64	lr:  0.05	hidsize: 64	acc:0.799
# --------------------------------------
# | [NN] best batchsize     | 4        |
# | [NN] best hidsize       | [16, 16] |
# | [NN] best learning rate | 0.001    |
# --------------------------------------
# --------------------------------------
# | [NN] with bce loss      | 0.863    |
# | [NN] with peer loss     | 0.818    |
# | [NN] with surrogate ... | 0.898    |
# --------------------------------------
# Logging to logs/svm/19-08-21-16-07-10
# {'dataset': 'waveform', 'e0': 0.1, 'e1': 0.3, 'episodes': 1000, 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'equalize_prior': False, 'alpha': 1.0, 'loss': 'bce', 'activation': 'relu', 'verbose': True}
# --------------------------------
# | [C-SVM] C1 = 0.1  | 0.703    |
# | [C-SVM] C1 = 0.2  | 0.703    |
# | [C-SVM] C1 = 0.25 | 0.703    |
# | [C-SVM] C1 = 0.33 | 0.703    |
# | [C-SVM] C1 = 0.5  | 0.721    |
# | [C-SVM] C1 = 1.0  | 0.788    |
# | [C-SVM] C1 = 10.0 | 0.584    |
# | [C-SVM] C1 = 2.0  | 0.774    |
# | [C-SVM] C1 = 3.0  | 0.749    |
# | [C-SVM] C1 = 4.0  | 0.723    |
# | [C-SVM] C1 = 5.0  | 0.688    |
# --------------------------------
# ------------------------------------
# | [C-SVM] accuracy max  | 0.892    |
# | [C-SVM] accuracy mean | 0.878    |
# | [C-SVM] accuracy min  | 0.856    |
# | [C-SVM] accuracy std  | 0.011    |
# | [C-SVM] best C1       | 1        |
# ------------------------------------
# Logging to logs/pam/19-08-21-16-07-22
# {'dataset': 'waveform', 'e0': 0.1, 'e1': 0.3, 'episodes': 1000, 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'equalize_prior': False, 'alpha': 1.0, 'loss': 'bce', 'activation': 'relu', 'verbose': True}
# ---------------------------------
# | [PAM] margin = 0.0 | 0.668    |
# | [PAM] margin = 0.1 | 0.727    |
# | [PAM] margin = 0.2 | 0.721    |
# | [PAM] margin = 0.3 | 0.736    |
# | [PAM] margin = 0.4 | 0.719    |
# | [PAM] margin = 0.5 | 0.711    |
# ---------------------------------
# ----------------------------------
# | [PAM] accuracy max  | 0.809    |
# | [PAM] accuracy mean | 0.707    |
# | [PAM] accuracy min  | 0.659    |
# | [PAM] accuracy std  | 0.0542   |
# | [PAM] best margin   | 0.3      |
# ----------------------------------

# %% [markdown]
# ### $e_0 = 0.2, e_1 = 0.2$

# %%
from runner import run

args = default_args.copy()
args.update({
    'dataset': 'waveform', 
    'e0': 0.2, 'e1': 0.2, 
    'equalize_prior': False, 
    'episodes': 2000, 
    'batchsize': 4, 
    'hidsize': [16, 16], 
    'lr': 0.001, 
#     'alpha': 0.6,
})
run(args)
# Out:
# Logging to logs/nn/19-08-25-23-08-55
# {'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'dataset': 'waveform', 'e0': 0.2, 'e1': 0.2, 'equalize_prior': False, 'episodes': 2000, 'batchsize': 4, 'hidsize': [16, 16], 'lr': 0.001}
# --------------------------------------
# | [PEER] alpha = 0.1      | 0.902    |
# | [PEER] alpha = 0.2      | 0.903    |
# | [PEER] alpha = 0.3      | 0.903    |
# | [PEER] alpha = 0.4      | 0.901    |
# | [PEER] alpha = 0.5      | 0.894    |
# | [PEER] alpha = 0.6      | 0.881    |
# | [PEER] alpha = 0.7      | 0.858    |
# | [PEER] alpha = 0.799... | 0.831    |
# | [PEER] alpha = 0.899... | 0.814    |
# | [PEER] alpha = 0.999... | 0.805    |
# | [PEER] alpha = 1.099... | 0.801    |
# | [PEER] alpha = 1.2      | 0.796    |
# | [PEER] alpha = 1.3      | 0.792    |
# | [PEER] alpha = 1.4      | 0.739    |
# | [PEER] alpha = 1.5      | 0.735    |
# | [PEER] alpha = 1.599... | 0.628    |
# | [PEER] alpha = 1.7      | 0.626    |
# | [PEER] alpha = 1.8      | 0.567    |
# | [PEER] alpha = 1.9      | 0.515    |
# | [PEER] alpha = 2.0      | 0.501    |
# --------------------------------------
# --------------------------------------
# | [NN] with bce loss      | 0.898    |
# | [NN] with peer loss     | 0.903    |
# | [NN] with surrogate ... | 0.899    |
# --------------------------------------
# Logging to logs/svm/19-08-25-23-17-54
# {'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'dataset': 'waveform', 'e0': 0.2, 'e1': 0.2, 'equalize_prior': False, 'episodes': 2000, 'batchsize': 4, 'hidsize': [16, 16], 'lr': 0.001}
# --------------------------------
# | [C-SVM] C1 = 0.1  | 0.603    |
# | [C-SVM] C1 = 0.2  | 0.603    |
# | [C-SVM] C1 = 0.25 | 0.603    |
# | [C-SVM] C1 = 0.33 | 0.638    |
# | [C-SVM] C1 = 0.5  | 0.713    |
# | [C-SVM] C1 = 1.0  | 0.749    |
# | [C-SVM] C1 = 10.0 | 0.462    |
# | [C-SVM] C1 = 2.0  | 0.723    |
# | [C-SVM] C1 = 3.0  | 0.641    |
# | [C-SVM] C1 = 4.0  | 0.571    |
# | [C-SVM] C1 = 5.0  | 0.517    |
# --------------------------------
# ------------------------------------
# | [C-SVM] accuracy max  | 0.907    |
# | [C-SVM] accuracy mean | 0.897    |
# | [C-SVM] accuracy min  | 0.884    |
# | [C-SVM] accuracy std  | 0.00842  |
# | [C-SVM] best C1       | 1        |
# ------------------------------------
# Logging to logs/pam/19-08-25-23-18-05
# {'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'dataset': 'waveform', 'e0': 0.2, 'e1': 0.2, 'equalize_prior': False, 'episodes': 2000, 'batchsize': 4, 'hidsize': [16, 16], 'lr': 0.001}
# -----------------------------------
# | [PAM] margin = 0     | 0.618    |
# | [PAM] margin = 0.125 | 0.692    |
# | [PAM] margin = 0.25  | 0.711    |
# | [PAM] margin = 0.5   | 0.701    |
# | [PAM] margin = 1     | 0.708    |
# | [PAM] margin = 2     | 0.706    |
# | [PAM] margin = 4     | 0.705    |
# -----------------------------------
# ----------------------------------
# | [PAM] accuracy max  | 0.872    |
# | [PAM] accuracy mean | 0.847    |
# | [PAM] accuracy min  | 0.816    |
# | [PAM] accuracy std  | 0.0164   |
# | [PAM] best margin   | 0.25     |
# ----------------------------------

# %%
from runner import run

args = default_args.copy()
args.update({
    'dataset': 'waveform', 
    'e0': 0.2, 'e1': 0.2, 
    'equalize_prior': False, 
    'episodes': 2000, 
    'batchsize': 4, 
    'hidsize': [16, 16], 
    'lr': 0.001, 
#     'alpha': 0.6,
})
run(args)
# Out:
# Logging to logs/nn/19-08-27-15-33-45
# {'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'dataset': 'waveform', 'e0': 0.2, 'e1': 0.2, 'equalize_prior': False, 'episodes': 2000, 'batchsize': 4, 'hidsize': [16, 16], 'lr': 0.001}
# ---------------------------------
# | [PEER] alpha = 0.4 | 0.743    |
# | [PEER] alpha = 0.5 | 0.743    |
# | [PEER] alpha = 0.6 | 0.736    |
# | [PEER] alpha = 0.7 | 0.718    |
# | [PEER] alpha = 0.8 | 0.699    |
# | [PEER] alpha = 0.9 | 0.687    |
# | [PEER] alpha = 1.0 | 0.68     |
# | [PEER] alpha = 1.1 | 0.677    |
# | [PEER] alpha = 1.2 | 0.672    |
# ---------------------------------
# --------------------------------------
# | [NN] with bce loss      | 0.898    |
# | [NN] with peer loss     | 0.901    |
# | [NN] with surrogate ... | 0.899    |
# | [PEER] best alpha       | 0.4      |
# --------------------------------------
# Logging to logs/svm/19-08-27-15-38-05
# {'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'dataset': 'waveform', 'e0': 0.2, 'e1': 0.2, 'equalize_prior': False, 'episodes': 2000, 'batchsize': 4, 'hidsize': [16, 16], 'lr': 0.001}
# --------------------------------
# | [C-SVM] C1 = 0.1  | 0.603    |
# | [C-SVM] C1 = 0.2  | 0.603    |
# | [C-SVM] C1 = 0.25 | 0.603    |
# | [C-SVM] C1 = 0.33 | 0.638    |
# | [C-SVM] C1 = 0.5  | 0.713    |
# | [C-SVM] C1 = 1.0  | 0.749    |
# | [C-SVM] C1 = 10.0 | 0.462    |
# | [C-SVM] C1 = 2.0  | 0.723    |
# | [C-SVM] C1 = 3.0  | 0.641    |
# | [C-SVM] C1 = 4.0  | 0.571    |
# | [C-SVM] C1 = 5.0  | 0.517    |
# --------------------------------
# ------------------------------------
# | [C-SVM] accuracy max  | 0.907    |
# | [C-SVM] accuracy mean | 0.897    |
# | [C-SVM] accuracy min  | 0.884    |
# | [C-SVM] accuracy std  | 0.00842  |
# | [C-SVM] best C1       | 1        |
# ------------------------------------
# Logging to logs/pam/19-08-27-15-38-17
# {'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'dataset': 'waveform', 'e0': 0.2, 'e1': 0.2, 'equalize_prior': False, 'episodes': 2000, 'batchsize': 4, 'hidsize': [16, 16], 'lr': 0.001}
# -----------------------------------
# | [PAM] margin = 0     | 0.613    |
# | [PAM] margin = 0.125 | 0.699    |
# | [PAM] margin = 0.25  | 0.7      |
# | [PAM] margin = 0.5   | 0.707    |
# | [PAM] margin = 1     | 0.704    |
# -----------------------------------
# ----------------------------------
# | [PAM] accuracy max  | 0.865    |
# | [PAM] accuracy mean | 0.847    |
# | [PAM] accuracy min  | 0.824    |
# | [PAM] accuracy std  | 0.0121   |
# | [PAM] best margin   | 0.5      |
# ----------------------------------

# %%
from runner import run
run({
    'dataset': 'waveform', 
    'e0': 0.1, 'e1': 0.3,
    'episodes': 3000,
#     'batchsize': 16,
#     'hidsize': [16, 16],
#     'lr': 0.005,
    'test_size': 0.15,
    'val_size': 0.1,
    'dropout': 0, 
    'normalize': True,
    'equalize_prior': False,
    'alpha': 1.,
    'loss': 'bce',
    'activation': 'relu',
    'verbose': True,
})
# Out:
# Logging to logs/nn/19-08-21-16-10-06
# {'dataset': 'waveform', 'e0': 0.1, 'e1': 0.3, 'episodes': 3000, 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'equalize_prior': False, 'alpha': 1.0, 'loss': 'bce', 'activation': 'relu', 'verbose': True}
# batchsize: 4	lr:0.0007	hidsize:  8	acc:0.77
# batchsize: 4	lr:0.0007	hidsize: 16	acc:0.815
# batchsize: 4	lr:0.0007	hidsize: 32	acc:0.808
# batchsize: 4	lr:0.0007	hidsize: 64	acc:0.813
# batchsize: 4	lr: 0.001	hidsize:  8	acc:0.767
# batchsize: 4	lr: 0.001	hidsize: 16	acc:0.816
# batchsize: 4	lr: 0.001	hidsize: 32	acc:0.809
# batchsize: 4	lr: 0.001	hidsize: 64	acc:0.813
# batchsize: 4	lr: 0.005	hidsize:  8	acc:0.81
# batchsize: 4	lr: 0.005	hidsize: 16	acc:0.812
# batchsize: 4	lr: 0.005	hidsize: 32	acc:0.808
# batchsize: 4	lr: 0.005	hidsize: 64	acc:0.813
# batchsize: 4	lr:  0.01	hidsize:  8	acc:0.812
# batchsize: 4	lr:  0.01	hidsize: 16	acc:0.811
# batchsize: 4	lr:  0.01	hidsize: 32	acc:0.807
# batchsize: 4	lr:  0.01	hidsize: 64	acc:0.813
# batchsize: 4	lr:  0.05	hidsize:  8	acc:0.799
# batchsize: 4	lr:  0.05	hidsize: 16	acc:0.806
# batchsize: 4	lr:  0.05	hidsize: 32	acc:0.808
# batchsize: 4	lr:  0.05	hidsize: 64	acc:0.812
# batchsize:16	lr:0.0007	hidsize:  8	acc:0.761
# batchsize:16	lr:0.0007	hidsize: 16	acc:0.811
# batchsize:16	lr:0.0007	hidsize: 32	acc:0.805
# batchsize:16	lr:0.0007	hidsize: 64	acc:0.809
# batchsize:16	lr: 0.001	hidsize:  8	acc:0.758
# batchsize:16	lr: 0.001	hidsize: 16	acc:0.811
# batchsize:16	lr: 0.001	hidsize: 32	acc:0.805
# batchsize:16	lr: 0.001	hidsize: 64	acc:0.808
# batchsize:16	lr: 0.005	hidsize:  8	acc:0.805
# batchsize:16	lr: 0.005	hidsize: 16	acc:0.81
# batchsize:16	lr: 0.005	hidsize: 32	acc:0.805
# batchsize:16	lr: 0.005	hidsize: 64	acc:0.807
# batchsize:16	lr:  0.01	hidsize:  8	acc:0.754
# batchsize:16	lr:  0.01	hidsize: 16	acc:0.808
# batchsize:16	lr:  0.01	hidsize: 32	acc:0.805
# batchsize:16	lr:  0.01	hidsize: 64	acc:0.808
# batchsize:16	lr:  0.05	hidsize:  8	acc:0.738
# batchsize:16	lr:  0.05	hidsize: 16	acc:0.808
# batchsize:16	lr:  0.05	hidsize: 32	acc:0.783
# batchsize:16	lr:  0.05	hidsize: 64	acc:0.806
# batchsize:32	lr:0.0007	hidsize:  8	acc:0.758
# batchsize:32	lr:0.0007	hidsize: 16	acc:0.809
# batchsize:32	lr:0.0007	hidsize: 32	acc:0.801
# batchsize:32	lr:0.0007	hidsize: 64	acc:0.805
# batchsize:32	lr: 0.001	hidsize:  8	acc:0.806
# batchsize:32	lr: 0.001	hidsize: 16	acc:0.807
# batchsize:32	lr: 0.001	hidsize: 32	acc:0.801
# batchsize:32	lr: 0.001	hidsize: 64	acc:0.805
# batchsize:32	lr: 0.005	hidsize:  8	acc:0.807
# batchsize:32	lr: 0.005	hidsize: 16	acc:0.805
# batchsize:32	lr: 0.005	hidsize: 32	acc:0.801
# batchsize:32	lr: 0.005	hidsize: 64	acc:0.805
# batchsize:32	lr:  0.01	hidsize:  8	acc:0.756
# batchsize:32	lr:  0.01	hidsize: 16	acc:0.805
# batchsize:32	lr:  0.01	hidsize: 32	acc:0.798
# batchsize:32	lr:  0.01	hidsize: 64	acc:0.803
# batchsize:32	lr:  0.05	hidsize:  8	acc:0.805
# batchsize:32	lr:  0.05	hidsize: 16	acc:0.801
# batchsize:32	lr:  0.05	hidsize: 32	acc:0.794
# batchsize:32	lr:  0.05	hidsize: 64	acc:0.8
# batchsize:64	lr:0.0007	hidsize:  8	acc:0.807
# batchsize:64	lr:0.0007	hidsize: 16	acc:0.807
# batchsize:64	lr:0.0007	hidsize: 32	acc:0.799
# batchsize:64	lr:0.0007	hidsize: 64	acc:0.804
# batchsize:64	lr: 0.001	hidsize:  8	acc:0.806
# batchsize:64	lr: 0.001	hidsize: 16	acc:0.806
# batchsize:64	lr: 0.001	hidsize: 32	acc:0.799
# batchsize:64	lr: 0.001	hidsize: 64	acc:0.804
# batchsize:64	lr: 0.005	hidsize:  8	acc:0.805
# batchsize:64	lr: 0.005	hidsize: 16	acc:0.804
# batchsize:64	lr: 0.005	hidsize: 32	acc:0.796
# batchsize:64	lr: 0.005	hidsize: 64	acc:0.803
# batchsize:64	lr:  0.01	hidsize:  8	acc:0.754
# batchsize:64	lr:  0.01	hidsize: 16	acc:0.805
# batchsize:64	lr:  0.01	hidsize: 32	acc:0.796
# batchsize:64	lr:  0.01	hidsize: 64	acc:0.8
# batchsize:64	lr:  0.05	hidsize:  8	acc:0.752
# batchsize:64	lr:  0.05	hidsize: 16	acc:0.802
# batchsize:64	lr:  0.05	hidsize: 32	acc:0.796
# batchsize:64	lr:  0.05	hidsize: 64	acc:0.799
# --------------------------------------
# | [NN] best batchsize     | 4        |
# | [NN] best hidsize       | [16, 16] |
# | [NN] best learning rate | 0.001    |
# --------------------------------------
# --------------------------------------
# | [NN] with bce loss      | 0.888    |
# | [NN] with peer loss     | 0.816    |
# | [NN] with surrogate ... | 0.904    |
# --------------------------------------
# Logging to logs/svm/19-08-21-17-11-56
# {'dataset': 'waveform', 'e0': 0.1, 'e1': 0.3, 'episodes': 3000, 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'equalize_prior': False, 'alpha': 1.0, 'loss': 'bce', 'activation': 'relu', 'verbose': True}
# --------------------------------
# | [C-SVM] C1 = 0.1  | 0.703    |
# | [C-SVM] C1 = 0.2  | 0.703    |
# | [C-SVM] C1 = 0.25 | 0.703    |
# | [C-SVM] C1 = 0.33 | 0.703    |
# | [C-SVM] C1 = 0.5  | 0.721    |
# | [C-SVM] C1 = 1.0  | 0.788    |
# | [C-SVM] C1 = 10.0 | 0.584    |
# | [C-SVM] C1 = 2.0  | 0.774    |
# | [C-SVM] C1 = 3.0  | 0.749    |
# | [C-SVM] C1 = 4.0  | 0.723    |
# | [C-SVM] C1 = 5.0  | 0.688    |
# --------------------------------
# ------------------------------------
# | [C-SVM] accuracy max  | 0.892    |
# | [C-SVM] accuracy mean | 0.878    |
# | [C-SVM] accuracy min  | 0.856    |
# | [C-SVM] accuracy std  | 0.011    |
# | [C-SVM] best C1       | 1        |
# ------------------------------------
# Logging to logs/pam/19-08-21-17-12-07
# {'dataset': 'waveform', 'e0': 0.1, 'e1': 0.3, 'episodes': 3000, 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'equalize_prior': False, 'alpha': 1.0, 'loss': 'bce', 'activation': 'relu', 'verbose': True}
# ---------------------------------
# | [PAM] margin = 0.0 | 0.668    |
# | [PAM] margin = 0.1 | 0.727    |
# | [PAM] margin = 0.2 | 0.721    |
# | [PAM] margin = 0.3 | 0.736    |
# | [PAM] margin = 0.4 | 0.719    |
# | [PAM] margin = 0.5 | 0.711    |
# ---------------------------------
# ----------------------------------
# | [PAM] accuracy max  | 0.809    |
# | [PAM] accuracy mean | 0.707    |
# | [PAM] accuracy min  | 0.659    |
# | [PAM] accuracy std  | 0.0542   |
# | [PAM] best margin   | 0.3      |
# ----------------------------------

# %%
from runner import run
run({
    'dataset': 'waveform', 
    'e0': 0.2, 'e1': 0.2,
    'episodes': 1000,
    'batchsize': 4,
    'hidsize': [16, 16],
    'lr': 0.0005,
    'test_size': 0.15,
    'val_size': 0.1,
    'dropout': 0, 
    'normalize': True,
    'equalize_prior': False,
    'alpha': 1.,
    'loss': 'bce',
    'activation': 'relu',
    'verbose': True,
})
# Out:
# Logging to logs/nn/19-08-20-23-01-27
# {'dataset': 'waveform', 'e0': 0.2, 'e1': 0.2, 'episodes': 1000, 'batchsize': 4, 'hidsize': [16, 16], 'lr': 0.0005, 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'equalize_prior': False, 'alpha': 1.0, 'loss': 'bce', 'activation': 'relu', 'verbose': True}
# --------------------------------------
# | [NN] with bce loss      | 0.887    |
# | [NN] with peer loss     | 0.813    |
# | [NN] with surrogate ... | 0.889    |
# --------------------------------------
# Logging to logs/svm/19-08-20-23-01-59
# {'dataset': 'waveform', 'e0': 0.2, 'e1': 0.2, 'episodes': 1000, 'batchsize': 4, 'hidsize': [16, 16], 'lr': 0.0005, 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'equalize_prior': False, 'alpha': 1.0, 'loss': 'bce', 'activation': 'relu', 'verbose': True}
# --------------------------------
# | [C-SVM] C1 = 0.1  | 0.663    |
# | [C-SVM] C1 = 0.2  | 0.663    |
# | [C-SVM] C1 = 0.25 | 0.663    |
# | [C-SVM] C1 = 0.33 | 0.718    |
# | [C-SVM] C1 = 0.5  | 0.847    |
# | [C-SVM] C1 = 1.0  | 0.897    |
# | [C-SVM] C1 = 10.0 | 0.435    |
# | [C-SVM] C1 = 2.0  | 0.858    |
# | [C-SVM] C1 = 3.0  | 0.742    |
# | [C-SVM] C1 = 4.0  | 0.621    |
# | [C-SVM] C1 = 5.0  | 0.537    |
# --------------------------------
# ------------------------------------
# | [C-SVM] accuracy max  | 0.911    |
# | [C-SVM] accuracy mean | 0.904    |
# | [C-SVM] accuracy min  | 0.896    |
# | [C-SVM] accuracy std  | 0.00476  |
# | [C-SVM] best C1       | 1        |
# ------------------------------------
# Logging to logs/pam/19-08-20-23-02-12
# {'dataset': 'waveform', 'e0': 0.2, 'e1': 0.2, 'episodes': 1000, 'batchsize': 4, 'hidsize': [16, 16], 'lr': 0.0005, 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'equalize_prior': False, 'alpha': 1.0, 'loss': 'bce', 'activation': 'relu', 'verbose': True}
# ---------------------------------
# | [PAM] margin = 0.0 | 0.657    |
# | [PAM] margin = 0.1 | 0.835    |
# | [PAM] margin = 0.2 | 0.837    |
# | [PAM] margin = 0.3 | 0.848    |
# | [PAM] margin = 0.4 | 0.846    |
# | [PAM] margin = 0.5 | 0.841    |
# ---------------------------------
# ----------------------------------
# | [PAM] accuracy max  | 0.865    |
# | [PAM] accuracy mean | 0.842    |
# | [PAM] accuracy min  | 0.812    |
# | [PAM] accuracy std  | 0.0168   |
# | [PAM] best margin   | 0.3      |
# ----------------------------------

# %% [markdown]
# ### $e_0 = 0.1, e_1 = 0.4$

# %%
from run_nn import find_best_alpha

args = default_args.copy()
args.update({
    'dataset': 'waveform', 
    'e0': 0.1, 'e1': 0.4, 
    'equalize_prior': False, 
    'episodes': 2000, 
    'batchsize': 4, 
    'hidsize': [16, 16], 
    'lr': 0.001, 
#     'alpha': 0.6,
})
find_best_alpha(args)
# Out:
# ---------------------------------
# | [PEER] alpha = -5  | 0.663    |
# | [PEER] alpha = 0.4 | 0.888    |
# | [PEER] alpha = 0.5 | 0.892    |
# | [PEER] alpha = 0.6 | 0.892    |
# | [PEER] alpha = 0.7 | 0.888    |
# | [PEER] alpha = 0.8 | 0.873    |
# | [PEER] alpha = 0.9 | 0.839    |
# | [PEER] alpha = 1.0 | 0.817    |
# | [PEER] alpha = 2.0 | 0.398    |
# | [PEER] alpha = 3.0 | 0.337    |
# | [PEER] alpha = 4.0 | 0.337    |
# | [PEER] alpha = 5.0 | 0.337    |
# ---------------------------------
# {'alpha': 0.5}

# %%
from runner import run

args = default_args.copy()
args.update({
    'dataset': 'waveform', 
    'e0': 0.1, 'e1': 0.4, 
    'equalize_prior': False, 
    'episodes': 2000, 
    'batchsize': 4, 
    'hidsize': [16, 16], 
    'lr': 0.001, 
#     'alpha': 0.6,
})
run(args)
# Out:
# Logging to logs/nn/19-08-30-16-41-01
# {'dataset': 'waveform', 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'e0': 0.1, 'e1': 0.4, 'equalize_prior': False, 'episodes': 2000, 'batchsize': 4, 'hidsize': [16, 16], 'lr': 0.001}
# ---------------------------------
# | [PEER] alpha = -5  | 0.737    |
# | [PEER] alpha = 0.4 | 0.763    |
# | [PEER] alpha = 0.5 | 0.763    |
# | [PEER] alpha = 0.6 | 0.752    |
# | [PEER] alpha = 0.7 | 0.748    |
# | [PEER] alpha = 0.8 | 0.726    |
# | [PEER] alpha = 0.9 | 0.691    |
# | [PEER] alpha = 1.0 | 0.666    |
# | [PEER] alpha = 2.0 | 0.314    |
# | [PEER] alpha = 3.0 | 0.263    |
# | [PEER] alpha = 4.0 | 0.263    |
# | [PEER] alpha = 5.0 | 0.263    |
# ---------------------------------
# --------------------------------------
# | [NN] with bce loss      | 0.835    |
# | [NN] with peer loss     | 0.888    |
# | [NN] with surrogate ... | 0.894    |
# | [PEER] best alpha       | 0.4      |
# --------------------------------------
# Logging to logs/svm/19-08-30-16-43-28
# {'dataset': 'waveform', 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'e0': 0.1, 'e1': 0.4, 'equalize_prior': False, 'episodes': 2000, 'batchsize': 4, 'hidsize': [16, 16], 'lr': 0.001}
# --------------------------------
# | [C-SVM] C1 = 0.1  | 0.737    |
# | [C-SVM] C1 = 0.2  | 0.737    |
# | [C-SVM] C1 = 0.25 | 0.737    |
# | [C-SVM] C1 = 0.33 | 0.737    |
# | [C-SVM] C1 = 0.5  | 0.737    |
# | [C-SVM] C1 = 1.0  | 0.77     |
# | [C-SVM] C1 = 10.0 | 0.55     |
# | [C-SVM] C1 = 2.0  | 0.759    |
# | [C-SVM] C1 = 3.0  | 0.732    |
# | [C-SVM] C1 = 4.0  | 0.705    |
# | [C-SVM] C1 = 5.0  | 0.665    |
# --------------------------------
# ------------------------------------
# | [C-SVM] accuracy max  | 0.833    |
# | [C-SVM] accuracy mean | 0.821    |
# | [C-SVM] accuracy min  | 0.809    |
# | [C-SVM] accuracy std  | 0.00881  |
# | [C-SVM] best C1       | 1        |
# ------------------------------------
# Logging to logs/pam/19-08-30-16-43-40
# {'dataset': 'waveform', 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'e0': 0.1, 'e1': 0.4, 'equalize_prior': False, 'episodes': 2000, 'batchsize': 4, 'hidsize': [16, 16], 'lr': 0.001}
# -----------------------------------
# | [PAM] margin = 0     | 0.657    |
# | [PAM] margin = 0.125 | 0.734    |
# | [PAM] margin = 0.25  | 0.737    |
# | [PAM] margin = 0.5   | 0.737    |
# | [PAM] margin = 1     | 0.737    |
# -----------------------------------
# ----------------------------------
# | [PAM] accuracy max  | 0.695    |
# | [PAM] accuracy mean | 0.663    |
# | [PAM] accuracy min  | 0.636    |
# | [PAM] accuracy std  | 0.0168   |
# | [PAM] best margin   | 0.25     |
# ----------------------------------

# %% [markdown]
# ### $e_0 = 0.2, e_1 = 0.4$

# %%
from runner import run

args = default_args.copy()
args.update({
    'dataset': 'waveform', 
    'e0': 0.2, 'e1': 0.4, 
    'equalize_prior': False, 
    'episodes': 2000, 
    'batchsize': 4, 
    'hidsize': [16, 16], 
    'lr': 0.001, 
#     'alpha': 0.6,
})
run(args)
# Out:
# Logging to logs/nn/19-08-25-23-19-39
# {'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'dataset': 'waveform', 'e0': 0.2, 'e1': 0.4, 'equalize_prior': False, 'episodes': 2000, 'batchsize': 4, 'hidsize': [16, 16], 'lr': 0.001}
# --------------------------------------
# | [PEER] alpha = 0.1      | 0.854    |
# | [PEER] alpha = 0.2      | 0.866    |
# | [PEER] alpha = 0.3      | 0.876    |
# | [PEER] alpha = 0.4      | 0.884    |
# | [PEER] alpha = 0.5      | 0.891    |
# | [PEER] alpha = 0.6      | 0.895    |
# | [PEER] alpha = 0.7      | 0.893    |
# | [PEER] alpha = 0.799... | 0.873    |
# | [PEER] alpha = 0.899... | 0.837    |
# | [PEER] alpha = 0.999... | 0.812    |
# | [PEER] alpha = 1.099... | 0.8      |
# | [PEER] alpha = 1.2      | 0.775    |
# | [PEER] alpha = 1.3      | 0.621    |
# | [PEER] alpha = 1.4      | 0.509    |
# | [PEER] alpha = 1.5      | 0.399    |
# | [PEER] alpha = 1.599... | 0.4      |
# | [PEER] alpha = 1.7      | 0.399    |
# | [PEER] alpha = 1.8      | 0.399    |
# | [PEER] alpha = 1.9      | 0.399    |
# | [PEER] alpha = 2.0      | 0.399    |
# --------------------------------------
# --------------------------------------
# | [NN] with bce loss      | 0.837    |
# | [NN] with peer loss     | 0.895    |
# | [NN] with surrogate ... | 0.884    |
# --------------------------------------
# Logging to logs/svm/19-08-25-23-28-56
# {'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'dataset': 'waveform', 'e0': 0.2, 'e1': 0.4, 'equalize_prior': False, 'episodes': 2000, 'batchsize': 4, 'hidsize': [16, 16], 'lr': 0.001}
# --------------------------------
# | [C-SVM] C1 = 0.1  | 0.669    |
# | [C-SVM] C1 = 0.2  | 0.669    |
# | [C-SVM] C1 = 0.25 | 0.669    |
# | [C-SVM] C1 = 0.33 | 0.669    |
# | [C-SVM] C1 = 0.5  | 0.669    |
# | [C-SVM] C1 = 1.0  | 0.705    |
# | [C-SVM] C1 = 10.0 | 0.403    |
# | [C-SVM] C1 = 2.0  | 0.682    |
# | [C-SVM] C1 = 3.0  | 0.592    |
# | [C-SVM] C1 = 4.0  | 0.512    |
# | [C-SVM] C1 = 5.0  | 0.458    |
# --------------------------------
# ------------------------------------
# | [C-SVM] accuracy max  | 0.848    |
# | [C-SVM] accuracy mean | 0.837    |
# | [C-SVM] accuracy min  | 0.824    |
# | [C-SVM] accuracy std  | 0.00854  |
# | [C-SVM] best C1       | 1        |
# ------------------------------------
# Logging to logs/pam/19-08-25-23-29-09
# {'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'dataset': 'waveform', 'e0': 0.2, 'e1': 0.4, 'equalize_prior': False, 'episodes': 2000, 'batchsize': 4, 'hidsize': [16, 16], 'lr': 0.001}
# -----------------------------------
# | [PAM] margin = 0     | 0.617    |
# | [PAM] margin = 0.125 | 0.673    |
# | [PAM] margin = 0.25  | 0.669    |
# | [PAM] margin = 0.5   | 0.669    |
# | [PAM] margin = 1     | 0.669    |
# | [PAM] margin = 2     | 0.669    |
# | [PAM] margin = 4     | 0.669    |
# -----------------------------------
# ----------------------------------
# | [PAM] accuracy max  | 0.716    |
# | [PAM] accuracy mean | 0.678    |
# | [PAM] accuracy min  | 0.647    |
# | [PAM] accuracy std  | 0.0209   |
# | [PAM] best margin   | 0.125    |
# ----------------------------------

# %%
from runner import run

args = default_args.copy()
args.update({
    'dataset': 'waveform', 
    'e0': 0.2, 'e1': 0.4, 
    'equalize_prior': False, 
    'episodes': 2000, 
    'batchsize': 4, 
    'hidsize': [16, 16], 
    'lr': 0.001, 
#     'alpha': 0.6,
})
run(args)
# Out:
# Logging to logs/nn/19-08-27-15-39-30
# {'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'dataset': 'waveform', 'e0': 0.2, 'e1': 0.4, 'equalize_prior': False, 'episodes': 2000, 'batchsize': 4, 'hidsize': [16, 16], 'lr': 0.001}
# ---------------------------------
# | [PEER] alpha = 0.4 | 0.707    |
# | [PEER] alpha = 0.5 | 0.704    |
# | [PEER] alpha = 0.6 | 0.699    |
# | [PEER] alpha = 0.7 | 0.691    |
# | [PEER] alpha = 0.8 | 0.679    |
# | [PEER] alpha = 0.9 | 0.649    |
# | [PEER] alpha = 1.0 | 0.626    |
# | [PEER] alpha = 1.1 | 0.614    |
# | [PEER] alpha = 1.2 | 0.596    |
# ---------------------------------
# --------------------------------------
# | [NN] with bce loss      | 0.837    |
# | [NN] with peer loss     | 0.884    |
# | [NN] with surrogate ... | 0.884    |
# | [PEER] best alpha       | 0.4      |
# --------------------------------------
# Logging to logs/svm/19-08-27-15-44-02
# {'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'dataset': 'waveform', 'e0': 0.2, 'e1': 0.4, 'equalize_prior': False, 'episodes': 2000, 'batchsize': 4, 'hidsize': [16, 16], 'lr': 0.001}
# --------------------------------
# | [C-SVM] C1 = 0.1  | 0.669    |
# | [C-SVM] C1 = 0.2  | 0.669    |
# | [C-SVM] C1 = 0.25 | 0.669    |
# | [C-SVM] C1 = 0.33 | 0.669    |
# | [C-SVM] C1 = 0.5  | 0.669    |
# | [C-SVM] C1 = 1.0  | 0.705    |
# | [C-SVM] C1 = 10.0 | 0.403    |
# | [C-SVM] C1 = 2.0  | 0.682    |
# | [C-SVM] C1 = 3.0  | 0.592    |
# | [C-SVM] C1 = 4.0  | 0.512    |
# | [C-SVM] C1 = 5.0  | 0.458    |
# --------------------------------
# ------------------------------------
# | [C-SVM] accuracy max  | 0.848    |
# | [C-SVM] accuracy mean | 0.837    |
# | [C-SVM] accuracy min  | 0.824    |
# | [C-SVM] accuracy std  | 0.00854  |
# | [C-SVM] best C1       | 1        |
# ------------------------------------
# Logging to logs/pam/19-08-27-15-44-17
# {'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'dataset': 'waveform', 'e0': 0.2, 'e1': 0.4, 'equalize_prior': False, 'episodes': 2000, 'batchsize': 4, 'hidsize': [16, 16], 'lr': 0.001}
# -----------------------------------
# | [PAM] margin = 0     | 0.59     |
# | [PAM] margin = 0.125 | 0.668    |
# | [PAM] margin = 0.25  | 0.669    |
# | [PAM] margin = 0.5   | 0.669    |
# | [PAM] margin = 1     | 0.669    |
# -----------------------------------
# ----------------------------------
# | [PAM] accuracy max  | 0.695    |
# | [PAM] accuracy mean | 0.663    |
# | [PAM] accuracy min  | 0.636    |
# | [PAM] accuracy std  | 0.0168   |
# | [PAM] best margin   | 0.25     |
# ----------------------------------

# %%
from runner import run
run({
    'dataset': 'waveform', 
    'e0': 0.2, 'e1': 0.4,
    'episodes': 1000,
#     'batchsize': 16,
#     'hidsize': [16, 16],
#     'lr': 0.005,
    'test_size': 0.15,
    'val_size': 0.1,
    'dropout': 0, 
    'normalize': True,
    'equalize_prior': False,
    'alpha': 1.,
    'loss': 'bce',
    'activation': 'relu',
    'verbose': True,
})
# Out:
# Logging to logs/nn/19-08-20-23-02-17
# {'dataset': 'waveform', 'e0': 0.2, 'e1': 0.4, 'episodes': 1000, 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'equalize_prior': False, 'alpha': 1.0, 'loss': 'bce', 'activation': 'relu', 'verbose': True}
# batchsize: 1	lr:0.0005	hidsize:  8	acc:0.604
# batchsize: 1	lr:0.0005	hidsize: 16	acc:0.685
# batchsize: 1	lr:0.0005	hidsize: 32	acc:0.732
# batchsize: 1	lr:0.0005	hidsize: 64	acc:0.785
# batchsize: 1	lr: 0.001	hidsize:  8	acc:0.685
# batchsize: 1	lr: 0.001	hidsize: 16	acc:0.764
# batchsize: 1	lr: 0.001	hidsize: 32	acc:0.792
# batchsize: 1	lr: 0.001	hidsize: 64	acc:0.776
# batchsize: 1	lr: 0.005	hidsize:  8	acc:0.731
# batchsize: 1	lr: 0.005	hidsize: 16	acc:0.736
# batchsize: 1	lr: 0.005	hidsize: 32	acc:0.717
# batchsize: 1	lr: 0.005	hidsize: 64	acc:0.706
# batchsize: 1	lr:  0.01	hidsize:  8	acc:0.678
# batchsize: 1	lr:  0.01	hidsize: 16	acc:0.716
# batchsize: 1	lr:  0.01	hidsize: 32	acc:0.703
# batchsize: 1	lr:  0.01	hidsize: 64	acc:0.746
# batchsize: 1	lr:  0.05	hidsize:  8	acc:0.637
# batchsize: 1	lr:  0.05	hidsize: 16	acc:0.71
# batchsize: 1	lr:  0.05	hidsize: 32	acc:0.696
# batchsize: 1	lr:  0.05	hidsize: 64	acc:0.717
# batchsize: 4	lr:0.0005	hidsize:  8	acc:0.641
# batchsize: 4	lr:0.0005	hidsize: 16	acc:0.789
# batchsize: 4	lr:0.0005	hidsize: 32	acc:0.793
# batchsize: 4	lr:0.0005	hidsize: 64	acc:0.804
# batchsize: 4	lr: 0.001	hidsize:  8	acc:0.729
# batchsize: 4	lr: 0.001	hidsize: 16	acc:0.815
# batchsize: 4	lr: 0.001	hidsize: 32	acc:0.797
# batchsize: 4	lr: 0.001	hidsize: 64	acc:0.806
# batchsize: 4	lr: 0.005	hidsize:  8	acc:0.804
# batchsize: 4	lr: 0.005	hidsize: 16	acc:0.811
# batchsize: 4	lr: 0.005	hidsize: 32	acc:0.795
# batchsize: 4	lr: 0.005	hidsize: 64	acc:0.801
# batchsize: 4	lr:  0.01	hidsize:  8	acc:0.804
# batchsize: 4	lr:  0.01	hidsize: 16	acc:0.806
# batchsize: 4	lr:  0.01	hidsize: 32	acc:0.793
# batchsize: 4	lr:  0.01	hidsize: 64	acc:0.805
# batchsize: 4	lr:  0.05	hidsize:  8	acc:0.721
# batchsize: 4	lr:  0.05	hidsize: 16	acc:0.674
# batchsize: 4	lr:  0.05	hidsize: 32	acc:0.741
# batchsize: 4	lr:  0.05	hidsize: 64	acc:0.798
# batchsize:16	lr:0.0005	hidsize:  8	acc:0.743
# batchsize:16	lr:0.0005	hidsize: 16	acc:0.803
# batchsize:16	lr:0.0005	hidsize: 32	acc:0.791
# batchsize:16	lr:0.0005	hidsize: 64	acc:0.796
# batchsize:16	lr: 0.001	hidsize:  8	acc:0.803
# batchsize:16	lr: 0.001	hidsize: 16	acc:0.806
# batchsize:16	lr: 0.001	hidsize: 32	acc:0.793
# batchsize:16	lr: 0.001	hidsize: 64	acc:0.797
# batchsize:16	lr: 0.005	hidsize:  8	acc:0.802
# batchsize:16	lr: 0.005	hidsize: 16	acc:0.786
# batchsize:16	lr: 0.005	hidsize: 32	acc:0.793
# batchsize:16	lr: 0.005	hidsize: 64	acc:0.801
# batchsize:16	lr:  0.01	hidsize:  8	acc:0.735
# batchsize:16	lr:  0.01	hidsize: 16	acc:0.801
# batchsize:16	lr:  0.01	hidsize: 32	acc:0.793
# batchsize:16	lr:  0.01	hidsize: 64	acc:0.802
# batchsize:16	lr:  0.05	hidsize:  8	acc:0.734
# batchsize:16	lr:  0.05	hidsize: 16	acc:0.813
# batchsize:16	lr:  0.05	hidsize: 32	acc:0.796
# batchsize:16	lr:  0.05	hidsize: 64	acc:0.793
# batchsize:64	lr:0.0005	hidsize:  8	acc:0.765
# batchsize:64	lr:0.0005	hidsize: 16	acc:0.809
# batchsize:64	lr:0.0005	hidsize: 32	acc:0.799
# batchsize:64	lr:0.0005	hidsize: 64	acc:0.801
# batchsize:64	lr: 0.001	hidsize:  8	acc:0.762
# batchsize:64	lr: 0.001	hidsize: 16	acc:0.807
# batchsize:64	lr: 0.001	hidsize: 32	acc:0.797
# batchsize:64	lr: 0.001	hidsize: 64	acc:0.803
# batchsize:64	lr: 0.005	hidsize:  8	acc:0.76
# batchsize:64	lr: 0.005	hidsize: 16	acc:0.803
# batchsize:64	lr: 0.005	hidsize: 32	acc:0.797
# batchsize:64	lr: 0.005	hidsize: 64	acc:0.804
# batchsize:64	lr:  0.01	hidsize:  8	acc:0.757
# batchsize:64	lr:  0.01	hidsize: 16	acc:0.791
# batchsize:64	lr:  0.01	hidsize: 32	acc:0.795
# batchsize:64	lr:  0.01	hidsize: 64	acc:0.803
# batchsize:64	lr:  0.05	hidsize:  8	acc:0.746
# batchsize:64	lr:  0.05	hidsize: 16	acc:0.8
# batchsize:64	lr:  0.05	hidsize: 32	acc:0.797
# batchsize:64	lr:  0.05	hidsize: 64	acc:0.8
# --------------------------------------
# | [NN] best batchsize     | 4        |
# | [NN] best hidsize       | [16, 16] |
# | [NN] best learning rate | 0.001    |
# --------------------------------------
# --------------------------------------
# | [NN] with bce loss      | 0.8      |
# | [NN] with peer loss     | 0.815    |
# | [NN] with surrogate ... | 0.891    |
# --------------------------------------
# Logging to logs/svm/19-08-20-23-18-31
# {'dataset': 'waveform', 'e0': 0.2, 'e1': 0.4, 'episodes': 1000, 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'equalize_prior': False, 'alpha': 1.0, 'loss': 'bce', 'activation': 'relu', 'verbose': True}
# --------------------------------
# | [C-SVM] C1 = 0.1  | 0.663    |
# | [C-SVM] C1 = 0.2  | 0.663    |
# | [C-SVM] C1 = 0.25 | 0.663    |
# | [C-SVM] C1 = 0.33 | 0.663    |
# | [C-SVM] C1 = 0.5  | 0.663    |
# | [C-SVM] C1 = 1.0  | 0.837    |
# | [C-SVM] C1 = 10.0 | 0.441    |
# | [C-SVM] C1 = 2.0  | 0.875    |
# | [C-SVM] C1 = 3.0  | 0.758    |
# | [C-SVM] C1 = 4.0  | 0.629    |
# | [C-SVM] C1 = 5.0  | 0.545    |
# --------------------------------
# ------------------------------------
# | [C-SVM] accuracy max  | 0.899    |
# | [C-SVM] accuracy mean | 0.875    |
# | [C-SVM] accuracy min  | 0.853    |
# | [C-SVM] accuracy std  | 0.0126   |
# | [C-SVM] best C1       | 2        |
# ------------------------------------
# Logging to logs/pam/19-08-20-23-18-45
# {'dataset': 'waveform', 'e0': 0.2, 'e1': 0.4, 'episodes': 1000, 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'equalize_prior': False, 'alpha': 1.0, 'loss': 'bce', 'activation': 'relu', 'verbose': True}
# ---------------------------------
# | [PAM] margin = 0.0 | 0.639    |
# | [PAM] margin = 0.1 | 0.686    |
# | [PAM] margin = 0.2 | 0.663    |
# | [PAM] margin = 0.3 | 0.663    |
# | [PAM] margin = 0.4 | 0.663    |
# | [PAM] margin = 0.5 | 0.663    |
# ---------------------------------
# ----------------------------------
# | [PAM] accuracy max  | 0.788    |
# | [PAM] accuracy mean | 0.688    |
# | [PAM] accuracy min  | 0.636    |
# | [PAM] accuracy std  | 0.0434   |
# | [PAM] best margin   | 0.1      |
# ----------------------------------

# %% [markdown]
# ### $e_0=0.4, e_1=0.4$

# %%
from runner import run

args = default_args.copy()
args.update({
    'dataset': 'waveform', 
    'e0': 0.4, 'e1': 0.4, 
    'equalize_prior': False, 
    'episodes': 2000, 
    'batchsize': 4, 
    'hidsize': [16, 16], 
    'lr': 0.001, 
#     'alpha': 0.6,
})
run(args)
# Out:
# Logging to logs/nn/19-08-25-23-33-48
# {'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'dataset': 'waveform', 'e0': 0.4, 'e1': 0.4, 'equalize_prior': False, 'episodes': 2000, 'batchsize': 4, 'hidsize': [16, 16], 'lr': 0.001}
# --------------------------------------
# | [PEER] alpha = 0.1      | 0.855    |
# | [PEER] alpha = 0.2      | 0.855    |
# | [PEER] alpha = 0.3      | 0.857    |
# | [PEER] alpha = 0.4      | 0.853    |
# | [PEER] alpha = 0.5      | 0.851    |
# | [PEER] alpha = 0.6      | 0.846    |
# | [PEER] alpha = 0.7      | 0.843    |
# | [PEER] alpha = 0.799... | 0.831    |
# | [PEER] alpha = 0.899... | 0.813    |
# | [PEER] alpha = 0.999... | 0.8      |
# | [PEER] alpha = 1.099... | 0.789    |
# | [PEER] alpha = 1.2      | 0.669    |
# | [PEER] alpha = 1.3      | 0.611    |
# | [PEER] alpha = 1.4      | 0.559    |
# | [PEER] alpha = 1.5      | 0.557    |
# | [PEER] alpha = 1.599... | 0.501    |
# | [PEER] alpha = 1.7      | 0.501    |
# | [PEER] alpha = 1.8      | 0.5      |
# | [PEER] alpha = 1.9      | 0.501    |
# | [PEER] alpha = 2.0      | 0.501    |
# --------------------------------------
# --------------------------------------
# | [NN] with bce loss      | 0.828    |
# | [NN] with peer loss     | 0.857    |
# | [NN] with surrogate ... | 0.852    |
# --------------------------------------
# Logging to logs/svm/19-08-25-23-43-43
# {'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'dataset': 'waveform', 'e0': 0.4, 'e1': 0.4, 'equalize_prior': False, 'episodes': 2000, 'batchsize': 4, 'hidsize': [16, 16], 'lr': 0.001}
# --------------------------------
# | [C-SVM] C1 = 0.1  | 0.534    |
# | [C-SVM] C1 = 0.2  | 0.534    |
# | [C-SVM] C1 = 0.25 | 0.534    |
# | [C-SVM] C1 = 0.33 | 0.534    |
# | [C-SVM] C1 = 0.5  | 0.534    |
# | [C-SVM] C1 = 1.0  | 0.576    |
# | [C-SVM] C1 = 10.0 | 0.466    |
# | [C-SVM] C1 = 2.0  | 0.475    |
# | [C-SVM] C1 = 3.0  | 0.466    |
# | [C-SVM] C1 = 4.0  | 0.467    |
# | [C-SVM] C1 = 5.0  | 0.467    |
# --------------------------------
# ------------------------------------
# | [C-SVM] accuracy max  | 0.869    |
# | [C-SVM] accuracy mean | 0.848    |
# | [C-SVM] accuracy min  | 0.833    |
# | [C-SVM] accuracy std  | 0.0108   |
# | [C-SVM] best C1       | 1        |
# ------------------------------------
# Logging to logs/pam/19-08-25-23-43-59
# {'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'dataset': 'waveform', 'e0': 0.4, 'e1': 0.4, 'equalize_prior': False, 'episodes': 2000, 'batchsize': 4, 'hidsize': [16, 16], 'lr': 0.001}
# -----------------------------------
# | [PAM] margin = 0     | 0.516    |
# | [PAM] margin = 0.125 | 0.553    |
# | [PAM] margin = 0.25  | 0.559    |
# | [PAM] margin = 0.5   | 0.563    |
# | [PAM] margin = 1     | 0.571    |
# | [PAM] margin = 2     | 0.566    |
# | [PAM] margin = 4     | 0.56     |
# -----------------------------------
# ----------------------------------
# | [PAM] accuracy max  | 0.812    |
# | [PAM] accuracy mean | 0.782    |
# | [PAM] accuracy min  | 0.741    |
# | [PAM] accuracy std  | 0.0259   |
# | [PAM] best margin   | 1        |
# ----------------------------------

# %%
from runner import run

args = default_args.copy()
args.update({
    'dataset': 'waveform', 
    'e0': 0.4, 'e1': 0.4, 
    'equalize_prior': False, 
    'episodes': 2000, 
    'batchsize': 4, 
    'hidsize': [16, 16], 
    'lr': 0.001, 
#     'alpha': 0.6,
})
run(args)
# Out:
# Logging to logs/nn/19-08-27-15-45-04
# {'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'dataset': 'waveform', 'e0': 0.4, 'e1': 0.4, 'equalize_prior': False, 'episodes': 2000, 'batchsize': 4, 'hidsize': [16, 16], 'lr': 0.001}
# ---------------------------------
# | [PEER] alpha = 0.4 | 0.572    |
# | [PEER] alpha = 0.5 | 0.572    |
# | [PEER] alpha = 0.6 | 0.57     |
# | [PEER] alpha = 0.7 | 0.572    |
# | [PEER] alpha = 0.8 | 0.568    |
# | [PEER] alpha = 0.9 | 0.565    |
# | [PEER] alpha = 1.0 | 0.566    |
# | [PEER] alpha = 1.1 | 0.565    |
# | [PEER] alpha = 1.2 | 0.535    |
# ---------------------------------
# --------------------------------------
# | [NN] with bce loss      | 0.828    |
# | [NN] with peer loss     | 0.853    |
# | [NN] with surrogate ... | 0.852    |
# | [PEER] best alpha       | 0.4      |
# --------------------------------------
# Logging to logs/svm/19-08-27-15-49-28
# {'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'dataset': 'waveform', 'e0': 0.4, 'e1': 0.4, 'equalize_prior': False, 'episodes': 2000, 'batchsize': 4, 'hidsize': [16, 16], 'lr': 0.001}
# --------------------------------
# | [C-SVM] C1 = 0.1  | 0.534    |
# | [C-SVM] C1 = 0.2  | 0.534    |
# | [C-SVM] C1 = 0.25 | 0.534    |
# | [C-SVM] C1 = 0.33 | 0.534    |
# | [C-SVM] C1 = 0.5  | 0.534    |
# | [C-SVM] C1 = 1.0  | 0.576    |
# | [C-SVM] C1 = 10.0 | 0.466    |
# | [C-SVM] C1 = 2.0  | 0.475    |
# | [C-SVM] C1 = 3.0  | 0.466    |
# | [C-SVM] C1 = 4.0  | 0.467    |
# | [C-SVM] C1 = 5.0  | 0.467    |
# --------------------------------
# ------------------------------------
# | [C-SVM] accuracy max  | 0.869    |
# | [C-SVM] accuracy mean | 0.848    |
# | [C-SVM] accuracy min  | 0.833    |
# | [C-SVM] accuracy std  | 0.0108   |
# | [C-SVM] best C1       | 1        |
# ------------------------------------
# Logging to logs/pam/19-08-27-15-49-42
# {'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'loss': 'bce', 'activation': 'relu', 'verbose': True, 'dataset': 'waveform', 'e0': 0.4, 'e1': 0.4, 'equalize_prior': False, 'episodes': 2000, 'batchsize': 4, 'hidsize': [16, 16], 'lr': 0.001}
# -----------------------------------
# | [PAM] margin = 0     | 0.501    |
# | [PAM] margin = 0.125 | 0.55     |
# | [PAM] margin = 0.25  | 0.552    |
# | [PAM] margin = 0.5   | 0.562    |
# | [PAM] margin = 1     | 0.567    |
# -----------------------------------
# ----------------------------------
# | [PAM] accuracy max  | 0.816    |
# | [PAM] accuracy mean | 0.788    |
# | [PAM] accuracy min  | 0.741    |
# | [PAM] accuracy std  | 0.0239   |
# | [PAM] best margin   | 1        |
# ----------------------------------

# %%
from runner import run
run({
    'dataset': 'waveform', 
    'e0': 0.4, 'e1': 0.4,
    'episodes': 1000,
#     'batchsize': 16,
#     'hidsize': [16, 16],
#     'lr': 0.005,
    'test_size': 0.15,
    'val_size': 0.1,
    'dropout': 0, 
    'normalize': True,
    'equalize_prior': False,
    'alpha': 1.,
    'loss': 'bce',
    'activation': 'relu',
    'verbose': True,
})
# Out:
# Logging to logs/nn/19-08-20-23-18-50
# {'dataset': 'waveform', 'e0': 0.4, 'e1': 0.4, 'episodes': 1000, 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'equalize_prior': False, 'alpha': 1.0, 'loss': 'bce', 'activation': 'relu', 'verbose': True}
# batchsize: 1	lr:0.0005	hidsize:  8	acc:0.487
# batchsize: 1	lr:0.0005	hidsize: 16	acc:0.61
# batchsize: 1	lr:0.0005	hidsize: 32	acc:0.548
# batchsize: 1	lr:0.0005	hidsize: 64	acc:0.611
# batchsize: 1	lr: 0.001	hidsize:  8	acc:0.543
# batchsize: 1	lr: 0.001	hidsize: 16	acc:0.621
# batchsize: 1	lr: 0.001	hidsize: 32	acc:0.568
# batchsize: 1	lr: 0.001	hidsize: 64	acc:0.646
# batchsize: 1	lr: 0.005	hidsize:  8	acc:0.627
# batchsize: 1	lr: 0.005	hidsize: 16	acc:0.63
# batchsize: 1	lr: 0.005	hidsize: 32	acc:0.618
# batchsize: 1	lr: 0.005	hidsize: 64	acc:0.655
# batchsize: 1	lr:  0.01	hidsize:  8	acc:0.618
# batchsize: 1	lr:  0.01	hidsize: 16	acc:0.6
# batchsize: 1	lr:  0.01	hidsize: 32	acc:0.646
# batchsize: 1	lr:  0.01	hidsize: 64	acc:0.59
# batchsize: 1	lr:  0.05	hidsize:  8	acc:0.554
# batchsize: 1	lr:  0.05	hidsize: 16	acc:0.553
# batchsize: 1	lr:  0.05	hidsize: 32	acc:0.562
# batchsize: 1	lr:  0.05	hidsize: 64	acc:0.608
# batchsize: 4	lr:0.0005	hidsize:  8	acc:0.584
# batchsize: 4	lr:0.0005	hidsize: 16	acc:0.669
# batchsize: 4	lr:0.0005	hidsize: 32	acc:0.735
# batchsize: 4	lr:0.0005	hidsize: 64	acc:0.761
# batchsize: 4	lr: 0.001	hidsize:  8	acc:0.631
# batchsize: 4	lr: 0.001	hidsize: 16	acc:0.744
# batchsize: 4	lr: 0.001	hidsize: 32	acc:0.784
# batchsize: 4	lr: 0.001	hidsize: 64	acc:0.771
# batchsize: 4	lr: 0.005	hidsize:  8	acc:0.724
# batchsize: 4	lr: 0.005	hidsize: 16	acc:0.742
# batchsize: 4	lr: 0.005	hidsize: 32	acc:0.778
# batchsize: 4	lr: 0.005	hidsize: 64	acc:0.724
# batchsize: 4	lr:  0.01	hidsize:  8	acc:0.693
# batchsize: 4	lr:  0.01	hidsize: 16	acc:0.735
# batchsize: 4	lr:  0.01	hidsize: 32	acc:0.718
# batchsize: 4	lr:  0.01	hidsize: 64	acc:0.713
# batchsize: 4	lr:  0.05	hidsize:  8	acc:0.588
# batchsize: 4	lr:  0.05	hidsize: 16	acc:0.697
# batchsize: 4	lr:  0.05	hidsize: 32	acc:0.717
# batchsize: 4	lr:  0.05	hidsize: 64	acc:0.719
# batchsize:16	lr:0.0005	hidsize:  8	acc:0.659
# batchsize:16	lr:0.0005	hidsize: 16	acc:0.753
# batchsize:16	lr:0.0005	hidsize: 32	acc:0.778
# batchsize:16	lr:0.0005	hidsize: 64	acc:0.785
# batchsize:16	lr: 0.001	hidsize:  8	acc:0.73
# batchsize:16	lr: 0.001	hidsize: 16	acc:0.791
# batchsize:16	lr: 0.001	hidsize: 32	acc:0.793
# batchsize:16	lr: 0.001	hidsize: 64	acc:0.791
# batchsize:16	lr: 0.005	hidsize:  8	acc:0.75
# batchsize:16	lr: 0.005	hidsize: 16	acc:0.783
# batchsize:16	lr: 0.005	hidsize: 32	acc:0.794
# batchsize:16	lr: 0.005	hidsize: 64	acc:0.789
# batchsize:16	lr:  0.01	hidsize:  8	acc:0.748
# batchsize:16	lr:  0.01	hidsize: 16	acc:0.803
# batchsize:16	lr:  0.01	hidsize: 32	acc:0.793
# batchsize:16	lr:  0.01	hidsize: 64	acc:0.793
# batchsize:16	lr:  0.05	hidsize:  8	acc:0.642
# batchsize:16	lr:  0.05	hidsize: 16	acc:0.771
# batchsize:16	lr:  0.05	hidsize: 32	acc:0.777
# batchsize:16	lr:  0.05	hidsize: 64	acc:0.781
# batchsize:64	lr:0.0005	hidsize:  8	acc:0.74
# batchsize:64	lr:0.0005	hidsize: 16	acc:0.8
# batchsize:64	lr:0.0005	hidsize: 32	acc:0.789
# batchsize:64	lr:0.0005	hidsize: 64	acc:0.79
# batchsize:64	lr: 0.001	hidsize:  8	acc:0.759
# batchsize:64	lr: 0.001	hidsize: 16	acc:0.798
# batchsize:64	lr: 0.001	hidsize: 32	acc:0.792
# batchsize:64	lr: 0.001	hidsize: 64	acc:0.791
# batchsize:64	lr: 0.005	hidsize:  8	acc:0.803
# batchsize:64	lr: 0.005	hidsize: 16	acc:0.797
# batchsize:64	lr: 0.005	hidsize: 32	acc:0.789
# batchsize:64	lr: 0.005	hidsize: 64	acc:0.793
# batchsize:64	lr:  0.01	hidsize:  8	acc:0.803
# batchsize:64	lr:  0.01	hidsize: 16	acc:0.806
# batchsize:64	lr:  0.01	hidsize: 32	acc:0.787
# batchsize:64	lr:  0.01	hidsize: 64	acc:0.795
# batchsize:64	lr:  0.05	hidsize:  8	acc:0.792
# batchsize:64	lr:  0.05	hidsize: 16	acc:0.774
# batchsize:64	lr:  0.05	hidsize: 32	acc:0.788
# batchsize:64	lr:  0.05	hidsize: 64	acc:0.797
# --------------------------------------
# | [NN] best batchsize     | 64       |
# | [NN] best hidsize       | [16, 16] |
# | [NN] best learning rate | 0.01     |
# --------------------------------------
# --------------------------------------
# | [NN] with bce loss      | 0.725    |
# | [NN] with peer loss     | 0.806    |
# | [NN] with surrogate ... | 0.818    |
# --------------------------------------
# Logging to logs/svm/19-08-20-23-35-06
# {'dataset': 'waveform', 'e0': 0.4, 'e1': 0.4, 'episodes': 1000, 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'equalize_prior': False, 'alpha': 1.0, 'loss': 'bce', 'activation': 'relu', 'verbose': True}
# --------------------------------
# | [C-SVM] C1 = 0.1  | 0.663    |
# | [C-SVM] C1 = 0.2  | 0.663    |
# | [C-SVM] C1 = 0.25 | 0.663    |
# | [C-SVM] C1 = 0.33 | 0.663    |
# | [C-SVM] C1 = 0.5  | 0.663    |
# | [C-SVM] C1 = 1.0  | 0.848    |
# | [C-SVM] C1 = 10.0 | 0.337    |
# | [C-SVM] C1 = 2.0  | 0.374    |
# | [C-SVM] C1 = 3.0  | 0.339    |
# | [C-SVM] C1 = 4.0  | 0.337    |
# | [C-SVM] C1 = 5.0  | 0.337    |
# --------------------------------
# ------------------------------------
# | [C-SVM] accuracy max  | 0.857    |
# | [C-SVM] accuracy mean | 0.839    |
# | [C-SVM] accuracy min  | 0.808    |
# | [C-SVM] accuracy std  | 0.0156   |
# | [C-SVM] best C1       | 1        |
# ------------------------------------
# Logging to logs/pam/19-08-20-23-35-20
# {'dataset': 'waveform', 'e0': 0.4, 'e1': 0.4, 'episodes': 1000, 'test_size': 0.15, 'val_size': 0.1, 'dropout': 0, 'normalize': True, 'equalize_prior': False, 'alpha': 1.0, 'loss': 'bce', 'activation': 'relu', 'verbose': True}
# ---------------------------------
# | [PAM] margin = 0.0 | 0.535    |
# | [PAM] margin = 0.1 | 0.694    |
# | [PAM] margin = 0.2 | 0.762    |
# | [PAM] margin = 0.3 | 0.745    |
# | [PAM] margin = 0.4 | 0.753    |
# | [PAM] margin = 0.5 | 0.771    |
# ---------------------------------
# ----------------------------------
# | [PAM] accuracy max  | 0.816    |
# | [PAM] accuracy mean | 0.783    |
# | [PAM] accuracy min  | 0.717    |
# | [PAM] accuracy std  | 0.0293   |
# | [PAM] best margin   | 0.5      |
# ----------------------------------
